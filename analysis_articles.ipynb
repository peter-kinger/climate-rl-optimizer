# %%
# 如果你能得到不同动作序列下的 (𝑟1,𝑟2)可以：

# 画出策略在 reward space 中的分布图（Pareto前沿）：

# 假设多种策略带来 (R1, R2)
import matplotlib.pyplot as plt
r1 = [0.5, 0.6, 0.8, 0.7]
r2 = [0.2, 0.3, 0.5, 0.4]
plt.scatter(r1, r2)
plt.xlabel("Objective 1")
plt.ylabel("Objective 2")
plt.title("Pareto Front - Multi-objective Tradeoff")
plt.show()
