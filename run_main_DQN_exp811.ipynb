# %% [markdown]
# # RL 训练

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import scipy.io
from matplotlib.gridspec import GridSpec
import math
import random
import torch

from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.logger import configure
from stable_baselines3.common.monitor import Monitor
from stable_baselines3 import PPO 
from stable_baselines3 import DQN

# 导入 BaseCallback
from stable_baselines3.common.callbacks import BaseCallback

import sys
import os

# 将 src 目录添加到模块搜索路径
sys.path.append(os.path.abspath('src'))

# 导入 IEMEnv 类
from src.envs.iseec_lx_v4_mdp_plot import IEMEnv
from src.utils.run_debug_plot import save_data 
from src.utils.run_debug_plot import save_plot_NSM_data
from src.utils.run_debug_plot import save_plot_SSM_data

from src.utils.run_debug_plot import save_future_data
from src.utils.run_debug_plot import save_plot_NSM_future_data
from src.utils.run_debug_plot import save_plot_SSM_future_data

from src.utils.run_debug_plot import plot_episode_reward
from src.utils.run_debug_plot import plot_episode_reward_simple
from src.utils.run_debug_plot import plot_3D_run

# %% [markdown]
# 定义保存位置参数
#
# > 所有的关键参数都放在最前面

# %%
# 增加随机种子的定义
def set_global_seed(seed):
    """设置全局随机种子"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False


# 设置全局种子
# SEED = 42 # 非测试，不指定种子
# set_global_seed(SEED)

# 全新的超参数配置过程，都放在一起
base_config = {
    # MDP 元素
    "custom_reward_type" : "multi_objective_single_T_a_exp811",
    # 环境 & 策略
    "env_id":   "iseec_lx_v4_mdp_plot",
    "rl_model_name": "DQN",
    "policy":   "MlpPolicy",
    "network_name" : "Netxxx_no_big_env",
    # 训练时长
    "total_timesteps_diy": 700000,
    "policy_kwargs_diy" : "dict_pi_vf_default", # for example: policy_kwargs = dict(activation_fn=th.nn.ReLU,net_arch=[256, 256, dict(pi=[128, 64], vf=[128, 64])])
    # 优化器 & 网络
    "hyperparams_diy": "default", 
    # "learning_rate":   3e-4,
    # "ent_coef":        0.0,
    # "batch_size":      64,
    # "n_epochs":        10,
    # 回放 & 更新频率（PPO 固定写法示例）
    # "gamma":           0.99,
    # "clip_range":      0.2,
    # "gae_lambda":      0.95,
    # 随机种子
    "use_random_reset": False, # 是否使用随机重置
    "seed":            42,
}


############### 具体的配置细节##############
# 设置保存的日志名字：
log_name = f'{base_config["env_id"]}_{base_config["rl_model_name"]}_{base_config["custom_reward_type"]}_{int(base_config["total_timesteps_diy"])}_{base_config["hyperparams_diy"]}' 
os.makedirs(f'./logs/{log_name}', exist_ok=True) # 创建日志目录

# 相当于接口部分
custom_reward_type = base_config["custom_reward_type"]
network_name = base_config["network_name"]
rl_model_name = base_config["rl_model_name"]
total_timesteps_diy = base_config["total_timesteps_diy"]
policy_kwargs_diy = base_config["policy_kwargs_diy"] 

# 设置日志保存路径和格式
new_logger = configure(
    f"logs/{log_name}",  # tmp_path 路径保存位置
    # ["stdout",     # 终端输出
    [
     "csv",        # CSV文件
     "tensorboard", # Tensorboard格式
     "json"        # JSON格式
    ]
)

# %% [markdown]
# ### 定义环境

# %%
env = IEMEnv(reward_type=base_config["custom_reward_type"])
env_monitor = Monitor(env, f'./logs/{log_name}')
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# ### 定义算法

# %%
# # 定义模型
# model = PPO(
#     "MlpPolicy", 
#     env_monitor, 
#     # ent_coef=0.01, # 增加策略寻找的鼓励，但是 suggestion 暂时不要改变
#     verbose=1,
#     )

model = DQN(
    "MlpPolicy", 
    env_monitor, 
    verbose=1,
    )

model.set_logger(new_logger) # set the parameter of the logger
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
# check 环境
from stable_baselines3.common.env_checker import check_env
# check_env(env_monitor)
log_name

print("Action space sample:", env.action_space.sample())
# print("Observation space sample:", env.observation_space.sample())

# type(env.action_space), type(env.observation_space)
print("Action space sample:", env.action_space.sample())
print("Observation space sample:", env.observation_space.sample())

print(model.policy)
# Out:
# Action space sample: 13
# Action space sample: 9
# Observation space sample: [ 1.0466407   0.76266839  0.94199472  0.31326114  0.56860426 -0.26327149
#  -0.78192519 -0.50045052  0.61222647 -0.05563534]
# DQNPolicy(
#   (q_net): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=16, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=16, bias=True)
#     )
#   )
# )

# %% [markdown]
# ### 模型训练

# %%
def plot_callback_reward(metrics):
    """绘制训练过程中的奖励曲线
    
    Args:
        metrics (dict): 包含训练指标的字典，需要包含以下键：
            - rewards: 原始奖励列表
            - moving_avg_rewards: 移动平均奖励列表
            - moving_std_rewards: 移动标准差列表
            - episodes: 总回合数
            - step_idx: 当前步数
    """
    plt.figure(figsize=(20, 5))
    
    # 创建主图
    plt.subplot(131)
    plt.title(f'Step: {metrics["step_idx"]}, Latest reward: {metrics["rewards"][-1]:.2f}\n'
              f'Episode: {metrics["episodes"]}, Moving avg: {metrics["moving_avg_rewards"][-1]:.2f}')
    
    # 绘制原始奖励
    episodes = range(len(metrics["rewards"]))
    plt.plot(episodes, metrics["rewards"], 
             label='Raw rewards', color='gray', alpha=0.3)
    
    # 绘制移动平均
    plt.plot(episodes, metrics["moving_avg_rewards"],
             label='Moving average', color='blue', linewidth=2)
    
    # 添加标准差区域
    moving_avg = np.array(metrics["moving_avg_rewards"])
    moving_std = np.array(metrics["moving_std_rewards"])
    
    # 0.25倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.25 * moving_std,
                    moving_avg + 0.25 * moving_std,
                    color='b', alpha=0.1,
                    label='0.25 std range')
    
    # 0.5倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.5 * moving_std,
                    moving_avg + 0.5 * moving_std,
                    color='b', alpha=0.1,
                    label='0.5 std range')
    
    # 设置坐标轴和标签
    plt.xlabel('Episodes')
    plt.ylabel('Episode Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

class TrainingMonitorCallback(BaseCallback):
    def __init__(self, verbose=1, window_size=50):
        super().__init__(verbose)
        self.window_size = window_size
        # Initialize data dictionary to store metrics
        self.data = {
            "rewards": [],
            "moving_avg_rewards": [],
            "moving_std_rewards": [],
            "episodes": 0,
            "step_idx": 0
        }
        self.episode_rewards = 0
        
    def _on_step(self):
        # Accumulate rewards for current episode
        reward = self.locals.get('rewards')[0]
        self.episode_rewards += reward
        self.data["step_idx"] += 1
        
        # When episode ends, update all metrics
        if self.locals.get('dones')[0]:
            # Store raw reward
            self.data["rewards"].append(self.episode_rewards)
            
            # Calculate moving average and std
            recent_rewards = self.data["rewards"][-self.window_size:]
            moving_avg = np.mean(recent_rewards)
            moving_std = np.std(recent_rewards) if len(recent_rewards) > 1 else 0
            
            # Store calculated metrics
            self.data["moving_avg_rewards"].append(moving_avg)
            self.data["moving_std_rewards"].append(moving_std)
            self.data["episodes"] += 1
            
            # Print progress
            print(f"Episode {self.data['episodes']} finished with reward: {self.episode_rewards:.2f}")
            print(f"Moving average (last {len(recent_rewards)} episodes): {moving_avg:.2f} ± {moving_std:.2f}")
            
            # Reset episode rewards
            self.episode_rewards = 0
            
        return True
    
    def get_metrics(self):
        """Return the collected metrics"""
        return self.data
    
# Create callback with custom window size
callback = TrainingMonitorCallback(window_size=50)

# Train the model
model.learn(
    total_timesteps=int(total_timesteps_diy),
    callback=callback,
    log_interval=1
)


# After training, get metrics for plotting
metrics = callback.get_metrics()

# Plot rewards using the plot_callback_reward function
plot_callback_reward(metrics)
# Out:
# Episode 1 finished with reward: -41.96
# Moving average (last 1 episodes): -41.96 ± 0.00
# Episode 2 finished with reward: -40.05
# Moving average (last 2 episodes): -41.01 ± 0.96
# Episode 3 finished with reward: -41.29
# Moving average (last 3 episodes): -41.10 ± 0.79
# Episode 4 finished with reward: -8.84
# Moving average (last 4 episodes): -33.04 ± 13.98
# Episode 5 finished with reward: -58.38
# Moving average (last 5 episodes): -38.10 ± 16.10
# Episode 6 finished with reward: -29.90
# Moving average (last 6 episodes): -36.74 ± 15.01
# Episode 7 finished with reward: -46.70
# Moving average (last 7 episodes): -38.16 ± 14.33
# Episode 8 finished with reward: -25.24
# Moving average (last 8 episodes): -36.54 ± 14.07
# Episode 9 finished with reward: -43.32
# Moving average (last 9 episodes): -37.30 ± 13.43
# Episode 10 finished with reward: -15.69
# Moving average (last 10 episodes): -35.14 ± 14.30
# Episode 11 finished with reward: -34.54
# Moving average (last 11 episodes): -35.08 ± 13.63
# Episode 12 finished with reward: -15.67
# Moving average (last 12 episodes): -33.47 ± 14.11
# Episode 13 finished with reward: -60.79
# Moving average (last 13 episodes): -35.57 ± 15.39
# Episode 14 finished with reward: -62.66
# Moving average (last 14 episodes): -37.50 ± 16.39
# Episode 15 finished with reward: -79.98
# Moving average (last 15 episodes): -40.33 ± 19.05
# Episode 16 finished with reward: -69.83
# Moving average (last 16 episodes): -42.18 ± 19.78
# Episode 17 finished with reward: -48.45
# Moving average (last 17 episodes): -42.55 ± 19.25
# Episode 18 finished with reward: -44.88
# Moving average (last 18 episodes): -42.68 ± 18.71
# Episode 19 finished with reward: -78.56
# Moving average (last 19 episodes): -44.57 ± 19.90
# Episode 20 finished with reward: -43.48
# Moving average (last 20 episodes): -44.51 ± 19.40
# Episode 21 finished with reward: -94.06
# Moving average (last 21 episodes): -46.87 ± 21.67
# Episode 22 finished with reward: -19.34
# Moving average (last 22 episodes): -45.62 ± 21.94
# Episode 23 finished with reward: -112.69
# Moving average (last 23 episodes): -48.54 ± 25.44
# Episode 24 finished with reward: 12.28
# Moving average (last 24 episodes): -46.00 ± 27.71
# Episode 25 finished with reward: -75.16
# Moving average (last 25 episodes): -47.17 ± 27.75
# Episode 26 finished with reward: -34.46
# Moving average (last 26 episodes): -46.68 ± 27.32
# Episode 27 finished with reward: -60.90
# Moving average (last 27 episodes): -47.21 ± 26.94
# Episode 28 finished with reward: -40.01
# Moving average (last 28 episodes): -46.95 ± 26.49
# Episode 29 finished with reward: 12.07
# Moving average (last 29 episodes): -44.91 ± 28.17
# Episode 30 finished with reward: -65.71
# Moving average (last 30 episodes): -45.61 ± 27.95
# Episode 31 finished with reward: -28.08
# Moving average (last 31 episodes): -45.04 ± 27.67
# Episode 32 finished with reward: -28.91
# Moving average (last 32 episodes): -44.54 ± 27.37
# Episode 33 finished with reward: -41.89
# Moving average (last 33 episodes): -44.46 ± 26.96
# Episode 34 finished with reward: -32.26
# Moving average (last 34 episodes): -44.10 ± 26.64
# Episode 35 finished with reward: -81.06
# Moving average (last 35 episodes): -45.15 ± 26.97
# Episode 36 finished with reward: -80.48
# Moving average (last 36 episodes): -46.14 ± 27.22
# Episode 37 finished with reward: -74.52
# Moving average (last 37 episodes): -46.90 ± 27.24
# Episode 38 finished with reward: -35.62
# Moving average (last 38 episodes): -46.61 ± 26.94
# Episode 39 finished with reward: -19.58
# Moving average (last 39 episodes): -45.91 ± 26.93
# Episode 40 finished with reward: -13.78
# Moving average (last 40 episodes): -45.11 ± 27.06
# Episode 41 finished with reward: -92.37
# Moving average (last 41 episodes): -46.26 ± 27.71
# Episode 42 finished with reward: -54.84
# Moving average (last 42 episodes): -46.47 ± 27.41
# Episode 43 finished with reward: -23.96
# Moving average (last 43 episodes): -45.94 ± 27.30
# Episode 44 finished with reward: 37.28
# Moving average (last 44 episodes): -44.05 ± 29.70
# Episode 45 finished with reward: -49.09
# Moving average (last 45 episodes): -44.16 ± 29.38
# Episode 46 finished with reward: -37.06
# Moving average (last 46 episodes): -44.01 ± 29.07
# Episode 47 finished with reward: -58.98
# Moving average (last 47 episodes): -44.33 ± 28.84
# Episode 48 finished with reward: -64.73
# Moving average (last 48 episodes): -44.75 ± 28.69
# Episode 49 finished with reward: -89.10
# Moving average (last 49 episodes): -45.66 ± 29.08
# Episode 50 finished with reward: -19.77
# Moving average (last 50 episodes): -45.14 ± 29.02
# Episode 51 finished with reward: -43.81
# Moving average (last 50 episodes): -45.18 ± 29.01
# Episode 52 finished with reward: -70.51
# Moving average (last 50 episodes): -45.79 ± 29.22
# Episode 53 finished with reward: 22.33
# Moving average (last 50 episodes): -44.51 ± 30.73
# Episode 54 finished with reward: -1.45
# Moving average (last 50 episodes): -44.37 ± 30.92
# Episode 55 finished with reward: -3.63
# Moving average (last 50 episodes): -43.27 ± 31.37
# Episode 56 finished with reward: -26.51
# Moving average (last 50 episodes): -43.20 ± 31.40
# Episode 57 finished with reward: -9.54
# Moving average (last 50 episodes): -42.46 ± 31.75
# Episode 58 finished with reward: -61.73
# Moving average (last 50 episodes): -43.19 ± 31.76
# Episode 59 finished with reward: -49.62
# Moving average (last 50 episodes): -43.32 ± 31.78
# Episode 60 finished with reward: -52.54
# Moving average (last 50 episodes): -44.05 ± 31.55
# Episode 61 finished with reward: -14.45
# Moving average (last 50 episodes): -43.65 ± 31.80
# Episode 62 finished with reward: -88.42
# Moving average (last 50 episodes): -45.11 ± 32.15
# Episode 63 finished with reward: -56.71
# Moving average (last 50 episodes): -45.02 ± 32.11
# Episode 64 finished with reward: -12.13
# Moving average (last 50 episodes): -44.01 ± 32.34
# Episode 65 finished with reward: -89.87
# Moving average (last 50 episodes): -44.21 ± 32.59
# Episode 66 finished with reward: -21.96
# Moving average (last 50 episodes): -43.25 ± 32.52
# Episode 67 finished with reward: -35.13
# Moving average (last 50 episodes): -42.99 ± 32.53
# Episode 68 finished with reward: -61.39
# Moving average (last 50 episodes): -43.32 ± 32.63
# Episode 69 finished with reward: -58.31
# Moving average (last 50 episodes): -42.91 ± 32.32
# Episode 70 finished with reward: -25.14
# Moving average (last 50 episodes): -42.55 ± 32.41
# Episode 71 finished with reward: -53.78
# Moving average (last 50 episodes): -41.74 ± 31.61
# Episode 72 finished with reward: -32.77
# Moving average (last 50 episodes): -42.01 ± 31.48
# Episode 73 finished with reward: 10.07
# Moving average (last 50 episodes): -39.55 ± 30.65
# Episode 74 finished with reward: -120.34
# Moving average (last 50 episodes): -42.21 ± 31.77
# Episode 75 finished with reward: -57.64
# Moving average (last 50 episodes): -41.86 ± 31.50
# Episode 76 finished with reward: -51.37
# Moving average (last 50 episodes): -42.19 ± 31.50
# Episode 77 finished with reward: -51.57
# Moving average (last 50 episodes): -42.01 ± 31.42
# Episode 78 finished with reward: -73.09
# Moving average (last 50 episodes): -42.67 ± 31.72
# Episode 79 finished with reward: -115.78
# Moving average (last 50 episodes): -45.23 ± 32.35
# Episode 80 finished with reward: -78.69
# Moving average (last 50 episodes): -45.49 ± 32.56
# Episode 81 finished with reward: -46.27
# Moving average (last 50 episodes): -45.85 ± 32.47
# Episode 82 finished with reward: -40.23
# Moving average (last 50 episodes): -46.08 ± 32.39
# Episode 83 finished with reward: 20.02
# Moving average (last 50 episodes): -44.84 ± 33.68
# Episode 84 finished with reward: -33.99
# Moving average (last 50 episodes): -44.87 ± 33.67
# Episode 85 finished with reward: -96.25
# Moving average (last 50 episodes): -45.18 ± 34.06
# Episode 86 finished with reward: -69.78
# Moving average (last 50 episodes): -44.96 ± 33.87
# Episode 87 finished with reward: -64.05
# Moving average (last 50 episodes): -44.75 ± 33.72
# Episode 88 finished with reward: -59.79
# Moving average (last 50 episodes): -45.24 ± 33.76
# Episode 89 finished with reward: 3.63
# Moving average (last 50 episodes): -44.77 ± 34.27
# Episode 90 finished with reward: 16.93
# Moving average (last 50 episodes): -44.16 ± 35.08
# Episode 91 finished with reward: -48.06
# Moving average (last 50 episodes): -43.27 ± 34.41
# Episode 92 finished with reward: -79.19
# Moving average (last 50 episodes): -43.76 ± 34.74
# Episode 93 finished with reward: -54.53
# Moving average (last 50 episodes): -44.37 ± 34.65
# Episode 94 finished with reward: -32.10
# Moving average (last 50 episodes): -45.76 ± 32.69
# Episode 95 finished with reward: -45.54
# Moving average (last 50 episodes): -45.69 ± 32.69
# Episode 96 finished with reward: -86.31
# Moving average (last 50 episodes): -46.67 ± 33.15
# Episode 97 finished with reward: -55.80
# Moving average (last 50 episodes): -46.61 ± 33.13
# Episode 98 finished with reward: -27.97
# Moving average (last 50 episodes): -45.87 ± 33.13
# Episode 99 finished with reward: -53.61
# Moving average (last 50 episodes): -45.16 ± 32.57
# Episode 100 finished with reward: -97.52
# Moving average (last 50 episodes): -46.72 ± 33.17
# Episode 101 finished with reward: -90.56
# Moving average (last 50 episodes): -47.65 ± 33.73
# Episode 102 finished with reward: -103.85
# Moving average (last 50 episodes): -48.32 ± 34.49
# Episode 103 finished with reward: -38.46
# Moving average (last 50 episodes): -49.54 ± 33.02
# Episode 104 finished with reward: -53.25
# Moving average (last 50 episodes): -50.57 ± 32.30
# Episode 105 finished with reward: -30.62
# Moving average (last 50 episodes): -51.11 ± 31.73
# Episode 106 finished with reward: -65.92
# Moving average (last 50 episodes): -51.90 ± 31.60
# Episode 107 finished with reward: -61.40
# Moving average (last 50 episodes): -52.94 ± 31.04
# Episode 108 finished with reward: -85.76
# Moving average (last 50 episodes): -53.42 ± 31.36
# Episode 109 finished with reward: -43.84
# Moving average (last 50 episodes): -53.30 ± 31.38
# Episode 110 finished with reward: -58.52
# Moving average (last 50 episodes): -53.42 ± 31.39
# Episode 111 finished with reward: -92.84
# Moving average (last 50 episodes): -54.99 ± 31.36
# Episode 112 finished with reward: -54.40
# Moving average (last 50 episodes): -54.31 ± 31.00
# Episode 113 finished with reward: -56.04
# Moving average (last 50 episodes): -54.30 ± 31.00
# Episode 114 finished with reward: -43.00
# Moving average (last 50 episodes): -54.91 ± 30.45
# Episode 115 finished with reward: -84.39
# Moving average (last 50 episodes): -54.80 ± 30.34
# Episode 116 finished with reward: -3.99
# Moving average (last 50 episodes): -54.44 ± 30.83
# Episode 117 finished with reward: -52.53
# Moving average (last 50 episodes): -54.79 ± 30.70
# Episode 118 finished with reward: -108.68
# Moving average (last 50 episodes): -55.74 ± 31.61
# Episode 119 finished with reward: 10.80
# Moving average (last 50 episodes): -54.36 ± 32.95
# Episode 120 finished with reward: -185.05
# Moving average (last 50 episodes): -57.55 ± 37.41
# Episode 121 finished with reward: -13.22
# Moving average (last 50 episodes): -56.74 ± 37.92
# Episode 122 finished with reward: -37.03
# Moving average (last 50 episodes): -56.83 ± 37.87
# Episode 123 finished with reward: -84.81
# Moving average (last 50 episodes): -58.73 ± 36.84
# Episode 124 finished with reward: -90.51
# Moving average (last 50 episodes): -58.13 ± 36.07
# Episode 125 finished with reward: -101.07
# Moving average (last 50 episodes): -59.00 ± 36.57
# Episode 126 finished with reward: -55.24
# Moving average (last 50 episodes): -59.07 ± 36.55
# Episode 127 finished with reward: -75.44
# Moving average (last 50 episodes): -59.55 ± 36.61
# Episode 128 finished with reward: -14.52
# Moving average (last 50 episodes): -58.38 ± 37.09
# Episode 129 finished with reward: -14.60
# Moving average (last 50 episodes): -56.36 ± 36.66
# Episode 130 finished with reward: -17.13
# Moving average (last 50 episodes): -55.13 ± 36.92
# Episode 131 finished with reward: -88.33
# Moving average (last 50 episodes): -55.97 ± 37.19
# Episode 132 finished with reward: -40.85
# Moving average (last 50 episodes): -55.98 ± 37.19
# Episode 133 finished with reward: -0.75
# Moving average (last 50 episodes): -56.39 ± 36.44
# Episode 134 finished with reward: -0.93
# Moving average (last 50 episodes): -55.73 ± 37.14
# Episode 135 finished with reward: -7.84
# Moving average (last 50 episodes): -53.97 ± 37.27
# Episode 136 finished with reward: -142.49
# Moving average (last 50 episodes): -55.42 ± 39.23
# Episode 137 finished with reward: -63.04
# Moving average (last 50 episodes): -55.40 ± 39.22
# Episode 138 finished with reward: -44.20
# Moving average (last 50 episodes): -55.09 ± 39.25
# Episode 139 finished with reward: 0.91
# Moving average (last 50 episodes): -55.14 ± 39.17
# Episode 140 finished with reward: -64.36
# Moving average (last 50 episodes): -56.77 ± 37.81
# Episode 141 finished with reward: -45.58
# Moving average (last 50 episodes): -56.72 ± 37.82
# Episode 142 finished with reward: -57.87
# Moving average (last 50 episodes): -56.29 ± 37.68
# Episode 143 finished with reward: -117.54
# Moving average (last 50 episodes): -57.55 ± 38.64
# Episode 144 finished with reward: -84.15
# Moving average (last 50 episodes): -58.59 ± 38.65
# Episode 145 finished with reward: -10.51
# Moving average (last 50 episodes): -57.89 ± 39.19
# Episode 146 finished with reward: -78.91
# Moving average (last 50 episodes): -57.74 ± 39.10
# Episode 147 finished with reward: -105.72
# Moving average (last 50 episodes): -58.74 ± 39.67
# Episode 148 finished with reward: -91.41
# Moving average (last 50 episodes): -60.01 ± 39.68
# Episode 149 finished with reward: -70.66
# Moving average (last 50 episodes): -60.35 ± 39.69
# Episode 150 finished with reward: -56.90
# Moving average (last 50 episodes): -59.54 ± 39.34
# Episode 151 finished with reward: -42.70
# Moving average (last 50 episodes): -58.58 ± 39.15
# Episode 152 finished with reward: -40.92
# Moving average (last 50 episodes): -57.32 ± 38.69
# Episode 153 finished with reward: 4.80
# Moving average (last 50 episodes): -56.46 ± 39.57
# Episode 154 finished with reward: 12.41
# Moving average (last 50 episodes): -55.15 ± 40.73
# Episode 155 finished with reward: -33.97
# Moving average (last 50 episodes): -55.21 ± 40.69
# Episode 156 finished with reward: -74.96
# Moving average (last 50 episodes): -55.39 ± 40.76
# Episode 157 finished with reward: -75.89
# Moving average (last 50 episodes): -55.68 ± 40.85
# Episode 158 finished with reward: -34.84
# Moving average (last 50 episodes): -54.66 ± 40.73
# Episode 159 finished with reward: -31.69
# Moving average (last 50 episodes): -54.42 ± 40.83
# Episode 160 finished with reward: -83.38
# Moving average (last 50 episodes): -54.92 ± 41.02
# Episode 161 finished with reward: 14.63
# Moving average (last 50 episodes): -52.77 ± 41.79
# Episode 162 finished with reward: -1.18
# Moving average (last 50 episodes): -51.71 ± 42.41
# Episode 163 finished with reward: -51.82
# Moving average (last 50 episodes): -51.62 ± 42.40
# Episode 164 finished with reward: -74.45
# Moving average (last 50 episodes): -52.25 ± 42.50
# Episode 165 finished with reward: -49.64
# Moving average (last 50 episodes): -51.55 ± 42.25
# Episode 166 finished with reward: -82.82
# Moving average (last 50 episodes): -53.13 ± 41.92
# Episode 167 finished with reward: -41.67
# Moving average (last 50 episodes): -52.91 ± 41.95
# Episode 168 finished with reward: -39.47
# Moving average (last 50 episodes): -51.53 ± 41.22
# Episode 169 finished with reward: -23.88
# Moving average (last 50 episodes): -52.22 ± 40.45
# Episode 170 finished with reward: -28.97
# Moving average (last 50 episodes): -49.10 ± 35.84
# Episode 171 finished with reward: -75.83
# Moving average (last 50 episodes): -50.35 ± 35.66
# Episode 172 finished with reward: -34.58
# Moving average (last 50 episodes): -50.31 ± 35.68
# Episode 173 finished with reward: -64.97
# Moving average (last 50 episodes): -49.91 ± 35.40
# Episode 174 finished with reward: -101.98
# Moving average (last 50 episodes): -50.14 ± 35.70
# Episode 175 finished with reward: -91.77
# Moving average (last 50 episodes): -49.95 ± 35.46
# Episode 176 finished with reward: -50.05
# Moving average (last 50 episodes): -49.85 ± 35.45
# Episode 177 finished with reward: -51.72
# Moving average (last 50 episodes): -49.37 ± 35.26
# Episode 178 finished with reward: -109.64
# Moving average (last 50 episodes): -51.28 ± 35.89
# Episode 179 finished with reward: -74.82
# Moving average (last 50 episodes): -52.48 ± 35.65
# Episode 180 finished with reward: 1.54
# Moving average (last 50 episodes): -52.11 ± 36.11
# Episode 181 finished with reward: -38.00
# Moving average (last 50 episodes): -51.10 ± 35.79
# Episode 182 finished with reward: -40.91
# Moving average (last 50 episodes): -51.10 ± 35.79
# Episode 183 finished with reward: -5.14
# Moving average (last 50 episodes): -51.19 ± 35.67
# Episode 184 finished with reward: -43.12
# Moving average (last 50 episodes): -52.03 ± 34.96
# Episode 185 finished with reward: -54.21
# Moving average (last 50 episodes): -52.96 ± 34.39
# Episode 186 finished with reward: -73.65
# Moving average (last 50 episodes): -51.58 ± 32.08
# Episode 187 finished with reward: -111.34
# Moving average (last 50 episodes): -52.55 ± 33.12
# Episode 188 finished with reward: -41.23
# Moving average (last 50 episodes): -52.49 ± 33.14
# Episode 189 finished with reward: -64.58
# Moving average (last 50 episodes): -53.80 ± 32.28
# Episode 190 finished with reward: -55.24
# Moving average (last 50 episodes): -53.62 ± 32.25
# Episode 191 finished with reward: -73.43
# Moving average (last 50 episodes): -54.17 ± 32.35
# Episode 192 finished with reward: -124.18
# Moving average (last 50 episodes): -55.50 ± 33.80
# Episode 193 finished with reward: -29.47
# Moving average (last 50 episodes): -53.74 ± 32.80
# Episode 194 finished with reward: -57.22
# Moving average (last 50 episodes): -53.20 ± 32.51
# Episode 195 finished with reward: -43.82
# Moving average (last 50 episodes): -53.87 ± 31.97
# Episode 196 finished with reward: -112.86
# Moving average (last 50 episodes): -54.55 ± 32.84
# Episode 197 finished with reward: -32.96
# Moving average (last 50 episodes): -53.09 ± 32.15
# Episode 198 finished with reward: -183.10
# Moving average (last 50 episodes): -54.92 ± 36.59
# Episode 199 finished with reward: -31.31
# Moving average (last 50 episodes): -54.14 ± 36.67
# Episode 200 finished with reward: -2.65
# Moving average (last 50 episodes): -53.05 ± 37.36
# Episode 201 finished with reward: -50.11
# Moving average (last 50 episodes): -53.20 ± 37.34
# Episode 202 finished with reward: -37.32
# Moving average (last 50 episodes): -53.13 ± 37.36
# Episode 203 finished with reward: -119.62
# Moving average (last 50 episodes): -55.62 ± 37.57
# Episode 204 finished with reward: -17.89
# Moving average (last 50 episodes): -56.22 ± 36.70
# Episode 205 finished with reward: 6.17
# Moving average (last 50 episodes): -55.42 ± 37.60
# Episode 206 finished with reward: -13.14
# Moving average (last 50 episodes): -54.18 ± 37.96
# Episode 207 finished with reward: -111.85
# Moving average (last 50 episodes): -54.90 ± 38.69
# Episode 208 finished with reward: -64.23
# Moving average (last 50 episodes): -55.49 ± 38.61
# Episode 209 finished with reward: -88.01
# Moving average (last 50 episodes): -56.62 ± 38.72
# Episode 210 finished with reward: -75.05
# Moving average (last 50 episodes): -56.45 ± 38.62
# Episode 211 finished with reward: -80.87
# Moving average (last 50 episodes): -58.36 ± 37.40
# Episode 212 finished with reward: -71.41
# Moving average (last 50 episodes): -59.77 ± 36.54
# Episode 213 finished with reward: -61.59
# Moving average (last 50 episodes): -59.96 ± 36.52
# Episode 214 finished with reward: -87.53
# Moving average (last 50 episodes): -60.22 ± 36.67
# Episode 215 finished with reward: -21.42
# Moving average (last 50 episodes): -59.66 ± 37.04
# Episode 216 finished with reward: -77.24
# Moving average (last 50 episodes): -59.55 ± 36.98
# Episode 217 finished with reward: -12.36
# Moving average (last 50 episodes): -58.96 ± 37.49
# Episode 218 finished with reward: -82.13
# Moving average (last 50 episodes): -59.81 ± 37.52
# Episode 219 finished with reward: 19.49
# Moving average (last 50 episodes): -58.95 ± 38.82
# Episode 220 finished with reward: -18.69
# Moving average (last 50 episodes): -58.74 ± 39.00
# Episode 221 finished with reward: -43.67
# Moving average (last 50 episodes): -58.10 ± 38.98
# Episode 222 finished with reward: -19.38
# Moving average (last 50 episodes): -57.79 ± 39.22
# Episode 223 finished with reward: -89.56
# Moving average (last 50 episodes): -58.29 ± 39.46
# Episode 224 finished with reward: -76.76
# Moving average (last 50 episodes): -57.78 ± 39.06
# Episode 225 finished with reward: -28.51
# Moving average (last 50 episodes): -56.52 ± 38.96
# Episode 226 finished with reward: -110.44
# Moving average (last 50 episodes): -57.72 ± 39.67
# Episode 227 finished with reward: -9.14
# Moving average (last 50 episodes): -56.87 ± 40.25
# Episode 228 finished with reward: -39.40
# Moving average (last 50 episodes): -55.47 ± 39.60
# Episode 229 finished with reward: -75.77
# Moving average (last 50 episodes): -55.49 ± 39.61
# Episode 230 finished with reward: -62.61
# Moving average (last 50 episodes): -56.77 ± 38.77
# Episode 231 finished with reward: -59.58
# Moving average (last 50 episodes): -57.20 ± 38.68
# Episode 232 finished with reward: -54.13
# Moving average (last 50 episodes): -57.47 ± 38.61
# Episode 233 finished with reward: -56.24
# Moving average (last 50 episodes): -58.49 ± 37.88
# Episode 234 finished with reward: 10.20
# Moving average (last 50 episodes): -57.42 ± 39.04
# Episode 235 finished with reward: -89.66
# Moving average (last 50 episodes): -58.13 ± 39.29
# Episode 236 finished with reward: -111.33
# Moving average (last 50 episodes): -58.88 ± 39.94
# Episode 237 finished with reward: -110.32
# Moving average (last 50 episodes): -58.86 ± 39.91
# Episode 238 finished with reward: -92.61
# Moving average (last 50 episodes): -59.89 ± 40.11
# Episode 239 finished with reward: -80.43
# Moving average (last 50 episodes): -60.21 ± 40.20
# Episode 240 finished with reward: -35.32
# Moving average (last 50 episodes): -59.81 ± 40.35
# Episode 241 finished with reward: -115.16
# Moving average (last 50 episodes): -60.64 ± 41.05
# Episode 242 finished with reward: -31.79
# Moving average (last 50 episodes): -58.80 ± 40.22
# Episode 243 finished with reward: -47.95
# Moving average (last 50 episodes): -59.17 ± 40.03
# Episode 244 finished with reward: -40.52
# Moving average (last 50 episodes): -58.83 ± 40.11
# Episode 245 finished with reward: -98.92
# Moving average (last 50 episodes): -59.93 ± 40.44
# Episode 246 finished with reward: -40.55
# Moving average (last 50 episodes): -58.49 ± 39.81
# Episode 247 finished with reward: -3.43
# Moving average (last 50 episodes): -57.90 ± 40.40
# Episode 248 finished with reward: -99.54
# Moving average (last 50 episodes): -56.23 ± 36.75
# Episode 249 finished with reward: -43.07
# Moving average (last 50 episodes): -56.46 ± 36.63
# Episode 250 finished with reward: -30.91
# Moving average (last 50 episodes): -57.03 ± 36.01
# Episode 251 finished with reward: -91.99
# Moving average (last 50 episodes): -57.86 ± 36.32
# Episode 252 finished with reward: -84.34
# Moving average (last 50 episodes): -58.80 ± 36.39
# Episode 253 finished with reward: -28.34
# Moving average (last 50 episodes): -56.98 ± 35.57
# Episode 254 finished with reward: -96.38
# Moving average (last 50 episodes): -58.55 ± 35.54
# Episode 255 finished with reward: -26.20
# Moving average (last 50 episodes): -59.20 ± 34.64
# Episode 256 finished with reward: -68.69
# Moving average (last 50 episodes): -60.31 ± 34.03
# Episode 257 finished with reward: -101.40
# Moving average (last 50 episodes): -60.10 ± 33.74
# Episode 258 finished with reward: -112.28
# Moving average (last 50 episodes): -61.06 ± 34.52
# Episode 259 finished with reward: -128.91
# Moving average (last 50 episodes): -61.88 ± 35.62
# Episode 260 finished with reward: -12.57
# Moving average (last 50 episodes): -60.63 ± 36.23
# Episode 261 finished with reward: -26.88
# Moving average (last 50 episodes): -59.55 ± 36.41
# Episode 262 finished with reward: -59.94
# Moving average (last 50 episodes): -59.32 ± 36.37
# Episode 263 finished with reward: -25.68
# Moving average (last 50 episodes): -58.60 ± 36.67
# Episode 264 finished with reward: -63.89
# Moving average (last 50 episodes): -58.13 ± 36.45
# Episode 265 finished with reward: -84.24
# Moving average (last 50 episodes): -59.38 ± 36.24
# Episode 266 finished with reward: -45.95
# Moving average (last 50 episodes): -58.76 ± 36.20
# Episode 267 finished with reward: -52.91
# Moving average (last 50 episodes): -59.57 ± 35.60
# Episode 268 finished with reward: -115.03
# Moving average (last 50 episodes): -60.23 ± 36.31
# Episode 269 finished with reward: -136.91
# Moving average (last 50 episodes): -63.35 ± 36.04
# Episode 270 finished with reward: -31.39
# Moving average (last 50 episodes): -63.61 ± 35.77
# Episode 271 finished with reward: -59.89
# Moving average (last 50 episodes): -63.93 ± 35.66
# Episode 272 finished with reward: -122.11
# Moving average (last 50 episodes): -65.99 ± 35.99
# Episode 273 finished with reward: -104.94
# Moving average (last 50 episodes): -66.30 ± 36.26
# Episode 274 finished with reward: -31.35
# Moving average (last 50 episodes): -65.39 ± 36.55
# Episode 275 finished with reward: -108.52
# Moving average (last 50 episodes): -66.99 ± 36.65
# Episode 276 finished with reward: -16.78
# Moving average (last 50 episodes): -65.11 ± 36.78
# Episode 277 finished with reward: -80.30
# Moving average (last 50 episodes): -66.54 ± 35.95
# Episode 278 finished with reward: -20.14
# Moving average (last 50 episodes): -66.15 ± 36.34
# Episode 279 finished with reward: -69.88
# Moving average (last 50 episodes): -66.03 ± 36.32
# Episode 280 finished with reward: -63.68
# Moving average (last 50 episodes): -66.06 ± 36.32
# Episode 281 finished with reward: -97.35
# Moving average (last 50 episodes): -66.81 ± 36.57
# Episode 282 finished with reward: -85.73
# Moving average (last 50 episodes): -67.44 ± 36.62
# Episode 283 finished with reward: -97.39
# Moving average (last 50 episodes): -68.27 ± 36.82
# Episode 284 finished with reward: 4.37
# Moving average (last 50 episodes): -68.38 ± 36.58
# Episode 285 finished with reward: -92.01
# Moving average (last 50 episodes): -68.43 ± 36.61
# Episode 286 finished with reward: -66.68
# Moving average (last 50 episodes): -67.54 ± 36.09
# Episode 287 finished with reward: -76.57
# Moving average (last 50 episodes): -66.86 ± 35.60
# Episode 288 finished with reward: -106.82
# Moving average (last 50 episodes): -67.15 ± 35.86
# Episode 289 finished with reward: -141.35
# Moving average (last 50 episodes): -68.36 ± 37.29
# Episode 290 finished with reward: -30.46
# Moving average (last 50 episodes): -68.27 ± 37.39
# Episode 291 finished with reward: -70.34
# Moving average (last 50 episodes): -67.37 ± 36.78
# Episode 292 finished with reward: 40.96
# Moving average (last 50 episodes): -65.92 ± 39.50
# Episode 293 finished with reward: -30.66
# Moving average (last 50 episodes): -65.57 ± 39.73
# Episode 294 finished with reward: -104.87
# Moving average (last 50 episodes): -66.86 ± 39.94
# Episode 295 finished with reward: -82.27
# Moving average (last 50 episodes): -66.52 ± 39.74
# Episode 296 finished with reward: -62.64
# Moving average (last 50 episodes): -66.97 ± 39.57
# Episode 297 finished with reward: 0.12
# Moving average (last 50 episodes): -66.89 ± 39.69
# Episode 298 finished with reward: -43.18
# Moving average (last 50 episodes): -65.77 ± 39.55
# Episode 299 finished with reward: -72.89
# Moving average (last 50 episodes): -66.36 ± 39.42
# Episode 300 finished with reward: -38.64
# Moving average (last 50 episodes): -66.52 ± 39.30
# Episode 301 finished with reward: -61.83
# Moving average (last 50 episodes): -65.92 ± 39.13
# Episode 302 finished with reward: -79.70
# Moving average (last 50 episodes): -65.82 ± 39.10
# Episode 303 finished with reward: -114.27
# Moving average (last 50 episodes): -67.54 ± 39.30
# Episode 304 finished with reward: -72.12
# Moving average (last 50 episodes): -67.06 ± 39.09
# Episode 305 finished with reward: -100.74
# Moving average (last 50 episodes): -68.55 ± 38.92
# Episode 306 finished with reward: -124.65
# Moving average (last 50 episodes): -69.67 ± 39.71
# Episode 307 finished with reward: 6.73
# Moving average (last 50 episodes): -67.50 ± 40.85
# Episode 308 finished with reward: -18.70
# Moving average (last 50 episodes): -65.63 ± 40.90
# Episode 309 finished with reward: -39.28
# Moving average (last 50 episodes): -63.84 ± 40.04
# Episode 310 finished with reward: -79.99
# Moving average (last 50 episodes): -65.19 ± 39.42
# Episode 311 finished with reward: -116.02
# Moving average (last 50 episodes): -66.97 ± 39.66
# Episode 312 finished with reward: -58.31
# Moving average (last 50 episodes): -66.94 ± 39.67
# Episode 313 finished with reward: -69.12
# Moving average (last 50 episodes): -67.81 ± 39.23
# Episode 314 finished with reward: -42.11
# Moving average (last 50 episodes): -67.37 ± 39.39
# Episode 315 finished with reward: -140.72
# Moving average (last 50 episodes): -68.50 ± 40.65
# Episode 316 finished with reward: -111.65
# Moving average (last 50 episodes): -69.81 ± 40.96
# Episode 317 finished with reward: -9.85
# Moving average (last 50 episodes): -68.95 ± 41.75
# Episode 318 finished with reward: -60.06
# Moving average (last 50 episodes): -67.85 ± 41.24
# Episode 319 finished with reward: -59.06
# Moving average (last 50 episodes): -66.30 ± 40.06
# Episode 320 finished with reward: -6.58
# Moving average (last 50 episodes): -65.80 ± 40.64
# Episode 321 finished with reward: 35.19
# Moving average (last 50 episodes): -63.90 ± 43.03
# Episode 322 finished with reward: -10.39
# Moving average (last 50 episodes): -61.66 ± 42.85
# Episode 323 finished with reward: -133.61
# Moving average (last 50 episodes): -62.24 ± 43.61
# Episode 324 finished with reward: -93.22
# Moving average (last 50 episodes): -63.47 ± 43.59
# Episode 325 finished with reward: -78.11
# Moving average (last 50 episodes): -62.87 ± 43.17
# Episode 326 finished with reward: -57.05
# Moving average (last 50 episodes): -63.67 ± 42.67
# Episode 327 finished with reward: -103.09
# Moving average (last 50 episodes): -64.13 ± 42.97
# Episode 328 finished with reward: -56.97
# Moving average (last 50 episodes): -64.86 ± 42.52
# Episode 329 finished with reward: -111.50
# Moving average (last 50 episodes): -65.70 ± 43.02
# Episode 330 finished with reward: -50.67
# Moving average (last 50 episodes): -65.44 ± 43.07
# Episode 331 finished with reward: -142.70
# Moving average (last 50 episodes): -66.34 ± 44.19
# Episode 332 finished with reward: -49.13
# Moving average (last 50 episodes): -65.61 ± 44.17
# Episode 333 finished with reward: -11.03
# Moving average (last 50 episodes): -63.88 ± 44.58
# Episode 334 finished with reward: -85.72
# Moving average (last 50 episodes): -65.69 ± 43.59
# Episode 335 finished with reward: 46.59
# Moving average (last 50 episodes): -62.91 ± 46.16
# Episode 336 finished with reward: -33.93
# Moving average (last 50 episodes): -62.26 ± 46.34
# Episode 337 finished with reward: -90.58
# Moving average (last 50 episodes): -62.54 ± 46.46
# Episode 338 finished with reward: -42.88
# Moving average (last 50 episodes): -61.26 ± 46.11
# Episode 339 finished with reward: -134.27
# Moving average (last 50 episodes): -61.12 ± 45.87
# Episode 340 finished with reward: -73.70
# Moving average (last 50 episodes): -61.98 ± 45.69
# Episode 341 finished with reward: -45.79
# Moving average (last 50 episodes): -61.49 ± 45.73
# Episode 342 finished with reward: -102.09
# Moving average (last 50 episodes): -64.35 ± 43.66
# Episode 343 finished with reward: -42.02
# Moving average (last 50 episodes): -64.58 ± 43.51
# Episode 344 finished with reward: -57.99
# Moving average (last 50 episodes): -63.64 ± 43.14
# Episode 345 finished with reward: -61.42
# Moving average (last 50 episodes): -63.23 ± 43.06
# Episode 346 finished with reward: -31.31
# Moving average (last 50 episodes): -62.60 ± 43.29
# Episode 347 finished with reward: -109.22
# Moving average (last 50 episodes): -64.79 ± 42.82
# Episode 348 finished with reward: -86.92
# Moving average (last 50 episodes): -65.66 ± 42.82
# Episode 349 finished with reward: -114.43
# Moving average (last 50 episodes): -66.49 ± 43.35
# Episode 350 finished with reward: -27.77
# Moving average (last 50 episodes): -66.28 ± 43.52
# Episode 351 finished with reward: -51.40
# Moving average (last 50 episodes): -66.07 ± 43.56
# Episode 352 finished with reward: -72.33
# Moving average (last 50 episodes): -65.92 ± 43.53
# Episode 353 finished with reward: -80.86
# Moving average (last 50 episodes): -65.25 ± 43.04
# Episode 354 finished with reward: -46.94
# Moving average (last 50 episodes): -64.75 ± 43.10
# Episode 355 finished with reward: -29.43
# Moving average (last 50 episodes): -63.32 ± 43.06
# Episode 356 finished with reward: -76.96
# Moving average (last 50 episodes): -62.37 ± 42.22
# Episode 357 finished with reward: -74.34
# Moving average (last 50 episodes): -63.99 ± 41.07
# Episode 358 finished with reward: -54.73
# Moving average (last 50 episodes): -64.71 ± 40.58
# Episode 359 finished with reward: -126.64
# Moving average (last 50 episodes): -66.46 ± 41.33
# Episode 360 finished with reward: -114.10
# Moving average (last 50 episodes): -67.14 ± 41.82
# Episode 361 finished with reward: -164.92
# Moving average (last 50 episodes): -68.12 ± 43.49
# Episode 362 finished with reward: -66.76
# Moving average (last 50 episodes): -68.29 ± 43.47
# Episode 363 finished with reward: -154.17
# Moving average (last 50 episodes): -69.99 ± 45.10
# Episode 364 finished with reward: -77.86
# Moving average (last 50 episodes): -70.70 ± 44.94
# Episode 365 finished with reward: -88.97
# Moving average (last 50 episodes): -69.67 ± 43.90
# Episode 366 finished with reward: -94.54
# Moving average (last 50 episodes): -69.32 ± 43.64
# Episode 367 finished with reward: -96.57
# Moving average (last 50 episodes): -71.06 ± 42.95
# Episode 368 finished with reward: -96.45
# Moving average (last 50 episodes): -71.79 ± 43.07
# Episode 369 finished with reward: -59.25
# Moving average (last 50 episodes): -71.79 ± 43.07
# Episode 370 finished with reward: -81.26
# Moving average (last 50 episodes): -73.28 ± 42.06
# Episode 371 finished with reward: -50.08
# Moving average (last 50 episodes): -74.99 ± 39.27
# Episode 372 finished with reward: -53.15
# Moving average (last 50 episodes): -75.84 ± 38.31
# Episode 373 finished with reward: -100.43
# Moving average (last 50 episodes): -75.18 ± 37.58
# Episode 374 finished with reward: -70.00
# Moving average (last 50 episodes): -74.72 ± 37.50
# Episode 375 finished with reward: -92.30
# Moving average (last 50 episodes): -75.00 ± 37.58
# Episode 376 finished with reward: -151.93
# Moving average (last 50 episodes): -76.90 ± 38.99
# Episode 377 finished with reward: -99.58
# Moving average (last 50 episodes): -76.83 ± 38.95
# Episode 378 finished with reward: -108.21
# Moving average (last 50 episodes): -77.85 ± 39.08
# Episode 379 finished with reward: -77.59
# Moving average (last 50 episodes): -77.17 ± 38.79
# Episode 380 finished with reward: -100.82
# Moving average (last 50 episodes): -78.18 ± 38.74
# Episode 381 finished with reward: -80.99
# Moving average (last 50 episodes): -76.94 ± 37.63
# Episode 382 finished with reward: -88.14
# Moving average (last 50 episodes): -77.72 ± 37.45
# Episode 383 finished with reward: -99.94
# Moving average (last 50 episodes): -79.50 ± 36.33
# Episode 384 finished with reward: -56.74
# Moving average (last 50 episodes): -78.92 ± 36.46
# Episode 385 finished with reward: -75.16
# Moving average (last 50 episodes): -81.36 ± 31.76
# Episode 386 finished with reward: -106.29
# Moving average (last 50 episodes): -82.80 ± 31.21
# Episode 387 finished with reward: -151.86
# Moving average (last 50 episodes): -84.03 ± 32.66
# Episode 388 finished with reward: 23.30
# Moving average (last 50 episodes): -82.71 ± 35.52
# Episode 389 finished with reward: -126.28
# Moving average (last 50 episodes): -82.55 ± 35.30
# Episode 390 finished with reward: -122.73
# Moving average (last 50 episodes): -83.53 ± 35.72
# Episode 391 finished with reward: -117.79
# Moving average (last 50 episodes): -84.97 ± 35.62
# Episode 392 finished with reward: -24.04
# Moving average (last 50 episodes): -83.41 ± 36.54
# Episode 393 finished with reward: -113.66
# Moving average (last 50 episodes): -84.84 ± 36.29
# Episode 394 finished with reward: -135.67
# Moving average (last 50 episodes): -86.39 ± 36.77
# Episode 395 finished with reward: -83.43
# Moving average (last 50 episodes): -86.83 ± 36.60
# Episode 396 finished with reward: -115.13
# Moving average (last 50 episodes): -88.51 ± 35.93
# Episode 397 finished with reward: -57.17
# Moving average (last 50 episodes): -87.47 ± 36.07
# Episode 398 finished with reward: -112.50
# Moving average (last 50 episodes): -87.98 ± 36.24
# Episode 399 finished with reward: -150.85
# Moving average (last 50 episodes): -88.71 ± 37.12
# Episode 400 finished with reward: -88.24
# Moving average (last 50 episodes): -89.92 ± 36.08
# Episode 401 finished with reward: -98.98
# Moving average (last 50 episodes): -90.87 ± 35.68
# Episode 402 finished with reward: -110.53
# Moving average (last 50 episodes): -91.63 ± 35.68
# Episode 403 finished with reward: -127.01
# Moving average (last 50 episodes): -92.56 ± 35.99
# Episode 404 finished with reward: -81.11
# Moving average (last 50 episodes): -93.24 ± 35.43
# Episode 405 finished with reward: -117.35
# Moving average (last 50 episodes): -95.00 ± 34.39
# Episode 406 finished with reward: -83.41
# Moving average (last 50 episodes): -95.13 ± 34.33
# Episode 407 finished with reward: 17.83
# Moving average (last 50 episodes): -93.28 ± 37.71
# Episode 408 finished with reward: -106.70
# Moving average (last 50 episodes): -94.32 ± 37.35
# Episode 409 finished with reward: -83.99
# Moving average (last 50 episodes): -93.47 ± 37.08
# Episode 410 finished with reward: -119.40
# Moving average (last 50 episodes): -93.58 ± 37.15
# Episode 411 finished with reward: -78.94
# Moving average (last 50 episodes): -91.86 ± 35.77
# Episode 412 finished with reward: -45.74
# Moving average (last 50 episodes): -91.44 ± 36.19
# Episode 413 finished with reward: -97.56
# Moving average (last 50 episodes): -90.30 ± 35.07
# Episode 414 finished with reward: -191.87
# Moving average (last 50 episodes): -92.58 ± 37.79
# Episode 415 finished with reward: -180.26
# Moving average (last 50 episodes): -94.41 ± 39.73
# Episode 416 finished with reward: -150.03
# Moving average (last 50 episodes): -95.52 ± 40.48
# Episode 417 finished with reward: -43.46
# Moving average (last 50 episodes): -94.46 ± 41.13
# Episode 418 finished with reward: -125.50
# Moving average (last 50 episodes): -95.04 ± 41.36
# Episode 419 finished with reward: -173.30
# Moving average (last 50 episodes): -97.32 ± 42.46
# Episode 420 finished with reward: -135.39
# Moving average (last 50 episodes): -98.40 ± 42.72
# Episode 421 finished with reward: -124.52
# Moving average (last 50 episodes): -99.89 ± 42.31
# Episode 422 finished with reward: -139.49
# Moving average (last 50 episodes): -101.62 ± 42.13
# Episode 423 finished with reward: -121.98
# Moving average (last 50 episodes): -102.05 ± 42.22
# Episode 424 finished with reward: -111.33
# Moving average (last 50 episodes): -102.87 ± 41.99
# Episode 425 finished with reward: -156.90
# Moving average (last 50 episodes): -104.17 ± 42.63
# Episode 426 finished with reward: -79.09
# Moving average (last 50 episodes): -102.71 ± 42.22
# Episode 427 finished with reward: -215.08
# Moving average (last 50 episodes): -105.02 ± 45.05
# Episode 428 finished with reward: -138.71
# Moving average (last 50 episodes): -105.63 ± 45.30
# Episode 429 finished with reward: -146.57
# Moving average (last 50 episodes): -107.01 ± 45.47
# Episode 430 finished with reward: -74.52
# Moving average (last 50 episodes): -106.48 ± 45.69
# Episode 431 finished with reward: -71.36
# Moving average (last 50 episodes): -106.29 ± 45.82
# Episode 432 finished with reward: -179.09
# Moving average (last 50 episodes): -108.11 ± 46.85
# Episode 433 finished with reward: -134.48
# Moving average (last 50 episodes): -108.80 ± 46.98
# Episode 434 finished with reward: -98.33
# Moving average (last 50 episodes): -109.63 ± 46.42
# Episode 435 finished with reward: -99.41
# Moving average (last 50 episodes): -110.12 ± 46.18
# Episode 436 finished with reward: -121.83
# Moving average (last 50 episodes): -110.43 ± 46.21
# Episode 437 finished with reward: -93.58
# Moving average (last 50 episodes): -109.26 ± 45.88
# Episode 438 finished with reward: -62.23
# Moving average (last 50 episodes): -110.97 ± 42.37
# Episode 439 finished with reward: -146.81
# Moving average (last 50 episodes): -111.38 ± 42.61
# Episode 440 finished with reward: -169.62
# Moving average (last 50 episodes): -112.32 ± 43.36
# Episode 441 finished with reward: -161.05
# Moving average (last 50 episodes): -113.19 ± 43.89
# Episode 442 finished with reward: -71.75
# Moving average (last 50 episodes): -114.14 ± 42.44
# Episode 443 finished with reward: -125.14
# Moving average (last 50 episodes): -114.37 ± 42.47
# Episode 444 finished with reward: -103.74
# Moving average (last 50 episodes): -113.73 ± 42.38
# Episode 445 finished with reward: -152.37
# Moving average (last 50 episodes): -115.11 ± 42.49
# Episode 446 finished with reward: -194.06
# Moving average (last 50 episodes): -116.69 ± 43.91
# Episode 447 finished with reward: -98.19
# Moving average (last 50 episodes): -117.51 ± 43.16
# Episode 448 finished with reward: -177.82
# Moving average (last 50 episodes): -118.82 ± 43.97
# Episode 449 finished with reward: -123.43
# Moving average (last 50 episodes): -118.27 ± 43.74
# Episode 450 finished with reward: -151.73
# Moving average (last 50 episodes): -119.54 ± 43.77
# Episode 451 finished with reward: -65.34
# Moving average (last 50 episodes): -118.86 ± 44.34
# Episode 452 finished with reward: -72.35
# Moving average (last 50 episodes): -118.10 ± 44.80
# Episode 453 finished with reward: -122.86
# Moving average (last 50 episodes): -118.02 ± 44.79
# Episode 454 finished with reward: -124.45
# Moving average (last 50 episodes): -118.89 ± 44.48
# Episode 455 finished with reward: -71.19
# Moving average (last 50 episodes): -117.96 ± 44.98
# Episode 456 finished with reward: -160.90
# Moving average (last 50 episodes): -119.51 ± 45.10
# Episode 457 finished with reward: -108.48
# Moving average (last 50 episodes): -122.04 ± 40.66
# Episode 458 finished with reward: -54.94
# Moving average (last 50 episodes): -121.00 ± 41.68
# Episode 459 finished with reward: -168.41
# Moving average (last 50 episodes): -122.69 ± 41.86
# Episode 460 finished with reward: -85.63
# Moving average (last 50 episodes): -122.02 ± 42.17
# Episode 461 finished with reward: -37.65
# Moving average (last 50 episodes): -121.19 ± 43.40
# Episode 462 finished with reward: -74.18
# Moving average (last 50 episodes): -121.76 ± 42.58
# Episode 463 finished with reward: -158.99
# Moving average (last 50 episodes): -122.99 ± 42.75
# Episode 464 finished with reward: -22.03
# Moving average (last 50 episodes): -119.59 ± 43.88
# Episode 465 finished with reward: -93.01
# Moving average (last 50 episodes): -117.85 ± 43.16
# Episode 466 finished with reward: -133.68
# Moving average (last 50 episodes): -117.52 ± 42.97
# Episode 467 finished with reward: -58.90
# Moving average (last 50 episodes): -117.83 ± 42.49
# Episode 468 finished with reward: -105.13
# Moving average (last 50 episodes): -117.42 ± 42.52
# Episode 469 finished with reward: -94.53
# Moving average (last 50 episodes): -115.84 ± 41.87
# Episode 470 finished with reward: -111.41
# Moving average (last 50 episodes): -115.37 ± 41.78
# Episode 471 finished with reward: -164.35
# Moving average (last 50 episodes): -116.16 ± 42.32
# Episode 472 finished with reward: -98.15
# Moving average (last 50 episodes): -115.33 ± 42.26
# Episode 473 finished with reward: -103.79
# Moving average (last 50 episodes): -114.97 ± 42.28
# Episode 474 finished with reward: -166.25
# Moving average (last 50 episodes): -116.07 ± 42.88
# Episode 475 finished with reward: -151.16
# Moving average (last 50 episodes): -115.95 ± 42.78
# Episode 476 finished with reward: -108.54
# Moving average (last 50 episodes): -116.54 ± 42.47
# Episode 477 finished with reward: -62.83
# Moving average (last 50 episodes): -113.50 ± 40.72
# Episode 478 finished with reward: -187.88
# Moving average (last 50 episodes): -114.48 ± 41.89
# Episode 479 finished with reward: -152.58
# Moving average (last 50 episodes): -114.60 ± 41.99
# Episode 480 finished with reward: -173.68
# Moving average (last 50 episodes): -116.59 ± 42.39
# Episode 481 finished with reward: -96.74
# Moving average (last 50 episodes): -117.09 ± 42.00
# Episode 482 finished with reward: -95.55
# Moving average (last 50 episodes): -115.42 ± 41.15
# Episode 483 finished with reward: -104.46
# Moving average (last 50 episodes): -114.82 ± 41.09
# Episode 484 finished with reward: -110.48
# Moving average (last 50 episodes): -115.07 ± 41.03
# Episode 485 finished with reward: -98.15
# Moving average (last 50 episodes): -115.04 ± 41.04
# Episode 486 finished with reward: -154.17
# Moving average (last 50 episodes): -115.69 ± 41.39
# Episode 487 finished with reward: -86.11
# Moving average (last 50 episodes): -115.54 ± 41.49
# Episode 488 finished with reward: -76.67
# Moving average (last 50 episodes): -115.83 ± 41.16
# Episode 489 finished with reward: -99.82
# Moving average (last 50 episodes): -114.89 ± 40.98
# Episode 490 finished with reward: -128.11
# Moving average (last 50 episodes): -114.06 ± 40.28
# Episode 491 finished with reward: -88.17
# Moving average (last 50 episodes): -112.60 ± 39.87
# Episode 492 finished with reward: -204.31
# Moving average (last 50 episodes): -115.25 ± 41.44
# Episode 493 finished with reward: -203.14
# Moving average (last 50 episodes): -116.81 ± 43.21
# Episode 494 finished with reward: -220.08
# Moving average (last 50 episodes): -119.14 ± 45.52
# Episode 495 finished with reward: -168.08
# Moving average (last 50 episodes): -119.45 ± 45.80
# Episode 496 finished with reward: -85.82
# Moving average (last 50 episodes): -117.29 ± 44.77
# Episode 497 finished with reward: -170.04
# Moving average (last 50 episodes): -118.72 ± 45.28
# Episode 498 finished with reward: -113.52
# Moving average (last 50 episodes): -117.44 ± 44.49
# Episode 499 finished with reward: -128.62
# Moving average (last 50 episodes): -117.54 ± 44.51
# Episode 500 finished with reward: -179.92
# Moving average (last 50 episodes): -118.10 ± 45.12
# Episode 501 finished with reward: -150.62
# Moving average (last 50 episodes): -119.81 ± 44.70
# Episode 502 finished with reward: -80.44
# Moving average (last 50 episodes): -119.97 ± 44.54
# Episode 503 finished with reward: -150.99
# Moving average (last 50 episodes): -120.53 ± 44.75
# Episode 504 finished with reward: -157.97
# Moving average (last 50 episodes): -121.20 ± 45.05
# Episode 505 finished with reward: -97.16
# Moving average (last 50 episodes): -121.72 ± 44.62
# Episode 506 finished with reward: -85.19
# Moving average (last 50 episodes): -120.21 ± 44.55
# Episode 507 finished with reward: -108.64
# Moving average (last 50 episodes): -120.21 ± 44.55
# Episode 508 finished with reward: -104.00
# Moving average (last 50 episodes): -121.19 ± 43.63
# Episode 509 finished with reward: -123.28
# Moving average (last 50 episodes): -120.29 ± 43.11
# Episode 510 finished with reward: -35.00
# Moving average (last 50 episodes): -119.28 ± 44.49
# Episode 511 finished with reward: -95.51
# Moving average (last 50 episodes): -120.44 ± 43.08
# Episode 512 finished with reward: -70.35
# Moving average (last 50 episodes): -120.36 ± 43.16
# Episode 513 finished with reward: -67.36
# Moving average (last 50 episodes): -118.53 ± 43.43
# Episode 514 finished with reward: -120.81
# Moving average (last 50 episodes): -120.50 ± 41.18
# Episode 515 finished with reward: -112.83
# Moving average (last 50 episodes): -120.90 ± 41.01
# Episode 516 finished with reward: -94.73
# Moving average (last 50 episodes): -120.12 ± 41.13
# Episode 517 finished with reward: -158.62
# Moving average (last 50 episodes): -122.11 ± 40.53
# Episode 518 finished with reward: -148.76
# Moving average (last 50 episodes): -122.99 ± 40.62
# Episode 519 finished with reward: -93.57
# Moving average (last 50 episodes): -122.97 ± 40.63
# Episode 520 finished with reward: -165.95
# Moving average (last 50 episodes): -124.06 ± 41.04
# Episode 521 finished with reward: -194.35
# Moving average (last 50 episodes): -124.66 ± 41.84
# Episode 522 finished with reward: -20.51
# Moving average (last 50 episodes): -123.11 ± 44.17
# Episode 523 finished with reward: -80.35
# Moving average (last 50 episodes): -122.64 ± 44.49
# Episode 524 finished with reward: -83.09
# Moving average (last 50 episodes): -120.97 ± 44.39
# Episode 525 finished with reward: -137.13
# Moving average (last 50 episodes): -120.69 ± 44.24
# Episode 526 finished with reward: -124.22
# Moving average (last 50 episodes): -121.01 ± 44.21
# Episode 527 finished with reward: -128.54
# Moving average (last 50 episodes): -122.32 ± 43.43
# Episode 528 finished with reward: -110.33
# Moving average (last 50 episodes): -120.77 ± 42.43
# Episode 529 finished with reward: -155.44
# Moving average (last 50 episodes): -120.83 ± 42.48
# Episode 530 finished with reward: -124.97
# Moving average (last 50 episodes): -119.85 ± 41.81
# Episode 531 finished with reward: -70.01
# Moving average (last 50 episodes): -119.32 ± 42.27
# Episode 532 finished with reward: -96.11
# Moving average (last 50 episodes): -119.33 ± 42.26
# Episode 533 finished with reward: -68.97
# Moving average (last 50 episodes): -118.62 ± 42.80
# Episode 534 finished with reward: -159.26
# Moving average (last 50 episodes): -119.60 ± 43.16
# Episode 535 finished with reward: -160.81
# Moving average (last 50 episodes): -120.85 ± 43.42
# Episode 536 finished with reward: -109.11
# Moving average (last 50 episodes): -119.95 ± 43.19
# Episode 537 finished with reward: -180.93
# Moving average (last 50 episodes): -121.84 ± 43.74
# Episode 538 finished with reward: -159.18
# Moving average (last 50 episodes): -123.49 ± 43.56
# Episode 539 finished with reward: -155.89
# Moving average (last 50 episodes): -124.62 ± 43.66
# Episode 540 finished with reward: -211.08
# Moving average (last 50 episodes): -126.28 ± 45.31
# Episode 541 finished with reward: -81.00
# Moving average (last 50 episodes): -126.13 ± 45.44
# Episode 542 finished with reward: -169.67
# Moving average (last 50 episodes): -125.44 ± 44.49
# Episode 543 finished with reward: -160.97
# Moving average (last 50 episodes): -124.60 ± 43.40
# Episode 544 finished with reward: -145.09
# Moving average (last 50 episodes): -123.10 ± 41.32
# Episode 545 finished with reward: -138.61
# Moving average (last 50 episodes): -122.51 ± 40.88
# Episode 546 finished with reward: -105.47
# Moving average (last 50 episodes): -122.90 ± 40.62
# Episode 547 finished with reward: -88.60
# Moving average (last 50 episodes): -121.27 ± 40.33
# Episode 548 finished with reward: -109.29
# Moving average (last 50 episodes): -121.19 ± 40.35

# %%
# def plot_smooth_rewards(rewards, window_sizes=[5, 20, 100]):
#     """
#     绘制平滑的奖励曲线
#     Args:
#         rewards: 奖励列表
#         window_sizes: 移动平均窗口大小列表
#     """
#     plt.figure(figsize=(12, 6))
    
#     # 绘制原始奖励
#     plt.plot(rewards, 'lightgray', alpha=0.3, label='Raw rewards')
    
#     # 绘制不同窗口大小的移动平均
#     colors = ['blue', 'green', 'red']
#     for window, color in zip(window_sizes, colors):
#         if len(rewards) >= window:
#             # 计算移动平均
#             smooth_rewards = np.convolve(rewards, 
#                                       np.ones(window)/window, 
#                                       mode='valid')
#             plt.plot(range(window-1, len(rewards)), 
#                     smooth_rewards, 
#                     color=color, 
#                     label=f'{window}-Episode Moving Average',
#                     linewidth=2)
    
#     plt.xlabel('Episode')
#     plt.ylabel('Reward')
#     plt.title('Training Rewards with Different Smoothing Windows')
#     plt.grid(True, alpha=0.3)
#     plt.legend()
#     plt.show()


# # 绘制平滑奖励曲线
# plot_smooth_rewards(metrics["rewards"])

# %% [markdown]
# notes: 如果要训练过程中查看模型，通过 tensorboard 查看

# %%
# 模型保存
model.save(f"./model/{log_name}")

# %% [markdown]
# ### 评估模型训练结果

# %% [markdown]
# > 利用 evaulate policy 函数评估

# %% [markdown]
# # 加载训练好的 RL 模型

# %%
from stable_baselines3.common.evaluation import evaluate_policy
mean_reward, std_reward = evaluate_policy(
    model, 
    model.get_env(), 
    deterministic=True,
    render=True,
    n_eval_episodes=10)

print(mean_reward)
print(std_reward)

# %%
# del model
# model = PPO.load(f"./model/{log_name}", env=env_monitor)
model = DQN.load(f"./model/{log_name}", env=env_monitor)

# %% [markdown]
# ### 结果展示

# %% [markdown]
# #### 纯净展示版本
#
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆

for ep in range(episodes):
    
    obs, _ = env_monitor.reset(use_random_reset=base_config["use_random_reset"], seed=base_config["seed"]) # 必须的，每次重现一次
    
    episode_reward = 0
    done = False
    
     
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        print(f"year {env_monitor.t}-Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # # 每10步更新一次图像
        # if i == max_steps-1:
        #     env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            env_monitor.render()
            plt.show()  # 添加这行来保持图形窗口
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")

# %% [markdown]
# ### 保存整体运行结果

# %%
env_test = IEMEnv(reward_type=custom_reward_type)

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 3 # 结果展示，只有一个 episode 部分
max_steps = 250

# all_episode_rewards = [] # 记录所有 episode 里面的
 
for ep in range(episodes):
    
    ##################################
    # 记录所需数组：每次 episode 重置
    total_action = []
    total_state = []
    total_reward = []
    total_done = []
    ##################################
    # 记录每个 episode 的 reward
    episode_reward = 0
    ##################################
    
    obs, _ = env_test.reset() # 必须的，每次重现一次 ，这里可能就需要固定随机种子了
    done = False
    
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        ##################################
        # 添加转换的部分
        action_number, action_name = IEMEnv.action2number_env(action)
        total_action.append(action_number)
        total_state.append(obs)
        total_reward.append(reward)
        total_done.append(done)
        ##################################
        # 记录每个 episode 的 reward
        episode_reward += reward # TODO：可以放在内容记录 step 部分
        ################################## 
        
        if done:
            print(f"Episode {ep} finished at step {i}")
            break
        
        # # 每10步更新一次图像
        # if ep % 10 == 0:
        #     env_monitor.render()
        #     # plt.pause(0.01)
    
    # all_episode_rewards.append(episode_reward)
    
    env_test.append_data_reward(episode_reward)
    
    save_future_data(env=env_test,custom_reward_type=custom_reward_type,rl_model_name=rl_model_name,network_name=policy_kwargs_diy,episode=ep,total_action=total_action,total_state=total_state,total_reward=total_reward,total_done=total_done,total_timesteps_name=total_timesteps_diy)

    save_plot_NSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    save_plot_SSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    # plot_3D_run(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state)
    
    
    print(f"Episode {ep} finished with reward{episode_reward}")
    
    
plot_data = env_test.get_variables()
plot_episode_reward(plot_data)

# %% [markdown]
# 主要针对可视化显示部分操作

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 绘制只展示一次 episode 结果

# env_test

for episode in range(1):
    obs, _ = env_test.reset() # 这里可能就需要固定随机种子了
    
    done = False
    
    for i in range(251):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        
        if done:
            print(f"Episode {episode} finished at step {i}")
            break

# %% [markdown]
# # 保存运行结果
