# %% [markdown]
# 绘制比较不同奖励函数对应的训练值

# %%
import os
import json
import matplotlib.pyplot as plt

# 统一读取数据
# 1.default single reward function Ta
# DQN
dqn_exp822_ep_rew_mean_list = []
dqn_exp822_episodes = []

with open(os.path.join("logs/iseec_lx_v4_mdp_plot_DQN_multi_objective_single_T_a_exp822_700000_default", "progress.json"), "r", encoding="utf-8") as f:
    for line in f: # 每一行读取
        if line.strip(): # 确保行不为空
            data = json.loads(line) # 单行的 data 部分
            if "rollout/ep_rew_mean" in data and "time/episodes" in data:
                dqn_exp822_ep_rew_mean_list.append(data["rollout/ep_rew_mean"])
                dqn_exp822_episodes.append(data["time/episodes"])

# PPO                      
PPO_exp822_ep_rew_mean_list = []
PPO_exp822_episodes = []  

with open(os.path.join("logs/iseec_lx_v4_mdp_plot_PPO_multi_objective_single_T_a_exp822_700000_default", "progress.json"), "r", encoding="utf-8") as f:
    for line in f: # 每一行读取
        if line.strip(): # 确保行不为空
            data = json.loads(line) # 单行的 data 部分
            if "rollout/ep_rew_mean" in data and "time/episodes" in data:
                PPO_exp822_ep_rew_mean_list.append(data["rollout/ep_rew_mean"])
                PPO_exp822_episodes.append(data["time/episodes"])

# 2、Reward function
exp914_dqn_ep_rew_mean_list = []
exp914_dqn_episodes = []        

with open(os.path.join("logs/iseec_lx_v4_mdp_plot_DQN_multi_objective_single_C_a_exp914_700000_default", "progress.json"), "r", encoding="utf-8") as f:
    for line in f: # 每一行读取
        if line.strip(): # 确保行不为空
            data = json.loads(line) # 单行的 data 部分
            if "rollout/ep_rew_mean" in data and "time/episodes" in data:
                exp914_dqn_ep_rew_mean_list.append(data["rollout/ep_rew_mean"])
                exp914_dqn_episodes.append(data["time/episodes"]) 
            
# 3. reward type: multi reward function
exp122_dqn_ep_rew_mean_list = []
exp122_dqn_episodes = []        

with open(os.path.join("logs/iseec_lx_v4_mdp_plot_DQN_multi_objective_all_T_a_Ca_exp122_weights_change_more_ta_700000_default", "progress.json"), "r", encoding="utf-8") as f:
    for line in f: # 每一行读取
        if line.strip(): # 确保行不为空
            data = json.loads(line) # 单行的 data 部分
            if "rollout/ep_rew_mean" in data and "time/episodes" in data:
                exp122_dqn_ep_rew_mean_list.append(data["rollout/ep_rew_mean"])
                exp122_dqn_episodes.append(data["time/episodes"]) 

# 绘制各种的 reward 曲线
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

ax1, ax2 = axes

ax1.set_title('different reward function with the same DQN algorithm', fontsize=12, fontweight='bold')
ax2.set_title('same reward function with different RL algorithm', fontsize=12, fontweight='bold')

ax1.plot(dqn_exp822_episodes, dqn_exp822_ep_rew_mean_list, label="Ta_reward_function", color='royalblue')
ax1.plot(exp914_dqn_episodes, exp914_dqn_ep_rew_mean_list, label="Ca_reward_function", color='tomato')
ax1.plot(exp122_dqn_episodes, exp122_dqn_ep_rew_mean_list, label="multi_obj_reward_function", color='seagreen')

ax1.set_xlabel("Episodes", fontsize=11)
ax1.set_ylabel("Moving Average Reward", fontsize=11)

ax1.legend(loc='upper left', fontsize=9, frameon=True)
ax1.grid(alpha=0.3)

# 统一配置细节
ax1.legend(loc='upper left', fontsize=9, frameon=True)

ax2.plot(dqn_exp822_episodes, dqn_exp822_ep_rew_mean_list, label="DQN", color= 'royalblue')
ax2.plot(PPO_exp822_episodes, PPO_exp822_ep_rew_mean_list, label="DQN", color='darkorange')

ax2.set_xlabel("Episodes", fontsize=11)
ax2.set_ylabel("Moving Average Reward", fontsize=11)

ax2.legend(loc='upper left', fontsize=9, frameon=True)
ax2.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# plt.savefig(overleaf+'/all_rewards.pdf')

# %%
import os
import json
import matplotlib.pyplot as plt

# 统一读取数据
# 1.default single reward function Ta
# DQN
dqn_exp822_ep_rew_mean_list = []
dqn_exp822_episodes = []

with open(os.path.join("logs/iseec_lx_v4_mdp_plot_DQN_multi_objective_single_T_a_exp822_700000_default", "progress.json"), "r", encoding="utf-8") as f:
    for line in f: # 每一行读取
        if line.strip(): # 确保行不为空
            data = json.loads(line) # 单行的 data 部分
            if "rollout/ep_rew_mean" in data and "time/episodes" in data:
                dqn_exp822_ep_rew_mean_list.append(data["rollout/ep_rew_mean"])
                dqn_exp822_episodes.append(data["time/episodes"])

# PPO                      
PPO_exp822_ep_rew_mean_list = []
PPO_exp822_episodes = []  

with open(os.path.join("logs/iseec_lx_v4_mdp_plot_PPO_multi_objective_single_T_a_exp822_700000_default", "progress.json"), "r", encoding="utf-8") as f:
    for line in f: # 每一行读取
        if line.strip(): # 确保行不为空
            data = json.loads(line) # 单行的 data 部分
            if "rollout/ep_rew_mean" in data and "time/episodes" in data:
                PPO_exp822_ep_rew_mean_list.append(data["rollout/ep_rew_mean"])
                PPO_exp822_episodes.append(data["time/episodes"])

# 2、Reward function
exp914_dqn_ep_rew_mean_list = []
exp914_dqn_episodes = []        

with open(os.path.join("logs/iseec_lx_v4_mdp_plot_DQN_multi_objective_single_C_a_exp914_700000_default", "progress.json"), "r", encoding="utf-8") as f:
    for line in f: # 每一行读取
        if line.strip(): # 确保行不为空
            data = json.loads(line) # 单行的 data 部分
            if "rollout/ep_rew_mean" in data and "time/episodes" in data:
                exp914_dqn_ep_rew_mean_list.append(data["rollout/ep_rew_mean"])
                exp914_dqn_episodes.append(data["time/episodes"]) 
            
# 3. reward type: multi reward function
exp122_dqn_ep_rew_mean_list = []
exp122_dqn_episodes = []        

with open(os.path.join("logs/iseec_lx_v4_mdp_plot_DQN_multi_objective_all_T_a_Ca_exp122_weights_change_more_ta_700000_default", "progress.json"), "r", encoding="utf-8") as f:
    for line in f: # 每一行读取
        if line.strip(): # 确保行不为空
            data = json.loads(line) # 单行的 data 部分
            if "rollout/ep_rew_mean" in data and "time/episodes" in data:
                exp122_dqn_ep_rew_mean_list.append(data["rollout/ep_rew_mean"])
                exp122_dqn_episodes.append(data["time/episodes"]) 
                
exp1013_dqn_ep_rew_mean_list = []
exp1013_dqn_episodes = []

with open(os.path.join("logs/iseec_lx_v4_mdp_plot_DQN_multi_objective_all_energy_exp1013_700000_default", "progress.json"), "r", encoding="utf-8") as f:
    for line in f: # 每一行读取
        if line.strip(): # 确保行不为空
            data = json.loads(line) # 单行的 data 部分
            if "rollout/ep_rew_mean" in data and "time/episodes" in data:
                exp1013_dqn_ep_rew_mean_list.append(data["rollout/ep_rew_mean"])
                exp1013_dqn_episodes.append(data["time/episodes"])

# 绘制各种的 reward 曲线
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

ax1, ax2 = axes

ax1.set_title('different reward function with the same DQN algorithm', fontsize=12, fontweight='bold')
ax2.set_title('same reward function with different RL algorithm', fontsize=12, fontweight='bold')

ax1.plot(dqn_exp822_episodes, dqn_exp822_ep_rew_mean_list, label="Ta_reward_function", color='royalblue')
ax1.plot(exp914_dqn_episodes, exp914_dqn_ep_rew_mean_list, label="Ca_reward_function", color='tomato')
ax1.plot(exp122_dqn_episodes, exp122_dqn_ep_rew_mean_list, label="Ca_reward_function", color='seagreen')
ax1.plot(exp1013_dqn_episodes, exp1013_dqn_ep_rew_mean_list, label="eneergy_reward_function", color='darkgreen')

ax1.set_xlabel("Episodes", fontsize=11)
ax1.set_ylabel("Moving Average Reward", fontsize=11)

ax1.legend(loc='upper left', fontsize=9, frameon=True)
ax1.grid(alpha=0.3)

# 统一配置细节
ax1.legend(loc='upper left', fontsize=9, frameon=True)

ax2.plot(dqn_exp822_episodes, dqn_exp822_ep_rew_mean_list, label="DQN", color= 'royalblue')
ax2.plot(PPO_exp822_episodes, PPO_exp822_ep_rew_mean_list, label="DQN", color='darkorange')

ax2.set_xlabel("Episodes", fontsize=11)
ax2.set_ylabel("Moving Average Reward", fontsize=11)

ax2.legend(loc='upper left', fontsize=9, frameon=True)
ax2.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# plt.savefig(overleaf+'/all_rewards.pdf')

# %% [markdown]
# 绘制不同 Reward 下在同一算法对应的可视化图
