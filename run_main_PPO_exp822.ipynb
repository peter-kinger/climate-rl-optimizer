# %% [markdown]
# # RL 训练

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import scipy.io
from matplotlib.gridspec import GridSpec
import math
import random
import torch

from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.logger import configure
from stable_baselines3.common.monitor import Monitor
from stable_baselines3 import PPO 
# 导入 BaseCallback
from stable_baselines3.common.callbacks import BaseCallback

import sys
import os

# 将 src 目录添加到模块搜索路径
sys.path.append(os.path.abspath('src'))

# 导入 IEMEnv 类
from src.envs.iseec_lx_v4_mdp_plot import IEMEnv
from src.utils.run_debug_plot import save_data 
from src.utils.run_debug_plot import save_plot_NSM_data
from src.utils.run_debug_plot import save_plot_SSM_data

from src.utils.run_debug_plot import save_future_data
from src.utils.run_debug_plot import save_plot_NSM_future_data
from src.utils.run_debug_plot import save_plot_SSM_future_data

from src.utils.run_debug_plot import plot_episode_reward
from src.utils.run_debug_plot import plot_episode_reward_simple
from src.utils.run_debug_plot import plot_3D_run

# %% [markdown]
# 定义保存位置参数
#
# > 所有的关键参数都放在最前面

# %%
# 增加随机种子的定义
def set_global_seed(seed):
    """设置全局随机种子"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False


# 设置全局种子
# SEED = 42 # 非测试，不指定种子
# set_global_seed(SEED)

# 全新的超参数配置过程，都放在一起
base_config = {
    # MDP 元素
    "custom_reward_type" : "multi_objective_single_T_a_exp822",
    # 环境 & 策略
    "env_id":   "iseec_lx_v4_mdp_plot",
    "rl_model_name": "PPO",
    "policy":   "MlpPolicy",
    "network_name" : "Netxxx_no_big_env",
    # 训练时长
    "total_timesteps_diy": 700000,
    "policy_kwargs_diy" : "dict_pi_vf_default", # for example: policy_kwargs = dict(activation_fn=th.nn.ReLU,net_arch=[256, 256, dict(pi=[128, 64], vf=[128, 64])])
    # 优化器 & 网络
    "hyperparams_diy": "default", 
    # "learning_rate":   3e-4,
    # "ent_coef":        0.0,
    # "batch_size":      64,
    # "n_epochs":        10,
    # 回放 & 更新频率（PPO 固定写法示例）
    # "gamma":           0.99,
    # "clip_range":      0.2,
    # "gae_lambda":      0.95,
    # 随机种子
    "use_random_reset": False, # 是否使用随机重置
    "seed":            42,
}


############### 具体的配置细节##############
# 设置保存的日志名字：
log_name = f'{base_config["env_id"]}_{base_config["rl_model_name"]}_{base_config["custom_reward_type"]}_{int(base_config["total_timesteps_diy"])}_{base_config["hyperparams_diy"]}' 
os.makedirs(f'./logs/{log_name}', exist_ok=True) # 创建日志目录

# 相当于接口部分
custom_reward_type = base_config["custom_reward_type"]
network_name = base_config["network_name"]
rl_model_name = base_config["rl_model_name"]
total_timesteps_diy = base_config["total_timesteps_diy"]
policy_kwargs_diy = base_config["policy_kwargs_diy"] 

# 设置日志保存路径和格式
new_logger = configure(
    f"logs/{log_name}",  # tmp_path 路径保存位置
    # ["stdout",     # 终端输出
    [
     "csv",        # CSV文件
     "tensorboard", # Tensorboard格式
     "json"        # JSON格式
    ]
)

# %% [markdown]
# ### 定义环境

# %%
env = IEMEnv(reward_type=base_config["custom_reward_type"], seed=base_config["seed"])
env_monitor = Monitor(env, f'./logs/{log_name}')
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# ### 定义算法

# %%
# # 定义模型
model = PPO(
    "MlpPolicy", 
    env_monitor, 
    # ent_coef=0.01, # 增加策略寻找的鼓励，但是 suggestion 暂时不要改变
    verbose=1,
    )

# model = DQN(
#     "MlpPolicy", 
#     env_monitor, 
#     verbose=1,
#     )

model.set_logger(new_logger) # set the parameter of the logger
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
# check 环境
from stable_baselines3.common.env_checker import check_env
# check_env(env_monitor)
log_name

print("Action space sample:", env.action_space.sample())
# print("Observation space sample:", env.observation_space.sample())

# type(env.action_space), type(env.observation_space)
print("Action space sample:", env.action_space.sample())
print("Observation space sample:", env.observation_space.sample())

print(model.policy)
# Out:
# Action space sample: 5
# Action space sample: 5
# Observation space sample: [-0.66964028 -0.25866138 -0.10536173  1.87398643 -0.30972435 -0.03890111
#   0.10999642  0.0838588  -0.87981264  0.50824515]
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (pi_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (vf_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=16, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %% [markdown]
# ### 模型训练

# %%
def plot_callback_reward(metrics):
    """绘制训练过程中的奖励曲线
    
    Args:
        metrics (dict): 包含训练指标的字典，需要包含以下键：
            - rewards: 原始奖励列表
            - moving_avg_rewards: 移动平均奖励列表
            - moving_std_rewards: 移动标准差列表
            - episodes: 总回合数
            - step_idx: 当前步数
    """
    plt.figure(figsize=(20, 5))
    
    # 创建主图
    plt.subplot(131)
    plt.title(f'Step: {metrics["step_idx"]}, Latest reward: {metrics["rewards"][-1]:.2f}\n'
              f'Episode: {metrics["episodes"]}, Moving avg: {metrics["moving_avg_rewards"][-1]:.2f}')
    
    # 绘制原始奖励
    episodes = range(len(metrics["rewards"]))
    plt.plot(episodes, metrics["rewards"], 
             label='Raw rewards', color='gray', alpha=0.3)
    
    # 绘制移动平均
    plt.plot(episodes, metrics["moving_avg_rewards"],
             label='Moving average', color='blue', linewidth=2)
    
    # 添加标准差区域
    moving_avg = np.array(metrics["moving_avg_rewards"])
    moving_std = np.array(metrics["moving_std_rewards"])
    
    # 0.25倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.25 * moving_std,
                    moving_avg + 0.25 * moving_std,
                    color='b', alpha=0.1,
                    label='0.25 std range')
    
    # 0.5倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.5 * moving_std,
                    moving_avg + 0.5 * moving_std,
                    color='b', alpha=0.1,
                    label='0.5 std range')
    
    # 设置坐标轴和标签
    plt.xlabel('Episodes')
    plt.ylabel('Episode Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

class TrainingMonitorCallback(BaseCallback):
    def __init__(self, verbose=1, window_size=50):
        super().__init__(verbose)
        self.window_size = window_size
        # Initialize data dictionary to store metrics
        self.data = {
            "rewards": [],
            "moving_avg_rewards": [],
            "moving_std_rewards": [],
            "episodes": 0,
            "step_idx": 0
        }
        self.episode_rewards = 0
        
    def _on_step(self):
        # Accumulate rewards for current episode
        reward = self.locals.get('rewards')[0]
        self.episode_rewards += reward
        self.data["step_idx"] += 1
        
        # When episode ends, update all metrics
        if self.locals.get('dones')[0]:
            # Store raw reward
            self.data["rewards"].append(self.episode_rewards)
            
            # Calculate moving average and std
            recent_rewards = self.data["rewards"][-self.window_size:]
            moving_avg = np.mean(recent_rewards)
            moving_std = np.std(recent_rewards) if len(recent_rewards) > 1 else 0
            
            # Store calculated metrics
            self.data["moving_avg_rewards"].append(moving_avg)
            self.data["moving_std_rewards"].append(moving_std)
            self.data["episodes"] += 1
            
            # # Print progress
            # print(f"Episode {self.data['episodes']} finished with reward: {self.episode_rewards:.2f}")
            # print(f"Moving average (last {len(recent_rewards)} episodes): {moving_avg:.2f} ± {moving_std:.2f}")
            
            # Reset episode rewards
            self.episode_rewards = 0
            
        return True
    
    def get_metrics(self):
        """Return the collected metrics"""
        return self.data
    
# Create callback with custom window size
callback = TrainingMonitorCallback(window_size=50)

# Train the model
model.learn(
    total_timesteps=int(total_timesteps_diy),
    callback=callback,
    log_interval=1
)

# After training, get metrics for plotting
metrics = callback.get_metrics()

# Plot rewards using the plot_callback_reward function
plot_callback_reward(metrics)

# %% [markdown]
# notes: 如果要训练过程中查看模型，通过 tensorboard 查看

# %%
# 模型保存
model.save(f"./model/{log_name}")

# %% [markdown]
# ### 评估模型训练结果

# %% [markdown]
# > 利用 evaulate policy 函数评估

# %% [markdown]
# # 加载训练好的 RL 模型

# %%
from stable_baselines3.common.evaluation import evaluate_policy
mean_reward, std_reward = evaluate_policy(
    model, 
    model.get_env(), 
    deterministic=True,
    render=True,
    n_eval_episodes=10)

print(mean_reward)
print(std_reward)
# Out:
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# 22.578978799999998
# 14.399667048205584

# %%
# del model
model = PPO.load(f"./model/{log_name}", env=env_monitor)
# model = DQN.load(f"./model/{log_name}", env=env_monitor)
# Out:
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### 结果展示

# %% [markdown]
# #### 纯净展示版本
#
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆

for ep in range(episodes):
    
    obs, _ = env_monitor.reset(use_random_reset=base_config["use_random_reset"], seed=base_config["seed"]) # 必须的，每次重现一次
    
    episode_reward = 0
    done = False
    
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        print(f"year {env_monitor.t}-Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # # 每10步更新一次图像
        # if i == max_steps-1:
        #     env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            env_monitor.render()
            plt.show()  # 添加这行来保持图形窗口
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")
# Out:
# year 2017-Step 0 - Action: 14 - Reward: 2.020338387561824 - Done: False
# year 2018-Step 1 - Action: 14 - Reward: 1.8550777590099266 - Done: False
# year 2019-Step 2 - Action: 14 - Reward: 1.6813196133017583 - Done: False
# year 2020-Step 3 - Action: 14 - Reward: 1.5004772370243313 - Done: False
# year 2021-Step 4 - Action: 14 - Reward: 1.3133820319298595 - Done: False
# year 2022-Step 5 - Action: 14 - Reward: 1.1351865426226715 - Done: False
# year 2023-Step 6 - Action: 14 - Reward: 0.9657895243744796 - Done: False
# year 2024-Step 7 - Action: 14 - Reward: 0.8052036625709813 - Done: False
# year 2025-Step 8 - Action: 14 - Reward: 0.6535148791511669 - Done: False
# year 2026-Step 9 - Action: 14 - Reward: 0.5108516632498783 - Done: False
# year 2027-Step 10 - Action: 14 - Reward: 0.7548874214820445 - Done: False
# year 2028-Step 11 - Action: 14 - Reward: 0.5068995891927774 - Done: False
# year 2029-Step 12 - Action: 14 - Reward: 0.27817920532716034 - Done: False
# year 2030-Step 13 - Action: 14 - Reward: 0.06917094458549489 - Done: False
# year 2031-Step 14 - Action: 14 - Reward: -0.05989308996328768 - Done: False
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.t to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.t` for environment variables or `env.get_wrapper_attr('t')` that will search the reminding wrappers.
#   logger.warn(
# year 2032-Step 15 - Action: 14 - Reward: -0.14437770739617717 - Done: False
# year 2033-Step 16 - Action: 14 - Reward: -0.21908270206397185 - Done: False
# year 2034-Step 17 - Action: 14 - Reward: -0.28412811231586566 - Done: False
# year 2035-Step 18 - Action: 14 - Reward: -0.33975038900137755 - Done: False
# year 2036-Step 19 - Action: 14 - Reward: -0.38624589286618605 - Done: False
# year 2037-Step 20 - Action: 14 - Reward: -0.4239549967277101 - Done: False
# year 2038-Step 21 - Action: 14 - Reward: -0.45326267845749557 - Done: False
# year 2039-Step 22 - Action: 14 - Reward: -0.47458596650461704 - Done: False
# year 2040-Step 23 - Action: 14 - Reward: -0.48837965665280203 - Done: False
# year 2041-Step 24 - Action: 14 - Reward: -0.49513005366642937 - Done: False
# year 2042-Step 25 - Action: 14 - Reward: -0.49571981263689113 - Done: False
# year 2043-Step 26 - Action: 14 - Reward: -0.4908943872350213 - Done: False
# year 2044-Step 27 - Action: 14 - Reward: -0.4810777270200983 - Done: False
# year 2045-Step 28 - Action: 14 - Reward: -0.46666772714726745 - Done: False
# year 2046-Step 29 - Action: 14 - Reward: -0.44801686543704977 - Done: False
# year 2047-Step 30 - Action: 14 - Reward: -0.4254321199775324 - Done: False
# year 2048-Step 31 - Action: 14 - Reward: -0.3991898061139587 - Done: False
# year 2049-Step 32 - Action: 14 - Reward: -0.3695373229043275 - Done: False
# year 2050-Step 33 - Action: 14 - Reward: -0.33669943631741583 - Done: False
# year 2051-Step 34 - Action: 14 - Reward: -0.3008790912488035 - Done: False
# year 2052-Step 35 - Action: 14 - Reward: -0.2643584609336447 - Done: False
# year 2053-Step 36 - Action: 14 - Reward: -0.22736828767309536 - Done: False
# year 2054-Step 37 - Action: 14 - Reward: -0.19008792249453954 - Done: False
# year 2055-Step 38 - Action: 14 - Reward: -0.15265135959605103 - Done: False
# year 2056-Step 39 - Action: 14 - Reward: -0.11515140306569638 - Done: False
# year 2057-Step 40 - Action: 14 - Reward: -0.07764719496742511 - Done: False
# year 2058-Step 41 - Action: 14 - Reward: -0.04016906122497943 - Done: False
# year 2059-Step 42 - Action: 14 - Reward: -0.0027233746294574868 - Done: False
# year 2060-Step 43 - Action: 14 - Reward: 0.0694064670141481 - Done: False
# year 2061-Step 44 - Action: 14 - Reward: 0.14427619931700608 - Done: False
# year 2062-Step 45 - Action: 14 - Reward: 0.21905638300816044 - Done: False
# year 2063-Step 46 - Action: 14 - Reward: 0.29287428381223224 - Done: False
# year 2064-Step 47 - Action: 14 - Reward: 0.3654511238938629 - Done: False
# year 2065-Step 48 - Action: 14 - Reward: 0.4368884821116925 - Done: False
# year 2066-Step 49 - Action: 14 - Reward: 0.5073016480354298 - Done: False
# year 2067-Step 50 - Action: 14 - Reward: 0.576654437287234 - Done: False
# year 2068-Step 51 - Action: 14 - Reward: 0.6448803412570991 - Done: False
# year 2069-Step 52 - Action: 14 - Reward: 0.7120531263127394 - Done: False
# year 2070-Step 53 - Action: 14 - Reward: 0.778321833310518 - Done: False
# year 2071-Step 54 - Action: 14 - Reward: 0.843855726239644 - Done: False
# year 2072-Step 55 - Action: 14 - Reward: 0.9087527278413043 - Done: False
# year 2073-Step 56 - Action: 14 - Reward: 0.9726690394938009 - Done: False
# year 2074-Step 57 - Action: 14 - Reward: 0.5169806271297261 - Done: False
# year 2075-Step 58 - Action: 14 - Reward: 0.5465222609607423 - Done: False
# year 2076-Step 59 - Action: 14 - Reward: 0.5751594823461281 - Done: False
# year 2077-Step 60 - Action: 14 - Reward: 0.6030830672980136 - Done: False
# year 2078-Step 61 - Action: 14 - Reward: 0.6304733843749 - Done: False
# year 2079-Step 62 - Action: 14 - Reward: 0.6574978709252344 - Done: False
# year 2080-Step 63 - Action: 14 - Reward: 0.6843110551404308 - Done: False
# year 2081-Step 64 - Action: 14 - Reward: 0.7110540413996902 - Done: False
# year 2082-Step 65 - Action: 14 - Reward: 0.737845507556214 - Done: False
# year 2083-Step 66 - Action: 14 - Reward: 0.7647917707005991 - Done: False
# year 2084-Step 67 - Action: 14 - Reward: 0.7919944192458539 - Done: False
# year 2085-Step 68 - Action: 14 - Reward: 0.8195465887505782 - Done: False
# year 2086-Step 69 - Action: 14 - Reward: 0.8475344490334458 - Done: False
# year 2087-Step 70 - Action: 14 - Reward: 0.8760350818682039 - Done: False
# year 2088-Step 71 - Action: 14 - Reward: 0.9051175095695052 - Done: False
# year 2089-Step 72 - Action: 14 - Reward: 0.9348425232372537 - Done: False
# year 2090-Step 73 - Action: 14 - Reward: 0.9652655863250736 - Done: False
# year 2091-Step 74 - Action: 14 - Reward: 0.9964269845574247 - Done: False
# year 2092-Step 75 - Action: 14 - Reward: 1.0283596674352002 - Done: False
# year 2093-Step 76 - Action: 14 - Reward: 1.0611079884068109 - Done: False
# year 2094-Step 77 - Action: 14 - Reward: 1.0947081934385505 - Done: False
# year 2095-Step 78 - Action: 14 - Reward: 1.1291952546985118 - Done: False
# year 2096-Step 79 - Action: 14 - Reward: 1.1646002416586299 - Done: False
# year 2097-Step 80 - Action: 14 - Reward: 1.200949077136868 - Done: False
# year 2098-Step 81 - Action: 14 - Reward: 1.2382648582806344 - Done: False
# year 2099-Step 82 - Action: 14 - Reward: -5.0 - Done: False
# year 2100-Step 83 - Action: 14 - Reward: -5.0 - Done: True
# Episode ended at step 83 with T_a = 1.2368265541709291
# Episode 0 finished with reward-5.0
# Final T_a: 1.2368265541709291

# %% [markdown]
# ### 保存整体运行结果

# %%
env_test = IEMEnv(reward_type=custom_reward_type)
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# 这里可能就需要固定随机种子了

# %% [markdown]
# 主要针对可视化显示部分操作

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 绘制只展示一次 episode 结果

# env_test

for episode in range(1):
    obs, _ = env_test.reset() # 这里可能就需要固定随机种子了
    
    done = False
    
    for i in range(251):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        
        if done:
            print(f"Episode {episode} finished at step {i}")
            break
# Out:
# Step 0 - Action: 14 - Reward: 1.8143745250456578 - Done: False
# Step 1 - Action: 14 - Reward: 1.6757461357940906 - Done: False
# Step 2 - Action: 14 - Reward: 1.5268578539765576 - Done: False
# Step 3 - Action: 14 - Reward: 1.3694658033899332 - Done: False
# Step 4 - Action: 14 - Reward: 1.2046698371037179 - Done: False
# Step 5 - Action: 14 - Reward: 1.047870542342716 - Done: False
# Step 6 - Action: 14 - Reward: 0.899240410011588 - Done: False
# Step 7 - Action: 14 - Reward: 0.7589713222752248 - Done: False
# Step 8 - Action: 14 - Reward: 0.6273030227440013 - Done: False
# Step 9 - Action: 14 - Reward: 0.5044723244543547 - Done: False
# Step 10 - Action: 14 - Reward: 0.7813597034618636 - Done: False
# Step 11 - Action: 14 - Reward: 0.5721826642923489 - Done: False
# Step 12 - Action: 14 - Reward: 0.38158412705553424 - Done: False
# Step 13 - Action: 14 - Reward: 0.20965150827230383 - Done: False
# Step 14 - Action: 14 - Reward: 0.05631856254972423 - Done: False
# Step 15 - Action: 14 - Reward: -0.039511810359104116 - Done: False
# Step 16 - Action: 14 - Reward: -0.09860008543853271 - Done: False
# Step 17 - Action: 14 - Reward: -0.1494568405128749 - Done: False
# Step 18 - Action: 14 - Reward: -0.19249190904359392 - Done: False
# Step 19 - Action: 14 - Reward: -0.22806915351869295 - Done: False
# Step 20 - Action: 14 - Reward: -0.256475322130002 - Done: False
# Step 21 - Action: 14 - Reward: -0.27802723469104507 - Done: False
# Step 22 - Action: 14 - Reward: -0.29302238701883754 - Done: False
# Step 23 - Action: 14 - Reward: -0.3017721881101565 - Done: False
# Step 24 - Action: 14 - Reward: -0.30458920732850725 - Done: False
# Step 25 - Action: 14 - Reward: -0.3022247080483509 - Done: False
# Step 26 - Action: 14 - Reward: -0.29533002743152403 - Done: False
# Step 27 - Action: 14 - Reward: -0.28420753160681156 - Done: False
# Step 28 - Action: 14 - Reward: -0.26915585524531993 - Done: False
# Step 29 - Action: 14 - Reward: -0.2504230925556017 - Done: False
# Step 30 - Action: 14 - Reward: -0.22822364279061924 - Done: False
# Step 31 - Action: 14 - Reward: -0.20274643282186422 - Done: False
# Step 32 - Action: 14 - Reward: -0.17416130875385183 - Done: False
# Step 33 - Action: 14 - Reward: -0.1426246147114496 - Done: False
# Step 34 - Action: 14 - Reward: -0.10827914094772795 - Done: False
# Step 35 - Action: 14 - Reward: -0.07335633096012262 - Done: False
# Step 36 - Action: 14 - Reward: -0.03804581725243339 - Done: False
# Step 37 - Action: 14 - Reward: -0.0024910612675410615 - Done: False
# Step 38 - Action: 14 - Reward: 0.06640383075461775 - Done: False
# Step 39 - Action: 14 - Reward: 0.13792449203828383 - Done: False
# Step 40 - Action: 14 - Reward: 0.20949603922499227 - Done: False
# Step 41 - Action: 14 - Reward: 0.2810837875974226 - Done: False
# Step 42 - Action: 14 - Reward: 0.35269464505975456 - Done: False
# Step 43 - Action: 14 - Reward: 0.4243685480715875 - Done: False
# Step 44 - Action: 14 - Reward: 0.4961700556053139 - Done: False
# Step 45 - Action: 14 - Reward: 0.5679964378351654 - Done: False
# Step 46 - Action: 14 - Reward: 0.6389720814868727 - Done: False
# Step 47 - Action: 14 - Reward: 0.7088155353666625 - Done: False
# Step 48 - Action: 14 - Reward: 0.777621726854254 - Done: False
# Step 49 - Action: 14 - Reward: 0.8455285726031425 - Done: False
# Step 50 - Action: 14 - Reward: 0.9126918493738567 - Done: False
# Step 51 - Action: 14 - Reward: 0.9791735552493663 - Done: False
# Step 52 - Action: 14 - Reward: 0.5224741201988592 - Done: False
# Step 53 - Action: 14 - Reward: 0.5550156143649354 - Done: False
# Step 54 - Action: 14 - Reward: 0.5872457881785009 - Done: False
# Step 55 - Action: 14 - Reward: 0.619187863163233 - Done: False
# Step 56 - Action: 14 - Reward: 0.6506438240377121 - Done: False
# Step 57 - Action: 14 - Reward: 0.680778624306605 - Done: False
# Step 58 - Action: 14 - Reward: 0.7097863992992581 - Done: False
# Step 59 - Action: 14 - Reward: 0.7378629384683522 - Done: False
# Step 60 - Action: 14 - Reward: 0.7651952344303303 - Done: False
# Step 61 - Action: 14 - Reward: 0.7919644235070467 - Done: False
# Step 62 - Action: 14 - Reward: 0.818338906310786 - Done: False
# Step 63 - Action: 14 - Reward: 0.8444771087044223 - Done: False
# Step 64 - Action: 14 - Reward: 0.8705239058635628 - Done: False
# Step 65 - Action: 14 - Reward: 0.8966030754311449 - Done: False
# Step 66 - Action: 14 - Reward: 0.9228256505678367 - Done: False
# Step 67 - Action: 14 - Reward: 0.949298615694395 - Done: False
# Step 68 - Action: 14 - Reward: 0.9761199149418942 - Done: False
# Step 69 - Action: 14 - Reward: 1.0033806541357693 - Done: False
# Step 70 - Action: 14 - Reward: 1.0311630801057003 - Done: False
# Step 71 - Action: 14 - Reward: 1.0595413033282297 - Done: False
# Step 72 - Action: 14 - Reward: 1.0885807001830938 - Done: False
# Step 73 - Action: 14 - Reward: 1.118341335508768 - Done: False
# Step 74 - Action: 14 - Reward: 1.1488678435215716 - Done: False
# Step 75 - Action: 14 - Reward: 1.1801966760629823 - Done: False
# Step 76 - Action: 14 - Reward: 1.2123756459087176 - Done: False
# Step 77 - Action: 14 - Reward: 1.245443635946234 - Done: False
# Step 78 - Action: 14 - Reward: 1.2794385760984883 - Done: False
# Step 79 - Action: 14 - Reward: 1.3143926658154081 - Done: False
# Step 80 - Action: 14 - Reward: 1.350335072720641 - Done: False
# Step 81 - Action: 14 - Reward: 1.3872894519814827 - Done: False
# Step 82 - Action: 14 - Reward: -5.0 - Done: False
# Step 83 - Action: 14 - Reward: -5.0 - Done: True
# Episode 0 finished at step 83

# %% [markdown]
# # 保存运行结果
