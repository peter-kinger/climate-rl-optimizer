# %% [markdown]
# # RL 训练

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import scipy.io
from matplotlib.gridspec import GridSpec
import math
import random
import torch

from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.logger import configure
from stable_baselines3.common.monitor import Monitor
from stable_baselines3 import PPO 
from stable_baselines3 import DQN

from stable_baselines3 import SAC

# 导入 BaseCallback
from stable_baselines3.common.callbacks import BaseCallback

import sys
import os

# 将 src 目录添加到模块搜索路径
sys.path.append(os.path.abspath('src'))

# 导入 IEMEnv 类
from src.envs.iseec_lx_v4_mdp_plot import IEMEnv
from src.utils.run_debug_plot import save_data 
from src.utils.run_debug_plot import save_plot_NSM_data
from src.utils.run_debug_plot import save_plot_SSM_data

from src.utils.run_debug_plot import save_future_data
from src.utils.run_debug_plot import save_plot_NSM_future_data
from src.utils.run_debug_plot import save_plot_SSM_future_data

from src.utils.run_debug_plot import plot_episode_reward
from src.utils.run_debug_plot import plot_episode_reward_simple
from src.utils.run_debug_plot import plot_3D_run

# %% [markdown]
# 定义保存位置参数
#
# > 所有的关键参数都放在最前面

# %%
# 增加随机种子的定义
def set_global_seed(seed):
    """设置全局随机种子"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False


# 设置全局种子
# SEED = 42 # 非测试，不指定种子
# set_global_seed(SEED)

# 全新的超参数配置过程，都放在一起
base_config = {
    # MDP 元素
    "custom_reward_type" : "multi_objective_single_T_a_exp822",
    # 环境 & 策略
    "env_id":   "iseec_lx_v4_mdp_plot",
    "rl_model_name": "PPO",
    "policy":   "MlpPolicy",
    "network_name" : "Netxxx_no_big_env",
    # 训练时长
    "total_timesteps_diy": 700000,
    "policy_kwargs_diy" : "dict_pi_vf_default", # for example: policy_kwargs = dict(activation_fn=th.nn.ReLU,net_arch=[256, 256, dict(pi=[128, 64], vf=[128, 64])])
    # 优化器 & 网络
    "hyperparams_diy": "default", 
    # "learning_rate":   3e-4,
    # "ent_coef":        0.0,
    # "batch_size":      64,
    # "n_epochs":        10,
    # 回放 & 更新频率（PPO 固定写法示例）
    # "gamma":           0.99,
    # "clip_range":      0.2,
    # "gae_lambda":      0.95,
    # 随机种子
    "use_random_reset": False, # 是否使用随机重置
    "seed":            42,
}


############### 具体的配置细节##############
# 设置保存的日志名字：
log_name = f'{base_config["env_id"]}_{base_config["rl_model_name"]}_{base_config["custom_reward_type"]}_{int(base_config["total_timesteps_diy"])}_{base_config["hyperparams_diy"]}' 
os.makedirs(f'./logs/{log_name}', exist_ok=True) # 创建日志目录

# 相当于接口部分
custom_reward_type = base_config["custom_reward_type"]
network_name = base_config["network_name"]
rl_model_name = base_config["rl_model_name"]
total_timesteps_diy = base_config["total_timesteps_diy"]
policy_kwargs_diy = base_config["policy_kwargs_diy"] 

# 设置日志保存路径和格式
new_logger = configure(
    f"logs/{log_name}",  # tmp_path 路径保存位置
    # ["stdout",     # 终端输出
    [
     "csv",        # CSV文件
     "tensorboard", # Tensorboard格式
     "json"        # JSON格式
    ]
)

# %% [markdown]
# ### 定义环境

# %%
env = IEMEnv(reward_type=base_config["custom_reward_type"])
env_monitor = Monitor(env, f'./logs/{log_name}')
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# ### 定义算法

# %%
# # 定义模型
# model = PPO(
#     "MlpPolicy", 
#     env_monitor, 
#     # ent_coef=0.01, # 增加策略寻找的鼓励，但是 suggestion 暂时不要改变
#     verbose=1,
#     )

model = DQN(
    "MlpPolicy", 
    env_monitor, 
    verbose=1,
    )

model.set_logger(new_logger) # set the parameter of the logger
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
# check 环境
from stable_baselines3.common.env_checker import check_env
# check_env(env_monitor)
log_name

print("Action space sample:", env.action_space.sample())
# print("Observation space sample:", env.observation_space.sample())

# type(env.action_space), type(env.observation_space)
print("Action space sample:", env.action_space.sample())
print("Observation space sample:", env.observation_space.sample())

print(model.policy)
# Out:
# Action space sample: 11
# Action space sample: 13
# Observation space sample: [ 0.17555105 -0.32337695  0.33203416  0.04710884 -0.24674828 -0.53885296
#  -0.04580617  0.95979523 -0.2069989   1.10358743]
# DQNPolicy(
#   (q_net): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=16, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=16, bias=True)
#     )
#   )
# )

# %% [markdown]
# ### 模型训练

# %%
def plot_callback_reward(metrics):
    """绘制训练过程中的奖励曲线
    
    Args:
        metrics (dict): 包含训练指标的字典，需要包含以下键：
            - rewards: 原始奖励列表
            - moving_avg_rewards: 移动平均奖励列表
            - moving_std_rewards: 移动标准差列表
            - episodes: 总回合数
            - step_idx: 当前步数
    """
    plt.figure(figsize=(20, 5))
    
    # 创建主图
    plt.subplot(131)
    plt.title(f'Step: {metrics["step_idx"]}, Latest reward: {metrics["rewards"][-1]:.2f}\n'
              f'Episode: {metrics["episodes"]}, Moving avg: {metrics["moving_avg_rewards"][-1]:.2f}')
    
    # 绘制原始奖励
    episodes = range(len(metrics["rewards"]))
    plt.plot(episodes, metrics["rewards"], 
             label='Raw rewards', color='gray', alpha=0.3)
    
    # 绘制移动平均
    plt.plot(episodes, metrics["moving_avg_rewards"],
             label='Moving average', color='blue', linewidth=2)
    
    # 添加标准差区域
    moving_avg = np.array(metrics["moving_avg_rewards"])
    moving_std = np.array(metrics["moving_std_rewards"])
    
    # 0.25倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.25 * moving_std,
                    moving_avg + 0.25 * moving_std,
                    color='b', alpha=0.1,
                    label='0.25 std range')
    
    # 0.5倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.5 * moving_std,
                    moving_avg + 0.5 * moving_std,
                    color='b', alpha=0.1,
                    label='0.5 std range')
    
    # 设置坐标轴和标签
    plt.xlabel('Episodes')
    plt.ylabel('Episode Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

class TrainingMonitorCallback(BaseCallback):
    def __init__(self, verbose=1, window_size=50):
        super().__init__(verbose)
        self.window_size = window_size
        # Initialize data dictionary to store metrics
        self.data = {
            "rewards": [],
            "moving_avg_rewards": [],
            "moving_std_rewards": [],
            "episodes": 0,
            "step_idx": 0
        }
        self.episode_rewards = 0
        
    def _on_step(self):
        # Accumulate rewards for current episode
        reward = self.locals.get('rewards')[0]
        self.episode_rewards += reward
        self.data["step_idx"] += 1
        
        # When episode ends, update all metrics
        if self.locals.get('dones')[0]:
            # Store raw reward
            self.data["rewards"].append(self.episode_rewards)
            
            # Calculate moving average and std
            recent_rewards = self.data["rewards"][-self.window_size:]
            moving_avg = np.mean(recent_rewards)
            moving_std = np.std(recent_rewards) if len(recent_rewards) > 1 else 0
            
            # Store calculated metrics
            self.data["moving_avg_rewards"].append(moving_avg)
            self.data["moving_std_rewards"].append(moving_std)
            self.data["episodes"] += 1
            
            # Print progress
            print(f"Episode {self.data['episodes']} finished with reward: {self.episode_rewards:.2f}")
            print(f"Moving average (last {len(recent_rewards)} episodes): {moving_avg:.2f} ± {moving_std:.2f}")
            
            # Reset episode rewards
            self.episode_rewards = 0
            
        return True
    
    def get_metrics(self):
        """Return the collected metrics"""
        return self.data
    
# Create callback with custom window size
callback = TrainingMonitorCallback(window_size=50)

# Train the model
model.learn(
    total_timesteps=int(total_timesteps_diy),
    callback=callback,
    log_interval=1
)


# After training, get metrics for plotting
metrics = callback.get_metrics()

# Plot rewards using the plot_callback_reward function
plot_callback_reward(metrics)
# Out:
# Episode 1 finished with reward: -26.33
# Moving average (last 1 episodes): -26.33 ± 0.00
# Episode 2 finished with reward: -19.98
# Moving average (last 2 episodes): -23.16 ± 3.18
# Episode 3 finished with reward: -42.62
# Moving average (last 3 episodes): -29.64 ± 9.54
# Episode 4 finished with reward: -68.49
# Moving average (last 4 episodes): -39.36 ± 18.74
# Episode 5 finished with reward: -16.71
# Moving average (last 5 episodes): -34.83 ± 19.05
# Episode 6 finished with reward: -41.84
# Moving average (last 6 episodes): -36.00 ± 17.59
# Episode 7 finished with reward: -73.22
# Moving average (last 7 episodes): -41.32 ± 20.85
# Episode 8 finished with reward: -25.11
# Moving average (last 8 episodes): -39.29 ± 20.23
# Episode 9 finished with reward: -93.24
# Moving average (last 9 episodes): -45.28 ± 25.52
# Episode 10 finished with reward: -22.30
# Moving average (last 10 episodes): -42.99 ± 25.17
# Episode 11 finished with reward: -93.49
# Moving average (last 11 episodes): -47.58 ± 28.05
# Episode 12 finished with reward: -28.76
# Moving average (last 12 episodes): -46.01 ± 27.35
# Episode 13 finished with reward: -39.36
# Moving average (last 13 episodes): -45.50 ± 26.34
# Episode 14 finished with reward: -74.71
# Moving average (last 14 episodes): -47.58 ± 26.47
# Episode 15 finished with reward: -17.77
# Moving average (last 15 episodes): -45.60 ± 26.64
# Episode 16 finished with reward: -49.53
# Moving average (last 16 episodes): -45.84 ± 25.81
# Episode 17 finished with reward: -41.20
# Moving average (last 17 episodes): -45.57 ± 25.06
# Episode 18 finished with reward: -58.76
# Moving average (last 18 episodes): -46.30 ± 24.54
# Episode 19 finished with reward: -77.88
# Moving average (last 19 episodes): -47.96 ± 24.91
# Episode 20 finished with reward: -48.61
# Moving average (last 20 episodes): -48.00 ± 24.28
# Episode 21 finished with reward: -49.60
# Moving average (last 21 episodes): -48.07 ± 23.69
# Episode 22 finished with reward: -7.62
# Moving average (last 22 episodes): -46.23 ± 24.63
# Episode 23 finished with reward: -35.75
# Moving average (last 23 episodes): -45.78 ± 24.19
# Episode 24 finished with reward: -42.77
# Moving average (last 24 episodes): -45.65 ± 23.69
# Episode 25 finished with reward: -10.33
# Moving average (last 25 episodes): -44.24 ± 24.22
# Episode 26 finished with reward: -39.92
# Moving average (last 26 episodes): -44.07 ± 23.76
# Episode 27 finished with reward: -29.13
# Moving average (last 27 episodes): -43.52 ± 23.49
# Episode 28 finished with reward: -71.20
# Moving average (last 28 episodes): -44.51 ± 23.63
# Episode 29 finished with reward: -79.71
# Moving average (last 29 episodes): -45.72 ± 24.09
# Episode 30 finished with reward: -115.53
# Moving average (last 30 episodes): -48.05 ± 26.80
# Episode 31 finished with reward: -74.20
# Moving average (last 31 episodes): -48.89 ± 26.76
# Episode 32 finished with reward: 8.48
# Moving average (last 32 episodes): -47.10 ± 28.17
# Episode 33 finished with reward: -89.50
# Moving average (last 33 episodes): -48.38 ± 28.68
# Episode 34 finished with reward: -80.55
# Moving average (last 34 episodes): -49.33 ± 28.77
# Episode 35 finished with reward: -25.35
# Moving average (last 35 episodes): -48.65 ± 28.63
# Episode 36 finished with reward: -37.97
# Moving average (last 36 episodes): -48.35 ± 28.29
# Episode 37 finished with reward: -48.20
# Moving average (last 37 episodes): -48.34 ± 27.90
# Episode 38 finished with reward: -80.93
# Moving average (last 38 episodes): -49.20 ± 28.02
# Episode 39 finished with reward: -24.40
# Moving average (last 39 episodes): -48.57 ± 27.94
# Episode 40 finished with reward: -66.52
# Moving average (last 40 episodes): -49.02 ± 27.73
# Episode 41 finished with reward: -24.68
# Moving average (last 41 episodes): -48.42 ± 27.65
# Episode 42 finished with reward: -46.60
# Moving average (last 42 episodes): -48.38 ± 27.32
# Episode 43 finished with reward: -64.43
# Moving average (last 43 episodes): -48.75 ± 27.10
# Episode 44 finished with reward: 16.70
# Moving average (last 44 episodes): -47.26 ± 28.51
# Episode 45 finished with reward: -39.53
# Moving average (last 45 episodes): -47.09 ± 28.22
# Episode 46 finished with reward: -27.28
# Moving average (last 46 episodes): -46.66 ± 28.06
# Episode 47 finished with reward: -63.45
# Moving average (last 47 episodes): -47.02 ± 27.86
# Episode 48 finished with reward: -51.15
# Moving average (last 48 episodes): -47.10 ± 27.58
# Episode 49 finished with reward: -53.84
# Moving average (last 49 episodes): -47.24 ± 27.31
# Episode 50 finished with reward: -49.42
# Moving average (last 50 episodes): -47.29 ± 27.04
# Episode 51 finished with reward: -109.26
# Moving average (last 50 episodes): -48.94 ± 28.22
# Episode 52 finished with reward: -36.44
# Moving average (last 50 episodes): -49.27 ± 27.98
# Episode 53 finished with reward: -76.36
# Moving average (last 50 episodes): -49.95 ± 28.21
# Episode 54 finished with reward: -39.50
# Moving average (last 50 episodes): -49.37 ± 28.13
# Episode 55 finished with reward: -67.68
# Moving average (last 50 episodes): -50.39 ± 27.85
# Episode 56 finished with reward: -55.53
# Moving average (last 50 episodes): -50.66 ± 27.83
# Episode 57 finished with reward: -17.96
# Moving average (last 50 episodes): -49.56 ± 28.01
# Episode 58 finished with reward: -22.03
# Moving average (last 50 episodes): -49.49 ± 28.06
# Episode 59 finished with reward: -26.04
# Moving average (last 50 episodes): -48.15 ± 27.54
# Episode 60 finished with reward: -42.50
# Moving average (last 50 episodes): -48.55 ± 27.31
# Episode 61 finished with reward: -14.11
# Moving average (last 50 episodes): -46.97 ± 26.95
# Episode 62 finished with reward: -40.41
# Moving average (last 50 episodes): -47.20 ± 26.84
# Episode 63 finished with reward: -104.88
# Moving average (last 50 episodes): -48.51 ± 28.00
# Episode 64 finished with reward: 20.09
# Moving average (last 50 episodes): -46.61 ± 29.34
# Episode 65 finished with reward: -54.73
# Moving average (last 50 episodes): -47.35 ± 29.07
# Episode 66 finished with reward: -51.27
# Moving average (last 50 episodes): -47.39 ± 29.07
# Episode 67 finished with reward: -9.71
# Moving average (last 50 episodes): -46.76 ± 29.54
# Episode 68 finished with reward: -42.87
# Moving average (last 50 episodes): -46.44 ± 29.49
# Episode 69 finished with reward: -54.14
# Moving average (last 50 episodes): -45.97 ± 29.17
# Episode 70 finished with reward: -82.84
# Moving average (last 50 episodes): -46.65 ± 29.62
# Episode 71 finished with reward: -22.78
# Moving average (last 50 episodes): -46.12 ± 29.81
# Episode 72 finished with reward: 10.85
# Moving average (last 50 episodes): -45.75 ± 30.39
# Episode 73 finished with reward: 0.35
# Moving average (last 50 episodes): -45.02 ± 31.04
# Episode 74 finished with reward: -49.67
# Moving average (last 50 episodes): -45.16 ± 31.05
# Episode 75 finished with reward: -79.38
# Moving average (last 50 episodes): -46.54 ± 31.00
# Episode 76 finished with reward: -14.79
# Moving average (last 50 episodes): -46.04 ± 31.31
# Episode 77 finished with reward: -35.18
# Moving average (last 50 episodes): -46.16 ± 31.25
# Episode 78 finished with reward: -84.06
# Moving average (last 50 episodes): -46.42 ± 31.51
# Episode 79 finished with reward: -55.22
# Moving average (last 50 episodes): -45.93 ± 31.18
# Episode 80 finished with reward: -44.52
# Moving average (last 50 episodes): -44.51 ± 29.55
# Episode 81 finished with reward: -56.59
# Moving average (last 50 episodes): -44.16 ± 29.30
# Episode 82 finished with reward: -15.35
# Moving average (last 50 episodes): -44.63 ± 28.62
# Episode 83 finished with reward: 9.54
# Moving average (last 50 episodes): -42.65 ± 28.88
# Episode 84 finished with reward: -67.73
# Moving average (last 50 episodes): -42.40 ± 28.60
# Episode 85 finished with reward: -27.76
# Moving average (last 50 episodes): -42.44 ± 28.57
# Episode 86 finished with reward: -130.20
# Moving average (last 50 episodes): -44.29 ± 31.09
# Episode 87 finished with reward: -16.40
# Moving average (last 50 episodes): -43.65 ± 31.32
# Episode 88 finished with reward: -52.17
# Moving average (last 50 episodes): -43.08 ± 30.90
# Episode 89 finished with reward: -46.89
# Moving average (last 50 episodes): -43.53 ± 30.78
# Episode 90 finished with reward: -61.51
# Moving average (last 50 episodes): -43.43 ± 30.72
# Episode 91 finished with reward: -60.57
# Moving average (last 50 episodes): -44.15 ± 30.69
# Episode 92 finished with reward: 4.69
# Moving average (last 50 episodes): -43.12 ± 31.44
# Episode 93 finished with reward: 5.96
# Moving average (last 50 episodes): -41.71 ± 32.02
# Episode 94 finished with reward: -60.13
# Moving average (last 50 episodes): -43.25 ± 31.01
# Episode 95 finished with reward: -65.33
# Moving average (last 50 episodes): -43.76 ± 31.16
# Episode 96 finished with reward: -34.22
# Moving average (last 50 episodes): -43.90 ± 31.10
# Episode 97 finished with reward: -84.93
# Moving average (last 50 episodes): -44.33 ± 31.51
# Episode 98 finished with reward: -61.99
# Moving average (last 50 episodes): -44.55 ± 31.60
# Episode 99 finished with reward: -34.25
# Moving average (last 50 episodes): -44.16 ± 31.60
# Episode 100 finished with reward: -4.02
# Moving average (last 50 episodes): -43.25 ± 32.09
# Episode 101 finished with reward: -26.89
# Moving average (last 50 episodes): -41.60 ± 30.74
# Episode 102 finished with reward: -58.64
# Moving average (last 50 episodes): -42.05 ± 30.82
# Episode 103 finished with reward: -22.78
# Moving average (last 50 episodes): -40.97 ± 30.54
# Episode 104 finished with reward: -42.47
# Moving average (last 50 episodes): -41.03 ± 30.54
# Episode 105 finished with reward: -12.22
# Moving average (last 50 episodes): -39.92 ± 30.56
# Episode 106 finished with reward: -56.09
# Moving average (last 50 episodes): -39.94 ± 30.57
# Episode 107 finished with reward: -38.19
# Moving average (last 50 episodes): -40.34 ± 30.41
# Episode 108 finished with reward: -70.05
# Moving average (last 50 episodes): -41.30 ± 30.57
# Episode 109 finished with reward: -79.64
# Moving average (last 50 episodes): -42.37 ± 30.95
# Episode 110 finished with reward: -50.65
# Moving average (last 50 episodes): -42.54 ± 30.98
# Episode 111 finished with reward: -56.20
# Moving average (last 50 episodes): -43.38 ± 30.76
# Episode 112 finished with reward: -20.38
# Moving average (last 50 episodes): -42.98 ± 30.93
# Episode 113 finished with reward: -49.13
# Moving average (last 50 episodes): -41.86 ± 29.66
# Episode 114 finished with reward: 32.36
# Moving average (last 50 episodes): -41.62 ± 30.21
# Episode 115 finished with reward: -64.09
# Moving average (last 50 episodes): -41.80 ± 30.32
# Episode 116 finished with reward: -100.28
# Moving average (last 50 episodes): -42.78 ± 31.39
# Episode 117 finished with reward: 5.78
# Moving average (last 50 episodes): -42.47 ± 31.78
# Episode 118 finished with reward: -59.19
# Moving average (last 50 episodes): -42.80 ± 31.87
# Episode 119 finished with reward: -49.53
# Moving average (last 50 episodes): -42.71 ± 31.84
# Episode 120 finished with reward: -56.45
# Moving average (last 50 episodes): -42.18 ± 31.39
# Episode 121 finished with reward: -71.46
# Moving average (last 50 episodes): -43.15 ± 31.53
# Episode 122 finished with reward: -54.61
# Moving average (last 50 episodes): -44.46 ± 30.60
# Episode 123 finished with reward: -59.00
# Moving average (last 50 episodes): -45.65 ± 29.99
# Episode 124 finished with reward: -37.23
# Moving average (last 50 episodes): -45.40 ± 30.01
# Episode 125 finished with reward: -27.96
# Moving average (last 50 episodes): -44.37 ± 29.70
# Episode 126 finished with reward: -143.64
# Moving average (last 50 episodes): -46.95 ± 32.48
# Episode 127 finished with reward: -41.06
# Moving average (last 50 episodes): -47.07 ± 32.45
# Episode 128 finished with reward: -7.45
# Moving average (last 50 episodes): -45.54 ± 32.48
# Episode 129 finished with reward: -69.64
# Moving average (last 50 episodes): -45.82 ± 32.63
# Episode 130 finished with reward: -66.95
# Moving average (last 50 episodes): -46.27 ± 32.76
# Episode 131 finished with reward: 15.26
# Moving average (last 50 episodes): -44.84 ± 33.83
# Episode 132 finished with reward: -27.71
# Moving average (last 50 episodes): -45.08 ± 33.66
# Episode 133 finished with reward: -61.91
# Moving average (last 50 episodes): -46.51 ± 32.82
# Episode 134 finished with reward: -78.60
# Moving average (last 50 episodes): -46.73 ± 32.99
# Episode 135 finished with reward: 16.59
# Moving average (last 50 episodes): -45.84 ± 34.07
# Episode 136 finished with reward: -69.58
# Moving average (last 50 episodes): -44.63 ± 32.07
# Episode 137 finished with reward: -49.82
# Moving average (last 50 episodes): -45.30 ± 31.82
# Episode 138 finished with reward: -38.81
# Moving average (last 50 episodes): -45.03 ± 31.82
# Episode 139 finished with reward: 12.29
# Moving average (last 50 episodes): -43.85 ± 32.81
# Episode 140 finished with reward: -21.29
# Moving average (last 50 episodes): -43.04 ± 32.86
# Episode 141 finished with reward: -64.85
# Moving average (last 50 episodes): -43.13 ± 32.91
# Episode 142 finished with reward: -25.01
# Moving average (last 50 episodes): -43.72 ± 32.30
# Episode 143 finished with reward: -19.05
# Moving average (last 50 episodes): -44.22 ± 31.72
# Episode 144 finished with reward: -49.41
# Moving average (last 50 episodes): -44.01 ± 31.65
# Episode 145 finished with reward: -17.37
# Moving average (last 50 episodes): -43.05 ± 31.71
# Episode 146 finished with reward: -70.66
# Moving average (last 50 episodes): -43.78 ± 31.92
# Episode 147 finished with reward: -87.98
# Moving average (last 50 episodes): -43.84 ± 32.00
# Episode 148 finished with reward: -12.38
# Moving average (last 50 episodes): -42.85 ± 32.19
# Episode 149 finished with reward: -50.32
# Moving average (last 50 episodes): -43.17 ± 32.19
# Episode 150 finished with reward: -4.34
# Moving average (last 50 episodes): -43.17 ± 32.18
# Episode 151 finished with reward: 4.63
# Moving average (last 50 episodes): -42.54 ± 32.79
# Episode 152 finished with reward: -32.93
# Moving average (last 50 episodes): -42.03 ± 32.74
# Episode 153 finished with reward: -60.60
# Moving average (last 50 episodes): -42.79 ± 32.72
# Episode 154 finished with reward: -48.33
# Moving average (last 50 episodes): -42.90 ± 32.73
# Episode 155 finished with reward: -32.32
# Moving average (last 50 episodes): -43.30 ± 32.47
# Episode 156 finished with reward: -63.46
# Moving average (last 50 episodes): -43.45 ± 32.55
# Episode 157 finished with reward: -26.03
# Moving average (last 50 episodes): -43.21 ± 32.63
# Episode 158 finished with reward: -28.15
# Moving average (last 50 episodes): -42.37 ± 32.47
# Episode 159 finished with reward: -87.10
# Moving average (last 50 episodes): -42.52 ± 32.66
# Episode 160 finished with reward: 3.06
# Moving average (last 50 episodes): -41.45 ± 33.25
# Episode 161 finished with reward: -20.26
# Moving average (last 50 episodes): -40.73 ± 33.31
# Episode 162 finished with reward: -58.34
# Moving average (last 50 episodes): -41.49 ± 33.27
# Episode 163 finished with reward: -22.93
# Moving average (last 50 episodes): -40.96 ± 33.35
# Episode 164 finished with reward: -44.87
# Moving average (last 50 episodes): -42.51 ± 31.67
# Episode 165 finished with reward: -64.65
# Moving average (last 50 episodes): -42.52 ± 31.68
# Episode 166 finished with reward: -1.27
# Moving average (last 50 episodes): -40.54 ± 31.09
# Episode 167 finished with reward: -57.25
# Moving average (last 50 episodes): -41.80 ± 30.46
# Episode 168 finished with reward: -5.28
# Moving average (last 50 episodes): -40.72 ± 30.78
# Episode 169 finished with reward: -24.83
# Moving average (last 50 episodes): -40.23 ± 30.83
# Episode 170 finished with reward: -72.26
# Moving average (last 50 episodes): -40.54 ± 31.07
# Episode 171 finished with reward: -21.46
# Moving average (last 50 episodes): -39.54 ± 30.87
# Episode 172 finished with reward: -68.72
# Moving average (last 50 episodes): -39.82 ± 31.07
# Episode 173 finished with reward: -23.32
# Moving average (last 50 episodes): -39.11 ± 31.03
# Episode 174 finished with reward: -58.88
# Moving average (last 50 episodes): -39.54 ± 31.15
# Episode 175 finished with reward: -66.26
# Moving average (last 50 episodes): -40.31 ± 31.33
# Episode 176 finished with reward: -37.51
# Moving average (last 50 episodes): -38.19 ± 27.63
# Episode 177 finished with reward: -5.69
# Moving average (last 50 episodes): -37.48 ± 28.00
# Episode 178 finished with reward: -19.78
# Moving average (last 50 episodes): -37.73 ± 27.79
# Episode 179 finished with reward: -49.50
# Moving average (last 50 episodes): -37.32 ± 27.47
# Episode 180 finished with reward: -16.63
# Moving average (last 50 episodes): -36.32 ± 27.28
# Episode 181 finished with reward: -60.13
# Moving average (last 50 episodes): -37.83 ± 26.46
# Episode 182 finished with reward: -20.58
# Moving average (last 50 episodes): -37.68 ± 26.53
# Episode 183 finished with reward: 10.06
# Moving average (last 50 episodes): -36.24 ± 27.13
# Episode 184 finished with reward: 34.99
# Moving average (last 50 episodes): -33.97 ± 28.22
# Episode 185 finished with reward: -48.29
# Moving average (last 50 episodes): -35.27 ± 27.34
# Episode 186 finished with reward: -19.55
# Moving average (last 50 episodes): -34.27 ± 26.98
# Episode 187 finished with reward: -42.39
# Moving average (last 50 episodes): -34.12 ± 26.92
# Episode 188 finished with reward: -26.88
# Moving average (last 50 episodes): -33.88 ± 26.93
# Episode 189 finished with reward: -5.00
# Moving average (last 50 episodes): -34.23 ± 26.44
# Episode 190 finished with reward: 16.22
# Moving average (last 50 episodes): -33.48 ± 27.31
# Episode 191 finished with reward: -85.96
# Moving average (last 50 episodes): -33.90 ± 27.95
# Episode 192 finished with reward: 7.18
# Moving average (last 50 episodes): -33.26 ± 28.51
# Episode 193 finished with reward: -6.84
# Moving average (last 50 episodes): -33.01 ± 28.68
# Episode 194 finished with reward: -7.22
# Moving average (last 50 episodes): -32.17 ± 28.81
# Episode 195 finished with reward: -47.41
# Moving average (last 50 episodes): -32.77 ± 28.81
# Episode 196 finished with reward: 30.47
# Moving average (last 50 episodes): -30.75 ± 29.62
# Episode 197 finished with reward: -12.94
# Moving average (last 50 episodes): -29.24 ± 28.56
# Episode 198 finished with reward: -3.54
# Moving average (last 50 episodes): -29.07 ± 28.69
# Episode 199 finished with reward: -51.09
# Moving average (last 50 episodes): -29.08 ± 28.70
# Episode 200 finished with reward: -40.53
# Moving average (last 50 episodes): -29.81 ± 28.52
# Episode 201 finished with reward: 8.17
# Moving average (last 50 episodes): -29.74 ± 28.61
# Episode 202 finished with reward: -41.40
# Moving average (last 50 episodes): -29.91 ± 28.66
# Episode 203 finished with reward: -65.42
# Moving average (last 50 episodes): -30.00 ± 28.77
# Episode 204 finished with reward: -1.52
# Moving average (last 50 episodes): -29.07 ± 28.92
# Episode 205 finished with reward: -0.84
# Moving average (last 50 episodes): -28.44 ± 29.18
# Episode 206 finished with reward: -46.36
# Moving average (last 50 episodes): -28.09 ± 28.87
# Episode 207 finished with reward: -24.09
# Moving average (last 50 episodes): -28.05 ± 28.87
# Episode 208 finished with reward: -37.95
# Moving average (last 50 episodes): -28.25 ± 28.91
# Episode 209 finished with reward: -18.33
# Moving average (last 50 episodes): -26.88 ± 27.68
# Episode 210 finished with reward: -66.48
# Moving average (last 50 episodes): -28.27 ± 27.89
# Episode 211 finished with reward: -39.44
# Moving average (last 50 episodes): -28.65 ± 27.91
# Episode 212 finished with reward: -12.41
# Moving average (last 50 episodes): -27.73 ± 27.67
# Episode 213 finished with reward: -11.62
# Moving average (last 50 episodes): -27.50 ± 27.76
# Episode 214 finished with reward: -100.26
# Moving average (last 50 episodes): -28.61 ± 29.48
# Episode 215 finished with reward: -34.15
# Moving average (last 50 episodes): -28.00 ± 29.04
# Episode 216 finished with reward: -29.91
# Moving average (last 50 episodes): -28.58 ± 28.79
# Episode 217 finished with reward: 9.20
# Moving average (last 50 episodes): -27.25 ± 28.97
# Episode 218 finished with reward: -10.66
# Moving average (last 50 episodes): -27.35 ± 28.89
# Episode 219 finished with reward: -35.35
# Moving average (last 50 episodes): -27.56 ± 28.91
# Episode 220 finished with reward: -28.43
# Moving average (last 50 episodes): -26.69 ± 28.20
# Episode 221 finished with reward: -56.74
# Moving average (last 50 episodes): -27.39 ± 28.50
# Episode 222 finished with reward: 7.21
# Moving average (last 50 episodes): -25.87 ± 28.28
# Episode 223 finished with reward: -78.48
# Moving average (last 50 episodes): -26.98 ± 29.22
# Episode 224 finished with reward: -19.47
# Moving average (last 50 episodes): -26.19 ± 28.88
# Episode 225 finished with reward: -25.47
# Moving average (last 50 episodes): -25.37 ± 28.31
# Episode 226 finished with reward: -23.62
# Moving average (last 50 episodes): -25.10 ± 28.25
# Episode 227 finished with reward: -12.78
# Moving average (last 50 episodes): -25.24 ± 28.17
# Episode 228 finished with reward: -7.30
# Moving average (last 50 episodes): -24.99 ± 28.28
# Episode 229 finished with reward: -116.35
# Moving average (last 50 episodes): -26.33 ± 30.86
# Episode 230 finished with reward: -46.22
# Moving average (last 50 episodes): -26.92 ± 30.96
# Episode 231 finished with reward: -20.64
# Moving average (last 50 episodes): -26.13 ± 30.60
# Episode 232 finished with reward: -21.53
# Moving average (last 50 episodes): -26.15 ± 30.60
# Episode 233 finished with reward: 2.44
# Moving average (last 50 episodes): -26.30 ± 30.43
# Episode 234 finished with reward: -15.35
# Moving average (last 50 episodes): -27.31 ± 29.20
# Episode 235 finished with reward: -103.98
# Moving average (last 50 episodes): -28.42 ± 30.98
# Episode 236 finished with reward: -25.43
# Moving average (last 50 episodes): -28.54 ± 30.96
# Episode 237 finished with reward: -11.73
# Moving average (last 50 episodes): -27.92 ± 30.99
# Episode 238 finished with reward: -0.60
# Moving average (last 50 episodes): -27.40 ± 31.22
# Episode 239 finished with reward: -23.73
# Moving average (last 50 episodes): -27.77 ± 31.06
# Episode 240 finished with reward: -27.00
# Moving average (last 50 episodes): -28.64 ± 30.42
# Episode 241 finished with reward: -45.24
# Moving average (last 50 episodes): -27.82 ± 29.40
# Episode 242 finished with reward: 4.82
# Moving average (last 50 episodes): -27.87 ± 29.35
# Episode 243 finished with reward: -9.16
# Moving average (last 50 episodes): -27.92 ± 29.32
# Episode 244 finished with reward: -11.38
# Moving average (last 50 episodes): -28.00 ± 29.26
# Episode 245 finished with reward: -36.44
# Moving average (last 50 episodes): -27.78 ± 29.16
# Episode 246 finished with reward: -26.31
# Moving average (last 50 episodes): -28.92 ± 27.95
# Episode 247 finished with reward: -34.24
# Moving average (last 50 episodes): -29.34 ± 27.86
# Episode 248 finished with reward: 3.00
# Moving average (last 50 episodes): -29.21 ± 28.00
# Episode 249 finished with reward: -41.10
# Moving average (last 50 episodes): -29.01 ± 27.88
# Episode 250 finished with reward: -18.29
# Moving average (last 50 episodes): -28.57 ± 27.87
# Episode 251 finished with reward: -70.54
# Moving average (last 50 episodes): -30.14 ± 27.97
# Episode 252 finished with reward: -32.86
# Moving average (last 50 episodes): -29.97 ± 27.93
# Episode 253 finished with reward: -24.78
# Moving average (last 50 episodes): -29.16 ± 27.47
# Episode 254 finished with reward: -7.50
# Moving average (last 50 episodes): -29.28 ± 27.36
# Episode 255 finished with reward: 15.03
# Moving average (last 50 episodes): -28.96 ± 27.78
# Episode 256 finished with reward: -5.06
# Moving average (last 50 episodes): -28.13 ± 27.87
# Episode 257 finished with reward: 8.10
# Moving average (last 50 episodes): -27.49 ± 28.32
# Episode 258 finished with reward: -30.10
# Moving average (last 50 episodes): -27.33 ± 28.28
# Episode 259 finished with reward: 9.48
# Moving average (last 50 episodes): -26.78 ± 28.72
# Episode 260 finished with reward: 24.78
# Moving average (last 50 episodes): -24.95 ± 29.04
# Episode 261 finished with reward: -17.57
# Moving average (last 50 episodes): -24.51 ± 28.98
# Episode 262 finished with reward: -7.84
# Moving average (last 50 episodes): -24.42 ± 29.03
# Episode 263 finished with reward: -36.05
# Moving average (last 50 episodes): -24.91 ± 29.02
# Episode 264 finished with reward: -110.57
# Moving average (last 50 episodes): -25.12 ± 29.58
# Episode 265 finished with reward: -36.59
# Moving average (last 50 episodes): -25.17 ± 29.60
# Episode 266 finished with reward: -4.99
# Moving average (last 50 episodes): -24.67 ± 29.72
# Episode 267 finished with reward: -51.29
# Moving average (last 50 episodes): -25.88 ± 29.55
# Episode 268 finished with reward: -10.78
# Moving average (last 50 episodes): -25.88 ± 29.55
# Episode 269 finished with reward: 7.88
# Moving average (last 50 episodes): -25.02 ± 29.89
# Episode 270 finished with reward: -12.10
# Moving average (last 50 episodes): -24.69 ± 29.94
# Episode 271 finished with reward: 1.97
# Moving average (last 50 episodes): -23.52 ± 29.81
# Episode 272 finished with reward: -46.38
# Moving average (last 50 episodes): -24.59 ± 29.65
# Episode 273 finished with reward: -78.71
# Moving average (last 50 episodes): -24.59 ± 29.66
# Episode 274 finished with reward: -8.95
# Moving average (last 50 episodes): -24.38 ± 29.73
# Episode 275 finished with reward: 21.19
# Moving average (last 50 episodes): -23.45 ± 30.41
# Episode 276 finished with reward: -4.15
# Moving average (last 50 episodes): -23.06 ± 30.53
# Episode 277 finished with reward: -48.61
# Moving average (last 50 episodes): -23.78 ± 30.70
# Episode 278 finished with reward: -45.38
# Moving average (last 50 episodes): -24.54 ± 30.75
# Episode 279 finished with reward: 5.72
# Moving average (last 50 episodes): -22.10 ± 28.10
# Episode 280 finished with reward: -42.64
# Moving average (last 50 episodes): -22.02 ± 28.04
# Episode 281 finished with reward: 33.20
# Moving average (last 50 episodes): -20.95 ± 29.09
# Episode 282 finished with reward: -3.81
# Moving average (last 50 episodes): -20.59 ± 29.19
# Episode 283 finished with reward: -48.47
# Moving average (last 50 episodes): -21.61 ± 29.25
# Episode 284 finished with reward: -12.80
# Moving average (last 50 episodes): -21.56 ± 29.27
# Episode 285 finished with reward: -37.95
# Moving average (last 50 episodes): -20.24 ± 26.91
# Episode 286 finished with reward: -11.04
# Moving average (last 50 episodes): -19.95 ± 26.93
# Episode 287 finished with reward: -32.30
# Moving average (last 50 episodes): -20.36 ± 26.96
# Episode 288 finished with reward: -42.05
# Moving average (last 50 episodes): -21.19 ± 26.98
# Episode 289 finished with reward: -37.07
# Moving average (last 50 episodes): -21.46 ± 27.07
# Episode 290 finished with reward: 21.90
# Moving average (last 50 episodes): -20.48 ± 27.72
# Episode 291 finished with reward: -37.55
# Moving average (last 50 episodes): -20.33 ± 27.61
# Episode 292 finished with reward: -18.75
# Moving average (last 50 episodes): -20.80 ± 27.37
# Episode 293 finished with reward: 12.68
# Moving average (last 50 episodes): -20.36 ± 27.73
# Episode 294 finished with reward: -74.29
# Moving average (last 50 episodes): -21.62 ± 28.70
# Episode 295 finished with reward: -21.20
# Moving average (last 50 episodes): -21.32 ± 28.62
# Episode 296 finished with reward: 33.64
# Moving average (last 50 episodes): -20.12 ± 29.63
# Episode 297 finished with reward: -4.67
# Moving average (last 50 episodes): -19.52 ± 29.64
# Episode 298 finished with reward: -35.97
# Moving average (last 50 episodes): -20.30 ± 29.55
# Episode 299 finished with reward: -64.40
# Moving average (last 50 episodes): -20.77 ± 30.05
# Episode 300 finished with reward: -21.74
# Moving average (last 50 episodes): -20.84 ± 30.05
# Episode 301 finished with reward: -58.97
# Moving average (last 50 episodes): -20.61 ± 29.71
# Episode 302 finished with reward: 10.46
# Moving average (last 50 episodes): -19.74 ± 29.97
# Episode 303 finished with reward: 0.20
# Moving average (last 50 episodes): -19.24 ± 30.09
# Episode 304 finished with reward: -23.31
# Moving average (last 50 episodes): -19.56 ± 30.04
# Episode 305 finished with reward: -30.77
# Moving average (last 50 episodes): -20.47 ± 29.67
# Episode 306 finished with reward: -32.15
# Moving average (last 50 episodes): -21.02 ± 29.63
# Episode 307 finished with reward: -86.80
# Moving average (last 50 episodes): -22.91 ± 30.73
# Episode 308 finished with reward: -123.77
# Moving average (last 50 episodes): -24.79 ± 33.81
# Episode 309 finished with reward: -35.68
# Moving average (last 50 episodes): -25.69 ± 33.48
# Episode 310 finished with reward: -78.48
# Moving average (last 50 episodes): -27.76 ± 33.49
# Episode 311 finished with reward: 0.58
# Moving average (last 50 episodes): -27.39 ± 33.70
# Episode 312 finished with reward: -69.23
# Moving average (last 50 episodes): -28.62 ± 34.08
# Episode 313 finished with reward: -58.46
# Moving average (last 50 episodes): -29.07 ± 34.32
# Episode 314 finished with reward: -17.54
# Moving average (last 50 episodes): -27.21 ± 32.31
# Episode 315 finished with reward: -11.70
# Moving average (last 50 episodes): -26.71 ± 32.36
# Episode 316 finished with reward: -24.33
# Moving average (last 50 episodes): -27.10 ± 32.21
# Episode 317 finished with reward: -37.48
# Moving average (last 50 episodes): -26.82 ± 32.06
# Episode 318 finished with reward: 8.49
# Moving average (last 50 episodes): -26.44 ± 32.36
# Episode 319 finished with reward: -55.58
# Moving average (last 50 episodes): -27.70 ± 32.24
# Episode 320 finished with reward: -37.10
# Moving average (last 50 episodes): -28.20 ± 32.19
# Episode 321 finished with reward: 9.02
# Moving average (last 50 episodes): -28.06 ± 32.33
# Episode 322 finished with reward: 6.76
# Moving average (last 50 episodes): -27.00 ± 32.59
# Episode 323 finished with reward: 28.16
# Moving average (last 50 episodes): -24.86 ± 32.63
# Episode 324 finished with reward: -16.42
# Moving average (last 50 episodes): -25.01 ± 32.57
# Episode 325 finished with reward: -44.33
# Moving average (last 50 episodes): -26.32 ± 32.00
# Episode 326 finished with reward: -4.78
# Moving average (last 50 episodes): -26.34 ± 31.99
# Episode 327 finished with reward: -22.92
# Moving average (last 50 episodes): -25.82 ± 31.84
# Episode 328 finished with reward: 19.00
# Moving average (last 50 episodes): -24.53 ± 32.32
# Episode 329 finished with reward: -32.36
# Moving average (last 50 episodes): -25.30 ± 32.04
# Episode 330 finished with reward: -54.83
# Moving average (last 50 episodes): -25.54 ± 32.22
# Episode 331 finished with reward: -28.73
# Moving average (last 50 episodes): -26.78 ± 31.11
# Episode 332 finished with reward: -4.58
# Moving average (last 50 episodes): -26.79 ± 31.10
# Episode 333 finished with reward: -11.10
# Moving average (last 50 episodes): -26.05 ± 31.02
# Episode 334 finished with reward: -28.39
# Moving average (last 50 episodes): -26.36 ± 30.96
# Episode 335 finished with reward: -0.42
# Moving average (last 50 episodes): -25.61 ± 31.12
# Episode 336 finished with reward: 18.72
# Moving average (last 50 episodes): -25.01 ± 31.68
# Episode 337 finished with reward: -27.33
# Moving average (last 50 episodes): -24.91 ± 31.66
# Episode 338 finished with reward: -10.46
# Moving average (last 50 episodes): -24.28 ± 31.63
# Episode 339 finished with reward: -10.45
# Moving average (last 50 episodes): -23.75 ± 31.63
# Episode 340 finished with reward: -16.56
# Moving average (last 50 episodes): -24.52 ± 30.97
# Episode 341 finished with reward: -42.46
# Moving average (last 50 episodes): -24.62 ± 31.02
# Episode 342 finished with reward: 23.44
# Moving average (last 50 episodes): -23.77 ± 31.74
# Episode 343 finished with reward: -69.40
# Moving average (last 50 episodes): -25.41 ± 31.93
# Episode 344 finished with reward: -45.38
# Moving average (last 50 episodes): -24.84 ± 31.30
# Episode 345 finished with reward: -3.52
# Moving average (last 50 episodes): -24.48 ± 31.43
# Episode 346 finished with reward: -13.49
# Moving average (last 50 episodes): -25.42 ± 30.37
# Episode 347 finished with reward: -23.16
# Moving average (last 50 episodes): -25.79 ± 30.22
# Episode 348 finished with reward: -70.49
# Moving average (last 50 episodes): -26.48 ± 30.84
# Episode 349 finished with reward: -43.76
# Moving average (last 50 episodes): -26.07 ± 30.46
# Episode 350 finished with reward: 2.59
# Moving average (last 50 episodes): -25.59 ± 30.72
# Episode 351 finished with reward: 15.00
# Moving average (last 50 episodes): -24.11 ± 30.86
# Episode 352 finished with reward: 2.23
# Moving average (last 50 episodes): -24.27 ± 30.69
# Episode 353 finished with reward: 6.41
# Moving average (last 50 episodes): -24.15 ± 30.81
# Episode 354 finished with reward: -118.92
# Moving average (last 50 episodes): -26.06 ± 33.54
# Episode 355 finished with reward: -51.19
# Moving average (last 50 episodes): -26.47 ± 33.72
# Episode 356 finished with reward: -43.50
# Moving average (last 50 episodes): -26.69 ± 33.79
# Episode 357 finished with reward: -28.85
# Moving average (last 50 episodes): -25.53 ± 32.69
# Episode 358 finished with reward: -27.73
# Moving average (last 50 episodes): -23.61 ± 29.53
# Episode 359 finished with reward: -14.64
# Moving average (last 50 episodes): -23.19 ± 29.50
# Episode 360 finished with reward: -21.66
# Moving average (last 50 episodes): -22.06 ± 28.43
# Episode 361 finished with reward: -65.20
# Moving average (last 50 episodes): -23.37 ± 28.87
# Episode 362 finished with reward: -11.02
# Moving average (last 50 episodes): -22.21 ± 28.16
# Episode 363 finished with reward: -43.95
# Moving average (last 50 episodes): -21.92 ± 27.86
# Episode 364 finished with reward: -36.88
# Moving average (last 50 episodes): -22.30 ± 27.93
# Episode 365 finished with reward: -49.43
# Moving average (last 50 episodes): -23.06 ± 28.14
# Episode 366 finished with reward: -10.40
# Moving average (last 50 episodes): -22.78 ± 28.20
# Episode 367 finished with reward: -35.38
# Moving average (last 50 episodes): -22.74 ± 28.18
# Episode 368 finished with reward: -5.65
# Moving average (last 50 episodes): -23.02 ± 27.93
# Episode 369 finished with reward: 17.58
# Moving average (last 50 episodes): -21.56 ± 28.10
# Episode 370 finished with reward: -32.77
# Moving average (last 50 episodes): -21.47 ± 28.06
# Episode 371 finished with reward: 5.77
# Moving average (last 50 episodes): -21.54 ± 28.00
# Episode 372 finished with reward: 39.55
# Moving average (last 50 episodes): -20.88 ± 29.02
# Episode 373 finished with reward: -6.00
# Moving average (last 50 episodes): -21.56 ± 28.25
# Episode 374 finished with reward: -30.21
# Moving average (last 50 episodes): -21.84 ± 28.26
# Episode 375 finished with reward: 2.80
# Moving average (last 50 episodes): -20.90 ± 28.28
# Episode 376 finished with reward: 24.15
# Moving average (last 50 episodes): -20.32 ± 28.89
# Episode 377 finished with reward: -75.89
# Moving average (last 50 episodes): -21.38 ± 29.92
# Episode 378 finished with reward: 7.57
# Moving average (last 50 episodes): -21.61 ± 29.66
# Episode 379 finished with reward: -64.98
# Moving average (last 50 episodes): -22.26 ± 30.24
# Episode 380 finished with reward: -24.13
# Moving average (last 50 episodes): -21.64 ± 29.88
# Episode 381 finished with reward: -6.96
# Moving average (last 50 episodes): -21.21 ± 29.93
# Episode 382 finished with reward: -57.84
# Moving average (last 50 episodes): -22.27 ± 30.27
# Episode 383 finished with reward: -16.54
# Moving average (last 50 episodes): -22.38 ± 30.24
# Episode 384 finished with reward: 20.10
# Moving average (last 50 episodes): -21.41 ± 30.80
# Episode 385 finished with reward: 7.50
# Moving average (last 50 episodes): -21.25 ± 30.93
# Episode 386 finished with reward: -4.22
# Moving average (last 50 episodes): -21.71 ± 30.50
# Episode 387 finished with reward: -56.58
# Moving average (last 50 episodes): -22.30 ± 30.88
# Episode 388 finished with reward: -18.59
# Moving average (last 50 episodes): -22.46 ± 30.84
# Episode 389 finished with reward: -0.52
# Moving average (last 50 episodes): -22.26 ± 30.95
# Episode 390 finished with reward: -82.11
# Moving average (last 50 episodes): -23.57 ± 32.05
# Episode 391 finished with reward: -14.13
# Moving average (last 50 episodes): -23.01 ± 31.96
# Episode 392 finished with reward: -89.05
# Moving average (last 50 episodes): -25.26 ± 32.56
# Episode 393 finished with reward: -16.48
# Moving average (last 50 episodes): -24.20 ± 31.97
# Episode 394 finished with reward: 33.99
# Moving average (last 50 episodes): -22.61 ± 32.83
# Episode 395 finished with reward: -31.18
# Moving average (last 50 episodes): -23.16 ± 32.74
# Episode 396 finished with reward: 24.26
# Moving average (last 50 episodes): -22.41 ± 33.38
# Episode 397 finished with reward: -28.83
# Moving average (last 50 episodes): -22.52 ± 33.40
# Episode 398 finished with reward: -15.41
# Moving average (last 50 episodes): -21.42 ± 32.70
# Episode 399 finished with reward: -34.88
# Moving average (last 50 episodes): -21.24 ± 32.60
# Episode 400 finished with reward: 1.85
# Moving average (last 50 episodes): -21.26 ± 32.59
# Episode 401 finished with reward: -4.80
# Moving average (last 50 episodes): -21.65 ± 32.26
# Episode 402 finished with reward: -17.53
# Moving average (last 50 episodes): -22.05 ± 32.09
# Episode 403 finished with reward: -53.58
# Moving average (last 50 episodes): -23.25 ± 32.12
# Episode 404 finished with reward: 25.05
# Moving average (last 50 episodes): -20.37 ± 29.79
# Episode 405 finished with reward: 3.28
# Moving average (last 50 episodes): -19.28 ± 29.63
# Episode 406 finished with reward: -2.33
# Moving average (last 50 episodes): -18.46 ± 29.52
# Episode 407 finished with reward: -25.68
# Moving average (last 50 episodes): -18.39 ± 29.50
# Episode 408 finished with reward: -58.05
# Moving average (last 50 episodes): -19.00 ± 30.00
# Episode 409 finished with reward: 28.15
# Moving average (last 50 episodes): -18.14 ± 30.71
# Episode 410 finished with reward: -51.62
# Moving average (last 50 episodes): -18.74 ± 31.06
# Episode 411 finished with reward: -88.87
# Moving average (last 50 episodes): -19.22 ± 31.94
# Episode 412 finished with reward: -54.44
# Moving average (last 50 episodes): -20.09 ± 32.29
# Episode 413 finished with reward: -15.96
# Moving average (last 50 episodes): -19.53 ± 32.11
# Episode 414 finished with reward: -73.34
# Moving average (last 50 episodes): -20.25 ± 32.90
# Episode 415 finished with reward: -70.07
# Moving average (last 50 episodes): -20.67 ± 33.39
# Episode 416 finished with reward: 3.58
# Moving average (last 50 episodes): -20.39 ± 33.53
# Episode 417 finished with reward: -39.62
# Moving average (last 50 episodes): -20.47 ± 33.58
# Episode 418 finished with reward: 13.60
# Moving average (last 50 episodes): -20.09 ± 33.86
# Episode 419 finished with reward: -48.18
# Moving average (last 50 episodes): -21.40 ± 33.64
# Episode 420 finished with reward: -33.68
# Moving average (last 50 episodes): -21.42 ± 33.65
# Episode 421 finished with reward: -9.00
# Moving average (last 50 episodes): -21.72 ± 33.47
# Episode 422 finished with reward: 28.46
# Moving average (last 50 episodes): -21.94 ± 33.10
# Episode 423 finished with reward: -2.47
# Moving average (last 50 episodes): -21.87 ± 33.14
# Episode 424 finished with reward: 17.70
# Moving average (last 50 episodes): -20.91 ± 33.57
# Episode 425 finished with reward: -28.99
# Moving average (last 50 episodes): -21.55 ± 33.42
# Episode 426 finished with reward: 8.32
# Moving average (last 50 episodes): -21.86 ± 33.06
# Episode 427 finished with reward: -2.58
# Moving average (last 50 episodes): -20.40 ± 32.24
# Episode 428 finished with reward: 10.96
# Moving average (last 50 episodes): -20.33 ± 32.31
# Episode 429 finished with reward: 6.12
# Moving average (last 50 episodes): -18.91 ± 31.87
# Episode 430 finished with reward: -22.89
# Moving average (last 50 episodes): -18.88 ± 31.87
# Episode 431 finished with reward: -35.48
# Moving average (last 50 episodes): -19.45 ± 31.91
# Episode 432 finished with reward: -88.34
# Moving average (last 50 episodes): -20.06 ± 32.91
# Episode 433 finished with reward: -14.00
# Moving average (last 50 episodes): -20.01 ± 32.92
# Episode 434 finished with reward: -39.93
# Moving average (last 50 episodes): -21.21 ± 32.52
# Episode 435 finished with reward: -28.63
# Moving average (last 50 episodes): -21.93 ± 32.28
# Episode 436 finished with reward: -29.06
# Moving average (last 50 episodes): -22.43 ± 32.19
# Episode 437 finished with reward: -17.01
# Moving average (last 50 episodes): -21.64 ± 31.83
# Episode 438 finished with reward: -15.10
# Moving average (last 50 episodes): -21.57 ± 31.84
# Episode 439 finished with reward: -19.43
# Moving average (last 50 episodes): -21.95 ± 31.70
# Episode 440 finished with reward: -61.32
# Moving average (last 50 episodes): -21.53 ± 31.04
# Episode 441 finished with reward: -18.57
# Moving average (last 50 episodes): -21.62 ± 31.02
# Episode 442 finished with reward: -30.35
# Moving average (last 50 episodes): -20.45 ± 29.52
# Episode 443 finished with reward: -51.77
# Moving average (last 50 episodes): -21.15 ± 29.84
# Episode 444 finished with reward: -48.61
# Moving average (last 50 episodes): -22.81 ± 29.02
# Episode 445 finished with reward: -84.02
# Moving average (last 50 episodes): -23.86 ± 30.24
# Episode 446 finished with reward: -62.35
# Moving average (last 50 episodes): -25.59 ± 29.91
# Episode 447 finished with reward: -24.62
# Moving average (last 50 episodes): -25.51 ± 29.91
# Episode 448 finished with reward: -30.19
# Moving average (last 50 episodes): -25.81 ± 29.88
# Episode 449 finished with reward: -6.41
# Moving average (last 50 episodes): -25.24 ± 29.97
# Episode 450 finished with reward: -26.84
# Moving average (last 50 episodes): -25.81 ± 29.72
# Episode 451 finished with reward: -16.04
# Moving average (last 50 episodes): -26.04 ± 29.60
# Episode 452 finished with reward: -38.25
# Moving average (last 50 episodes): -26.45 ± 29.63
# Episode 453 finished with reward: -11.89
# Moving average (last 50 episodes): -25.62 ± 29.44
# Episode 454 finished with reward: -75.76
# Moving average (last 50 episodes): -27.63 ± 29.35
# Episode 455 finished with reward: -2.15
# Moving average (last 50 episodes): -27.74 ± 29.25
# Episode 456 finished with reward: 12.03
# Moving average (last 50 episodes): -27.45 ± 29.56
# Episode 457 finished with reward: -22.20
# Moving average (last 50 episodes): -27.38 ± 29.57
# Episode 458 finished with reward: -10.50
# Moving average (last 50 episodes): -26.43 ± 29.33
# Episode 459 finished with reward: 2.82
# Moving average (last 50 episodes): -26.94 ± 28.60
# Episode 460 finished with reward: -94.92
# Moving average (last 50 episodes): -27.81 ± 29.95
# Episode 461 finished with reward: 26.51
# Moving average (last 50 episodes): -25.50 ± 29.60
# Episode 462 finished with reward: 19.78
# Moving average (last 50 episodes): -24.01 ± 29.97
# Episode 463 finished with reward: 15.24
# Moving average (last 50 episodes): -23.39 ± 30.45
# Episode 464 finished with reward: 19.36
# Moving average (last 50 episodes): -21.54 ± 30.18
# Episode 465 finished with reward: -10.42
# Moving average (last 50 episodes): -20.34 ± 29.40
# Episode 466 finished with reward: -23.87
# Moving average (last 50 episodes): -20.89 ± 29.21
# Episode 467 finished with reward: -19.35
# Moving average (last 50 episodes): -20.49 ± 29.09
# Episode 468 finished with reward: -35.68
# Moving average (last 50 episodes): -21.47 ± 28.75
# Episode 469 finished with reward: -58.00
# Moving average (last 50 episodes): -21.67 ± 28.96
# Episode 470 finished with reward: -25.52
# Moving average (last 50 episodes): -21.50 ± 28.92
# Episode 471 finished with reward: -18.35
# Moving average (last 50 episodes): -21.69 ± 28.86
# Episode 472 finished with reward: 28.66
# Moving average (last 50 episodes): -21.69 ± 28.87
# Episode 473 finished with reward: -24.98
# Moving average (last 50 episodes): -22.14 ± 28.74
# Episode 474 finished with reward: -15.78
# Moving average (last 50 episodes): -22.81 ± 28.19
# Episode 475 finished with reward: 8.63
# Moving average (last 50 episodes): -22.05 ± 28.52
# Episode 476 finished with reward: -51.67
# Moving average (last 50 episodes): -23.25 ± 28.48
# Episode 477 finished with reward: -6.40
# Moving average (last 50 episodes): -23.33 ± 28.43
# Episode 478 finished with reward: 18.10
# Moving average (last 50 episodes): -23.19 ± 28.62
# Episode 479 finished with reward: -6.86
# Moving average (last 50 episodes): -23.45 ± 28.41
# Episode 480 finished with reward: -28.23
# Moving average (last 50 episodes): -23.55 ± 28.41
# Episode 481 finished with reward: -19.75
# Moving average (last 50 episodes): -23.24 ± 28.37
# Episode 482 finished with reward: -27.31
# Moving average (last 50 episodes): -22.02 ± 26.81
# Episode 483 finished with reward: -10.69
# Moving average (last 50 episodes): -21.95 ± 26.83
# Episode 484 finished with reward: -23.05
# Moving average (last 50 episodes): -21.62 ± 26.71
# Episode 485 finished with reward: 9.95
# Moving average (last 50 episodes): -20.84 ± 27.05
# Episode 486 finished with reward: 26.69
# Moving average (last 50 episodes): -19.73 ± 27.83
# Episode 487 finished with reward: -38.72
# Moving average (last 50 episodes): -20.16 ± 27.95
# Episode 488 finished with reward: -13.72
# Moving average (last 50 episodes): -20.14 ± 27.96
# Episode 489 finished with reward: 12.63
# Moving average (last 50 episodes): -19.49 ± 28.33
# Episode 490 finished with reward: -8.17
# Moving average (last 50 episodes): -18.43 ± 27.73
# Episode 491 finished with reward: -21.13
# Moving average (last 50 episodes): -18.48 ± 27.74
# Episode 492 finished with reward: -22.27
# Moving average (last 50 episodes): -18.32 ± 27.69
# Episode 493 finished with reward: -24.58
# Moving average (last 50 episodes): -17.78 ± 27.29
# Episode 494 finished with reward: -11.99
# Moving average (last 50 episodes): -17.04 ± 26.94
# Episode 495 finished with reward: -25.48
# Moving average (last 50 episodes): -15.87 ± 25.23
# Episode 496 finished with reward: -47.39
# Moving average (last 50 episodes): -15.57 ± 24.76
# Episode 497 finished with reward: 5.46
# Moving average (last 50 episodes): -14.97 ± 24.90
# Episode 498 finished with reward: -33.18
# Moving average (last 50 episodes): -15.03 ± 24.94
# Episode 499 finished with reward: 4.17
# Moving average (last 50 episodes): -14.82 ± 25.05
# Episode 500 finished with reward: -169.90
# Moving average (last 50 episodes): -17.68 ± 33.13
# Episode 501 finished with reward: -45.46
# Moving average (last 50 episodes): -18.27 ± 33.36
# Episode 502 finished with reward: -17.67
# Moving average (last 50 episodes): -17.86 ± 33.23
# Episode 503 finished with reward: -115.09
# Moving average (last 50 episodes): -19.92 ± 35.90
# Episode 504 finished with reward: -7.75
# Moving average (last 50 episodes): -18.56 ± 35.03
# Episode 505 finished with reward: -98.30
# Moving average (last 50 episodes): -20.49 ± 36.68
# Episode 506 finished with reward: -8.00
# Moving average (last 50 episodes): -20.89 ± 36.43
# Episode 507 finished with reward: 1.22
# Moving average (last 50 episodes): -20.42 ± 36.56
# Episode 508 finished with reward: -4.97
# Moving average (last 50 episodes): -20.31 ± 36.60
# Episode 509 finished with reward: 13.49
# Moving average (last 50 episodes): -20.09 ± 36.76
# Episode 510 finished with reward: -26.75
# Moving average (last 50 episodes): -18.73 ± 35.19
# Episode 511 finished with reward: -1.87
# Moving average (last 50 episodes): -19.30 ± 34.69
# Episode 512 finished with reward: -3.82
# Moving average (last 50 episodes): -19.77 ± 34.31
# Episode 513 finished with reward: -0.08
# Moving average (last 50 episodes): -20.08 ± 34.06
# Episode 514 finished with reward: -20.46
# Moving average (last 50 episodes): -20.87 ± 33.59
# Episode 515 finished with reward: -5.71
# Moving average (last 50 episodes): -20.78 ± 33.63
# Episode 516 finished with reward: -68.25
# Moving average (last 50 episodes): -21.67 ± 34.28
# Episode 517 finished with reward: 16.29
# Moving average (last 50 episodes): -20.95 ± 34.69
# Episode 518 finished with reward: 12.96
# Moving average (last 50 episodes): -19.98 ± 34.94
# Episode 519 finished with reward: 21.59
# Moving average (last 50 episodes): -18.39 ± 34.99
# Episode 520 finished with reward: -62.39
# Moving average (last 50 episodes): -19.13 ± 35.51
# Episode 521 finished with reward: -205.56
# Moving average (last 50 episodes): -22.87 ± 44.07
# Episode 522 finished with reward: 4.10
# Moving average (last 50 episodes): -23.36 ± 43.63
# Episode 523 finished with reward: -7.92
# Moving average (last 50 episodes): -23.02 ± 43.68
# Episode 524 finished with reward: -23.52
# Moving average (last 50 episodes): -23.18 ± 43.67
# Episode 525 finished with reward: -50.87
# Moving average (last 50 episodes): -24.37 ± 43.60
# Episode 526 finished with reward: -13.65
# Moving average (last 50 episodes): -23.61 ± 43.45
# Episode 527 finished with reward: -79.24
# Moving average (last 50 episodes): -25.06 ± 44.06
# Episode 528 finished with reward: 39.10
# Moving average (last 50 episodes): -24.64 ± 44.57
# Episode 529 finished with reward: -35.28
# Moving average (last 50 episodes): -25.21 ± 44.52
# Episode 530 finished with reward: -179.36
# Moving average (last 50 episodes): -28.23 ± 49.48
# Episode 531 finished with reward: -109.22
# ...
# Moving average (last 50 episodes): 16.05 ± 16.48
# Episode 8157 finished with reward: 23.55
# Moving average (last 50 episodes): 16.22 ± 16.51
# Episode 8158 finished with reward: 15.81
# Moving average (last 50 episodes): 16.95 ± 15.64
# Episode 8159 finished with reward: 30.97
# Moving average (last 50 episodes): 17.80 ± 15.21
# Episode 8160 finished with reward: 14.32
# Moving average (last 50 episodes): 17.51 ± 15.13
# Episode 8161 finished with reward: 31.02
# Moving average (last 50 episodes): 17.52 ± 15.14
# Episode 8162 finished with reward: 0.02
# Moving average (last 50 episodes): 17.07 ± 15.32
# Episode 8163 finished with reward: 30.76
# Moving average (last 50 episodes): 17.21 ± 15.42
# Episode 8164 finished with reward: 52.06
# Moving average (last 50 episodes): 17.79 ± 16.15
# Episode 8165 finished with reward: 24.05
# Moving average (last 50 episodes): 18.08 ± 16.13
# Episode 8166 finished with reward: 7.10
# Moving average (last 50 episodes): 17.84 ± 16.20
# Episode 8167 finished with reward: -7.45
# Moving average (last 50 episodes): 17.65 ± 16.45
# Episode 8168 finished with reward: -4.83
# Moving average (last 50 episodes): 17.43 ± 16.67
# Episode 8169 finished with reward: 24.92
# Moving average (last 50 episodes): 17.57 ± 16.71
# Episode 8170 finished with reward: 8.29
# Moving average (last 50 episodes): 17.94 ± 16.27
# Episode 8171 finished with reward: 17.56
# Moving average (last 50 episodes): 18.00 ± 16.27
# Episode 8172 finished with reward: -2.81
# Moving average (last 50 episodes): 17.57 ± 16.53
# Episode 8173 finished with reward: -20.85
# Moving average (last 50 episodes): 16.75 ± 17.37
# Episode 8174 finished with reward: 19.42
# Moving average (last 50 episodes): 16.59 ± 17.31
# Episode 8175 finished with reward: 10.73
# Moving average (last 50 episodes): 16.79 ± 17.19
# Episode 8176 finished with reward: -4.52
# Moving average (last 50 episodes): 16.56 ± 17.39
# Episode 8177 finished with reward: 47.51
# Moving average (last 50 episodes): 17.35 ± 17.88
# Episode 8178 finished with reward: 20.95
# Moving average (last 50 episodes): 17.16 ± 17.79
# Episode 8179 finished with reward: -2.14
# Moving average (last 50 episodes): 16.53 ± 17.90
# Episode 8180 finished with reward: 25.40
# Moving average (last 50 episodes): 16.40 ± 17.81
# Episode 8181 finished with reward: -31.97
# Moving average (last 50 episodes): 15.69 ± 18.97
# Episode 8182 finished with reward: 15.34
# Moving average (last 50 episodes): 15.91 ± 18.90
# Episode 8183 finished with reward: 54.47
# Moving average (last 50 episodes): 16.45 ± 19.60
# Episode 8184 finished with reward: -9.84
# Moving average (last 50 episodes): 15.88 ± 19.94
# Episode 8185 finished with reward: 36.05
# Moving average (last 50 episodes): 15.91 ± 19.97
# Episode 8186 finished with reward: 39.87
# Moving average (last 50 episodes): 16.16 ± 20.19
# Episode 8187 finished with reward: 22.40
# Moving average (last 50 episodes): 16.09 ± 20.16
# Episode 8188 finished with reward: 32.45
# Moving average (last 50 episodes): 16.19 ± 20.23
# Episode 8189 finished with reward: 22.69
# Moving average (last 50 episodes): 16.15 ± 20.21
# Episode 8190 finished with reward: 5.35
# Moving average (last 50 episodes): 15.42 ± 19.93
# Episode 8191 finished with reward: 9.54
# Moving average (last 50 episodes): 15.71 ± 19.74
# Episode 8192 finished with reward: 8.23
# Moving average (last 50 episodes): 15.61 ± 19.76
# Episode 8193 finished with reward: 17.28
# Moving average (last 50 episodes): 15.88 ± 19.68
# Episode 8194 finished with reward: 23.30
# Moving average (last 50 episodes): 15.72 ± 19.59
# Episode 8195 finished with reward: 48.85
# Moving average (last 50 episodes): 16.94 ± 19.71
# Episode 8196 finished with reward: 27.17
# Moving average (last 50 episodes): 17.44 ± 19.65
# Episode 8197 finished with reward: 39.15
# Moving average (last 50 episodes): 18.38 ± 19.54
# Episode 8198 finished with reward: -16.62
# Moving average (last 50 episodes): 17.63 ± 20.14
# Episode 8199 finished with reward: -10.30
# Moving average (last 50 episodes): 17.12 ± 20.51
# Episode 8200 finished with reward: -5.10
# Moving average (last 50 episodes): 16.81 ± 20.73
# Episode 8201 finished with reward: 17.64
# Moving average (last 50 episodes): 16.07 ± 20.01
# Episode 8202 finished with reward: 17.52
# Moving average (last 50 episodes): 16.88 ± 19.21
# Episode 8203 finished with reward: 16.88
# Moving average (last 50 episodes): 16.96 ± 19.20
# Episode 8204 finished with reward: 16.95
# Moving average (last 50 episodes): 16.42 ± 18.81
# Episode 8205 finished with reward: 20.67
# Moving average (last 50 episodes): 16.07 ± 18.57
# Episode 8206 finished with reward: 8.02
# Moving average (last 50 episodes): 15.76 ± 18.57
# Episode 8207 finished with reward: 2.89
# Moving average (last 50 episodes): 15.34 ± 18.62
# Episode 8208 finished with reward: 13.29
# Moving average (last 50 episodes): 15.29 ± 18.62
# Episode 8209 finished with reward: 24.35
# Moving average (last 50 episodes): 15.16 ± 18.53
# Episode 8210 finished with reward: 36.80
# Moving average (last 50 episodes): 15.61 ± 18.78
# Episode 8211 finished with reward: 42.65
# Moving average (last 50 episodes): 15.84 ± 19.04
# Episode 8212 finished with reward: -10.75
# Moving average (last 50 episodes): 15.63 ± 19.28
# Episode 8213 finished with reward: 28.32
# Moving average (last 50 episodes): 15.58 ± 19.24
# Episode 8214 finished with reward: 18.87
# Moving average (last 50 episodes): 14.91 ± 18.53
# Episode 8215 finished with reward: 47.45
# Moving average (last 50 episodes): 15.38 ± 19.04
# Episode 8216 finished with reward: -12.49
# Moving average (last 50 episodes): 14.99 ± 19.41
# Episode 8217 finished with reward: 36.13
# Moving average (last 50 episodes): 15.86 ± 19.36
# Episode 8218 finished with reward: 46.52
# Moving average (last 50 episodes): 16.89 ± 19.59
# Episode 8219 finished with reward: -15.52
# Moving average (last 50 episodes): 16.08 ± 20.07
# Episode 8220 finished with reward: 0.75
# Moving average (last 50 episodes): 15.93 ± 20.16
# Episode 8221 finished with reward: 24.45
# Moving average (last 50 episodes): 16.07 ± 20.19
# Episode 8222 finished with reward: 6.20
# Moving average (last 50 episodes): 16.25 ± 20.07
# Episode 8223 finished with reward: 32.22
# Moving average (last 50 episodes): 17.31 ± 19.47
# Episode 8224 finished with reward: 8.57
# Moving average (last 50 episodes): 17.09 ± 19.51
# Episode 8225 finished with reward: 47.52
# Moving average (last 50 episodes): 17.83 ± 19.94
# Episode 8226 finished with reward: 32.89
# Moving average (last 50 episodes): 18.58 ± 19.79
# Episode 8227 finished with reward: 24.33
# Moving average (last 50 episodes): 18.11 ± 19.37
# Episode 8228 finished with reward: 10.75
# Moving average (last 50 episodes): 17.91 ± 19.40
# Episode 8229 finished with reward: 33.64
# Moving average (last 50 episodes): 18.62 ± 19.30
# Episode 8230 finished with reward: -12.40
# Moving average (last 50 episodes): 17.87 ± 19.76
# Episode 8231 finished with reward: 13.59
# Moving average (last 50 episodes): 18.78 ± 18.44
# Episode 8232 finished with reward: 44.15
# Moving average (last 50 episodes): 19.36 ± 18.78
# Episode 8233 finished with reward: 24.08
# Moving average (last 50 episodes): 18.75 ± 18.11
# Episode 8234 finished with reward: 10.94
# Moving average (last 50 episodes): 19.16 ± 17.68
# Episode 8235 finished with reward: 19.57
# Moving average (last 50 episodes): 18.83 ± 17.52
# Episode 8236 finished with reward: 32.08
# Moving average (last 50 episodes): 18.68 ± 17.36
# Episode 8237 finished with reward: -25.57
# Moving average (last 50 episodes): 17.72 ± 18.42
# Episode 8238 finished with reward: 25.03
# Moving average (last 50 episodes): 17.57 ± 18.33
# Episode 8239 finished with reward: -23.42
# Moving average (last 50 episodes): 16.65 ± 19.19
# Episode 8240 finished with reward: 35.00
# Moving average (last 50 episodes): 17.24 ± 19.29
# Episode 8241 finished with reward: 26.60
# Moving average (last 50 episodes): 17.58 ± 19.30
# Episode 8242 finished with reward: 23.15
# Moving average (last 50 episodes): 17.88 ± 19.27
# Episode 8243 finished with reward: 1.67
# Moving average (last 50 episodes): 17.57 ± 19.40
# Episode 8244 finished with reward: -23.98
# Moving average (last 50 episodes): 16.62 ± 20.24
# Episode 8245 finished with reward: 53.27
# Moving average (last 50 episodes): 16.71 ± 20.39
# Episode 8246 finished with reward: 40.69
# Moving average (last 50 episodes): 16.98 ± 20.61
# Episode 8247 finished with reward: 30.64
# Moving average (last 50 episodes): 16.81 ± 20.46
# Episode 8248 finished with reward: 42.84
# Moving average (last 50 episodes): 18.00 ± 20.21
# Episode 8249 finished with reward: 28.33
# Moving average (last 50 episodes): 18.77 ± 19.85
# Episode 8250 finished with reward: 24.88
# Moving average (last 50 episodes): 19.37 ± 19.57
# Episode 8251 finished with reward: -9.02
# Moving average (last 50 episodes): 18.84 ± 19.97
# Episode 8252 finished with reward: 17.59
# Moving average (last 50 episodes): 18.84 ± 19.97
# Episode 8253 finished with reward: 1.62
# Moving average (last 50 episodes): 18.54 ± 20.11
# Episode 8254 finished with reward: -5.50
# Moving average (last 50 episodes): 18.09 ± 20.39
# Episode 8255 finished with reward: 45.31
# Moving average (last 50 episodes): 18.58 ± 20.74
# Episode 8256 finished with reward: -9.04
# Moving average (last 50 episodes): 18.24 ± 21.05
# Episode 8257 finished with reward: 37.79
# Moving average (last 50 episodes): 18.94 ± 21.11
# Episode 8258 finished with reward: 53.46
# Moving average (last 50 episodes): 19.74 ± 21.64
# Episode 8259 finished with reward: 17.79
# Moving average (last 50 episodes): 19.61 ± 21.63
# Episode 8260 finished with reward: 32.23
# Moving average (last 50 episodes): 19.52 ± 21.57
# Episode 8261 finished with reward: 6.99
# Moving average (last 50 episodes): 18.80 ± 21.38
# Episode 8262 finished with reward: -5.97
# Moving average (last 50 episodes): 18.90 ± 21.26
# Episode 8263 finished with reward: 20.71
# Moving average (last 50 episodes): 18.75 ± 21.21
# Episode 8264 finished with reward: 25.32
# Moving average (last 50 episodes): 18.88 ± 21.23
# Episode 8265 finished with reward: 45.35
# Moving average (last 50 episodes): 18.83 ± 21.18
# Episode 8266 finished with reward: 36.32
# Moving average (last 50 episodes): 19.81 ± 20.84
# Episode 8267 finished with reward: -4.31
# Moving average (last 50 episodes): 19.00 ± 20.97
# Episode 8268 finished with reward: 23.02
# Moving average (last 50 episodes): 18.53 ± 20.61
# Episode 8269 finished with reward: 17.14
# Moving average (last 50 episodes): 19.19 ± 20.03
# Episode 8270 finished with reward: 21.81
# Moving average (last 50 episodes): 19.61 ± 19.86
# Episode 8271 finished with reward: 20.28
# Moving average (last 50 episodes): 19.52 ± 19.85
# Episode 8272 finished with reward: -11.94
# Moving average (last 50 episodes): 19.16 ± 20.25
# Episode 8273 finished with reward: 14.72
# Moving average (last 50 episodes): 18.81 ± 20.17
# Episode 8274 finished with reward: 46.44
# Moving average (last 50 episodes): 19.57 ± 20.48
# Episode 8275 finished with reward: 26.96
# Moving average (last 50 episodes): 19.16 ± 20.12
# Episode 8276 finished with reward: -4.15
# Moving average (last 50 episodes): 18.42 ± 20.28
# Episode 8277 finished with reward: 24.84
# Moving average (last 50 episodes): 18.43 ± 20.28
# Episode 8278 finished with reward: -27.73
# Moving average (last 50 episodes): 17.66 ± 21.27
# Episode 8279 finished with reward: 23.42
# Moving average (last 50 episodes): 17.45 ± 21.16
# Episode 8280 finished with reward: 3.58
# Moving average (last 50 episodes): 17.77 ± 20.83
# Episode 8281 finished with reward: 15.15
# Moving average (last 50 episodes): 17.80 ± 20.82
# Episode 8282 finished with reward: 13.71
# Moving average (last 50 episodes): 17.19 ± 20.48
# Episode 8283 finished with reward: 31.37
# Moving average (last 50 episodes): 17.34 ± 20.56
# Episode 8284 finished with reward: 10.36
# Moving average (last 50 episodes): 17.33 ± 20.56
# Episode 8285 finished with reward: 15.31
# Moving average (last 50 episodes): 17.24 ± 20.56
# Episode 8286 finished with reward: -12.96
# Moving average (last 50 episodes): 16.34 ± 20.87
# Episode 8287 finished with reward: 15.07
# Moving average (last 50 episodes): 17.15 ± 20.00
# Episode 8288 finished with reward: 1.55
# Moving average (last 50 episodes): 16.68 ± 20.09
# Episode 8289 finished with reward: -7.57
# Moving average (last 50 episodes): 17.00 ± 19.57
# Episode 8290 finished with reward: 26.94
# Moving average (last 50 episodes): 16.84 ± 19.45
# Episode 8291 finished with reward: 28.60
# Moving average (last 50 episodes): 16.88 ± 19.47
# Episode 8292 finished with reward: 2.58
# Moving average (last 50 episodes): 16.47 ± 19.55
# Episode 8293 finished with reward: 34.02
# Moving average (last 50 episodes): 17.12 ± 19.59
# Episode 8294 finished with reward: 8.32
# Moving average (last 50 episodes): 17.76 ± 18.74
# Episode 8295 finished with reward: 5.12
# Moving average (last 50 episodes): 16.80 ± 18.11
# Episode 8296 finished with reward: 38.04
# Moving average (last 50 episodes): 16.75 ± 18.05
# Episode 8297 finished with reward: 21.77
# Moving average (last 50 episodes): 16.57 ± 17.95
# Episode 8298 finished with reward: -40.76
# Moving average (last 50 episodes): 14.90 ± 19.27
# Episode 8299 finished with reward: 3.98
# Moving average (last 50 episodes): 14.41 ± 19.24
# Episode 8300 finished with reward: 69.51
# Moving average (last 50 episodes): 15.30 ± 20.68
# Episode 8301 finished with reward: -21.87
# Moving average (last 50 episodes): 15.05 ± 21.06
# Episode 8302 finished with reward: 9.46
# Moving average (last 50 episodes): 14.88 ± 21.07
# Episode 8303 finished with reward: 39.73
# Moving average (last 50 episodes): 15.64 ± 21.27
# Episode 8304 finished with reward: -28.72
# Moving average (last 50 episodes): 15.18 ± 21.96
# Episode 8305 finished with reward: -21.85
# Moving average (last 50 episodes): 13.84 ± 22.13
# Episode 8306 finished with reward: 46.35
# Moving average (last 50 episodes): 14.95 ± 22.35
# Episode 8307 finished with reward: 5.48
# Moving average (last 50 episodes): 14.30 ± 22.14
# Episode 8308 finished with reward: 6.92
# Moving average (last 50 episodes): 13.37 ± 21.44
# Episode 8309 finished with reward: 33.62
# Moving average (last 50 episodes): 13.68 ± 21.62
# Episode 8310 finished with reward: 10.25
# Moving average (last 50 episodes): 13.25 ± 21.46
# Episode 8311 finished with reward: -0.38
# Moving average (last 50 episodes): 13.10 ± 21.53
# Episode 8312 finished with reward: 8.51
# Moving average (last 50 episodes): 13.39 ± 21.37
# Episode 8313 finished with reward: 36.82
# Moving average (last 50 episodes): 13.71 ± 21.60
# Episode 8314 finished with reward: 8.94
# Moving average (last 50 episodes): 13.38 ± 21.54
# Episode 8315 finished with reward: 23.95
# Moving average (last 50 episodes): 12.95 ± 21.11
# Episode 8316 finished with reward: 26.66
# Moving average (last 50 episodes): 12.76 ± 20.94
# Episode 8317 finished with reward: 16.97
# Moving average (last 50 episodes): 13.19 ± 20.81
# Episode 8318 finished with reward: -0.38
# Moving average (last 50 episodes): 12.72 ± 20.84
# Episode 8319 finished with reward: 33.58
# Moving average (last 50 episodes): 13.05 ± 21.04
# Episode 8320 finished with reward: -18.64
# Moving average (last 50 episodes): 12.24 ± 21.46
# Episode 8321 finished with reward: 16.78
# Moving average (last 50 episodes): 12.17 ± 21.44
# Episode 8322 finished with reward: 31.28
# Moving average (last 50 episodes): 13.03 ± 21.32
# Episode 8323 finished with reward: 39.04
# Moving average (last 50 episodes): 13.52 ± 21.63
# Episode 8324 finished with reward: -7.59
# Moving average (last 50 episodes): 12.44 ± 21.30
# Episode 8325 finished with reward: 17.60
# Moving average (last 50 episodes): 12.25 ± 21.22
# Episode 8326 finished with reward: 13.83
# Moving average (last 50 episodes): 12.61 ± 21.09
# Episode 8327 finished with reward: -2.44
# Moving average (last 50 episodes): 12.07 ± 21.12
# Episode 8328 finished with reward: 33.54
# Moving average (last 50 episodes): 13.29 ± 20.54
# Episode 8329 finished with reward: 39.48
# Moving average (last 50 episodes): 13.61 ± 20.82
# Episode 8330 finished with reward: 17.56
# Moving average (last 50 episodes): 13.89 ± 20.78
# Episode 8331 finished with reward: 28.39
# Moving average (last 50 episodes): 14.16 ± 20.88
# Episode 8332 finished with reward: 1.73
# Moving average (last 50 episodes): 13.92 ± 20.95
# Episode 8333 finished with reward: 31.02
# Moving average (last 50 episodes): 13.91 ± 20.94

# %%
# def plot_smooth_rewards(rewards, window_sizes=[5, 20, 100]):
#     """
#     绘制平滑的奖励曲线
#     Args:
#         rewards: 奖励列表
#         window_sizes: 移动平均窗口大小列表
#     """
#     plt.figure(figsize=(12, 6))
    
#     # 绘制原始奖励
#     plt.plot(rewards, 'lightgray', alpha=0.3, label='Raw rewards')
    
#     # 绘制不同窗口大小的移动平均
#     colors = ['blue', 'green', 'red']
#     for window, color in zip(window_sizes, colors):
#         if len(rewards) >= window:
#             # 计算移动平均
#             smooth_rewards = np.convolve(rewards, 
#                                       np.ones(window)/window, 
#                                       mode='valid')
#             plt.plot(range(window-1, len(rewards)), 
#                     smooth_rewards, 
#                     color=color, 
#                     label=f'{window}-Episode Moving Average',
#                     linewidth=2)
    
#     plt.xlabel('Episode')
#     plt.ylabel('Reward')
#     plt.title('Training Rewards with Different Smoothing Windows')
#     plt.grid(True, alpha=0.3)
#     plt.legend()
#     plt.show()


# # 绘制平滑奖励曲线
# plot_smooth_rewards(metrics["rewards"])

# %% [markdown]
# notes: 如果要训练过程中查看模型，通过 tensorboard 查看

# %%
# 模型保存
model.save(f"./model/{log_name}")

# %% [markdown]
# ### 评估模型训练结果

# %% [markdown]
# > 利用 evaulate policy 函数评估

# %% [markdown]
# # 加载训练好的 RL 模型

# %%
from stable_baselines3.common.evaluation import evaluate_policy
mean_reward, std_reward = evaluate_policy(
    model, 
    model.get_env(), 
    deterministic=True,
    render=True,
    n_eval_episodes=10)

print(mean_reward)
print(std_reward)
# Out:
# c:\Users\14842\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# 24.5718341
# 16.944411577632128

# %%
# del model
model = PPO.load(f"./model/{log_name}", env=env_monitor)
# model = DQN.load(f"./model/{log_name}", env=env_monitor)
# Out:
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # del model
# ----> 2 model = PPO.load(f"./model/{log_name}", env=env_monitor)
#       3 # model = DQN.load(f"./model/{log_name}", env=env_monitor)
#
# File c:\Users\14842\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\base_class.py:740, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     738 model.__dict__.update(data)
#     739 model.__dict__.update(kwargs)
# --> 740 model._setup_model()
#     742 try:
#     743     # put state_dicts back in place
#     744     model.set_parameters(params, exact_match=True, device=device)
#
# File c:\Users\14842\.conda\envs\torch_env\lib\site-packages\stable_baselines3\ppo\ppo.py:174, in PPO._setup_model(self)
#     173 def _setup_model(self) -> None:
# --> 174     super()._setup_model()
#     176     # Initialize schedules for policy/value clipping
#     177     self.clip_range = get_schedule_fn(self.clip_range)
#
# File c:\Users\14842\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:134, in OnPolicyAlgorithm._setup_model(self)
#     122         self.rollout_buffer_class = RolloutBuffer
#     124 self.rollout_buffer = self.rollout_buffer_class(
#     125     self.n_steps,
#     126     self.observation_space,  # type: ignore[arg-type]
#    (...)
#     132     **self.rollout_buffer_kwargs,
#     133 )
# --> 134 self.policy = self.policy_class(  # type: ignore[assignment]
#     135     self.observation_space, self.action_space, self.lr_schedule, use_sde=self.use_sde, **self.policy_kwargs
#     136 )
#     137 self.policy = self.policy.to(self.device)
#
# TypeError: __init__() got an unexpected keyword argument 'use_sde'

# %% [markdown]
# ### 结果展示

# %% [markdown]
# #### 纯净展示版本
#
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆

for ep in range(episodes):
    
    obs, _ = env_monitor.reset(use_random_reset=base_config["use_random_reset"], seed=base_config["seed"]) # 必须的，每次重现一次
    
    episode_reward = 0
    done = False
    
     
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        print(f"year {env_monitor.t}-Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # # 每10步更新一次图像
        # if i == max_steps-1:
        #     env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            env_monitor.render()
            plt.show()  # 添加这行来保持图形窗口
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")

# %% [markdown]
# ### 保存整体运行结果

# %%
env_test = IEMEnv(reward_type=custom_reward_type)

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 3 # 结果展示，只有一个 episode 部分
max_steps = 250

# all_episode_rewards = [] # 记录所有 episode 里面的
 
for ep in range(episodes):
    
    ##################################
    # 记录所需数组：每次 episode 重置
    total_action = []
    total_state = []
    total_reward = []
    total_done = []
    ##################################
    # 记录每个 episode 的 reward
    episode_reward = 0
    ##################################
    
    obs, _ = env_test.reset() # 必须的，每次重现一次 ，这里可能就需要固定随机种子了
    done = False
    
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        ##################################
        # 添加转换的部分
        action_number, action_name = IEMEnv.action2number_env(action)
        total_action.append(action_number)
        total_state.append(obs)
        total_reward.append(reward)
        total_done.append(done)
        ##################################
        # 记录每个 episode 的 reward
        episode_reward += reward # TODO：可以放在内容记录 step 部分
        ################################## 
        
        if done:
            print(f"Episode {ep} finished at step {i}")
            break
        
        # # 每10步更新一次图像
        # if ep % 10 == 0:
        #     env_monitor.render()
        #     # plt.pause(0.01)
    
    # all_episode_rewards.append(episode_reward)
    
    env_test.append_data_reward(episode_reward)
    
    save_future_data(env=env_test,custom_reward_type=custom_reward_type,rl_model_name=rl_model_name,network_name=policy_kwargs_diy,episode=ep,total_action=total_action,total_state=total_state,total_reward=total_reward,total_done=total_done,total_timesteps_name=total_timesteps_diy)

    save_plot_NSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    save_plot_SSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    # plot_3D_run(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state)
    
    
    print(f"Episode {ep} finished with reward{episode_reward}")
    
    
plot_data = env_test.get_variables()
plot_episode_reward(plot_data)

# %% [markdown]
# 主要针对可视化显示部分操作

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 绘制只展示一次 episode 结果

# env_test

for episode in range(1):
    obs, _ = env_test.reset() # 这里可能就需要固定随机种子了
    
    done = False
    
    for i in range(251):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        
        if done:
            print(f"Episode {episode} finished at step {i}")
            break

# %% [markdown]
# # 保存运行结果
