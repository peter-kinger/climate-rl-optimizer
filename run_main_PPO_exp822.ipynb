# %% [markdown]
# # RL 训练

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import scipy.io
from matplotlib.gridspec import GridSpec
import math
import random
import torch

from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.logger import configure
from stable_baselines3.common.monitor import Monitor
from stable_baselines3 import PPO 
from stable_baselines3 import DQN

from stable_baselines3 import SAC

# 导入 BaseCallback
from stable_baselines3.common.callbacks import BaseCallback

import sys
import os

# 将 src 目录添加到模块搜索路径
sys.path.append(os.path.abspath('src'))

# 导入 IEMEnv 类
from src.envs.iseec_lx_v4_mdp_plot import IEMEnv
from src.utils.run_debug_plot import save_data 
from src.utils.run_debug_plot import save_plot_NSM_data
from src.utils.run_debug_plot import save_plot_SSM_data

from src.utils.run_debug_plot import save_future_data
from src.utils.run_debug_plot import save_plot_NSM_future_data
from src.utils.run_debug_plot import save_plot_SSM_future_data

from src.utils.run_debug_plot import plot_episode_reward
from src.utils.run_debug_plot import plot_episode_reward_simple
from src.utils.run_debug_plot import plot_3D_run

# %% [markdown]
# 定义保存位置参数
#
# > 所有的关键参数都放在最前面

# %%
# 增加随机种子的定义
def set_global_seed(seed):
    """设置全局随机种子"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False


# 设置全局种子
# SEED = 42 # 非测试，不指定种子
# set_global_seed(SEED)

# 全新的超参数配置过程，都放在一起
base_config = {
    # MDP 元素
    "custom_reward_type" : "multi_objective_single_T_a_exp822",
    # 环境 & 策略
    "env_id":   "iseec_lx_v4_mdp_plot",
    "rl_model_name": "PPO",
    "policy":   "MlpPolicy",
    "network_name" : "Netxxx_no_big_env",
    # 训练时长
    "total_timesteps_diy": 700000,
    "policy_kwargs_diy" : "dict_pi_vf_default", # for example: policy_kwargs = dict(activation_fn=th.nn.ReLU,net_arch=[256, 256, dict(pi=[128, 64], vf=[128, 64])])
    # 优化器 & 网络
    "hyperparams_diy": "default", 
    # "learning_rate":   3e-4,
    # "ent_coef":        0.0,
    # "batch_size":      64,
    # "n_epochs":        10,
    # 回放 & 更新频率（PPO 固定写法示例）
    # "gamma":           0.99,
    # "clip_range":      0.2,
    # "gae_lambda":      0.95,
    # 随机种子
    "use_random_reset": False, # 是否使用随机重置
    "seed":            42,
}


############### 具体的配置细节##############
# 设置保存的日志名字：
log_name = f'{base_config["env_id"]}_{base_config["rl_model_name"]}_{base_config["custom_reward_type"]}_{int(base_config["total_timesteps_diy"])}_{base_config["hyperparams_diy"]}' 
os.makedirs(f'./logs/{log_name}', exist_ok=True) # 创建日志目录

# 相当于接口部分
custom_reward_type = base_config["custom_reward_type"]
network_name = base_config["network_name"]
rl_model_name = base_config["rl_model_name"]
total_timesteps_diy = base_config["total_timesteps_diy"]
policy_kwargs_diy = base_config["policy_kwargs_diy"] 

# 设置日志保存路径和格式
new_logger = configure(
    f"logs/{log_name}",  # tmp_path 路径保存位置
    # ["stdout",     # 终端输出
    [
     "csv",        # CSV文件
     "tensorboard", # Tensorboard格式
     "json"        # JSON格式
    ]
)

# %% [markdown]
# ### 定义环境

# %%
env = IEMEnv(reward_type=base_config["custom_reward_type"])
env_monitor = Monitor(env, f'./logs/{log_name}')
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# ### 定义算法

# %%
# # 定义模型
model = PPO(
    "MlpPolicy", 
    env_monitor, 
    # ent_coef=0.01, # 增加策略寻找的鼓励，但是 suggestion 暂时不要改变
    verbose=1,
    )

# model = DQN(
#     "MlpPolicy", 
#     env_monitor, 
#     verbose=1,
#     )

model.set_logger(new_logger) # set the parameter of the logger
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
# check 环境
from stable_baselines3.common.env_checker import check_env
# check_env(env_monitor)
log_name

print("Action space sample:", env.action_space.sample())
# print("Observation space sample:", env.observation_space.sample())

# type(env.action_space), type(env.observation_space)
print("Action space sample:", env.action_space.sample())
print("Observation space sample:", env.observation_space.sample())

print(model.policy)
# Out:
# Action space sample: 9
# Action space sample: 13
# Observation space sample: [ 0.01248482 -0.12892005 -0.44720971  0.5625265   0.21748904  1.83659054
#   0.6866946   0.7357719   0.08102591  1.11885463]
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (pi_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (vf_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=16, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %% [markdown]
# ### 模型训练

# %%
def plot_callback_reward(metrics):
    """绘制训练过程中的奖励曲线
    
    Args:
        metrics (dict): 包含训练指标的字典，需要包含以下键：
            - rewards: 原始奖励列表
            - moving_avg_rewards: 移动平均奖励列表
            - moving_std_rewards: 移动标准差列表
            - episodes: 总回合数
            - step_idx: 当前步数
    """
    plt.figure(figsize=(20, 5))
    
    # 创建主图
    plt.subplot(131)
    plt.title(f'Step: {metrics["step_idx"]}, Latest reward: {metrics["rewards"][-1]:.2f}\n'
              f'Episode: {metrics["episodes"]}, Moving avg: {metrics["moving_avg_rewards"][-1]:.2f}')
    
    # 绘制原始奖励
    episodes = range(len(metrics["rewards"]))
    plt.plot(episodes, metrics["rewards"], 
             label='Raw rewards', color='gray', alpha=0.3)
    
    # 绘制移动平均
    plt.plot(episodes, metrics["moving_avg_rewards"],
             label='Moving average', color='blue', linewidth=2)
    
    # 添加标准差区域
    moving_avg = np.array(metrics["moving_avg_rewards"])
    moving_std = np.array(metrics["moving_std_rewards"])
    
    # 0.25倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.25 * moving_std,
                    moving_avg + 0.25 * moving_std,
                    color='b', alpha=0.1,
                    label='0.25 std range')
    
    # 0.5倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.5 * moving_std,
                    moving_avg + 0.5 * moving_std,
                    color='b', alpha=0.1,
                    label='0.5 std range')
    
    # 设置坐标轴和标签
    plt.xlabel('Episodes')
    plt.ylabel('Episode Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

class TrainingMonitorCallback(BaseCallback):
    def __init__(self, verbose=1, window_size=50):
        super().__init__(verbose)
        self.window_size = window_size
        # Initialize data dictionary to store metrics
        self.data = {
            "rewards": [],
            "moving_avg_rewards": [],
            "moving_std_rewards": [],
            "episodes": 0,
            "step_idx": 0
        }
        self.episode_rewards = 0
        
    def _on_step(self):
        # Accumulate rewards for current episode
        reward = self.locals.get('rewards')[0]
        self.episode_rewards += reward
        self.data["step_idx"] += 1
        
        # When episode ends, update all metrics
        if self.locals.get('dones')[0]:
            # Store raw reward
            self.data["rewards"].append(self.episode_rewards)
            
            # Calculate moving average and std
            recent_rewards = self.data["rewards"][-self.window_size:]
            moving_avg = np.mean(recent_rewards)
            moving_std = np.std(recent_rewards) if len(recent_rewards) > 1 else 0
            
            # Store calculated metrics
            self.data["moving_avg_rewards"].append(moving_avg)
            self.data["moving_std_rewards"].append(moving_std)
            self.data["episodes"] += 1
            
            # Print progress
            print(f"Episode {self.data['episodes']} finished with reward: {self.episode_rewards:.2f}")
            print(f"Moving average (last {len(recent_rewards)} episodes): {moving_avg:.2f} ± {moving_std:.2f}")
            
            # Reset episode rewards
            self.episode_rewards = 0
            
        return True
    
    def get_metrics(self):
        """Return the collected metrics"""
        return self.data
    
# Create callback with custom window size
callback = TrainingMonitorCallback(window_size=50)

# Train the model
model.learn(
    total_timesteps=int(total_timesteps_diy),
    callback=callback,
    log_interval=1
)


# After training, get metrics for plotting
metrics = callback.get_metrics()

# Plot rewards using the plot_callback_reward function
plot_callback_reward(metrics)
# Out:
# Episode 1 finished with reward: -33.24
# Moving average (last 1 episodes): -33.24 ± 0.00
# Episode 2 finished with reward: -14.83
# Moving average (last 2 episodes): -24.04 ± 9.21
# Episode 3 finished with reward: -54.69
# Moving average (last 3 episodes): -34.25 ± 16.29
# Episode 4 finished with reward: -10.15
# Moving average (last 4 episodes): -28.23 ± 17.55
# Episode 5 finished with reward: -34.79
# Moving average (last 5 episodes): -29.54 ± 15.91
# Episode 6 finished with reward: -49.31
# Moving average (last 6 episodes): -32.83 ± 16.29
# Episode 7 finished with reward: -46.84
# Moving average (last 7 episodes): -34.83 ± 15.86
# Episode 8 finished with reward: -12.51
# Moving average (last 8 episodes): -32.04 ± 16.57
# Episode 9 finished with reward: -7.33
# Moving average (last 9 episodes): -29.30 ± 17.45
# Episode 10 finished with reward: -92.36
# Moving average (last 10 episodes): -35.60 ± 25.14
# Episode 11 finished with reward: -32.04
# Moving average (last 11 episodes): -35.28 ± 23.99
# Episode 12 finished with reward: -58.33
# Moving average (last 12 episodes): -37.20 ± 23.83
# Episode 13 finished with reward: 1.45
# Moving average (last 13 episodes): -34.23 ± 25.11
# Episode 14 finished with reward: -75.38
# Moving average (last 14 episodes): -37.17 ± 26.41
# Episode 15 finished with reward: -56.03
# Moving average (last 15 episodes): -38.42 ± 25.95
# Episode 16 finished with reward: -60.06
# Moving average (last 16 episodes): -39.78 ± 25.66
# Episode 17 finished with reward: -141.68
# Moving average (last 17 episodes): -45.77 ± 34.57
# Episode 18 finished with reward: -129.13
# Moving average (last 18 episodes): -50.40 ± 38.64
# Episode 19 finished with reward: -60.23
# Moving average (last 19 episodes): -50.92 ± 37.67
# Episode 20 finished with reward: -37.19
# Moving average (last 20 episodes): -50.23 ± 36.84
# Episode 21 finished with reward: -28.95
# Moving average (last 21 episodes): -49.22 ± 36.24
# Episode 22 finished with reward: -23.55
# Moving average (last 22 episodes): -48.05 ± 35.81
# Episode 23 finished with reward: -37.69
# Moving average (last 23 episodes): -47.60 ± 35.08
# Episode 24 finished with reward: -31.45
# Moving average (last 24 episodes): -46.93 ± 34.50
# Episode 25 finished with reward: 12.23
# Moving average (last 25 episodes): -44.56 ± 35.73
# Episode 26 finished with reward: -42.76
# Moving average (last 26 episodes): -44.49 ± 35.04
# Episode 27 finished with reward: -13.71
# Moving average (last 27 episodes): -43.35 ± 34.87
# Episode 28 finished with reward: 6.19
# Moving average (last 28 episodes): -41.58 ± 35.46
# Episode 29 finished with reward: -28.37
# Moving average (last 29 episodes): -41.13 ± 34.92
# Episode 30 finished with reward: -35.63
# Moving average (last 30 episodes): -40.94 ± 34.35
# Episode 31 finished with reward: -32.98
# Moving average (last 31 episodes): -40.69 ± 33.82
# Episode 32 finished with reward: -56.06
# Moving average (last 32 episodes): -41.17 ± 33.40
# Episode 33 finished with reward: -53.31
# Moving average (last 33 episodes): -41.54 ± 32.95
# Episode 34 finished with reward: -85.27
# Moving average (last 34 episodes): -42.82 ± 33.29
# Episode 35 finished with reward: -51.42
# Moving average (last 35 episodes): -43.07 ± 32.85
# Episode 36 finished with reward: -63.30
# Moving average (last 36 episodes): -43.63 ± 32.56
# Episode 37 finished with reward: -88.58
# Moving average (last 37 episodes): -44.84 ± 32.93
# Episode 38 finished with reward: 1.60
# Moving average (last 38 episodes): -43.62 ± 33.33
# Episode 39 finished with reward: -23.78
# Moving average (last 39 episodes): -43.11 ± 33.05
# Episode 40 finished with reward: -45.90
# Moving average (last 40 episodes): -43.18 ± 32.64
# Episode 41 finished with reward: 13.82
# Moving average (last 41 episodes): -41.79 ± 33.42
# Episode 42 finished with reward: -30.44
# Moving average (last 42 episodes): -41.52 ± 33.06
# Episode 43 finished with reward: -66.98
# Moving average (last 43 episodes): -42.11 ± 32.90
# Episode 44 finished with reward: -33.83
# Moving average (last 44 episodes): -41.93 ± 32.55
# Episode 45 finished with reward: 38.71
# Moving average (last 45 episodes): -40.13 ± 34.31
# Episode 46 finished with reward: -99.84
# Moving average (last 46 episodes): -41.43 ± 35.03
# Episode 47 finished with reward: -67.46
# Moving average (last 47 episodes): -41.99 ± 34.86
# Episode 48 finished with reward: -40.98
# Moving average (last 48 episodes): -41.97 ± 34.50
# Episode 49 finished with reward: -104.78
# Moving average (last 49 episodes): -43.25 ± 35.28
# Episode 50 finished with reward: -26.94
# Moving average (last 50 episodes): -42.92 ± 35.00
# Episode 51 finished with reward: 29.04
# Moving average (last 50 episodes): -41.68 ± 36.40
# Episode 52 finished with reward: -18.79
# Moving average (last 50 episodes): -41.75 ± 36.35
# Episode 53 finished with reward: -47.76
# Moving average (last 50 episodes): -41.62 ± 36.31
# Episode 54 finished with reward: 27.36
# Moving average (last 50 episodes): -40.87 ± 37.33
# Episode 55 finished with reward: 4.01
# Moving average (last 50 episodes): -40.09 ± 37.85
# Episode 56 finished with reward: -22.54
# Moving average (last 50 episodes): -39.55 ± 37.90
# Episode 57 finished with reward: -49.48
# Moving average (last 50 episodes): -39.61 ± 37.91
# Episode 58 finished with reward: -27.75
# Moving average (last 50 episodes): -39.91 ± 37.75
# Episode 59 finished with reward: -24.05
# Moving average (last 50 episodes): -40.25 ± 37.54
# Episode 60 finished with reward: -31.78
# Moving average (last 50 episodes): -39.04 ± 36.81
# Episode 61 finished with reward: -18.48
# Moving average (last 50 episodes): -38.76 ± 36.91
# Episode 62 finished with reward: -20.67
# Moving average (last 50 episodes): -38.01 ± 36.88
# Episode 63 finished with reward: -75.12
# Moving average (last 50 episodes): -39.54 ± 36.80
# Episode 64 finished with reward: -74.90
# Moving average (last 50 episodes): -39.53 ± 36.79
# Episode 65 finished with reward: -67.63
# Moving average (last 50 episodes): -39.77 ± 36.93
# Episode 66 finished with reward: -25.41
# Moving average (last 50 episodes): -39.07 ± 36.87
# Episode 67 finished with reward: -8.12
# Moving average (last 50 episodes): -36.40 ± 34.07
# Episode 68 finished with reward: -57.33
# Moving average (last 50 episodes): -34.96 ± 31.55
# Episode 69 finished with reward: -86.85
# Moving average (last 50 episodes): -35.50 ± 32.19
# Episode 70 finished with reward: -58.08
# Moving average (last 50 episodes): -35.92 ± 32.35
# Episode 71 finished with reward: -7.08
# Moving average (last 50 episodes): -35.48 ± 32.59
# Episode 72 finished with reward: -58.04
# Moving average (last 50 episodes): -36.17 ± 32.69
# Episode 73 finished with reward: -60.94
# Moving average (last 50 episodes): -36.63 ± 32.87
# Episode 74 finished with reward: 18.85
# Moving average (last 50 episodes): -35.63 ± 33.78
# Episode 75 finished with reward: -42.12
# Moving average (last 50 episodes): -36.71 ± 33.08
# Episode 76 finished with reward: -60.13
# Moving average (last 50 episodes): -37.06 ± 33.24
# Episode 77 finished with reward: -69.73
# Moving average (last 50 episodes): -38.18 ± 33.38
# Episode 78 finished with reward: -3.25
# Moving average (last 50 episodes): -38.37 ± 33.15
# Episode 79 finished with reward: -18.47
# Moving average (last 50 episodes): -38.17 ± 33.24
# Episode 80 finished with reward: -7.54
# Moving average (last 50 episodes): -37.61 ± 33.51
# Episode 81 finished with reward: -43.86
# Moving average (last 50 episodes): -37.83 ± 33.52
# Episode 82 finished with reward: 5.08
# Moving average (last 50 episodes): -36.61 ± 33.94
# Episode 83 finished with reward: -43.88
# Moving average (last 50 episodes): -36.42 ± 33.87
# Episode 84 finished with reward: -46.86
# Moving average (last 50 episodes): -35.65 ± 33.19
# Episode 85 finished with reward: -50.29
# Moving average (last 50 episodes): -35.63 ± 33.18
# Episode 86 finished with reward: -75.01
# Moving average (last 50 episodes): -35.86 ± 33.41
# Episode 87 finished with reward: -101.54
# Moving average (last 50 episodes): -36.12 ± 33.87
# Episode 88 finished with reward: -4.05
# Moving average (last 50 episodes): -36.23 ± 33.75
# Episode 89 finished with reward: -82.87
# Moving average (last 50 episodes): -37.41 ± 34.32
# Episode 90 finished with reward: -36.31
# Moving average (last 50 episodes): -37.22 ± 34.30
# Episode 91 finished with reward: -33.61
# Moving average (last 50 episodes): -38.17 ± 33.52
# Episode 92 finished with reward: -12.22
# Moving average (last 50 episodes): -37.81 ± 33.70
# Episode 93 finished with reward: -9.37
# Moving average (last 50 episodes): -36.65 ± 33.67
# Episode 94 finished with reward: -62.48
# Moving average (last 50 episodes): -37.23 ± 33.86
# Episode 95 finished with reward: -4.26
# Moving average (last 50 episodes): -38.09 ± 32.44
# Episode 96 finished with reward: -25.05
# Moving average (last 50 episodes): -36.59 ± 31.26
# Episode 97 finished with reward: -40.53
# Moving average (last 50 episodes): -36.05 ± 30.95
# Episode 98 finished with reward: -54.13
# Moving average (last 50 episodes): -36.32 ± 31.05
# Episode 99 finished with reward: -21.18
# Moving average (last 50 episodes): -34.64 ± 29.53
# Episode 100 finished with reward: -31.22
# Moving average (last 50 episodes): -34.73 ± 29.52
# Episode 101 finished with reward: -22.96
# Moving average (last 50 episodes): -35.77 ± 28.14
# Episode 102 finished with reward: -2.87
# Moving average (last 50 episodes): -35.45 ± 28.41
# Episode 103 finished with reward: -37.19
# Moving average (last 50 episodes): -35.24 ± 28.36
# Episode 104 finished with reward: -26.86
# Moving average (last 50 episodes): -36.32 ± 26.95
# Episode 105 finished with reward: -19.16
# Moving average (last 50 episodes): -36.79 ± 26.45
# Episode 106 finished with reward: -48.34
# Moving average (last 50 episodes): -37.30 ± 26.41
# Episode 107 finished with reward: -37.87
# Moving average (last 50 episodes): -37.07 ± 26.36
# Episode 108 finished with reward: -47.23
# Moving average (last 50 episodes): -37.46 ± 26.36
# Episode 109 finished with reward: -21.70
# Moving average (last 50 episodes): -37.41 ± 26.39
# Episode 110 finished with reward: 13.58
# Moving average (last 50 episodes): -36.51 ± 27.33
# Episode 111 finished with reward: -0.84
# Moving average (last 50 episodes): -36.15 ± 27.67
# Episode 112 finished with reward: -19.55
# Moving average (last 50 episodes): -36.13 ± 27.68
# Episode 113 finished with reward: -4.25
# Moving average (last 50 episodes): -34.71 ± 27.46
# Episode 114 finished with reward: -13.01
# Moving average (last 50 episodes): -33.48 ± 27.02
# Episode 115 finished with reward: -42.08
# Moving average (last 50 episodes): -32.96 ± 26.60
# Episode 116 finished with reward: -15.51
# Moving average (last 50 episodes): -32.77 ± 26.70
# Episode 117 finished with reward: 7.47
# Moving average (last 50 episodes): -32.45 ± 27.07
# Episode 118 finished with reward: -33.88
# Moving average (last 50 episodes): -31.99 ± 26.84
# Episode 119 finished with reward: -29.11
# Moving average (last 50 episodes): -30.83 ± 25.67
# Episode 120 finished with reward: -37.44
# Moving average (last 50 episodes): -30.42 ± 25.39
# Episode 121 finished with reward: -16.06
# Moving average (last 50 episodes): -30.60 ± 25.26
# Episode 122 finished with reward: -71.36
# Moving average (last 50 episodes): -30.86 ± 25.61
# Episode 123 finished with reward: -47.67
# Moving average (last 50 episodes): -30.60 ± 25.37
# Episode 124 finished with reward: -15.08
# Moving average (last 50 episodes): -31.28 ± 24.47
# Episode 125 finished with reward: -7.77
# Moving average (last 50 episodes): -30.59 ± 24.64
# Episode 126 finished with reward: -13.13
# Moving average (last 50 episodes): -29.65 ± 24.39
# Episode 127 finished with reward: 13.97
# Moving average (last 50 episodes): -27.98 ± 24.45
# Episode 128 finished with reward: 22.16
# Moving average (last 50 episodes): -27.47 ± 25.22
# Episode 129 finished with reward: -44.25
# Moving average (last 50 episodes): -27.98 ± 25.29
# Episode 130 finished with reward: -26.96
# Moving average (last 50 episodes): -28.37 ± 25.12
# Episode 131 finished with reward: -3.37
# Moving average (last 50 episodes): -27.56 ± 25.26
# Episode 132 finished with reward: 1.57
# Moving average (last 50 episodes): -27.63 ± 25.18
# Episode 133 finished with reward: -42.82
# Moving average (last 50 episodes): -27.61 ± 25.16
# Episode 134 finished with reward: -53.75
# Moving average (last 50 episodes): -27.75 ± 25.29
# Episode 135 finished with reward: -21.12
# Moving average (last 50 episodes): -27.16 ± 25.09
# Episode 136 finished with reward: -18.40
# Moving average (last 50 episodes): -26.03 ± 24.17
# Episode 137 finished with reward: -29.37
# Moving average (last 50 episodes): -24.59 ± 21.64
# Episode 138 finished with reward: -5.26
# Moving average (last 50 episodes): -24.61 ± 21.62
# Episode 139 finished with reward: -68.78
# Moving average (last 50 episodes): -24.33 ± 20.94
# Episode 140 finished with reward: -18.99
# Moving average (last 50 episodes): -23.99 ± 20.88
# Episode 141 finished with reward: -26.27
# Moving average (last 50 episodes): -23.84 ± 20.84
# Episode 142 finished with reward: -56.23
# Moving average (last 50 episodes): -24.72 ± 21.25
# Episode 143 finished with reward: -42.80
# Moving average (last 50 episodes): -25.39 ± 21.29
# Episode 144 finished with reward: -19.06
# Moving average (last 50 episodes): -24.52 ± 20.63
# Episode 145 finished with reward: -14.60
# Moving average (last 50 episodes): -24.73 ± 20.48
# Episode 146 finished with reward: -33.56
# Moving average (last 50 episodes): -24.90 ± 20.52
# Episode 147 finished with reward: 31.74
# Moving average (last 50 episodes): -23.45 ± 21.87
# Episode 148 finished with reward: 15.88
# Moving average (last 50 episodes): -22.05 ± 22.10
# Episode 149 finished with reward: 7.94
# Moving average (last 50 episodes): -21.47 ± 22.49
# Episode 150 finished with reward: 34.34
# Moving average (last 50 episodes): -20.16 ± 23.76
# Episode 151 finished with reward: -17.32
# Moving average (last 50 episodes): -20.04 ± 23.76
# Episode 152 finished with reward: -55.02
# Moving average (last 50 episodes): -21.09 ± 24.12
# Episode 153 finished with reward: -36.36
# Moving average (last 50 episodes): -21.07 ± 24.11
# Episode 154 finished with reward: -53.71
# Moving average (last 50 episodes): -21.61 ± 24.53
# Episode 155 finished with reward: -3.80
# Moving average (last 50 episodes): -21.30 ± 24.66
# Episode 156 finished with reward: -49.45
# Moving average (last 50 episodes): -21.32 ± 24.68
# Episode 157 finished with reward: -12.94
# Moving average (last 50 episodes): -20.82 ± 24.59
# Episode 158 finished with reward: -55.89
# Moving average (last 50 episodes): -21.00 ± 24.81
# Episode 159 finished with reward: -68.74
# Moving average (last 50 episodes): -21.94 ± 25.69
# Episode 160 finished with reward: -53.37
# Moving average (last 50 episodes): -23.28 ± 25.55
# Episode 161 finished with reward: -15.08
# Moving average (last 50 episodes): -23.56 ± 25.38
# Episode 162 finished with reward: -18.79
# Moving average (last 50 episodes): -23.55 ± 25.38
# Episode 163 finished with reward: -60.03
# Moving average (last 50 episodes): -24.66 ± 25.73
# Episode 164 finished with reward: 4.91
# Moving average (last 50 episodes): -24.30 ± 26.02
# Episode 165 finished with reward: 26.67
# Moving average (last 50 episodes): -22.93 ± 26.84
# Episode 166 finished with reward: -11.97
# Moving average (last 50 episodes): -22.86 ± 26.87
# Episode 167 finished with reward: -36.16
# Moving average (last 50 episodes): -23.73 ± 26.58
# Episode 168 finished with reward: 0.98
# Moving average (last 50 episodes): -23.03 ± 26.76
# Episode 169 finished with reward: -76.89
# Moving average (last 50 episodes): -23.99 ± 27.79
# Episode 170 finished with reward: -37.19
# Moving average (last 50 episodes): -23.98 ± 27.79
# Episode 171 finished with reward: -36.14
# Moving average (last 50 episodes): -24.39 ± 27.81
# Episode 172 finished with reward: -8.73
# Moving average (last 50 episodes): -23.13 ± 27.07
# Episode 173 finished with reward: 1.67
# Moving average (last 50 episodes): -22.15 ± 27.06
# Episode 174 finished with reward: -51.19
# Moving average (last 50 episodes): -22.87 ± 27.34
# Episode 175 finished with reward: -4.01
# Moving average (last 50 episodes): -22.79 ± 27.39
# Episode 176 finished with reward: 6.04
# Moving average (last 50 episodes): -22.41 ± 27.65
# Episode 177 finished with reward: -41.21
# Moving average (last 50 episodes): -23.51 ± 27.28
# Episode 178 finished with reward: -61.61
# Moving average (last 50 episodes): -25.19 ± 26.99
# Episode 179 finished with reward: 4.54
# Moving average (last 50 episodes): -24.21 ± 27.17
# Episode 180 finished with reward: 31.51
# Moving average (last 50 episodes): -23.04 ± 28.26
# Episode 181 finished with reward: 23.87
# Moving average (last 50 episodes): -22.50 ± 28.89
# Episode 182 finished with reward: -54.12
# Moving average (last 50 episodes): -23.61 ± 29.01
# Episode 183 finished with reward: -7.32
# Moving average (last 50 episodes): -22.90 ± 28.97
# Episode 184 finished with reward: 0.31
# Moving average (last 50 episodes): -21.82 ± 28.81
# Episode 185 finished with reward: -34.87
# Moving average (last 50 episodes): -22.10 ± 28.86
# Episode 186 finished with reward: 5.95
# Moving average (last 50 episodes): -21.61 ± 29.13
# Episode 187 finished with reward: 1.38
# Moving average (last 50 episodes): -21.00 ± 29.28
# Episode 188 finished with reward: -6.47
# Moving average (last 50 episodes): -21.02 ± 29.27
# Episode 189 finished with reward: -55.35
# Moving average (last 50 episodes): -20.75 ± 28.89
# Episode 190 finished with reward: -54.32
# Moving average (last 50 episodes): -21.46 ± 29.26
# Episode 191 finished with reward: 4.15
# Moving average (last 50 episodes): -20.85 ± 29.47
# Episode 192 finished with reward: -10.82
# Moving average (last 50 episodes): -19.94 ± 29.07
# Episode 193 finished with reward: -23.16
# Moving average (last 50 episodes): -19.55 ± 28.89
# Episode 194 finished with reward: -24.58
# Moving average (last 50 episodes): -19.66 ± 28.90
# Episode 195 finished with reward: -34.36
# Moving average (last 50 episodes): -20.05 ± 28.96
# Episode 196 finished with reward: -1.02
# Moving average (last 50 episodes): -19.40 ± 29.01
# Episode 197 finished with reward: 8.28
# Moving average (last 50 episodes): -19.87 ± 28.36
# Episode 198 finished with reward: -11.41
# Moving average (last 50 episodes): -20.42 ± 27.93
# Episode 199 finished with reward: -11.00
# Moving average (last 50 episodes): -20.80 ± 27.67
# Episode 200 finished with reward: -43.93
# Moving average (last 50 episodes): -22.36 ± 26.70
# Episode 201 finished with reward: -27.61
# Moving average (last 50 episodes): -22.57 ± 26.70
# Episode 202 finished with reward: -20.23
# Moving average (last 50 episodes): -21.87 ± 26.30
# Episode 203 finished with reward: -5.63
# Moving average (last 50 episodes): -21.26 ± 26.31
# Episode 204 finished with reward: -11.85
# Moving average (last 50 episodes): -20.42 ± 25.93
# Episode 205 finished with reward: -7.70
# Moving average (last 50 episodes): -20.50 ± 25.89
# Episode 206 finished with reward: -41.48
# Moving average (last 50 episodes): -20.34 ± 25.73
# Episode 207 finished with reward: -8.78
# Moving average (last 50 episodes): -20.25 ± 25.76
# Episode 208 finished with reward: -61.85
# Moving average (last 50 episodes): -20.37 ± 25.94
# Episode 209 finished with reward: -8.45
# Moving average (last 50 episodes): -19.17 ± 25.05
# Episode 210 finished with reward: 11.12
# Moving average (last 50 episodes): -17.88 ± 24.92
# Episode 211 finished with reward: -50.45
# Moving average (last 50 episodes): -18.59 ± 25.32
# Episode 212 finished with reward: -3.34
# Moving average (last 50 episodes): -18.28 ± 25.41
# Episode 213 finished with reward: -33.45
# Moving average (last 50 episodes): -17.75 ± 24.81
# Episode 214 finished with reward: -38.56
# Moving average (last 50 episodes): -18.61 ± 24.76
# Episode 215 finished with reward: 20.93
# Moving average (last 50 episodes): -18.73 ± 24.56
# Episode 216 finished with reward: 9.25
# Moving average (last 50 episodes): -18.30 ± 24.86
# Episode 217 finished with reward: -99.38
# Moving average (last 50 episodes): -19.57 ± 27.23
# Episode 218 finished with reward: 4.28
# Moving average (last 50 episodes): -19.50 ± 27.28
# Episode 219 finished with reward: -5.42
# Moving average (last 50 episodes): -18.07 ± 26.08
# Episode 220 finished with reward: -39.28
# Moving average (last 50 episodes): -18.12 ± 26.11
# Episode 221 finished with reward: -30.62
# Moving average (last 50 episodes): -18.01 ± 26.05
# Episode 222 finished with reward: 30.64
# Moving average (last 50 episodes): -17.22 ± 26.90
# Episode 223 finished with reward: 22.77
# Moving average (last 50 episodes): -16.80 ± 27.35
# Episode 224 finished with reward: 15.71
# Moving average (last 50 episodes): -15.46 ± 27.27
# Episode 225 finished with reward: 21.87
# Moving average (last 50 episodes): -14.94 ± 27.73
# Episode 226 finished with reward: 10.49
# Moving average (last 50 episodes): -14.85 ± 27.80
# Episode 227 finished with reward: -7.59
# Moving average (last 50 episodes): -14.18 ± 27.56
# Episode 228 finished with reward: -5.62
# Moving average (last 50 episodes): -13.06 ± 26.74
# Episode 229 finished with reward: -49.87
# Moving average (last 50 episodes): -14.15 ± 27.10
# Episode 230 finished with reward: -26.67
# Moving average (last 50 episodes): -15.31 ± 26.36
# Episode 231 finished with reward: -32.84
# Moving average (last 50 episodes): -16.45 ± 25.86
# Episode 232 finished with reward: 6.60
# Moving average (last 50 episodes): -15.23 ± 25.49
# Episode 233 finished with reward: -22.61
# Moving average (last 50 episodes): -15.54 ± 25.48
# Episode 234 finished with reward: -22.49
# Moving average (last 50 episodes): -15.99 ± 25.40
# Episode 235 finished with reward: -40.41
# Moving average (last 50 episodes): -16.10 ± 25.49
# Episode 236 finished with reward: 8.91
# Moving average (last 50 episodes): -16.04 ± 25.55
# Episode 237 finished with reward: 13.05
# Moving average (last 50 episodes): -15.81 ± 25.76
# Episode 238 finished with reward: 19.74
# Moving average (last 50 episodes): -15.29 ± 26.21
# Episode 239 finished with reward: -32.73
# Moving average (last 50 episodes): -14.83 ± 25.70
# Episode 240 finished with reward: 2.51
# Moving average (last 50 episodes): -13.70 ± 25.18
# Episode 241 finished with reward: 5.63
# Moving average (last 50 episodes): -13.67 ± 25.20
# Episode 242 finished with reward: 11.62
# Moving average (last 50 episodes): -13.22 ± 25.45
# Episode 243 finished with reward: -31.20
# Moving average (last 50 episodes): -13.38 ± 25.54
# Episode 244 finished with reward: 39.73
# Moving average (last 50 episodes): -12.09 ± 26.54
# Episode 245 finished with reward: -16.85
# Moving average (last 50 episodes): -11.74 ± 26.36
# Episode 246 finished with reward: 14.34
# Moving average (last 50 episodes): -11.44 ± 26.57
# Episode 247 finished with reward: -21.44
# Moving average (last 50 episodes): -12.03 ± 26.45
# Episode 248 finished with reward: -14.50
# Moving average (last 50 episodes): -12.09 ± 26.46
# Episode 249 finished with reward: -4.50
# Moving average (last 50 episodes): -11.96 ± 26.48
# Episode 250 finished with reward: -35.89
# Moving average (last 50 episodes): -11.80 ± 26.31
# Episode 251 finished with reward: 34.07
# Moving average (last 50 episodes): -10.57 ± 26.97
# Episode 252 finished with reward: -40.49
# Moving average (last 50 episodes): -10.97 ± 27.27
# Episode 253 finished with reward: 11.84
# Moving average (last 50 episodes): -10.62 ± 27.44
# Episode 254 finished with reward: 7.82
# Moving average (last 50 episodes): -10.23 ± 27.56
# Episode 255 finished with reward: 0.12
# Moving average (last 50 episodes): -10.07 ± 27.60
# Episode 256 finished with reward: -56.67
# Moving average (last 50 episodes): -10.38 ± 28.02
# Episode 257 finished with reward: -60.96
# Moving average (last 50 episodes): -11.42 ± 28.90
# Episode 258 finished with reward: -19.67
# Moving average (last 50 episodes): -10.58 ± 28.02
# Episode 259 finished with reward: 30.00
# Moving average (last 50 episodes): -9.81 ± 28.59
# Episode 260 finished with reward: 7.92
# Moving average (last 50 episodes): -9.87 ± 28.55
# Episode 261 finished with reward: 20.39
# Moving average (last 50 episodes): -8.46 ± 28.26
# Episode 262 finished with reward: -7.26
# Moving average (last 50 episodes): -8.54 ± 28.25
# Episode 263 finished with reward: -8.19
# Moving average (last 50 episodes): -8.03 ± 28.02
# Episode 264 finished with reward: -50.00
# Moving average (last 50 episodes): -8.26 ± 28.31
# Episode 265 finished with reward: -2.99
# Moving average (last 50 episodes): -8.74 ± 28.02
# Episode 266 finished with reward: 3.76
# Moving average (last 50 episodes): -8.85 ± 27.96
# Episode 267 finished with reward: -6.22
# Moving average (last 50 episodes): -6.98 ± 24.79
# Episode 268 finished with reward: -3.58
# Moving average (last 50 episodes): -7.14 ± 24.74
# Episode 269 finished with reward: 11.60
# Moving average (last 50 episodes): -6.80 ± 24.88
# Episode 270 finished with reward: -7.80
# Moving average (last 50 episodes): -6.17 ± 24.44
# Episode 271 finished with reward: -3.86
# Moving average (last 50 episodes): -5.64 ± 24.19
# Episode 272 finished with reward: -23.63
# Moving average (last 50 episodes): -6.72 ± 23.75
# Episode 273 finished with reward: -14.81
# Moving average (last 50 episodes): -7.47 ± 23.40
# Episode 274 finished with reward: -32.49
# Moving average (last 50 episodes): -8.44 ± 23.42
# Episode 275 finished with reward: -1.41
# Moving average (last 50 episodes): -8.90 ± 23.04
# Episode 276 finished with reward: -5.27
# Moving average (last 50 episodes): -9.22 ± 22.88
# Episode 277 finished with reward: 36.59
# Moving average (last 50 episodes): -8.33 ± 23.76
# Episode 278 finished with reward: -18.26
# Moving average (last 50 episodes): -8.59 ± 23.80
# Episode 279 finished with reward: 1.94
# Moving average (last 50 episodes): -7.55 ± 23.10
# Episode 280 finished with reward: 15.42
# Moving average (last 50 episodes): -6.71 ± 23.15
# Episode 281 finished with reward: 3.46
# Moving average (last 50 episodes): -5.98 ± 22.89
# Episode 282 finished with reward: -2.08
# Moving average (last 50 episodes): -6.16 ± 22.83
# Episode 283 finished with reward: 5.46
# Moving average (last 50 episodes): -5.59 ± 22.76
# Episode 284 finished with reward: -26.54
# Moving average (last 50 episodes): -5.68 ± 22.83
# Episode 285 finished with reward: 26.96
# Moving average (last 50 episodes): -4.33 ± 22.72
# Episode 286 finished with reward: -12.13
# Moving average (last 50 episodes): -4.75 ± 22.67
# Episode 287 finished with reward: 15.92
# Moving average (last 50 episodes): -4.69 ± 22.72
# Episode 288 finished with reward: -25.75
# Moving average (last 50 episodes): -5.60 ± 22.63
# Episode 289 finished with reward: -21.00
# Moving average (last 50 episodes): -5.37 ± 22.41
# Episode 290 finished with reward: -15.70
# Moving average (last 50 episodes): -5.73 ± 22.43
# Episode 291 finished with reward: -1.64
# Moving average (last 50 episodes): -5.88 ± 22.38
# Episode 292 finished with reward: -14.10
# Moving average (last 50 episodes): -6.39 ± 22.26
# Episode 293 finished with reward: -60.42
# Moving average (last 50 episodes): -6.98 ± 23.27
# Episode 294 finished with reward: 10.07
# Moving average (last 50 episodes): -7.57 ± 22.43
# Episode 295 finished with reward: 5.06
# Moving average (last 50 episodes): -7.13 ± 22.46
# Episode 296 finished with reward: -2.16
# Moving average (last 50 episodes): -7.46 ± 22.26
# Episode 297 finished with reward: 15.11
# Moving average (last 50 episodes): -6.73 ± 22.39
# Episode 298 finished with reward: 0.63
# Moving average (last 50 episodes): -6.43 ± 22.39
# Episode 299 finished with reward: -16.14
# Moving average (last 50 episodes): -6.66 ± 22.43
# Episode 300 finished with reward: -23.08
# Moving average (last 50 episodes): -6.40 ± 22.16
# Episode 301 finished with reward: -31.86
# Moving average (last 50 episodes): -7.72 ± 21.67
# Episode 302 finished with reward: 0.59
# Moving average (last 50 episodes): -6.90 ± 21.19
# Episode 303 finished with reward: -8.11
# Moving average (last 50 episodes): -7.30 ± 21.02
# Episode 304 finished with reward: -32.74
# Moving average (last 50 episodes): -8.11 ± 21.20
# Episode 305 finished with reward: -26.48
# Moving average (last 50 episodes): -8.64 ± 21.32
# Episode 306 finished with reward: -12.98
# Moving average (last 50 episodes): -7.77 ± 20.20
# Episode 307 finished with reward: -19.25
# Moving average (last 50 episodes): -6.93 ± 18.80
# Episode 308 finished with reward: -10.38
# Moving average (last 50 episodes): -6.75 ± 18.72
# Episode 309 finished with reward: -14.78
# Moving average (last 50 episodes): -7.64 ± 18.00
# Episode 310 finished with reward: 6.84
# Moving average (last 50 episodes): -7.67 ± 17.98
# Episode 311 finished with reward: 15.55
# Moving average (last 50 episodes): -7.76 ± 17.84
# Episode 312 finished with reward: 15.52
# Moving average (last 50 episodes): -7.31 ± 18.13
# Episode 313 finished with reward: -18.75
# Moving average (last 50 episodes): -7.52 ± 18.20
# Episode 314 finished with reward: 16.78
# Moving average (last 50 episodes): -6.18 ± 17.47
# Episode 315 finished with reward: -14.21
# Moving average (last 50 episodes): -6.41 ± 17.50
# Episode 316 finished with reward: -8.47
# Moving average (last 50 episodes): -6.65 ± 17.44
# Episode 317 finished with reward: -0.55
# Moving average (last 50 episodes): -6.54 ± 17.47
# Episode 318 finished with reward: -16.09
# Moving average (last 50 episodes): -6.79 ± 17.51
# Episode 319 finished with reward: 21.47
# Moving average (last 50 episodes): -6.59 ± 17.77
# Episode 320 finished with reward: -14.45
# Moving average (last 50 episodes): -6.72 ± 17.80
# Episode 321 finished with reward: 26.00
# Moving average (last 50 episodes): -6.13 ± 18.38
# Episode 322 finished with reward: 20.12
# Moving average (last 50 episodes): -5.25 ± 18.57
# Episode 323 finished with reward: 9.99
# Moving average (last 50 episodes): -4.76 ± 18.64
# Episode 324 finished with reward: -49.08
# Moving average (last 50 episodes): -5.09 ± 19.27
# Episode 325 finished with reward: 20.81
# Moving average (last 50 episodes): -4.64 ± 19.60
# Episode 326 finished with reward: -23.98
# Moving average (last 50 episodes): -5.02 ± 19.78
# Episode 327 finished with reward: -14.72
# Moving average (last 50 episodes): -6.04 ± 18.91
# Episode 328 finished with reward: -13.70
# Moving average (last 50 episodes): -5.95 ± 18.86
# Episode 329 finished with reward: -13.43
# Moving average (last 50 episodes): -6.26 ± 18.86
# Episode 330 finished with reward: 10.35
# Moving average (last 50 episodes): -6.36 ± 18.75
# Episode 331 finished with reward: 25.33
# Moving average (last 50 episodes): -5.92 ± 19.23
# Episode 332 finished with reward: 1.48
# Moving average (last 50 episodes): -5.85 ± 19.25
# Episode 333 finished with reward: -13.32
# Moving average (last 50 episodes): -6.23 ± 19.21
# Episode 334 finished with reward: 33.61
# Moving average (last 50 episodes): -5.03 ± 19.77
# Episode 335 finished with reward: -5.53
# Moving average (last 50 episodes): -5.67 ± 19.24
# Episode 336 finished with reward: -26.34
# Moving average (last 50 episodes): -5.96 ± 19.43
# Episode 337 finished with reward: 12.18
# Moving average (last 50 episodes): -6.03 ± 19.36
# Episode 338 finished with reward: 9.40
# Moving average (last 50 episodes): -5.33 ± 19.27
# Episode 339 finished with reward: -16.21
# Moving average (last 50 episodes): -5.24 ± 19.20
# Episode 340 finished with reward: 14.58
# Moving average (last 50 episodes): -4.63 ± 19.34
# Episode 341 finished with reward: -28.68
# Moving average (last 50 episodes): -5.17 ± 19.62
# Episode 342 finished with reward: -44.08
# Moving average (last 50 episodes): -5.77 ± 20.33
# Episode 343 finished with reward: 0.78
# Moving average (last 50 episodes): -4.55 ± 18.79
# Episode 344 finished with reward: 10.64
# Moving average (last 50 episodes): -4.53 ± 18.80
# Episode 345 finished with reward: -1.35
# Moving average (last 50 episodes): -4.66 ± 18.75
# Episode 346 finished with reward: 42.48
# Moving average (last 50 episodes): -3.77 ± 19.88
# Episode 347 finished with reward: 5.32
# Moving average (last 50 episodes): -3.97 ± 19.74
# Episode 348 finished with reward: -13.49
# Moving average (last 50 episodes): -4.25 ± 19.77
# Episode 349 finished with reward: -17.68
# Moving average (last 50 episodes): -4.28 ± 19.79
# Episode 350 finished with reward: 1.03
# Moving average (last 50 episodes): -3.80 ± 19.62
# Episode 351 finished with reward: -10.50
# Moving average (last 50 episodes): -3.37 ± 19.23
# Episode 352 finished with reward: 22.73
# Moving average (last 50 episodes): -2.93 ± 19.57
# Episode 353 finished with reward: -17.19
# Moving average (last 50 episodes): -3.11 ± 19.66
# Episode 354 finished with reward: -35.26
# Moving average (last 50 episodes): -3.16 ± 19.74
# Episode 355 finished with reward: 26.24
# Moving average (last 50 episodes): -2.10 ± 19.87
# Episode 356 finished with reward: 44.86
# Moving average (last 50 episodes): -0.95 ± 20.87
# Episode 357 finished with reward: 10.95
# Moving average (last 50 episodes): -0.34 ± 20.76
# Episode 358 finished with reward: -12.91
# Moving average (last 50 episodes): -0.39 ± 20.79
# Episode 359 finished with reward: -34.55
# Moving average (last 50 episodes): -0.79 ± 21.24
# Episode 360 finished with reward: 1.61
# Moving average (last 50 episodes): -0.89 ± 21.22
# Episode 361 finished with reward: -8.96
# Moving average (last 50 episodes): -1.38 ± 21.12
# Episode 362 finished with reward: 3.67
# Moving average (last 50 episodes): -1.62 ± 20.99
# Episode 363 finished with reward: 9.60
# Moving average (last 50 episodes): -1.05 ± 20.90
# Episode 364 finished with reward: -11.12
# Moving average (last 50 episodes): -1.61 ± 20.79
# Episode 365 finished with reward: -26.24
# Moving average (last 50 episodes): -1.85 ± 21.01
# Episode 366 finished with reward: 37.40
# Moving average (last 50 episodes): -0.94 ± 21.69
# Episode 367 finished with reward: -1.36
# Moving average (last 50 episodes): -0.95 ± 21.69
# Episode 368 finished with reward: 16.07
# Moving average (last 50 episodes): -0.31 ± 21.71
# Episode 369 finished with reward: 26.70
# Moving average (last 50 episodes): -0.20 ± 21.82
# Episode 370 finished with reward: 2.98
# Moving average (last 50 episodes): 0.15 ± 21.73
# Episode 371 finished with reward: -9.98
# Moving average (last 50 episodes): -0.57 ± 21.46
# Episode 372 finished with reward: 6.62
# Moving average (last 50 episodes): -0.84 ± 21.28
# Episode 373 finished with reward: -12.92
# Moving average (last 50 episodes): -1.30 ± 21.29
# Episode 374 finished with reward: 2.18
# Moving average (last 50 episodes): -0.28 ± 20.17
# Episode 375 finished with reward: -29.26
# Moving average (last 50 episodes): -1.28 ± 20.34
# Episode 376 finished with reward: -6.39
# Moving average (last 50 episodes): -0.93 ± 20.09
# Episode 377 finished with reward: 18.94
# Moving average (last 50 episodes): -0.25 ± 20.18
# Episode 378 finished with reward: -16.63
# Moving average (last 50 episodes): -0.31 ± 20.23
# Episode 379 finished with reward: 4.76
# Moving average (last 50 episodes): 0.05 ± 20.15
# Episode 380 finished with reward: 19.34
# Moving average (last 50 episodes): 0.23 ± 20.28
# Episode 381 finished with reward: 7.33
# Moving average (last 50 episodes): -0.13 ± 19.99
# Episode 382 finished with reward: 0.69
# Moving average (last 50 episodes): -0.14 ± 19.99
# Episode 383 finished with reward: 15.30
# Moving average (last 50 episodes): 0.43 ± 20.01
# Episode 384 finished with reward: 13.32
# Moving average (last 50 episodes): 0.02 ± 19.54
# Episode 385 finished with reward: -5.00
# Moving average (last 50 episodes): 0.03 ± 19.53
# Episode 386 finished with reward: -0.67
# Moving average (last 50 episodes): 0.55 ± 19.17
# Episode 387 finished with reward: -15.94
# Moving average (last 50 episodes): -0.02 ± 19.23
# Episode 388 finished with reward: -11.64
# Moving average (last 50 episodes): -0.44 ± 19.25
# Episode 389 finished with reward: -4.73
# Moving average (last 50 episodes): -0.21 ± 19.13
# Episode 390 finished with reward: -1.49
# Moving average (last 50 episodes): -0.53 ± 19.01
# Episode 391 finished with reward: 26.10
# Moving average (last 50 episodes): 0.57 ± 18.94
# Episode 392 finished with reward: 10.54
# Moving average (last 50 episodes): 1.66 ± 17.87
# Episode 393 finished with reward: -20.36
# Moving average (last 50 episodes): 1.24 ± 18.14
# Episode 394 finished with reward: -21.79
# Moving average (last 50 episodes): 0.59 ± 18.37
# Episode 395 finished with reward: -4.17
# Moving average (last 50 episodes): 0.53 ± 18.38
# Episode 396 finished with reward: -23.14
# Moving average (last 50 episodes): -0.78 ± 17.67
# Episode 397 finished with reward: 2.94
# Moving average (last 50 episodes): -0.83 ± 17.65
# Episode 398 finished with reward: -33.02
# Moving average (last 50 episodes): -1.22 ± 18.14
# Episode 399 finished with reward: 21.31
# Moving average (last 50 episodes): -0.44 ± 18.25
# Episode 400 finished with reward: 5.15
# Moving average (last 50 episodes): -0.36 ± 18.27
# Episode 401 finished with reward: -16.66
# Moving average (last 50 episodes): -0.48 ± 18.36
# Episode 402 finished with reward: 24.23
# Moving average (last 50 episodes): -0.45 ± 18.39
# Episode 403 finished with reward: -32.63
# Moving average (last 50 episodes): -0.76 ± 18.80
# Episode 404 finished with reward: -12.20
# Moving average (last 50 episodes): -0.30 ± 18.22
# Episode 405 finished with reward: 4.00
# Moving average (last 50 episodes): -0.74 ± 17.83
# Episode 406 finished with reward: 28.83
# Moving average (last 50 episodes): -1.06 ± 17.14
# Episode 407 finished with reward: 24.41
# Moving average (last 50 episodes): -0.79 ± 17.43
# Episode 408 finished with reward: -13.08
# Moving average (last 50 episodes): -0.80 ± 17.43
# Episode 409 finished with reward: 1.21
# Moving average (last 50 episodes): -0.08 ± 16.75
# Episode 410 finished with reward: -35.00
# Moving average (last 50 episodes): -0.81 ± 17.45
# Episode 411 finished with reward: -17.83
# Moving average (last 50 episodes): -0.99 ± 17.58
# Episode 412 finished with reward: -19.87
# Moving average (last 50 episodes): -1.46 ± 17.76
# Episode 413 finished with reward: -19.15
# Moving average (last 50 episodes): -2.04 ± 17.86
# Episode 414 finished with reward: -3.38
# Moving average (last 50 episodes): -1.88 ± 17.81
# Episode 415 finished with reward: 31.60
# Moving average (last 50 episodes): -0.73 ± 18.07
# Episode 416 finished with reward: 0.06
# Moving average (last 50 episodes): -1.47 ± 17.23
# Episode 417 finished with reward: 1.74
# Moving average (last 50 episodes): -1.41 ± 17.24
# Episode 418 finished with reward: 55.39
# Moving average (last 50 episodes): -0.62 ± 18.84
# Episode 419 finished with reward: -17.34
# Moving average (last 50 episodes): -1.51 ± 18.57
# Episode 420 finished with reward: -6.48
# Moving average (last 50 episodes): -1.69 ± 18.57
# Episode 421 finished with reward: -3.44
# Moving average (last 50 episodes): -1.56 ± 18.53
# Episode 422 finished with reward: 27.18
# Moving average (last 50 episodes): -1.15 ± 18.93
# Episode 423 finished with reward: 27.10
# Moving average (last 50 episodes): -0.35 ± 19.26
# Episode 424 finished with reward: 14.74
# Moving average (last 50 episodes): -0.10 ± 19.38
# Episode 425 finished with reward: -4.58
# Moving average (last 50 episodes): 0.39 ± 18.94
# Episode 426 finished with reward: 1.77
# Moving average (last 50 episodes): 0.56 ± 18.91
# Episode 427 finished with reward: -60.51
# Moving average (last 50 episodes): -1.03 ± 20.57
# Episode 428 finished with reward: -3.60
# Moving average (last 50 episodes): -0.77 ± 20.45
# Episode 429 finished with reward: -2.46
# Moving average (last 50 episodes): -0.92 ± 20.43
# Episode 430 finished with reward: 3.83
# Moving average (last 50 episodes): -1.23 ± 20.24
# Episode 431 finished with reward: -27.75
# Moving average (last 50 episodes): -1.93 ± 20.54
# Episode 432 finished with reward: -21.02
# Moving average (last 50 episodes): -2.36 ± 20.71
# Episode 433 finished with reward: -64.86
# Moving average (last 50 episodes): -3.97 ± 22.32
# Episode 434 finished with reward: -17.67
# Moving average (last 50 episodes): -4.59 ± 22.26
# Episode 435 finished with reward: 8.34
# Moving average (last 50 episodes): -4.32 ± 22.33
# Episode 436 finished with reward: -4.87
# Moving average (last 50 episodes): -4.40 ± 22.33
# Episode 437 finished with reward: 28.50
# Moving average (last 50 episodes): -3.52 ± 22.73
# Episode 438 finished with reward: -2.07
# Moving average (last 50 episodes): -3.32 ± 22.70
# Episode 439 finished with reward: 21.11
# Moving average (last 50 episodes): -2.81 ± 22.96
# Episode 440 finished with reward: -26.49
# Moving average (last 50 episodes): -3.31 ± 23.19
# Episode 441 finished with reward: -53.06
# Moving average (last 50 episodes): -4.89 ± 23.83
# Episode 442 finished with reward: 10.65
# Moving average (last 50 episodes): -4.89 ± 23.83
# Episode 443 finished with reward: 29.35
# Moving average (last 50 episodes): -3.89 ± 24.20
# Episode 444 finished with reward: -6.58
# Moving average (last 50 episodes): -3.59 ± 24.06
# Episode 445 finished with reward: -5.26
# Moving average (last 50 episodes): -3.61 ± 24.06
# Episode 446 finished with reward: -13.02
# Moving average (last 50 episodes): -3.41 ± 23.94
# Episode 447 finished with reward: 1.32
# Moving average (last 50 episodes): -3.44 ± 23.93
# Episode 448 finished with reward: -21.44
# Moving average (last 50 episodes): -3.21 ± 23.70
# Episode 449 finished with reward: 22.23
# Moving average (last 50 episodes): -3.19 ± 23.72
# Episode 450 finished with reward: -39.55
# Moving average (last 50 episodes): -4.09 ± 24.23
# Episode 451 finished with reward: 7.04
# Moving average (last 50 episodes): -3.61 ± 24.21
# Episode 452 finished with reward: 39.59
# Moving average (last 50 episodes): -3.30 ± 24.65
# Episode 453 finished with reward: -5.95
# Moving average (last 50 episodes): -2.77 ± 24.30
# Episode 454 finished with reward: -30.82
# Moving average (last 50 episodes): -3.14 ± 24.58
# Episode 455 finished with reward: -6.67
# Moving average (last 50 episodes): -3.36 ± 24.56
# Episode 456 finished with reward: -16.12
# Moving average (last 50 episodes): -4.26 ± 24.19
# Episode 457 finished with reward: -5.61
# Moving average (last 50 episodes): -4.86 ± 23.84
# Episode 458 finished with reward: 7.90
# Moving average (last 50 episodes): -4.44 ± 23.88
# Episode 459 finished with reward: 15.37
# Moving average (last 50 episodes): -4.15 ± 24.03
# Episode 460 finished with reward: 9.13
# Moving average (last 50 episodes): -3.27 ± 23.69
# Episode 461 finished with reward: -29.01
# Moving average (last 50 episodes): -3.49 ± 23.87
# Episode 462 finished with reward: 21.54
# Moving average (last 50 episodes): -2.67 ± 24.01
# Episode 463 finished with reward: 18.49
# Moving average (last 50 episodes): -1.91 ± 24.07
# Episode 464 finished with reward: 2.08
# Moving average (last 50 episodes): -1.80 ± 24.08
# Episode 465 finished with reward: 8.31
# Moving average (last 50 episodes): -2.27 ± 23.65
# Episode 466 finished with reward: 4.07
# Moving average (last 50 episodes): -2.19 ± 23.66
# Episode 467 finished with reward: 35.17
# Moving average (last 50 episodes): -1.52 ± 24.23
# Episode 468 finished with reward: -13.57
# Moving average (last 50 episodes): -2.90 ± 22.87
# Episode 469 finished with reward: 14.41
# Moving average (last 50 episodes): -2.26 ± 22.91
# Episode 470 finished with reward: -5.86
# Moving average (last 50 episodes): -2.25 ± 22.90
# Episode 471 finished with reward: -14.01
# Moving average (last 50 episodes): -2.46 ± 22.96
# Episode 472 finished with reward: -6.93
# Moving average (last 50 episodes): -3.15 ± 22.57
# Episode 473 finished with reward: 0.91
# Moving average (last 50 episodes): -3.67 ± 22.17
# Episode 474 finished with reward: -14.49
# Moving average (last 50 episodes): -4.25 ± 22.06
# Episode 475 finished with reward: 38.94
# Moving average (last 50 episodes): -3.38 ± 22.87
# Episode 476 finished with reward: 9.72
# Moving average (last 50 episodes): -3.22 ± 22.94
# Episode 477 finished with reward: 8.08
# Moving average (last 50 episodes): -1.85 ± 21.47
# Episode 478 finished with reward: 9.07
# Moving average (last 50 episodes): -1.60 ± 21.52
# Episode 479 finished with reward: 3.68
# Moving average (last 50 episodes): -1.48 ± 21.54
# Episode 480 finished with reward: -18.18
# Moving average (last 50 episodes): -1.92 ± 21.65
# Episode 481 finished with reward: -21.71
# Moving average (last 50 episodes): -1.80 ± 21.52
# Episode 482 finished with reward: 29.65
# Moving average (last 50 episodes): -0.78 ± 21.78
# Episode 483 finished with reward: 60.87
# Moving average (last 50 episodes): 1.73 ± 21.50
# Episode 484 finished with reward: -55.86
# Moving average (last 50 episodes): 0.97 ± 22.81
# Episode 485 finished with reward: -36.84
# Moving average (last 50 episodes): 0.06 ± 23.39
# Episode 486 finished with reward: 8.37
# Moving average (last 50 episodes): 0.33 ± 23.40
# Episode 487 finished with reward: 5.52
# Moving average (last 50 episodes): -0.13 ± 23.07
# Episode 488 finished with reward: 26.19
# Moving average (last 50 episodes): 0.44 ± 23.36
# Episode 489 finished with reward: -9.51
# Moving average (last 50 episodes): -0.18 ± 23.21
# Episode 490 finished with reward: -1.89
# Moving average (last 50 episodes): 0.31 ± 22.91
# Episode 491 finished with reward: 52.14
# Moving average (last 50 episodes): 2.42 ± 22.74
# Episode 492 finished with reward: 4.17
# Moving average (last 50 episodes): 2.29 ± 22.71
# Episode 493 finished with reward: 16.86
# Moving average (last 50 episodes): 2.04 ± 22.48
# Episode 494 finished with reward: -42.21
# Moving average (last 50 episodes): 1.33 ± 23.29
# Episode 495 finished with reward: 0.96
# Moving average (last 50 episodes): 1.45 ± 23.27
# Episode 496 finished with reward: -7.90
# Moving average (last 50 episodes): 1.55 ± 23.22
# Episode 497 finished with reward: 17.48
# Moving average (last 50 episodes): 1.88 ± 23.32
# Episode 498 finished with reward: -18.06
# Moving average (last 50 episodes): 1.94 ± 23.26
# Episode 499 finished with reward: -36.94
# Moving average (last 50 episodes): 0.76 ± 23.70
# Episode 500 finished with reward: -18.19
# Moving average (last 50 episodes): 1.19 ± 23.16
# Episode 501 finished with reward: -11.65
# Moving average (last 50 episodes): 0.81 ± 23.21
# Episode 502 finished with reward: 16.24
# Moving average (last 50 episodes): 0.35 ± 22.65
# Episode 503 finished with reward: 36.97
# Moving average (last 50 episodes): 1.21 ± 23.21
# Episode 504 finished with reward: -21.18
# Moving average (last 50 episodes): 1.40 ± 22.98
# Episode 505 finished with reward: -29.07
# Moving average (last 50 episodes): 0.95 ± 23.35
# Episode 506 finished with reward: 7.56
# Moving average (last 50 episodes): 1.42 ± 23.23
# Episode 507 finished with reward: 19.69
# Moving average (last 50 episodes): 1.93 ± 23.35
# Episode 508 finished with reward: 3.81
# Moving average (last 50 episodes): 1.85 ± 23.34
# Episode 509 finished with reward: 23.37
# Moving average (last 50 episodes): 2.01 ± 23.46
# Episode 510 finished with reward: 7.10
# Moving average (last 50 episodes): 1.97 ± 23.45
# Episode 511 finished with reward: -13.34
# Moving average (last 50 episodes): 2.28 ± 23.13
# Episode 512 finished with reward: -21.61
# Moving average (last 50 episodes): 1.42 ± 23.20
# Episode 513 finished with reward: 14.95
# Moving average (last 50 episodes): 1.35 ± 23.16
# Episode 514 finished with reward: 44.88
# Moving average (last 50 episodes): 2.20 ± 23.94
# Episode 515 finished with reward: 28.73
# Moving average (last 50 episodes): 2.61 ± 24.22
# Episode 516 finished with reward: -32.29
# Moving average (last 50 episodes): 1.88 ± 24.70
# Episode 517 finished with reward: 0.80
# Moving average (last 50 episodes): 1.20 ± 24.24
# Episode 518 finished with reward: 5.18
# Moving average (last 50 episodes): 1.57 ± 24.16
# Episode 519 finished with reward: 3.96
# Moving average (last 50 episodes): 1.36 ± 24.09
# Episode 520 finished with reward: -2.51
# Moving average (last 50 episodes): 1.43 ± 24.07
# Episode 521 finished with reward: 0.42
# Moving average (last 50 episodes): 1.72 ± 23.97
# Episode 522 finished with reward: -4.29
# Moving average (last 50 episodes): 1.77 ± 23.96
# Episode 523 finished with reward: -0.58
# Moving average (last 50 episodes): 1.74 ± 23.96
# Episode 524 finished with reward: -27.08
# Moving average (last 50 episodes): 1.49 ± 24.19
# Episode 525 finished with reward: 1.72
# Moving average (last 50 episodes): 0.75 ± 23.59
# Episode 526 finished with reward: 4.12
# Moving average (last 50 episodes): 0.63 ± 23.56
# Episode 527 finished with reward: -3.27
# Moving average (last 50 episodes): 0.41 ± 23.55
# Episode 528 finished with reward: -29.66
# Moving average (last 50 episodes): -0.37 ± 23.88
# Episode 529 finished with reward: -0.74
# Moving average (last 50 episodes): -0.46 ± 23.88
# Episode 530 finished with reward: -6.36
# Moving average (last 50 episodes): -0.22 ± 23.76
# Episode 531 finished with reward: 21.97
# Moving average (last 50 episodes): 0.65 ± 23.75
# Episode 532 finished with reward: 38.04
# Moving average (last 50 episodes): 0.82 ± 23.99
# Episode 533 finished with reward: 20.96
# Moving average (last 50 episodes): 0.02 ± 22.60
# Episode 534 finished with reward: -26.05
# Moving average (last 50 episodes): 0.62 ± 21.48
# Episode 535 finished with reward: 10.91
# Moving average (last 50 episodes): 1.57 ± 20.85
# Episode 536 finished with reward: -0.33
# Moving average (last 50 episodes): 1.40 ± 20.83
# ...
# Moving average (last 50 episodes): 22.14 ± 18.87
# Episode 8162 finished with reward: 22.05
# Moving average (last 50 episodes): 21.47 ± 18.24
# Episode 8163 finished with reward: 41.48
# Moving average (last 50 episodes): 21.76 ± 18.44
# Episode 8164 finished with reward: 18.53
# Moving average (last 50 episodes): 21.36 ± 18.30
# Episode 8165 finished with reward: 13.85
# Moving average (last 50 episodes): 21.42 ± 18.27
# Episode 8166 finished with reward: 10.23
# Moving average (last 50 episodes): 20.81 ± 18.12
# Episode 8167 finished with reward: 2.46
# Moving average (last 50 episodes): 20.64 ± 18.26
# Episode 8168 finished with reward: 15.79
# Moving average (last 50 episodes): 20.99 ± 17.98
# Episode 8169 finished with reward: 28.65
# Moving average (last 50 episodes): 21.56 ± 17.76
# Episode 8170 finished with reward: 24.42
# Moving average (last 50 episodes): 21.25 ± 17.57
# Episode 8171 finished with reward: -7.92
# Moving average (last 50 episodes): 20.62 ± 18.03
# Episode 8172 finished with reward: 20.75
# Moving average (last 50 episodes): 20.29 ± 17.87
# Episode 8173 finished with reward: -10.55
# Moving average (last 50 episodes): 19.98 ± 18.27
# Episode 8174 finished with reward: 54.94
# Moving average (last 50 episodes): 21.53 ± 17.86
# Episode 8175 finished with reward: -29.12
# Moving average (last 50 episodes): 19.88 ± 18.64
# Episode 8176 finished with reward: 27.50
# Moving average (last 50 episodes): 20.00 ± 18.67
# Episode 8177 finished with reward: 28.03
# Moving average (last 50 episodes): 20.94 ± 17.84
# Episode 8178 finished with reward: 23.02
# Moving average (last 50 episodes): 21.19 ± 17.78
# Episode 8179 finished with reward: 2.53
# Moving average (last 50 episodes): 21.15 ± 17.82
# Episode 8180 finished with reward: 58.57
# Moving average (last 50 episodes): 21.88 ± 18.57
# Episode 8181 finished with reward: 36.58
# Moving average (last 50 episodes): 22.54 ± 18.50
# Episode 8182 finished with reward: 13.92
# Moving average (last 50 episodes): 22.48 ± 18.52
# Episode 8183 finished with reward: 28.02
# Moving average (last 50 episodes): 22.52 ± 18.53
# Episode 8184 finished with reward: 45.85
# Moving average (last 50 episodes): 23.26 ± 18.71
# Episode 8185 finished with reward: 32.74
# Moving average (last 50 episodes): 23.12 ± 18.62
# Episode 8186 finished with reward: 26.13
# Moving average (last 50 episodes): 23.51 ± 18.48
# Episode 8187 finished with reward: 2.04
# Moving average (last 50 episodes): 23.01 ± 18.71
# Episode 8188 finished with reward: 26.14
# Moving average (last 50 episodes): 22.45 ± 18.18
# Episode 8189 finished with reward: 35.51
# Moving average (last 50 episodes): 22.09 ± 17.73
# Episode 8190 finished with reward: 20.51
# Moving average (last 50 episodes): 22.07 ± 17.73
# Episode 8191 finished with reward: 74.04
# Moving average (last 50 episodes): 22.87 ± 19.10
# Episode 8192 finished with reward: 26.11
# Moving average (last 50 episodes): 23.11 ± 19.06
# Episode 8193 finished with reward: 2.65
# Moving average (last 50 episodes): 22.90 ± 19.23
# Episode 8194 finished with reward: 27.70
# Moving average (last 50 episodes): 23.12 ± 19.22
# Episode 8195 finished with reward: 19.95
# Moving average (last 50 episodes): 22.52 ± 18.82
# Episode 8196 finished with reward: -3.99
# Moving average (last 50 episodes): 22.02 ± 19.19
# Episode 8197 finished with reward: 23.08
# Moving average (last 50 episodes): 22.26 ± 19.12
# Episode 8198 finished with reward: -0.15
# Moving average (last 50 episodes): 21.58 ± 19.29
# Episode 8199 finished with reward: 42.09
# Moving average (last 50 episodes): 22.57 ± 19.04
# Episode 8200 finished with reward: -0.82
# Moving average (last 50 episodes): 22.08 ± 19.32
# Episode 8201 finished with reward: 27.30
# Moving average (last 50 episodes): 21.60 ± 18.88
# Episode 8202 finished with reward: 29.05
# Moving average (last 50 episodes): 21.16 ± 18.44
# Episode 8203 finished with reward: 24.91
# Moving average (last 50 episodes): 20.92 ± 18.32
# Episode 8204 finished with reward: 23.19
# Moving average (last 50 episodes): 21.26 ± 18.20
# Episode 8205 finished with reward: 34.36
# Moving average (last 50 episodes): 21.65 ± 18.26
# Episode 8206 finished with reward: 1.12
# Moving average (last 50 episodes): 21.07 ± 18.45
# Episode 8207 finished with reward: 36.20
# Moving average (last 50 episodes): 21.36 ± 18.57
# Episode 8208 finished with reward: 38.46
# Moving average (last 50 episodes): 21.67 ± 18.72
# Episode 8209 finished with reward: 20.91
# Moving average (last 50 episodes): 21.30 ± 18.55
# Episode 8210 finished with reward: -2.97
# Moving average (last 50 episodes): 21.12 ± 18.74
# Episode 8211 finished with reward: 11.05
# Moving average (last 50 episodes): 21.34 ± 18.56
# Episode 8212 finished with reward: 19.79
# Moving average (last 50 episodes): 21.29 ± 18.56
# Episode 8213 finished with reward: -31.99
# Moving average (last 50 episodes): 19.82 ± 19.77
# Episode 8214 finished with reward: 19.14
# Moving average (last 50 episodes): 19.83 ± 19.77
# Episode 8215 finished with reward: 8.50
# Moving average (last 50 episodes): 19.73 ± 19.82
# Episode 8216 finished with reward: 22.40
# Moving average (last 50 episodes): 19.97 ± 19.77
# Episode 8217 finished with reward: -35.95
# Moving average (last 50 episodes): 19.20 ± 21.14
# Episode 8218 finished with reward: 5.13
# Moving average (last 50 episodes): 18.99 ± 21.23
# Episode 8219 finished with reward: 14.46
# Moving average (last 50 episodes): 18.71 ± 21.19
# Episode 8220 finished with reward: -12.31
# Moving average (last 50 episodes): 17.97 ± 21.61
# Episode 8221 finished with reward: 24.82
# Moving average (last 50 episodes): 18.63 ± 21.31
# Episode 8222 finished with reward: 42.23
# Moving average (last 50 episodes): 19.06 ± 21.56
# Episode 8223 finished with reward: -0.97
# Moving average (last 50 episodes): 19.25 ± 21.34
# Episode 8224 finished with reward: 0.44
# Moving average (last 50 episodes): 18.16 ± 20.88
# Episode 8225 finished with reward: 34.47
# Moving average (last 50 episodes): 19.43 ± 19.87
# Episode 8226 finished with reward: -20.49
# Moving average (last 50 episodes): 18.47 ± 20.60
# Episode 8227 finished with reward: 16.56
# Moving average (last 50 episodes): 18.24 ± 20.56
# Episode 8228 finished with reward: 42.82
# Moving average (last 50 episodes): 18.64 ± 20.84
# Episode 8229 finished with reward: 53.80
# Moving average (last 50 episodes): 19.66 ± 21.28
# Episode 8230 finished with reward: 46.62
# Moving average (last 50 episodes): 19.42 ± 20.90
# Episode 8231 finished with reward: 0.54
# Moving average (last 50 episodes): 18.70 ± 20.92
# Episode 8232 finished with reward: 6.95
# Moving average (last 50 episodes): 18.56 ± 20.97
# Episode 8233 finished with reward: 25.20
# Moving average (last 50 episodes): 18.51 ± 20.95
# Episode 8234 finished with reward: 41.59
# Moving average (last 50 episodes): 18.42 ± 20.85
# Episode 8235 finished with reward: 29.19
# Moving average (last 50 episodes): 18.35 ± 20.80
# Episode 8236 finished with reward: 9.92
# Moving average (last 50 episodes): 18.03 ± 20.81
# Episode 8237 finished with reward: -1.95
# Moving average (last 50 episodes): 17.95 ± 20.88
# Episode 8238 finished with reward: 44.97
# Moving average (last 50 episodes): 18.32 ± 21.19
# Episode 8239 finished with reward: 43.74
# Moving average (last 50 episodes): 18.49 ± 21.35
# Episode 8240 finished with reward: 45.07
# Moving average (last 50 episodes): 18.98 ± 21.67
# Episode 8241 finished with reward: 50.18
# Moving average (last 50 episodes): 18.50 ± 20.70
# Episode 8242 finished with reward: 54.06
# Moving average (last 50 episodes): 19.06 ± 21.26
# Episode 8243 finished with reward: 34.71
# Moving average (last 50 episodes): 19.70 ± 21.24
# Episode 8244 finished with reward: 36.59
# Moving average (last 50 episodes): 19.88 ± 21.35
# Episode 8245 finished with reward: 25.72
# Moving average (last 50 episodes): 19.99 ± 21.36
# Episode 8246 finished with reward: 1.01
# Moving average (last 50 episodes): 20.09 ± 21.26
# Episode 8247 finished with reward: 31.14
# Moving average (last 50 episodes): 20.26 ± 21.31
# Episode 8248 finished with reward: 34.09
# Moving average (last 50 episodes): 20.94 ± 21.20
# Episode 8249 finished with reward: 40.92
# Moving average (last 50 episodes): 20.92 ± 21.17
# Episode 8250 finished with reward: -16.21
# Moving average (last 50 episodes): 20.61 ± 21.60
# Episode 8251 finished with reward: 0.91
# Moving average (last 50 episodes): 20.08 ± 21.75
# Episode 8252 finished with reward: 7.53
# Moving average (last 50 episodes): 19.65 ± 21.78
# Episode 8253 finished with reward: 41.66
# Moving average (last 50 episodes): 19.99 ± 21.98
# Episode 8254 finished with reward: 18.39
# Moving average (last 50 episodes): 19.89 ± 21.98
# Episode 8255 finished with reward: 32.65
# Moving average (last 50 episodes): 19.86 ± 21.96
# Episode 8256 finished with reward: 25.93
# Moving average (last 50 episodes): 20.35 ± 21.81
# Episode 8257 finished with reward: 20.96
# Moving average (last 50 episodes): 20.05 ± 21.69
# Episode 8258 finished with reward: 17.13
# Moving average (last 50 episodes): 19.62 ± 21.54
# Episode 8259 finished with reward: 0.45
# Moving average (last 50 episodes): 19.21 ± 21.70
# Episode 8260 finished with reward: -12.08
# Moving average (last 50 episodes): 19.03 ± 21.92
# Episode 8261 finished with reward: 26.24
# Moving average (last 50 episodes): 19.33 ± 21.92
# Episode 8262 finished with reward: 50.77
# Moving average (last 50 episodes): 19.95 ± 22.35
# Episode 8263 finished with reward: 27.58
# Moving average (last 50 episodes): 21.14 ± 21.11
# Episode 8264 finished with reward: 34.40
# Moving average (last 50 episodes): 21.45 ± 21.19
# Episode 8265 finished with reward: -1.73
# Moving average (last 50 episodes): 21.25 ± 21.36
# Episode 8266 finished with reward: 35.36
# Moving average (last 50 episodes): 21.50 ± 21.45
# Episode 8267 finished with reward: 4.14
# Moving average (last 50 episodes): 22.31 ± 19.99
# Episode 8268 finished with reward: 5.87
# Moving average (last 50 episodes): 22.32 ± 19.97
# Episode 8269 finished with reward: 20.20
# Moving average (last 50 episodes): 22.44 ± 19.94
# Episode 8270 finished with reward: 45.85
# Moving average (last 50 episodes): 23.60 ± 19.58
# Episode 8271 finished with reward: -7.71
# Moving average (last 50 episodes): 22.95 ± 20.06
# Episode 8272 finished with reward: 7.06
# Moving average (last 50 episodes): 22.25 ± 19.99
# Episode 8273 finished with reward: 20.70
# Moving average (last 50 episodes): 22.68 ± 19.71
# Episode 8274 finished with reward: 29.95
# Moving average (last 50 episodes): 23.27 ± 19.48
# Episode 8275 finished with reward: -6.58
# Moving average (last 50 episodes): 22.45 ± 19.85
# Episode 8276 finished with reward: -18.13
# Moving average (last 50 episodes): 22.50 ± 19.75
# Episode 8277 finished with reward: 14.27
# Moving average (last 50 episodes): 22.45 ± 19.77
# Episode 8278 finished with reward: -17.38
# Moving average (last 50 episodes): 21.25 ± 20.32
# Episode 8279 finished with reward: 18.08
# Moving average (last 50 episodes): 20.53 ± 19.78
# Episode 8280 finished with reward: 16.98
# Moving average (last 50 episodes): 19.94 ± 19.43
# Episode 8281 finished with reward: 43.88
# Moving average (last 50 episodes): 20.81 ± 19.51
# Episode 8282 finished with reward: 12.32
# Moving average (last 50 episodes): 20.91 ± 19.45
# Episode 8283 finished with reward: 14.46
# Moving average (last 50 episodes): 20.70 ± 19.46
# Episode 8284 finished with reward: 5.09
# Moving average (last 50 episodes): 19.97 ± 19.35
# Episode 8285 finished with reward: 16.69
# Moving average (last 50 episodes): 19.72 ± 19.31
# Episode 8286 finished with reward: 30.05
# Moving average (last 50 episodes): 20.12 ± 19.31
# Episode 8287 finished with reward: 33.67
# Moving average (last 50 episodes): 20.83 ± 19.14
# Episode 8288 finished with reward: 33.65
# Moving average (last 50 episodes): 20.61 ± 18.92
# Episode 8289 finished with reward: 15.45
# Moving average (last 50 episodes): 20.04 ± 18.64
# Episode 8290 finished with reward: 23.52
# Moving average (last 50 episodes): 19.61 ± 18.30
# Episode 8291 finished with reward: 23.19
# Moving average (last 50 episodes): 19.07 ± 17.78
# Episode 8292 finished with reward: 38.38
# Moving average (last 50 episodes): 18.76 ± 17.29
# Episode 8293 finished with reward: 22.21
# Moving average (last 50 episodes): 18.51 ± 17.15
# Episode 8294 finished with reward: 4.39
# Moving average (last 50 episodes): 17.86 ± 17.06
# Episode 8295 finished with reward: 25.85
# Moving average (last 50 episodes): 17.86 ± 17.06
# Episode 8296 finished with reward: 24.19
# Moving average (last 50 episodes): 18.33 ± 16.91
# Episode 8297 finished with reward: 37.64
# Moving average (last 50 episodes): 18.46 ± 17.04
# Episode 8298 finished with reward: 37.50
# Moving average (last 50 episodes): 18.53 ± 17.11
# Episode 8299 finished with reward: 20.62
# Moving average (last 50 episodes): 18.12 ± 16.81
# Episode 8300 finished with reward: -14.67
# Moving average (last 50 episodes): 18.15 ± 16.75
# Episode 8301 finished with reward: 11.40
# Moving average (last 50 episodes): 18.36 ± 16.59
# Episode 8302 finished with reward: 29.45
# Moving average (last 50 episodes): 18.80 ± 16.59
# Episode 8303 finished with reward: 3.00
# Moving average (last 50 episodes): 18.03 ± 16.41
# Episode 8304 finished with reward: 22.21
# Moving average (last 50 episodes): 18.10 ± 16.42
# Episode 8305 finished with reward: -20.95
# Moving average (last 50 episodes): 17.03 ± 17.17
# Episode 8306 finished with reward: -5.26
# Moving average (last 50 episodes): 16.41 ± 17.40
# Episode 8307 finished with reward: 34.49
# Moving average (last 50 episodes): 16.68 ± 17.57
# Episode 8308 finished with reward: -12.02
# Moving average (last 50 episodes): 16.09 ± 18.02
# Episode 8309 finished with reward: 21.35
# Moving average (last 50 episodes): 16.51 ± 17.90
# Episode 8310 finished with reward: 45.26
# Moving average (last 50 episodes): 17.66 ± 17.86
# Episode 8311 finished with reward: -31.56
# Moving average (last 50 episodes): 16.50 ± 19.10
# Episode 8312 finished with reward: 27.97
# Moving average (last 50 episodes): 16.05 ± 18.54
# Episode 8313 finished with reward: 22.73
# Moving average (last 50 episodes): 15.95 ± 18.49
# Episode 8314 finished with reward: 30.91
# Moving average (last 50 episodes): 15.88 ± 18.43
# Episode 8315 finished with reward: -21.64
# Moving average (last 50 episodes): 15.48 ± 19.01
# Episode 8316 finished with reward: 32.74
# Moving average (last 50 episodes): 15.43 ± 18.96
# Episode 8317 finished with reward: 48.79
# Moving average (last 50 episodes): 16.32 ± 19.45
# Episode 8318 finished with reward: 13.23
# Moving average (last 50 episodes): 16.47 ± 19.40
# Episode 8319 finished with reward: 15.92
# Moving average (last 50 episodes): 16.38 ± 19.39
# Episode 8320 finished with reward: 27.60
# Moving average (last 50 episodes): 16.02 ± 19.00
# Episode 8321 finished with reward: 43.89
# Moving average (last 50 episodes): 17.05 ± 19.09
# Episode 8322 finished with reward: 36.41
# Moving average (last 50 episodes): 17.64 ± 19.22
# Episode 8323 finished with reward: -2.52
# Moving average (last 50 episodes): 17.17 ± 19.42
# Episode 8324 finished with reward: 25.01
# Moving average (last 50 episodes): 17.07 ± 19.37
# Episode 8325 finished with reward: 31.46
# Moving average (last 50 episodes): 17.83 ± 19.17
# Episode 8326 finished with reward: 32.86
# Moving average (last 50 episodes): 18.85 ± 18.58
# Episode 8327 finished with reward: 39.57
# Moving average (last 50 episodes): 19.36 ± 18.79
# Episode 8328 finished with reward: -1.67
# Moving average (last 50 episodes): 19.67 ± 18.30
# Episode 8329 finished with reward: 22.17
# Moving average (last 50 episodes): 19.76 ± 18.30
# Episode 8330 finished with reward: 34.05
# Moving average (last 50 episodes): 20.10 ± 18.40
# Episode 8331 finished with reward: -6.00
# Moving average (last 50 episodes): 19.10 ± 18.44
# Episode 8332 finished with reward: 26.10
# Moving average (last 50 episodes): 19.38 ± 18.44
# Episode 8333 finished with reward: 11.42
# Moving average (last 50 episodes): 19.32 ± 18.46
# Episode 8334 finished with reward: 31.50
# Moving average (last 50 episodes): 19.84 ± 18.42
# Episode 8335 finished with reward: 33.75
# Moving average (last 50 episodes): 20.18 ± 18.52
# Episode 8336 finished with reward: -4.36
# Moving average (last 50 episodes): 19.50 ± 18.78
# Episode 8337 finished with reward: 35.74
# Moving average (last 50 episodes): 19.54 ± 18.81
# Episode 8338 finished with reward: 53.11
# Moving average (last 50 episodes): 19.93 ± 19.29

# %%
# def plot_smooth_rewards(rewards, window_sizes=[5, 20, 100]):
#     """
#     绘制平滑的奖励曲线
#     Args:
#         rewards: 奖励列表
#         window_sizes: 移动平均窗口大小列表
#     """
#     plt.figure(figsize=(12, 6))
    
#     # 绘制原始奖励
#     plt.plot(rewards, 'lightgray', alpha=0.3, label='Raw rewards')
    
#     # 绘制不同窗口大小的移动平均
#     colors = ['blue', 'green', 'red']
#     for window, color in zip(window_sizes, colors):
#         if len(rewards) >= window:
#             # 计算移动平均
#             smooth_rewards = np.convolve(rewards, 
#                                       np.ones(window)/window, 
#                                       mode='valid')
#             plt.plot(range(window-1, len(rewards)), 
#                     smooth_rewards, 
#                     color=color, 
#                     label=f'{window}-Episode Moving Average',
#                     linewidth=2)
    
#     plt.xlabel('Episode')
#     plt.ylabel('Reward')
#     plt.title('Training Rewards with Different Smoothing Windows')
#     plt.grid(True, alpha=0.3)
#     plt.legend()
#     plt.show()


# # 绘制平滑奖励曲线
# plot_smooth_rewards(metrics["rewards"])

# %% [markdown]
# notes: 如果要训练过程中查看模型，通过 tensorboard 查看

# %%
# 模型保存
model.save(f"./model/{log_name}")

# %% [markdown]
# ### 评估模型训练结果

# %% [markdown]
# > 利用 evaulate policy 函数评估

# %% [markdown]
# # 加载训练好的 RL 模型

# %%
from stable_baselines3.common.evaluation import evaluate_policy
mean_reward, std_reward = evaluate_policy(
    model, 
    model.get_env(), 
    deterministic=True,
    render=True,
    n_eval_episodes=10)

print(mean_reward)
print(std_reward)
# Out:
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# -0.0430807999999999
# 16.714301370287895

# %%
# del model
model = PPO.load(f"./model/{log_name}", env=env_monitor)
# model = DQN.load(f"./model/{log_name}", env=env_monitor)
# Out:
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### 结果展示

# %% [markdown]
# #### 纯净展示版本
#
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆

for ep in range(episodes):
    
    obs, _ = env_monitor.reset(use_random_reset=base_config["use_random_reset"], seed=base_config["seed"]) # 必须的，每次重现一次
    
    episode_reward = 0
    done = False
    
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        print(f"year {env_monitor.t}-Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # # 每10步更新一次图像
        # if i == max_steps-1:
        #     env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            env_monitor.render()
            plt.show()  # 添加这行来保持图形窗口
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")
# Out:
# year 2017-Step 0 - Action: 14 - Reward: 2.020338387561824 - Done: False
# year 2018-Step 1 - Action: 14 - Reward: 1.8550777590099266 - Done: False
# year 2019-Step 2 - Action: 14 - Reward: 1.6813196133017583 - Done: False
# year 2020-Step 3 - Action: 14 - Reward: 1.5004772370243313 - Done: False
# year 2021-Step 4 - Action: 14 - Reward: 1.3133820319298595 - Done: False
# year 2022-Step 5 - Action: 14 - Reward: 1.1351865426226715 - Done: False
# year 2023-Step 6 - Action: 14 - Reward: 0.9657895243744796 - Done: False
# year 2024-Step 7 - Action: 14 - Reward: 0.8052036625709813 - Done: False
# year 2025-Step 8 - Action: 14 - Reward: 0.6535148791511669 - Done: False
# year 2026-Step 9 - Action: 14 - Reward: 0.5108516632498783 - Done: False
# year 2027-Step 10 - Action: 14 - Reward: 0.7548874214820445 - Done: False
# year 2028-Step 11 - Action: 14 - Reward: 0.5068995891927774 - Done: False
# year 2029-Step 12 - Action: 14 - Reward: 0.27817920532716034 - Done: False
# year 2030-Step 13 - Action: 14 - Reward: 0.06917094458549489 - Done: False
# year 2031-Step 14 - Action: 14 - Reward: -0.05989308996328768 - Done: False
# year 2032-Step 15 - Action: 14 - Reward: -0.14437770739617717 - Done: False
# year 2033-Step 16 - Action: 14 - Reward: -0.21908270206397185 - Done: False
# year 2034-Step 17 - Action: 14 - Reward: -0.28412811231586566 - Done: False
# year 2035-Step 18 - Action: 14 - Reward: -0.33975038900137755 - Done: False
# year 2036-Step 19 - Action: 14 - Reward: -0.38624589286618605 - Done: False
# year 2037-Step 20 - Action: 14 - Reward: -0.4239549967277101 - Done: False
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.t to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.t` for environment variables or `env.get_wrapper_attr('t')` that will search the reminding wrappers.
#   logger.warn(
# year 2038-Step 21 - Action: 14 - Reward: -0.45326267845749557 - Done: False
# year 2039-Step 22 - Action: 14 - Reward: -0.47458596650461704 - Done: False
# year 2040-Step 23 - Action: 14 - Reward: -0.48837965665280203 - Done: False
# year 2041-Step 24 - Action: 14 - Reward: -0.49513005366642937 - Done: False
# year 2042-Step 25 - Action: 14 - Reward: -0.49571981263689113 - Done: False
# year 2043-Step 26 - Action: 14 - Reward: -0.4908943872350213 - Done: False
# year 2044-Step 27 - Action: 14 - Reward: -0.4810777270200983 - Done: False
# year 2045-Step 28 - Action: 14 - Reward: -0.46666772714726745 - Done: False
# year 2046-Step 29 - Action: 14 - Reward: -0.44801686543704977 - Done: False
# year 2047-Step 30 - Action: 14 - Reward: -0.4254321199775324 - Done: False
# year 2048-Step 31 - Action: 14 - Reward: -0.3991898061139587 - Done: False
# year 2049-Step 32 - Action: 14 - Reward: -0.3695373229043275 - Done: False
# year 2050-Step 33 - Action: 14 - Reward: -0.33669943631741583 - Done: False
# year 2051-Step 34 - Action: 14 - Reward: -0.3008790912488035 - Done: False
# year 2052-Step 35 - Action: 1 - Reward: -0.26436015348961894 - Done: False
# year 2053-Step 36 - Action: 1 - Reward: -0.227567074295546 - Done: False
# year 2054-Step 37 - Action: 1 - Reward: -0.190984351475868 - Done: False
# year 2055-Step 38 - Action: 1 - Reward: -0.15497621897424319 - Done: False
# year 2056-Step 39 - Action: 1 - Reward: -0.11989265024718754 - Done: False
# year 2057-Step 40 - Action: 1 - Reward: -0.08594087622583735 - Done: False
# year 2058-Step 41 - Action: 1 - Reward: -0.05331202871663221 - Done: False
# year 2059-Step 42 - Action: 1 - Reward: -0.022148928655691957 - Done: False
# year 2060-Step 43 - Action: 1 - Reward: 0.014943449571152012 - Done: False
# year 2061-Step 44 - Action: 1 - Reward: 0.07103373407562286 - Done: False
# year 2062-Step 45 - Action: 1 - Reward: 0.12370117913794276 - Done: False
# year 2063-Step 46 - Action: 1 - Reward: 0.17200820866927868 - Done: False
# year 2064-Step 47 - Action: 1 - Reward: 0.21560902086142253 - Done: False
# year 2065-Step 48 - Action: 1 - Reward: 0.2545278753016089 - Done: False
# year 2066-Step 49 - Action: 1 - Reward: 0.2886670657489132 - Done: False
# year 2067-Step 50 - Action: 1 - Reward: 0.3177593232386666 - Done: False
# year 2068-Step 51 - Action: 1 - Reward: 0.3416856687850012 - Done: False
# year 2069-Step 52 - Action: 1 - Reward: 0.3603917042097571 - Done: False
# year 2070-Step 53 - Action: 1 - Reward: 0.3738790155951355 - Done: False
# year 2071-Step 54 - Action: 1 - Reward: 0.38219506786566715 - Done: False
# year 2072-Step 55 - Action: 1 - Reward: 0.3853609558170423 - Done: False
# year 2073-Step 56 - Action: 1 - Reward: 0.3829246275779652 - Done: False
# year 2074-Step 57 - Action: 1 - Reward: 0.3731732059113435 - Done: False
# year 2075-Step 58 - Action: 1 - Reward: 0.3564711143013488 - Done: False
# year 2076-Step 59 - Action: 1 - Reward: 0.33318650674174943 - Done: False
# year 2077-Step 60 - Action: 1 - Reward: 0.3036886506595793 - Done: False
# year 2078-Step 61 - Action: 1 - Reward: 0.26834459036482405 - Done: False
# year 2079-Step 62 - Action: 1 - Reward: 0.22751977904839515 - Done: False
# year 2080-Step 63 - Action: 1 - Reward: 0.1815717759279889 - Done: False
# year 2081-Step 64 - Action: 1 - Reward: 0.13085070047305747 - Done: False
# year 2082-Step 65 - Action: 1 - Reward: 0.07568500256030841 - Done: False
# year 2083-Step 66 - Action: 1 - Reward: 0.01637996041116585 - Done: False
# year 2084-Step 67 - Action: 1 - Reward: -0.023383149878799525 - Done: False
# year 2085-Step 68 - Action: 1 - Reward: -0.05675011673400787 - Done: False
# year 2086-Step 69 - Action: 1 - Reward: -0.09175712253089552 - Done: False
# year 2087-Step 70 - Action: 1 - Reward: -0.1282582528256626 - Done: False
# year 2088-Step 71 - Action: 1 - Reward: -0.16611308480955933 - Done: False
# year 2089-Step 72 - Action: 1 - Reward: -0.20518693182693726 - Done: False
# year 2090-Step 73 - Action: 1 - Reward: -0.2453502309973954 - Done: False
# year 2091-Step 74 - Action: 14 - Reward: -0.28646533629126836 - Done: False
# year 2092-Step 75 - Action: 1 - Reward: -0.32747840204909284 - Done: False
# year 2093-Step 76 - Action: 1 - Reward: -0.36792032287013 - Done: False
# year 2094-Step 77 - Action: 1 - Reward: -0.40789968465550386 - Done: False
# year 2095-Step 78 - Action: 1 - Reward: -0.44746759980821005 - Done: False
# year 2096-Step 79 - Action: 1 - Reward: -0.48665559499994737 - Done: False
# year 2097-Step 80 - Action: 1 - Reward: -0.52548499301175 - Done: False
# year 2098-Step 81 - Action: 1 - Reward: -0.5639681550974951 - Done: False
# year 2099-Step 82 - Action: 1 - Reward: -0.6021100274308122 - Done: False
# year 2100-Step 83 - Action: 1 - Reward: -0.6399093070162043 - Done: True
# Episode ended at step 83 with T_a = 1.6279818614032409
# Episode 0 finished with reward-0.6399093070162043
# Final T_a: 1.6279818614032409

# %% [markdown]
# ### 保存整体运行结果

# %%
env_test = IEMEnv(reward_type=custom_reward_type)
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 3 # 结果展示，只有一个 episode 部分
max_steps = 250

# all_episode_rewards = [] # 记录所有 episode 里面的
 
for ep in range(episodes):
    
    ##################################
    # 记录所需数组：每次 episode 重置
    total_action = []
    total_state = []
    total_reward = []
    total_done = []
    ##################################
    # 记录每个 episode 的 reward
    episode_reward = 0
    ##################################
    
    obs, _ = env_test.reset() # 必须的，每次重现一次 ，这里可能就需要固定随机种子了
    done = False
    
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        ##################################
        # 添加转换的部分
        action_number, action_name = IEMEnv.action2number_env(action)
        total_action.append(action_number)
        total_state.append(obs)
        total_reward.append(reward)
        total_done.append(done)
        ##################################
        # 记录每个 episode 的 reward
        episode_reward += reward # TODO：可以放在内容记录 step 部分
        ################################## 
        
        if done:
            print(f"Episode {ep} finished at step {i}")
            break
        
        # # 每10步更新一次图像
        # if ep % 10 == 0:
        #     env_monitor.render()
        #     # plt.pause(0.01)
    
    # all_episode_rewards.append(episode_reward)
    
    env_test.append_data_reward(episode_reward)
    
    save_future_data(env=env_test,custom_reward_type=custom_reward_type,rl_model_name=rl_model_name,network_name=policy_kwargs_diy,episode=ep,total_action=total_action,total_state=total_state,total_reward=total_reward,total_done=total_done,total_timesteps_name=total_timesteps_diy)

    save_plot_NSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    save_plot_SSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    # plot_3D_run(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state)
    
    
    print(f"Episode {ep} finished with reward{episode_reward}")
    
    
plot_data = env_test.get_variables()
plot_episode_reward(plot_data)

# %% [markdown]
# 主要针对可视化显示部分操作

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 绘制只展示一次 episode 结果

# env_test

for episode in range(1):
    obs, _ = env_test.reset() # 这里可能就需要固定随机种子了
    
    done = False
    
    for i in range(251):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        
        if done:
            print(f"Episode {episode} finished at step {i}")
            break
# Out:
# Step 0 - Action: 14 - Reward: 3.0904728670266177 - Done: False
# Step 1 - Action: 14 - Reward: 2.8143259504006064 - Done: False
# Step 2 - Action: 14 - Reward: 2.5388782590533747 - Done: False
# Step 3 - Action: 14 - Reward: 2.2645900074085965 - Done: False
# Step 4 - Action: 14 - Reward: 1.9915873908854798 - Done: False
# Step 5 - Action: 14 - Reward: 1.734452545111016 - Done: False
# Step 6 - Action: 14 - Reward: 1.4926104266443496 - Done: False
# Step 7 - Action: 14 - Reward: 1.2655849260739827 - Done: False
# Step 8 - Action: 14 - Reward: 1.052969926174866 - Done: False
# Step 9 - Action: 14 - Reward: 0.854478131863341 - Done: False
# Step 10 - Action: 14 - Reward: 0.6698605977014027 - Done: False
# Step 11 - Action: 14 - Reward: 0.9978527975752249 - Done: False
# Step 12 - Action: 14 - Reward: 0.6829959997166313 - Done: False
# Step 13 - Action: 14 - Reward: 0.394796378144493 - Done: False
# Step 14 - Action: 14 - Reward: 0.13280484966322836 - Done: False
# Step 15 - Action: 14 - Reward: -0.0518705563332289 - Done: False
# Step 16 - Action: 14 - Reward: -0.15792615235523555 - Done: False
# Step 17 - Action: 14 - Reward: -0.25217683361350773 - Done: False
# Step 18 - Action: 14 - Reward: -0.335103368050359 - Done: False
# Step 19 - Action: 14 - Reward: -0.40718676221516037 - Done: False
# Step 20 - Action: 14 - Reward: -0.4689232925926312 - Done: False
# Step 21 - Action: 14 - Reward: -0.5208153857359787 - Done: False
# Step 22 - Action: 14 - Reward: -0.5633955746806307 - Done: False
# Step 23 - Action: 14 - Reward: -0.5972127814109618 - Done: False
# Step 24 - Action: 14 - Reward: -0.6227619651364247 - Done: False
# Step 25 - Action: 14 - Reward: -0.6409921455294931 - Done: False
# Step 26 - Action: 14 - Reward: -0.6527198458236327 - Done: False
# Step 27 - Action: 14 - Reward: -0.6584133417596649 - Done: False
# Step 28 - Action: 14 - Reward: -0.6585099261429961 - Done: False
# Step 29 - Action: 14 - Reward: -0.6534054723911853 - Done: False
# Step 30 - Action: 14 - Reward: -0.6434595485197891 - Done: False
# Step 31 - Action: 14 - Reward: -0.6289974965731493 - Done: False
# Step 32 - Action: 14 - Reward: -0.6103163408647927 - Done: False
# Step 33 - Action: 14 - Reward: -0.5876873592052789 - Done: False
# Step 34 - Action: 14 - Reward: -0.5613598647682938 - Done: False
# Step 35 - Action: 14 - Reward: -0.5336583135044404 - Done: False
# Step 36 - Action: 14 - Reward: -0.5048527037579098 - Done: False
# Step 37 - Action: 1 - Reward: -0.4751617321554935 - Done: False
# Step 38 - Action: 1 - Reward: -0.44494696257410205 - Done: False
# Step 39 - Action: 14 - Reward: -0.41458904694523735 - Done: False
# Step 40 - Action: 1 - Reward: -0.3842041474591984 - Done: False
# Step 41 - Action: 1 - Reward: -0.35396533396973573 - Done: False
# Step 42 - Action: 1 - Reward: -0.3241466075662469 - Done: False
# Step 43 - Action: 1 - Reward: -0.29491537882767593 - Done: False
# Step 44 - Action: 1 - Reward: -0.26642732179476325 - Done: False
# Step 45 - Action: 1 - Reward: -0.23884546314123845 - Done: False
# Step 46 - Action: 1 - Reward: -0.21277368794706764 - Done: False
# Step 47 - Action: 1 - Reward: -0.18856240685101167 - Done: False
# Step 48 - Action: 1 - Reward: -0.166458647250044 - Done: False
# Step 49 - Action: 1 - Reward: -0.14661441965269195 - Done: False
# Step 50 - Action: 1 - Reward: -0.1291389456452241 - Done: False
# Step 51 - Action: 1 - Reward: -0.11410406777368043 - Done: False
# Step 52 - Action: 1 - Reward: -0.10154794314541804 - Done: False
# Step 53 - Action: 1 - Reward: -0.09148090558088628 - Done: False
# Step 54 - Action: 1 - Reward: -0.08388866215753299 - Done: False
# Step 55 - Action: 1 - Reward: -0.07876934079554032 - Done: False
# Step 56 - Action: 1 - Reward: -0.07635704507861552 - Done: False
# Step 57 - Action: 1 - Reward: -0.0775156220703832 - Done: False
# Step 58 - Action: 1 - Reward: -0.0820706750496103 - Done: False
# Step 59 - Action: 1 - Reward: -0.08984492718875359 - Done: False
# Step 60 - Action: 1 - Reward: -0.1006600094632304 - Done: False
# Step 61 - Action: 1 - Reward: -0.11433886340066812 - Done: False
# Step 62 - Action: 1 - Reward: -0.13070592501442269 - Done: False
# Step 63 - Action: 1 - Reward: -0.14958859552808956 - Done: False
# Step 64 - Action: 1 - Reward: -0.17081618700794832 - Done: False
# Step 65 - Action: 1 - Reward: -0.19422949994221006 - Done: False
# Step 66 - Action: 1 - Reward: -0.21968080867171502 - Done: False
# Step 67 - Action: 1 - Reward: -0.24702528806602397 - Done: False
# Step 68 - Action: 1 - Reward: -0.2761405806875805 - Done: False
# Step 69 - Action: 1 - Reward: -0.3068773483290299 - Done: False
# Step 70 - Action: 1 - Reward: -0.3390938814409217 - Done: False
# Step 71 - Action: 1 - Reward: -0.3726547866583041 - Done: False
# Step 72 - Action: 1 - Reward: -0.4074273849453314 - Done: False
# Step 73 - Action: 1 - Reward: -0.44328674032457993 - Done: False
# Step 74 - Action: 1 - Reward: -0.48011202351729176 - Done: False
# Step 75 - Action: 1 - Reward: -0.5177887949867166 - Done: False
# Step 76 - Action: 1 - Reward: -0.5562072751930547 - Done: False
# Step 77 - Action: 1 - Reward: -0.5952619175391771 - Done: False
# Step 78 - Action: 1 - Reward: -0.6348542121976408 - Done: False
# Step 79 - Action: 1 - Reward: -0.6748928269579368 - Done: False
# Step 80 - Action: 1 - Reward: -0.7152852315418745 - Done: False
# Step 81 - Action: 1 - Reward: -0.7559427418553022 - Done: False
# Step 82 - Action: 1 - Reward: -0.7967814898463033 - Done: False
# Step 83 - Action: 1 - Reward: -0.8377230866307261 - Done: True
# Episode 0 finished at step 83

# %% [markdown]
# # 保存运行结果
