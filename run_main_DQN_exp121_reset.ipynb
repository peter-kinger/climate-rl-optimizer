# %% [markdown]
# # RL 训练

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import scipy.io  
from matplotlib.gridspec import GridSpec
import math
import random
import torch

from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.logger import configure
from stable_baselines3.common.monitor import Monitor
from stable_baselines3 import PPO 
from stable_baselines3 import DQN

# 导入 BaseCallback
from stable_baselines3.common.callbacks import BaseCallback

import sys
import os

# 将 src 目录添加到模块搜索路径
sys.path.append(os.path.abspath('src'))

# 导入 IEMEnv 类
from src.envs.iseec_lx_v4_mdp_plot import IEMEnv
from src.utils.run_debug_plot import save_data 
from src.utils.run_debug_plot import save_plot_NSM_data
from src.utils.run_debug_plot import save_plot_SSM_data

from src.utils.run_debug_plot import save_future_data
from src.utils.run_debug_plot import save_plot_NSM_future_data
from src.utils.run_debug_plot import save_plot_SSM_future_data

from src.utils.run_debug_plot import plot_episode_reward
from src.utils.run_debug_plot import plot_episode_reward_simple
from src.utils.run_debug_plot import plot_3D_run

# %% [markdown]
# 定义保存位置参数
#
# > 所有的关键参数都放在最前面

# %%
# 增加随机种子的定义
def set_global_seed(seed):
    """设置全局随机种子"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False


# 设置全局种子
# SEED = 42 # 非测试，不指定种子
# set_global_seed(SEED)

# 全新的超参数配置过程，都放在一起
base_config = {
    # MDP 元素
    "custom_reward_type" : "multi_objective_all_T_a_Ca_exp121_reset",
    # 环境 & 策略
    "env_id":   "iseec_lx_v4_mdp_plot",
    "rl_model_name": "DQN",
    "policy":   "MlpPolicy",
    "network_name" : "Netxxx_no_big_env",
    # 训练时长
    "total_timesteps_diy": 700000,
    "policy_kwargs_diy" : "dict_pi_vf_default", # for example: policy_kwargs = dict(activation_fn=th.nn.ReLU,net_arch=[256, 256, dict(pi=[128, 64], vf=[128, 64])])
    # 优化器 & 网络
    "hyperparams_diy": "default", 
    # "learning_rate":   3e-4,
    # "ent_coef":        0.0,
    # "batch_size":      64,
    # "n_epochs":        10,
    # 回放 & 更新频率（PPO 固定写法示例）
    # "gamma":           0.99,
    # "clip_range":      0.2,
    # "gae_lambda":      0.95,
    # 随机种子
    "use_random_reset": False, # 是否使用随机重置
    "seed":            42,
}


############### 具体的配置细节##############
# 设置保存的日志名字：
log_name = f'{base_config["env_id"]}_{base_config["rl_model_name"]}_{base_config["custom_reward_type"]}_{int(base_config["total_timesteps_diy"])}_{base_config["hyperparams_diy"]}' 
os.makedirs(f'./logs/{log_name}', exist_ok=True) # 创建日志目录

# 相当于接口部分
custom_reward_type = base_config["custom_reward_type"]
network_name = base_config["network_name"]
rl_model_name = base_config["rl_model_name"]
total_timesteps_diy = base_config["total_timesteps_diy"]
policy_kwargs_diy = base_config["policy_kwargs_diy"] 

# 设置日志保存路径和格式
new_logger = configure(
    f"logs/{log_name}",  # tmp_path 路径保存位置
    # ["stdout",     # 终端输出
    [
     "csv",        # CSV文件
     "tensorboard", # Tensorboard格式
     "json"        # JSON格式
    ]
)

# %% [markdown]
# ### 定义环境

# %%
env = IEMEnv(reward_type=base_config["custom_reward_type"], seed=base_config["seed"])
env_monitor = Monitor(env, f'./logs/{log_name}')
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# ### 定义算法

# %%
# # 定义模型
# model = PPO(
#     "MlpPolicy", 
#     env_monitor, 
#     # ent_coef=0.01, # 增加策略寻找的鼓励，但是 suggestion 暂时不要改变
#     verbose=1,
#     )

model = DQN(
    "MlpPolicy", 
    env_monitor, 
    verbose=1,
    )

model.set_logger(new_logger) # set the parameter of the logger
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
# check 环境
from stable_baselines3.common.env_checker import check_env
# check_env(env_monitor)
log_name

print("Action space sample:", env.action_space.sample())
# print("Observation space sample:", env.observation_space.sample())

# type(env.action_space), type(env.observation_space)
print("Action space sample:", env.action_space.sample())
print("Observation space sample:", env.observation_space.sample())

print(model.policy)
# Out:
# Action space sample: 11
# Action space sample: 0
# Observation space sample: [ 1.01816453  0.67597226 -0.97002156  0.6910615  -0.06312414 -0.11593102
#   0.9075122  -0.00232892  1.27046547 -2.04429404]
# DQNPolicy(
#   (q_net): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=16, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=16, bias=True)
#     )
#   )
# )

# %% [markdown]
# ### 模型训练

# %%
def plot_callback_reward(metrics):
    """绘制训练过程中的奖励曲线
    
    Args:
        metrics (dict): 包含训练指标的字典，需要包含以下键：
            - rewards: 原始奖励列表
            - moving_avg_rewards: 移动平均奖励列表
            - moving_std_rewards: 移动标准差列表
            - episodes: 总回合数
            - step_idx: 当前步数
    """
    plt.figure(figsize=(20, 5))
    
    # 创建主图
    plt.subplot(131)
    plt.title(f'Step: {metrics["step_idx"]}, Latest reward: {metrics["rewards"][-1]:.2f}\n'
              f'Episode: {metrics["episodes"]}, Moving avg: {metrics["moving_avg_rewards"][-1]:.2f}')
    
    # 绘制原始奖励
    episodes = range(len(metrics["rewards"]))
    plt.plot(episodes, metrics["rewards"], 
             label='Raw rewards', color='gray', alpha=0.3)
    
    # 绘制移动平均
    plt.plot(episodes, metrics["moving_avg_rewards"],
             label='Moving average', color='blue', linewidth=2)
    
    # 添加标准差区域
    moving_avg = np.array(metrics["moving_avg_rewards"])
    moving_std = np.array(metrics["moving_std_rewards"])
    
    # 0.25倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.25 * moving_std,
                    moving_avg + 0.25 * moving_std,
                    color='b', alpha=0.1,
                    label='0.25 std range')
    
    # 0.5倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.5 * moving_std,
                    moving_avg + 0.5 * moving_std,
                    color='b', alpha=0.1,
                    label='0.5 std range')
    
    # 设置坐标轴和标签
    plt.xlabel('Episodes')
    plt.ylabel('Episode Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

class TrainingMonitorCallback(BaseCallback):
    def __init__(self, verbose=1, window_size=50):
        super().__init__(verbose)
        self.window_size = window_size
        # Initialize data dictionary to store metrics
        self.data = {
            "rewards": [],
            "moving_avg_rewards": [],
            "moving_std_rewards": [],
            "episodes": 0,
            "step_idx": 0
        }
        self.episode_rewards = 0
        
    def _on_step(self):
        # Accumulate rewards for current episode
        reward = self.locals.get('rewards')[0]
        self.episode_rewards += reward
        self.data["step_idx"] += 1
        
        # When episode ends, update all metrics
        if self.locals.get('dones')[0]:
            # Store raw reward
            self.data["rewards"].append(self.episode_rewards)
            
            # Calculate moving average and std
            recent_rewards = self.data["rewards"][-self.window_size:]
            moving_avg = np.mean(recent_rewards)
            moving_std = np.std(recent_rewards) if len(recent_rewards) > 1 else 0
            
            # Store calculated metrics
            self.data["moving_avg_rewards"].append(moving_avg)
            self.data["moving_std_rewards"].append(moving_std)
            self.data["episodes"] += 1
            
            # Print progress
            print(f"Episode {self.data['episodes']} finished with reward: {self.episode_rewards:.2f}")
            print(f"Moving average (last {len(recent_rewards)} episodes): {moving_avg:.2f} ± {moving_std:.2f}")
            
            # Reset episode rewards
            self.episode_rewards = 0
            
        return True
    
    def get_metrics(self):
        """Return the collected metrics"""
        return self.data
    
# Create callback with custom window size
callback = TrainingMonitorCallback(window_size=50)

# Train the model
model.learn(
    total_timesteps=int(total_timesteps_diy),
    callback=callback,
    log_interval=1
)

# After training, get metrics for plotting
metrics = callback.get_metrics()

# Plot rewards using the plot_callback_reward function
plot_callback_reward(metrics)
# Out:
# Episode 1 finished with reward: -126.81
# Moving average (last 1 episodes): -126.81 ± 0.00
# Episode 2 finished with reward: -3.33
# Moving average (last 2 episodes): -65.07 ± 61.74
# Episode 3 finished with reward: -54.19
# Moving average (last 3 episodes): -61.45 ± 50.67
# Episode 4 finished with reward: -79.19
# Moving average (last 4 episodes): -65.88 ± 44.55
# Episode 5 finished with reward: -129.80
# Moving average (last 5 episodes): -78.67 ± 47.34
# Episode 6 finished with reward: -71.03
# Moving average (last 6 episodes): -77.39 ± 43.31
# Episode 7 finished with reward: -13.93
# Moving average (last 7 episodes): -68.33 ± 45.84
# Episode 8 finished with reward: -36.14
# Moving average (last 8 episodes): -64.30 ± 44.18
# Episode 9 finished with reward: -46.20
# Moving average (last 9 episodes): -62.29 ± 42.04
# Episode 10 finished with reward: -83.56
# Moving average (last 10 episodes): -64.42 ± 40.39
# Episode 11 finished with reward: -81.94
# Moving average (last 11 episodes): -66.01 ± 38.84
# Episode 12 finished with reward: -72.80
# Moving average (last 12 episodes): -66.58 ± 37.23
# Episode 13 finished with reward: -97.88
# Moving average (last 13 episodes): -68.99 ± 36.73
# Episode 14 finished with reward: 248.18
# Moving average (last 14 episodes): -46.33 ± 89.02
# Episode 15 finished with reward: -73.60
# Moving average (last 15 episodes): -48.15 ± 86.27
# Episode 16 finished with reward: -2.36
# Moving average (last 16 episodes): -45.29 ± 84.26
# Episode 17 finished with reward: -111.14
# Moving average (last 17 episodes): -49.16 ± 83.20
# Episode 18 finished with reward: -81.45
# Moving average (last 18 episodes): -50.95 ± 81.20
# Episode 19 finished with reward: -104.21
# Moving average (last 19 episodes): -53.76 ± 79.92
# Episode 20 finished with reward: -115.50
# Moving average (last 20 episodes): -56.84 ± 79.05
# Episode 21 finished with reward: -73.01
# Moving average (last 21 episodes): -57.61 ± 77.22
# Episode 22 finished with reward: -80.59
# Moving average (last 22 episodes): -58.66 ± 75.60
# Episode 23 finished with reward: -121.75
# Moving average (last 23 episodes): -61.40 ± 75.05
# Episode 24 finished with reward: -50.94
# Moving average (last 24 episodes): -60.96 ± 73.50
# Episode 25 finished with reward: 55.43
# Moving average (last 25 episodes): -56.31 ± 75.54
# Episode 26 finished with reward: -117.37
# Moving average (last 26 episodes): -58.66 ± 75.00
# Episode 27 finished with reward: -123.57
# Moving average (last 27 episodes): -61.06 ± 74.61
# Episode 28 finished with reward: 615.06
# Moving average (last 28 episodes): -36.91 ± 145.30
# Episode 29 finished with reward: -73.16
# Moving average (last 29 episodes): -38.16 ± 142.92
# Episode 30 finished with reward: -62.28
# Moving average (last 30 episodes): -38.97 ± 140.59
# Episode 31 finished with reward: -116.26
# Moving average (last 31 episodes): -41.46 ± 138.97
# Episode 32 finished with reward: -63.21
# Moving average (last 32 episodes): -42.14 ± 136.84
# Episode 33 finished with reward: -56.38
# Moving average (last 33 episodes): -42.57 ± 134.77
# Episode 34 finished with reward: -68.55
# Moving average (last 34 episodes): -43.34 ± 132.85
# Episode 35 finished with reward: -23.55
# Moving average (last 35 episodes): -42.77 ± 130.98
# Episode 36 finished with reward: -90.84
# Moving average (last 36 episodes): -44.11 ± 129.38
# Episode 37 finished with reward: -91.27
# Moving average (last 37 episodes): -45.38 ± 127.85
# Episode 38 finished with reward: -88.67
# Moving average (last 38 episodes): -46.52 ± 126.35
# Episode 39 finished with reward: -82.93
# Moving average (last 39 episodes): -47.45 ± 124.85
# Episode 40 finished with reward: -58.46
# Moving average (last 40 episodes): -47.73 ± 123.29
# Episode 41 finished with reward: -125.72
# Moving average (last 41 episodes): -49.63 ± 122.37
# Episode 42 finished with reward: -90.66
# Moving average (last 42 episodes): -50.61 ± 121.07
# Episode 43 finished with reward: -102.70
# Moving average (last 43 episodes): -51.82 ± 119.91
# Episode 44 finished with reward: -112.15
# Moving average (last 44 episodes): -53.19 ± 118.88
# Episode 45 finished with reward: -89.31
# Moving average (last 45 episodes): -53.99 ± 117.67
# Episode 46 finished with reward: -77.97
# Moving average (last 46 episodes): -54.51 ± 116.44
# Episode 47 finished with reward: -140.91
# Moving average (last 47 episodes): -56.35 ± 115.87
# Episode 48 finished with reward: -95.79
# Moving average (last 48 episodes): -57.17 ± 114.79
# Episode 49 finished with reward: 511.53
# Moving average (last 49 episodes): -45.57 ± 139.19
# Episode 50 finished with reward: 68.84
# Moving average (last 50 episodes): -43.28 ± 138.72
# Episode 51 finished with reward: -114.56
# Moving average (last 50 episodes): -43.03 ± 138.58
# Episode 52 finished with reward: -83.15
# Moving average (last 50 episodes): -44.63 ± 138.58
# Episode 53 finished with reward: -110.97
# Moving average (last 50 episodes): -45.77 ± 138.88
# Episode 54 finished with reward: -107.04
# Moving average (last 50 episodes): -46.32 ± 139.07
# Episode 55 finished with reward: -109.11
# Moving average (last 50 episodes): -45.91 ± 138.85
# Episode 56 finished with reward: -121.27
# Moving average (last 50 episodes): -46.91 ± 139.21
# Episode 57 finished with reward: -44.76
# Moving average (last 50 episodes): -47.53 ± 139.13
# Episode 58 finished with reward: -102.69
# Moving average (last 50 episodes): -48.86 ± 139.34
# Episode 59 finished with reward: -101.02
# Moving average (last 50 episodes): -49.96 ± 139.53
# Episode 60 finished with reward: -82.93
# Moving average (last 50 episodes): -49.95 ± 139.52
# Episode 61 finished with reward: -110.75
# Moving average (last 50 episodes): -50.52 ± 139.71
# Episode 62 finished with reward: -112.79
# Moving average (last 50 episodes): -51.32 ± 139.95
# Episode 63 finished with reward: -103.67
# Moving average (last 50 episodes): -51.44 ± 139.99
# Episode 64 finished with reward: -113.24
# Moving average (last 50 episodes): -58.67 ± 133.52
# Episode 65 finished with reward: -103.23
# Moving average (last 50 episodes): -59.26 ± 133.65
# Episode 66 finished with reward: -21.61
# Moving average (last 50 episodes): -59.64 ± 133.51
# Episode 67 finished with reward: -102.70
# Moving average (last 50 episodes): -59.48 ± 133.45
# Episode 68 finished with reward: -109.43
# Moving average (last 50 episodes): -60.04 ± 133.60
# Episode 69 finished with reward: -91.96
# Moving average (last 50 episodes): -59.79 ± 133.53
# Episode 70 finished with reward: 254.97
# Moving average (last 50 episodes): -52.38 ± 140.34
# Episode 71 finished with reward: 477.42
# Moving average (last 50 episodes): -41.37 ± 158.68
# Episode 72 finished with reward: -123.40
# Moving average (last 50 episodes): -42.23 ± 159.00
# Episode 73 finished with reward: -62.96
# Moving average (last 50 episodes): -41.05 ± 158.63
# Episode 74 finished with reward: -79.42
# Moving average (last 50 episodes): -41.62 ± 158.71
# Episode 75 finished with reward: -66.17
# Moving average (last 50 episodes): -44.05 ± 158.14
# Episode 76 finished with reward: -113.41
# Moving average (last 50 episodes): -43.97 ± 158.10
# Episode 77 finished with reward: -69.47
# Moving average (last 50 episodes): -42.89 ± 157.74
# Episode 78 finished with reward: -49.96
# Moving average (last 50 episodes): -56.19 ± 126.68
# Episode 79 finished with reward: -89.85
# Moving average (last 50 episodes): -56.53 ± 126.75
# Episode 80 finished with reward: -117.79
# Moving average (last 50 episodes): -57.64 ± 127.03
# Episode 81 finished with reward: -119.52
# Moving average (last 50 episodes): -57.70 ± 127.06
# Episode 82 finished with reward: -92.31
# Moving average (last 50 episodes): -58.28 ± 127.16
# Episode 83 finished with reward: -85.06
# Moving average (last 50 episodes): -58.86 ± 127.21
# Episode 84 finished with reward: -84.64
# Moving average (last 50 episodes): -59.18 ± 127.25
# Episode 85 finished with reward: -113.67
# Moving average (last 50 episodes): -60.98 ± 127.38
# Episode 86 finished with reward: 393.25
# Moving average (last 50 episodes): -51.30 ± 142.27
# Episode 87 finished with reward: -89.16
# Moving average (last 50 episodes): -51.26 ± 142.25
# Episode 88 finished with reward: -96.37
# Moving average (last 50 episodes): -51.41 ± 142.30
# Episode 89 finished with reward: -93.59
# Moving average (last 50 episodes): -51.63 ± 142.35
# Episode 90 finished with reward: -34.10
# Moving average (last 50 episodes): -51.14 ± 142.37
# Episode 91 finished with reward: -53.20
# Moving average (last 50 episodes): -49.69 ± 141.97
# Episode 92 finished with reward: 194.74
# Moving average (last 50 episodes): -43.98 ± 145.89
# Episode 93 finished with reward: -112.06
# Moving average (last 50 episodes): -44.17 ± 145.97
# Episode 94 finished with reward: -106.86
# Moving average (last 50 episodes): -44.06 ± 145.93
# Episode 95 finished with reward: -63.85
# Moving average (last 50 episodes): -43.55 ± 145.81
# Episode 96 finished with reward: 71.09
# Moving average (last 50 episodes): -40.57 ± 146.60
# Episode 97 finished with reward: -91.97
# Moving average (last 50 episodes): -39.59 ± 146.09
# Episode 98 finished with reward: -104.22
# Moving average (last 50 episodes): -39.76 ± 146.16
# Episode 99 finished with reward: -99.10
# Moving average (last 50 episodes): -51.97 ± 123.31
# Episode 100 finished with reward: -69.48
# Moving average (last 50 episodes): -54.74 ± 122.11
# Episode 101 finished with reward: 336.79
# Moving average (last 50 episodes): -45.71 ± 133.51
# Episode 102 finished with reward: -102.65
# Moving average (last 50 episodes): -46.10 ± 133.65
# Episode 103 finished with reward: 604.19
# Moving average (last 50 episodes): -31.80 ± 161.34
# Episode 104 finished with reward: -123.85
# Moving average (last 50 episodes): -32.14 ± 161.51
# Episode 105 finished with reward: -116.04
# Moving average (last 50 episodes): -32.28 ± 161.58
# Episode 106 finished with reward: -28.66
# Moving average (last 50 episodes): -30.42 ± 161.08
# Episode 107 finished with reward: -86.03
# Moving average (last 50 episodes): -31.25 ± 161.26
# Episode 108 finished with reward: -88.96
# Moving average (last 50 episodes): -30.97 ± 161.15
# Episode 109 finished with reward: -57.05
# Moving average (last 50 episodes): -30.09 ± 160.88
# Episode 110 finished with reward: -69.23
# Moving average (last 50 episodes): -29.82 ± 160.80
# Episode 111 finished with reward: -103.92
# Moving average (last 50 episodes): -29.68 ± 160.74
# Episode 112 finished with reward: -100.18
# Moving average (last 50 episodes): -29.43 ± 160.62
# Episode 113 finished with reward: 476.67
# Moving average (last 50 episodes): -17.82 ± 175.15
# Episode 114 finished with reward: 75.63
# Moving average (last 50 episodes): -14.05 ± 175.08
# Episode 115 finished with reward: -75.07
# Moving average (last 50 episodes): -13.48 ± 174.84
# Episode 116 finished with reward: -75.41
# Moving average (last 50 episodes): -14.56 ± 175.05
# Episode 117 finished with reward: 871.22
# Moving average (last 50 episodes): 4.92 ± 214.01
# Episode 118 finished with reward: -118.45
# Moving average (last 50 episodes): 4.74 ± 214.11
# Episode 119 finished with reward: -78.43
# Moving average (last 50 episodes): 5.01 ± 214.00
# Episode 120 finished with reward: -88.12
# Moving average (last 50 episodes): -1.85 ± 211.36
# Episode 121 finished with reward: -101.02
# Moving average (last 50 episodes): -13.42 ± 200.35
# Episode 122 finished with reward: 187.27
# Moving average (last 50 episodes): -7.21 ± 201.66
# Episode 123 finished with reward: -58.32
# Moving average (last 50 episodes): -7.12 ± 201.63
# Episode 124 finished with reward: -120.48
# Moving average (last 50 episodes): -7.94 ± 202.01
# Episode 125 finished with reward: -73.16
# Moving average (last 50 episodes): -8.08 ± 202.05
# Episode 126 finished with reward: -95.40
# Moving average (last 50 episodes): -7.72 ± 201.88
# Episode 127 finished with reward: -73.58
# Moving average (last 50 episodes): -7.80 ± 201.91
# Episode 128 finished with reward: -75.93
# Moving average (last 50 episodes): -8.32 ± 202.05
# Episode 129 finished with reward: -83.36
# Moving average (last 50 episodes): -8.19 ± 202.00
# Episode 130 finished with reward: -42.19
# Moving average (last 50 episodes): -6.68 ± 201.45
# Episode 131 finished with reward: -37.13
# Moving average (last 50 episodes): -5.03 ± 200.86
# Episode 132 finished with reward: -89.73
# Moving average (last 50 episodes): -4.98 ± 200.84
# Episode 133 finished with reward: -95.08
# Moving average (last 50 episodes): -5.18 ± 200.92
# Episode 134 finished with reward: -69.80
# Moving average (last 50 episodes): -4.88 ± 200.81
# Episode 135 finished with reward: -58.43
# Moving average (last 50 episodes): -3.78 ± 200.36
# Episode 136 finished with reward: -68.39
# Moving average (last 50 episodes): -13.01 ± 192.33
# Episode 137 finished with reward: -18.83
# Moving average (last 50 episodes): -11.60 ± 192.03
# Episode 138 finished with reward: -105.40
# Moving average (last 50 episodes): -11.78 ± 192.11
# Episode 139 finished with reward: -118.65
# Moving average (last 50 episodes): -12.28 ± 192.36
# Episode 140 finished with reward: -42.88
# Moving average (last 50 episodes): -12.46 ± 192.38
# Episode 141 finished with reward: -87.51
# Moving average (last 50 episodes): -13.15 ± 192.59
# Episode 142 finished with reward: -73.48
# Moving average (last 50 episodes): -18.51 ± 190.44
# Episode 143 finished with reward: -126.30
# Moving average (last 50 episodes): -18.80 ± 190.59
# Episode 144 finished with reward: 43.57
# Moving average (last 50 episodes): -15.79 ± 190.37
# Episode 145 finished with reward: -61.13
# Moving average (last 50 episodes): -15.73 ± 190.35
# Episode 146 finished with reward: -75.00
# Moving average (last 50 episodes): -18.65 ± 190.12
# Episode 147 finished with reward: -86.67
# Moving average (last 50 episodes): -18.55 ± 190.08
# Episode 148 finished with reward: -128.85
# Moving average (last 50 episodes): -19.04 ± 190.33
# Episode 149 finished with reward: -98.35
# Moving average (last 50 episodes): -19.03 ± 190.33
# Episode 150 finished with reward: -115.06
# Moving average (last 50 episodes): -19.94 ± 190.68
# Episode 151 finished with reward: -47.53
# Moving average (last 50 episodes): -27.62 ± 183.76
# Episode 152 finished with reward: -101.93
# Moving average (last 50 episodes): -27.61 ± 183.76
# Episode 153 finished with reward: -116.48
# Moving average (last 50 episodes): -42.02 ± 160.41
# Episode 154 finished with reward: -110.30
# Moving average (last 50 episodes): -41.75 ± 160.29
# Episode 155 finished with reward: 206.34
# Moving average (last 50 episodes): -35.30 ± 163.62
# Episode 156 finished with reward: -101.30
# Moving average (last 50 episodes): -36.76 ± 163.88
# Episode 157 finished with reward: -87.56
# Moving average (last 50 episodes): -36.79 ± 163.89
# Episode 158 finished with reward: 300.68
# Moving average (last 50 episodes): -28.99 ± 170.35
# Episode 159 finished with reward: -108.95
# Moving average (last 50 episodes): -30.03 ± 170.68
# Episode 160 finished with reward: 314.10
# Moving average (last 50 episodes): -22.37 ± 177.23
# Episode 161 finished with reward: -141.73
# Moving average (last 50 episodes): -23.12 ± 177.66
# Episode 162 finished with reward: -24.52
# Moving average (last 50 episodes): -21.61 ± 177.32
# Episode 163 finished with reward: -111.61
# Moving average (last 50 episodes): -33.37 ± 162.79
# Episode 164 finished with reward: -79.45
# Moving average (last 50 episodes): -36.48 ± 162.16
# Episode 165 finished with reward: -133.58
# Moving average (last 50 episodes): -37.65 ± 162.64
# Episode 166 finished with reward: 463.72
# Moving average (last 50 episodes): -26.86 ± 177.02
# Episode 167 finished with reward: -11.01
# Moving average (last 50 episodes): -44.51 ± 122.05
# Episode 168 finished with reward: -77.61
# Moving average (last 50 episodes): -43.69 ± 121.69
# Episode 169 finished with reward: -124.00
# Moving average (last 50 episodes): -44.60 ± 122.12
# Episode 170 finished with reward: -111.81
# Moving average (last 50 episodes): -45.08 ± 122.33
# Episode 171 finished with reward: 17.10
# Moving average (last 50 episodes): -42.71 ± 122.37
# Episode 172 finished with reward: -128.68
# Moving average (last 50 episodes): -49.03 ± 118.42
# Episode 173 finished with reward: -87.27
# Moving average (last 50 episodes): -49.61 ± 118.54
# Episode 174 finished with reward: -95.90
# Moving average (last 50 episodes): -49.12 ± 118.29
# Episode 175 finished with reward: -124.54
# Moving average (last 50 episodes): -50.15 ± 118.72
# Episode 176 finished with reward: -54.33
# Moving average (last 50 episodes): -49.33 ± 118.55
# Episode 177 finished with reward: 97.73
# Moving average (last 50 episodes): -45.90 ± 120.26
# Episode 178 finished with reward: -98.40
# Moving average (last 50 episodes): -46.35 ± 120.41
# Episode 179 finished with reward: 291.25
# Moving average (last 50 episodes): -38.86 ± 129.21
# Episode 180 finished with reward: -100.66
# Moving average (last 50 episodes): -40.03 ± 129.50
# Episode 181 finished with reward: -116.32
# Moving average (last 50 episodes): -41.61 ± 129.94
# Episode 182 finished with reward: -52.17
# Moving average (last 50 episodes): -40.86 ± 129.77
# Episode 183 finished with reward: -43.14
# Moving average (last 50 episodes): -39.82 ± 129.54
# Episode 184 finished with reward: -73.63
# Moving average (last 50 episodes): -39.90 ± 129.55
# Episode 185 finished with reward: -114.78
# Moving average (last 50 episodes): -41.02 ± 129.96
# Episode 186 finished with reward: -85.35
# Moving average (last 50 episodes): -41.36 ± 130.05
# Episode 187 finished with reward: -78.95
# Moving average (last 50 episodes): -42.57 ± 130.11
# Episode 188 finished with reward: -115.72
# Moving average (last 50 episodes): -42.77 ± 130.22
# Episode 189 finished with reward: -63.74
# Moving average (last 50 episodes): -41.67 ± 129.81
# Episode 190 finished with reward: -132.07
# Moving average (last 50 episodes): -43.46 ± 130.42
# Episode 191 finished with reward: -66.04
# Moving average (last 50 episodes): -43.03 ± 130.31
# Episode 192 finished with reward: -122.14
# Moving average (last 50 episodes): -44.00 ± 130.72
# Episode 193 finished with reward: -91.96
# Moving average (last 50 episodes): -43.31 ± 130.37
# Episode 194 finished with reward: -113.20
# Moving average (last 50 episodes): -46.45 ± 130.13
# Episode 195 finished with reward: -75.09
# Moving average (last 50 episodes): -46.73 ± 130.18
# Episode 196 finished with reward: 244.72
# Moving average (last 50 episodes): -40.34 ± 136.34
# Episode 197 finished with reward: -123.15
# Moving average (last 50 episodes): -41.06 ± 136.68
# Episode 198 finished with reward: 273.16
# Moving average (last 50 episodes): -33.02 ± 142.96
# Episode 199 finished with reward: -85.46
# Moving average (last 50 episodes): -32.77 ± 142.85
# Episode 200 finished with reward: -102.84
# Moving average (last 50 episodes): -32.52 ± 142.72
# Episode 201 finished with reward: 258.21
# Moving average (last 50 episodes): -26.41 ± 148.39
# Episode 202 finished with reward: 21.88
# Moving average (last 50 episodes): -23.93 ± 148.14
# Episode 203 finished with reward: -83.49
# Moving average (last 50 episodes): -23.27 ± 147.80
# Episode 204 finished with reward: -60.07
# Moving average (last 50 episodes): -22.27 ± 147.37
# Episode 205 finished with reward: -23.75
# Moving average (last 50 episodes): -26.87 ± 143.71
# Episode 206 finished with reward: 114.29
# Moving average (last 50 episodes): -22.56 ± 144.64
# Episode 207 finished with reward: -120.37
# Moving average (last 50 episodes): -23.21 ± 145.01
# Episode 208 finished with reward: -1.14
# Moving average (last 50 episodes): -29.25 ± 137.49
# Episode 209 finished with reward: 67.24
# Moving average (last 50 episodes): -25.73 ± 137.66
# Episode 210 finished with reward: -120.22
# Moving average (last 50 episodes): -34.41 ± 129.40
# Episode 211 finished with reward: -76.17
# Moving average (last 50 episodes): -33.10 ± 128.63
# Episode 212 finished with reward: -119.92
# Moving average (last 50 episodes): -35.01 ± 129.20
# Episode 213 finished with reward: -75.87
# Moving average (last 50 episodes): -34.29 ± 128.87
# Episode 214 finished with reward: -97.12
# Moving average (last 50 episodes): -34.65 ± 129.02
# Episode 215 finished with reward: 23.86
# Moving average (last 50 episodes): -31.50 ± 128.48
# Episode 216 finished with reward: -109.88
# Moving average (last 50 episodes): -42.97 ± 107.68
# Episode 217 finished with reward: -62.14
# Moving average (last 50 episodes): -43.99 ± 107.61
# Episode 218 finished with reward: -59.47
# Moving average (last 50 episodes): -43.63 ± 107.53
# Episode 219 finished with reward: -73.77
# Moving average (last 50 episodes): -42.63 ± 107.01
# Episode 220 finished with reward: -69.95
# Moving average (last 50 episodes): -41.79 ± 106.62
# Episode 221 finished with reward: -67.12
# Moving average (last 50 episodes): -43.47 ± 106.35
# Episode 222 finished with reward: -37.16
# Moving average (last 50 episodes): -41.64 ± 105.65
# Episode 223 finished with reward: -119.75
# Moving average (last 50 episodes): -42.29 ± 106.03
# Episode 224 finished with reward: -91.78
# Moving average (last 50 episodes): -42.21 ± 105.99
# Episode 225 finished with reward: -27.62
# Moving average (last 50 episodes): -40.27 ± 105.35
# Episode 226 finished with reward: -55.76
# Moving average (last 50 episodes): -40.30 ± 105.35
# Episode 227 finished with reward: 458.48
# Moving average (last 50 episodes): -33.08 ± 125.07
# Episode 228 finished with reward: -82.08
# Moving average (last 50 episodes): -32.76 ± 124.92
# Episode 229 finished with reward: -99.36
# Moving average (last 50 episodes): -40.57 ± 116.33
# Episode 230 finished with reward: -38.90
# Moving average (last 50 episodes): -39.34 ± 116.01
# Episode 231 finished with reward: 153.38
# Moving average (last 50 episodes): -33.94 ± 118.55
# Episode 232 finished with reward: 618.31
# Moving average (last 50 episodes): -20.53 ± 149.59
# Episode 233 finished with reward: -102.55
# Moving average (last 50 episodes): -21.72 ± 150.00
# Episode 234 finished with reward: -83.05
# Moving average (last 50 episodes): -21.91 ± 150.07
# Episode 235 finished with reward: -114.71
# Moving average (last 50 episodes): -21.91 ± 150.07
# Episode 236 finished with reward: -84.25
# Moving average (last 50 episodes): -21.88 ± 150.06
# Episode 237 finished with reward: -82.23
# Moving average (last 50 episodes): -21.95 ± 150.08
# Episode 238 finished with reward: -94.65
# Moving average (last 50 episodes): -21.53 ± 149.85
# Episode 239 finished with reward: -134.77
# Moving average (last 50 episodes): -22.95 ± 150.58
# Episode 240 finished with reward: -101.80
# Moving average (last 50 episodes): -22.34 ± 150.20
# Episode 241 finished with reward: -95.85
# Moving average (last 50 episodes): -22.94 ± 150.43
# Episode 242 finished with reward: -49.50
# Moving average (last 50 episodes): -21.49 ± 149.81
# Episode 243 finished with reward: -86.00
# Moving average (last 50 episodes): -21.37 ± 149.76
# Episode 244 finished with reward: 449.22
# Moving average (last 50 episodes): -10.12 ± 162.98
# Episode 245 finished with reward: 505.10
# Moving average (last 50 episodes): 1.48 ± 177.91
# Episode 246 finished with reward: -92.48
# Moving average (last 50 episodes): -5.26 ± 174.93
# Episode 247 finished with reward: -4.45
# Moving average (last 50 episodes): -2.89 ± 174.11
# Episode 248 finished with reward: -66.21
# Moving average (last 50 episodes): -9.67 ± 169.78
# Episode 249 finished with reward: -61.48
# Moving average (last 50 episodes): -9.19 ± 169.60
# Episode 250 finished with reward: -72.93
# Moving average (last 50 episodes): -8.60 ± 169.32
# Episode 251 finished with reward: -85.45
# Moving average (last 50 episodes): -15.47 ± 165.28
# Episode 252 finished with reward: -80.29
# Moving average (last 50 episodes): -17.51 ± 165.44
# Episode 253 finished with reward: 580.71
# Moving average (last 50 episodes): -4.23 ± 185.10
# Episode 254 finished with reward: -69.25
# Moving average (last 50 episodes): -4.41 ± 185.16
# Episode 255 finished with reward: -82.84
# Moving average (last 50 episodes): -5.59 ± 185.47
# Episode 256 finished with reward: -113.88
# Moving average (last 50 episodes): -10.16 ± 185.27
# Episode 257 finished with reward: -86.48
# Moving average (last 50 episodes): -9.48 ± 184.93
# Episode 258 finished with reward: -83.75
# Moving average (last 50 episodes): -11.13 ± 185.22
# Episode 259 finished with reward: -57.13
# Moving average (last 50 episodes): -13.62 ± 184.98
# Episode 260 finished with reward: -52.16
# Moving average (last 50 episodes): -12.26 ± 184.44
# Episode 261 finished with reward: -104.04
# Moving average (last 50 episodes): -12.82 ± 184.68
# Episode 262 finished with reward: -61.38
# Moving average (last 50 episodes): -11.64 ± 184.18
# Episode 263 finished with reward: -84.55
# Moving average (last 50 episodes): -11.82 ± 184.24
# Episode 264 finished with reward: -108.84
# Moving average (last 50 episodes): -12.05 ± 184.36
# Episode 265 finished with reward: -119.57
# Moving average (last 50 episodes): -14.92 ± 184.89
# Episode 266 finished with reward: -99.84
# Moving average (last 50 episodes): -14.72 ± 184.79
# Episode 267 finished with reward: -94.15
# Moving average (last 50 episodes): -15.36 ± 185.01
# Episode 268 finished with reward: -78.19
# Moving average (last 50 episodes): -15.74 ± 185.12
# Episode 269 finished with reward: -98.83
# Moving average (last 50 episodes): -16.24 ± 185.31
# Episode 270 finished with reward: -16.29
# Moving average (last 50 episodes): -15.16 ± 185.15
# Episode 271 finished with reward: -102.75
# Moving average (last 50 episodes): -15.88 ± 185.42
# Episode 272 finished with reward: -130.38
# Moving average (last 50 episodes): -17.74 ± 186.09
# Episode 273 finished with reward: -113.46
# Moving average (last 50 episodes): -17.61 ± 186.02
# Episode 274 finished with reward: -200.01
# Moving average (last 50 episodes): -19.78 ± 187.50
# Episode 275 finished with reward: 663.17
# Moving average (last 50 episodes): -5.96 ± 210.46
# Episode 276 finished with reward: -34.05
# Moving average (last 50 episodes): -5.53 ± 210.38
# Episode 277 finished with reward: -70.94
# Moving average (last 50 episodes): -16.12 ± 199.81
# Episode 278 finished with reward: -106.44
# Moving average (last 50 episodes): -16.60 ± 200.00
# Episode 279 finished with reward: -22.49
# Moving average (last 50 episodes): -15.07 ± 199.66
# Episode 280 finished with reward: -64.47
# Moving average (last 50 episodes): -15.58 ± 199.75
# Episode 281 finished with reward: 92.99
# Moving average (last 50 episodes): -16.79 ± 198.90
# Episode 282 finished with reward: -61.50
# Moving average (last 50 episodes): -30.38 ± 177.06
# Episode 283 finished with reward: -131.72
# Moving average (last 50 episodes): -30.97 ± 177.35
# Episode 284 finished with reward: -87.71
# Moving average (last 50 episodes): -31.06 ± 177.38
# Episode 285 finished with reward: -121.09
# Moving average (last 50 episodes): -31.19 ± 177.44
# Episode 286 finished with reward: -74.05
# Moving average (last 50 episodes): -30.98 ± 177.38
# Episode 287 finished with reward: -70.97
# Moving average (last 50 episodes): -30.76 ± 177.32
# Episode 288 finished with reward: -97.89
# Moving average (last 50 episodes): -30.82 ± 177.35
# Episode 289 finished with reward: -105.41
# Moving average (last 50 episodes): -30.24 ± 177.05
# Episode 290 finished with reward: 13.89
# Moving average (last 50 episodes): -27.92 ± 176.86
# Episode 291 finished with reward: -97.54
# Moving average (last 50 episodes): -27.96 ± 176.87
# Episode 292 finished with reward: -53.69
# Moving average (last 50 episodes): -28.04 ± 176.88
# Episode 293 finished with reward: -89.05
# Moving average (last 50 episodes): -28.10 ± 176.90
# Episode 294 finished with reward: 84.06
# Moving average (last 50 episodes): -35.40 ± 164.12
# Episode 295 finished with reward: -110.53
# Moving average (last 50 episodes): -47.72 ± 145.10
# Episode 296 finished with reward: -78.79
# Moving average (last 50 episodes): -47.44 ± 145.03
# Episode 297 finished with reward: -81.55
# Moving average (last 50 episodes): -48.98 ± 144.97
# Episode 298 finished with reward: -105.29
# Moving average (last 50 episodes): -49.77 ± 145.17
# Episode 299 finished with reward: -130.84
# Moving average (last 50 episodes): -51.15 ± 145.61
# Episode 300 finished with reward: -88.98
# Moving average (last 50 episodes): -51.47 ± 145.67
# Episode 301 finished with reward: -58.01
# Moving average (last 50 episodes): -50.92 ± 145.59
# Episode 302 finished with reward: -72.12
# Moving average (last 50 episodes): -50.76 ± 145.57
# Episode 303 finished with reward: -60.49
# Moving average (last 50 episodes): -63.59 ± 114.24
# Episode 304 finished with reward: -77.26
# Moving average (last 50 episodes): -63.75 ± 114.26
# Episode 305 finished with reward: -34.08
# Moving average (last 50 episodes): -62.77 ± 114.30
# Episode 306 finished with reward: -32.57
# Moving average (last 50 episodes): -61.14 ± 114.14
# Episode 307 finished with reward: -47.21
# Moving average (last 50 episodes): -60.36 ± 114.10
# Episode 308 finished with reward: -15.43
# Moving average (last 50 episodes): -58.99 ± 114.22
# Episode 309 finished with reward: -88.46
# Moving average (last 50 episodes): -59.62 ± 114.29
# Episode 310 finished with reward: -109.25
# Moving average (last 50 episodes): -60.76 ± 114.50
# Episode 311 finished with reward: -49.54
# Moving average (last 50 episodes): -59.67 ± 114.34
# Episode 312 finished with reward: -70.37
# Moving average (last 50 episodes): -59.85 ± 114.35
# Episode 313 finished with reward: -77.00
# Moving average (last 50 episodes): -59.70 ± 114.32
# Episode 314 finished with reward: -19.71
# Moving average (last 50 episodes): -57.92 ± 114.23
# Episode 315 finished with reward: -131.88
# Moving average (last 50 episodes): -58.16 ± 114.38
# Episode 316 finished with reward: -58.53
# Moving average (last 50 episodes): -57.34 ± 114.22
# Episode 317 finished with reward: -116.28
# Moving average (last 50 episodes): -57.78 ± 114.41
# Episode 318 finished with reward: -95.45
# Moving average (last 50 episodes): -58.12 ± 114.50
# Episode 319 finished with reward: -114.10
# Moving average (last 50 episodes): -58.43 ± 114.62
# Episode 320 finished with reward: -85.04
# Moving average (last 50 episodes): -59.81 ± 114.52
# Episode 321 finished with reward: -126.43
# Moving average (last 50 episodes): -60.28 ± 114.75
# Episode 322 finished with reward: -108.28
# Moving average (last 50 episodes): -59.84 ± 114.52
# Episode 323 finished with reward: -96.63
# Moving average (last 50 episodes): -59.50 ± 114.39
# Episode 324 finished with reward: -81.53
# Moving average (last 50 episodes): -57.13 ± 112.67
# Episode 325 finished with reward: 217.56
# Moving average (last 50 episodes): -66.04 ± 61.21
# Episode 326 finished with reward: -98.76
# Moving average (last 50 episodes): -67.34 ± 61.20
# Episode 327 finished with reward: -6.29
# Moving average (last 50 episodes): -66.04 ± 61.79
# Episode 328 finished with reward: -56.63
# Moving average (last 50 episodes): -65.05 ± 61.53
# Episode 329 finished with reward: -71.40
# Moving average (last 50 episodes): -66.03 ± 61.24
# Episode 330 finished with reward: -53.10
# Moving average (last 50 episodes): -65.80 ± 61.27
# Episode 331 finished with reward: 22.65
# Moving average (last 50 episodes): -67.21 ± 58.34
# Episode 332 finished with reward: -80.21
# Moving average (last 50 episodes): -67.58 ± 58.36
# Episode 333 finished with reward: -115.52
# Moving average (last 50 episodes): -67.26 ± 58.05
# Episode 334 finished with reward: -99.22
# Moving average (last 50 episodes): -67.49 ± 58.15
# Episode 335 finished with reward: -128.42
# Moving average (last 50 episodes): -67.63 ± 58.30
# Episode 336 finished with reward: -79.64
# Moving average (last 50 episodes): -67.74 ± 58.31
# Episode 337 finished with reward: -73.83
# Moving average (last 50 episodes): -67.80 ± 58.32
# Episode 338 finished with reward: -71.97
# Moving average (last 50 episodes): -67.28 ± 58.16
# Episode 339 finished with reward: -23.62
# Moving average (last 50 episodes): -65.65 ± 58.22
# Episode 340 finished with reward: -118.60
# Moving average (last 50 episodes): -68.30 ± 57.55
# Episode 341 finished with reward: -144.60
# Moving average (last 50 episodes): -69.24 ± 58.40
# Episode 342 finished with reward: -43.92
# Moving average (last 50 episodes): -69.04 ± 58.47
# Episode 343 finished with reward: -101.58
# Moving average (last 50 episodes): -69.29 ± 58.58
# Episode 344 finished with reward: -36.07
# Moving average (last 50 episodes): -71.70 ± 54.57
# Episode 345 finished with reward: -129.82
# Moving average (last 50 episodes): -72.08 ± 54.91
# Episode 346 finished with reward: -111.27
# Moving average (last 50 episodes): -72.73 ± 55.17
# Episode 347 finished with reward: -154.33
# Moving average (last 50 episodes): -74.19 ± 56.33
# Episode 348 finished with reward: -96.49
# Moving average (last 50 episodes): -74.01 ± 56.25
# Episode 349 finished with reward: -85.64
# Moving average (last 50 episodes): -73.11 ± 55.69
# Episode 350 finished with reward: -135.12
# Moving average (last 50 episodes): -74.03 ± 56.32
# Episode 351 finished with reward: -85.54
# Moving average (last 50 episodes): -74.58 ± 56.30
# Episode 352 finished with reward: -89.61
# Moving average (last 50 episodes): -74.93 ± 56.34
# Episode 353 finished with reward: -95.56
# Moving average (last 50 episodes): -75.63 ± 56.37
# Episode 354 finished with reward: -74.55
# Moving average (last 50 episodes): -75.58 ± 56.37
# Episode 355 finished with reward: -76.73
# Moving average (last 50 episodes): -76.43 ± 56.06
# Episode 356 finished with reward: -26.25
# Moving average (last 50 episodes): -76.30 ± 56.17
# Episode 357 finished with reward: 210.18
# Moving average (last 50 episodes): -71.16 ± 68.94
# Episode 358 finished with reward: -44.92
# Moving average (last 50 episodes): -71.75 ± 68.58
# Episode 359 finished with reward: -20.23
# Moving average (last 50 episodes): -70.38 ± 68.92
# Episode 360 finished with reward: 566.29
# Moving average (last 50 episodes): -56.87 ± 112.44
# Episode 361 finished with reward: -90.16
# Moving average (last 50 episodes): -57.68 ± 112.53
# Episode 362 finished with reward: -101.65
# Moving average (last 50 episodes): -58.31 ± 112.69
# Episode 363 finished with reward: -66.96
# Moving average (last 50 episodes): -58.11 ± 112.67
# Episode 364 finished with reward: -60.52
# Moving average (last 50 episodes): -58.92 ± 112.53
# Episode 365 finished with reward: -49.39
# Moving average (last 50 episodes): -57.27 ± 112.05
# Episode 366 finished with reward: -97.76
# Moving average (last 50 episodes): -58.06 ± 112.20
# Episode 367 finished with reward: -122.47
# Moving average (last 50 episodes): -58.18 ± 112.27
# Episode 368 finished with reward: -106.29
# Moving average (last 50 episodes): -58.40 ± 112.35
# Episode 369 finished with reward: 218.33
# Moving average (last 50 episodes): -51.75 ± 118.52
# Episode 370 finished with reward: -72.89
# Moving average (last 50 episodes): -51.51 ± 118.47
# Episode 371 finished with reward: -105.18
# Moving average (last 50 episodes): -51.08 ± 118.23
# Episode 372 finished with reward: -71.53
# Moving average (last 50 episodes): -50.35 ± 117.99
# Episode 373 finished with reward: 392.41
# Moving average (last 50 episodes): -40.57 ± 133.06
# Episode 374 finished with reward: -108.04
# Moving average (last 50 episodes): -41.10 ± 133.27
# Episode 375 finished with reward: -223.89
# Moving average (last 50 episodes): -49.93 ± 130.43
# Episode 376 finished with reward: -58.44
# Moving average (last 50 episodes): -49.12 ± 130.25
# Episode 377 finished with reward: -122.12
# Moving average (last 50 episodes): -51.44 ± 130.50
# Episode 378 finished with reward: -95.08
# Moving average (last 50 episodes): -52.21 ± 130.64
# Episode 379 finished with reward: -76.59
# Moving average (last 50 episodes): -52.31 ± 130.66
# Episode 380 finished with reward: 35.25
# Moving average (last 50 episodes): -50.54 ± 131.23
# Episode 381 finished with reward: -142.65
# Moving average (last 50 episodes): -53.85 ± 131.43
# Episode 382 finished with reward: -69.60
# Moving average (last 50 episodes): -53.64 ± 131.40
# Episode 383 finished with reward: 16.37
# Moving average (last 50 episodes): -51.00 ± 131.45
# Episode 384 finished with reward: -117.25
# Moving average (last 50 episodes): -51.36 ± 131.61
# Episode 385 finished with reward: -102.84
# Moving average (last 50 episodes): -50.85 ± 131.36
# Episode 386 finished with reward: -132.16
# Moving average (last 50 episodes): -51.90 ± 131.79
# Episode 387 finished with reward: -90.71
# Moving average (last 50 episodes): -52.24 ± 131.87
# Episode 388 finished with reward: -178.65
# Moving average (last 50 episodes): -54.37 ± 133.03
# Episode 389 finished with reward: -104.13
# Moving average (last 50 episodes): -55.98 ± 133.13
# Episode 390 finished with reward: -197.82
# Moving average (last 50 episodes): -57.56 ± 134.34
# Episode 391 finished with reward: -168.45
# Moving average (last 50 episodes): -58.04 ± 134.69
# Episode 392 finished with reward: -97.35
# Moving average (last 50 episodes): -59.11 ± 134.78
# Episode 393 finished with reward: -69.69
# Moving average (last 50 episodes): -58.47 ± 134.66
# Episode 394 finished with reward: -104.14
# Moving average (last 50 episodes): -59.83 ± 134.77
# Episode 395 finished with reward: -33.38
# Moving average (last 50 episodes): -57.90 ± 134.44
# Episode 396 finished with reward: -45.69
# Moving average (last 50 episodes): -56.59 ± 134.23
# Episode 397 finished with reward: -101.18
# Moving average (last 50 episodes): -55.53 ± 133.66
# Episode 398 finished with reward: -64.53
# Moving average (last 50 episodes): -54.89 ± 133.54
# Episode 399 finished with reward: -163.16
# Moving average (last 50 episodes): -56.44 ± 134.34
# Episode 400 finished with reward: -99.50
# Moving average (last 50 episodes): -55.73 ± 134.01
# Episode 401 finished with reward: 182.72
# Moving average (last 50 episodes): -50.36 ± 138.02
# Episode 402 finished with reward: -96.90
# Moving average (last 50 episodes): -50.51 ± 138.07
# Episode 403 finished with reward: -46.85
# Moving average (last 50 episodes): -49.53 ± 137.92
# Episode 404 finished with reward: 173.87
# Moving average (last 50 episodes): -44.57 ± 141.36
# Episode 405 finished with reward: -140.31
# Moving average (last 50 episodes): -45.84 ± 141.93
# Episode 406 finished with reward: 441.74
# Moving average (last 50 episodes): -36.48 ± 157.49
# Episode 407 finished with reward: -23.60
# Moving average (last 50 episodes): -41.15 ± 153.52
# Episode 408 finished with reward: -104.09
# Moving average (last 50 episodes): -42.34 ± 153.77
# Episode 409 finished with reward: -103.66
# Moving average (last 50 episodes): -44.01 ± 153.97
# Episode 410 finished with reward: -12.04
# Moving average (last 50 episodes): -55.57 ± 127.06
# Episode 411 finished with reward: -71.99
# Moving average (last 50 episodes): -55.21 ± 126.99
# Episode 412 finished with reward: -43.98
# Moving average (last 50 episodes): -54.05 ± 126.83
# Episode 413 finished with reward: -130.38
# Moving average (last 50 episodes): -55.32 ± 127.26
# Episode 414 finished with reward: -93.48
# Moving average (last 50 episodes): -55.98 ± 127.37
# Episode 415 finished with reward: -68.73
# Moving average (last 50 episodes): -56.37 ± 127.38
# Episode 416 finished with reward: -56.42
# Moving average (last 50 episodes): -55.54 ± 127.25
# Episode 417 finished with reward: -126.11
# Moving average (last 50 episodes): -55.62 ± 127.29
# Episode 418 finished with reward: -110.60
# Moving average (last 50 episodes): -55.70 ± 127.32
# Episode 419 finished with reward: -44.73
# Moving average (last 50 episodes): -60.96 ± 121.18
# Episode 420 finished with reward: 120.26
# Moving average (last 50 episodes): -57.10 ± 123.78
# Episode 421 finished with reward: -38.95
# Moving average (last 50 episodes): -55.78 ± 123.62
# Episode 422 finished with reward: -51.13
# Moving average (last 50 episodes): -55.37 ± 123.60
# Episode 423 finished with reward: -115.71
# Moving average (last 50 episodes): -65.53 ± 106.00
# Episode 424 finished with reward: -97.25
# Moving average (last 50 episodes): -65.31 ± 105.92
# Episode 425 finished with reward: -210.68
# Moving average (last 50 episodes): -65.05 ± 105.54
# Episode 426 finished with reward: -88.38
# Moving average (last 50 episodes): -65.65 ± 105.59
# Episode 427 finished with reward: -92.10
# Moving average (last 50 episodes): -65.05 ± 105.35
# Episode 428 finished with reward: -94.52
# Moving average (last 50 episodes): -65.04 ± 105.35
# Episode 429 finished with reward: -95.08
# Moving average (last 50 episodes): -65.41 ± 105.42
# Episode 430 finished with reward: 354.30
# Moving average (last 50 episodes): -59.03 ± 119.97
# Episode 431 finished with reward: -158.68
# Moving average (last 50 episodes): -59.35 ± 120.22
# Episode 432 finished with reward: -114.93
# Moving average (last 50 episodes): -60.25 ± 120.46
# Episode 433 finished with reward: -139.83
# Moving average (last 50 episodes): -63.38 ± 120.46
# Episode 434 finished with reward: -178.95
# Moving average (last 50 episodes): -64.61 ± 121.32
# Episode 435 finished with reward: -38.45
# Moving average (last 50 episodes): -63.32 ± 121.25
# Episode 436 finished with reward: -82.07
# Moving average (last 50 episodes): -62.32 ± 120.88
# Episode 437 finished with reward: -42.55
# Moving average (last 50 episodes): -61.36 ± 120.84
# Episode 438 finished with reward: -63.01
# Moving average (last 50 episodes): -59.05 ± 119.68
# Episode 439 finished with reward: -45.00
# Moving average (last 50 episodes): -57.86 ± 119.52
# Episode 440 finished with reward: -51.20
# Moving average (last 50 episodes): -54.93 ± 117.83
# Episode 441 finished with reward: -151.14
# Moving average (last 50 episodes): -54.58 ± 117.53
# Episode 442 finished with reward: -78.38
# Moving average (last 50 episodes): -54.20 ± 117.42
# Episode 443 finished with reward: -79.62
# Moving average (last 50 episodes): -54.40 ± 117.45
# Episode 444 finished with reward: -117.98
# Moving average (last 50 episodes): -54.68 ± 117.58
# Episode 445 finished with reward: -32.01
# Moving average (last 50 episodes): -54.65 ± 117.59
# Episode 446 finished with reward: 209.46
# Moving average (last 50 episodes): -49.55 ± 123.27
# Episode 447 finished with reward: -178.59
# Moving average (last 50 episodes): -51.10 ± 124.39
# Episode 448 finished with reward: -76.38
# Moving average (last 50 episodes): -51.33 ± 124.42
# Episode 449 finished with reward: -218.27
# Moving average (last 50 episodes): -52.44 ± 125.65
# Episode 450 finished with reward: -83.05
# Moving average (last 50 episodes): -52.11 ± 125.55
# Episode 451 finished with reward: -89.18
# Moving average (last 50 episodes): -57.55 ± 121.06
# Episode 452 finished with reward: -57.88
# Moving average (last 50 episodes): -56.77 ± 120.93
# Episode 453 finished with reward: -89.40
# Moving average (last 50 episodes): -57.62 ± 121.01
# Episode 454 finished with reward: -76.90
# Moving average (last 50 episodes): -62.63 ± 116.42
# Episode 455 finished with reward: -99.89
# Moving average (last 50 episodes): -61.82 ± 116.02
# Episode 456 finished with reward: -79.47
# Moving average (last 50 episodes): -72.25 ± 91.03
# Episode 457 finished with reward: -25.67
# Moving average (last 50 episodes): -72.29 ± 91.01
# Episode 458 finished with reward: -61.98
# Moving average (last 50 episodes): -71.45 ± 90.91
# Episode 459 finished with reward: -173.66
# Moving average (last 50 episodes): -72.85 ± 91.92
# Episode 460 finished with reward: -42.33
# Moving average (last 50 episodes): -73.45 ± 91.62
# Episode 461 finished with reward: -96.22
# Moving average (last 50 episodes): -73.94 ± 91.68
# Episode 462 finished with reward: -65.39
# Moving average (last 50 episodes): -74.37 ± 91.59
# Episode 463 finished with reward: -113.69
# Moving average (last 50 episodes): -74.03 ± 91.41
# Episode 464 finished with reward: -130.19
# Moving average (last 50 episodes): -74.77 ± 91.71
# Episode 465 finished with reward: -118.09
# Moving average (last 50 episodes): -75.75 ± 91.91
# Episode 466 finished with reward: 38.20
# Moving average (last 50 episodes): -73.86 ± 93.25
# Episode 467 finished with reward: -32.65
# Moving average (last 50 episodes): -71.99 ± 93.12
# Episode 468 finished with reward: -141.88
# Moving average (last 50 episodes): -72.62 ± 93.48
# Episode 469 finished with reward: -133.88
# Moving average (last 50 episodes): -74.40 ± 93.78
# Episode 470 finished with reward: -44.83
# Moving average (last 50 episodes): -77.70 ± 89.69
# Episode 471 finished with reward: -116.08
# Moving average (last 50 episodes): -79.24 ± 89.67
# Episode 472 finished with reward: -53.21
# Moving average (last 50 episodes): -79.29 ± 89.66
# Episode 473 finished with reward: -196.91
# Moving average (last 50 episodes): -80.91 ± 91.03
# Episode 474 finished with reward: -133.62
# Moving average (last 50 episodes): -81.64 ± 91.30
# Episode 475 finished with reward: -14.18
# Moving average (last 50 episodes): -77.71 ± 89.88
# Episode 476 finished with reward: -195.46
# Moving average (last 50 episodes): -79.85 ± 91.37
# Episode 477 finished with reward: -76.82
# Moving average (last 50 episodes): -79.54 ± 91.36
# Episode 478 finished with reward: -144.44
# Moving average (last 50 episodes): -80.54 ± 91.79
# Episode 479 finished with reward: -29.80
# Moving average (last 50 episodes): -79.24 ± 92.03
# Episode 480 finished with reward: -41.17
# Moving average (last 50 episodes): -87.15 ± 68.39
# Episode 481 finished with reward: -195.83
# Moving average (last 50 episodes): -87.89 ± 69.36
# Episode 482 finished with reward: -68.94
# Moving average (last 50 episodes): -86.97 ± 69.30
# Episode 483 finished with reward: -84.39
# Moving average (last 50 episodes): -85.86 ± 68.89
# Episode 484 finished with reward: -210.50
# Moving average (last 50 episodes): -86.49 ± 69.88
# Episode 485 finished with reward: -135.09
# Moving average (last 50 episodes): -88.42 ± 69.86
# Episode 486 finished with reward: -185.33
# Moving average (last 50 episodes): -90.49 ± 71.15
# Episode 487 finished with reward: -38.77
# Moving average (last 50 episodes): -90.41 ± 71.21
# Episode 488 finished with reward: -16.64
# Moving average (last 50 episodes): -89.49 ± 71.86
# Episode 489 finished with reward: -216.28
# Moving average (last 50 episodes): -92.91 ± 73.71
# Episode 490 finished with reward: -134.85
# Moving average (last 50 episodes): -94.59 ± 73.70
# Episode 491 finished with reward: -62.06
# Moving average (last 50 episodes): -92.80 ± 73.38
# Episode 492 finished with reward: -67.42
# Moving average (last 50 episodes): -92.58 ± 73.44
# Episode 493 finished with reward: -75.30
# Moving average (last 50 episodes): -92.50 ± 73.46
# Episode 494 finished with reward: -76.25
# Moving average (last 50 episodes): -91.66 ± 73.40
# Episode 495 finished with reward: -79.40
# Moving average (last 50 episodes): -92.61 ± 72.93
# Episode 496 finished with reward: -119.67
# Moving average (last 50 episodes): -99.19 ± 58.87
# Episode 497 finished with reward: -96.05
# Moving average (last 50 episodes): -97.54 ± 57.76
# Episode 498 finished with reward: -50.04
# Moving average (last 50 episodes): -97.02 ± 58.07
# Episode 499 finished with reward: -55.22
# Moving average (last 50 episodes): -93.76 ± 55.70
# Episode 500 finished with reward: -294.35
# Moving average (last 50 episodes): -97.98 ± 62.35
# Episode 501 finished with reward: -100.05
# Moving average (last 50 episodes): -98.20 ± 62.34
# Episode 502 finished with reward: -58.57
# Moving average (last 50 episodes): -98.21 ± 62.33
# Episode 503 finished with reward: -90.75
# Moving average (last 50 episodes): -98.24 ± 62.32
# Episode 504 finished with reward: -99.85
# Moving average (last 50 episodes): -98.70 ± 62.25
# Episode 505 finished with reward: -78.67
# Moving average (last 50 episodes): -98.27 ± 62.31
# Episode 506 finished with reward: -36.87
# Moving average (last 50 episodes): -97.42 ± 62.85
# Episode 507 finished with reward: -207.86
# Moving average (last 50 episodes): -101.07 ± 63.86
# Episode 508 finished with reward: -192.24
# Moving average (last 50 episodes): -103.67 ± 64.86
# Episode 509 finished with reward: -57.59
# Moving average (last 50 episodes): -101.35 ± 64.39
# Episode 510 finished with reward: -119.41
# Moving average (last 50 episodes): -102.89 ± 63.88
# Episode 511 finished with reward: -125.33
# Moving average (last 50 episodes): -103.47 ± 63.95
# Episode 512 finished with reward: -91.77
# Moving average (last 50 episodes): -104.00 ± 63.74
# Episode 513 finished with reward: -115.07
# Moving average (last 50 episodes): -104.03 ± 63.75
# Episode 514 finished with reward: -29.95
# Moving average (last 50 episodes): -102.02 ± 64.46
# Episode 515 finished with reward: -88.34
# Moving average (last 50 episodes): -101.43 ± 64.45
# Episode 516 finished with reward: -106.35
# Moving average (last 50 episodes): -104.32 ± 61.29
# Episode 517 finished with reward: -100.09
# Moving average (last 50 episodes): -105.67 ± 60.43
# Episode 518 finished with reward: -226.55
# Moving average (last 50 episodes): -107.36 ± 62.57
# Episode 519 finished with reward: -113.52
# Moving average (last 50 episodes): -106.95 ± 62.46
# Episode 520 finished with reward: -141.33
# Moving average (last 50 episodes): -108.88 ± 62.00
# Episode 521 finished with reward: -76.85
# Moving average (last 50 episodes): -108.10 ± 62.15
# Episode 522 finished with reward: -52.87
# Moving average (last 50 episodes): -108.09 ± 62.16
# Episode 523 finished with reward: -133.47
# ...
# Episode 8160 finished with reward: -28.26
# Moving average (last 50 episodes): -46.30 ± 34.60
# Episode 8161 finished with reward: 3.16
# Moving average (last 50 episodes): -46.84 ± 33.59
# Episode 8162 finished with reward: -87.25
# Moving average (last 50 episodes): -48.35 ± 33.68
# Episode 8163 finished with reward: -3.17
# Moving average (last 50 episodes): -47.15 ± 34.19
# Episode 8164 finished with reward: -68.75
# Moving average (last 50 episodes): -48.27 ± 33.96
# Episode 8165 finished with reward: -93.26
# Moving average (last 50 episodes): -50.34 ± 33.49
# Episode 8166 finished with reward: -85.88
# Moving average (last 50 episodes): -50.99 ± 33.86
# Episode 8167 finished with reward: -34.91
# Moving average (last 50 episodes): -50.37 ± 33.87
# Episode 8168 finished with reward: -67.49
# Moving average (last 50 episodes): -50.34 ± 33.85
# Episode 8169 finished with reward: -68.99
# Moving average (last 50 episodes): -51.81 ± 33.03
# Episode 8170 finished with reward: -58.09
# Moving average (last 50 episodes): -51.44 ± 32.85
# Episode 8171 finished with reward: -87.27
# Moving average (last 50 episodes): -52.36 ± 33.19
# Episode 8172 finished with reward: -76.52
# Moving average (last 50 episodes): -54.16 ± 32.00
# Episode 8173 finished with reward: -56.59
# Moving average (last 50 episodes): -54.34 ± 31.99
# Episode 8174 finished with reward: 28.38
# Moving average (last 50 episodes): -51.91 ± 33.53
# Episode 8175 finished with reward: -66.92
# Moving average (last 50 episodes): -52.01 ± 33.57
# Episode 8176 finished with reward: 10.17
# Moving average (last 50 episodes): -50.90 ± 34.67
# Episode 8177 finished with reward: -72.77
# Moving average (last 50 episodes): -51.76 ± 34.66
# Episode 8178 finished with reward: 9.81
# Moving average (last 50 episodes): -50.53 ± 35.72
# Episode 8179 finished with reward: -16.01
# Moving average (last 50 episodes): -51.31 ± 34.52
# Episode 8180 finished with reward: -88.40
# Moving average (last 50 episodes): -52.07 ± 34.91
# Episode 8181 finished with reward: 14.77
# Moving average (last 50 episodes): -49.85 ± 35.55
# Episode 8182 finished with reward: -74.96
# Moving average (last 50 episodes): -50.87 ± 35.53
# Episode 8183 finished with reward: -46.02
# Moving average (last 50 episodes): -50.34 ± 35.40
# Episode 8184 finished with reward: -16.40
# Moving average (last 50 episodes): -50.55 ± 35.16
# Episode 8185 finished with reward: -70.87
# Moving average (last 50 episodes): -50.43 ± 35.09
# Episode 8186 finished with reward: -63.18
# Moving average (last 50 episodes): -49.73 ± 34.46
# Episode 8187 finished with reward: -43.51
# Moving average (last 50 episodes): -50.49 ± 33.90
# Episode 8188 finished with reward: -59.27
# Moving average (last 50 episodes): -50.70 ± 33.92
# Episode 8189 finished with reward: -73.69
# Moving average (last 50 episodes): -50.76 ± 33.95
# Episode 8190 finished with reward: -9.43
# Moving average (last 50 episodes): -49.26 ± 34.09
# Episode 8191 finished with reward: -36.75
# Moving average (last 50 episodes): -47.99 ± 33.35
# Episode 8192 finished with reward: -84.88
# Moving average (last 50 episodes): -48.31 ± 33.62
# Episode 8193 finished with reward: -10.98
# Moving average (last 50 episodes): -46.47 ± 33.08
# Episode 8194 finished with reward: -89.04
# Moving average (last 50 episodes): -47.62 ± 33.54
# Episode 8195 finished with reward: -114.13
# Moving average (last 50 episodes): -48.56 ± 34.71
# Episode 8196 finished with reward: -19.93
# Moving average (last 50 episodes): -47.91 ± 34.93
# Episode 8197 finished with reward: -74.01
# Moving average (last 50 episodes): -48.28 ± 35.11
# Episode 8198 finished with reward: -84.07
# Moving average (last 50 episodes): -49.49 ± 35.28
# Episode 8199 finished with reward: -78.50
# Moving average (last 50 episodes): -50.54 ± 35.35
# Episode 8200 finished with reward: -71.42
# Moving average (last 50 episodes): -49.74 ± 34.40
# Episode 8201 finished with reward: -55.08
# Moving average (last 50 episodes): -49.67 ± 34.38
# Episode 8202 finished with reward: -60.40
# Moving average (last 50 episodes): -49.31 ± 34.17
# Episode 8203 finished with reward: -22.06
# Moving average (last 50 episodes): -48.80 ± 34.39
# Episode 8204 finished with reward: 16.91
# Moving average (last 50 episodes): -47.19 ± 35.52
# Episode 8205 finished with reward: 86.45
# Moving average (last 50 episodes): -44.39 ± 40.13
# Episode 8206 finished with reward: -50.82
# Moving average (last 50 episodes): -45.86 ± 38.97
# Episode 8207 finished with reward: -93.16
# Moving average (last 50 episodes): -47.10 ± 39.47
# Episode 8208 finished with reward: -51.34
# Moving average (last 50 episodes): -47.40 ± 39.44
# Episode 8209 finished with reward: 46.25
# Moving average (last 50 episodes): -45.97 ± 41.46
# Episode 8210 finished with reward: -72.78
# Moving average (last 50 episodes): -46.86 ± 41.55
# Episode 8211 finished with reward: 22.80
# Moving average (last 50 episodes): -46.47 ± 42.11
# Episode 8212 finished with reward: -71.72
# Moving average (last 50 episodes): -46.16 ± 41.87
# Episode 8213 finished with reward: -94.21
# Moving average (last 50 episodes): -47.98 ± 41.94
# Episode 8214 finished with reward: -103.97
# Moving average (last 50 episodes): -48.68 ± 42.57
# Episode 8215 finished with reward: -88.27
# Moving average (last 50 episodes): -48.58 ± 42.47
# Episode 8216 finished with reward: -14.54
# Moving average (last 50 episodes): -47.16 ± 42.39
# Episode 8217 finished with reward: -32.41
# Moving average (last 50 episodes): -47.11 ± 42.41
# Episode 8218 finished with reward: -67.90
# Moving average (last 50 episodes): -47.11 ± 42.41
# Episode 8219 finished with reward: 6.52
# Moving average (last 50 episodes): -45.60 ± 42.95
# Episode 8220 finished with reward: -46.03
# Moving average (last 50 episodes): -45.36 ± 42.91
# Episode 8221 finished with reward: -51.08
# Moving average (last 50 episodes): -44.64 ± 42.50
# Episode 8222 finished with reward: -63.03
# Moving average (last 50 episodes): -44.37 ± 42.34
# Episode 8223 finished with reward: -64.16
# Moving average (last 50 episodes): -44.52 ± 42.40
# Episode 8224 finished with reward: -11.57
# Moving average (last 50 episodes): -45.32 ± 41.38
# Episode 8225 finished with reward: -28.42
# Moving average (last 50 episodes): -44.55 ± 41.33
# Episode 8226 finished with reward: -34.82
# Moving average (last 50 episodes): -45.45 ± 40.61
# Episode 8227 finished with reward: -73.73
# Moving average (last 50 episodes): -45.47 ± 40.63
# Episode 8228 finished with reward: -17.93
# Moving average (last 50 episodes): -46.02 ± 40.05
# Episode 8229 finished with reward: 286.12
# Moving average (last 50 episodes): -39.98 ± 61.29
# Episode 8230 finished with reward: -49.51
# Moving average (last 50 episodes): -39.20 ± 60.91
# Episode 8231 finished with reward: -53.34
# Moving average (last 50 episodes): -40.57 ± 60.45
# Episode 8232 finished with reward: 41.88
# Moving average (last 50 episodes): -38.23 ± 61.33
# Episode 8233 finished with reward: -43.76
# Moving average (last 50 episodes): -38.18 ± 61.32
# Episode 8234 finished with reward: 3.58
# Moving average (last 50 episodes): -37.78 ± 61.53
# Episode 8235 finished with reward: -15.43
# Moving average (last 50 episodes): -36.68 ± 61.42
# Episode 8236 finished with reward: -45.71
# Moving average (last 50 episodes): -36.33 ± 61.32
# Episode 8237 finished with reward: 39.31
# Moving average (last 50 episodes): -34.67 ± 62.21
# Episode 8238 finished with reward: -66.07
# Moving average (last 50 episodes): -34.81 ± 62.28
# Episode 8239 finished with reward: -11.66
# Moving average (last 50 episodes): -33.57 ± 62.11
# Episode 8240 finished with reward: -91.77
# Moving average (last 50 episodes): -35.21 ± 62.53
# Episode 8241 finished with reward: 6.45
# Moving average (last 50 episodes): -34.35 ± 62.80
# Episode 8242 finished with reward: -49.54
# Moving average (last 50 episodes): -33.64 ± 62.43
# Episode 8243 finished with reward: -1.21
# Moving average (last 50 episodes): -33.45 ± 62.52
# Episode 8244 finished with reward: -17.75
# Moving average (last 50 episodes): -32.02 ± 62.04
# Episode 8245 finished with reward: -84.41
# Moving average (last 50 episodes): -31.43 ± 61.39
# Episode 8246 finished with reward: -70.16
# Moving average (last 50 episodes): -32.43 ± 61.61
# Episode 8247 finished with reward: -34.70
# Moving average (last 50 episodes): -31.64 ± 61.32
# Episode 8248 finished with reward: -7.91
# Moving average (last 50 episodes): -30.12 ± 60.94
# Episode 8249 finished with reward: -54.12
# Moving average (last 50 episodes): -29.63 ± 60.65
# Episode 8250 finished with reward: -58.88
# Moving average (last 50 episodes): -29.38 ± 60.50
# Episode 8251 finished with reward: -18.19
# Moving average (last 50 episodes): -28.64 ± 60.41
# Episode 8252 finished with reward: -75.12
# Moving average (last 50 episodes): -28.94 ± 60.60
# Episode 8253 finished with reward: -84.55
# Moving average (last 50 episodes): -30.19 ± 61.09
# Episode 8254 finished with reward: -54.30
# Moving average (last 50 episodes): -31.61 ± 60.80
# Episode 8255 finished with reward: -85.55
# Moving average (last 50 episodes): -35.05 ± 58.86
# Episode 8256 finished with reward: -57.47
# Moving average (last 50 episodes): -35.19 ± 58.90
# Episode 8257 finished with reward: -41.97
# Moving average (last 50 episodes): -34.16 ± 58.33
# Episode 8258 finished with reward: -87.38
# Moving average (last 50 episodes): -34.88 ± 58.76
# Episode 8259 finished with reward: -60.03
# Moving average (last 50 episodes): -37.01 ± 57.70
# Episode 8260 finished with reward: -9.24
# Moving average (last 50 episodes): -35.74 ± 57.60
# Episode 8261 finished with reward: -59.73
# Moving average (last 50 episodes): -37.39 ± 57.07
# Episode 8262 finished with reward: 13.80
# Moving average (last 50 episodes): -35.68 ± 57.30
# Episode 8263 finished with reward: -58.95
# Moving average (last 50 episodes): -34.97 ± 56.79
# Episode 8264 finished with reward: 27.75
# Moving average (last 50 episodes): -32.34 ± 56.58
# Episode 8265 finished with reward: -81.81
# Moving average (last 50 episodes): -32.21 ± 56.46
# Episode 8266 finished with reward: -68.60
# Moving average (last 50 episodes): -33.29 ± 56.63
# Episode 8267 finished with reward: -58.03
# Moving average (last 50 episodes): -33.80 ± 56.74
# Episode 8268 finished with reward: -53.44
# Moving average (last 50 episodes): -33.51 ± 56.60
# Episode 8269 finished with reward: -55.07
# Moving average (last 50 episodes): -34.74 ± 56.38
# Episode 8270 finished with reward: -75.02
# Moving average (last 50 episodes): -35.32 ± 56.65
# Episode 8271 finished with reward: -82.02
# Moving average (last 50 episodes): -35.94 ± 56.98
# Episode 8272 finished with reward: -61.42
# Moving average (last 50 episodes): -35.91 ± 56.97
# Episode 8273 finished with reward: -49.47
# Moving average (last 50 episodes): -35.62 ± 56.86
# Episode 8274 finished with reward: -89.14
# Moving average (last 50 episodes): -37.17 ± 57.24
# Episode 8275 finished with reward: 39.50
# Moving average (last 50 episodes): -35.81 ± 58.23
# Episode 8276 finished with reward: -1.47
# Moving average (last 50 episodes): -35.14 ± 58.43
# Episode 8277 finished with reward: -82.22
# Moving average (last 50 episodes): -35.31 ± 58.55
# Episode 8278 finished with reward: -89.95
# Moving average (last 50 episodes): -36.75 ± 58.99
# Episode 8279 finished with reward: -6.40
# Moving average (last 50 episodes): -42.60 ± 37.14
# Episode 8280 finished with reward: -101.03
# Moving average (last 50 episodes): -43.63 ± 38.02
# Episode 8281 finished with reward: -77.16
# Moving average (last 50 episodes): -44.11 ± 38.28
# Episode 8282 finished with reward: -33.70
# Moving average (last 50 episodes): -45.62 ± 36.30
# Episode 8283 finished with reward: -11.59
# Moving average (last 50 episodes): -44.98 ± 36.61
# Episode 8284 finished with reward: -60.48
# Moving average (last 50 episodes): -46.26 ± 36.00
# Episode 8285 finished with reward: 27.12
# Moving average (last 50 episodes): -45.41 ± 37.21
# Episode 8286 finished with reward: -63.86
# Moving average (last 50 episodes): -45.77 ± 37.30
# Episode 8287 finished with reward: -19.79
# Moving average (last 50 episodes): -46.95 ± 35.47
# Episode 8288 finished with reward: 45.98
# Moving average (last 50 episodes): -44.71 ± 37.67
# Episode 8289 finished with reward: -29.88
# Moving average (last 50 episodes): -45.08 ± 37.43
# Episode 8290 finished with reward: -108.61
# Moving average (last 50 episodes): -45.41 ± 37.92
# Episode 8291 finished with reward: 36.51
# Moving average (last 50 episodes): -44.81 ± 38.96
# Episode 8292 finished with reward: -110.95
# Moving average (last 50 episodes): -46.04 ± 40.05
# Episode 8293 finished with reward: -38.44
# Moving average (last 50 episodes): -46.79 ± 39.55
# Episode 8294 finished with reward: -63.90
# Moving average (last 50 episodes): -47.71 ± 39.40
# Episode 8295 finished with reward: -106.39
# Moving average (last 50 episodes): -48.15 ± 39.92
# Episode 8296 finished with reward: -51.63
# Moving average (last 50 episodes): -47.78 ± 39.80
# Episode 8297 finished with reward: -48.05
# Moving average (last 50 episodes): -48.04 ± 39.76
# Episode 8298 finished with reward: -57.95
# Moving average (last 50 episodes): -49.05 ± 39.37
# Episode 8299 finished with reward: -80.19
# Moving average (last 50 episodes): -49.57 ± 39.60
# Episode 8300 finished with reward: -1.16
# Moving average (last 50 episodes): -48.41 ± 40.15
# Episode 8301 finished with reward: -10.22
# Moving average (last 50 episodes): -48.25 ± 40.29
# Episode 8302 finished with reward: -128.03
# Moving average (last 50 episodes): -49.31 ± 41.65
# Episode 8303 finished with reward: 21.08
# Moving average (last 50 episodes): -47.20 ± 42.48
# Episode 8304 finished with reward: -60.77
# Moving average (last 50 episodes): -47.33 ± 42.51
# Episode 8305 finished with reward: -63.71
# Moving average (last 50 episodes): -46.89 ± 42.23
# Episode 8306 finished with reward: -46.67
# Moving average (last 50 episodes): -46.68 ± 42.20
# Episode 8307 finished with reward: -38.36
# Moving average (last 50 episodes): -46.60 ± 42.21
# Episode 8308 finished with reward: -22.42
# Moving average (last 50 episodes): -45.30 ± 41.93
# Episode 8309 finished with reward: -83.75
# Moving average (last 50 episodes): -45.78 ± 42.23
# Episode 8310 finished with reward: -22.80
# Moving average (last 50 episodes): -46.05 ± 42.04
# Episode 8311 finished with reward: 5.94
# Moving average (last 50 episodes): -44.74 ± 42.61
# Episode 8312 finished with reward: 49.04
# Moving average (last 50 episodes): -44.03 ± 43.85
# Episode 8313 finished with reward: -50.73
# Moving average (last 50 episodes): -43.87 ± 43.81
# Episode 8314 finished with reward: 19.72
# Moving average (last 50 episodes): -44.03 ± 43.56
# Episode 8315 finished with reward: -4.34
# Moving average (last 50 episodes): -42.48 ± 43.57
# Episode 8316 finished with reward: -101.77
# Moving average (last 50 episodes): -43.14 ± 44.21
# Episode 8317 finished with reward: -60.28
# Moving average (last 50 episodes): -43.19 ± 44.22
# Episode 8318 finished with reward: -26.73
# Moving average (last 50 episodes): -42.65 ± 44.26
# Episode 8319 finished with reward: -71.74
# Moving average (last 50 episodes): -42.99 ± 44.41
# Episode 8320 finished with reward: -116.86
# Moving average (last 50 episodes): -43.82 ± 45.39
# Episode 8321 finished with reward: -116.46
# Moving average (last 50 episodes): -44.51 ± 46.22
# Episode 8322 finished with reward: 15.85
# Moving average (last 50 episodes): -42.97 ± 46.91
# Episode 8323 finished with reward: -54.00
# Moving average (last 50 episodes): -43.06 ± 46.93
# Episode 8324 finished with reward: -18.26
# Moving average (last 50 episodes): -41.64 ± 46.59
# Episode 8325 finished with reward: -73.20
# Moving average (last 50 episodes): -43.89 ± 45.32
# Episode 8326 finished with reward: -89.09
# Moving average (last 50 episodes): -45.65 ± 45.34
# Episode 8327 finished with reward: 25.09
# Moving average (last 50 episodes): -43.50 ± 46.09
# Episode 8328 finished with reward: -41.06
# Moving average (last 50 episodes): -42.52 ± 45.61
# Episode 8329 finished with reward: -51.18
# Moving average (last 50 episodes): -43.42 ± 45.33
# Episode 8330 finished with reward: -55.65
# Moving average (last 50 episodes): -42.51 ± 44.61
# Episode 8331 finished with reward: -29.73
# Moving average (last 50 episodes): -41.56 ± 44.37
# Episode 8332 finished with reward: -70.91
# Moving average (last 50 episodes): -42.31 ± 44.54
# Episode 8333 finished with reward: -50.38
# Moving average (last 50 episodes): -43.08 ± 44.34

# %%
# def plot_smooth_rewards(rewards, window_sizes=[5, 20, 100]):
#     """
#     绘制平滑的奖励曲线
#     Args:
#         rewards: 奖励列表
#         window_sizes: 移动平均窗口大小列表
#     """
#     plt.figure(figsize=(12, 6))
    
#     # 绘制原始奖励
#     plt.plot(rewards, 'lightgray', alpha=0.3, label='Raw rewards')
    
#     # 绘制不同窗口大小的移动平均
#     colors = ['blue', 'green', 'red']
#     for window, color in zip(window_sizes, colors):
#         if len(rewards) >= window:
#             # 计算移动平均
#             smooth_rewards = np.convolve(rewards, 
#                                       np.ones(window)/window, 
#                                       mode='valid')
#             plt.plot(range(window-1, len(rewards)), 
#                     smooth_rewards, 
#                     color=color, 
#                     label=f'{window}-Episode Moving Average',
#                     linewidth=2)
    
#     plt.xlabel('Episode')
#     plt.ylabel('Reward')
#     plt.title('Training Rewards with Different Smoothing Windows')
#     plt.grid(True, alpha=0.3)
#     plt.legend()
#     plt.show()


# # 绘制平滑奖励曲线
# plot_smooth_rewards(metrics["rewards"])

# %% [markdown]
# notes: 如果要训练过程中查看模型，通过 tensorboard 查看

# %%
# 模型保存
model.save(f"./model/{log_name}")

# %% [markdown]
# ### 评估模型训练结果

# %% [markdown]
# > 利用 evaulate policy 函数评估

# %% [markdown]
# # 加载训练好的 RL 模型

# %%
from stable_baselines3.common.evaluation import evaluate_policy
mean_reward, std_reward = evaluate_policy(
    model, 
    model.get_env(), 
    deterministic=True,
    render=True,
    n_eval_episodes=10)

print(mean_reward)
print(std_reward)
# Out:
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# -86.9208533
# 23.682831764599015

# %%
# del model
# model = PPO.load(f"./model/{log_name}", env=env_monitor)
model = DQN.load(f"./model/{log_name}", env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### 结果展示

# %% [markdown]
# #### 纯净展示版本
#
# 这里可能就需要固定随机种子了

# %%
env = IEMEnv(reward_type=base_config["custom_reward_type"], seed=base_config["seed"])

# 运行中绘制的图
episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆

for ep in range(episodes):
    
    obs, _ = env.reset(use_random_reset=True, seed=16) # 必须的，每次重现一次
    
    episode_reward = 0
    done = False
    
     
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env.step(action)
        
        print(f"year {env.t}-Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # # 每10步更新一次图像
        # if i == max_steps-1:
        #     env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            env.render()
            plt.show()  # 添加这行来保持图形窗口
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]
# year 2017-Step 0 - Action: 12 - Reward: 0 - Done: False
# year 2018-Step 1 - Action: 12 - Reward: 0 - Done: False
# year 2019-Step 2 - Action: 11 - Reward: 0 - Done: False
# year 2020-Step 3 - Action: 11 - Reward: 0 - Done: False
# year 2021-Step 4 - Action: 11 - Reward: 0 - Done: False
# year 2022-Step 5 - Action: 11 - Reward: 0 - Done: False
# year 2023-Step 6 - Action: 11 - Reward: 0 - Done: False
# year 2024-Step 7 - Action: 5 - Reward: 0 - Done: False
# year 2025-Step 8 - Action: 12 - Reward: 8.87365640996332 - Done: False
# year 2026-Step 9 - Action: 12 - Reward: 7.924457530158274 - Done: False
# year 2027-Step 10 - Action: 12 - Reward: 7.0623782343159816 - Done: False
# year 2028-Step 11 - Action: 12 - Reward: 6.308270926141522 - Done: False
# year 2029-Step 12 - Action: 11 - Reward: 5.663071773020696 - Done: False
# year 2030-Step 13 - Action: 12 - Reward: 5.073903780234047 - Done: False
# year 2031-Step 14 - Action: 11 - Reward: 4.617064044807252 - Done: False
# year 2032-Step 15 - Action: 11 - Reward: -0.8414291041804355 - Done: False
# year 2033-Step 16 - Action: 8 - Reward: -0.7741568437350057 - Done: False
# year 2034-Step 17 - Action: 11 - Reward: -0.7397654971893193 - Done: False
# year 2035-Step 18 - Action: 11 - Reward: -0.7188762273438801 - Done: False
# year 2036-Step 19 - Action: 11 - Reward: -0.715134923318507 - Done: False
# year 2037-Step 20 - Action: 8 - Reward: -0.7284648139552522 - Done: False
# year 2038-Step 21 - Action: 0 - Reward: -0.7687030362418306 - Done: False
# year 2039-Step 22 - Action: 0 - Reward: -0.818140673040362 - Done: False
# year 2040-Step 23 - Action: 5 - Reward: -0.87461304422961 - Done: False
# year 2041-Step 24 - Action: 5 - Reward: -0.9280669358719105 - Done: False
# year 2042-Step 25 - Action: 5 - Reward: -0.9749887879923081 - Done: False
# year 2043-Step 26 - Action: 5 - Reward: -1.0195845121185902 - Done: False
# year 2044-Step 27 - Action: 0 - Reward: -1.0630320989582094 - Done: False
# year 2045-Step 28 - Action: 5 - Reward: -1.106544838239923 - Done: False
# year 2046-Step 29 - Action: 5 - Reward: -1.1468932789132826 - Done: False
# year 2047-Step 30 - Action: 5 - Reward: -1.1846681316537695 - Done: False
# year 2048-Step 31 - Action: 5 - Reward: -1.220182662422298 - Done: False
# year 2049-Step 32 - Action: 5 - Reward: -1.2538778194129299 - Done: False
# year 2050-Step 33 - Action: 5 - Reward: -1.2860997551941358 - Done: False
# year 2051-Step 34 - Action: 5 - Reward: -1.317166866683924 - Done: False
# year 2052-Step 35 - Action: 5 - Reward: -1.3493949634977362 - Done: False
# year 2053-Step 36 - Action: 5 - Reward: -1.383089074344894 - Done: False
# year 2054-Step 37 - Action: 5 - Reward: -1.418424017565225 - Done: False
# year 2055-Step 38 - Action: 5 - Reward: -1.4556534184686196 - Done: False
# year 2056-Step 39 - Action: 5 - Reward: -1.4947530492870313 - Done: False
# year 2057-Step 40 - Action: 0 - Reward: -1.5355603038466923 - Done: False
# year 2058-Step 41 - Action: 5 - Reward: -1.5739745217642729 - Done: False
# year 2059-Step 42 - Action: 5 - Reward: -1.614239215574946 - Done: False
# year 2060-Step 43 - Action: 5 - Reward: -1.6564572360387868 - Done: False
# year 2061-Step 44 - Action: 5 - Reward: -1.7011051442470397 - Done: False
# year 2062-Step 45 - Action: 5 - Reward: -1.748965602166267 - Done: False
# year 2063-Step 46 - Action: 5 - Reward: -1.8008245659739812 - Done: False
# year 2064-Step 47 - Action: 5 - Reward: -1.856953009489961 - Done: False
# year 2065-Step 48 - Action: 5 - Reward: -1.9174086994330821 - Done: False
# year 2066-Step 49 - Action: 5 - Reward: -1.982178776446662 - Done: False
# year 2067-Step 50 - Action: 5 - Reward: -2.051188709090005 - Done: False
# year 2068-Step 51 - Action: 5 - Reward: -2.124310543619114 - Done: False
# year 2069-Step 52 - Action: 5 - Reward: -2.201379687091313 - Done: False
# year 2070-Step 53 - Action: 5 - Reward: -2.2822047667050964 - Done: False
# year 2071-Step 54 - Action: 5 - Reward: -2.366581524442445 - Done: False
# year 2072-Step 55 - Action: 5 - Reward: -2.4548960399453765 - Done: False
# year 2073-Step 56 - Action: 5 - Reward: -2.5470751256643145 - Done: False
# year 2074-Step 57 - Action: 5 - Reward: -2.6436659636970394 - Done: False
# year 2075-Step 58 - Action: 0 - Reward: -2.7428945273914183 - Done: False
# year 2076-Step 59 - Action: 5 - Reward: -2.828567066155231 - Done: False
# year 2077-Step 60 - Action: 5 - Reward: -2.918366072124875 - Done: False
# year 2078-Step 61 - Action: 5 - Reward: -3.010725027101983 - Done: False
# year 2079-Step 62 - Action: 5 - Reward: -3.105725363521466 - Done: False
# year 2080-Step 63 - Action: 5 - Reward: -3.203070333574093 - Done: False
# year 2081-Step 64 - Action: 5 - Reward: -3.302874194770438 - Done: False
# year 2082-Step 65 - Action: 8 - Reward: -3.4020672555874434 - Done: False
# year 2083-Step 66 - Action: 8 - Reward: -3.482944038547502 - Done: False
# year 2084-Step 67 - Action: 9 - Reward: -3.5404749236071225 - Done: False
# year 2085-Step 68 - Action: 9 - Reward: -3.6044133152548996 - Done: False
# year 2086-Step 69 - Action: 9 - Reward: -3.6699472382438674 - Done: False
# year 2087-Step 70 - Action: 0 - Reward: -3.735770069775136 - Done: False
# year 2088-Step 71 - Action: 8 - Reward: -3.7729007578345928 - Done: False
# year 2089-Step 72 - Action: 8 - Reward: -3.7876986089627676 - Done: False
# year 2090-Step 73 - Action: 9 - Reward: -3.7897162548562835 - Done: False
# year 2091-Step 74 - Action: 8 - Reward: -3.7930346347506574 - Done: False
# year 2092-Step 75 - Action: 9 - Reward: -3.7783264717663125 - Done: False
# year 2093-Step 76 - Action: 9 - Reward: -3.767578000793849 - Done: False
# year 2094-Step 77 - Action: 13 - Reward: -3.758578578677735 - Done: False
# year 2095-Step 78 - Action: 13 - Reward: -3.7508197681511666 - Done: False
# year 2096-Step 79 - Action: 13 - Reward: -3.7441282257115085 - Done: False
# year 2097-Step 80 - Action: 13 - Reward: -3.7383704051960334 - Done: False
# year 2098-Step 81 - Action: 13 - Reward: -3.733444446233642 - Done: False
# year 2099-Step 82 - Action: 13 - Reward: -3.729271525952155 - Done: False
# year 2100-Step 83 - Action: 13 - Reward: -3.725789243985586 - Done: True
# Episode ended at step 83 with T_a = 2.2032860661048095
# Episode 0 finished with reward-3.725789243985586
# Final T_a: 2.2032860661048095

# %%
# 运行中绘制的图
episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆

for ep in range(episodes):
    
    obs, _ = env_monitor.reset(use_random_reset=base_config["use_random_reset"], seed=100) # 必须的，每次重现一次
    
    episode_reward = 0
    done = False
    
     
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        print(f"year {env_monitor.t}-Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # # 每10步更新一次图像
        # if i == max_steps-1:
        #     env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            env_monitor.render()
            plt.show()  # 添加这行来保持图形窗口
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")
# Out:
# year 2017-Step 0 - Action: 12 - Reward: 0 - Done: False
# year 2018-Step 1 - Action: 12 - Reward: 0 - Done: False
# year 2019-Step 2 - Action: 11 - Reward: 0 - Done: False
# year 2020-Step 3 - Action: 11 - Reward: 0 - Done: False
# year 2021-Step 4 - Action: 11 - Reward: 0 - Done: False
# year 2022-Step 5 - Action: 11 - Reward: 10.141218771329699 - Done: False
# year 2023-Step 6 - Action: 11 - Reward: 9.156799679779297 - Done: False
# year 2024-Step 7 - Action: 4 - Reward: 8.195132514486863 - Done: False
# year 2025-Step 8 - Action: 12 - Reward: 7.3304081169502195 - Done: False
# year 2026-Step 9 - Action: 12 - Reward: 6.546604354116775 - Done: False
# year 2027-Step 10 - Action: 12 - Reward: 5.870566686848557 - Done: False
# year 2028-Step 11 - Action: 12 - Reward: 5.30082990282184 - Done: False
# year 2029-Step 12 - Action: 12 - Reward: 4.8519610929285335 - Done: False
# year 2030-Step 13 - Action: 11 - Reward: -0.9089728822785823 - Done: False
# year 2031-Step 14 - Action: 11 - Reward: -0.8597668441858751 - Done: False
# year 2032-Step 15 - Action: 0 - Reward: -0.8231474504730362 - Done: False
# year 2033-Step 16 - Action: 0 - Reward: -0.8220384097152202 - Done: False
# year 2034-Step 17 - Action: 0 - Reward: -0.8362234591805883 - Done: False
# year 2035-Step 18 - Action: 5 - Reward: -0.868800853605855 - Done: False
# year 2036-Step 19 - Action: 5 - Reward: -0.9023891634310578 - Done: False
# year 2037-Step 20 - Action: 0 - Reward: -0.9388016064286699 - Done: False
# year 2038-Step 21 - Action: 5 - Reward: -0.985985819013057 - Done: False
# year 2039-Step 22 - Action: 5 - Reward: -1.029960359498736 - Done: False
# year 2040-Step 23 - Action: 5 - Reward: -1.0723573219280123 - Done: False
# year 2041-Step 24 - Action: 5 - Reward: -1.1122632659672527 - Done: False
# year 2042-Step 25 - Action: 5 - Reward: -1.1459027465015057 - Done: False
# year 2043-Step 26 - Action: 5 - Reward: -1.1774286164681953 - Done: False
# year 2044-Step 27 - Action: 5 - Reward: -1.2074704512031993 - Done: False
# year 2045-Step 28 - Action: 5 - Reward: -1.2362664015171678 - Done: False
# year 2046-Step 29 - Action: 5 - Reward: -1.2644553588060115 - Done: False
# year 2047-Step 30 - Action: 5 - Reward: -1.2922937932589738 - Done: False
# year 2048-Step 31 - Action: 0 - Reward: -1.320352471999252 - Done: False
# year 2049-Step 32 - Action: 5 - Reward: -1.348507400998265 - Done: False
# year 2050-Step 33 - Action: 5 - Reward: -1.3748468560235985 - Done: False
# year 2051-Step 34 - Action: 5 - Reward: -1.3997154577939501 - Done: False
# year 2052-Step 35 - Action: 5 - Reward: -1.4254511026139407 - Done: False
# year 2053-Step 36 - Action: 5 - Reward: -1.4523152452194381 - Done: False
# year 2054-Step 37 - Action: 5 - Reward: -1.4806438603018348 - Done: False
# year 2055-Step 38 - Action: 5 - Reward: -1.5106207474325817 - Done: False
# year 2056-Step 39 - Action: 5 - Reward: -1.5422317100510277 - Done: False
# year 2057-Step 40 - Action: 5 - Reward: -1.5760097456790403 - Done: False
# year 2058-Step 41 - Action: 5 - Reward: -1.6124645249084313 - Done: False
# year 2059-Step 42 - Action: 5 - Reward: -1.6519533482966313 - Done: False
# year 2060-Step 43 - Action: 5 - Reward: -1.694668080383425 - Done: False
# year 2061-Step 44 - Action: 5 - Reward: -1.7407254562411663 - Done: False
# year 2062-Step 45 - Action: 5 - Reward: -1.7911176039363006 - Done: False
# year 2063-Step 46 - Action: 5 - Reward: -1.8462913411544895 - Done: False
# year 2064-Step 47 - Action: 5 - Reward: -1.9064390380659761 - Done: False
# year 2065-Step 48 - Action: 0 - Reward: -1.9698206469504058 - Done: False
# year 2066-Step 49 - Action: 5 - Reward: -2.0283437257581785 - Done: False
# year 2067-Step 50 - Action: 5 - Reward: -2.0901622967122395 - Done: False
# year 2068-Step 51 - Action: 5 - Reward: -2.155423788682521 - Done: False
# year 2069-Step 52 - Action: 5 - Reward: -2.223911677532431 - Done: False
# year 2070-Step 53 - Action: 5 - Reward: -2.2955324347402093 - Done: False
# year 2071-Step 54 - Action: 5 - Reward: -2.3702943784171873 - Done: False
# year 2072-Step 55 - Action: 5 - Reward: -2.448582956432458 - Done: False
# year 2073-Step 56 - Action: 5 - Reward: -2.5304408921029875 - Done: False
# year 2074-Step 57 - Action: 5 - Reward: -2.6165246718180795 - Done: False
# year 2075-Step 58 - Action: 5 - Reward: -2.706569831681949 - Done: False
# year 2076-Step 59 - Action: 5 - Reward: -2.800315697993377 - Done: False
# year 2077-Step 60 - Action: 0 - Reward: -2.8956728977632187 - Done: False
# year 2078-Step 61 - Action: 8 - Reward: -2.973215652458632 - Done: False
# year 2079-Step 62 - Action: 9 - Reward: -3.036235723754226 - Done: False
# year 2080-Step 63 - Action: 9 - Reward: -3.10239921003965 - Done: False
# year 2081-Step 64 - Action: 0 - Reward: -3.1687163962195655 - Done: False
# year 2082-Step 65 - Action: 9 - Reward: -3.21729758081781 - Done: False
# year 2083-Step 66 - Action: 9 - Reward: -3.2687989225573744 - Done: False
# year 2084-Step 67 - Action: 8 - Reward: -3.31895435818172 - Done: False
# year 2085-Step 68 - Action: 8 - Reward: -3.351213395920463 - Done: False
# year 2086-Step 69 - Action: 8 - Reward: -3.366146150158117 - Done: False
# year 2087-Step 70 - Action: 9 - Reward: -3.3650109689301044 - Done: False
# year 2088-Step 71 - Action: 9 - Reward: -3.368334643867993 - Done: False
# year 2089-Step 72 - Action: 9 - Reward: -3.373358550385518 - Done: False
# year 2090-Step 73 - Action: 9 - Reward: -3.3796732505879796 - Done: False
# year 2091-Step 74 - Action: 13 - Reward: -3.38702891501456 - Done: False
# year 2092-Step 75 - Action: 13 - Reward: -3.3951657286415853 - Done: False
# year 2093-Step 76 - Action: 13 - Reward: -3.404004240248913 - Done: False
# year 2094-Step 77 - Action: 13 - Reward: -3.413486611777675 - Done: False
# year 2095-Step 78 - Action: 13 - Reward: -3.4235699499719687 - Done: False
# year 2096-Step 79 - Action: 13 - Reward: -3.4342483890559006 - Done: False
# year 2097-Step 80 - Action: 11 - Reward: -3.445472262271993 - Done: False
# year 2098-Step 81 - Action: 11 - Reward: -3.457248512578497 - Done: False
# year 2099-Step 82 - Action: 11 - Reward: -3.4695416406505664 - Done: False
# year 2100-Step 83 - Action: 11 - Reward: -3.4823166492082787 - Done: True
# Episode ended at step 83 with T_a = 2.1673654071285355
# Episode 0 finished with reward-3.4823166492082787
# Final T_a: 2.1673654071285355

# %%
# 运行中绘制的图
episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆

for ep in range(episodes):
    
    obs, _ = env_monitor.reset(use_random_reset=base_config["use_random_reset"], seed=45) # 必须的，每次重现一次
    
    episode_reward = 0
    done = False
    
     
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        print(f"year {env_monitor.t}-Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # # 每10步更新一次图像
        # if i == max_steps-1:
        #     env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            env_monitor.render()
            plt.show()  # 添加这行来保持图形窗口
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")
# Out:
# year 2017-Step 0 - Action: 12 - Reward: 0 - Done: False
# year 2018-Step 1 - Action: 12 - Reward: 0 - Done: False
# year 2019-Step 2 - Action: 11 - Reward: 0 - Done: False
# year 2020-Step 3 - Action: 11 - Reward: 0 - Done: False
# year 2021-Step 4 - Action: 11 - Reward: 0 - Done: False
# year 2022-Step 5 - Action: 11 - Reward: 10.141218771329699 - Done: False
# year 2023-Step 6 - Action: 11 - Reward: 9.156799679779297 - Done: False
# year 2024-Step 7 - Action: 4 - Reward: 8.195132514486863 - Done: False
# year 2025-Step 8 - Action: 12 - Reward: 7.3304081169502195 - Done: False
# year 2026-Step 9 - Action: 12 - Reward: 6.546604354116775 - Done: False
# year 2027-Step 10 - Action: 12 - Reward: 5.870566686848557 - Done: False
# year 2028-Step 11 - Action: 12 - Reward: 5.30082990282184 - Done: False
# year 2029-Step 12 - Action: 12 - Reward: 4.8519610929285335 - Done: False
# year 2030-Step 13 - Action: 11 - Reward: -0.9089728822785823 - Done: False
# year 2031-Step 14 - Action: 11 - Reward: -0.8597668441858751 - Done: False
# year 2032-Step 15 - Action: 0 - Reward: -0.8231474504730362 - Done: False
# year 2033-Step 16 - Action: 0 - Reward: -0.8220384097152202 - Done: False
# year 2034-Step 17 - Action: 0 - Reward: -0.8362234591805883 - Done: False
# year 2035-Step 18 - Action: 5 - Reward: -0.868800853605855 - Done: False
# year 2036-Step 19 - Action: 5 - Reward: -0.9023891634310578 - Done: False
# year 2037-Step 20 - Action: 0 - Reward: -0.9388016064286699 - Done: False
# year 2038-Step 21 - Action: 5 - Reward: -0.985985819013057 - Done: False
# year 2039-Step 22 - Action: 5 - Reward: -1.029960359498736 - Done: False
# year 2040-Step 23 - Action: 5 - Reward: -1.0723573219280123 - Done: False
# year 2041-Step 24 - Action: 5 - Reward: -1.1122632659672527 - Done: False
# year 2042-Step 25 - Action: 5 - Reward: -1.1459027465015057 - Done: False
# year 2043-Step 26 - Action: 5 - Reward: -1.1774286164681953 - Done: False
# year 2044-Step 27 - Action: 5 - Reward: -1.2074704512031993 - Done: False
# year 2045-Step 28 - Action: 5 - Reward: -1.2362664015171678 - Done: False
# year 2046-Step 29 - Action: 5 - Reward: -1.2644553588060115 - Done: False
# year 2047-Step 30 - Action: 5 - Reward: -1.2922937932589738 - Done: False
# year 2048-Step 31 - Action: 0 - Reward: -1.320352471999252 - Done: False
# year 2049-Step 32 - Action: 5 - Reward: -1.348507400998265 - Done: False
# year 2050-Step 33 - Action: 5 - Reward: -1.3748468560235985 - Done: False
# year 2051-Step 34 - Action: 5 - Reward: -1.3997154577939501 - Done: False
# year 2052-Step 35 - Action: 5 - Reward: -1.4254511026139407 - Done: False
# year 2053-Step 36 - Action: 5 - Reward: -1.4523152452194381 - Done: False
# year 2054-Step 37 - Action: 5 - Reward: -1.4806438603018348 - Done: False
# year 2055-Step 38 - Action: 5 - Reward: -1.5106207474325817 - Done: False
# year 2056-Step 39 - Action: 5 - Reward: -1.5422317100510277 - Done: False
# year 2057-Step 40 - Action: 5 - Reward: -1.5760097456790403 - Done: False
# year 2058-Step 41 - Action: 5 - Reward: -1.6124645249084313 - Done: False
# year 2059-Step 42 - Action: 5 - Reward: -1.6519533482966313 - Done: False
# year 2060-Step 43 - Action: 5 - Reward: -1.694668080383425 - Done: False
# year 2061-Step 44 - Action: 5 - Reward: -1.7407254562411663 - Done: False
# year 2062-Step 45 - Action: 5 - Reward: -1.7911176039363006 - Done: False
# year 2063-Step 46 - Action: 5 - Reward: -1.8462913411544895 - Done: False
# year 2064-Step 47 - Action: 5 - Reward: -1.9064390380659761 - Done: False
# year 2065-Step 48 - Action: 0 - Reward: -1.9698206469504058 - Done: False
# year 2066-Step 49 - Action: 5 - Reward: -2.0283437257581785 - Done: False
# year 2067-Step 50 - Action: 5 - Reward: -2.0901622967122395 - Done: False
# year 2068-Step 51 - Action: 5 - Reward: -2.155423788682521 - Done: False
# year 2069-Step 52 - Action: 5 - Reward: -2.223911677532431 - Done: False
# year 2070-Step 53 - Action: 5 - Reward: -2.2955324347402093 - Done: False
# year 2071-Step 54 - Action: 5 - Reward: -2.3702943784171873 - Done: False
# year 2072-Step 55 - Action: 5 - Reward: -2.448582956432458 - Done: False
# year 2073-Step 56 - Action: 5 - Reward: -2.5304408921029875 - Done: False
# year 2074-Step 57 - Action: 5 - Reward: -2.6165246718180795 - Done: False
# year 2075-Step 58 - Action: 5 - Reward: -2.706569831681949 - Done: False
# year 2076-Step 59 - Action: 5 - Reward: -2.800315697993377 - Done: False
# year 2077-Step 60 - Action: 0 - Reward: -2.8956728977632187 - Done: False
# year 2078-Step 61 - Action: 8 - Reward: -2.973215652458632 - Done: False
# year 2079-Step 62 - Action: 9 - Reward: -3.036235723754226 - Done: False
# year 2080-Step 63 - Action: 9 - Reward: -3.10239921003965 - Done: False
# year 2081-Step 64 - Action: 0 - Reward: -3.1687163962195655 - Done: False
# year 2082-Step 65 - Action: 9 - Reward: -3.21729758081781 - Done: False
# year 2083-Step 66 - Action: 9 - Reward: -3.2687989225573744 - Done: False
# year 2084-Step 67 - Action: 8 - Reward: -3.31895435818172 - Done: False
# year 2085-Step 68 - Action: 8 - Reward: -3.351213395920463 - Done: False
# year 2086-Step 69 - Action: 8 - Reward: -3.366146150158117 - Done: False
# year 2087-Step 70 - Action: 9 - Reward: -3.3650109689301044 - Done: False
# year 2088-Step 71 - Action: 9 - Reward: -3.368334643867993 - Done: False
# year 2089-Step 72 - Action: 9 - Reward: -3.373358550385518 - Done: False
# year 2090-Step 73 - Action: 9 - Reward: -3.3796732505879796 - Done: False
# year 2091-Step 74 - Action: 13 - Reward: -3.38702891501456 - Done: False
# year 2092-Step 75 - Action: 13 - Reward: -3.3951657286415853 - Done: False
# year 2093-Step 76 - Action: 13 - Reward: -3.404004240248913 - Done: False
# year 2094-Step 77 - Action: 13 - Reward: -3.413486611777675 - Done: False
# year 2095-Step 78 - Action: 13 - Reward: -3.4235699499719687 - Done: False
# year 2096-Step 79 - Action: 13 - Reward: -3.4342483890559006 - Done: False
# year 2097-Step 80 - Action: 11 - Reward: -3.445472262271993 - Done: False
# year 2098-Step 81 - Action: 11 - Reward: -3.457248512578497 - Done: False
# year 2099-Step 82 - Action: 11 - Reward: -3.4695416406505664 - Done: False
# year 2100-Step 83 - Action: 11 - Reward: -3.4823166492082787 - Done: True
# Episode ended at step 83 with T_a = 2.1673654071285355
# Episode 0 finished with reward-3.4823166492082787
# Final T_a: 2.1673654071285355

# %% [markdown]
# ### 保存整体运行结果

# %%
env_test = IEMEnv(reward_type=custom_reward_type)
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 3 # 结果展示，只有一个 episode 部分
max_steps = 250

# all_episode_rewards = [] # 记录所有 episode 里面的
 
for ep in range(episodes):
    
    ##################################
    # 记录所需数组：每次 episode 重置
    total_action = []
    total_state = []
    total_reward = []
    total_done = []
    ##################################
    # 记录每个 episode 的 reward
    episode_reward = 0
    ##################################
    
    obs, _ = env_test.reset() # 必须的，每次重现一次 ，这里可能就需要固定随机种子了
    done = False
    
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        ##################################
        # 添加转换的部分
        action_number, action_name = IEMEnv.action2number_env(action)
        total_action.append(action_number)
        total_state.append(obs)
        total_reward.append(reward)
        total_done.append(done)
        ##################################
        # 记录每个 episode 的 reward
        episode_reward += reward # TODO：可以放在内容记录 step 部分
        ################################## 
        
        if done:
            print(f"Episode {ep} finished at step {i}")
            break
        
        # # 每10步更新一次图像
        # if ep % 10 == 0:
        #     env_monitor.render()
        #     # plt.pause(0.01)
    
    # all_episode_rewards.append(episode_reward)
    
    env_test.append_data_reward(episode_reward)
    
    save_future_data(env=env_test,custom_reward_type=custom_reward_type,rl_model_name=rl_model_name,network_name=policy_kwargs_diy,episode=ep,total_action=total_action,total_state=total_state,total_reward=total_reward,total_done=total_done,total_timesteps_name=total_timesteps_diy)

    save_plot_NSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    save_plot_SSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    # plot_3D_run(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state)
    
    
    print(f"Episode {ep} finished with reward{episode_reward}")
    
    
plot_data = env_test.get_variables()
plot_episode_reward(plot_data)

# %% [markdown]
# 主要针对可视化显示部分操作

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 绘制只展示一次 episode 结果

# env_test

for episode in range(1):
    obs, _ = env_test.reset() # 这里可能就需要固定随机种子了
    
    done = False
    
    for i in range(251):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        
        if done:
            print(f"Episode {episode} finished at step {i}")
            break
# Out:
# Step 0 - Action: 12 - Reward: 0 - Done: False
# Step 1 - Action: 12 - Reward: 0 - Done: False
# Step 2 - Action: 11 - Reward: 0 - Done: False
# Step 3 - Action: 11 - Reward: 0 - Done: False
# Step 4 - Action: 11 - Reward: 0 - Done: False
# Step 5 - Action: 11 - Reward: 14.06803450305953 - Done: False
# Step 6 - Action: 11 - Reward: 13.241892160840784 - Done: False
# Step 7 - Action: 11 - Reward: 12.416837663138327 - Done: False
# Step 8 - Action: 11 - Reward: 11.596726015898676 - Done: False
# Step 9 - Action: 11 - Reward: 10.785607826593377 - Done: False
# Step 10 - Action: 11 - Reward: 9.984023531493742 - Done: False
# Step 11 - Action: 11 - Reward: 9.19906112558602 - Done: False
# Step 12 - Action: 11 - Reward: 8.439103367514551 - Done: False
# Step 13 - Action: 11 - Reward: 7.709027599574892 - Done: False
# Step 14 - Action: 11 - Reward: 7.010503319839671 - Done: False
# Step 15 - Action: 12 - Reward: 6.342170747417553 - Done: False
# Step 16 - Action: 12 - Reward: -1.1608074575177778 - Done: False
# Step 17 - Action: 12 - Reward: -1.077101243477358 - Done: False
# Step 18 - Action: 11 - Reward: -1.0159949417335505 - Done: False
# Step 19 - Action: 0 - Reward: -0.9663008363597819 - Done: False
# Step 20 - Action: 0 - Reward: -0.9492030802569783 - Done: False
# Step 21 - Action: 5 - Reward: -0.9496312451890921 - Done: False
# Step 22 - Action: 0 - Reward: -0.9577220992518973 - Done: False
# Step 23 - Action: 5 - Reward: -0.982671251366742 - Done: False
# Step 24 - Action: 5 - Reward: -1.0062435327344788 - Done: False
# Step 25 - Action: 5 - Reward: -1.0241265335374923 - Done: False
# Step 26 - Action: 5 - Reward: -1.0419932662243785 - Done: False
# Step 27 - Action: 5 - Reward: -1.0601157396122955 - Done: False
# Step 28 - Action: 5 - Reward: -1.0787664526179686 - Done: False
# Step 29 - Action: 5 - Reward: -1.0982971639214143 - Done: False
# Step 30 - Action: 5 - Reward: -1.118640471610285 - Done: False
# Step 31 - Action: 5 - Reward: -1.1399146215179192 - Done: False
# Step 32 - Action: 5 - Reward: -1.1619431057693372 - Done: False
# Step 33 - Action: 0 - Reward: -1.185716225474183 - Done: False
# Step 34 - Action: 5 - Reward: -1.2118074005090764 - Done: False
# Step 35 - Action: 5 - Reward: -1.2382714351033737 - Done: False
# Step 36 - Action: 5 - Reward: -1.2657243994242615 - Done: False
# Step 37 - Action: 5 - Reward: -1.2944822135258862 - Done: False
# Step 38 - Action: 5 - Reward: -1.3247877923672327 - Done: False
# Step 39 - Action: 5 - Reward: -1.356730624983374 - Done: False
# Step 40 - Action: 5 - Reward: -1.3903716741650565 - Done: False
# Step 41 - Action: 5 - Reward: -1.426137717207389 - Done: False
# Step 42 - Action: 5 - Reward: -1.464597092339363 - Done: False
# Step 43 - Action: 5 - Reward: -1.5060568298908694 - Done: False
# Step 44 - Action: 5 - Reward: -1.5508424599969688 - Done: False
# Step 45 - Action: 5 - Reward: -1.599520293304683 - Done: False
# Step 46 - Action: 5 - Reward: -1.6529266854160063 - Done: False
# Step 47 - Action: 5 - Reward: -1.7113291175291419 - Done: False
# Step 48 - Action: 5 - Reward: -1.7747404073183761 - Done: False
# Step 49 - Action: 5 - Reward: -1.84308745251094 - Done: False
# Step 50 - Action: 0 - Reward: -1.9150825196928325 - Done: False
# Step 51 - Action: 5 - Reward: -1.9800476085255945 - Done: False
# Step 52 - Action: 5 - Reward: -2.048680068793557 - Done: False
# Step 53 - Action: 5 - Reward: -2.1201128394158886 - Done: False
# Step 54 - Action: 5 - Reward: -2.194604115133708 - Done: False
# Step 55 - Action: 5 - Reward: -2.2723837917993355 - Done: False
# Step 56 - Action: 5 - Reward: -2.3535519660162714 - Done: False
# Step 57 - Action: 5 - Reward: -2.438811135142957 - Done: False
# Step 58 - Action: 0 - Reward: -2.526934312905644 - Done: False
# Step 59 - Action: 8 - Reward: -2.5991462336593227 - Done: False
# Step 60 - Action: 9 - Reward: -2.6572637945452153 - Done: False
# Step 61 - Action: 9 - Reward: -2.719411946659761 - Done: False
# Step 62 - Action: 9 - Reward: -2.7836944613660974 - Done: False
# Step 63 - Action: 8 - Reward: -2.8478192153144075 - Done: False
# Step 64 - Action: 9 - Reward: -2.8930194185307987 - Done: False
# Step 65 - Action: 9 - Reward: -2.944221641891296 - Done: False
# Step 66 - Action: 2 - Reward: -2.9965859798828345 - Done: False
# Step 67 - Action: 2 - Reward: -3.027886494674584 - Done: False
# Step 68 - Action: 9 - Reward: -3.034546847001674 - Done: False
# Step 69 - Action: 9 - Reward: -3.0455687604143304 - Done: False
# Step 70 - Action: 9 - Reward: -3.058113199245048 - Done: False
# Step 71 - Action: 9 - Reward: -3.0720111977125026 - Done: False
# Step 72 - Action: 9 - Reward: -3.086872928132142 - Done: False
# Step 73 - Action: 9 - Reward: -3.1025550417104717 - Done: False
# Step 74 - Action: 9 - Reward: -3.118956685978409 - Done: False
# Step 75 - Action: 13 - Reward: -3.136001738862608 - Done: False
# Step 76 - Action: 13 - Reward: -3.1535336852909572 - Done: False
# Step 77 - Action: 13 - Reward: -3.1715758407884573 - Done: False
# Step 78 - Action: 13 - Reward: -3.190080053401876 - Done: False
# Step 79 - Action: 13 - Reward: -3.2090394685694097 - Done: False
# Step 80 - Action: 11 - Reward: -3.228447742342186 - Done: False
# Step 81 - Action: 11 - Reward: -3.2483291140841706 - Done: False
# Step 82 - Action: 11 - Reward: -3.2686528871252154 - Done: False
# Step 83 - Action: 11 - Reward: -3.289392192484511 - Done: True
# Episode 0 finished at step 83

# %% [markdown]
# # 保存运行结果
