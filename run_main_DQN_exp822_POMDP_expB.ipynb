# %% [markdown]
# # RL 训练

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import scipy.io
from matplotlib.gridspec import GridSpec
import math
import random
import torch
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.logger import configure
from stable_baselines3.common.monitor import Monitor
from stable_baselines3 import PPO 
from stable_baselines3 import DQN
# 导入 BaseCallback
from stable_baselines3.common.callbacks import BaseCallback
import sys
import os
# 导入 IEMEnv 类
from src.envs.iseec_lx_v4_pomdp import IEMEnv
from src.utils.run_debug_plot import save_data 
from src.utils.run_debug_plot import save_plot_NSM_data
from src.utils.run_debug_plot import save_plot_SSM_data
from src.utils.run_debug_plot import save_future_data
from src.utils.run_debug_plot import save_plot_NSM_future_data
from src.utils.run_debug_plot import save_plot_SSM_future_data
from src.utils.run_debug_plot import plot_episode_reward
from src.utils.run_debug_plot import plot_episode_reward_simple
from src.utils.run_debug_plot import plot_3D_run
# 将 src 目录添加到模块搜索路径
sys.path.append(os.path.abspath('src'))

# 增加随机种子的定义
def set_global_seed(seed):
    """设置全局随机种子"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False


# 设置全局种子
# SEED = 42 # 非测试，不指定种子
# set_global_seed(SEED)

# 全新的超参数配置过程，都放在一起
base_config = {
    # MDP 元素
    "custom_reward_type" : "multi_objective_single_T_a_exp822",
    # 环境 & 策略
    "env_id":   "iseec_lx_v4_mdp_pomdp_nature",
    "rl_model_name": "DQN",
    "policy":   "MlpPolicy",
    "network_name" : "Netxxx_no_big_env",
    # 训练时长
    "total_timesteps_diy": 700000,
    "policy_kwargs_diy" : "dict_pi_vf_default", # for example: policy_kwargs = dict(activation_fn=th.nn.ReLU,net_arch=[256, 256, dict(pi=[128, 64], vf=[128, 64])])
    # 优化器 & 网络
    "hyperparams_diy": "default", 
    # "learning_rate":   3e-4,
    # "ent_coef":        0.0,
    # "batch_size":      64,
    # "n_epochs":        10,
    # 回放 & 更新频率（PPO 固定写法示例）
    # "gamma":           0.99,
    # "clip_range":      0.2,
    # "gae_lambda":      0.95,
    # 随机种子
    "use_random_reset": False, # 是否使用随机重置
    "seed":            42,
    "po_mdp_state": [0, 1, 4, 5, 6]
}

############### 具体的配置细节##############
# 设置保存的日志名字：
log_name = f'{base_config["env_id"]}_{base_config["rl_model_name"]}_{base_config["custom_reward_type"]}_{int(base_config["total_timesteps_diy"])}_{base_config["hyperparams_diy"]}' 
os.makedirs(f'./logs/{log_name}', exist_ok=True) # 创建日志目录

# 相当于接口部分
custom_reward_type = base_config["custom_reward_type"]
network_name = base_config["network_name"]
rl_model_name = base_config["rl_model_name"]
total_timesteps_diy = base_config["total_timesteps_diy"]
policy_kwargs_diy = base_config["policy_kwargs_diy"] 

# 设置日志保存路径和格式
new_logger = configure(
    f"logs/{log_name}",  # tmp_path 路径保存位置
    # ["stdout",     # 终端输出
    [
     "csv",        # CSV文件
     "tensorboard", # Tensorboard格式
     "json"        # JSON格式
    ]
)


# 定义环境
env = IEMEnv(reward_type=base_config["custom_reward_type"], seed=base_config["seed"], pomdp_state_indices=base_config["po_mdp_state"])
env_monitor = Monitor(env, f'./logs/{log_name}')

# 定义算法
# model = PPO(
#     "MlpPolicy", 
#     env_monitor, 
#     # ent_coef=0.01, # 增加策略寻找的鼓励，但是 suggestion 暂时不要改变
#     verbose=1,
#     )

model = DQN(
    "MlpPolicy", 
    env_monitor, 
    verbose=1,
    )

model.set_logger(new_logger) # set the parameter of the logger
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
# check 环境
from stable_baselines3.common.env_checker import check_env
# check_env(env_monitor)
print(log_name)
print("Action space sample:", env.action_space.sample())
print("Action space sample:", env.action_space.sample())
print("Observation space sample:", env.observation_space.sample())
# print(model.policy)
# Out:
# iseec_lx_v4_mdp_pomdp_nature_DQN_multi_objective_single_T_a_exp822_700000_default
# Action space sample: 5
# Action space sample: 14
# Observation space sample: [-0.20446361  1.44069067 -1.0254987  -1.8266391  -0.52499196]

# %% [markdown]
# ### 模型训练

# %%
def plot_callback_reward(metrics):
    """绘制训练过程中的奖励曲线
    
    Args:
        metrics (dict): 包含训练指标的字典，需要包含以下键：
            - rewards: 原始奖励列表
            - moving_avg_rewards: 移动平均奖励列表
            - moving_std_rewards: 移动标准差列表
            - episodes: 总回合数
            - step_idx: 当前步数
    """
    plt.figure(figsize=(20, 5))
    
    # 创建主图
    plt.subplot(131)
    plt.title(f'Step: {metrics["step_idx"]}, Latest reward: {metrics["rewards"][-1]:.2f}\n'
              f'Episode: {metrics["episodes"]}, Moving avg: {metrics["moving_avg_rewards"][-1]:.2f}')
    
    # 绘制原始奖励
    episodes = range(len(metrics["rewards"]))
    plt.plot(episodes, metrics["rewards"], 
             label='Raw rewards', color='gray', alpha=0.3)
    
    # 绘制移动平均
    plt.plot(episodes, metrics["moving_avg_rewards"],
             label='Moving average', color='blue', linewidth=2)
    
    # 添加标准差区域
    moving_avg = np.array(metrics["moving_avg_rewards"])
    moving_std = np.array(metrics["moving_std_rewards"])
    
    # 0.25倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.25 * moving_std,
                    moving_avg + 0.25 * moving_std,
                    color='b', alpha=0.1,
                    label='0.25 std range')
    
    # 0.5倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.5 * moving_std,
                    moving_avg + 0.5 * moving_std,
                    color='b', alpha=0.1,
                    label='0.5 std range')
    
    # 设置坐标轴和标签
    plt.xlabel('Episodes')
    plt.ylabel('Episode Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

class TrainingMonitorCallback(BaseCallback):
    def __init__(self, verbose=1, window_size=50):
        super().__init__(verbose)
        self.window_size = window_size
        # Initialize data dictionary to store metrics
        self.data = {
            "rewards": [],
            "moving_avg_rewards": [],
            "moving_std_rewards": [],
            "episodes": 0,
            "step_idx": 0
        }
        self.episode_rewards = 0
        
    def _on_step(self):
        # Accumulate rewards for current episode
        reward = self.locals.get('rewards')[0]
        self.episode_rewards += reward
        self.data["step_idx"] += 1
        
        # When episode ends, update all metrics
        if self.locals.get('dones')[0]:
            # Store raw reward
            self.data["rewards"].append(self.episode_rewards)
            
            # Calculate moving average and std
            recent_rewards = self.data["rewards"][-self.window_size:]
            moving_avg = np.mean(recent_rewards)
            moving_std = np.std(recent_rewards) if len(recent_rewards) > 1 else 0
            
            # Store calculated metrics
            self.data["moving_avg_rewards"].append(moving_avg)
            self.data["moving_std_rewards"].append(moving_std)
            self.data["episodes"] += 1
            
            # Reset episode rewards
            self.episode_rewards = 0
            
        return True
    
    def get_metrics(self):
        """Return the collected metrics"""
        return self.data
    
# Create callback with custom window size
callback = TrainingMonitorCallback(window_size=50)

# Train the model
model.learn(
    total_timesteps=int(total_timesteps_diy),
    callback=callback,
    log_interval=1
)


# After training, get metrics for plotting
metrics = callback.get_metrics()

# Plot rewards using the plot_callback_reward function
plot_callback_reward(metrics)

# %%
# 模型保存
model.save(f"./model/{log_name}")

# %% [markdown]
# ### 评估模型训练结果

# %% [markdown]
# # 加载训练好的 RL 模型

# %%
# del model
# model = PPO.load(f"./model/{log_name}", env=env_monitor)
model = DQN.load(f"./model/{log_name}", env=env_monitor)
# Out:
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### 结果展示

# %% [markdown]
# #### 纯净展示版本
#
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆

for ep in range(episodes):
    
    obs, _ = env_monitor.reset(use_random_reset=base_config["use_random_reset"], seed=base_config["seed"]) # 必须的，每次重现一次
    
    episode_reward = 0
    done = False
    
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        # print(f"year {env_monitor.t}-Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # # 每10步更新一次图像
        # if i == max_steps-1:
        #     env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            # print(f"Episode ended at step {i} with T_a = {obs[0]}")
            env_monitor.render()
            plt.show()  # 添加这行来保持图形窗口
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")
# Out:
# year 2017-Step 0 - Action: 0 - Reward: 2.020338901819331 - Done: False
# year 2018-Step 1 - Action: 0 - Reward: 1.855076793527477 - Done: False
# year 2019-Step 2 - Action: 0 - Reward: 1.6813185321893231 - Done: False
# year 2020-Step 3 - Action: 0 - Reward: 1.500493422048409 - Done: False
# year 2021-Step 4 - Action: 12 - Reward: 1.3134328058436817 - Done: False
# year 2022-Step 5 - Action: 12 - Reward: 1.1352356860372481 - Done: False
# year 2023-Step 6 - Action: 12 - Reward: 0.9658138676829875 - Done: False
# year 2024-Step 7 - Action: 12 - Reward: 0.8050794439266584 - Done: False
# year 2025-Step 8 - Action: 12 - Reward: 0.6529024174103482 - Done: False
# year 2026-Step 9 - Action: 12 - Reward: 0.5091781206874602 - Done: False
# year 2027-Step 10 - Action: 12 - Reward: 0.7475503520964288 - Done: False
# year 2028-Step 11 - Action: 12 - Reward: 0.4932581844417827 - Done: False
# year 2029-Step 12 - Action: 12 - Reward: 0.2553243781057568 - Done: False
# year 2030-Step 13 - Action: 0 - Reward: 0.0337199404517774 - Done: False
# year 2031-Step 14 - Action: 0 - Reward: -0.08575686811725158 - Done: False
# year 2032-Step 15 - Action: 0 - Reward: -0.1803835038164614 - Done: False
# year 2033-Step 16 - Action: 0 - Reward: -0.26722871339755483 - Done: False
# year 2034-Step 17 - Action: 0 - Reward: -0.34643980393297413 - Done: False
# year 2035-Step 18 - Action: 0 - Reward: -0.41814487988147353 - Done: False
# year 2036-Step 19 - Action: 0 - Reward: -0.4824246891014339 - Done: False
# year 2037-Step 20 - Action: 0 - Reward: -0.5393480594460087 - Done: False
# year 2038-Step 21 - Action: 0 - Reward: -0.5889688504517454 - Done: False
# year 2039-Step 22 - Action: 0 - Reward: -0.6313436538240325 - Done: False
# year 2040-Step 23 - Action: 0 - Reward: -0.6665301157984471 - Done: False
# year 2041-Step 24 - Action: 0 - Reward: -0.694601761369571 - Done: False
# year 2042-Step 25 - Action: 0 - Reward: -0.7160767209315266 - Done: False
# year 2043-Step 26 - Action: 0 - Reward: -0.7314555192977612 - Done: False
# year 2044-Step 27 - Action: 0 - Reward: -0.7410228859642298 - Done: False
# year 2045-Step 28 - Action: 0 - Reward: -0.7450134303997336 - Done: False
# year 2046-Step 29 - Action: 4 - Reward: -0.7437011667892246 - Done: False
# year 2047-Step 30 - Action: 4 - Reward: -0.7372833912998866 - Done: False
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.t to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.t` for environment variables or `env.get_wrapper_attr('t')` that will search the reminding wrappers.
#   logger.warn(
# year 2048-Step 31 - Action: 4 - Reward: -0.7259503817331892 - Done: False
# year 2049-Step 32 - Action: 4 - Reward: -0.7099003178288843 - Done: False
# year 2050-Step 33 - Action: 4 - Reward: -0.6893400676340078 - Done: False
# year 2051-Step 34 - Action: 4 - Reward: -0.6644853249393989 - Done: False
# year 2052-Step 35 - Action: 4 - Reward: -0.6376465232346995 - Done: False
# year 2053-Step 36 - Action: 4 - Reward: -0.6091400009818371 - Done: False
# year 2054-Step 37 - Action: 4 - Reward: -0.5792362462822853 - Done: False
# year 2055-Step 38 - Action: 4 - Reward: -0.5481484817934934 - Done: False
# year 2056-Step 39 - Action: 0 - Reward: -0.5160714488417784 - Done: False
# year 2057-Step 40 - Action: 0 - Reward: -0.48318167275112733 - Done: False
# year 2058-Step 41 - Action: 0 - Reward: -0.4496361301114149 - Done: False
# year 2059-Step 42 - Action: 0 - Reward: -0.41555992021785615 - Done: False
# year 2060-Step 43 - Action: 0 - Reward: -0.3810561805400703 - Done: False
# year 2061-Step 44 - Action: 12 - Reward: -0.3462031942232979 - Done: False
# year 2062-Step 45 - Action: 12 - Reward: -0.3111238598989863 - Done: False
# year 2063-Step 46 - Action: 12 - Reward: -0.2764117040623415 - Done: False
# year 2064-Step 47 - Action: 12 - Reward: -0.24236598429963951 - Done: False
# year 2065-Step 48 - Action: 12 - Reward: -0.2090864395716341 - Done: False
# year 2066-Step 49 - Action: 12 - Reward: -0.17661557973237985 - Done: False
# year 2067-Step 50 - Action: 12 - Reward: -0.14497125802957922 - Done: False
# year 2068-Step 51 - Action: 12 - Reward: -0.114126853304517 - Done: False
# year 2069-Step 52 - Action: 12 - Reward: -0.08402732485664255 - Done: False
# year 2070-Step 53 - Action: 12 - Reward: -0.05458876135322921 - Done: False
# year 2071-Step 54 - Action: 12 - Reward: -0.025705840726314433 - Done: False
# year 2072-Step 55 - Action: 12 - Reward: 0.005402845753041952 - Done: False
# year 2073-Step 56 - Action: 12 - Reward: 0.060981080700091006 - Done: False
# year 2074-Step 57 - Action: 12 - Reward: 0.11374152726640663 - Done: False
# year 2075-Step 58 - Action: 12 - Reward: 0.1641604857059531 - Done: False
# year 2076-Step 59 - Action: 12 - Reward: 0.21270200328551647 - Done: False
# year 2077-Step 60 - Action: 12 - Reward: 0.25981336961943047 - Done: False
# year 2078-Step 61 - Action: 12 - Reward: 0.3059234189291504 - Done: False
# year 2079-Step 62 - Action: 12 - Reward: 0.3514392519628662 - Done: False
# year 2080-Step 63 - Action: 12 - Reward: 0.3967439817551832 - Done: False
# year 2081-Step 64 - Action: 12 - Reward: 0.44219688560177106 - Done: False
# year 2082-Step 65 - Action: 12 - Reward: 0.48811058510382255 - Done: False
# year 2083-Step 66 - Action: 12 - Reward: 0.5347755067038973 - Done: False
# year 2084-Step 67 - Action: 12 - Reward: 0.5824666850525007 - Done: False
# year 2085-Step 68 - Action: 12 - Reward: 0.631440086340509 - Done: False
# year 2086-Step 69 - Action: 12 - Reward: 0.6819339538221403 - Done: False
# year 2087-Step 70 - Action: 12 - Reward: 0.7341666479984021 - Done: False
# year 2088-Step 71 - Action: 12 - Reward: 0.7883370744955398 - Done: False
# year 2089-Step 72 - Action: 12 - Reward: 0.8446247241765681 - Done: False
# year 2090-Step 73 - Action: 12 - Reward: 0.9031895500618914 - Done: False
# year 2091-Step 74 - Action: 0 - Reward: 0.9641730055504749 - Done: False
# year 2092-Step 75 - Action: 0 - Reward: 0.5138404736447855 - Done: False
# year 2093-Step 76 - Action: 0 - Reward: 0.5468975890978844 - Done: False
# year 2094-Step 77 - Action: 0 - Reward: 0.581293903611767 - Done: False
# year 2095-Step 78 - Action: 0 - Reward: 0.6170602004165793 - Done: False
# year 2096-Step 79 - Action: 0 - Reward: 0.6542232921831737 - Done: False
# year 2097-Step 80 - Action: 0 - Reward: 0.6928073863509787 - Done: False
# year 2098-Step 81 - Action: 0 - Reward: 0.7328333070413307 - Done: False
# year 2099-Step 82 - Action: 0 - Reward: -5.0 - Done: False
# year 2100-Step 83 - Action: 0 - Reward: -5.0 - Done: True
# Episode ended at step 83 with T_a = 1.3365390704635682
# Episode 0 finished with reward-5.0
# Final T_a: 1.3365390704635682

# %% [markdown]
# ### 保存整体运行结果

# %%
env_test = IEMEnv(reward_type=custom_reward_type)
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 3 # 结果展示，只有一个 episode 部分
max_steps = 250

# all_episode_rewards = [] # 记录所有 episode 里面的
 
for ep in range(episodes):
    
    ##################################
    # 记录所需数组：每次 episode 重置
    total_action = []
    total_state = []
    total_reward = []
    total_done = []
    ##################################
    # 记录每个 episode 的 reward
    episode_reward = 0
    ##################################
    
    obs, _ = env_test.reset() # 必须的，每次重现一次 ，这里可能就需要固定随机种子了
    done = False
    
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        ##################################
        # 添加转换的部分
        action_number, action_name = IEMEnv.action2number_env(action)
        total_action.append(action_number)
        total_state.append(obs)
        total_reward.append(reward)
        total_done.append(done)
        ##################################
        # 记录每个 episode 的 reward
        episode_reward += reward # TODO：可以放在内容记录 step 部分
        ################################## 
        
        if done:
            print(f"Episode {ep} finished at step {i}")
            break
        
        # # 每10步更新一次图像
        # if ep % 10 == 0:
        #     env_monitor.render()
        #     # plt.pause(0.01)
    
    # all_episode_rewards.append(episode_reward)
    
    env_test.append_data_reward(episode_reward)
    
    save_future_data(env=env_test,custom_reward_type=custom_reward_type,rl_model_name=rl_model_name,network_name=policy_kwargs_diy,episode=ep,total_action=total_action,total_state=total_state,total_reward=total_reward,total_done=total_done,total_timesteps_name=total_timesteps_diy)

    save_plot_NSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    save_plot_SSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    # plot_3D_run(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state)
    
    
    print(f"Episode {ep} finished with reward{episode_reward}")
    
    
plot_data = env_test.get_variables()
plot_episode_reward(plot_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 25
#      21 done = False
#      23 for i in range(max_steps):
#      24     # action = env_monitor.action_space.sample()
# ---> 25     action, _ = model.predict(obs, deterministic=True)
#      26     obs, reward, done, _, info = env_test.step(action)
#      28     print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
#
# File c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\dqn\dqn.py:255, in DQN.predict(self, observation, state, episode_start, deterministic)
#     253         action = np.array(self.action_space.sample())
#     254 else:
# --> 255     action, state = self.policy.predict(observation, state, episode_start, deterministic)
#     256 return action, state
#
# File c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\policies.py:365, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     356 if isinstance(observation, tuple) and len(observation) == 2 and isinstance(observation[1], dict):
#     357     raise ValueError(
#     358         "You have passed a tuple to the predict() function instead of a Numpy array or a Dict. "
#     359         "You are probably mixing Gym API with SB3 VecEnv API: `obs, info = env.reset()` (Gym) "
#    (...)
#     362         "and documentation for more information: https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api"
#     363     )
# --> 365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
#     368     actions = self._predict(obs_tensor, deterministic=deterministic)
#
# File c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\policies.py:272, in BaseModel.obs_to_tensor(self, observation)
#     268     observation = np.array(observation)
#     270 if not isinstance(observation, dict):
#     271     # Dict obs need to be handled separately
# --> 272     vectorized_env = is_vectorized_observation(observation, self.observation_space)
#     273     # Add batch dimension if needed
#     274     observation = observation.reshape((-1, *self.observation_space.shape))  # type: ignore[misc]
#
# File c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\utils.py:401, in is_vectorized_observation(observation, observation_space)
#     399 for space_type, is_vec_obs_func in is_vec_obs_func_dict.items():
#     400     if isinstance(observation_space, space_type):
# --> 401         return is_vec_obs_func(observation, observation_space)  # type: ignore[operator]
#     402 else:
#     403     # for-else happens if no break is called
#     404     raise ValueError(f"Error: Cannot determine if the observation is vectorized with the space type {observation_space}.")
#
# File c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\utils.py:268, in is_vectorized_box_observation(observation, observation_space)
#     266     return True
#     267 else:
# --> 268     raise ValueError(
#     269         f"Error: Unexpected observation shape {observation.shape} for "
#     270         + f"Box environment, please use {observation_space.shape} "
#     271         + "or (n_env, {}) for the observation shape.".format(", ".join(map(str, observation_space.shape)))
#     272     )
#
# ValueError: Error: Unexpected observation shape (10,) for Box environment, please use (5,) or (n_env, 5) for the observation shape.
