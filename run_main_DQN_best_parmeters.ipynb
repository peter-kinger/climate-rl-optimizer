# %% [markdown]
# # RL 训练

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import scipy.io
from matplotlib.gridspec import GridSpec
import math
import random
import torch

from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.logger import configure
from stable_baselines3.common.monitor import Monitor
from stable_baselines3 import PPO 
from stable_baselines3 import DQN

# 导入 BaseCallback
from stable_baselines3.common.callbacks import BaseCallback

import sys
import os

# 将 src 目录添加到模块搜索路径
sys.path.append(os.path.abspath('src'))

# 导入 IEMEnv 类
from src.envs.iseec_lx_v4_mdp_plot import IEMEnv
from src.utils.run_debug_plot import save_data 
from src.utils.run_debug_plot import save_plot_NSM_data
from src.utils.run_debug_plot import save_plot_SSM_data

from src.utils.run_debug_plot import save_future_data
from src.utils.run_debug_plot import save_plot_NSM_future_data
from src.utils.run_debug_plot import save_plot_SSM_future_data

from src.utils.run_debug_plot import plot_episode_reward
from src.utils.run_debug_plot import plot_episode_reward_simple
from src.utils.run_debug_plot import plot_3D_run

# %% [markdown]
# 定义保存位置参数
#
# > 所有的关键参数都放在最前面

# %%
# 增加随机种子的定义
def set_global_seed(seed):
    """设置全局随机种子"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False


# 设置全局种子
# SEED = 42 # 非测试，不指定种子
# set_global_seed(SEED)

# 全新的超参数配置过程，都放在一起
base_config = {
    # MDP 元素
    "custom_reward_type" : "sparse",
    # 环境 & 策略
    "env_id":   "iseec_lx_v4_mdp_plot",
    "rl_model_name": "DQN",
    "policy":   "MlpPolicy",
    ""
    "network_name" : "Netxxx_no_big_env",
    # 训练时长
    "total_timesteps_diy": 800000,
    "policy_kwargs_diy" : "dict_pi_vf_default", # for example: policy_kwargs = dict(activation_fn=th.nn.ReLU,net_arch=[256, 256, dict(pi=[128, 64], vf=[128, 64])])
    # 优化器 & 网络
    "hyperparams_diy": "default", 
    # "learning_rate":   3e-4,
    # "ent_coef":        0.0,
    # "batch_size":      64,
    # "n_epochs":        10,
    # 回放 & 更新频率（PPO 固定写法示例）
    # "gamma":           0.99,
    # "clip_range":      0.2,
    # "gae_lambda":      0.95,
    # 随机种子
    # "seed":            42,
}


############### 具体的配置细节##############
# 设置保存的日志名字：
log_name = f'{base_config["env_id"]}_{base_config["rl_model_name"]}_{base_config["custom_reward_type"]}_{int(base_config["total_timesteps_diy"])}_{base_config["hyperparams_diy"]}' 
os.makedirs(f'./logs/{log_name}', exist_ok=True) # 创建日志目录

# 相当于接口部分
custom_reward_type = base_config["custom_reward_type"]
network_name = base_config["network_name"]
rl_model_name = base_config["rl_model_name"]
total_timesteps_diy = base_config["total_timesteps_diy"]

policy_kwargs_diy = "dict_pi_vf_default" # f

# 设置日志保存路径和格式
new_logger = configure(
    f"logs/{log_name}",  # tmp_path 路径保存位置
    # ["stdout",     # 终端输出
    [
     "csv",        # CSV文件
     "tensorboard", # Tensorboard格式
     "json"        # JSON格式
    ]
)

# %% [markdown]
# ### 定义环境

# %%
env = IEMEnv(reward_type=base_config["custom_reward_type"])
env_monitor = Monitor(env, f'./logs/{log_name}')
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# ### 定义算法

# %%
# # 定义模型
# model = PPO(
#     "MlpPolicy", 
#     env_monitor, 
#     # ent_coef=0.01, # 增加策略寻找的鼓励，但是 suggestion 暂时不要改变
#     verbose=1,
#     )

model = DQN(
    "MlpPolicy", 
    env_monitor, 
    verbose=1,
    )

model.set_logger(new_logger) # set the parameter of the logger
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
# check 环境
from stable_baselines3.common.env_checker import check_env
# check_env(env_monitor)
log_name

print("Action space sample:", env.action_space.sample())
# print("Observation space sample:", env.observation_space.sample())

# type(env.action_space), type(env.observation_space)
print("Action space sample:", env.action_space.sample())
print("Observation space sample:", env.observation_space.sample())

print(model.policy)
# Out:
# Action space sample: 15
# Action space sample: 4
# Observation space sample: [-0.49827309 -0.21993946 -0.93053667  1.05840052  1.08661638  1.3931996
#  -1.2230665  -0.58646848 -1.00284737 -0.92521094]
# DQNPolicy(
#   (q_net): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=16, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=16, bias=True)
#     )
#   )
# )

# %% [markdown]
# ### 模型训练

# %%
def plot_callback_reward(metrics):
    """绘制训练过程中的奖励曲线
    
    Args:
        metrics (dict): 包含训练指标的字典，需要包含以下键：
            - rewards: 原始奖励列表
            - moving_avg_rewards: 移动平均奖励列表
            - moving_std_rewards: 移动标准差列表
            - episodes: 总回合数
            - step_idx: 当前步数
    """
    plt.figure(figsize=(20, 5))
    
    # 创建主图
    plt.subplot(131)
    plt.title(f'Step: {metrics["step_idx"]}, Latest reward: {metrics["rewards"][-1]:.2f}\n'
              f'Episode: {metrics["episodes"]}, Moving avg: {metrics["moving_avg_rewards"][-1]:.2f}')
    
    # 绘制原始奖励
    episodes = range(len(metrics["rewards"]))
    plt.plot(episodes, metrics["rewards"], 
             label='Raw rewards', color='gray', alpha=0.3)
    
    # 绘制移动平均
    plt.plot(episodes, metrics["moving_avg_rewards"],
             label='Moving average', color='blue', linewidth=2)
    
    # 添加标准差区域
    moving_avg = np.array(metrics["moving_avg_rewards"])
    moving_std = np.array(metrics["moving_std_rewards"])
    
    # 0.25倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.25 * moving_std,
                    moving_avg + 0.25 * moving_std,
                    color='b', alpha=0.1,
                    label='0.25 std range')
    
    # 0.5倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.5 * moving_std,
                    moving_avg + 0.5 * moving_std,
                    color='b', alpha=0.1,
                    label='0.5 std range')
    
    # 设置坐标轴和标签
    plt.xlabel('Episodes')
    plt.ylabel('Episode Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

class TrainingMonitorCallback(BaseCallback):
    def __init__(self, verbose=1, window_size=50):
        super().__init__(verbose)
        self.window_size = window_size
        # Initialize data dictionary to store metrics
        self.data = {
            "rewards": [],
            "moving_avg_rewards": [],
            "moving_std_rewards": [],
            "episodes": 0,
            "step_idx": 0
        }
        self.episode_rewards = 0
        
    def _on_step(self):
        # Accumulate rewards for current episode
        reward = self.locals.get('rewards')[0]
        self.episode_rewards += reward
        self.data["step_idx"] += 1
        
        # When episode ends, update all metrics
        if self.locals.get('dones')[0]:
            # Store raw reward
            self.data["rewards"].append(self.episode_rewards)
            
            # Calculate moving average and std
            recent_rewards = self.data["rewards"][-self.window_size:]
            moving_avg = np.mean(recent_rewards)
            moving_std = np.std(recent_rewards) if len(recent_rewards) > 1 else 0
            
            # Store calculated metrics
            self.data["moving_avg_rewards"].append(moving_avg)
            self.data["moving_std_rewards"].append(moving_std)
            self.data["episodes"] += 1
            
            # Print progress
            print(f"Episode {self.data['episodes']} finished with reward: {self.episode_rewards:.2f}")
            print(f"Moving average (last {len(recent_rewards)} episodes): {moving_avg:.2f} ± {moving_std:.2f}")
            
            # Reset episode rewards
            self.episode_rewards = 0
            
        return True
    
    def get_metrics(self):
        """Return the collected metrics"""
        return self.data
    
# Create callback with custom window size
callback = TrainingMonitorCallback(window_size=50)

# Train the model
model.learn(
    total_timesteps=int(total_timesteps_diy),
    callback=callback,
    log_interval=1
)

# After training, get metrics for plotting
metrics = callback.get_metrics()

# Plot rewards using the plot_callback_reward function
plot_callback_reward(metrics)
# Out:
# Episode 1 finished with reward: -544.52
# Moving average (last 1 episodes): -544.52 ± 0.00
# Episode 2 finished with reward: -328.24
# Moving average (last 2 episodes): -436.38 ± 108.14
# Episode 3 finished with reward: -2574.01
# Moving average (last 3 episodes): -1148.92 ± 1011.55
# Episode 4 finished with reward: 117.77
# Moving average (last 4 episodes): -832.25 ± 1033.57
# Episode 5 finished with reward: 306.62
# Moving average (last 5 episodes): -604.48 ± 1030.60
# Episode 6 finished with reward: -2050.46
# Moving average (last 6 episodes): -845.47 ± 1084.21
# Episode 7 finished with reward: 371.86
# Moving average (last 7 episodes): -671.57 ± 1090.43
# Episode 8 finished with reward: -2169.01
# Moving average (last 8 episodes): -858.75 ± 1133.87
# Episode 9 finished with reward: -605.47
# Moving average (last 9 episodes): -830.61 ± 1071.99
# Episode 10 finished with reward: 365.59
# Moving average (last 10 episodes): -710.99 ± 1078.43
# Episode 11 finished with reward: 224.09
# Moving average (last 11 episodes): -625.98 ± 1062.80
# Episode 12 finished with reward: 184.64
# Moving average (last 12 episodes): -558.43 ± 1041.93
# Episode 13 finished with reward: 106.31
# Moving average (last 13 episodes): -507.29 ± 1016.60
# Episode 14 finished with reward: -2657.27
# Moving average (last 14 episodes): -660.86 ± 1125.28
# Episode 15 finished with reward: 350.16
# Moving average (last 15 episodes): -593.46 ± 1115.99
# Episode 16 finished with reward: -2553.62
# Moving average (last 16 episodes): -715.97 ± 1180.14
# Episode 17 finished with reward: 372.02
# Moving average (last 17 episodes): -651.97 ± 1173.17
# Episode 18 finished with reward: -85.82
# Moving average (last 18 episodes): -620.52 ± 1147.47
# Episode 19 finished with reward: 408.51
# Moving average (last 19 episodes): -566.36 ± 1140.26
# Episode 20 finished with reward: -857.54
# Moving average (last 20 episodes): -580.92 ± 1113.20
# Episode 21 finished with reward: -1199.48
# Moving average (last 21 episodes): -610.37 ± 1094.33
# Episode 22 finished with reward: -2221.99
# Moving average (last 22 episodes): -683.63 ± 1120.63
# Episode 23 finished with reward: 350.61
# Moving average (last 23 episodes): -638.66 ± 1116.11
# Episode 24 finished with reward: -115.31
# Moving average (last 24 episodes): -616.86 ± 1097.60
# Episode 25 finished with reward: -152.45
# Moving average (last 25 episodes): -598.28 ± 1079.27
# Episode 26 finished with reward: 359.73
# Moving average (last 26 episodes): -561.43 ± 1074.22
# Episode 27 finished with reward: -722.88
# Moving average (last 27 episodes): -567.41 ± 1054.59
# Episode 28 finished with reward: -2998.93
# Moving average (last 28 episodes): -654.25 ± 1129.62
# Episode 29 finished with reward: 213.86
# Moving average (last 29 episodes): -624.32 ± 1121.22
# Episode 30 finished with reward: -1075.49
# Moving average (last 30 episodes): -639.36 ± 1105.34
# Episode 31 finished with reward: -76.15
# Moving average (last 31 episodes): -621.19 ± 1091.91
# Episode 32 finished with reward: 132.19
# Moving average (last 32 episodes): -597.65 ± 1082.68
# Episode 33 finished with reward: -1255.18
# Moving average (last 33 episodes): -617.57 ± 1072.09
# Episode 34 finished with reward: 130.93
# Moving average (last 34 episodes): -595.56 ± 1063.75
# Episode 35 finished with reward: -2256.65
# Moving average (last 35 episodes): -643.02 ± 1084.35
# Episode 36 finished with reward: -2673.01
# Moving average (last 36 episodes): -699.41 ± 1120.02
# Episode 37 finished with reward: 344.38
# Moving average (last 37 episodes): -671.19 ± 1117.67
# Episode 38 finished with reward: 331.67
# Moving average (last 38 episodes): -644.80 ± 1114.49
# Episode 39 finished with reward: -1172.19
# Moving average (last 39 episodes): -658.33 ± 1103.26
# Episode 40 finished with reward: -359.99
# Moving average (last 40 episodes): -650.87 ± 1090.38
# Episode 41 finished with reward: -340.21
# Moving average (last 41 episodes): -643.29 ± 1078.07
# Episode 42 finished with reward: 320.25
# Moving average (last 42 episodes): -620.35 ± 1075.24
# Episode 43 finished with reward: 388.93
# Moving average (last 43 episodes): -596.88 ± 1073.49
# Episode 44 finished with reward: 307.40
# Moving average (last 44 episodes): -576.33 ± 1069.75
# Episode 45 finished with reward: -1151.79
# Moving average (last 45 episodes): -589.11 ± 1061.19
# Episode 46 finished with reward: -191.74
# Moving average (last 46 episodes): -580.48 ± 1051.19
# Episode 47 finished with reward: -1486.34
# Moving average (last 47 episodes): -599.75 ± 1048.13
# Episode 48 finished with reward: -721.30
# Moving average (last 48 episodes): -602.28 ± 1037.30
# Episode 49 finished with reward: 132.65
# Moving average (last 49 episodes): -587.28 ± 1031.91
# Episode 50 finished with reward: -2461.66
# Moving average (last 50 episodes): -624.77 ± 1054.70
# Episode 51 finished with reward: -86.98
# Moving average (last 50 episodes): -615.62 ± 1057.34
# Episode 52 finished with reward: -1568.05
# Moving average (last 50 episodes): -640.42 ± 1064.82
# Episode 53 finished with reward: -188.84
# Moving average (last 50 episodes): -592.71 ± 1029.99
# Episode 54 finished with reward: 145.24
# Moving average (last 50 episodes): -592.16 ± 1030.37
# Episode 55 finished with reward: -251.60
# Moving average (last 50 episodes): -603.33 ± 1023.57
# Episode 56 finished with reward: 175.05
# Moving average (last 50 episodes): -558.82 ± 1007.95
# Episode 57 finished with reward: -162.74
# Moving average (last 50 episodes): -569.51 ± 1000.83
# Episode 58 finished with reward: 326.40
# Moving average (last 50 episodes): -519.60 ± 981.86
# Episode 59 finished with reward: 166.97
# Moving average (last 50 episodes): -504.15 ± 986.45
# Episode 60 finished with reward: -893.29
# Moving average (last 50 episodes): -529.33 ± 979.98
# Episode 61 finished with reward: 321.61
# Moving average (last 50 episodes): -527.38 ± 981.57
# Episode 62 finished with reward: 363.34
# Moving average (last 50 episodes): -523.81 ± 984.48
# Episode 63 finished with reward: 368.36
# Moving average (last 50 episodes): -518.56 ± 988.51
# Episode 64 finished with reward: -549.75
# Moving average (last 50 episodes): -476.41 ± 940.17
# Episode 65 finished with reward: 360.31
# Moving average (last 50 episodes): -476.21 ± 940.35
# Episode 66 finished with reward: -2562.19
# Moving average (last 50 episodes): -476.38 ± 940.72
# Episode 67 finished with reward: -2393.01
# Moving average (last 50 episodes): -531.68 ± 970.04
# Episode 68 finished with reward: -1746.12
# Moving average (last 50 episodes): -564.89 ± 982.55
# Episode 69 finished with reward: -2287.75
# Moving average (last 50 episodes): -618.81 ± 1001.45
# Episode 70 finished with reward: 154.94
# Moving average (last 50 episodes): -598.57 ± 1006.64
# Episode 71 finished with reward: 142.96
# Moving average (last 50 episodes): -571.72 ± 1008.16
# Episode 72 finished with reward: -2019.82
# Moving average (last 50 episodes): -567.67 ± 1001.92
# Episode 73 finished with reward: -2058.76
# Moving average (last 50 episodes): -615.86 ± 1014.45
# Episode 74 finished with reward: -962.94
# Moving average (last 50 episodes): -632.81 ± 1013.03
# Episode 75 finished with reward: 382.20
# Moving average (last 50 episodes): -622.12 ± 1020.84
# Episode 76 finished with reward: -953.35
# Moving average (last 50 episodes): -648.38 ± 1012.09
# Episode 77 finished with reward: -629.48
# Moving average (last 50 episodes): -646.51 ± 1012.04
# Episode 78 finished with reward: 128.33
# Moving average (last 50 episodes): -583.97 ± 960.02
# Episode 79 finished with reward: -33.57
# Moving average (last 50 episodes): -588.92 ± 956.53
# Episode 80 finished with reward: 129.16
# Moving average (last 50 episodes): -564.82 ± 959.14
# Episode 81 finished with reward: -2869.68
# Moving average (last 50 episodes): -620.69 ± 1009.10
# Episode 82 finished with reward: -1248.35
# Moving average (last 50 episodes): -648.31 ± 1007.01
# Episode 83 finished with reward: -929.97
# Moving average (last 50 episodes): -641.80 ± 1004.12
# Episode 84 finished with reward: -872.46
# Moving average (last 50 episodes): -661.87 ± 998.48
# Episode 85 finished with reward: -91.67
# Moving average (last 50 episodes): -618.57 ± 975.05
# Episode 86 finished with reward: -371.70
# Moving average (last 50 episodes): -572.54 ± 930.28
# Episode 87 finished with reward: -1201.81
# Moving average (last 50 episodes): -603.47 ± 924.97
# Episode 88 finished with reward: 393.18
# Moving average (last 50 episodes): -602.24 ± 926.25
# Episode 89 finished with reward: 327.16
# Moving average (last 50 episodes): -572.25 ± 931.57
# Episode 90 finished with reward: 365.17
# Moving average (last 50 episodes): -557.75 ± 940.36
# Episode 91 finished with reward: -935.70
# Moving average (last 50 episodes): -569.66 ± 941.30
# Episode 92 finished with reward: -532.87
# Moving average (last 50 episodes): -586.72 ± 932.71
# Episode 93 finished with reward: -964.74
# Moving average (last 50 episodes): -613.79 ± 923.60
# Episode 94 finished with reward: 354.61
# Moving average (last 50 episodes): -612.85 ± 924.56
# Episode 95 finished with reward: -2685.77
# Moving average (last 50 episodes): -643.53 ± 966.44
# Episode 96 finished with reward: -362.42
# Moving average (last 50 episodes): -646.94 ± 965.14
# Episode 97 finished with reward: -258.88
# Moving average (last 50 episodes): -622.39 ± 959.07
# Episode 98 finished with reward: -2479.86
# Moving average (last 50 episodes): -657.56 ± 993.67
# Episode 99 finished with reward: 333.66
# Moving average (last 50 episodes): -653.54 ± 997.26
# Episode 100 finished with reward: 356.08
# Moving average (last 50 episodes): -597.19 ± 972.81
# Episode 101 finished with reward: -1458.97
# Moving average (last 50 episodes): -624.63 ± 977.37
# Episode 102 finished with reward: -656.97
# Moving average (last 50 episodes): -606.41 ± 968.06
# Episode 103 finished with reward: -677.57
# Moving average (last 50 episodes): -616.18 ± 966.26
# Episode 104 finished with reward: 175.14
# Moving average (last 50 episodes): -615.58 ± 966.74
# Episode 105 finished with reward: 304.11
# Moving average (last 50 episodes): -604.47 ± 974.03
# Episode 106 finished with reward: -1259.12
# Moving average (last 50 episodes): -633.15 ± 971.76
# Episode 107 finished with reward: 337.46
# Moving average (last 50 episodes): -623.15 ± 979.10
# Episode 108 finished with reward: 238.26
# Moving average (last 50 episodes): -624.91 ± 977.47
# Episode 109 finished with reward: -1292.96
# Moving average (last 50 episodes): -654.11 ± 975.18
# Episode 110 finished with reward: 197.45
# Moving average (last 50 episodes): -632.29 ± 981.76
# Episode 111 finished with reward: 34.26
# Moving average (last 50 episodes): -638.04 ± 976.99
# Episode 112 finished with reward: -1579.25
# Moving average (last 50 episodes): -676.89 ± 975.02
# Episode 113 finished with reward: -566.55
# Moving average (last 50 episodes): -695.59 ± 963.69
# Episode 114 finished with reward: -910.80
# Moving average (last 50 episodes): -702.81 ± 963.93
# Episode 115 finished with reward: -1015.17
# Moving average (last 50 episodes): -730.32 ± 952.76
# Episode 116 finished with reward: 333.13
# Moving average (last 50 episodes): -672.42 ± 927.31
# Episode 117 finished with reward: -2137.10
# Moving average (last 50 episodes): -667.30 ± 918.46
# Episode 118 finished with reward: 344.69
# Moving average (last 50 episodes): -625.48 ± 915.98
# Episode 119 finished with reward: 3.56
# Moving average (last 50 episodes): -579.65 ± 888.58
# Episode 120 finished with reward: -1758.05
# Moving average (last 50 episodes): -617.91 ± 897.27
# Episode 121 finished with reward: -202.20
# Moving average (last 50 episodes): -624.82 ± 892.70
# Episode 122 finished with reward: -1322.21
# Moving average (last 50 episodes): -610.87 ± 876.09
# Episode 123 finished with reward: -163.99
# Moving average (last 50 episodes): -572.97 ± 853.32
# Episode 124 finished with reward: -2524.19
# Moving average (last 50 episodes): -604.20 ± 894.59
# Episode 125 finished with reward: 184.16
# Moving average (last 50 episodes): -608.16 ± 890.64
# Episode 126 finished with reward: -99.67
# Moving average (last 50 episodes): -591.08 ± 892.04
# Episode 127 finished with reward: 355.23
# Moving average (last 50 episodes): -571.39 ± 901.80
# Episode 128 finished with reward: 139.65
# Moving average (last 50 episodes): -571.16 ± 901.97
# Episode 129 finished with reward: -861.64
# Moving average (last 50 episodes): -587.72 ± 899.55
# Episode 130 finished with reward: -285.61
# Moving average (last 50 episodes): -596.02 ± 894.80
# Episode 131 finished with reward: -1187.06
# Moving average (last 50 episodes): -562.37 ± 838.53
# Episode 132 finished with reward: 355.78
# Moving average (last 50 episodes): -530.28 ± 842.35
# Episode 133 finished with reward: 33.65
# Moving average (last 50 episodes): -511.01 ± 844.00
# Episode 134 finished with reward: 122.77
# Moving average (last 50 episodes): -491.11 ± 846.98
# Episode 135 finished with reward: -3285.45
# Moving average (last 50 episodes): -554.98 ± 930.73
# Episode 136 finished with reward: -2719.09
# Moving average (last 50 episodes): -601.93 ± 978.29
# Episode 137 finished with reward: 369.35
# Moving average (last 50 episodes): -570.51 ± 983.74
# Episode 138 finished with reward: -1264.56
# Moving average (last 50 episodes): -603.66 ± 978.62
# Episode 139 finished with reward: 349.27
# Moving average (last 50 episodes): -603.22 ± 979.05
# Episode 140 finished with reward: 114.20
# Moving average (last 50 episodes): -608.24 ± 974.70
# Episode 141 finished with reward: -3262.23
# Moving average (last 50 episodes): -654.77 ± 1042.40
# Episode 142 finished with reward: -2115.94
# Moving average (last 50 episodes): -686.43 ± 1062.08
# Episode 143 finished with reward: 353.34
# Moving average (last 50 episodes): -660.07 ± 1071.16
# Episode 144 finished with reward: -392.08
# Moving average (last 50 episodes): -675.00 ± 1062.08
# Episode 145 finished with reward: -3023.04
# Moving average (last 50 episodes): -681.75 ± 1075.81
# Episode 146 finished with reward: 371.54
# Moving average (last 50 episodes): -667.07 ± 1085.03
# Episode 147 finished with reward: -205.76
# Moving average (last 50 episodes): -666.01 ± 1085.46
# Episode 148 finished with reward: -2588.98
# Moving average (last 50 episodes): -668.19 ± 1089.21
# Episode 149 finished with reward: 188.58
# Moving average (last 50 episodes): -671.09 ± 1086.72
# Episode 150 finished with reward: 338.65
# Moving average (last 50 episodes): -671.44 ± 1086.40
# Episode 151 finished with reward: 346.97
# Moving average (last 50 episodes): -635.32 ± 1089.63
# Episode 152 finished with reward: 107.29
# Moving average (last 50 episodes): -620.04 ± 1094.57
# Episode 153 finished with reward: 314.20
# Moving average (last 50 episodes): -600.20 ± 1102.31
# Episode 154 finished with reward: -2315.27
# Moving average (last 50 episodes): -650.01 ± 1122.23
# Episode 155 finished with reward: 349.28
# Moving average (last 50 episodes): -649.10 ± 1123.02
# Episode 156 finished with reward: -2281.69
# Moving average (last 50 episodes): -669.56 ± 1143.07
# Episode 157 finished with reward: -2567.44
# Moving average (last 50 episodes): -727.65 ± 1164.04
# Episode 158 finished with reward: -1325.38
# Moving average (last 50 episodes): -758.93 ± 1158.66
# Episode 159 finished with reward: -447.06
# Moving average (last 50 episodes): -742.01 ± 1156.92
# Episode 160 finished with reward: 211.52
# Moving average (last 50 episodes): -741.73 ± 1157.15
# Episode 161 finished with reward: -1133.74
# Moving average (last 50 episodes): -765.09 ± 1153.03
# Episode 162 finished with reward: -503.92
# Moving average (last 50 episodes): -743.58 ± 1147.66
# Episode 163 finished with reward: -1233.76
# Moving average (last 50 episodes): -756.93 ± 1149.40
# Episode 164 finished with reward: -2316.16
# Moving average (last 50 episodes): -785.03 ± 1169.82
# Episode 165 finished with reward: -967.64
# Moving average (last 50 episodes): -784.08 ± 1169.65
# Episode 166 finished with reward: -96.42
# Moving average (last 50 episodes): -792.67 ± 1162.97
# Episode 167 finished with reward: 351.98
# Moving average (last 50 episodes): -742.89 ± 1157.62
# Episode 168 finished with reward: -708.70
# Moving average (last 50 episodes): -763.96 ± 1147.17
# Episode 169 finished with reward: -1786.47
# Moving average (last 50 episodes): -799.76 ± 1150.59
# Episode 170 finished with reward: 352.20
# Moving average (last 50 episodes): -757.55 ± 1153.36
# Episode 171 finished with reward: -1588.07
# Moving average (last 50 episodes): -785.27 ± 1156.33
# Episode 172 finished with reward: -58.94
# Moving average (last 50 episodes): -760.01 ± 1158.12
# Episode 173 finished with reward: 317.62
# Moving average (last 50 episodes): -750.37 ± 1165.02
# Episode 174 finished with reward: 213.95
# Moving average (last 50 episodes): -695.61 ± 1144.53
# Episode 175 finished with reward: 132.92
# Moving average (last 50 episodes): -696.64 ± 1143.77
# Episode 176 finished with reward: -2010.95
# Moving average (last 50 episodes): -734.86 ± 1155.06
# Episode 177 finished with reward: -2818.91
# Moving average (last 50 episodes): -798.34 ± 1180.35
# Episode 178 finished with reward: -187.05
# Moving average (last 50 episodes): -804.88 ± 1176.04
# Episode 179 finished with reward: -1612.08
# Moving average (last 50 episodes): -819.89 ± 1181.44
# Episode 180 finished with reward: -3052.10
# Moving average (last 50 episodes): -875.22 ± 1219.30
# Episode 181 finished with reward: -252.78
# Moving average (last 50 episodes): -856.53 ± 1221.53
# Episode 182 finished with reward: 254.73
# Moving average (last 50 episodes): -858.55 ± 1219.61
# Episode 183 finished with reward: -2375.14
# Moving average (last 50 episodes): -906.73 ± 1230.94
# Episode 184 finished with reward: -1167.90
# Moving average (last 50 episodes): -932.54 ± 1222.58
# Episode 185 finished with reward: -485.20
# Moving average (last 50 episodes): -876.54 ± 1176.79
# Episode 186 finished with reward: -620.11
# Moving average (last 50 episodes): -834.56 ± 1147.39
# Episode 187 finished with reward: -1199.43
# Moving average (last 50 episodes): -865.93 ± 1135.42
# Episode 188 finished with reward: -943.05
# Moving average (last 50 episodes): -859.50 ± 1134.06
# Episode 189 finished with reward: -1500.50
# Moving average (last 50 episodes): -896.50 ± 1124.15
# Episode 190 finished with reward: 375.47
# Moving average (last 50 episodes): -891.27 ± 1129.43
# Episode 191 finished with reward: 135.59
# Moving average (last 50 episodes): -823.32 ± 1086.12
# Episode 192 finished with reward: 361.72
# Moving average (last 50 episodes): -773.76 ± 1082.53
# Episode 193 finished with reward: -810.90
# Moving average (last 50 episodes): -797.05 ± 1070.49
# Episode 194 finished with reward: -2532.52
# Moving average (last 50 episodes): -839.86 ± 1095.93
# Episode 195 finished with reward: -2327.52
# Moving average (last 50 episodes): -825.95 ± 1072.30
# Episode 196 finished with reward: 202.60
# Moving average (last 50 episodes): -829.32 ± 1068.78
# Episode 197 finished with reward: -823.99
# Moving average (last 50 episodes): -841.69 ± 1065.06
# Episode 198 finished with reward: -1365.85
# Moving average (last 50 episodes): -817.23 ± 1038.36
# Episode 199 finished with reward: -800.84
# Moving average (last 50 episodes): -837.01 ± 1028.38
# Episode 200 finished with reward: -2620.76
# Moving average (last 50 episodes): -896.20 ± 1044.06
# Episode 201 finished with reward: -64.09
# Moving average (last 50 episodes): -904.42 ± 1035.82
# Episode 202 finished with reward: -163.87
# Moving average (last 50 episodes): -909.85 ± 1031.21
# Episode 203 finished with reward: -33.13
# Moving average (last 50 episodes): -916.79 ± 1024.09
# Episode 204 finished with reward: -188.79
# Moving average (last 50 episodes): -874.26 ± 1009.18
# Episode 205 finished with reward: -3219.29
# Moving average (last 50 episodes): -945.64 ± 1045.65
# Episode 206 finished with reward: 80.02
# Moving average (last 50 episodes): -898.40 ± 1037.54
# Episode 207 finished with reward: 350.81
# Moving average (last 50 episodes): -840.04 ± 1024.00
# Episode 208 finished with reward: -87.78
# Moving average (last 50 episodes): -815.29 ± 1026.92
# Episode 209 finished with reward: -1748.68
# Moving average (last 50 episodes): -841.32 ± 1033.74
# Episode 210 finished with reward: -78.06
# Moving average (last 50 episodes): -847.11 ± 1028.62
# Episode 211 finished with reward: -1685.52
# Moving average (last 50 episodes): -858.14 ± 1034.58
# Episode 212 finished with reward: 301.25
# Moving average (last 50 episodes): -842.04 ± 1046.17
# Episode 213 finished with reward: 353.05
# Moving average (last 50 episodes): -810.31 ± 1057.81
# Episode 214 finished with reward: -1107.88
# Moving average (last 50 episodes): -786.14 ± 1036.72
# Episode 215 finished with reward: -3259.61
# Moving average (last 50 episodes): -831.98 ± 1092.88
# Episode 216 finished with reward: -1727.61
# Moving average (last 50 episodes): -864.60 ± 1094.78
# Episode 217 finished with reward: 162.29
# Moving average (last 50 episodes): -868.40 ± 1090.88
# Episode 218 finished with reward: -2343.67
# Moving average (last 50 episodes): -901.10 ± 1109.94
# Episode 219 finished with reward: 346.69
# Moving average (last 50 episodes): -858.43 ± 1116.07
# Episode 220 finished with reward: 337.21
# Moving average (last 50 episodes): -858.73 ± 1115.75
# Episode 221 finished with reward: -55.25
# Moving average (last 50 episodes): -828.08 ± 1116.35
# Episode 222 finished with reward: -1985.45
# Moving average (last 50 episodes): -866.61 ± 1122.36
# Episode 223 finished with reward: 139.26
# Moving average (last 50 episodes): -870.17 ± 1118.87
# Episode 224 finished with reward: 332.74
# Moving average (last 50 episodes): -867.80 ± 1121.30
# Episode 225 finished with reward: -2994.57
# Moving average (last 50 episodes): -930.35 ± 1150.58
# Episode 226 finished with reward: -1482.57
# Moving average (last 50 episodes): -919.78 ± 1143.00
# Episode 227 finished with reward: -2799.24
# Moving average (last 50 episodes): -919.39 ± 1142.35
# Episode 228 finished with reward: -2260.65
# Moving average (last 50 episodes): -960.86 ± 1152.61
# Episode 229 finished with reward: -969.55
# Moving average (last 50 episodes): -948.01 ± 1148.85
# Episode 230 finished with reward: -661.34
# Moving average (last 50 episodes): -900.19 ± 1109.36
# Episode 231 finished with reward: 294.86
# Moving average (last 50 episodes): -889.24 ± 1118.36
# Episode 232 finished with reward: 345.92
# Moving average (last 50 episodes): -887.42 ± 1120.30
# Episode 233 finished with reward: -2585.54
# Moving average (last 50 episodes): -891.62 ± 1126.26
# Episode 234 finished with reward: -698.19
# Moving average (last 50 episodes): -882.23 ± 1125.87
# Episode 235 finished with reward: -1264.61
# Moving average (last 50 episodes): -897.82 ± 1125.66
# Episode 236 finished with reward: -902.88
# Moving average (last 50 episodes): -903.47 ± 1124.96
# Episode 237 finished with reward: -513.62
# Moving average (last 50 episodes): -889.76 ± 1125.45
# Episode 238 finished with reward: 108.68
# Moving average (last 50 episodes): -868.72 ± 1134.06
# Episode 239 finished with reward: -22.63
# Moving average (last 50 episodes): -839.17 ± 1136.46
# Episode 240 finished with reward: -1843.51
# Moving average (last 50 episodes): -883.55 ± 1131.48
# Episode 241 finished with reward: -1329.72
# Moving average (last 50 episodes): -912.85 ± 1123.65
# Episode 242 finished with reward: -78.15
# Moving average (last 50 episodes): -921.65 ± 1115.33
# Episode 243 finished with reward: 248.84
# Moving average (last 50 episodes): -900.46 ± 1127.24
# Episode 244 finished with reward: -672.18
# Moving average (last 50 episodes): -863.25 ± 1103.20
# Episode 245 finished with reward: -2630.29
# Moving average (last 50 episodes): -869.30 ± 1112.02
# Episode 246 finished with reward: -1673.65
# Moving average (last 50 episodes): -906.83 ± 1106.86
# Episode 247 finished with reward: -1274.39
# Moving average (last 50 episodes): -915.84 ± 1107.98
# Episode 248 finished with reward: -2480.21
# Moving average (last 50 episodes): -938.12 ± 1127.84
# Episode 249 finished with reward: 333.30
# Moving average (last 50 episodes): -915.44 ± 1141.69
# Episode 250 finished with reward: -3292.13
# Moving average (last 50 episodes): -928.87 ± 1165.37
# Episode 251 finished with reward: -3360.14
# Moving average (last 50 episodes): -994.79 ± 1207.06
# Episode 252 finished with reward: -1790.52
# Moving average (last 50 episodes): -1027.32 ± 1206.15
# Episode 253 finished with reward: -2742.46
# Moving average (last 50 episodes): -1081.51 ± 1221.04
# Episode 254 finished with reward: -2934.29
# Moving average (last 50 episodes): -1136.42 ± 1241.22
# Episode 255 finished with reward: -2001.67
# Moving average (last 50 episodes): -1112.07 ± 1211.71
# Episode 256 finished with reward: 349.44
# Moving average (last 50 episodes): -1106.68 ± 1217.59
# Episode 257 finished with reward: -910.27
# Moving average (last 50 episodes): -1131.90 ± 1200.07
# Episode 258 finished with reward: 376.86
# Moving average (last 50 episodes): -1122.61 ± 1209.88
# Episode 259 finished with reward: -1961.89
# Moving average (last 50 episodes): -1126.87 ± 1212.45
# Episode 260 finished with reward: -1426.31
# Moving average (last 50 episodes): -1153.84 ± 1203.78
# Episode 261 finished with reward: -59.68
# Moving average (last 50 episodes): -1121.32 ± 1210.92
# Episode 262 finished with reward: 206.12
# Moving average (last 50 episodes): -1123.22 ± 1208.76
# Episode 263 finished with reward: -3020.43
# Moving average (last 50 episodes): -1190.69 ± 1218.58
# Episode 264 finished with reward: -335.81
# Moving average (last 50 episodes): -1175.25 ± 1224.41
# Episode 265 finished with reward: -1064.09
# Moving average (last 50 episodes): -1131.34 ± 1187.69
# Episode 266 finished with reward: -3515.67
# Moving average (last 50 episodes): -1167.10 ± 1231.23
# Episode 267 finished with reward: -1055.03
# Moving average (last 50 episodes): -1191.45 ± 1216.65
# Episode 268 finished with reward: -2645.05
# Moving average (last 50 episodes): -1197.47 ± 1223.07
# Episode 269 finished with reward: -1703.83
# Moving average (last 50 episodes): -1238.48 ± 1204.85
# Episode 270 finished with reward: -1593.23
# Moving average (last 50 episodes): -1277.09 ± 1184.50
# Episode 271 finished with reward: -1171.18
# Moving average (last 50 episodes): -1299.41 ± 1171.71
# Episode 272 finished with reward: -3067.59
# Moving average (last 50 episodes): -1321.05 ± 1193.96
# Episode 273 finished with reward: 129.30
# Moving average (last 50 episodes): -1321.25 ± 1193.72
# Episode 274 finished with reward: -998.02
# Moving average (last 50 episodes): -1347.87 ± 1171.17
# Episode 275 finished with reward: -505.98
# Moving average (last 50 episodes): -1298.10 ± 1152.87
# Episode 276 finished with reward: -3106.03
# Moving average (last 50 episodes): -1330.57 ± 1180.14
# Episode 277 finished with reward: -157.27
# Moving average (last 50 episodes): -1277.73 ± 1172.32
# Episode 278 finished with reward: -2902.66
# Moving average (last 50 episodes): -1290.57 ± 1186.45
# Episode 279 finished with reward: -2948.74
# Moving average (last 50 episodes): -1330.15 ± 1207.90
# Episode 280 finished with reward: -2513.60
# Moving average (last 50 episodes): -1367.20 ± 1215.20
# Episode 281 finished with reward: -2151.44
# Moving average (last 50 episodes): -1416.12 ± 1196.40
# Episode 282 finished with reward: -1918.90
# Moving average (last 50 episodes): -1461.42 ± 1171.45
# Episode 283 finished with reward: -2668.41
# Moving average (last 50 episodes): -1463.08 ± 1173.09
# Episode 284 finished with reward: -2456.07
# Moving average (last 50 episodes): -1498.23 ± 1175.98
# Episode 285 finished with reward: 379.86
# Moving average (last 50 episodes): -1465.34 ± 1204.70
# Episode 286 finished with reward: -518.90
# Moving average (last 50 episodes): -1457.67 ± 1209.47
# Episode 287 finished with reward: 153.03
# Moving average (last 50 episodes): -1444.33 ± 1223.40
# Episode 288 finished with reward: -283.84
# Moving average (last 50 episodes): -1452.18 ± 1214.64
# Episode 289 finished with reward: -1301.97
# Moving average (last 50 episodes): -1477.77 ± 1197.61
# Episode 290 finished with reward: -563.74
# Moving average (last 50 episodes): -1452.17 ± 1203.18
# Episode 291 finished with reward: -1962.96
# Moving average (last 50 episodes): -1464.84 ± 1205.16
# Episode 292 finished with reward: -1258.97
# Moving average (last 50 episodes): -1488.46 ± 1189.22
# Episode 293 finished with reward: -574.26
# Moving average (last 50 episodes): -1504.92 ± 1170.61
# Episode 294 finished with reward: -2389.66
# Moving average (last 50 episodes): -1539.27 ± 1170.87
# Episode 295 finished with reward: -735.80
# Moving average (last 50 episodes): -1501.38 ± 1165.59
# Episode 296 finished with reward: -500.05
# Moving average (last 50 episodes): -1477.91 ± 1173.67
# Episode 297 finished with reward: -3693.18
# Moving average (last 50 episodes): -1526.28 ± 1213.46
# Episode 298 finished with reward: -2765.85
# Moving average (last 50 episodes): -1531.99 ± 1218.60
# Episode 299 finished with reward: -2334.36
# Moving average (last 50 episodes): -1585.35 ± 1193.91
# Episode 300 finished with reward: -2847.07
# Moving average (last 50 episodes): -1576.45 ± 1182.76
# Episode 301 finished with reward: -465.69
# Moving average (last 50 episodes): -1518.56 ± 1164.74
# Episode 302 finished with reward: -1716.00
# Moving average (last 50 episodes): -1517.07 ± 1164.44
# Episode 303 finished with reward: -130.18
# Moving average (last 50 episodes): -1464.82 ± 1166.89
# Episode 304 finished with reward: -2054.44
# Moving average (last 50 episodes): -1447.22 ± 1151.12
# Episode 305 finished with reward: -1793.28
# Moving average (last 50 episodes): -1443.06 ± 1149.48
# Episode 306 finished with reward: -2998.23
# Moving average (last 50 episodes): -1510.01 ± 1140.59
# Episode 307 finished with reward: -2650.71
# Moving average (last 50 episodes): -1544.82 ± 1148.28
# Episode 308 finished with reward: -2763.98
# Moving average (last 50 episodes): -1607.64 ± 1127.16
# Episode 309 finished with reward: -2986.01
# Moving average (last 50 episodes): -1628.12 ± 1142.61
# Episode 310 finished with reward: -2077.24
# Moving average (last 50 episodes): -1641.14 ± 1143.94
# Episode 311 finished with reward: -1727.35
# Moving average (last 50 episodes): -1674.49 ± 1121.43
# Episode 312 finished with reward: -2905.59
# Moving average (last 50 episodes): -1736.72 ± 1101.51
# Episode 313 finished with reward: -3199.13
# Moving average (last 50 episodes): -1740.30 ± 1105.95
# Episode 314 finished with reward: 237.77
# Moving average (last 50 episodes): -1728.83 ± 1123.30
# Episode 315 finished with reward: 120.79
# Moving average (last 50 episodes): -1705.13 ± 1149.27
# Episode 316 finished with reward: -2809.24
# Moving average (last 50 episodes): -1691.00 ± 1131.12
# Episode 317 finished with reward: -2595.23
# Moving average (last 50 episodes): -1721.80 ± 1134.35
# Episode 318 finished with reward: -3806.21
# Moving average (last 50 episodes): -1745.03 ± 1164.50
# Episode 319 finished with reward: -2562.42
# Moving average (last 50 episodes): -1762.20 ± 1170.08
# Episode 320 finished with reward: 381.03
# Moving average (last 50 episodes): -1722.71 ± 1207.82
# Episode 321 finished with reward: -2535.63
# Moving average (last 50 episodes): -1750.00 ± 1210.46
# Episode 322 finished with reward: -64.83
# Moving average (last 50 episodes): -1689.95 ± 1218.07
# Episode 323 finished with reward: -91.07
# Moving average (last 50 episodes): -1694.35 ± 1211.86
# Episode 324 finished with reward: -3126.80
# Moving average (last 50 episodes): -1736.93 ± 1223.98
# Episode 325 finished with reward: -2338.72
# Moving average (last 50 episodes): -1773.59 ± 1213.97
# Episode 326 finished with reward: -70.52
# Moving average (last 50 episodes): -1712.87 ± 1221.70
# Episode 327 finished with reward: -1398.66
# Moving average (last 50 episodes): -1737.70 ± 1202.29
# Episode 328 finished with reward: -2452.84
# Moving average (last 50 episodes): -1728.71 ± 1195.20
# Episode 329 finished with reward: -40.62
# Moving average (last 50 episodes): -1670.54 ± 1205.13
# Episode 330 finished with reward: -2928.84
# Moving average (last 50 episodes): -1678.85 ± 1212.32
# Episode 331 finished with reward: 370.72
# Moving average (last 50 episodes): -1628.41 ± 1243.68
# Episode 332 finished with reward: -2333.77
# Moving average (last 50 episodes): -1636.70 ± 1246.97
# Episode 333 finished with reward: -900.46
# Moving average (last 50 episodes): -1601.34 ± 1242.27
# Episode 334 finished with reward: -2804.69
# Moving average (last 50 episodes): -1608.32 ± 1248.01
# Episode 335 finished with reward: -1647.09
# Moving average (last 50 episodes): -1648.86 ± 1215.26
# Episode 336 finished with reward: -2472.44
# Moving average (last 50 episodes): -1687.93 ± 1209.69
# Episode 337 finished with reward: -3258.43
# Moving average (last 50 episodes): -1756.16 ± 1200.11
# Episode 338 finished with reward: -2261.33
# Moving average (last 50 episodes): -1795.70 ± 1183.40
# Episode 339 finished with reward: -2587.98
# Moving average (last 50 episodes): -1821.43 ± 1186.36
# Episode 340 finished with reward: -1828.16
# Moving average (last 50 episodes): -1846.71 ± 1172.68
# Episode 341 finished with reward: 204.85
# Moving average (last 50 episodes): -1803.36 ± 1207.15
# Episode 342 finished with reward: -585.80
# Moving average (last 50 episodes): -1789.89 ± 1216.86
# Episode 343 finished with reward: -783.06
# Moving average (last 50 episodes): -1794.07 ± 1213.03
# Episode 344 finished with reward: -2647.49
# Moving average (last 50 episodes): -1799.23 ± 1216.10
# Episode 345 finished with reward: 341.86
# Moving average (last 50 episodes): -1777.67 ± 1243.99
# Episode 346 finished with reward: -2671.33
# Moving average (last 50 episodes): -1821.10 ± 1236.50
# Episode 347 finished with reward: -1593.69
# Moving average (last 50 episodes): -1779.11 ± 1207.53
# Episode 348 finished with reward: -61.98
# Moving average (last 50 episodes): -1725.03 ± 1222.58
# Episode 349 finished with reward: -3758.56
# Moving average (last 50 episodes): -1753.52 ± 1252.66
# Episode 350 finished with reward: 345.90
# Moving average (last 50 episodes): -1689.66 ± 1276.45
# Episode 351 finished with reward: -1024.50
# Moving average (last 50 episodes): -1700.83 ± 1268.10
# Episode 352 finished with reward: 14.24
# Moving average (last 50 episodes): -1666.23 ± 1290.62
# Episode 353 finished with reward: 47.15
# Moving average (last 50 episodes): -1662.68 ± 1295.07
# Episode 354 finished with reward: -2774.54
# Moving average (last 50 episodes): -1677.08 ± 1303.33
# Episode 355 finished with reward: -2965.10
# Moving average (last 50 episodes): -1700.52 ± 1315.68
# Episode 356 finished with reward: -202.07
# Moving average (last 50 episodes): -1644.60 ± 1318.76
# Episode 357 finished with reward: -1637.80
# Moving average (last 50 episodes): -1624.34 ± 1310.90
# Episode 358 finished with reward: -2339.11
# Moving average (last 50 episodes): -1615.84 ± 1304.85
# Episode 359 finished with reward: -1131.32
# Moving average (last 50 episodes): -1578.75 ± 1291.67
# Episode 360 finished with reward: -2191.63
# Moving average (last 50 episodes): -1581.03 ± 1292.65
# Episode 361 finished with reward: -2670.11
# Moving average (last 50 episodes): -1599.89 ± 1301.49
# Episode 362 finished with reward: -2832.56
# Moving average (last 50 episodes): -1598.43 ± 1300.07
# Episode 363 finished with reward: -2242.29
# Moving average (last 50 episodes): -1579.29 ± 1283.30
# Episode 364 finished with reward: -2572.53
# Moving average (last 50 episodes): -1635.50 ± 1263.88
# Episode 365 finished with reward: 280.05
# Moving average (last 50 episodes): -1632.31 ± 1268.49
# Episode 366 finished with reward: -1919.33
# Moving average (last 50 episodes): -1614.52 ± 1258.06
# Episode 367 finished with reward: -2673.69
# Moving average (last 50 episodes): -1616.08 ± 1259.33
# Episode 368 finished with reward: -2567.09
# Moving average (last 50 episodes): -1591.30 ± 1227.78
# Episode 369 finished with reward: -3251.64
# Moving average (last 50 episodes): -1605.09 ± 1242.39
# Episode 370 finished with reward: -857.91
# Moving average (last 50 episodes): -1629.87 ± 1214.57
# Episode 371 finished with reward: -4239.52
# Moving average (last 50 episodes): -1663.94 ± 1262.47
# Episode 372 finished with reward: 356.62
# Moving average (last 50 episodes): -1655.51 ± 1274.47
# Episode 373 finished with reward: -1792.39
# Moving average (last 50 episodes): -1689.54 ± 1254.80
# Episode 374 finished with reward: -2547.73
# Moving average (last 50 episodes): -1677.96 ± 1244.11
# Episode 375 finished with reward: -59.26
# Moving average (last 50 episodes): -1632.37 ± 1260.72
# Episode 376 finished with reward: -2889.68
# Moving average (last 50 episodes): -1688.75 ± 1252.62
# Episode 377 finished with reward: 337.21
# Moving average (last 50 episodes): -1654.04 ± 1283.85
# Episode 378 finished with reward: -384.03
# Moving average (last 50 episodes): -1612.66 ± 1290.75
# Episode 379 finished with reward: -2825.10
# Moving average (last 50 episodes): -1668.35 ± 1281.76
# Episode 380 finished with reward: 104.58
# Moving average (last 50 episodes): -1607.68 ± 1292.41
# Episode 381 finished with reward: -2624.41
# Moving average (last 50 episodes): -1667.58 ± 1268.51
# Episode 382 finished with reward: -2966.28
# Moving average (last 50 episodes): -1680.23 ± 1278.21
# Episode 383 finished with reward: 180.06
# Moving average (last 50 episodes): -1658.62 ± 1300.16
# Episode 384 finished with reward: -2549.01
# Moving average (last 50 episodes): -1653.51 ± 1296.14
# Episode 385 finished with reward: -2479.40
# Moving average (last 50 episodes): -1670.16 ± 1301.28
# Episode 386 finished with reward: -3166.46
# Moving average (last 50 episodes): -1684.04 ± 1313.41
# Episode 387 finished with reward: -86.53
# Moving average (last 50 episodes): -1620.60 ± 1312.44
# Episode 388 finished with reward: -3586.61
# Moving average (last 50 episodes): -1647.10 ± 1338.24
# Episode 389 finished with reward: -1243.32
# Moving average (last 50 episodes): -1620.21 ± 1332.56
# Episode 390 finished with reward: -2457.44
# Moving average (last 50 episodes): -1632.80 ± 1337.43
# Episode 391 finished with reward: -3205.44
# Moving average (last 50 episodes): -1701.00 ± 1328.90
# Episode 392 finished with reward: -1816.07
# Moving average (last 50 episodes): -1725.61 ± 1319.38
# Episode 393 finished with reward: -1297.83
# Moving average (last 50 episodes): -1735.90 ± 1313.98
# Episode 394 finished with reward: -2335.91
# Moving average (last 50 episodes): -1729.67 ± 1310.38
# Episode 395 finished with reward: 316.97
# Moving average (last 50 episodes): -1730.17 ± 1309.60
# Episode 396 finished with reward: -820.18
# Moving average (last 50 episodes): -1693.15 ± 1308.63
# Episode 397 finished with reward: -1917.18
# Moving average (last 50 episodes): -1699.62 ± 1308.92
# Episode 398 finished with reward: -1922.19
# Moving average (last 50 episodes): -1736.82 ± 1288.12
# Episode 399 finished with reward: -3095.63
# Moving average (last 50 episodes): -1723.56 ± 1270.53
# Episode 400 finished with reward: -3900.86
# Moving average (last 50 episodes): -1808.50 ± 1271.30
# Episode 401 finished with reward: -3316.29
# Moving average (last 50 episodes): -1854.33 ± 1283.46
# Episode 402 finished with reward: -2675.55
# Moving average (last 50 episodes): -1908.13 ± 1260.17
# Episode 403 finished with reward: -1350.23
# Moving average (last 50 episodes): -1936.08 ± 1231.67
# Episode 404 finished with reward: 326.03
# Moving average (last 50 episodes): -1874.06 ± 1265.49
# Episode 405 finished with reward: -3507.70
# Moving average (last 50 episodes): -1884.92 ± 1277.07
# Episode 406 finished with reward: -2214.27
# Moving average (last 50 episodes): -1925.16 ± 1254.92
# Episode 407 finished with reward: -2756.12
# Moving average (last 50 episodes): -1947.53 ± 1259.55
# Episode 408 finished with reward: -596.51
# Moving average (last 50 episodes): -1912.67 ± 1272.28
# Episode 409 finished with reward: -3555.01
# Moving average (last 50 episodes): -1961.15 ± 1287.67
# Episode 410 finished with reward: -1977.09
# Moving average (last 50 episodes): -1956.86 ± 1287.25
# Episode 411 finished with reward: 360.42
# Moving average (last 50 episodes): -1896.25 ± 1323.09
# Episode 412 finished with reward: -1939.24
# Moving average (last 50 episodes): -1878.38 ± 1316.34
# Episode 413 finished with reward: -625.09
# Moving average (last 50 episodes): -1846.04 ± 1326.82
# Episode 414 finished with reward: -2594.68
# Moving average (last 50 episodes): -1846.48 ± 1327.07
# Episode 415 finished with reward: -2019.54
# Moving average (last 50 episodes): -1892.47 ± 1291.96
# Episode 416 finished with reward: -2765.58
# Moving average (last 50 episodes): -1909.40 ± 1297.73
# Episode 417 finished with reward: -2840.33
# Moving average (last 50 episodes): -1912.73 ± 1299.90
# Episode 418 finished with reward: -1483.53
# Moving average (last 50 episodes): -1891.06 ± 1297.84
# Episode 419 finished with reward: -1638.74
# Moving average (last 50 episodes): -1858.80 ± 1283.59
# Episode 420 finished with reward: -2654.87
# Moving average (last 50 episodes): -1894.74 ± 1280.21
# Episode 421 finished with reward: -2273.03
# Moving average (last 50 episodes): -1855.41 ± 1237.05
# Episode 422 finished with reward: -4084.98
# Moving average (last 50 episodes): -1944.24 ± 1234.49
# Episode 423 finished with reward: -2912.26
# Moving average (last 50 episodes): -1966.64 ± 1241.67
# Episode 424 finished with reward: -2694.64
# Moving average (last 50 episodes): -1969.58 ± 1243.22
# Episode 425 finished with reward: -1114.72
# Moving average (last 50 episodes): -1990.69 ± 1219.33
# Episode 426 finished with reward: -2541.24
# Moving average (last 50 episodes): -1983.72 ± 1215.16
# Episode 427 finished with reward: -1151.07
# Moving average (last 50 episodes): -2013.48 ± 1175.53
# Episode 428 finished with reward: -2092.01
# Moving average (last 50 episodes): -2047.64 ± 1152.27
# Episode 429 finished with reward: -3625.00
# Moving average (last 50 episodes): -2063.64 ± 1168.39
# Episode 430 finished with reward: -3941.20
# Moving average (last 50 episodes): -2144.56 ± 1155.45
# Episode 431 finished with reward: -3422.91
# Moving average (last 50 episodes): -2160.53 ± 1167.43
# Episode 432 finished with reward: -2418.05
# Moving average (last 50 episodes): -2149.56 ± 1162.37
# Episode 433 finished with reward: -827.65
# Moving average (last 50 episodes): -2169.72 ± 1130.10
# Episode 434 finished with reward: 314.46
# Moving average (last 50 episodes): -2112.45 ± 1180.84
# Episode 435 finished with reward: -55.71
# Moving average (last 50 episodes): -2063.97 ± 1214.06
# Episode 436 finished with reward: -3155.89
# Moving average (last 50 episodes): -2063.76 ± 1213.87
# Episode 437 finished with reward: -3178.37
# Moving average (last 50 episodes): -2125.60 ± 1190.09
# Episode 438 finished with reward: -240.31
# Moving average (last 50 episodes): -2058.67 ± 1200.09
# Episode 439 finished with reward: -3131.81
# Moving average (last 50 episodes): -2096.44 ± 1203.55
# Episode 440 finished with reward: 341.11
# Moving average (last 50 episodes): -2040.47 ± 1249.65
# Episode 441 finished with reward: -2630.46
# Moving average (last 50 episodes): -2028.97 ± 1241.50
# Episode 442 finished with reward: -3040.57
# Moving average (last 50 episodes): -2053.46 ± 1249.11
# Episode 443 finished with reward: -3349.21
# Moving average (last 50 episodes): -2094.49 ± 1257.28
# Episode 444 finished with reward: 174.14
# Moving average (last 50 episodes): -2044.29 ± 1296.15
# Episode 445 finished with reward: -3212.13
# Moving average (last 50 episodes): -2114.87 ± 1261.26
# Episode 446 finished with reward: -3807.18
# Moving average (last 50 episodes): -2174.61 ± 1269.24
# Episode 447 finished with reward: -719.89
# Moving average (last 50 episodes): -2150.66 ± 1285.07
# Episode 448 finished with reward: -4111.45
# Moving average (last 50 episodes): -2194.45 ± 1313.52
# Episode 449 finished with reward: -2381.57
# Moving average (last 50 episodes): -2180.17 ± 1307.51
# Episode 450 finished with reward: -5176.30
# Moving average (last 50 episodes): -2205.68 ± 1352.50
# Episode 451 finished with reward: -1689.89
# Moving average (last 50 episodes): -2173.15 ± 1344.93
# Episode 452 finished with reward: 359.30
# Moving average (last 50 episodes): -2112.45 ± 1388.66
# Episode 453 finished with reward: -2418.89
# Moving average (last 50 episodes): -2133.82 ± 1384.98
# Episode 454 finished with reward: -3601.69
# Moving average (last 50 episodes): -2212.38 ± 1354.28
# Episode 455 finished with reward: -2867.33
# Moving average (last 50 episodes): -2199.57 ± 1344.97
# Episode 456 finished with reward: -4264.39
# Moving average (last 50 episodes): -2240.57 ± 1375.69
# Episode 457 finished with reward: -553.28
# Moving average (last 50 episodes): -2196.52 ± 1393.63
# Episode 458 finished with reward: -2578.04
# Moving average (last 50 episodes): -2236.15 ± 1375.63
# Episode 459 finished with reward: -290.44
# Moving average (last 50 episodes): -2170.86 ± 1388.89
# Episode 460 finished with reward: -3138.39
# Moving average (last 50 episodes): -2194.08 ± 1395.15
# Episode 461 finished with reward: -3656.14
# Moving average (last 50 episodes): -2274.41 ± 1360.97
# Episode 462 finished with reward: -2886.01
# Moving average (last 50 episodes): -2293.35 ± 1362.76
# Episode 463 finished with reward: -3679.16
# Moving average (last 50 episodes): -2354.43 ± 1355.04
# Episode 464 finished with reward: -2143.80
# Moving average (last 50 episodes): -2345.41 ± 1354.91
# Episode 465 finished with reward: -3792.49
# Moving average (last 50 episodes): -2380.87 ± 1369.04
# Episode 466 finished with reward: 53.01
# Moving average (last 50 episodes): -2324.50 ± 1409.47
# Episode 467 finished with reward: -3412.39
# Moving average (last 50 episodes): -2335.94 ± 1415.92
# Episode 468 finished with reward: -2940.33
# Moving average (last 50 episodes): -2365.08 ± 1413.07
# Episode 469 finished with reward: -56.21
# Moving average (last 50 episodes): -2333.43 ± 1446.31
# Episode 470 finished with reward: -2923.91
# Moving average (last 50 episodes): -2338.81 ± 1448.00
# Episode 471 finished with reward: -1487.62
# Moving average (last 50 episodes): -2323.10 ± 1452.88
# Episode 472 finished with reward: 60.45
# Moving average (last 50 episodes): -2240.19 ± 1468.17
# Episode 473 finished with reward: -2956.42
# Moving average (last 50 episodes): -2241.07 ± 1468.59
# Episode 474 finished with reward: -2822.22
# Moving average (last 50 episodes): -2243.63 ± 1469.49
# Episode 475 finished with reward: -1758.90
# Moving average (last 50 episodes): -2256.51 ± 1462.34
# Episode 476 finished with reward: 198.28
# Moving average (last 50 episodes): -2201.72 ± 1501.44
# Episode 477 finished with reward: -3229.68
# Moving average (last 50 episodes): -2243.29 ± 1500.55
# Episode 478 finished with reward: -3291.32
# Moving average (last 50 episodes): -2267.28 ± 1507.51
# Episode 479 finished with reward: -982.60
# Moving average (last 50 episodes): -2214.43 ± 1505.30
# Episode 480 finished with reward: -2879.76
# Moving average (last 50 episodes): -2193.20 ± 1488.19
# Episode 481 finished with reward: -3954.66
# Moving average (last 50 episodes): -2203.83 ± 1498.80
# Episode 482 finished with reward: -2526.62
# Moving average (last 50 episodes): -2206.01 ± 1499.19
# Episode 483 finished with reward: -1981.43
# Moving average (last 50 episodes): -2229.08 ± 1486.62
# Episode 484 finished with reward: -3193.91
# Moving average (last 50 episodes): -2299.25 ± 1447.19
# Episode 485 finished with reward: -3119.41
# Moving average (last 50 episodes): -2360.52 ± 1415.41
# Episode 486 finished with reward: -4210.68
# Moving average (last 50 episodes): -2381.62 ± 1434.83
# Episode 487 finished with reward: -3519.93
# Moving average (last 50 episodes): -2388.45 ± 1439.41
# Episode 488 finished with reward: -771.27
# Moving average (last 50 episodes): -2399.07 ± 1425.42
# Episode 489 finished with reward: -1192.57
# Moving average (last 50 episodes): -2360.28 ± 1431.32
# Episode 490 finished with reward: -2860.35
# Moving average (last 50 episodes): -2424.31 ± 1379.72
# Episode 491 finished with reward: -3113.38
# Moving average (last 50 episodes): -2433.97 ± 1382.82
# Episode 492 finished with reward: -2513.75
# Moving average (last 50 episodes): -2423.44 ± 1380.16
# Episode 493 finished with reward: 127.43
# Moving average (last 50 episodes): -2353.90 ± 1418.80
# Episode 494 finished with reward: -1925.56
# Moving average (last 50 episodes): -2395.90 ± 1373.71
# Episode 495 finished with reward: -2952.82
# Moving average (last 50 episodes): -2390.71 ± 1371.11
# Episode 496 finished with reward: -3915.47
# Moving average (last 50 episodes): -2392.88 ± 1373.43
# Episode 497 finished with reward: -2440.82
# Moving average (last 50 episodes): -2427.30 ± 1352.48
# Episode 498 finished with reward: -3744.26
# Moving average (last 50 episodes): -2419.95 ± 1344.28
# Episode 499 finished with reward: -3128.85
# Moving average (last 50 episodes): -2434.90 ± 1347.92
# Episode 500 finished with reward: -691.42
# Moving average (last 50 episodes): -2345.20 ± 1311.24
# Episode 501 finished with reward: -4246.45
# Moving average (last 50 episodes): -2396.33 ± 1334.33
# Episode 502 finished with reward: -2752.69
# Moving average (last 50 episodes): -2458.57 ± 1275.63
# Episode 503 finished with reward: -252.27
# Moving average (last 50 episodes): -2415.24 ± 1312.51
# ...
# Episode 1184 finished with reward: -7185.59
# Moving average (last 50 episodes): -3903.29 ± 2117.83
# Episode 1185 finished with reward: -5915.04
# Moving average (last 50 episodes): -3926.49 ± 2133.33
# Episode 1186 finished with reward: -6133.10
# Moving average (last 50 episodes): -3943.13 ± 2147.19
# Episode 1187 finished with reward: -5379.13
# Moving average (last 50 episodes): -4046.76 ± 2088.15
# Episode 1188 finished with reward: -5217.00
# Moving average (last 50 episodes): -4014.64 ± 2057.31
# Episode 1189 finished with reward: -5665.30
# Moving average (last 50 episodes): -3991.35 ± 2031.75
# Episode 1190 finished with reward: -5012.86
# Moving average (last 50 episodes): -4088.64 ± 1960.64
# Episode 1191 finished with reward: -2748.93
# Moving average (last 50 episodes): -4148.60 ± 1870.84
# Episode 1192 finished with reward: -2167.99
# Moving average (last 50 episodes): -4100.99 ± 1890.25
# Episode 1193 finished with reward: -4406.67
# Moving average (last 50 episodes): -4127.25 ± 1885.19
# Episode 1194 finished with reward: -5891.69
# Moving average (last 50 episodes): -4164.39 ± 1901.22
# Episode 1195 finished with reward: -6119.65
# Moving average (last 50 episodes): -4295.74 ± 1802.33
# Episode 1196 finished with reward: -4513.26
# Moving average (last 50 episodes): -4389.72 ± 1684.90
# Episode 1197 finished with reward: -7444.45
# Moving average (last 50 episodes): -4454.69 ± 1737.97
# Episode 1198 finished with reward: -5047.12
# Moving average (last 50 episodes): -4500.53 ± 1722.69
# Episode 1199 finished with reward: -5424.06
# Moving average (last 50 episodes): -4542.14 ± 1719.37
# Episode 1200 finished with reward: -5372.65
# Moving average (last 50 episodes): -4558.54 ± 1723.30
# Episode 1201 finished with reward: -5959.03
# Moving average (last 50 episodes): -4596.90 ± 1732.67
# Episode 1202 finished with reward: -6532.02
# Moving average (last 50 episodes): -4657.60 ± 1746.19
# Episode 1203 finished with reward: -5674.71
# Moving average (last 50 episodes): -4674.01 ± 1751.81
# Episode 1204 finished with reward: -5628.04
# Moving average (last 50 episodes): -4698.45 ± 1756.42
# Episode 1205 finished with reward: -3787.51
# Moving average (last 50 episodes): -4708.08 ± 1750.07
# Episode 1206 finished with reward: -4837.06
# Moving average (last 50 episodes): -4720.41 ± 1748.76
# Episode 1207 finished with reward: -5874.36
# Moving average (last 50 episodes): -4774.47 ± 1741.80
# Episode 1208 finished with reward: -5842.17
# Moving average (last 50 episodes): -4806.86 ± 1746.29
# Episode 1209 finished with reward: -6237.15
# Moving average (last 50 episodes): -4814.80 ± 1751.87
# Episode 1210 finished with reward: -5528.62
# Moving average (last 50 episodes): -4843.60 ± 1751.53
# Episode 1211 finished with reward: -5843.09
# Moving average (last 50 episodes): -4866.41 ± 1756.96
# Episode 1212 finished with reward: -5263.95
# Moving average (last 50 episodes): -4885.74 ± 1755.91
# Episode 1213 finished with reward: -6623.25
# Moving average (last 50 episodes): -4965.77 ± 1742.04
# Episode 1214 finished with reward: -5546.84
# Moving average (last 50 episodes): -5066.64 ± 1622.65
# Episode 1215 finished with reward: -3852.15
# Moving average (last 50 episodes): -5024.79 ± 1626.44
# Episode 1216 finished with reward: -3342.61
# Moving average (last 50 episodes): -4989.30 ± 1643.31
# Episode 1217 finished with reward: -4468.69
# Moving average (last 50 episodes): -5057.41 ± 1546.92
# Episode 1218 finished with reward: -6237.71
# Moving average (last 50 episodes): -5181.60 ± 1378.25
# Episode 1219 finished with reward: -5144.58
# Moving average (last 50 episodes): -5161.52 ± 1371.31
# Episode 1220 finished with reward: -4118.76
# Moving average (last 50 episodes): -5137.25 ± 1378.79
# Episode 1221 finished with reward: -4287.99
# Moving average (last 50 episodes): -5103.10 ± 1378.26
# Episode 1222 finished with reward: -3118.53
# Moving average (last 50 episodes): -5061.83 ± 1405.89
# Episode 1223 finished with reward: -6364.77
# Moving average (last 50 episodes): -5101.39 ± 1414.15
# Episode 1224 finished with reward: -6736.14
# Moving average (last 50 episodes): -5199.58 ± 1352.45
# Episode 1225 finished with reward: -6310.73
# Moving average (last 50 episodes): -5240.45 ± 1354.53
# Episode 1226 finished with reward: -4486.68
# Moving average (last 50 episodes): -5208.73 ± 1353.24
# Episode 1227 finished with reward: -3183.86
# Moving average (last 50 episodes): -5204.63 ± 1359.05
# Episode 1228 finished with reward: -6137.81
# Moving average (last 50 episodes): -5328.90 ± 1136.37
# Episode 1229 finished with reward: -5437.19
# Moving average (last 50 episodes): -5334.10 ± 1136.26
# Episode 1230 finished with reward: -5228.42
# Moving average (last 50 episodes): -5322.84 ± 1134.46
# Episode 1231 finished with reward: -4399.46
# Moving average (last 50 episodes): -5285.18 ± 1133.24
# Episode 1232 finished with reward: -3188.64
# Moving average (last 50 episodes): -5224.14 ± 1161.96
# Episode 1233 finished with reward: -4674.59
# Moving average (last 50 episodes): -5190.83 ± 1153.33
# Episode 1234 finished with reward: -4271.83
# Moving average (last 50 episodes): -5132.56 ± 1124.32
# Episode 1235 finished with reward: -3309.93
# Moving average (last 50 episodes): -5080.45 ± 1146.98
# Episode 1236 finished with reward: -4105.77
# Moving average (last 50 episodes): -5039.91 ± 1144.89
# Episode 1237 finished with reward: -5109.29
# Moving average (last 50 episodes): -5034.51 ± 1143.91
# Episode 1238 finished with reward: -4792.35
# Moving average (last 50 episodes): -5026.02 ± 1144.10
# Episode 1239 finished with reward: -4455.27
# Moving average (last 50 episodes): -5001.82 ± 1143.12
# Episode 1240 finished with reward: -6579.36
# Moving average (last 50 episodes): -5033.15 ± 1164.26
# Episode 1241 finished with reward: -5747.60
# Moving average (last 50 episodes): -5093.12 ± 1121.50
# Episode 1242 finished with reward: -5992.60
# Moving average (last 50 episodes): -5169.61 ± 1047.36
# Episode 1243 finished with reward: -6713.80
# Moving average (last 50 episodes): -5215.76 ± 1063.43
# Episode 1244 finished with reward: -3896.29
# Moving average (last 50 episodes): -5175.85 ± 1074.70
# Episode 1245 finished with reward: -4075.53
# Moving average (last 50 episodes): -5134.97 ± 1076.90
# Episode 1246 finished with reward: -6034.66
# Moving average (last 50 episodes): -5165.39 ± 1080.39
# Episode 1247 finished with reward: -5120.44
# Moving average (last 50 episodes): -5118.91 ± 1030.17
# Episode 1248 finished with reward: -4490.99
# Moving average (last 50 episodes): -5107.79 ± 1033.88
# Episode 1249 finished with reward: -5909.52
# Moving average (last 50 episodes): -5117.50 ± 1039.07
# Episode 1250 finished with reward: -6875.44
# Moving average (last 50 episodes): -5147.56 ± 1067.36
# Episode 1251 finished with reward: -6511.33
# Moving average (last 50 episodes): -5158.60 ± 1078.50
# Episode 1252 finished with reward: -5260.98
# Moving average (last 50 episodes): -5133.18 ± 1060.66
# Episode 1253 finished with reward: -4356.52
# Moving average (last 50 episodes): -5106.82 ± 1063.25
# Episode 1254 finished with reward: -4880.31
# Moving average (last 50 episodes): -5091.86 ± 1061.07
# Episode 1255 finished with reward: -4776.76
# Moving average (last 50 episodes): -5111.65 ± 1045.68
# Episode 1256 finished with reward: -4458.46
# Moving average (last 50 episodes): -5104.08 ± 1049.01
# Episode 1257 finished with reward: 360.74
# Moving average (last 50 episodes): -4979.37 ± 1292.39
# Episode 1258 finished with reward: -4738.95
# Moving average (last 50 episodes): -4957.31 ± 1286.88
# Episode 1259 finished with reward: -3862.94
# Moving average (last 50 episodes): -4909.83 ± 1282.57
# Episode 1260 finished with reward: -3467.86
# Moving average (last 50 episodes): -4868.61 ± 1295.08
# Episode 1261 finished with reward: -5442.99
# Moving average (last 50 episodes): -4860.61 ± 1290.26
# Episode 1262 finished with reward: -4282.42
# Moving average (last 50 episodes): -4840.98 ± 1291.44
# Episode 1263 finished with reward: -4108.28
# Moving average (last 50 episodes): -4790.68 ± 1269.84
# Episode 1264 finished with reward: -5153.26
# Moving average (last 50 episodes): -4782.81 ± 1266.34
# Episode 1265 finished with reward: -5553.22
# Moving average (last 50 episodes): -4816.83 ± 1263.73
# Episode 1266 finished with reward: -5922.94
# Moving average (last 50 episodes): -4868.43 ± 1255.13
# Episode 1267 finished with reward: -4684.05
# Moving average (last 50 episodes): -4872.74 ± 1254.12
# Episode 1268 finished with reward: -4549.38
# Moving average (last 50 episodes): -4838.97 ± 1239.56
# Episode 1269 finished with reward: -4902.76
# Moving average (last 50 episodes): -4834.14 ± 1238.83
# Episode 1270 finished with reward: -6020.66
# Moving average (last 50 episodes): -4872.18 ± 1245.46
# Episode 1271 finished with reward: -4514.72
# Moving average (last 50 episodes): -4876.71 ± 1243.74
# Episode 1272 finished with reward: -5825.93
# Moving average (last 50 episodes): -4930.86 ± 1224.81
# Episode 1273 finished with reward: -5505.81
# Moving average (last 50 episodes): -4913.68 ± 1210.51
# Episode 1274 finished with reward: -6282.80
# Moving average (last 50 episodes): -4904.61 ± 1198.47
# Episode 1275 finished with reward: -5558.55
# Moving average (last 50 episodes): -4889.57 ± 1185.37
# Episode 1276 finished with reward: -4323.85
# Moving average (last 50 episodes): -4886.31 ± 1186.70
# Episode 1277 finished with reward: -6593.46
# Moving average (last 50 episodes): -4954.50 ± 1184.87
# Episode 1278 finished with reward: -4409.82
# Moving average (last 50 episodes): -4919.94 ± 1175.01
# Episode 1279 finished with reward: -5044.64
# Moving average (last 50 episodes): -4912.09 ± 1172.84
# Episode 1280 finished with reward: -7171.95
# Moving average (last 50 episodes): -4950.96 ± 1214.16
# Episode 1281 finished with reward: -6896.76
# Moving average (last 50 episodes): -5000.91 ± 1241.50
# Episode 1282 finished with reward: -5729.87
# Moving average (last 50 episodes): -5051.73 ± 1218.06
# Episode 1283 finished with reward: -4667.12
# Moving average (last 50 episodes): -5051.59 ± 1218.11
# Episode 1284 finished with reward: -6156.90
# Moving average (last 50 episodes): -5089.29 ± 1222.56
# Episode 1285 finished with reward: -5889.58
# Moving average (last 50 episodes): -5140.88 ± 1200.61
# Episode 1286 finished with reward: -6755.94
# Moving average (last 50 episodes): -5193.88 ± 1212.19
# Episode 1287 finished with reward: -4438.13
# Moving average (last 50 episodes): -5180.46 ± 1216.76
# Episode 1288 finished with reward: -4373.67
# Moving average (last 50 episodes): -5172.09 ± 1220.84
# Episode 1289 finished with reward: -7440.25
# Moving average (last 50 episodes): -5231.79 ± 1256.78
# Episode 1290 finished with reward: -5593.83
# Moving average (last 50 episodes): -5212.08 ± 1243.14
# Episode 1291 finished with reward: -4155.68
# Moving average (last 50 episodes): -5180.24 ± 1249.39
# Episode 1292 finished with reward: -6985.52
# Moving average (last 50 episodes): -5200.10 ± 1269.87
# Episode 1293 finished with reward: -6428.35
# Moving average (last 50 episodes): -5194.39 ± 1263.67
# Episode 1294 finished with reward: -6826.84
# Moving average (last 50 episodes): -5253.00 ± 1270.05
# Episode 1295 finished with reward: -5635.12
# Moving average (last 50 episodes): -5284.19 ± 1259.86
# Episode 1296 finished with reward: -5456.64
# Moving average (last 50 episodes): -5272.63 ± 1255.57
# Episode 1297 finished with reward: -6895.97
# Moving average (last 50 episodes): -5308.14 ± 1275.71
# Episode 1298 finished with reward: -6465.34
# Moving average (last 50 episodes): -5347.63 ± 1280.35
# Episode 1299 finished with reward: -4043.80
# Moving average (last 50 episodes): -5310.31 ± 1290.58
# Episode 1300 finished with reward: -4823.11
# Moving average (last 50 episodes): -5269.27 ± 1272.66
# Episode 1301 finished with reward: -7157.40
# Moving average (last 50 episodes): -5282.19 ± 1288.39
# Episode 1302 finished with reward: -5578.04
# Moving average (last 50 episodes): -5288.53 ± 1289.05
# Episode 1303 finished with reward: -6066.44
# Moving average (last 50 episodes): -5322.73 ± 1286.55
# Episode 1304 finished with reward: -4074.90
# Moving average (last 50 episodes): -5306.62 ± 1296.99
# Episode 1305 finished with reward: -6319.86
# Moving average (last 50 episodes): -5337.48 ± 1302.36
# Episode 1306 finished with reward: -5185.93
# Moving average (last 50 episodes): -5352.03 ± 1296.51
# Episode 1307 finished with reward: -5676.29
# Moving average (last 50 episodes): -5472.77 ± 1007.84
# Episode 1308 finished with reward: -5839.00
# Moving average (last 50 episodes): -5494.77 ± 1003.58
# Episode 1309 finished with reward: -5481.59
# Moving average (last 50 episodes): -5527.14 ± 976.15
# Episode 1310 finished with reward: -7128.69
# Moving average (last 50 episodes): -5600.36 ± 956.03
# Episode 1311 finished with reward: -6146.54
# Moving average (last 50 episodes): -5614.43 ± 958.78
# Episode 1312 finished with reward: -6441.44
# Moving average (last 50 episodes): -5657.61 ± 946.36
# Episode 1313 finished with reward: -4885.85
# Moving average (last 50 episodes): -5673.16 ± 926.96
# Episode 1314 finished with reward: -5559.89
# Moving average (last 50 episodes): -5681.30 ± 924.14
# Episode 1315 finished with reward: -4702.69
# Moving average (last 50 episodes): -5664.29 ± 934.12
# Episode 1316 finished with reward: -5689.25
# Moving average (last 50 episodes): -5659.61 ± 933.40
# Episode 1317 finished with reward: -5468.15
# Moving average (last 50 episodes): -5675.29 ± 923.41
# Episode 1318 finished with reward: -6170.56
# Moving average (last 50 episodes): -5707.72 ± 911.69
# Episode 1319 finished with reward: -6406.44
# Moving average (last 50 episodes): -5737.79 ± 909.44
# Episode 1320 finished with reward: -6224.55
# Moving average (last 50 episodes): -5741.87 ± 911.16
# Episode 1321 finished with reward: -5596.76
# Moving average (last 50 episodes): -5763.51 ± 894.45
# Episode 1322 finished with reward: -6455.10
# Moving average (last 50 episodes): -5776.09 ± 899.65
# Episode 1323 finished with reward: -4390.35
# Moving average (last 50 episodes): -5753.78 ± 919.68
# Episode 1324 finished with reward: -5908.83
# Moving average (last 50 episodes): -5746.30 ± 916.87
# Episode 1325 finished with reward: -6575.45
# Moving average (last 50 episodes): -5766.64 ± 923.73
# Episode 1326 finished with reward: -3304.21
# Moving average (last 50 episodes): -5746.25 ± 965.66
# Episode 1327 finished with reward: -6689.98
# Moving average (last 50 episodes): -5748.18 ± 967.45
# Episode 1328 finished with reward: -5843.05
# Moving average (last 50 episodes): -5776.84 ± 948.41
# Episode 1329 finished with reward: -4306.26
# Moving average (last 50 episodes): -5762.08 ± 965.30
# Episode 1330 finished with reward: -4844.11
# Moving average (last 50 episodes): -5715.52 ± 952.22
# Episode 1331 finished with reward: -3684.98
# Moving average (last 50 episodes): -5651.28 ± 978.35
# Episode 1332 finished with reward: -3511.05
# Moving average (last 50 episodes): -5606.91 ± 1023.07
# Episode 1333 finished with reward: -3611.61
# Moving average (last 50 episodes): -5585.80 ± 1052.71
# Episode 1334 finished with reward: -5252.56
# Moving average (last 50 episodes): -5567.71 ± 1050.51
# Episode 1335 finished with reward: -5901.06
# Moving average (last 50 episodes): -5567.94 ± 1050.58
# Episode 1336 finished with reward: -5330.54
# Moving average (last 50 episodes): -5539.43 ± 1037.21
# Episode 1337 finished with reward: -3500.36
# Moving average (last 50 episodes): -5520.68 ± 1065.06
# Episode 1338 finished with reward: -5859.39
# Moving average (last 50 episodes): -5550.39 ± 1053.30
# Episode 1339 finished with reward: -4168.93
# Moving average (last 50 episodes): -5484.97 ± 1035.33
# Episode 1340 finished with reward: -5701.61
# Moving average (last 50 episodes): -5487.12 ± 1035.67
# Episode 1341 finished with reward: -4634.77
# Moving average (last 50 episodes): -5496.70 ± 1025.47
# Episode 1342 finished with reward: -5433.79
# Moving average (last 50 episodes): -5465.67 ± 1003.18
# Episode 1343 finished with reward: -4242.83
# Moving average (last 50 episodes): -5421.96 ± 1007.89
# Episode 1344 finished with reward: -7307.92
# Moving average (last 50 episodes): -5431.58 ± 1023.43
# Episode 1345 finished with reward: -4814.23
# Moving average (last 50 episodes): -5415.16 ± 1026.61
# Episode 1346 finished with reward: -5994.12
# Moving average (last 50 episodes): -5425.91 ± 1029.80

# %%
# def plot_smooth_rewards(rewards, window_sizes=[5, 20, 100]):
#     """
#     绘制平滑的奖励曲线
#     Args:
#         rewards: 奖励列表
#         window_sizes: 移动平均窗口大小列表
#     """
#     plt.figure(figsize=(12, 6))
    
#     # 绘制原始奖励
#     plt.plot(rewards, 'lightgray', alpha=0.3, label='Raw rewards')
    
#     # 绘制不同窗口大小的移动平均
#     colors = ['blue', 'green', 'red']
#     for window, color in zip(window_sizes, colors):
#         if len(rewards) >= window:
#             # 计算移动平均
#             smooth_rewards = np.convolve(rewards, 
#                                       np.ones(window)/window, 
#                                       mode='valid')
#             plt.plot(range(window-1, len(rewards)), 
#                     smooth_rewards, 
#                     color=color, 
#                     label=f'{window}-Episode Moving Average',
#                     linewidth=2)
    
#     plt.xlabel('Episode')
#     plt.ylabel('Reward')
#     plt.title('Training Rewards with Different Smoothing Windows')
#     plt.grid(True, alpha=0.3)
#     plt.legend()
#     plt.show()


# # 绘制平滑奖励曲线
# plot_smooth_rewards(metrics["rewards"])

# %% [markdown]
# notes: 如果要训练过程中查看模型，通过 tensorboard 查看

# %%
# 模型保存
model.save(f"./model/{log_name}")

# %% [markdown]
# ### 评估模型训练结果

# %% [markdown]
# > 利用 evaulate policy 函数评估

# %% [markdown]
# # 加载训练好的 RL 模型

# %%
from stable_baselines3.common.evaluation import evaluate_policy
mean_reward, std_reward = evaluate_policy(
    model, 
    model.get_env(), 
    deterministic=True,
    render=True,
    n_eval_episodes=10)

print(mean_reward)
print(std_reward)

# %%
del model
# model = PPO.load(f"./model/{log_name}", env=env_monitor)
model = DQN.load(f"./model/{log_name}", env=env_monitor)

# %% [markdown]
# ### 结果展示

# %% [markdown]
# #### 纯净展示版本
#
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆

for ep in range(episodes):
    
    obs, _ = env_monitor.reset() # 必须的，每次重现一次
    episode_reward = 0
    done = False
     
     
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        print(f"year {env_monitor.t}-Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # # 每10步更新一次图像
        # if i == max_steps-1:
        #     env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            env_monitor.render()
            plt.show()  # 添加这行来保持图形窗口
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")

# %% [markdown]
# ### 保存整体运行结果

# %%
env_test = IEMEnv(reward_type=custom_reward_type)

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 3 # 结果展示，只有一个 episode 部分
max_steps = 250

# all_episode_rewards = [] # 记录所有 episode 里面的
 
for ep in range(episodes):
    
    ##################################
    # 记录所需数组：每次 episode 重置
    total_action = []
    total_state = []
    total_reward = []
    total_done = []
    ##################################
    # 记录每个 episode 的 reward
    episode_reward = 0
    ##################################
    
    obs, _ = env_test.reset() # 必须的，每次重现一次 ，这里可能就需要固定随机种子了
    done = False
    
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        ##################################
        # 添加转换的部分
        action_number, action_name = IEMEnv.action2number_env(action)
        total_action.append(action_number)
        total_state.append(obs)
        total_reward.append(reward)
        total_done.append(done)
        ##################################
        # 记录每个 episode 的 reward
        episode_reward += reward # TODO：可以放在内容记录 step 部分
        ################################## 
        
        if done:
            print(f"Episode {ep} finished at step {i}")
            break
        
        # # 每10步更新一次图像
        # if ep % 10 == 0:
        #     env_monitor.render()
        #     # plt.pause(0.01)
    
    # all_episode_rewards.append(episode_reward)
    
    env_test.append_data_reward(episode_reward)
    
    save_future_data(env=env_test,custom_reward_type=custom_reward_type,rl_model_name=rl_model_name,network_name=policy_kwargs_diy,episode=ep,total_action=total_action,total_state=total_state,total_reward=total_reward,total_done=total_done,total_timesteps_name=total_timesteps_diy)

    save_plot_NSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    save_plot_SSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    # plot_3D_run(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state)
    
    
    print(f"Episode {ep} finished with reward{episode_reward}")
    
    
plot_data = env_test.get_variables()
plot_episode_reward(plot_data)

# %% [markdown]
# 主要针对可视化显示部分操作

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 绘制只展示一次 episode 结果

# env_test

for episode in range(1):
    obs, _ = env_test.reset() # 这里可能就需要固定随机种子了
    
    done = False
    
    for i in range(251):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        
        if done:
            print(f"Episode {episode} finished at step {i}")
            break

# %% [markdown]
# # 保存运行结果
