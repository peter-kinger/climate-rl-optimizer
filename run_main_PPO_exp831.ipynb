# %% [markdown]
# # RL 训练

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import scipy.io
from matplotlib.gridspec import GridSpec
import math
import random
import torch

from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.logger import configure
from stable_baselines3.common.monitor import Monitor
from stable_baselines3 import PPO 
from stable_baselines3 import DQN

# 导入 BaseCallback
from stable_baselines3.common.callbacks import BaseCallback

import sys
import os

# 将 src 目录添加到模块搜索路径
sys.path.append(os.path.abspath('src'))

# 导入 IEMEnv 类
from src.envs.iseec_lx_v4_mdp_plot import IEMEnv
from src.utils.run_debug_plot import save_data 
from src.utils.run_debug_plot import save_plot_NSM_data
from src.utils.run_debug_plot import save_plot_SSM_data

from src.utils.run_debug_plot import save_future_data
from src.utils.run_debug_plot import save_plot_NSM_future_data
from src.utils.run_debug_plot import save_plot_SSM_future_data

from src.utils.run_debug_plot import plot_episode_reward
from src.utils.run_debug_plot import plot_episode_reward_simple
from src.utils.run_debug_plot import plot_3D_run

# %% [markdown]
# 定义保存位置参数
#
# > 所有的关键参数都放在最前面

# %%
# 增加随机种子的定义
def set_global_seed(seed):
    """设置全局随机种子"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False


# 设置全局种子
# SEED = 42 # 非测试，不指定种子
# set_global_seed(SEED)

# 全新的超参数配置过程，都放在一起
base_config = {
    # MDP 元素
    "custom_reward_type" : "multi_objective_single_T_a_exp831",
    # 环境 & 策略
    "env_id":   "iseec_lx_v4_mdp_plot",
    "rl_model_name": "PPO",
    "policy":   "MlpPolicy",
    "network_name" : "Netxxx_no_big_env",
    # 训练时长
    "total_timesteps_diy": 700000,
    "policy_kwargs_diy" : "dict_pi_vf_default", # for example: policy_kwargs = dict(activation_fn=th.nn.ReLU,net_arch=[256, 256, dict(pi=[128, 64], vf=[128, 64])])
    # 优化器 & 网络
    "hyperparams_diy": "default", 
    # "learning_rate":   3e-4,
    # "ent_coef":        0.0,
    # "batch_size":      64,
    # "n_epochs":        10,
    # 回放 & 更新频率（PPO 固定写法示例）
    # "gamma":           0.99,
    # "clip_range":      0.2,
    # "gae_lambda":      0.95,
    # 随机种子
    "use_random_reset": False, # 是否使用随机重置
    "seed":            42,
}


############### 具体的配置细节##############
# 设置保存的日志名字：
log_name = f'{base_config["env_id"]}_{base_config["rl_model_name"]}_{base_config["custom_reward_type"]}_{int(base_config["total_timesteps_diy"])}_{base_config["hyperparams_diy"]}' 
os.makedirs(f'./logs/{log_name}', exist_ok=True) # 创建日志目录

# 相当于接口部分
custom_reward_type = base_config["custom_reward_type"]
network_name = base_config["network_name"]
rl_model_name = base_config["rl_model_name"]
total_timesteps_diy = base_config["total_timesteps_diy"]
policy_kwargs_diy = base_config["policy_kwargs_diy"] 

# 设置日志保存路径和格式
new_logger = configure(
    f"logs/{log_name}",  # tmp_path 路径保存位置
    # ["stdout",     # 终端输出
    [
     "csv",        # CSV文件
     "tensorboard", # Tensorboard格式
     "json"        # JSON格式
    ]
)

# %% [markdown]
# ### 定义环境

# %%
env = IEMEnv(reward_type=base_config["custom_reward_type"])
env_monitor = Monitor(env, f'./logs/{log_name}')
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# ### 定义算法

# %%
# # 定义模型
# model = PPO(
#     "MlpPolicy", 
#     env_monitor, 
#     # ent_coef=0.01, # 增加策略寻找的鼓励，但是 suggestion 暂时不要改变
#     verbose=1,
#     )

# model = DQN(
#     "MlpPolicy", 
#     env_monitor, 
#     verbose=1,
#     )

model = PPO(    
    "MlpPolicy", 
    env_monitor, 
    verbose=1,)

model.set_logger(new_logger) # set the parameter of the logger
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
# check 环境
from stable_baselines3.common.env_checker import check_env
# check_env(env_monitor)
log_name

print("Action space sample:", env.action_space.sample())
# print("Observation space sample:", env.observation_space.sample())

# type(env.action_space), type(env.observation_space)
print("Action space sample:", env.action_space.sample())
print("Observation space sample:", env.observation_space.sample())

print(model.policy)
# Out:
# Action space sample: 8
# Action space sample: 6
# Observation space sample: [-0.17893618 -0.06007363 -0.08068441  0.11661372  0.44741474  0.14766978
#   2.04154749 -1.22579757 -0.03287824 -0.52425699]
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (pi_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (vf_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=16, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %% [markdown]
# ### 模型训练

# %%
def plot_callback_reward(metrics):
    """绘制训练过程中的奖励曲线
    
    Args:
        metrics (dict): 包含训练指标的字典，需要包含以下键：
            - rewards: 原始奖励列表
            - moving_avg_rewards: 移动平均奖励列表
            - moving_std_rewards: 移动标准差列表
            - episodes: 总回合数
            - step_idx: 当前步数
    """
    plt.figure(figsize=(20, 5))
    
    # 创建主图
    plt.subplot(131)
    plt.title(f'Step: {metrics["step_idx"]}, Latest reward: {metrics["rewards"][-1]:.2f}\n'
              f'Episode: {metrics["episodes"]}, Moving avg: {metrics["moving_avg_rewards"][-1]:.2f}')
    
    # 绘制原始奖励
    episodes = range(len(metrics["rewards"]))
    plt.plot(episodes, metrics["rewards"], 
             label='Raw rewards', color='gray', alpha=0.3)
    
    # 绘制移动平均
    plt.plot(episodes, metrics["moving_avg_rewards"],
             label='Moving average', color='blue', linewidth=2)
    
    # 添加标准差区域
    moving_avg = np.array(metrics["moving_avg_rewards"])
    moving_std = np.array(metrics["moving_std_rewards"])
    
    # 0.25倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.25 * moving_std,
                    moving_avg + 0.25 * moving_std,
                    color='b', alpha=0.1,
                    label='0.25 std range')
    
    # 0.5倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.5 * moving_std,
                    moving_avg + 0.5 * moving_std,
                    color='b', alpha=0.1,
                    label='0.5 std range')
    
    # 设置坐标轴和标签
    plt.xlabel('Episodes')
    plt.ylabel('Episode Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

class TrainingMonitorCallback(BaseCallback):
    def __init__(self, verbose=1, window_size=50):
        super().__init__(verbose)
        self.window_size = window_size
        # Initialize data dictionary to store metrics
        self.data = {
            "rewards": [],
            "moving_avg_rewards": [],
            "moving_std_rewards": [],
            "episodes": 0,
            "step_idx": 0
        }
        self.episode_rewards = 0
        
    def _on_step(self):
        # Accumulate rewards for current episode
        reward = self.locals.get('rewards')[0]
        self.episode_rewards += reward
        self.data["step_idx"] += 1
        
        # When episode ends, update all metrics
        if self.locals.get('dones')[0]:
            # Store raw reward
            self.data["rewards"].append(self.episode_rewards)
            
            # Calculate moving average and std
            recent_rewards = self.data["rewards"][-self.window_size:]
            moving_avg = np.mean(recent_rewards)
            moving_std = np.std(recent_rewards) if len(recent_rewards) > 1 else 0
            
            # Store calculated metrics
            self.data["moving_avg_rewards"].append(moving_avg)
            self.data["moving_std_rewards"].append(moving_std)
            self.data["episodes"] += 1
            
            # Print progress
            print(f"Episode {self.data['episodes']} finished with reward: {self.episode_rewards:.2f}")
            print(f"Moving average (last {len(recent_rewards)} episodes): {moving_avg:.2f} ± {moving_std:.2f}")
            
            # Reset episode rewards
            self.episode_rewards = 0
            
        return True
    
    def get_metrics(self):
        """Return the collected metrics"""
        return self.data
    
# Create callback with custom window size
callback = TrainingMonitorCallback(window_size=50)

# Train the model
model.learn(
    total_timesteps=int(total_timesteps_diy),
    callback=callback,
    log_interval=1
)


# After training, get metrics for plotting
metrics = callback.get_metrics()

# Plot rewards using the plot_callback_reward function
plot_callback_reward(metrics)
# Out:
# Episode 1 finished with reward: -28.16
# Moving average (last 1 episodes): -28.16 ± 0.00
# Episode 2 finished with reward: 24.62
# Moving average (last 2 episodes): -1.77 ± 26.39
# Episode 3 finished with reward: -32.42
# Moving average (last 3 episodes): -11.99 ± 25.94
# Episode 4 finished with reward: -49.17
# Moving average (last 4 episodes): -21.28 ± 27.64
# Episode 5 finished with reward: -89.26
# Moving average (last 5 episodes): -34.88 ± 36.75
# Episode 6 finished with reward: -114.28
# Moving average (last 6 episodes): -48.11 ± 44.73
# Episode 7 finished with reward: -96.09
# Moving average (last 7 episodes): -54.97 ± 44.69
# Episode 8 finished with reward: -71.30
# Moving average (last 8 episodes): -57.01 ± 42.15
# Episode 9 finished with reward: -64.30
# Moving average (last 9 episodes): -57.82 ± 39.81
# Episode 10 finished with reward: -73.84
# Moving average (last 10 episodes): -59.42 ± 38.07
# Episode 11 finished with reward: -59.42
# Moving average (last 11 episodes): -59.42 ± 36.30
# Episode 12 finished with reward: -9.18
# Moving average (last 12 episodes): -55.23 ± 37.42
# Episode 13 finished with reward: 62.93
# Moving average (last 13 episodes): -46.14 ± 47.79
# Episode 14 finished with reward: -33.26
# Moving average (last 14 episodes): -45.22 ± 46.17
# Episode 15 finished with reward: -49.04
# Moving average (last 15 episodes): -45.48 ± 44.62
# Episode 16 finished with reward: -63.06
# Moving average (last 16 episodes): -46.58 ± 43.41
# Episode 17 finished with reward: -73.16
# Moving average (last 17 episodes): -48.14 ± 42.58
# Episode 18 finished with reward: -31.89
# Moving average (last 18 episodes): -47.24 ± 41.54
# Episode 19 finished with reward: -37.28
# Moving average (last 19 episodes): -46.71 ± 40.50
# Episode 20 finished with reward: -47.01
# Moving average (last 20 episodes): -46.73 ± 39.47
# Episode 21 finished with reward: 34.59
# Moving average (last 21 episodes): -42.86 ± 42.23
# Episode 22 finished with reward: -71.16
# Moving average (last 22 episodes): -44.14 ± 41.68
# Episode 23 finished with reward: -42.08
# Moving average (last 23 episodes): -44.05 ± 40.77
# Episode 24 finished with reward: -56.94
# Moving average (last 24 episodes): -44.59 ± 39.99
# Episode 25 finished with reward: -37.78
# Moving average (last 25 episodes): -44.32 ± 39.21
# Episode 26 finished with reward: -35.90
# Moving average (last 26 episodes): -43.99 ± 38.48
# Episode 27 finished with reward: -67.20
# Moving average (last 27 episodes): -44.85 ± 38.01
# Episode 28 finished with reward: -15.45
# Moving average (last 28 episodes): -43.80 ± 37.73
# Episode 29 finished with reward: -13.65
# Moving average (last 29 episodes): -42.76 ± 37.48
# Episode 30 finished with reward: -55.57
# Moving average (last 30 episodes): -43.19 ± 36.92
# Episode 31 finished with reward: -53.45
# Moving average (last 31 episodes): -43.52 ± 36.36
# Episode 32 finished with reward: -38.77
# Moving average (last 32 episodes): -43.37 ± 35.80
# Episode 33 finished with reward: -78.20
# Moving average (last 33 episodes): -44.43 ± 35.75
# Episode 34 finished with reward: -25.00
# Moving average (last 34 episodes): -43.86 ± 35.38
# Episode 35 finished with reward: -30.73
# Moving average (last 35 episodes): -43.48 ± 34.94
# Episode 36 finished with reward: -43.02
# Moving average (last 36 episodes): -43.47 ± 34.45
# Episode 37 finished with reward: -67.33
# Moving average (last 37 episodes): -44.11 ± 34.20
# Episode 38 finished with reward: -48.81
# Moving average (last 38 episodes): -44.24 ± 33.75
# Episode 39 finished with reward: 1.16
# Moving average (last 39 episodes): -43.07 ± 34.08
# Episode 40 finished with reward: -46.63
# Moving average (last 40 episodes): -43.16 ± 33.66
# Episode 41 finished with reward: -34.19
# Moving average (last 41 episodes): -42.94 ± 33.27
# Episode 42 finished with reward: -44.92
# Moving average (last 42 episodes): -42.99 ± 32.88
# Episode 43 finished with reward: -19.98
# Moving average (last 43 episodes): -42.46 ± 32.68
# Episode 44 finished with reward: -74.00
# Moving average (last 44 episodes): -43.17 ± 32.64
# Episode 45 finished with reward: -54.09
# Moving average (last 45 episodes): -43.41 ± 32.32
# Episode 46 finished with reward: 5.71
# Moving average (last 46 episodes): -42.35 ± 32.76
# Episode 47 finished with reward: 0.07
# Moving average (last 47 episodes): -41.44 ± 32.98
# Episode 48 finished with reward: -58.65
# Moving average (last 48 episodes): -41.80 ± 32.73
# Episode 49 finished with reward: -38.48
# Moving average (last 49 episodes): -41.74 ± 32.40
# Episode 50 finished with reward: 3.19
# Moving average (last 50 episodes): -40.84 ± 32.68
# Episode 51 finished with reward: -10.55
# Moving average (last 50 episodes): -40.48 ± 32.91
# Episode 52 finished with reward: -11.25
# Moving average (last 50 episodes): -41.20 ± 31.86
# Episode 53 finished with reward: -7.41
# Moving average (last 50 episodes): -40.70 ± 32.19
# Episode 54 finished with reward: -65.58
# Moving average (last 50 episodes): -41.03 ± 32.35
# Episode 55 finished with reward: -70.29
# Moving average (last 50 episodes): -40.65 ± 31.89
# Episode 56 finished with reward: -16.32
# Moving average (last 50 episodes): -38.69 ± 30.28
# Episode 57 finished with reward: -23.17
# Moving average (last 50 episodes): -37.23 ± 29.22
# Episode 58 finished with reward: -87.72
# Moving average (last 50 episodes): -37.56 ± 29.69
# Episode 59 finished with reward: -24.59
# Moving average (last 50 episodes): -36.77 ± 29.49
# Episode 60 finished with reward: -26.87
# Moving average (last 50 episodes): -35.83 ± 29.04
# Episode 61 finished with reward: -36.52
# Moving average (last 50 episodes): -35.37 ± 28.84
# Episode 62 finished with reward: 61.98
# Moving average (last 50 episodes): -33.95 ± 31.71
# Episode 63 finished with reward: -7.51
# Moving average (last 50 episodes): -35.36 ± 28.81
# Episode 64 finished with reward: -52.55
# Moving average (last 50 episodes): -35.74 ± 28.91
# Episode 65 finished with reward: -15.39
# Moving average (last 50 episodes): -35.07 ± 28.98
# Episode 66 finished with reward: 0.29
# Moving average (last 50 episodes): -33.80 ± 29.12
# Episode 67 finished with reward: -30.04
# Moving average (last 50 episodes): -32.94 ± 28.57
# Episode 68 finished with reward: -38.83
# Moving average (last 50 episodes): -33.08 ± 28.58
# Episode 69 finished with reward: -46.47
# Moving average (last 50 episodes): -33.26 ± 28.64
# Episode 70 finished with reward: -20.08
# Moving average (last 50 episodes): -32.72 ± 28.63
# Episode 71 finished with reward: -18.18
# Moving average (last 50 episodes): -33.78 ± 27.06
# Episode 72 finished with reward: -5.81
# Moving average (last 50 episodes): -32.47 ± 26.80
# Episode 73 finished with reward: 25.87
# Moving average (last 50 episodes): -31.11 ± 27.97
# Episode 74 finished with reward: -57.08
# Moving average (last 50 episodes): -31.12 ± 27.97
# Episode 75 finished with reward: 19.99
# Moving average (last 50 episodes): -29.96 ± 28.85
# Episode 76 finished with reward: 11.14
# Moving average (last 50 episodes): -29.02 ± 29.41
# Episode 77 finished with reward: -24.57
# Moving average (last 50 episodes): -28.17 ± 28.90
# Episode 78 finished with reward: -56.96
# Moving average (last 50 episodes): -29.00 ± 29.12
# Episode 79 finished with reward: 31.76
# Moving average (last 50 episodes): -28.09 ± 30.27
# Episode 80 finished with reward: -52.73
# Moving average (last 50 episodes): -28.03 ± 30.22
# Episode 81 finished with reward: -155.45
# Moving average (last 50 episodes): -30.07 ± 34.94
# Episode 82 finished with reward: -112.14
# Moving average (last 50 episodes): -31.54 ± 36.77
# Episode 83 finished with reward: -10.47
# Moving average (last 50 episodes): -30.18 ± 36.27
# Episode 84 finished with reward: 1.87
# Moving average (last 50 episodes): -29.65 ± 36.54
# Episode 85 finished with reward: -42.72
# Moving average (last 50 episodes): -29.89 ± 36.59
# Episode 86 finished with reward: -41.20
# Moving average (last 50 episodes): -29.85 ± 36.57
# Episode 87 finished with reward: -20.86
# Moving average (last 50 episodes): -28.92 ± 36.20
# Episode 88 finished with reward: 7.43
# Moving average (last 50 episodes): -27.80 ± 36.44
# Episode 89 finished with reward: -27.05
# Moving average (last 50 episodes): -28.36 ± 36.20
# Episode 90 finished with reward: -98.62
# Moving average (last 50 episodes): -29.40 ± 37.44
# Episode 91 finished with reward: -4.50
# Moving average (last 50 episodes): -28.81 ± 37.59
# Episode 92 finished with reward: -98.37
# Moving average (last 50 episodes): -29.88 ± 38.77
# Episode 93 finished with reward: -24.58
# Moving average (last 50 episodes): -29.97 ± 38.76
# Episode 94 finished with reward: -58.54
# Moving average (last 50 episodes): -29.66 ± 38.46
# Episode 95 finished with reward: -56.51
# Moving average (last 50 episodes): -29.71 ± 38.50
# Episode 96 finished with reward: -32.01
# Moving average (last 50 episodes): -30.46 ± 38.16
# Episode 97 finished with reward: -10.90
# Moving average (last 50 episodes): -30.68 ± 38.02
# Episode 98 finished with reward: -31.73
# Moving average (last 50 episodes): -30.14 ± 37.81
# Episode 99 finished with reward: -11.92
# Moving average (last 50 episodes): -29.61 ± 37.87
# Episode 100 finished with reward: -3.28
# Moving average (last 50 episodes): -29.74 ± 37.77
# Episode 101 finished with reward: 23.48
# Moving average (last 50 episodes): -29.06 ± 38.41
# Episode 102 finished with reward: -12.06
# Moving average (last 50 episodes): -29.08 ± 38.41
# Episode 103 finished with reward: -17.36
# Moving average (last 50 episodes): -29.27 ± 38.32
# Episode 104 finished with reward: -76.05
# Moving average (last 50 episodes): -29.48 ± 38.55
# Episode 105 finished with reward: -23.25
# Moving average (last 50 episodes): -28.54 ± 38.11
# Episode 106 finished with reward: -14.64
# Moving average (last 50 episodes): -28.51 ± 38.12
# Episode 107 finished with reward: 15.50
# Moving average (last 50 episodes): -27.74 ± 38.61
# Episode 108 finished with reward: 59.87
# Moving average (last 50 episodes): -24.78 ± 39.54
# Episode 109 finished with reward: -56.41
# Moving average (last 50 episodes): -25.42 ± 39.79
# Episode 110 finished with reward: -51.56
# Moving average (last 50 episodes): -25.91 ± 39.96
# Episode 111 finished with reward: -31.94
# Moving average (last 50 episodes): -25.82 ± 39.94
# Episode 112 finished with reward: 21.88
# Moving average (last 50 episodes): -26.63 ± 38.55
# Episode 113 finished with reward: -30.49
# Moving average (last 50 episodes): -27.08 ± 38.45
# Episode 114 finished with reward: 16.89
# Moving average (last 50 episodes): -25.70 ± 38.76
# Episode 115 finished with reward: -48.28
# Moving average (last 50 episodes): -26.35 ± 38.86
# Episode 116 finished with reward: 18.07
# Moving average (last 50 episodes): -26.00 ± 39.18
# Episode 117 finished with reward: -39.95
# Moving average (last 50 episodes): -26.20 ± 39.22
# Episode 118 finished with reward: 14.32
# Moving average (last 50 episodes): -25.13 ± 39.59
# Episode 119 finished with reward: -3.11
# Moving average (last 50 episodes): -24.27 ± 39.58
# Episode 120 finished with reward: -57.86
# Moving average (last 50 episodes): -25.02 ± 39.86
# Episode 121 finished with reward: 40.19
# Moving average (last 50 episodes): -23.85 ± 40.88
# Episode 122 finished with reward: -13.15
# Moving average (last 50 episodes): -24.00 ± 40.83
# Episode 123 finished with reward: -1.19
# Moving average (last 50 episodes): -24.54 ± 40.34
# Episode 124 finished with reward: -28.99
# Moving average (last 50 episodes): -23.98 ± 40.08
# Episode 125 finished with reward: -0.66
# Moving average (last 50 episodes): -24.39 ± 39.73
# Episode 126 finished with reward: 8.00
# Moving average (last 50 episodes): -24.46 ± 39.68
# Episode 127 finished with reward: 34.68
# Moving average (last 50 episodes): -23.27 ± 40.53
# Episode 128 finished with reward: -3.74
# Moving average (last 50 episodes): -22.21 ± 40.33
# Episode 129 finished with reward: -10.89
# Moving average (last 50 episodes): -23.06 ± 39.62
# Episode 130 finished with reward: -51.78
# Moving average (last 50 episodes): -23.04 ± 39.61
# Episode 131 finished with reward: -11.23
# Moving average (last 50 episodes): -20.16 ± 34.82
# Episode 132 finished with reward: 46.02
# Moving average (last 50 episodes): -16.99 ± 33.48
# Episode 133 finished with reward: -7.74
# Moving average (last 50 episodes): -16.94 ± 33.50
# Episode 134 finished with reward: 17.79
# Moving average (last 50 episodes): -16.62 ± 33.75
# Episode 135 finished with reward: 44.13
# Moving average (last 50 episodes): -14.88 ± 34.58
# Episode 136 finished with reward: -61.31
# Moving average (last 50 episodes): -15.29 ± 35.00
# Episode 137 finished with reward: -29.83
# Moving average (last 50 episodes): -15.46 ± 35.05
# Episode 138 finished with reward: -0.48
# Moving average (last 50 episodes): -15.62 ± 34.97
# Episode 139 finished with reward: -16.91
# Moving average (last 50 episodes): -15.42 ± 34.93
# Episode 140 finished with reward: -25.64
# Moving average (last 50 episodes): -13.96 ± 32.89
# Episode 141 finished with reward: -21.39
# Moving average (last 50 episodes): -14.30 ± 32.88
# Episode 142 finished with reward: -36.27
# Moving average (last 50 episodes): -13.06 ± 30.78
# Episode 143 finished with reward: -12.19
# Moving average (last 50 episodes): -12.81 ± 30.74
# Episode 144 finished with reward: -18.54
# Moving average (last 50 episodes): -12.01 ± 30.05
# Episode 145 finished with reward: -42.19
# Moving average (last 50 episodes): -11.72 ± 29.69
# Episode 146 finished with reward: -1.74
# Moving average (last 50 episodes): -11.12 ± 29.58
# Episode 147 finished with reward: 26.43
# Moving average (last 50 episodes): -10.37 ± 30.04
# Episode 148 finished with reward: -12.86
# Moving average (last 50 episodes): -9.99 ± 29.89
# Episode 149 finished with reward: -26.08
# Moving average (last 50 episodes): -10.28 ± 29.98
# Episode 150 finished with reward: 0.49
# Moving average (last 50 episodes): -10.20 ± 30.00
# Episode 151 finished with reward: -28.23
# Moving average (last 50 episodes): -11.23 ± 29.71
# Episode 152 finished with reward: -6.09
# Moving average (last 50 episodes): -11.12 ± 29.72
# Episode 153 finished with reward: -59.33
# Moving average (last 50 episodes): -11.95 ± 30.47
# Episode 154 finished with reward: -10.28
# Moving average (last 50 episodes): -10.64 ± 29.06
# Episode 155 finished with reward: -19.28
# Moving average (last 50 episodes): -10.56 ± 29.03
# Episode 156 finished with reward: 7.88
# Moving average (last 50 episodes): -10.11 ± 29.14
# Episode 157 finished with reward: -22.35
# Moving average (last 50 episodes): -10.87 ± 28.95
# Episode 158 finished with reward: -74.90
# Moving average (last 50 episodes): -13.56 ± 28.51
# Episode 159 finished with reward: -4.30
# Moving average (last 50 episodes): -12.52 ± 27.87
# Episode 160 finished with reward: 42.88
# Moving average (last 50 episodes): -10.63 ± 28.36
# Episode 161 finished with reward: -12.83
# Moving average (last 50 episodes): -10.25 ± 28.19
# Episode 162 finished with reward: -89.97
# Moving average (last 50 episodes): -12.49 ± 29.94
# Episode 163 finished with reward: 28.35
# Moving average (last 50 episodes): -11.31 ± 30.36
# Episode 164 finished with reward: 13.30
# Moving average (last 50 episodes): -11.38 ± 30.30
# Episode 165 finished with reward: -60.80
# Moving average (last 50 episodes): -11.63 ± 30.65
# Episode 166 finished with reward: 29.37
# Moving average (last 50 episodes): -11.40 ± 30.91
# Episode 167 finished with reward: -22.86
# Moving average (last 50 episodes): -11.06 ± 30.69
# Episode 168 finished with reward: -28.55
# Moving average (last 50 episodes): -11.92 ± 30.57
# Episode 169 finished with reward: -34.16
# Moving average (last 50 episodes): -12.54 ± 30.70
# Episode 170 finished with reward: 23.00
# Moving average (last 50 episodes): -10.92 ± 30.39
# Episode 171 finished with reward: -4.32
# Moving average (last 50 episodes): -11.81 ± 29.52
# Episode 172 finished with reward: -29.75
# Moving average (last 50 episodes): -12.15 ± 29.63
# Episode 173 finished with reward: -1.62
# Moving average (last 50 episodes): -12.15 ± 29.63
# Episode 174 finished with reward: -21.36
# Moving average (last 50 episodes): -12.00 ± 29.56
# Episode 175 finished with reward: -20.94
# Moving average (last 50 episodes): -12.41 ± 29.54
# Episode 176 finished with reward: -22.70
# Moving average (last 50 episodes): -13.02 ± 29.43
# Episode 177 finished with reward: -8.20
# Moving average (last 50 episodes): -13.88 ± 28.64
# Episode 178 finished with reward: -30.20
# Moving average (last 50 episodes): -14.41 ± 28.69
# Episode 179 finished with reward: -61.64
# Moving average (last 50 episodes): -15.42 ± 29.44
# Episode 180 finished with reward: -45.63
# Moving average (last 50 episodes): -15.30 ± 29.30
# Episode 181 finished with reward: 24.29
# Moving average (last 50 episodes): -14.59 ± 29.81
# Episode 182 finished with reward: 14.60
# Moving average (last 50 episodes): -15.22 ± 28.84
# Episode 183 finished with reward: -12.98
# Moving average (last 50 episodes): -15.32 ± 28.83
# Episode 184 finished with reward: -32.68
# Moving average (last 50 episodes): -16.33 ± 28.53
# Episode 185 finished with reward: -7.27
# Moving average (last 50 episodes): -17.36 ± 27.23
# Episode 186 finished with reward: -62.47
# Moving average (last 50 episodes): -17.38 ± 27.27
# Episode 187 finished with reward: 59.49
# Moving average (last 50 episodes): -15.60 ± 29.25
# Episode 188 finished with reward: -37.22
# Moving average (last 50 episodes): -16.33 ± 29.32
# Episode 189 finished with reward: -47.51
# Moving average (last 50 episodes): -16.94 ± 29.64
# Episode 190 finished with reward: -25.39
# Moving average (last 50 episodes): -16.94 ± 29.64
# Episode 191 finished with reward: 52.43
# Moving average (last 50 episodes): -15.46 ± 31.18
# Episode 192 finished with reward: 2.23
# Moving average (last 50 episodes): -14.69 ± 31.14
# Episode 193 finished with reward: 13.55
# Moving average (last 50 episodes): -14.18 ± 31.38
# Episode 194 finished with reward: -5.93
# Moving average (last 50 episodes): -13.93 ± 31.40
# Episode 195 finished with reward: -30.74
# Moving average (last 50 episodes): -13.70 ± 31.23
# Episode 196 finished with reward: -34.44
# Moving average (last 50 episodes): -14.35 ± 31.32
# Episode 197 finished with reward: -3.14
# Moving average (last 50 episodes): -14.94 ± 30.82
# Episode 198 finished with reward: 3.66
# Moving average (last 50 episodes): -14.61 ± 30.93
# Episode 199 finished with reward: 27.57
# Moving average (last 50 episodes): -13.54 ± 31.44
# Episode 200 finished with reward: -53.11
# Moving average (last 50 episodes): -14.61 ± 31.85
# Episode 201 finished with reward: -26.28
# Moving average (last 50 episodes): -14.57 ± 31.84
# Episode 202 finished with reward: 26.26
# Moving average (last 50 episodes): -13.92 ± 32.33
# Episode 203 finished with reward: 22.60
# Moving average (last 50 episodes): -12.29 ± 32.06
# Episode 204 finished with reward: 14.44
# Moving average (last 50 episodes): -11.79 ± 32.28
# Episode 205 finished with reward: 1.63
# Moving average (last 50 episodes): -11.37 ± 32.31
# Episode 206 finished with reward: -54.02
# Moving average (last 50 episodes): -12.61 ± 32.73
# Episode 207 finished with reward: 3.65
# Moving average (last 50 episodes): -12.09 ± 32.78
# Episode 208 finished with reward: -88.96
# Moving average (last 50 episodes): -12.37 ± 33.37
# Episode 209 finished with reward: 54.94
# Moving average (last 50 episodes): -11.19 ± 34.67
# Episode 210 finished with reward: -27.64
# Moving average (last 50 episodes): -12.60 ± 33.86
# Episode 211 finished with reward: 5.79
# Moving average (last 50 episodes): -12.23 ± 33.96
# Episode 212 finished with reward: -44.06
# Moving average (last 50 episodes): -11.31 ± 32.43
# Episode 213 finished with reward: -42.35
# Moving average (last 50 episodes): -12.72 ± 32.21
# Episode 214 finished with reward: -30.33
# Moving average (last 50 episodes): -13.59 ± 32.09
# Episode 215 finished with reward: 16.32
# Moving average (last 50 episodes): -12.05 ± 31.63
# Episode 216 finished with reward: -48.26
# Moving average (last 50 episodes): -13.60 ± 31.46
# Episode 217 finished with reward: -3.95
# Moving average (last 50 episodes): -13.23 ± 31.46
# Episode 218 finished with reward: -15.47
# Moving average (last 50 episodes): -12.97 ± 31.39
# Episode 219 finished with reward: 1.11
# Moving average (last 50 episodes): -12.26 ± 31.30
# Episode 220 finished with reward: -20.41
# Moving average (last 50 episodes): -13.13 ± 30.91
# Episode 221 finished with reward: -23.44
# Moving average (last 50 episodes): -13.51 ± 30.92
# Episode 222 finished with reward: 63.86
# Moving average (last 50 episodes): -11.64 ± 32.66
# Episode 223 finished with reward: -58.74
# Moving average (last 50 episodes): -12.78 ± 33.29
# Episode 224 finished with reward: -40.69
# Moving average (last 50 episodes): -13.17 ± 33.50
# Episode 225 finished with reward: 0.61
# Moving average (last 50 episodes): -12.74 ± 33.53
# Episode 226 finished with reward: 5.31
# Moving average (last 50 episodes): -12.18 ± 33.59
# Episode 227 finished with reward: 20.08
# Moving average (last 50 episodes): -11.61 ± 33.89
# Episode 228 finished with reward: -41.73
# Moving average (last 50 episodes): -11.84 ± 34.06
# Episode 229 finished with reward: -39.29
# Moving average (last 50 episodes): -11.39 ± 33.54
# Episode 230 finished with reward: 26.97
# Moving average (last 50 episodes): -9.94 ± 33.60
# Episode 231 finished with reward: -33.96
# Moving average (last 50 episodes): -11.11 ± 33.40
# Episode 232 finished with reward: -9.02
# Moving average (last 50 episodes): -11.58 ± 33.20
# Episode 233 finished with reward: 7.41
# Moving average (last 50 episodes): -11.17 ± 33.31
# Episode 234 finished with reward: -26.44
# Moving average (last 50 episodes): -11.05 ± 33.24
# Episode 235 finished with reward: -47.30
# Moving average (last 50 episodes): -11.85 ± 33.62
# Episode 236 finished with reward: 39.25
# Moving average (last 50 episodes): -9.81 ± 33.57
# Episode 237 finished with reward: -44.19
# Moving average (last 50 episodes): -11.89 ± 32.41
# Episode 238 finished with reward: -34.61
# Moving average (last 50 episodes): -11.83 ± 32.37
# Episode 239 finished with reward: -23.99
# Moving average (last 50 episodes): -11.36 ± 32.02
# Episode 240 finished with reward: -27.02
# Moving average (last 50 episodes): -11.40 ± 32.03
# Episode 241 finished with reward: -31.03
# Moving average (last 50 episodes): -13.07 ± 30.81
# Episode 242 finished with reward: -42.12
# Moving average (last 50 episodes): -13.95 ± 31.00
# Episode 243 finished with reward: -22.06
# Moving average (last 50 episodes): -14.66 ± 30.77
# Episode 244 finished with reward: -35.03
# Moving average (last 50 episodes): -15.25 ± 30.87
# Episode 245 finished with reward: -35.35
# Moving average (last 50 episodes): -15.34 ± 30.92
# Episode 246 finished with reward: -15.44
# Moving average (last 50 episodes): -14.96 ± 30.80
# Episode 247 finished with reward: -36.76
# Moving average (last 50 episodes): -15.63 ± 30.90
# Episode 248 finished with reward: -7.81
# Moving average (last 50 episodes): -15.86 ± 30.80
# Episode 249 finished with reward: -1.98
# Moving average (last 50 episodes): -16.45 ± 30.24
# Episode 250 finished with reward: 34.94
# Moving average (last 50 episodes): -14.69 ± 30.62
# Episode 251 finished with reward: -8.57
# Moving average (last 50 episodes): -14.34 ± 30.58
# Episode 252 finished with reward: -63.48
# Moving average (last 50 episodes): -16.13 ± 30.78
# Episode 253 finished with reward: -45.27
# Moving average (last 50 episodes): -17.49 ± 30.54
# Episode 254 finished with reward: 33.03
# Moving average (last 50 episodes): -17.12 ± 31.04
# Episode 255 finished with reward: -24.94
# Moving average (last 50 episodes): -17.65 ± 30.94
# Episode 256 finished with reward: -9.35
# Moving average (last 50 episodes): -16.76 ± 30.52
# Episode 257 finished with reward: 59.30
# Moving average (last 50 episodes): -15.64 ± 32.21
# Episode 258 finished with reward: -3.82
# Moving average (last 50 episodes): -13.94 ± 30.49
# Episode 259 finished with reward: -10.86
# Moving average (last 50 episodes): -15.26 ± 28.87
# Episode 260 finished with reward: -9.86
# Moving average (last 50 episodes): -14.90 ± 28.82
# Episode 261 finished with reward: 35.44
# Moving average (last 50 episodes): -14.31 ± 29.54
# Episode 262 finished with reward: -20.25
# Moving average (last 50 episodes): -13.83 ± 29.24
# Episode 263 finished with reward: -61.95
# Moving average (last 50 episodes): -14.22 ± 29.75
# Episode 264 finished with reward: -54.63
# Moving average (last 50 episodes): -14.71 ± 30.20
# Episode 265 finished with reward: 54.86
# Moving average (last 50 episodes): -13.94 ± 31.45
# Episode 266 finished with reward: 57.46
# Moving average (last 50 episodes): -11.82 ± 32.61
# Episode 267 finished with reward: 35.88
# Moving average (last 50 episodes): -11.03 ± 33.27
# Episode 268 finished with reward: -22.12
# Moving average (last 50 episodes): -11.16 ± 33.30
# Episode 269 finished with reward: 0.71
# Moving average (last 50 episodes): -11.17 ± 33.30
# Episode 270 finished with reward: 33.00
# Moving average (last 50 episodes): -10.10 ± 33.84
# Episode 271 finished with reward: -10.25
# Moving average (last 50 episodes): -9.84 ± 33.78
# Episode 272 finished with reward: -12.13
# Moving average (last 50 episodes): -11.36 ± 32.10
# Episode 273 finished with reward: -51.44
# Moving average (last 50 episodes): -11.21 ± 31.90
# Episode 274 finished with reward: -15.30
# Moving average (last 50 episodes): -10.70 ± 31.63
# Episode 275 finished with reward: 27.37
# Moving average (last 50 episodes): -10.17 ± 32.04
# Episode 276 finished with reward: 17.10
# Moving average (last 50 episodes): -9.93 ± 32.19
# Episode 277 finished with reward: -16.28
# Moving average (last 50 episodes): -10.66 ± 31.92
# Episode 278 finished with reward: -7.09
# Moving average (last 50 episodes): -9.97 ± 31.61
# Episode 279 finished with reward: -37.53
# Moving average (last 50 episodes): -9.93 ± 31.58
# Episode 280 finished with reward: -16.23
# Moving average (last 50 episodes): -10.79 ± 31.14
# Episode 281 finished with reward: 8.51
# Moving average (last 50 episodes): -9.94 ± 31.08
# Episode 282 finished with reward: -57.25
# Moving average (last 50 episodes): -10.91 ± 31.78
# Episode 283 finished with reward: -32.34
# Moving average (last 50 episodes): -11.70 ± 31.81
# Episode 284 finished with reward: -22.65
# Moving average (last 50 episodes): -11.63 ± 31.78
# Episode 285 finished with reward: -21.47
# Moving average (last 50 episodes): -11.11 ± 31.40
# Episode 286 finished with reward: 11.59
# Moving average (last 50 episodes): -11.67 ± 30.74
# Episode 287 finished with reward: -0.36
# Moving average (last 50 episodes): -10.79 ± 30.43
# Episode 288 finished with reward: -22.41
# Moving average (last 50 episodes): -10.54 ± 30.28
# Episode 289 finished with reward: -6.51
# Moving average (last 50 episodes): -10.19 ± 30.23
# Episode 290 finished with reward: -11.93
# Moving average (last 50 episodes): -9.89 ± 30.13
# Episode 291 finished with reward: -44.08
# Moving average (last 50 episodes): -10.15 ± 30.37
# Episode 292 finished with reward: 16.22
# Moving average (last 50 episodes): -8.99 ± 30.24
# Episode 293 finished with reward: 15.60
# Moving average (last 50 episodes): -8.23 ± 30.37
# Episode 294 finished with reward: 20.18
# Moving average (last 50 episodes): -7.13 ± 30.38
# Episode 295 finished with reward: 25.03
# Moving average (last 50 episodes): -5.92 ± 30.44
# Episode 296 finished with reward: -51.67
# Moving average (last 50 episodes): -6.65 ± 31.08
# Episode 297 finished with reward: 7.24
# Moving average (last 50 episodes): -5.77 ± 30.84
# Episode 298 finished with reward: 15.20
# Moving average (last 50 episodes): -5.31 ± 30.97
# Episode 299 finished with reward: -45.78
# Moving average (last 50 episodes): -6.18 ± 31.48
# Episode 300 finished with reward: -24.19
# Moving average (last 50 episodes): -7.36 ± 31.02
# Episode 301 finished with reward: 38.45
# Moving average (last 50 episodes): -6.42 ± 31.68
# Episode 302 finished with reward: -17.11
# Moving average (last 50 episodes): -5.50 ± 30.66
# Episode 303 finished with reward: -30.14
# Moving average (last 50 episodes): -5.19 ± 30.34
# Episode 304 finished with reward: -26.07
# Moving average (last 50 episodes): -6.38 ± 29.97
# Episode 305 finished with reward: 15.63
# Moving average (last 50 episodes): -5.57 ± 30.01
# Episode 306 finished with reward: -4.47
# Moving average (last 50 episodes): -5.47 ± 30.00
# Episode 307 finished with reward: 0.06
# Moving average (last 50 episodes): -6.65 ± 28.56
# Episode 308 finished with reward: 27.50
# Moving average (last 50 episodes): -6.03 ± 28.95
# Episode 309 finished with reward: -28.63
# Moving average (last 50 episodes): -6.38 ± 29.12
# Episode 310 finished with reward: -8.75
# Moving average (last 50 episodes): -6.36 ± 29.12
# Episode 311 finished with reward: -55.70
# Moving average (last 50 episodes): -8.18 ± 29.29
# Episode 312 finished with reward: -12.59
# Moving average (last 50 episodes): -8.03 ± 29.25
# Episode 313 finished with reward: 30.43
# Moving average (last 50 episodes): -6.18 ± 28.70
# Episode 314 finished with reward: -15.64
# Moving average (last 50 episodes): -5.40 ± 27.89
# Episode 315 finished with reward: -2.36
# Moving average (last 50 episodes): -6.55 ± 26.54
# Episode 316 finished with reward: 50.29
# Moving average (last 50 episodes): -6.69 ± 26.21
# Episode 317 finished with reward: -18.74
# Moving average (last 50 episodes): -7.78 ± 25.54
# Episode 318 finished with reward: 39.15
# Moving average (last 50 episodes): -6.56 ± 26.28
# Episode 319 finished with reward: 44.81
# Moving average (last 50 episodes): -5.67 ± 27.23
# Episode 320 finished with reward: 8.27
# Moving average (last 50 episodes): -6.17 ± 26.75
# Episode 321 finished with reward: -23.19
# Moving average (last 50 episodes): -6.43 ± 26.85
# Episode 322 finished with reward: -36.41
# Moving average (last 50 episodes): -6.91 ± 27.16
# Episode 323 finished with reward: 13.01
# Moving average (last 50 episodes): -5.62 ± 26.54
# Episode 324 finished with reward: -1.03
# Moving average (last 50 episodes): -5.34 ± 26.51
# Episode 325 finished with reward: -27.05
# Moving average (last 50 episodes): -6.43 ± 26.26
# Episode 326 finished with reward: 56.85
# Moving average (last 50 episodes): -5.63 ± 27.54
# Episode 327 finished with reward: -4.66
# Moving average (last 50 episodes): -5.40 ± 27.49
# Episode 328 finished with reward: 12.11
# Moving average (last 50 episodes): -5.02 ± 27.60
# Episode 329 finished with reward: -67.45
# Moving average (last 50 episodes): -5.61 ± 28.61
# Episode 330 finished with reward: 24.80
# Moving average (last 50 episodes): -4.79 ± 28.88
# Episode 331 finished with reward: -25.81
# Moving average (last 50 episodes): -5.48 ± 28.96
# Episode 332 finished with reward: -9.25
# Moving average (last 50 episodes): -4.52 ± 28.01
# Episode 333 finished with reward: 5.25
# Moving average (last 50 episodes): -3.77 ± 27.75
# Episode 334 finished with reward: 23.99
# Moving average (last 50 episodes): -2.84 ± 27.89
# Episode 335 finished with reward: 37.01
# Moving average (last 50 episodes): -1.67 ± 28.30
# Episode 336 finished with reward: 58.98
# Moving average (last 50 episodes): -0.72 ± 29.50
# Episode 337 finished with reward: 24.86
# Moving average (last 50 episodes): -0.21 ± 29.72
# Episode 338 finished with reward: 59.56
# Moving average (last 50 episodes): 1.43 ± 30.69
# Episode 339 finished with reward: -34.53
# Moving average (last 50 episodes): 0.86 ± 31.09
# Episode 340 finished with reward: 3.39
# Moving average (last 50 episodes): 1.17 ± 31.03
# Episode 341 finished with reward: 30.23
# Moving average (last 50 episodes): 2.66 ± 30.61
# Episode 342 finished with reward: -14.27
# Moving average (last 50 episodes): 2.05 ± 30.64
# Episode 343 finished with reward: -5.36
# Moving average (last 50 episodes): 1.63 ± 30.59
# Episode 344 finished with reward: 39.10
# Moving average (last 50 episodes): 2.01 ± 30.93
# Episode 345 finished with reward: 36.72
# Moving average (last 50 episodes): 2.24 ± 31.15
# Episode 346 finished with reward: 42.64
# Moving average (last 50 episodes): 4.13 ± 30.68
# Episode 347 finished with reward: 58.40
# Moving average (last 50 episodes): 5.15 ± 31.61
# Episode 348 finished with reward: -18.11
# Moving average (last 50 episodes): 4.48 ± 31.74
# Episode 349 finished with reward: 9.09
# Moving average (last 50 episodes): 5.58 ± 30.92
# Episode 350 finished with reward: -1.56
# Moving average (last 50 episodes): 6.03 ± 30.64
# Episode 351 finished with reward: -10.12
# Moving average (last 50 episodes): 5.06 ± 30.37
# Episode 352 finished with reward: 9.85
# Moving average (last 50 episodes): 5.60 ± 30.21
# Episode 353 finished with reward: -6.08
# Moving average (last 50 episodes): 6.08 ± 29.83
# Episode 354 finished with reward: -0.24
# Moving average (last 50 episodes): 6.60 ± 29.49
# Episode 355 finished with reward: 14.52
# Moving average (last 50 episodes): 6.58 ± 29.48
# Episode 356 finished with reward: 10.04
# Moving average (last 50 episodes): 6.87 ± 29.44
# Episode 357 finished with reward: -10.05
# Moving average (last 50 episodes): 6.67 ± 29.52
# Episode 358 finished with reward: 29.57
# Moving average (last 50 episodes): 6.71 ± 29.55
# Episode 359 finished with reward: -14.93
# Moving average (last 50 episodes): 6.98 ± 29.29
# Episode 360 finished with reward: -12.23
# Moving average (last 50 episodes): 6.91 ± 29.33
# Episode 361 finished with reward: 10.78
# Moving average (last 50 episodes): 8.24 ± 27.93
# Episode 362 finished with reward: -37.65
# Moving average (last 50 episodes): 7.74 ± 28.52
# Episode 363 finished with reward: 16.89
# Moving average (last 50 episodes): 7.47 ± 28.37
# Episode 364 finished with reward: 29.14
# Moving average (last 50 episodes): 8.36 ± 28.33
# Episode 365 finished with reward: -20.93
# Moving average (last 50 episodes): 7.99 ± 28.59
# Episode 366 finished with reward: 14.77
# Moving average (last 50 episodes): 7.28 ± 27.96
# Episode 367 finished with reward: 24.83
# Moving average (last 50 episodes): 8.15 ± 27.82
# Episode 368 finished with reward: 12.33
# Moving average (last 50 episodes): 7.62 ± 27.47
# Episode 369 finished with reward: 33.42
# Moving average (last 50 episodes): 7.39 ± 27.21
# Episode 370 finished with reward: -10.85
# Moving average (last 50 episodes): 7.01 ± 27.33
# Episode 371 finished with reward: 55.93
# Moving average (last 50 episodes): 8.59 ± 27.82
# Episode 372 finished with reward: 16.59
# Moving average (last 50 episodes): 9.65 ± 27.08
# Episode 373 finished with reward: -11.86
# Moving average (last 50 episodes): 9.15 ± 27.24
# Episode 374 finished with reward: -0.85
# Moving average (last 50 episodes): 9.16 ± 27.24
# Episode 375 finished with reward: 8.25
# Moving average (last 50 episodes): 9.86 ± 26.75
# Episode 376 finished with reward: -15.51
# Moving average (last 50 episodes): 8.41 ± 26.12
# Episode 377 finished with reward: -21.17
# Moving average (last 50 episodes): 8.08 ± 26.38
# Episode 378 finished with reward: 40.73
# Moving average (last 50 episodes): 8.66 ± 26.77
# Episode 379 finished with reward: 30.74
# Moving average (last 50 episodes): 10.62 ± 24.63
# Episode 380 finished with reward: 16.66
# Moving average (last 50 episodes): 10.46 ± 24.57
# Episode 381 finished with reward: 3.79
# Moving average (last 50 episodes): 11.05 ± 24.04
# Episode 382 finished with reward: 6.92
# Moving average (last 50 episodes): 11.37 ± 23.87
# Episode 383 finished with reward: -8.71
# Moving average (last 50 episodes): 11.09 ± 24.02
# Episode 384 finished with reward: 76.39
# Moving average (last 50 episodes): 12.14 ± 25.65
# Episode 385 finished with reward: -5.89
# Moving average (last 50 episodes): 11.28 ± 25.52
# Episode 386 finished with reward: 4.19
# Moving average (last 50 episodes): 10.19 ± 24.61
# Episode 387 finished with reward: -1.56
# Moving average (last 50 episodes): 9.66 ± 24.57
# Episode 388 finished with reward: -44.25
# Moving average (last 50 episodes): 7.58 ± 24.65
# Episode 389 finished with reward: -0.65
# Moving average (last 50 episodes): 8.26 ± 23.94
# Episode 390 finished with reward: 4.32
# Moving average (last 50 episodes): 8.28 ± 23.94
# Episode 391 finished with reward: 12.38
# Moving average (last 50 episodes): 7.92 ± 23.74
# Episode 392 finished with reward: 51.39
# Moving average (last 50 episodes): 9.24 ± 24.29
# Episode 393 finished with reward: 15.68
# Moving average (last 50 episodes): 9.66 ± 24.21
# Episode 394 finished with reward: 33.12
# Moving average (last 50 episodes): 9.54 ± 24.08
# Episode 395 finished with reward: 46.58
# Moving average (last 50 episodes): 9.73 ± 24.34
# Episode 396 finished with reward: -7.34
# Moving average (last 50 episodes): 8.73 ± 23.99
# Episode 397 finished with reward: -7.08
# Moving average (last 50 episodes): 7.43 ± 23.01
# Episode 398 finished with reward: 25.73
# Moving average (last 50 episodes): 8.30 ± 22.86
# Episode 399 finished with reward: -0.77
# Moving average (last 50 episodes): 8.10 ± 22.89
# Episode 400 finished with reward: 9.47
# Moving average (last 50 episodes): 8.33 ± 22.85
# Episode 401 finished with reward: -28.30
# Moving average (last 50 episodes): 7.96 ± 23.28
# Episode 402 finished with reward: 15.07
# Moving average (last 50 episodes): 8.07 ± 23.30
# Episode 403 finished with reward: 65.61
# Moving average (last 50 episodes): 9.50 ± 24.56
# Episode 404 finished with reward: 80.86
# Moving average (last 50 episodes): 11.12 ± 26.47
# Episode 405 finished with reward: 51.46
# Moving average (last 50 episodes): 11.86 ± 27.06
# Episode 406 finished with reward: -2.14
# Moving average (last 50 episodes): 11.62 ± 27.13
# Episode 407 finished with reward: 33.68
# Moving average (last 50 episodes): 12.49 ± 27.12
# Episode 408 finished with reward: 33.09
# Moving average (last 50 episodes): 12.56 ± 27.17
# Episode 409 finished with reward: 35.77
# Moving average (last 50 episodes): 13.58 ± 27.07
# Episode 410 finished with reward: 61.04
# Moving average (last 50 episodes): 15.04 ± 27.61
# Episode 411 finished with reward: -17.92
# Moving average (last 50 episodes): 14.47 ± 27.99
# Episode 412 finished with reward: 58.76
# Moving average (last 50 episodes): 16.40 ± 27.65
# Episode 413 finished with reward: 9.07
# Moving average (last 50 episodes): 16.24 ± 27.67
# Episode 414 finished with reward: -8.19
# Moving average (last 50 episodes): 15.49 ± 27.82
# Episode 415 finished with reward: 57.11
# Moving average (last 50 episodes): 17.05 ± 27.92
# Episode 416 finished with reward: 19.48
# Moving average (last 50 episodes): 17.15 ± 27.92
# Episode 417 finished with reward: 50.73
# Moving average (last 50 episodes): 17.67 ± 28.30
# Episode 418 finished with reward: 28.68
# Moving average (last 50 episodes): 17.99 ± 28.33
# Episode 419 finished with reward: 33.98
# Moving average (last 50 episodes): 18.00 ± 28.33
# Episode 420 finished with reward: 19.48
# Moving average (last 50 episodes): 18.61 ± 28.03
# Episode 421 finished with reward: 5.85
# Moving average (last 50 episodes): 17.61 ± 27.57
# Episode 422 finished with reward: -1.79
# Moving average (last 50 episodes): 17.24 ± 27.70
# Episode 423 finished with reward: 41.01
# Moving average (last 50 episodes): 18.30 ± 27.58
# Episode 424 finished with reward: -5.53
# Moving average (last 50 episodes): 18.21 ± 27.65
# Episode 425 finished with reward: 25.61
# Moving average (last 50 episodes): 18.55 ± 27.64
# Episode 426 finished with reward: 32.17
# Moving average (last 50 episodes): 19.51 ± 27.26
# Episode 427 finished with reward: 76.22
# Moving average (last 50 episodes): 21.45 ± 27.76
# Episode 428 finished with reward: 2.48
# Moving average (last 50 episodes): 20.69 ± 27.75
# Episode 429 finished with reward: 44.88
# Moving average (last 50 episodes): 20.97 ± 27.92
# Episode 430 finished with reward: 17.87
# Moving average (last 50 episodes): 21.00 ± 27.92
# Episode 431 finished with reward: 2.45
# Moving average (last 50 episodes): 20.97 ± 27.93
# Episode 432 finished with reward: 81.61
# Moving average (last 50 episodes): 22.46 ± 29.12
# Episode 433 finished with reward: 26.92
# Moving average (last 50 episodes): 23.18 ± 28.78
# Episode 434 finished with reward: 56.10
# Moving average (last 50 episodes): 22.77 ± 28.16
# Episode 435 finished with reward: 31.79
# Moving average (last 50 episodes): 23.52 ± 27.89
# Episode 436 finished with reward: -6.57
# Moving average (last 50 episodes): 23.31 ± 28.08
# Episode 437 finished with reward: 24.03
# Moving average (last 50 episodes): 23.82 ± 27.85
# Episode 438 finished with reward: 14.04
# Moving average (last 50 episodes): 24.99 ± 26.14
# Episode 439 finished with reward: 21.08
# Moving average (last 50 episodes): 25.42 ± 25.89
# Episode 440 finished with reward: -1.79
# Moving average (last 50 episodes): 25.30 ± 26.01
# Episode 441 finished with reward: -22.04
# Moving average (last 50 episodes): 24.61 ± 26.78
# Episode 442 finished with reward: 70.80
# Moving average (last 50 episodes): 25.00 ± 27.31
# Episode 443 finished with reward: 5.42
# Moving average (last 50 episodes): 24.79 ± 27.41
# Episode 444 finished with reward: -23.18
# Moving average (last 50 episodes): 23.67 ± 28.19
# Episode 445 finished with reward: 35.91
# Moving average (last 50 episodes): 23.45 ± 28.06
# Episode 446 finished with reward: 63.74
# Moving average (last 50 episodes): 24.87 ± 28.26
# Episode 447 finished with reward: 8.19
# Moving average (last 50 episodes): 25.18 ± 28.00
# Episode 448 finished with reward: 43.88
# Moving average (last 50 episodes): 25.54 ± 28.12
# Episode 449 finished with reward: 3.93
# Moving average (last 50 episodes): 25.64 ± 28.04
# Episode 450 finished with reward: 76.44
# Moving average (last 50 episodes): 26.98 ± 28.82
# Episode 451 finished with reward: 59.26
# Moving average (last 50 episodes): 28.73 ± 28.06
# Episode 452 finished with reward: 28.19
# Moving average (last 50 episodes): 28.99 ± 27.99
# Episode 453 finished with reward: -0.91
# Moving average (last 50 episodes): 27.66 ± 27.80
# Episode 454 finished with reward: 8.92
# Moving average (last 50 episodes): 26.22 ± 26.86
# Episode 455 finished with reward: 32.72
# Moving average (last 50 episodes): 25.85 ± 26.63
# Episode 456 finished with reward: 28.58
# Moving average (last 50 episodes): 26.46 ± 26.33
# Episode 457 finished with reward: 32.73
# Moving average (last 50 episodes): 26.44 ± 26.33
# Episode 458 finished with reward: 57.79
# Moving average (last 50 episodes): 26.94 ± 26.68
# Episode 459 finished with reward: 14.47
# Moving average (last 50 episodes): 26.51 ± 26.70
# Episode 460 finished with reward: 6.16
# Moving average (last 50 episodes): 25.41 ± 26.39
# Episode 461 finished with reward: 37.51
# Moving average (last 50 episodes): 26.52 ± 25.70
# Episode 462 finished with reward: 24.65
# Moving average (last 50 episodes): 25.84 ± 25.28
# Episode 463 finished with reward: 49.16
# Moving average (last 50 episodes): 26.64 ± 25.37
# Episode 464 finished with reward: 19.91
# Moving average (last 50 episodes): 27.20 ± 24.90
# Episode 465 finished with reward: 42.81
# Moving average (last 50 episodes): 26.92 ± 24.64
# Episode 466 finished with reward: 21.13
# Moving average (last 50 episodes): 26.95 ± 24.63
# Episode 467 finished with reward: 51.91
# Moving average (last 50 episodes): 26.97 ± 24.65
# Episode 468 finished with reward: 52.83
# Moving average (last 50 episodes): 27.46 ± 24.92
# Episode 469 finished with reward: 53.43
# Moving average (last 50 episodes): 27.84 ± 25.16
# Episode 470 finished with reward: -36.04
# Moving average (last 50 episodes): 26.73 ± 26.69
# Episode 471 finished with reward: 41.84
# Moving average (last 50 episodes): 27.45 ± 26.60
# Episode 472 finished with reward: 4.70
# Moving average (last 50 episodes): 27.58 ± 26.47
# Episode 473 finished with reward: 40.67
# Moving average (last 50 episodes): 27.58 ± 26.47
# Episode 474 finished with reward: 71.17
# Moving average (last 50 episodes): 29.11 ± 26.73
# Episode 475 finished with reward: 34.31
# Moving average (last 50 episodes): 29.29 ± 26.73
# Episode 476 finished with reward: 78.59
# Moving average (last 50 episodes): 30.21 ± 27.61
# Episode 477 finished with reward: 54.47
# Moving average (last 50 episodes): 29.78 ± 27.05
# Episode 478 finished with reward: -1.75
# Moving average (last 50 episodes): 29.69 ± 27.14
# Episode 479 finished with reward: -34.25
# Moving average (last 50 episodes): 28.11 ± 28.48
# Episode 480 finished with reward: -1.33
# Moving average (last 50 episodes): 27.73 ± 28.74
# Episode 481 finished with reward: 46.78
# Moving average (last 50 episodes): 28.61 ± 28.63
# Episode 482 finished with reward: 3.42
# Moving average (last 50 episodes): 27.05 ± 27.82
# Episode 483 finished with reward: -29.59
# Moving average (last 50 episodes): 25.92 ± 28.93
# Episode 484 finished with reward: -6.62
# Moving average (last 50 episodes): 24.67 ± 28.95
# Episode 485 finished with reward: 42.01
# Moving average (last 50 episodes): 24.87 ± 29.04
# Episode 486 finished with reward: 0.18
# Moving average (last 50 episodes): 25.01 ± 28.91
# Episode 487 finished with reward: 19.60
# Moving average (last 50 episodes): 24.92 ± 28.92
# Episode 488 finished with reward: 33.20
# Moving average (last 50 episodes): 25.30 ± 28.90
# Episode 489 finished with reward: 66.96
# Moving average (last 50 episodes): 26.22 ± 29.47
# Episode 490 finished with reward: 7.21
# Moving average (last 50 episodes): 26.40 ± 29.33
# Episode 491 finished with reward: 12.32
# Moving average (last 50 episodes): 27.08 ± 28.58
# Episode 492 finished with reward: 75.83
# Moving average (last 50 episodes): 27.19 ± 28.74
# Episode 493 finished with reward: -13.44
# Moving average (last 50 episodes): 26.81 ± 29.14
# Episode 494 finished with reward: 53.63
# Moving average (last 50 episodes): 28.34 ± 28.48
# Episode 495 finished with reward: 22.14
# Moving average (last 50 episodes): 28.07 ± 28.48
# Episode 496 finished with reward: 65.88
# Moving average (last 50 episodes): 28.11 ± 28.53
# Episode 497 finished with reward: -9.65
# Moving average (last 50 episodes): 27.75 ± 28.89
# Episode 498 finished with reward: 67.39
# Moving average (last 50 episodes): 28.22 ± 29.33
# Episode 499 finished with reward: 75.21
# Moving average (last 50 episodes): 29.65 ± 29.85
# Episode 500 finished with reward: -21.89
# Moving average (last 50 episodes): 27.68 ± 29.94
# Episode 501 finished with reward: 26.87
# Moving average (last 50 episodes): 27.04 ± 29.60
# Episode 502 finished with reward: 35.57
# Moving average (last 50 episodes): 27.18 ± 29.62
# Episode 503 finished with reward: 21.51
# Moving average (last 50 episodes): 27.63 ± 29.36
# Episode 504 finished with reward: 32.13
# Moving average (last 50 episodes): 28.10 ± 29.24
# Episode 505 finished with reward: 12.88
# Moving average (last 50 episodes): 27.70 ± 29.31
# Episode 506 finished with reward: 13.94
# Moving average (last 50 episodes): 27.41 ± 29.37
# Episode 507 finished with reward: 20.65
# Moving average (last 50 episodes): 27.17 ± 29.38
# Episode 508 finished with reward: 6.81
# Moving average (last 50 episodes): 26.15 ± 29.18
# Episode 509 finished with reward: -18.30
# Moving average (last 50 episodes): 25.49 ± 29.80
# Episode 510 finished with reward: 19.58
# Moving average (last 50 episodes): 25.76 ± 29.68
# Episode 511 finished with reward: 5.90
# Moving average (last 50 episodes): 25.13 ± 29.76
# Episode 512 finished with reward: 84.02
# Moving average (last 50 episodes): 26.31 ± 30.88
# Episode 513 finished with reward: 4.52
# Moving average (last 50 episodes): 25.42 ± 30.86
# Episode 514 finished with reward: 67.71
# Moving average (last 50 episodes): 26.38 ± 31.41
# Episode 515 finished with reward: 46.12
# Moving average (last 50 episodes): 26.44 ± 31.44
# Episode 516 finished with reward: 42.00
# Moving average (last 50 episodes): 26.86 ± 31.51
# Episode 517 finished with reward: -3.54
# Moving average (last 50 episodes): 25.75 ± 31.58
# Episode 518 finished with reward: 59.23
# Moving average (last 50 episodes): 25.88 ± 31.71
# Episode 519 finished with reward: -6.09
# Moving average (last 50 episodes): 24.69 ± 31.77
# Episode 520 finished with reward: 49.89
# Moving average (last 50 episodes): 26.41 ± 30.74
# Episode 521 finished with reward: 77.86
# Moving average (last 50 episodes): 27.13 ± 31.51
# Episode 522 finished with reward: 16.71
# Moving average (last 50 episodes): 27.37 ± 31.38
# Episode 523 finished with reward: 18.46
# Moving average (last 50 episodes): 26.92 ± 31.35
# Episode 524 finished with reward: 18.92
# Moving average (last 50 episodes): 25.88 ± 30.72
# Episode 525 finished with reward: -1.64
# Moving average (last 50 episodes): 25.16 ± 30.93
# Episode 526 finished with reward: 18.17
# Moving average (last 50 episodes): 23.95 ± 29.99
# Episode 527 finished with reward: 61.52
# Moving average (last 50 episodes): 24.09 ± 30.15
# Episode 528 finished with reward: -21.32
# Moving average (last 50 episodes): 23.70 ± 30.61
# Episode 529 finished with reward: 29.51
# Moving average (last 50 episodes): 24.98 ± 29.47
# Episode 530 finished with reward: 9.37
# Moving average (last 50 episodes): 25.19 ± 29.32
# Episode 531 finished with reward: -55.47
# Moving average (last 50 episodes): 23.15 ± 31.24
# Episode 532 finished with reward: 28.67
# Moving average (last 50 episodes): 23.65 ± 31.12
# Episode 533 finished with reward: 63.02
# Moving average (last 50 episodes): 25.50 ± 30.65
# Episode 534 finished with reward: 21.18
# Moving average (last 50 episodes): 26.06 ± 30.32
# Episode 535 finished with reward: 37.08
# Moving average (last 50 episodes): 25.96 ± 30.27
# Episode 536 finished with reward: 34.32
# Moving average (last 50 episodes): 26.64 ± 30.07
# ...
# Moving average (last 50 episodes): 56.31 ± 25.38
# Episode 8162 finished with reward: 99.08
# Moving average (last 50 episodes): 57.13 ± 26.08
# Episode 8163 finished with reward: 48.40
# Moving average (last 50 episodes): 56.52 ± 25.92
# Episode 8164 finished with reward: 59.59
# Moving average (last 50 episodes): 57.35 ± 25.33
# Episode 8165 finished with reward: 57.93
# Moving average (last 50 episodes): 57.55 ± 25.30
# Episode 8166 finished with reward: 68.91
# Moving average (last 50 episodes): 57.22 ± 25.04
# Episode 8167 finished with reward: 51.25
# Moving average (last 50 episodes): 57.49 ± 24.89
# Episode 8168 finished with reward: 29.59
# Moving average (last 50 episodes): 56.64 ± 25.10
# Episode 8169 finished with reward: 70.97
# Moving average (last 50 episodes): 56.77 ± 25.16
# Episode 8170 finished with reward: 46.15
# Moving average (last 50 episodes): 56.97 ± 25.03
# Episode 8171 finished with reward: 92.61
# Moving average (last 50 episodes): 57.92 ± 25.46
# Episode 8172 finished with reward: 88.31
# Moving average (last 50 episodes): 58.65 ± 25.80
# Episode 8173 finished with reward: 87.24
# Moving average (last 50 episodes): 60.37 ± 24.74
# Episode 8174 finished with reward: 91.10
# Moving average (last 50 episodes): 61.00 ± 25.11
# Episode 8175 finished with reward: 79.40
# Moving average (last 50 episodes): 61.90 ± 24.95
# Episode 8176 finished with reward: 79.06
# Moving average (last 50 episodes): 61.76 ± 24.84
# Episode 8177 finished with reward: 66.21
# Moving average (last 50 episodes): 62.52 ± 24.37
# Episode 8178 finished with reward: 69.72
# Moving average (last 50 episodes): 63.62 ± 23.41
# Episode 8179 finished with reward: 50.60
# Moving average (last 50 episodes): 63.49 ± 23.46
# Episode 8180 finished with reward: 29.00
# Moving average (last 50 episodes): 62.59 ± 23.90
# Episode 8181 finished with reward: 51.21
# Moving average (last 50 episodes): 62.51 ± 23.93
# Episode 8182 finished with reward: 54.50
# Moving average (last 50 episodes): 62.04 ± 23.86
# Episode 8183 finished with reward: 59.17
# Moving average (last 50 episodes): 61.90 ± 23.85
# Episode 8184 finished with reward: 70.48
# Moving average (last 50 episodes): 61.72 ± 23.75
# Episode 8185 finished with reward: 104.25
# Moving average (last 50 episodes): 62.11 ± 24.28
# Episode 8186 finished with reward: 98.75
# Moving average (last 50 episodes): 62.82 ± 24.82
# Episode 8187 finished with reward: 94.07
# Moving average (last 50 episodes): 62.73 ± 24.70
# Episode 8188 finished with reward: 44.94
# Moving average (last 50 episodes): 62.68 ± 24.73
# Episode 8189 finished with reward: 37.80
# Moving average (last 50 episodes): 61.74 ± 24.77
# Episode 8190 finished with reward: 23.79
# Moving average (last 50 episodes): 60.61 ± 25.18
# Episode 8191 finished with reward: 63.79
# Moving average (last 50 episodes): 61.34 ± 24.73
# Episode 8192 finished with reward: 26.60
# Moving average (last 50 episodes): 60.44 ± 25.16
# Episode 8193 finished with reward: 33.47
# Moving average (last 50 episodes): 60.51 ± 25.08
# Episode 8194 finished with reward: 68.16
# Moving average (last 50 episodes): 61.80 ± 23.73
# Episode 8195 finished with reward: 44.36
# Moving average (last 50 episodes): 61.20 ± 23.79
# Episode 8196 finished with reward: 83.49
# Moving average (last 50 episodes): 61.10 ± 23.68
# Episode 8197 finished with reward: 14.90
# Moving average (last 50 episodes): 60.52 ± 24.44
# Episode 8198 finished with reward: 43.75
# Moving average (last 50 episodes): 60.20 ± 24.55
# Episode 8199 finished with reward: 65.69
# Moving average (last 50 episodes): 60.67 ± 24.42
# Episode 8200 finished with reward: 94.32
# Moving average (last 50 episodes): 62.25 ± 23.98
# Episode 8201 finished with reward: 15.42
# Moving average (last 50 episodes): 61.51 ± 24.83
# Episode 8202 finished with reward: 46.85
# Moving average (last 50 episodes): 61.56 ± 24.79
# Episode 8203 finished with reward: 24.25
# Moving average (last 50 episodes): 60.19 ± 24.93
# Episode 8204 finished with reward: 50.24
# Moving average (last 50 episodes): 60.33 ± 24.86
# Episode 8205 finished with reward: 62.62
# Moving average (last 50 episodes): 60.29 ± 24.85
# Episode 8206 finished with reward: 30.06
# Moving average (last 50 episodes): 59.36 ± 25.09
# Episode 8207 finished with reward: 39.41
# Moving average (last 50 episodes): 59.34 ± 25.10
# Episode 8208 finished with reward: 64.89
# Moving average (last 50 episodes): 59.85 ± 24.95
# Episode 8209 finished with reward: 26.39
# Moving average (last 50 episodes): 58.75 ± 25.18
# Episode 8210 finished with reward: 5.62
# Moving average (last 50 episodes): 56.62 ± 25.08
# Episode 8211 finished with reward: 17.41
# Moving average (last 50 episodes): 56.52 ± 25.22
# Episode 8212 finished with reward: 73.04
# Moving average (last 50 episodes): 55.99 ± 24.60
# Episode 8213 finished with reward: 51.07
# Moving average (last 50 episodes): 56.05 ± 24.59
# Episode 8214 finished with reward: 65.36
# Moving average (last 50 episodes): 56.16 ± 24.62
# Episode 8215 finished with reward: 24.04
# Moving average (last 50 episodes): 55.49 ± 25.02
# Episode 8216 finished with reward: 73.95
# Moving average (last 50 episodes): 55.59 ± 25.08
# Episode 8217 finished with reward: 63.62
# Moving average (last 50 episodes): 55.83 ± 25.10
# Episode 8218 finished with reward: 50.42
# Moving average (last 50 episodes): 56.25 ± 24.83
# Episode 8219 finished with reward: 38.78
# Moving average (last 50 episodes): 55.61 ± 24.86
# Episode 8220 finished with reward: 49.21
# Moving average (last 50 episodes): 55.67 ± 24.84
# Episode 8221 finished with reward: 27.27
# Moving average (last 50 episodes): 54.36 ± 24.58
# Episode 8222 finished with reward: 57.25
# Moving average (last 50 episodes): 53.74 ± 24.10
# Episode 8223 finished with reward: 86.59
# Moving average (last 50 episodes): 53.73 ± 24.09
# Episode 8224 finished with reward: 81.56
# Moving average (last 50 episodes): 53.54 ± 23.82
# Episode 8225 finished with reward: 32.06
# Moving average (last 50 episodes): 52.59 ± 23.72
# Episode 8226 finished with reward: 49.69
# Moving average (last 50 episodes): 52.00 ± 23.42
# Episode 8227 finished with reward: 66.03
# Moving average (last 50 episodes): 52.00 ± 23.42
# Episode 8228 finished with reward: 81.89
# Moving average (last 50 episodes): 52.24 ± 23.66
# Episode 8229 finished with reward: 61.73
# Moving average (last 50 episodes): 52.46 ± 23.70
# Episode 8230 finished with reward: 56.94
# Moving average (last 50 episodes): 53.02 ± 23.46
# Episode 8231 finished with reward: 121.09
# Moving average (last 50 episodes): 54.42 ± 25.32
# Episode 8232 finished with reward: 56.41
# Moving average (last 50 episodes): 54.46 ± 25.32
# Episode 8233 finished with reward: 61.97
# Moving average (last 50 episodes): 54.52 ± 25.34
# Episode 8234 finished with reward: 88.27
# Moving average (last 50 episodes): 54.87 ± 25.68
# Episode 8235 finished with reward: 31.75
# Moving average (last 50 episodes): 53.42 ± 24.89
# Episode 8236 finished with reward: 47.59
# Moving average (last 50 episodes): 52.40 ± 24.04
# Episode 8237 finished with reward: 49.41
# Moving average (last 50 episodes): 51.50 ± 23.29
# Episode 8238 finished with reward: 16.38
# Moving average (last 50 episodes): 50.93 ± 23.79
# Episode 8239 finished with reward: 66.01
# Moving average (last 50 episodes): 51.50 ± 23.81
# Episode 8240 finished with reward: 23.36
# Moving average (last 50 episodes): 51.49 ± 23.82
# Episode 8241 finished with reward: 31.17
# Moving average (last 50 episodes): 50.84 ± 23.92
# Episode 8242 finished with reward: 69.85
# Moving average (last 50 episodes): 51.70 ± 23.81
# Episode 8243 finished with reward: 77.75
# Moving average (last 50 episodes): 52.59 ± 23.94
# Episode 8244 finished with reward: 32.94
# Moving average (last 50 episodes): 51.88 ± 23.99
# Episode 8245 finished with reward: 73.59
# Moving average (last 50 episodes): 52.47 ± 24.15
# Episode 8246 finished with reward: 76.64
# Moving average (last 50 episodes): 52.33 ± 23.99
# Episode 8247 finished with reward: 54.55
# Moving average (last 50 episodes): 53.12 ± 23.39
# Episode 8248 finished with reward: 22.85
# Moving average (last 50 episodes): 52.71 ± 23.74
# Episode 8249 finished with reward: 48.62
# Moving average (last 50 episodes): 52.36 ± 23.67
# Episode 8250 finished with reward: 51.57
# Moving average (last 50 episodes): 51.51 ± 22.90
# Episode 8251 finished with reward: 34.80
# Moving average (last 50 episodes): 51.90 ± 22.45
# Episode 8252 finished with reward: 33.99
# Moving average (last 50 episodes): 51.64 ± 22.58
# Episode 8253 finished with reward: 46.57
# Moving average (last 50 episodes): 52.09 ± 22.25
# Episode 8254 finished with reward: 52.49
# Moving average (last 50 episodes): 52.13 ± 22.25
# Episode 8255 finished with reward: 34.85
# Moving average (last 50 episodes): 51.58 ± 22.33
# Episode 8256 finished with reward: 72.05
# Moving average (last 50 episodes): 52.42 ± 22.29
# Episode 8257 finished with reward: 8.71
# Moving average (last 50 episodes): 51.80 ± 23.05
# Episode 8258 finished with reward: 73.82
# Moving average (last 50 episodes): 51.98 ± 23.18
# Episode 8259 finished with reward: 75.99
# Moving average (last 50 episodes): 52.97 ± 23.13
# Episode 8260 finished with reward: 70.86
# Moving average (last 50 episodes): 54.28 ± 22.24
# Episode 8261 finished with reward: 20.75
# Moving average (last 50 episodes): 54.34 ± 22.14
# Episode 8262 finished with reward: 74.20
# Moving average (last 50 episodes): 54.37 ± 22.16
# Episode 8263 finished with reward: 81.63
# Moving average (last 50 episodes): 54.98 ± 22.48
# Episode 8264 finished with reward: 37.01
# Moving average (last 50 episodes): 54.41 ± 22.57
# Episode 8265 finished with reward: 60.80
# Moving average (last 50 episodes): 55.15 ± 22.16
# Episode 8266 finished with reward: 47.06
# Moving average (last 50 episodes): 54.61 ± 22.02
# Episode 8267 finished with reward: 15.29
# Moving average (last 50 episodes): 53.64 ± 22.66
# Episode 8268 finished with reward: 35.23
# Moving average (last 50 episodes): 53.34 ± 22.80
# Episode 8269 finished with reward: 30.81
# Moving average (last 50 episodes): 53.18 ± 22.93
# Episode 8270 finished with reward: 47.69
# Moving average (last 50 episodes): 53.15 ± 22.94
# Episode 8271 finished with reward: 19.81
# Moving average (last 50 episodes): 53.00 ± 23.13
# Episode 8272 finished with reward: 61.89
# Moving average (last 50 episodes): 53.09 ± 23.15
# Episode 8273 finished with reward: 48.95
# Moving average (last 50 episodes): 52.34 ± 22.66
# Episode 8274 finished with reward: 29.92
# Moving average (last 50 episodes): 51.31 ± 22.48
# Episode 8275 finished with reward: 81.90
# Moving average (last 50 episodes): 52.30 ± 22.71
# Episode 8276 finished with reward: 26.92
# Moving average (last 50 episodes): 51.85 ± 22.98
# Episode 8277 finished with reward: 73.49
# Moving average (last 50 episodes): 52.00 ± 23.10
# Episode 8278 finished with reward: 74.58
# Moving average (last 50 episodes): 51.85 ± 22.93
# Episode 8279 finished with reward: 37.29
# Moving average (last 50 episodes): 51.36 ± 22.98
# Episode 8280 finished with reward: 12.23
# Moving average (last 50 episodes): 50.47 ± 23.60
# Episode 8281 finished with reward: 71.60
# Moving average (last 50 episodes): 49.48 ± 21.57
# Episode 8282 finished with reward: 34.75
# Moving average (last 50 episodes): 49.04 ± 21.64
# Episode 8283 finished with reward: 64.51
# Moving average (last 50 episodes): 49.09 ± 21.68
# Episode 8284 finished with reward: 32.99
# Moving average (last 50 episodes): 47.99 ± 21.05
# Episode 8285 finished with reward: 54.30
# Moving average (last 50 episodes): 48.44 ± 20.94
# Episode 8286 finished with reward: 52.42
# Moving average (last 50 episodes): 48.54 ± 20.95
# Episode 8287 finished with reward: 45.79
# Moving average (last 50 episodes): 48.46 ± 20.95
# Episode 8288 finished with reward: 58.64
# Moving average (last 50 episodes): 49.31 ± 20.49
# Episode 8289 finished with reward: 70.88
# Moving average (last 50 episodes): 49.41 ± 20.58
# Episode 8290 finished with reward: 25.67
# Moving average (last 50 episodes): 49.45 ± 20.52
# Episode 8291 finished with reward: 51.19
# Moving average (last 50 episodes): 49.85 ± 20.35
# Episode 8292 finished with reward: 57.96
# Moving average (last 50 episodes): 49.62 ± 20.19
# Episode 8293 finished with reward: 78.67
# Moving average (last 50 episodes): 49.63 ± 20.21
# Episode 8294 finished with reward: 10.08
# Moving average (last 50 episodes): 49.18 ± 20.84
# Episode 8295 finished with reward: 59.03
# Moving average (last 50 episodes): 48.89 ± 20.59
# Episode 8296 finished with reward: 52.87
# Moving average (last 50 episodes): 48.41 ± 20.22
# Episode 8297 finished with reward: 35.86
# Moving average (last 50 episodes): 48.04 ± 20.27
# Episode 8298 finished with reward: 38.98
# Moving average (last 50 episodes): 48.36 ± 20.00
# Episode 8299 finished with reward: 53.19
# Moving average (last 50 episodes): 48.45 ± 20.01
# Episode 8300 finished with reward: 48.18
# Moving average (last 50 episodes): 48.38 ± 20.00
# Episode 8301 finished with reward: 41.13
# Moving average (last 50 episodes): 48.51 ± 19.94
# Episode 8302 finished with reward: 70.19
# Moving average (last 50 episodes): 49.23 ± 20.05
# Episode 8303 finished with reward: 44.97
# Moving average (last 50 episodes): 49.20 ± 20.06
# Episode 8304 finished with reward: 68.38
# Moving average (last 50 episodes): 49.52 ± 20.23
# Episode 8305 finished with reward: 28.86
# Moving average (last 50 episodes): 49.40 ± 20.34
# Episode 8306 finished with reward: 56.55
# Moving average (last 50 episodes): 49.09 ± 20.11
# Episode 8307 finished with reward: 68.11
# Moving average (last 50 episodes): 50.28 ± 19.43
# Episode 8308 finished with reward: 17.13
# Moving average (last 50 episodes): 49.14 ± 19.67
# Episode 8309 finished with reward: 52.24
# Moving average (last 50 episodes): 48.67 ± 19.30
# Episode 8310 finished with reward: 56.50
# Moving average (last 50 episodes): 48.38 ± 19.08
# Episode 8311 finished with reward: 40.22
# Moving average (last 50 episodes): 48.77 ± 18.70
# Episode 8312 finished with reward: 34.05
# Moving average (last 50 episodes): 47.97 ± 18.46
# Episode 8313 finished with reward: 111.95
# Moving average (last 50 episodes): 48.57 ± 19.99
# Episode 8314 finished with reward: 40.25
# Moving average (last 50 episodes): 48.64 ± 19.95
# Episode 8315 finished with reward: 79.98
# Moving average (last 50 episodes): 49.02 ± 20.36
# Episode 8316 finished with reward: 38.66
# Moving average (last 50 episodes): 48.85 ± 20.41
# Episode 8317 finished with reward: 104.71
# Moving average (last 50 episodes): 50.64 ± 21.29
# Episode 8318 finished with reward: 46.84
# Moving average (last 50 episodes): 50.88 ± 21.19
# Episode 8319 finished with reward: 21.94
# Moving average (last 50 episodes): 50.70 ± 21.39
# Episode 8320 finished with reward: 54.18
# Moving average (last 50 episodes): 50.83 ± 21.39
# Episode 8321 finished with reward: 30.64
# Moving average (last 50 episodes): 51.04 ± 21.13
# Episode 8322 finished with reward: 79.95
# Moving average (last 50 episodes): 51.41 ± 21.46
# Episode 8323 finished with reward: 33.33
# Moving average (last 50 episodes): 51.09 ± 21.61
# Episode 8324 finished with reward: 59.92
# Moving average (last 50 episodes): 51.69 ± 21.43
# Episode 8325 finished with reward: 44.98
# Moving average (last 50 episodes): 50.95 ± 21.01
# Episode 8326 finished with reward: 53.06
# Moving average (last 50 episodes): 51.48 ± 20.73
# Episode 8327 finished with reward: 114.79
# Moving average (last 50 episodes): 52.30 ± 22.35
# Episode 8328 finished with reward: 40.18
# Moving average (last 50 episodes): 51.62 ± 22.18
# Episode 8329 finished with reward: 26.65
# Moving average (last 50 episodes): 51.40 ± 22.37
# Episode 8330 finished with reward: 93.50
# Moving average (last 50 episodes): 53.03 ± 22.41
# Episode 8331 finished with reward: 48.55
# Moving average (last 50 episodes): 52.57 ± 22.26
# Episode 8332 finished with reward: 49.25
# Moving average (last 50 episodes): 52.86 ± 22.12
# Episode 8333 finished with reward: 80.10
# Moving average (last 50 episodes): 53.17 ± 22.39
# Episode 8334 finished with reward: 25.54
# Moving average (last 50 episodes): 53.02 ± 22.55
# Episode 8335 finished with reward: 75.94
# Moving average (last 50 episodes): 53.45 ± 22.78
# Episode 8336 finished with reward: 46.04
# Moving average (last 50 episodes): 53.33 ± 22.80
# Episode 8337 finished with reward: 62.93
# Moving average (last 50 episodes): 53.67 ± 22.81
# Episode 8338 finished with reward: 26.96
# Moving average (last 50 episodes): 53.03 ± 23.11

# %%
# def plot_smooth_rewards(rewards, window_sizes=[5, 20, 100]):
#     """
#     绘制平滑的奖励曲线
#     Args:
#         rewards: 奖励列表
#         window_sizes: 移动平均窗口大小列表
#     """
#     plt.figure(figsize=(12, 6))
    
#     # 绘制原始奖励
#     plt.plot(rewards, 'lightgray', alpha=0.3, label='Raw rewards')
    
#     # 绘制不同窗口大小的移动平均
#     colors = ['blue', 'green', 'red']
#     for window, color in zip(window_sizes, colors):
#         if len(rewards) >= window:
#             # 计算移动平均
#             smooth_rewards = np.convolve(rewards, 
#                                       np.ones(window)/window, 
#                                       mode='valid')
#             plt.plot(range(window-1, len(rewards)), 
#                     smooth_rewards, 
#                     color=color, 
#                     label=f'{window}-Episode Moving Average',
#                     linewidth=2)
    
#     plt.xlabel('Episode')
#     plt.ylabel('Reward')
#     plt.title('Training Rewards with Different Smoothing Windows')
#     plt.grid(True, alpha=0.3)
#     plt.legend()
#     plt.show()


# # 绘制平滑奖励曲线
# plot_smooth_rewards(metrics["rewards"])

# %% [markdown]
# notes: 如果要训练过程中查看模型，通过 tensorboard 查看

# %%
# 模型保存
model.save(f"./model/{log_name}")

# %% [markdown]
# ### 评估模型训练结果

# %% [markdown]
# > 利用 evaulate policy 函数评估

# %% [markdown]
# # 加载训练好的 RL 模型

# %%
from stable_baselines3.common.evaluation import evaluate_policy
mean_reward, std_reward = evaluate_policy(
    model, 
    model.get_env(), 
    deterministic=True,
    render=True,
    n_eval_episodes=10)

print(mean_reward)
print(std_reward)
# Out:
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# 64.525419
# 25.050201958475093

# %%
# del model
model = PPO.load(f"./model/{log_name}", env=env_monitor)
# model = DQN.load(f"./model/{log_name}", env=env_monitor)
# Out:
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### 结果展示

# %% [markdown]
# #### 纯净展示版本
#
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆

for ep in range(episodes):
    
    obs, _ = env_monitor.reset(use_random_reset=base_config["use_random_reset"], seed=base_config["seed"]) # 必须的，每次重现一次
    
    episode_reward = 0
    done = False
    
     
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        print(f"year {env_monitor.t}-Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # # 每10步更新一次图像
        # if i == max_steps-1:
        #     env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            env_monitor.render()
            plt.show()  # 添加这行来保持图形窗口
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")
# Out:
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.t to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.t` for environment variables or `env.get_wrapper_attr('t')` that will search the reminding wrappers.
#   logger.warn(
# year 2017-Step 0 - Action: 6 - Reward: 2.020338387561824 - Done: False
# year 2018-Step 1 - Action: 6 - Reward: 1.8550777590099266 - Done: False
# year 2019-Step 2 - Action: 6 - Reward: 1.6813196133017583 - Done: False
# year 2020-Step 3 - Action: 6 - Reward: 1.5004772370243313 - Done: False
# year 2021-Step 4 - Action: 6 - Reward: 1.3133820319298595 - Done: False
# year 2022-Step 5 - Action: 6 - Reward: 2.270373085245343 - Done: False
# year 2023-Step 6 - Action: 6 - Reward: 1.9315790487489592 - Done: False
# year 2024-Step 7 - Action: 6 - Reward: 1.6104073251419626 - Done: False
# year 2025-Step 8 - Action: 6 - Reward: 1.3070297583023338 - Done: False
# year 2026-Step 9 - Action: 6 - Reward: 1.0217033264997566 - Done: False
# year 2027-Step 10 - Action: 6 - Reward: 0.7548874214820445 - Done: False
# year 2028-Step 11 - Action: 6 - Reward: 0.5068995891927774 - Done: False
# year 2029-Step 12 - Action: 6 - Reward: 0.27817920532716034 - Done: False
# year 2030-Step 13 - Action: 6 - Reward: 0.06917094458549489 - Done: False
# year 2031-Step 14 - Action: 6 - Reward: -0.05989308996328768 - Done: False
# year 2032-Step 15 - Action: 6 - Reward: -0.14437770739617717 - Done: False
# year 2033-Step 16 - Action: 6 - Reward: -0.21908270206397185 - Done: False
# year 2034-Step 17 - Action: 12 - Reward: -0.28412803185564606 - Done: False
# year 2035-Step 18 - Action: 12 - Reward: -0.33975000781320097 - Done: False
# year 2036-Step 19 - Action: 12 - Reward: -0.38644614253702025 - Done: False
# year 2037-Step 20 - Action: 12 - Reward: -0.42475519478118784 - Done: False
# year 2038-Step 21 - Action: 12 - Reward: -0.4550822640069285 - Done: False
# year 2039-Step 22 - Action: 12 - Reward: -0.47784101232045795 - Done: False
# year 2040-Step 23 - Action: 12 - Reward: -0.4934017446149863 - Done: False
# year 2041-Step 24 - Action: 12 - Reward: -0.50212826561295 - Done: False
# year 2042-Step 25 - Action: 12 - Reward: -0.5047685139967517 - Done: False
# year 2043-Step 26 - Action: 12 - Reward: -0.5020712227659963 - Done: False
# year 2044-Step 27 - Action: 12 - Reward: -0.4944735260677491 - Done: False
# year 2045-Step 28 - Action: 12 - Reward: -0.48232458798409983 - Done: False
# year 2046-Step 29 - Action: 12 - Reward: -0.4659308973255738 - Done: False
# year 2047-Step 30 - Action: 12 - Reward: -0.4455863900947987 - Done: False
# year 2048-Step 31 - Action: 12 - Reward: -0.4215299802281691 - Done: False
# year 2049-Step 32 - Action: 12 - Reward: -0.3939884377460312 - Done: False
# year 2050-Step 33 - Action: 12 - Reward: -0.3631514430073901 - Done: False
# year 2051-Step 34 - Action: 12 - Reward: -0.3291957464903794 - Done: False
# year 2052-Step 35 - Action: 12 - Reward: -0.29437085049605294 - Done: False
# year 2053-Step 36 - Action: 12 - Reward: -0.258889746481642 - Done: False
# year 2054-Step 37 - Action: 12 - Reward: -0.22291262477915574 - Done: False
# year 2055-Step 38 - Action: 12 - Reward: -0.1865623167835062 - Done: False
# year 2056-Step 39 - Action: 12 - Reward: -0.1499198701165172 - Done: False
# year 2057-Step 40 - Action: 12 - Reward: -0.11303647089818458 - Done: False
# year 2058-Step 41 - Action: 12 - Reward: -0.07593349554930073 - Done: False
# year 2059-Step 42 - Action: 12 - Reward: -0.038610007943795654 - Done: False
# year 2060-Step 43 - Action: 12 - Reward: -0.0010451401160249674 - Done: False
# year 2061-Step 44 - Action: 12 - Reward: 0.07359445340675341 - Done: False
# year 2062-Step 45 - Action: 12 - Reward: 0.14976790185299738 - Done: False
# year 2063-Step 46 - Action: 12 - Reward: 0.22554443180566652 - Done: False
# year 2064-Step 47 - Action: 12 - Reward: 0.30065733795999305 - Done: False
# year 2065-Step 48 - Action: 12 - Reward: 0.37513962029361414 - Done: False
# year 2066-Step 49 - Action: 12 - Reward: 0.44904909268907334 - Done: False
# year 2067-Step 50 - Action: 12 - Reward: 0.5223533255379587 - Done: False
# year 2068-Step 51 - Action: 12 - Reward: 0.5950439316066247 - Done: False
# year 2069-Step 52 - Action: 12 - Reward: 0.6671685565426855 - Done: False
# year 2070-Step 53 - Action: 12 - Reward: 0.7388203472307153 - Done: False
# year 2071-Step 54 - Action: 12 - Reward: 0.810135780862633 - Done: False
# year 2072-Step 55 - Action: 12 - Reward: 0.8812104189906833 - Done: False
# year 2073-Step 56 - Action: 12 - Reward: 0.9516919574159521 - Done: False
# year 2074-Step 57 - Action: 12 - Reward: 1.0199381403949892 - Done: False
# year 2075-Step 58 - Action: 12 - Reward: 1.0863697206217782 - Done: False
# year 2076-Step 59 - Action: 12 - Reward: 1.1513965873613996 - Done: False
# year 2077-Step 60 - Action: 12 - Reward: 1.215415673797775 - Done: False
# year 2078-Step 61 - Action: 12 - Reward: 1.2788087821107275 - Done: False
# year 2079-Step 62 - Action: 12 - Reward: 1.341936352428923 - Done: False
# year 2080-Step 63 - Action: 12 - Reward: 1.4051422199550645 - Done: False
# year 2081-Step 64 - Action: 12 - Reward: 1.4687431397345985 - Done: False
# year 2082-Step 65 - Action: 12 - Reward: 1.533014773782131 - Done: False
# year 2083-Step 66 - Action: 12 - Reward: 1.5982105376694378 - Done: False
# year 2084-Step 67 - Action: 12 - Reward: 1.6645717957643513 - Done: False
# year 2085-Step 68 - Action: 12 - Reward: 1.7323242922713145 - Done: False
# year 2086-Step 69 - Action: 12 - Reward: 1.80167914195551 - Done: False
# year 2087-Step 70 - Action: 12 - Reward: 1.8728328753177292 - Done: False
# year 2088-Step 71 - Action: 12 - Reward: 1.9459656838405959 - Done: False
# year 2089-Step 72 - Action: 12 - Reward: 2.02124280800402 - Done: False
# year 2090-Step 73 - Action: 12 - Reward: 2.0988146223383186 - Done: False
# year 2091-Step 74 - Action: 12 - Reward: 2.1788173807389155 - Done: False
# year 2092-Step 75 - Action: 12 - Reward: 2.2613711770196265 - Done: False
# year 2093-Step 76 - Action: 12 - Reward: 2.346588456449643 - Done: False
# year 2094-Step 77 - Action: 12 - Reward: 2.434578238731382 - Done: False
# year 2095-Step 78 - Action: 12 - Reward: 1.2627226734584185 - Done: False
# year 2096-Step 79 - Action: 12 - Reward: 1.3096458415663548 - Done: False
# year 2097-Step 80 - Action: 12 - Reward: 1.3581057041965705 - Done: False
# year 2098-Step 81 - Action: 12 - Reward: 1.408147976904004 - Done: False
# year 2099-Step 82 - Action: 12 - Reward: 1.4598206536071345 - Done: False
# year 2100-Step 83 - Action: 12 - Reward: -5.0 - Done: True
# Episode ended at step 83 with T_a = 1.1973653385848921
# Episode 0 finished with reward-5.0
# Final T_a: 1.1973653385848921

# %% [markdown]
# ### 保存整体运行结果

# %%
env_test = IEMEnv(reward_type=custom_reward_type)
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 3 # 结果展示，只有一个 episode 部分
max_steps = 250

# all_episode_rewards = [] # 记录所有 episode 里面的
 
for ep in range(episodes):
    
    ##################################
    # 记录所需数组：每次 episode 重置
    total_action = []
    total_state = []
    total_reward = []
    total_done = []
    ##################################
    # 记录每个 episode 的 reward
    episode_reward = 0
    ##################################
    
    obs, _ = env_test.reset() # 必须的，每次重现一次 ，这里可能就需要固定随机种子了
    done = False
    
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        ##################################
        # 添加转换的部分
        action_number, action_name = IEMEnv.action2number_env(action)
        total_action.append(action_number)
        total_state.append(obs)
        total_reward.append(reward)
        total_done.append(done)
        ##################################
        # 记录每个 episode 的 reward
        episode_reward += reward # TODO：可以放在内容记录 step 部分
        ################################## 
        
        if done:
            print(f"Episode {ep} finished at step {i}")
            break
        
        # # 每10步更新一次图像
        # if ep % 10 == 0:
        #     env_monitor.render()
        #     # plt.pause(0.01)
    
    # all_episode_rewards.append(episode_reward)
    
    env_test.append_data_reward(episode_reward)
    
    save_future_data(env=env_test,custom_reward_type=custom_reward_type,rl_model_name=rl_model_name,network_name=policy_kwargs_diy,episode=ep,total_action=total_action,total_state=total_state,total_reward=total_reward,total_done=total_done,total_timesteps_name=total_timesteps_diy)

    save_plot_NSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    save_plot_SSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    # plot_3D_run(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state)
    
    
    print(f"Episode {ep} finished with reward{episode_reward}")
    
    
plot_data = env_test.get_variables()
plot_episode_reward(plot_data)

# %% [markdown]
# 主要针对可视化显示部分操作

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 绘制只展示一次 episode 结果

# env_test

for episode in range(1):
    obs, _ = env_test.reset() # 这里可能就需要固定随机种子了
    
    done = False
    
    for i in range(251):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        
        if done:
            print(f"Episode {episode} finished at step {i}")
            break
# Out:
# Step 0 - Action: 6 - Reward: 3.0904728670266177 - Done: False
# Step 1 - Action: 6 - Reward: 2.8143259504006064 - Done: False
# Step 2 - Action: 6 - Reward: 2.5388782590533747 - Done: False
# Step 3 - Action: 6 - Reward: 2.2645900074085965 - Done: False
# Step 4 - Action: 6 - Reward: 1.9915873908854798 - Done: False
# Step 5 - Action: 6 - Reward: 1.734452545111016 - Done: False
# Step 6 - Action: 6 - Reward: 1.4926104266443496 - Done: False
# Step 7 - Action: 6 - Reward: 1.2655849260739827 - Done: False
# Step 8 - Action: 6 - Reward: 2.105939852349732 - Done: False
# Step 9 - Action: 6 - Reward: 1.708956263726682 - Done: False
# Step 10 - Action: 6 - Reward: 1.3397211954028054 - Done: False
# Step 11 - Action: 6 - Reward: 0.9978527975752249 - Done: False
# Step 12 - Action: 6 - Reward: 0.6829959997166313 - Done: False
# Step 13 - Action: 6 - Reward: 0.394796378144493 - Done: False
# Step 14 - Action: 6 - Reward: 0.13280484966322836 - Done: False
# Step 15 - Action: 6 - Reward: -0.0518705563332289 - Done: False
# Step 16 - Action: 6 - Reward: -0.15792615235523555 - Done: False
# Step 17 - Action: 12 - Reward: -0.25217684935732176 - Done: False
# Step 18 - Action: 12 - Reward: -0.33510351010520023 - Done: False
# Step 19 - Action: 12 - Reward: -0.40733257865593564 - Done: False
# Step 20 - Action: 12 - Reward: -0.46950881921812626 - Done: False
# Step 21 - Action: 12 - Reward: -0.5221907815099769 - Done: False
# Step 22 - Action: 12 - Reward: -0.5658371019006381 - Done: False
# Step 23 - Action: 12 - Reward: -0.6009295229633072 - Done: False
# Step 24 - Action: 12 - Reward: -0.6279060959506011 - Done: False
# Step 25 - Action: 12 - Reward: -0.647589687542176 - Done: False
# Step 26 - Action: 12 - Reward: -0.6607884712864698 - Done: False
# Step 27 - Action: 12 - Reward: -0.6679795808238542 - Done: False
# Step 28 - Action: 12 - Reward: -0.6696079785970155 - Done: False
# Step 29 - Action: 12 - Reward: -0.6660691501107674 - Done: False
# Step 30 - Action: 12 - Reward: -0.6577030479725332 - Done: False
# Step 31 - Action: 12 - Reward: -0.6448190833832101 - Done: False
# Step 32 - Action: 12 - Reward: -0.6276897340598453 - Done: False
# Step 33 - Action: 12 - Reward: -0.6065628261481659 - Done: False
# Step 34 - Action: 12 - Reward: -0.5816607154983078 - Done: False
# Step 35 - Action: 12 - Reward: -0.55528218880177 - Done: False
# Step 36 - Action: 12 - Reward: -0.5276830948283806 - Done: False
# Step 37 - Action: 12 - Reward: -0.4990652867400114 - Done: False
# Step 38 - Action: 12 - Reward: -0.4695887263041687 - Done: False
# Step 39 - Action: 12 - Reward: -0.43937118304876455 - Done: False
# Step 40 - Action: 12 - Reward: -0.40849638460277116 - Done: False
# Step 41 - Action: 12 - Reward: -0.37701731059586074 - Done: False
# Step 42 - Action: 12 - Reward: -0.34496137871523724 - Done: False
# Step 43 - Action: 12 - Reward: -0.3123346118860304 - Done: False
# Step 44 - Action: 12 - Reward: -0.2791254711061353 - Done: False
# Step 45 - Action: 12 - Reward: -0.24538932987489215 - Done: False
# Step 46 - Action: 12 - Reward: -0.2115981426715441 - Done: False
# Step 47 - Action: 12 - Reward: -0.1780010268139176 - Done: False
# Step 48 - Action: 12 - Reward: -0.1447104071825267 - Done: False
# Step 49 - Action: 12 - Reward: -0.11176112140490746 - Done: False
# Step 50 - Action: 12 - Reward: -0.07915538671950495 - Done: False
# Step 51 - Action: 12 - Reward: -0.046856426698511644 - Done: False
# Step 52 - Action: 12 - Reward: -0.014800184550806117 - Done: False
# Step 53 - Action: 12 - Reward: 0.03419157108593973 - Done: False
# Step 54 - Action: 12 - Reward: 0.09785662320954458 - Done: False
# Step 55 - Action: 12 - Reward: 0.16152824264327625 - Done: False
# Step 56 - Action: 12 - Reward: 0.22488377930348413 - Done: False
# Step 57 - Action: 12 - Reward: 0.2862979354805706 - Done: False
# Step 58 - Action: 12 - Reward: 0.3461951412201092 - Done: False
# Step 59 - Action: 12 - Reward: 0.40498119613043393 - Done: False
# Step 60 - Action: 12 - Reward: 0.4630416617812161 - Done: False
# Step 61 - Action: 12 - Reward: 0.5207381923820353 - Done: False
# Step 62 - Action: 12 - Reward: 0.5784075746205386 - Done: False
# Step 63 - Action: 12 - Reward: 0.636362211103696 - Done: False
# Step 64 - Action: 12 - Reward: 0.6948873297667268 - Done: False
# Step 65 - Action: 12 - Reward: 0.7542225995684393 - Done: False
# Step 66 - Action: 12 - Reward: 0.8145899655754851 - Done: False
# Step 67 - Action: 12 - Reward: 0.8761928697234711 - Done: False
# Step 68 - Action: 12 - Reward: 0.9392206714366358 - Done: False
# Step 69 - Action: 12 - Reward: 1.0038481384941966 - Done: False
# Step 70 - Action: 12 - Reward: 1.0702348912055615 - Done: False
# Step 71 - Action: 12 - Reward: 1.1385255855958798 - Done: False
# Step 72 - Action: 12 - Reward: 1.2088507860112063 - Done: False
# Step 73 - Action: 12 - Reward: 1.2813274523047946 - Done: False
# Step 74 - Action: 12 - Reward: 1.356059804287515 - Done: False
# Step 75 - Action: 12 - Reward: 1.4331361317463398 - Done: False
# Step 76 - Action: 12 - Reward: 1.5126419363942167 - Done: False
# Step 77 - Action: 12 - Reward: 1.5946588296185582 - Done: False
# Step 78 - Action: 12 - Reward: 1.6792659204472615 - Done: False
# Step 79 - Action: 12 - Reward: 1.7665399372822899 - Done: False
# Step 80 - Action: 12 - Reward: 1.8565612061484593 - Done: False
# Step 81 - Action: 12 - Reward: 1.949409865834777 - Done: False
# Step 82 - Action: 12 - Reward: 2.0451315904287237 - Done: False
# Step 83 - Action: 12 - Reward: 2.143802990236592 - Done: True
# Episode 0 finished at step 83

# %% [markdown]
# # 保存运行结果
