# %% [markdown]
# # RL 训练

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import scipy.io
from matplotlib.gridspec import GridSpec
import math
import random
import torch

from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.logger import configure
from stable_baselines3.common.monitor import Monitor
from stable_baselines3 import PPO 
from stable_baselines3 import DQN

# 导入 BaseCallback
from stable_baselines3.common.callbacks import BaseCallback

import sys
import os

# 将 src 目录添加到模块搜索路径
sys.path.append(os.path.abspath('src'))

# 导入 IEMEnv 类
from src.envs.iseec_lx_v4_mdp_plot import IEMEnv
from src.utils.run_debug_plot import save_data 
from src.utils.run_debug_plot import save_plot_NSM_data
from src.utils.run_debug_plot import save_plot_SSM_data

from src.utils.run_debug_plot import save_future_data
from src.utils.run_debug_plot import save_plot_NSM_future_data
from src.utils.run_debug_plot import save_plot_SSM_future_data

from src.utils.run_debug_plot import plot_episode_reward
from src.utils.run_debug_plot import plot_episode_reward_simple
from src.utils.run_debug_plot import plot_3D_run

# %% [markdown]
# 定义保存位置参数
#
# > 所有的关键参数都放在最前面

# %%
# 增加随机种子的定义
def set_global_seed(seed):
    """设置全局随机种子"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# 设置全局种子
# SEED = 42 # 非测试，不指定种子
# set_global_seed(SEED)

custom_reward_type = "critical_ste_temperature"
network_name = "Netxxx_no"
rl_model_name = "PPO"
total_timesteps_diy = 1e6

# gamma_diy = 0.99 # 但是是定义在 model 中，

policy_kwargs_diy = "dict_pi_vf_default" # for example: policy_kwargs = dict(activation_fn=th.nn.ReLU,net_arch=[256, 256, dict(pi=[128, 64], vf=[128, 64])])

# 设置保存的日志名字：
log_name = f"iseec_v4_{rl_model_name}_{policy_kwargs_diy}_{int(total_timesteps_diy)}_{custom_reward_type}" # log_name = "iseec_v4_PPO_Net256_6e5_callback"
os.makedirs(f"./logs/{log_name}", exist_ok=True) # # 创建日志目录

# 设置日志保存路径和格式
tmp_path = f"logs/{log_name}"
new_logger = configure(
    tmp_path, 
    ["stdout",     # 终端输出
     "csv",        # CSV文件
     "tensorboard", # Tensorboard格式
     "json"        # JSON格式
    ]
)
# Out:
# Logging to logs/iseec_v4_PPO_dict_pi_vf_default_1000000_critical_ste_temperature

# %%
log_name
# Out:
# 'iseec_v4_PPO_dict_pi_vf_default_1000000_critical_ste_temperature'

# %% [markdown]
# ### 定义环境

# %%
env = IEMEnv(reward_type=custom_reward_type)

# env.seed(42) 还是需要自己手动定义的

env_monitor = Monitor(env, f'./logs/{log_name}')

# check 环境
from stable_baselines3.common.env_checker import check_env
check_env(env_monitor)


print("Action space sample:", env.action_space.sample())
# print("Observation space sample:", env.observation_space.sample())

# type(env.action_space), type(env.observation_space)
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]
# Action space sample: [0 0 0 1]

# %%
print("Action space sample:", env.action_space.sample())
print("Observation space sample:", env.observation_space.sample())
# Out:
# Action space sample: [0 1 1 1]
# Observation space sample: [-0.72679777  0.06552112 -0.74394582 -1.19428581 -0.61157624  0.56207181
#   0.4462994   0.00334092 -0.01098108  1.10786805]

# %% [markdown]
# ### 定义算法

# %%
# 定义模型
model = PPO(
    "MlpPolicy", 
    env_monitor, 

    verbose=1,
    )



# model = DQN(
#     "MlpPolicy", 
#     env_monitor, 

#     verbose=1,
#     )

model.set_logger(new_logger) # set the parameter of the logger

print(model.policy)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (pi_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (vf_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=8, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %% [markdown]
# ### 模型训练

# %%
def plot_callback_reward(metrics):
    """绘制训练过程中的奖励曲线
    
    Args:
        metrics (dict): 包含训练指标的字典，需要包含以下键：
            - rewards: 原始奖励列表
            - moving_avg_rewards: 移动平均奖励列表
            - moving_std_rewards: 移动标准差列表
            - episodes: 总回合数
            - step_idx: 当前步数
    """
    plt.figure(figsize=(20, 5))
    
    # 创建主图
    plt.subplot(131)
    plt.title(f'Step: {metrics["step_idx"]}, Latest reward: {metrics["rewards"][-1]:.2f}\n'
              f'Episode: {metrics["episodes"]}, Moving avg: {metrics["moving_avg_rewards"][-1]:.2f}')
    
    # 绘制原始奖励
    episodes = range(len(metrics["rewards"]))
    plt.plot(episodes, metrics["rewards"], 
             label='Raw rewards', color='gray', alpha=0.3)
    
    # 绘制移动平均
    plt.plot(episodes, metrics["moving_avg_rewards"],
             label='Moving average', color='blue', linewidth=2)
    
    # 添加标准差区域
    moving_avg = np.array(metrics["moving_avg_rewards"])
    moving_std = np.array(metrics["moving_std_rewards"])
    
    # 0.25倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.25 * moving_std,
                    moving_avg + 0.25 * moving_std,
                    color='b', alpha=0.1,
                    label='0.25 std range')
    
    # 0.5倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.5 * moving_std,
                    moving_avg + 0.5 * moving_std,
                    color='b', alpha=0.1,
                    label='0.5 std range')
    
    # 设置坐标轴和标签
    plt.xlabel('Episodes')
    plt.ylabel('Episode Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()


class TrainingMonitorCallback(BaseCallback):
    def __init__(self, verbose=1, window_size=50):
        super().__init__(verbose)
        self.window_size = window_size
        # Initialize data dictionary to store metrics
        self.data = {
            "rewards": [],
            "moving_avg_rewards": [],
            "moving_std_rewards": [],
            "episodes": 0,
            "step_idx": 0
        }
        self.episode_rewards = 0
        
    def _on_step(self):
        # Accumulate rewards for current episode
        reward = self.locals.get('rewards')[0]
        self.episode_rewards += reward
        self.data["step_idx"] += 1
        
        # When episode ends, update all metrics
        if self.locals.get('dones')[0]:
            # Store raw reward
            self.data["rewards"].append(self.episode_rewards)
            
            # Calculate moving average and std
            recent_rewards = self.data["rewards"][-self.window_size:]
            moving_avg = np.mean(recent_rewards)
            moving_std = np.std(recent_rewards) if len(recent_rewards) > 1 else 0
            
            # Store calculated metrics
            self.data["moving_avg_rewards"].append(moving_avg)
            self.data["moving_std_rewards"].append(moving_std)
            self.data["episodes"] += 1
            
            # Print progress
            print(f"Episode {self.data['episodes']} finished with reward: {self.episode_rewards:.2f}")
            print(f"Moving average (last {len(recent_rewards)} episodes): {moving_avg:.2f} ± {moving_std:.2f}")
            
            # Reset episode rewards
            self.episode_rewards = 0
            
        return True
    
    def get_metrics(self):
        """Return the collected metrics"""
        return self.data
# Create callback with custom window size
callback = TrainingMonitorCallback(window_size=50)

# Train the model
model.learn(
    total_timesteps=int(total_timesteps_diy),
    callback=callback,
    log_interval=1
)

# After training, get metrics for plotting
metrics = callback.get_metrics()

# Plot rewards using the plot_callback_reward function
plot_callback_reward(metrics)
# Out:
# Outside PB!
# Episode 1 finished with reward: -225.79
# Moving average (last 1 episodes): -225.79 ± 0.00
# Episode 2 finished with reward: -512.99
# Moving average (last 2 episodes): -369.39 ± 143.60
# Episode 3 finished with reward: -978.00
# Moving average (last 3 episodes): -572.26 ± 309.94
# Episode 4 finished with reward: -1002.46
# Moving average (last 4 episodes): -679.81 ± 326.72
# Outside PB!
# Episode 5 finished with reward: -249.77
# Moving average (last 5 episodes): -593.80 ± 339.10
# Episode 6 finished with reward: -746.77
# Moving average (last 6 episodes): -619.29 ± 314.76
# Episode 7 finished with reward: -674.47
# Moving average (last 7 episodes): -627.18 ± 292.05
# Outside PB!
# Episode 8 finished with reward: -302.66
# Moving average (last 8 episodes): -586.61 ± 293.51
# Episode 9 finished with reward: -835.80
# Moving average (last 9 episodes): -614.30 ± 287.59
# Episode 10 finished with reward: -921.07
# Moving average (last 10 episodes): -644.98 ± 287.94
# Episode 11 finished with reward: -1267.28
# Moving average (last 11 episodes): -701.55 ± 327.68
# Episode 12 finished with reward: -1210.63
# Moving average (last 12 episodes): -743.97 ± 343.84
# Episode 13 finished with reward: -609.45
# Moving average (last 13 episodes): -733.63 ± 332.29
# Outside PB!
# Episode 14 finished with reward: -271.46
# Moving average (last 14 episodes): -700.61 ± 341.61
# Outside PB!
# Episode 15 finished with reward: -285.45
# Moving average (last 15 episodes): -672.94 ± 345.89
# Outside PB!
# Episode 16 finished with reward: -220.17
# Moving average (last 16 episodes): -644.64 ± 352.38
# Episode 17 finished with reward: -1127.12
# Moving average (last 17 episodes): -673.02 ± 360.22
# Episode 18 finished with reward: -474.59
# Moving average (last 18 episodes): -662.00 ± 353.01
# Outside PB!
# Episode 19 finished with reward: -213.44
# Moving average (last 19 episodes): -638.39 ± 357.90
# Outside PB!
# Episode 20 finished with reward: -216.84
# Moving average (last 20 episodes): -617.31 ± 360.73
# Outside PB!
# Episode 21 finished with reward: -249.35
# Moving average (last 21 episodes): -599.79 ± 360.65
# Episode 22 finished with reward: -765.11
# Moving average (last 22 episodes): -607.30 ± 354.04
# Episode 23 finished with reward: -1254.77
# Moving average (last 23 episodes): -635.45 ± 370.58
# Episode 24 finished with reward: -693.91
# Moving average (last 24 episodes): -637.89 ± 362.96
# Episode 25 finished with reward: -827.80
# Moving average (last 25 episodes): -645.49 ± 357.57
# Outside PB!
# Episode 26 finished with reward: -292.59
# Moving average (last 26 episodes): -631.91 ± 357.13
# Episode 27 finished with reward: -1160.81
# Moving average (last 27 episodes): -651.50 ± 364.41
# Outside PB!
# Episode 28 finished with reward: -281.36
# Moving average (last 28 episodes): -638.28 ± 364.38
# Episode 29 finished with reward: -395.20
# Moving average (last 29 episodes): -629.90 ± 360.78
# Episode 30 finished with reward: -714.47
# Moving average (last 30 episodes): -632.72 ± 355.04
# Outside PB!
# Episode 31 finished with reward: -357.15
# Moving average (last 31 episodes): -623.83 ± 352.64
# Outside PB!
# Episode 32 finished with reward: -238.28
# Moving average (last 32 episodes): -611.78 ± 353.51
# Outside PB!
# Episode 33 finished with reward: -257.63
# Moving average (last 33 episodes): -601.05 ± 353.37
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61.3     |
# |    ep_rew_mean     | -601     |
# | time/              |          |
# |    fps             | 123      |
# |    iterations      | 1        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode 34 finished with reward: -813.38
# Moving average (last 34 episodes): -607.29 ± 349.98
# Outside PB!
# Episode 35 finished with reward: -362.56
# Moving average (last 35 episodes): -600.30 ± 347.34
# Episode 36 finished with reward: -380.10
# Moving average (last 36 episodes): -594.19 ± 344.39
# Episode 37 finished with reward: -780.55
# Moving average (last 37 episodes): -599.22 ± 341.05
# Episode 38 finished with reward: -666.25
# Moving average (last 38 episodes): -600.99 ± 336.70
# Episode 39 finished with reward: -863.74
# Moving average (last 39 episodes): -607.72 ± 334.94
# Outside PB!
# Episode 40 finished with reward: -261.79
# Moving average (last 40 episodes): -599.07 ± 335.11
# Episode 41 finished with reward: -828.03
# Moving average (last 41 episodes): -604.66 ± 332.88
# Episode 42 finished with reward: -813.80
# Moving average (last 42 episodes): -609.64 ± 330.43
# Episode 43 finished with reward: -1078.14
# Moving average (last 43 episodes): -620.53 ± 334.11
# Episode 44 finished with reward: -1033.78
# Moving average (last 44 episodes): -629.93 ± 335.99
# Episode 45 finished with reward: -871.82
# Moving average (last 45 episodes): -635.30 ± 334.14
# Outside PB!
# Episode 46 finished with reward: -204.21
# Moving average (last 46 episodes): -625.93 ± 336.42
# Outside PB!
# Episode 47 finished with reward: -325.97
# Moving average (last 47 episodes): -619.55 ± 335.62
# Episode 48 finished with reward: -1300.44
# Moving average (last 48 episodes): -633.73 ± 346.05
# Outside PB!
# Episode 49 finished with reward: -254.35
# Moving average (last 49 episodes): -625.99 ± 346.68
# Outside PB!
# Episode 50 finished with reward: -267.68
# Moving average (last 50 episodes): -618.82 ± 346.84
# Episode 51 finished with reward: -1065.75
# Moving average (last 50 episodes): -635.62 ± 347.74
# Outside PB!
# Episode 52 finished with reward: -211.46
# Moving average (last 50 episodes): -629.59 ± 352.39
# Episode 53 finished with reward: -1152.00
# Moving average (last 50 episodes): -633.07 ± 356.65
# Episode 54 finished with reward: -894.01
# Moving average (last 50 episodes): -630.90 ± 354.72
# Outside PB!
# Episode 55 finished with reward: -322.22
# Moving average (last 50 episodes): -632.35 ± 353.31
# Outside PB!
# Episode 56 finished with reward: -282.68
# Moving average (last 50 episodes): -623.07 ± 356.26
# Episode 57 finished with reward: -745.17
# Moving average (last 50 episodes): -624.49 ± 356.61
# Outside PB!
# Episode 58 finished with reward: -365.80
# Moving average (last 50 episodes): -625.75 ± 355.57
# Outside PB!
# Episode 59 finished with reward: -225.89
# Moving average (last 50 episodes): -613.55 ± 358.61
# Outside PB!
# Episode 60 finished with reward: -201.40
# Moving average (last 50 episodes): -599.16 ± 360.41
# Episode 61 finished with reward: -951.88
# Moving average (last 50 episodes): -592.85 ± 351.31
# Outside PB!
# Episode 62 finished with reward: -239.01
# Moving average (last 50 episodes): -573.42 ± 343.38
# Episode 63 finished with reward: -679.99
# Moving average (last 50 episodes): -574.83 ± 343.67
# Episode 64 finished with reward: -788.42
# Moving average (last 50 episodes): -585.17 ± 342.16
# Outside PB!
# Episode 65 finished with reward: -241.31
# Moving average (last 50 episodes): -584.28 ± 342.99
# Episode 66 finished with reward: -958.00
# Moving average (last 50 episodes): -599.04 ± 342.88
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.2        |
# |    ep_rew_mean          | -610        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 2           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008044444 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | -0.000211   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00408    |
# |    value_loss           | 2.86e+04    |
# -----------------------------------------
# Episode 67 finished with reward: -874.26
# Moving average (last 50 episodes): -593.98 ± 336.87
# Episode 68 finished with reward: -976.29
# Moving average (last 50 episodes): -604.02 ± 340.61
# Episode 69 finished with reward: -1081.90
# Moving average (last 50 episodes): -621.39 ± 342.39
# Episode 70 finished with reward: -469.48
# Moving average (last 50 episodes): -626.44 ± 338.22
# Outside PB!
# Episode 71 finished with reward: -219.18
# Moving average (last 50 episodes): -625.84 ± 338.92
# Episode 72 finished with reward: -772.72
# Moving average (last 50 episodes): -625.99 ± 338.99
# Episode 73 finished with reward: -784.54
# Moving average (last 50 episodes): -616.58 ± 327.75
# Episode 74 finished with reward: -890.30
# Moving average (last 50 episodes): -620.51 ± 329.82
# Outside PB!
# Episode 75 finished with reward: -282.58
# Moving average (last 50 episodes): -609.61 ± 331.79
# Episode 76 finished with reward: -953.06
# Moving average (last 50 episodes): -622.82 ± 332.06
# Episode 77 finished with reward: -1096.04
# Moving average (last 50 episodes): -621.52 ± 330.08
# Episode 78 finished with reward: -1167.43
# Moving average (last 50 episodes): -639.24 ± 335.09
# Outside PB!
# Episode 79 finished with reward: -258.82
# Moving average (last 50 episodes): -636.51 ± 337.61
# Episode 80 finished with reward: -1193.25
# Moving average (last 50 episodes): -646.09 ± 346.36
# Episode 81 finished with reward: -1035.06
# Moving average (last 50 episodes): -659.65 ± 348.05
# Episode 82 finished with reward: -874.93
# Moving average (last 50 episodes): -672.38 ± 344.02
# Episode 83 finished with reward: -920.28
# Moving average (last 50 episodes): -685.63 ± 340.53
# Episode 84 finished with reward: -1120.29
# Moving average (last 50 episodes): -691.77 ± 345.51
# Outside PB!
# Episode 85 finished with reward: -238.28
# Moving average (last 50 episodes): -689.29 ± 348.31
# Episode 86 finished with reward: -778.53
# Moving average (last 50 episodes): -697.25 ± 345.69
# Episode 87 finished with reward: -639.05
# Moving average (last 50 episodes): -694.42 ± 345.58
# Episode 88 finished with reward: -1092.83
# Moving average (last 50 episodes): -702.96 ± 350.01
# Outside PB!
# Episode 89 finished with reward: -226.12
# Moving average (last 50 episodes): -690.20 ± 355.49
# Episode 90 finished with reward: -804.58
# Moving average (last 50 episodes): -701.06 ± 350.50
# Episode 91 finished with reward: -473.68
# Moving average (last 50 episodes): -693.97 ± 351.44
# Episode 92 finished with reward: -1041.26
# Moving average (last 50 episodes): -698.52 ± 354.42
# Episode 93 finished with reward: -1054.22
# Moving average (last 50 episodes): -698.04 ± 353.92
# Episode 94 finished with reward: -1004.49
# Moving average (last 50 episodes): -697.46 ± 353.39
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65          |
# |    ep_rew_mean          | -666        |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 3           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008743194 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.000461    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.42e+04    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00299    |
# |    value_loss           | 3.02e+04    |
# -----------------------------------------
# Episode 95 finished with reward: -818.71
# Moving average (last 50 episodes): -696.40 ± 352.95
# Outside PB!
# Episode 96 finished with reward: -257.51
# Moving average (last 50 episodes): -697.46 ± 351.54
# Episode 97 finished with reward: -849.39
# Moving average (last 50 episodes): -707.93 ± 348.09
# Episode 98 finished with reward: -808.58
# Moving average (last 50 episodes): -698.09 ± 338.01
# Episode 99 finished with reward: -979.09
# Moving average (last 50 episodes): -712.59 ± 334.19
# Outside PB!
# Episode 100 finished with reward: -176.35
# Moving average (last 50 episodes): -710.76 ± 336.86
# Outside PB!
# Episode 101 finished with reward: -261.49
# Moving average (last 50 episodes): -694.68 ± 338.72
# Episode 102 finished with reward: -815.66
# Moving average (last 50 episodes): -706.76 ± 331.98
# Outside PB!
# Episode 103 finished with reward: -186.47
# Moving average (last 50 episodes): -687.45 ± 333.59
# Episode 104 finished with reward: -867.27
# Moving average (last 50 episodes): -686.91 ± 333.28
# Episode 105 finished with reward: -764.73
# Moving average (last 50 episodes): -695.76 ± 329.33
# Episode 106 finished with reward: -782.28
# Moving average (last 50 episodes): -705.76 ± 324.19
# Episode 107 finished with reward: -826.37
# Moving average (last 50 episodes): -707.38 ± 324.58
# Episode 108 finished with reward: -855.33
# Moving average (last 50 episodes): -717.17 ± 321.50
# Episode 109 finished with reward: -1094.20
# Moving average (last 50 episodes): -734.54 ± 317.93
# Episode 110 finished with reward: -752.72
# Moving average (last 50 episodes): -745.56 ± 308.67
# Episode 111 finished with reward: -1054.96
# Moving average (last 50 episodes): -747.62 ± 310.38
# Episode 112 finished with reward: -366.61
# Moving average (last 50 episodes): -750.18 ± 306.69
# Outside PB!
# Episode 113 finished with reward: -352.52
# Moving average (last 50 episodes): -743.63 ± 311.58
# Outside PB!
# Episode 114 finished with reward: -210.82
# Moving average (last 50 episodes): -732.08 ± 320.29
# Outside PB!
# Episode 115 finished with reward: -360.04
# Moving average (last 50 episodes): -734.45 ± 317.07
# Outside PB!
# Episode 116 finished with reward: -250.55
# Moving average (last 50 episodes): -720.30 ± 322.51
# Outside PB!
# Episode 117 finished with reward: -287.27
# Moving average (last 50 episodes): -708.56 ± 327.34
# Episode 118 finished with reward: -792.79
# Moving average (last 50 episodes): -704.89 ± 325.34
# Episode 119 finished with reward: -953.58
# Moving average (last 50 episodes): -702.33 ± 322.85
# Episode 120 finished with reward: -715.34
# Moving average (last 50 episodes): -707.24 ± 321.14
# Outside PB!
# Episode 121 finished with reward: -183.86
# Moving average (last 50 episodes): -706.54 ± 322.25
# Episode 122 finished with reward: -804.43
# Moving average (last 50 episodes): -707.17 ± 322.41
# Outside PB!
# Episode 123 finished with reward: -278.53
# Moving average (last 50 episodes): -697.05 ± 327.72
# Episode 124 finished with reward: -697.36
# Moving average (last 50 episodes): -693.19 ± 326.56
# Episode 125 finished with reward: -602.22
# Moving average (last 50 episodes): -699.58 ± 321.54
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.1        |
# |    ep_rew_mean          | -655        |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 4           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011163488 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.000242    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.56e+04    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00768    |
# |    value_loss           | 3.42e+04    |
# -----------------------------------------
# Episode 126 finished with reward: -649.99
# Moving average (last 50 episodes): -693.52 ± 319.56
# Outside PB!
# Episode 127 finished with reward: -357.67
# Moving average (last 50 episodes): -678.76 ± 317.67
# Episode 128 finished with reward: -625.86
# Moving average (last 50 episodes): -667.92 ± 309.97
# Outside PB!
# Episode 129 finished with reward: -283.97
# Moving average (last 50 episodes): -668.43 ± 309.32
# Episode 130 finished with reward: -650.94
# Moving average (last 50 episodes): -657.58 ± 300.10
# Outside PB!
# Episode 131 finished with reward: -229.05
# Moving average (last 50 episodes): -641.46 ± 301.04
# Outside PB!
# Episode 132 finished with reward: -188.40
# Moving average (last 50 episodes): -627.73 ± 305.69
# Outside PB!
# Episode 133 finished with reward: -225.63
# Moving average (last 50 episodes): -613.84 ± 307.86
# Outside PB!
# Episode 134 finished with reward: -221.65
# Moving average (last 50 episodes): -595.86 ± 303.98
# Episode 135 finished with reward: -922.37
# Moving average (last 50 episodes): -609.55 ± 302.97
# Outside PB!
# Episode 136 finished with reward: -179.16
# Moving average (last 50 episodes): -597.56 ± 307.86
# Outside PB!
# Episode 137 finished with reward: -205.80
# Moving average (last 50 episodes): -588.89 ± 312.63
# Episode 138 finished with reward: -571.61
# Moving average (last 50 episodes): -578.47 ± 304.23
# Outside PB!
# Episode 139 finished with reward: -212.03
# Moving average (last 50 episodes): -578.19 ± 304.56
# Outside PB!
# Episode 140 finished with reward: -230.27
# Moving average (last 50 episodes): -566.70 ± 306.63
# Episode 141 finished with reward: -1010.09
# Moving average (last 50 episodes): -577.43 ± 312.52
# Outside PB!
# Episode 142 finished with reward: -274.50
# Moving average (last 50 episodes): -562.09 ± 308.16
# Outside PB!
# Episode 143 finished with reward: -210.37
# Moving average (last 50 episodes): -545.22 ± 303.83
# Outside PB!
# Episode 144 finished with reward: -159.31
# Moving average (last 50 episodes): -528.31 ± 301.30
# Outside PB!
# Episode 145 finished with reward: -195.59
# Moving average (last 50 episodes): -515.85 ± 301.92
# Outside PB!
# Episode 146 finished with reward: -218.56
# Moving average (last 50 episodes): -515.07 ± 302.64
# Episode 147 finished with reward: -1003.94
# Moving average (last 50 episodes): -518.16 ± 306.80
# Outside PB!
# Episode 148 finished with reward: -386.41
# Moving average (last 50 episodes): -509.72 ± 304.49
# Episode 149 finished with reward: -727.56
# Moving average (last 50 episodes): -504.69 ± 298.71
# Episode 150 finished with reward: -990.05
# Moving average (last 50 episodes): -520.96 ± 302.52
# Outside PB!
# Episode 151 finished with reward: -312.97
# Moving average (last 50 episodes): -521.99 ± 301.73
# Outside PB!
# Episode 152 finished with reward: -236.44
# Moving average (last 50 episodes): -510.41 ± 301.35
# Outside PB!
# Episode 153 finished with reward: -291.91
# Moving average (last 50 episodes): -512.52 ± 299.44
# Outside PB!
# Episode 154 finished with reward: -321.10
# Moving average (last 50 episodes): -501.59 ± 296.24
# Outside PB!
# Episode 155 finished with reward: -278.68
# Moving average (last 50 episodes): -491.87 ± 295.42
# Outside PB!
# Episode 156 finished with reward: -324.93
# Moving average (last 50 episodes): -482.73 ± 293.36
# Outside PB!
# Episode 157 finished with reward: -204.65
# Moving average (last 50 episodes): -470.29 ± 291.70
# Outside PB!
# Episode 158 finished with reward: -239.28
# Moving average (last 50 episodes): -457.97 ± 288.17
# Episode 159 finished with reward: -854.09
# Moving average (last 50 episodes): -453.17 ± 279.39
# Episode 160 finished with reward: -1063.86
# Moving average (last 50 episodes): -459.39 ± 289.28
# Outside PB!
# Episode 161 finished with reward: -233.32
# Moving average (last 50 episodes): -442.96 ± 278.11
# Outside PB!
# Episode 162 finished with reward: -191.77
# Moving average (last 50 episodes): -439.46 ± 280.14
# Outside PB!
# Episode 163 finished with reward: -344.59
# Moving average (last 50 episodes): -439.30 ± 280.19
# Outside PB!
# Episode 164 finished with reward: -241.03
# Moving average (last 50 episodes): -439.91 ± 279.73
# Episode 165 finished with reward: -801.31
# Moving average (last 50 episodes): -448.73 ± 284.00
# Outside PB!
# Episode 166 finished with reward: -238.61
# Moving average (last 50 episodes): -448.49 ± 284.17
# Episode 167 finished with reward: -1169.53
# Moving average (last 50 episodes): -466.14 ± 300.53
# Episode 168 finished with reward: -851.65
# Moving average (last 50 episodes): -467.32 ± 301.92
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 59.5         |
# |    ep_rew_mean          | -586         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 5            |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0085706785 |
# |    clip_fraction        | 0.0855       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.000229     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63e+04     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00961     |
# |    value_loss           | 2.59e+04     |
# ------------------------------------------
# Episode 169 finished with reward: -636.84
# Moving average (last 50 episodes): -460.98 ± 294.89
# Outside PB!
# Episode 170 finished with reward: -220.52
# Moving average (last 50 episodes): -451.09 ± 294.49
# Outside PB!
# Episode 171 finished with reward: -222.34
# Moving average (last 50 episodes): -451.85 ± 293.84
# Outside PB!
# Episode 172 finished with reward: -188.85
# Moving average (last 50 episodes): -439.54 ± 291.70
# Outside PB!
# Episode 173 finished with reward: -176.09
# Moving average (last 50 episodes): -437.49 ± 293.18
# Outside PB!
# Episode 174 finished with reward: -263.99
# Moving average (last 50 episodes): -428.83 ± 291.77
# Outside PB!
# Episode 175 finished with reward: -182.70
# Moving average (last 50 episodes): -420.44 ± 292.69
# Outside PB!
# Episode 176 finished with reward: -187.66
# Moving average (last 50 episodes): -411.19 ± 292.60
# Outside PB!
# Episode 177 finished with reward: -227.92
# Moving average (last 50 episodes): -408.60 ± 293.64
# Episode 178 finished with reward: -774.28
# Moving average (last 50 episodes): -411.56 ± 296.55
# Outside PB!
# Episode 179 finished with reward: -202.99
# Moving average (last 50 episodes): -409.94 ± 297.46
# Outside PB!
# Episode 180 finished with reward: -206.87
# Moving average (last 50 episodes): -401.06 ± 296.77
# Outside PB!
# Episode 181 finished with reward: -184.67
# Moving average (last 50 episodes): -400.18 ± 297.34
# Outside PB!
# Episode 182 finished with reward: -308.07
# Moving average (last 50 episodes): -402.57 ± 296.11
# Outside PB!
# Episode 183 finished with reward: -202.58
# Moving average (last 50 episodes): -402.11 ± 296.40
# Outside PB!
# Episode 184 finished with reward: -193.86
# Moving average (last 50 episodes): -401.55 ± 296.77
# Outside PB!
# Episode 185 finished with reward: -208.59
# Moving average (last 50 episodes): -387.28 ± 288.42
# Outside PB!
# Episode 186 finished with reward: -216.48
# Moving average (last 50 episodes): -388.02 ± 287.93
# Outside PB!
# Episode 187 finished with reward: -190.55
# Moving average (last 50 episodes): -387.72 ± 288.13
# Outside PB!
# Episode 188 finished with reward: -231.46
# Moving average (last 50 episodes): -380.91 ± 287.72
# Episode 189 finished with reward: -1086.51
# Moving average (last 50 episodes): -398.40 ± 303.09
# Outside PB!
# Episode 190 finished with reward: -191.18
# Moving average (last 50 episodes): -397.62 ± 303.58
# Outside PB!
# Episode 191 finished with reward: -196.00
# Moving average (last 50 episodes): -381.34 ± 291.90
# Outside PB!
# Episode 192 finished with reward: -199.58
# Moving average (last 50 episodes): -379.84 ± 292.63
# Episode 193 finished with reward: -1128.71
# Moving average (last 50 episodes): -398.21 ± 309.74
# Outside PB!
# Episode 194 finished with reward: -242.66
# Moving average (last 50 episodes): -399.88 ± 308.67
# Outside PB!
# Episode 195 finished with reward: -160.25
# Moving average (last 50 episodes): -399.17 ± 309.18
# Episode 196 finished with reward: -997.79
# Moving average (last 50 episodes): -414.75 ± 319.16
# Outside PB!
# Episode 197 finished with reward: -270.06
# Moving average (last 50 episodes): -400.08 ± 308.42
# Outside PB!
# Episode 198 finished with reward: -259.45
# Moving average (last 50 episodes): -397.54 ± 309.04
# Episode 199 finished with reward: -1001.85
# Moving average (last 50 episodes): -403.02 ± 317.18
# Episode 200 finished with reward: -1052.98
# Moving average (last 50 episodes): -404.28 ± 319.62
# Outside PB!
# Episode 201 finished with reward: -207.13
# Moving average (last 50 episodes): -402.16 ± 320.57
# Outside PB!
# Episode 202 finished with reward: -231.34
# Moving average (last 50 episodes): -402.06 ± 320.62
# Outside PB!
# Episode 203 finished with reward: -189.12
# Moving average (last 50 episodes): -400.01 ± 321.65
# Outside PB!
# Episode 204 finished with reward: -245.11
# Moving average (last 50 episodes): -398.49 ± 322.20
# Outside PB!
# Episode 205 finished with reward: -188.83
# Moving average (last 50 episodes): -396.69 ± 323.11
# Outside PB!
# Episode 206 finished with reward: -202.83
# Moving average (last 50 episodes): -394.25 ± 324.10
# Outside PB!
# Episode 207 finished with reward: -323.82
# Moving average (last 50 episodes): -396.63 ± 323.14
# Episode 208 finished with reward: -749.86
# Moving average (last 50 episodes): -406.84 ± 326.06
# Outside PB!
# Episode 209 finished with reward: -260.62
# Moving average (last 50 episodes): -394.97 ± 320.31
# Episode 210 finished with reward: -745.58
# Moving average (last 50 episodes): -388.61 ± 309.95
# Outside PB!
# Episode 211 finished with reward: -206.23
# Moving average (last 50 episodes): -388.07 ± 310.25
# Outside PB!
# Episode 212 finished with reward: -212.53
# Moving average (last 50 episodes): -388.48 ± 310.00
# Outside PB!
# Episode 213 finished with reward: -197.02
# Moving average (last 50 episodes): -385.53 ± 311.10
# Outside PB!
# Episode 214 finished with reward: -289.74
# Moving average (last 50 episodes): -386.50 ± 310.72
# Outside PB!
# Episode 215 finished with reward: -229.34
# Moving average (last 50 episodes): -375.06 ± 305.73
# Outside PB!
# Episode 216 finished with reward: -286.52
# Moving average (last 50 episodes): -376.02 ± 305.38
# Outside PB!
# Episode 217 finished with reward: -204.95
# Moving average (last 50 episodes): -356.73 ± 284.39
# Outside PB!
# Episode 218 finished with reward: -289.22
# Moving average (last 50 episodes): -345.48 ± 275.57
# Episode 219 finished with reward: -753.18
# Moving average (last 50 episodes): -347.81 ± 278.50
# Outside PB!
# Episode 220 finished with reward: -160.10
# Moving average (last 50 episodes): -346.60 ± 279.18
# Episode 221 finished with reward: -1034.73
# Moving average (last 50 episodes): -362.85 ± 294.68
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.2        |
# |    ep_rew_mean          | -407        |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 6           |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011770939 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.00246     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24e+04    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00746    |
# |    value_loss           | 2.27e+04    |
# -----------------------------------------
# Outside PB!
# Episode 222 finished with reward: -222.62
# Moving average (last 50 episodes): -363.52 ± 294.32
# Outside PB!
# Episode 223 finished with reward: -160.31
# Moving average (last 50 episodes): -363.21 ± 294.53
# Outside PB!
# Episode 224 finished with reward: -155.92
# Moving average (last 50 episodes): -361.05 ± 295.65
# Outside PB!
# Episode 225 finished with reward: -282.22
# Moving average (last 50 episodes): -363.04 ± 294.77
# Outside PB!
# Episode 226 finished with reward: -214.21
# Moving average (last 50 episodes): -363.57 ± 294.48
# Outside PB!
# Episode 227 finished with reward: -202.01
# Moving average (last 50 episodes): -363.05 ± 294.74
# Outside PB!
# Episode 228 finished with reward: -159.39
# Moving average (last 50 episodes): -350.75 ± 290.12
# Outside PB!
# Episode 229 finished with reward: -188.02
# Moving average (last 50 episodes): -350.45 ± 290.28
# Outside PB!
# Episode 230 finished with reward: -197.95
# Moving average (last 50 episodes): -350.28 ± 290.37
# Outside PB!
# Episode 231 finished with reward: -253.31
# Moving average (last 50 episodes): -351.65 ± 289.74
# Outside PB!
# Episode 232 finished with reward: -200.69
# Moving average (last 50 episodes): -349.50 ± 290.46
# Outside PB!
# Episode 233 finished with reward: -188.75
# Moving average (last 50 episodes): -349.22 ± 290.60
# Outside PB!
# Episode 234 finished with reward: -189.31
# Moving average (last 50 episodes): -349.13 ± 290.65
# Outside PB!
# Episode 235 finished with reward: -214.46
# Moving average (last 50 episodes): -349.25 ± 290.60
# Outside PB!
# Episode 236 finished with reward: -206.22
# Moving average (last 50 episodes): -349.04 ± 290.69
# Outside PB!
# Episode 237 finished with reward: -190.82
# Moving average (last 50 episodes): -349.05 ± 290.69
# Outside PB!
# Episode 238 finished with reward: -176.32
# Moving average (last 50 episodes): -347.95 ± 291.24
# Outside PB!
# Episode 239 finished with reward: -224.79
# Moving average (last 50 episodes): -330.71 ± 271.88
# Outside PB!
# Episode 240 finished with reward: -171.50
# Moving average (last 50 episodes): -330.32 ± 272.09
# Outside PB!
# Episode 241 finished with reward: -189.97
# Moving average (last 50 episodes): -330.20 ± 272.15
# Outside PB!
# Episode 242 finished with reward: -165.22
# Moving average (last 50 episodes): -329.51 ± 272.53
# Outside PB!
# Episode 243 finished with reward: -197.23
# Moving average (last 50 episodes): -310.88 ± 247.99
# Outside PB!
# Episode 244 finished with reward: -223.08
# Moving average (last 50 episodes): -310.49 ± 248.11
# Outside PB!
# Episode 245 finished with reward: -201.68
# Moving average (last 50 episodes): -311.32 ± 247.68
# Outside PB!
# Episode 246 finished with reward: -191.99
# Moving average (last 50 episodes): -295.20 ± 227.91
# Outside PB!
# Episode 247 finished with reward: -242.27
# Moving average (last 50 episodes): -294.65 ± 228.01
# Outside PB!
# Episode 248 finished with reward: -221.35
# Moving average (last 50 episodes): -293.88 ± 228.19
# Outside PB!
# Episode 249 finished with reward: -258.50
# Moving average (last 50 episodes): -279.02 ± 204.57
# Outside PB!
# Episode 250 finished with reward: -222.12
# Moving average (last 50 episodes): -262.40 ± 172.21
# Outside PB!
# Episode 251 finished with reward: -174.91
# Moving average (last 50 episodes): -261.76 ± 172.48
# Outside PB!
# Episode 252 finished with reward: -170.55
# Moving average (last 50 episodes): -260.54 ± 172.90
# Outside PB!
# Episode 253 finished with reward: -192.37
# Moving average (last 50 episodes): -260.61 ± 172.88
# Outside PB!
# Episode 254 finished with reward: -179.72
# Moving average (last 50 episodes): -259.30 ± 173.24
# Outside PB!
# Episode 255 finished with reward: -165.53
# Moving average (last 50 episodes): -258.83 ± 173.46
# Outside PB!
# Episode 256 finished with reward: -265.46
# Moving average (last 50 episodes): -260.08 ± 173.27
# Episode 257 finished with reward: -1059.74
# Moving average (last 50 episodes): -274.80 ± 206.19
# Outside PB!
# Episode 258 finished with reward: -164.58
# Moving average (last 50 episodes): -263.10 ± 195.21
# Outside PB!
# Episode 259 finished with reward: -169.29
# Moving average (last 50 episodes): -261.27 ± 195.65
# Outside PB!
# Episode 260 finished with reward: -193.69
# Moving average (last 50 episodes): -250.23 ± 183.19
# Outside PB!
# Episode 261 finished with reward: -161.31
# Moving average (last 50 episodes): -249.33 ± 183.51
# Outside PB!
# Episode 262 finished with reward: -200.66
# Moving average (last 50 episodes): -249.10 ± 183.57
# Outside PB!
# Episode 263 finished with reward: -201.25
# Moving average (last 50 episodes): -249.18 ± 183.54
# Outside PB!
# Episode 264 finished with reward: -219.31
# Moving average (last 50 episodes): -247.77 ± 183.50
# Outside PB!
# Episode 265 finished with reward: -183.84
# Moving average (last 50 episodes): -246.86 ± 183.70
# Outside PB!
# Episode 266 finished with reward: -265.74
# Moving average (last 50 episodes): -246.45 ± 183.63
# Outside PB!
# Episode 267 finished with reward: -196.78
# Moving average (last 50 episodes): -246.28 ± 183.67
# Outside PB!
# Episode 268 finished with reward: -168.12
# Moving average (last 50 episodes): -243.86 ± 183.89
# Outside PB!
# Episode 269 finished with reward: -190.88
# Moving average (last 50 episodes): -232.62 ± 168.99
# Outside PB!
# Episode 270 finished with reward: -193.84
# Moving average (last 50 episodes): -233.29 ± 168.76
# Outside PB!
# Episode 271 finished with reward: -166.40
# Moving average (last 50 episodes): -215.92 ± 124.19
# Outside PB!
# Episode 272 finished with reward: -205.04
# Moving average (last 50 episodes): -215.57 ± 124.19
# Outside PB!
# Episode 273 finished with reward: -170.32
# Moving average (last 50 episodes): -215.77 ± 124.11
# Episode 274 finished with reward: -1275.88
# Moving average (last 50 episodes): -238.17 ± 193.15
# Outside PB!
# Episode 275 finished with reward: -185.27
# Moving average (last 50 episodes): -236.23 ± 193.19
# Outside PB!
# Episode 276 finished with reward: -201.91
# Moving average (last 50 episodes): -235.99 ± 193.22
# Outside PB!
# Episode 277 finished with reward: -229.14
# Moving average (last 50 episodes): -236.53 ± 193.16
# Outside PB!
# Episode 278 finished with reward: -195.37
# Moving average (last 50 episodes): -237.25 ± 192.94
# Outside PB!
# Episode 279 finished with reward: -169.86
# Moving average (last 50 episodes): -236.89 ± 193.05
# Outside PB!
# Episode 280 finished with reward: -200.76
# Moving average (last 50 episodes): -236.94 ± 193.04
# Outside PB!
# Episode 281 finished with reward: -256.09
# Moving average (last 50 episodes): -237.00 ± 193.04
# Outside PB!
# Episode 282 finished with reward: -209.51
# Moving average (last 50 episodes): -237.17 ± 193.02
# Outside PB!
# Episode 283 finished with reward: -299.88
# Moving average (last 50 episodes): -239.40 ± 193.08
# Outside PB!
# Episode 284 finished with reward: -183.71
# Moving average (last 50 episodes): -239.28 ± 193.12
# Outside PB!
# Episode 285 finished with reward: -247.70
# Moving average (last 50 episodes): -239.95 ± 193.09
# Outside PB!
# Episode 286 finished with reward: -268.03
# Moving average (last 50 episodes): -241.19 ± 193.06
# Outside PB!
# Episode 287 finished with reward: -197.02
# Moving average (last 50 episodes): -241.31 ± 193.03
# Outside PB!
# Episode 288 finished with reward: -239.48
# Moving average (last 50 episodes): -242.57 ± 192.81
# Outside PB!
# Episode 289 finished with reward: -153.73
# Moving average (last 50 episodes): -241.15 ± 193.20
# Outside PB!
# Episode 290 finished with reward: -205.23
# Moving average (last 50 episodes): -241.83 ± 193.01
# Outside PB!
# Episode 291 finished with reward: -178.29
# Moving average (last 50 episodes): -241.59 ± 193.08
# Outside PB!
# Episode 292 finished with reward: -196.06
# Moving average (last 50 episodes): -242.21 ± 192.89
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.4        |
# |    ep_rew_mean          | -286        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 7           |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012690203 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.00222     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 1.95e+04    |
# -----------------------------------------
# Outside PB!
# Episode 293 finished with reward: -162.33
# Moving average (last 50 episodes): -241.51 ± 193.11
# Outside PB!
# Episode 294 finished with reward: -165.68
# Moving average (last 50 episodes): -240.36 ± 193.39
# Outside PB!
# Episode 295 finished with reward: -162.82
# Moving average (last 50 episodes): -239.59 ± 193.62
# Outside PB!
# Episode 296 finished with reward: -178.89
# Moving average (last 50 episodes): -239.32 ± 193.69
# Outside PB!
# Episode 297 finished with reward: -189.15
# Moving average (last 50 episodes): -238.26 ± 193.82
# Outside PB!
# Episode 298 finished with reward: -192.90
# Moving average (last 50 episodes): -237.69 ± 193.91
# Outside PB!
# Episode 299 finished with reward: -190.28
# Moving average (last 50 episodes): -236.33 ± 194.00
# Outside PB!
# Episode 300 finished with reward: -148.57
# Moving average (last 50 episodes): -234.86 ± 194.38
# Outside PB!
# Episode 301 finished with reward: -202.32
# Moving average (last 50 episodes): -235.41 ± 194.25
# Outside PB!
# Episode 302 finished with reward: -218.81
# Moving average (last 50 episodes): -236.37 ± 194.04
# Outside PB!
# Episode 303 finished with reward: -219.95
# Moving average (last 50 episodes): -236.92 ± 193.96
# Outside PB!
# Episode 304 finished with reward: -148.39
# Moving average (last 50 episodes): -236.30 ± 194.19
# Outside PB!
# Episode 305 finished with reward: -231.60
# Moving average (last 50 episodes): -237.62 ± 193.93
# Outside PB!
# Episode 306 finished with reward: -156.84
# Moving average (last 50 episodes): -235.44 ± 194.21
# Outside PB!
# Episode 307 finished with reward: -173.31
# Moving average (last 50 episodes): -217.72 ± 154.57
# Outside PB!
# Episode 308 finished with reward: -162.57
# Moving average (last 50 episodes): -217.68 ± 154.59
# Outside PB!
# Episode 309 finished with reward: -180.50
# Moving average (last 50 episodes): -217.90 ± 154.52
# Outside PB!
# Episode 310 finished with reward: -170.20
# Moving average (last 50 episodes): -217.43 ± 154.63
# Outside PB!
# Episode 311 finished with reward: -320.06
# Moving average (last 50 episodes): -220.61 ± 155.08
# Outside PB!
# Episode 312 finished with reward: -164.56
# Moving average (last 50 episodes): -219.88 ± 155.25
# Outside PB!
# Episode 313 finished with reward: -274.30
# Moving average (last 50 episodes): -221.34 ± 155.41
# Outside PB!
# Episode 314 finished with reward: -221.57
# Moving average (last 50 episodes): -221.39 ± 155.41
# Outside PB!
# Episode 315 finished with reward: -212.89
# Moving average (last 50 episodes): -221.97 ± 155.33
# Outside PB!
# Episode 316 finished with reward: -203.24
# Moving average (last 50 episodes): -220.72 ± 155.22
# Outside PB!
# Episode 317 finished with reward: -229.68
# Moving average (last 50 episodes): -221.38 ± 155.19
# Outside PB!
# Episode 318 finished with reward: -184.74
# Moving average (last 50 episodes): -221.71 ± 155.09
# Outside PB!
# Episode 319 finished with reward: -162.04
# Moving average (last 50 episodes): -221.13 ± 155.26
# Outside PB!
# Episode 320 finished with reward: -166.28
# Moving average (last 50 episodes): -220.58 ± 155.40
# Outside PB!
# Episode 321 finished with reward: -192.98
# Moving average (last 50 episodes): -221.11 ± 155.26
# Outside PB!
# Episode 322 finished with reward: -175.83
# Moving average (last 50 episodes): -220.53 ± 155.38
# Outside PB!
# Episode 323 finished with reward: -156.27
# Moving average (last 50 episodes): -220.25 ± 155.48
# Outside PB!
# Episode 324 finished with reward: -203.11
# Moving average (last 50 episodes): -198.79 ± 37.84
# Outside PB!
# Episode 325 finished with reward: -188.60
# Moving average (last 50 episodes): -198.86 ± 37.82
# Outside PB!
# Episode 326 finished with reward: -210.26
# Moving average (last 50 episodes): -199.03 ± 37.85
# Outside PB!
# Episode 327 finished with reward: -210.81
# Moving average (last 50 episodes): -198.66 ± 37.65
# Outside PB!
# Episode 328 finished with reward: -189.32
# Moving average (last 50 episodes): -198.54 ± 37.67
# Outside PB!
# Episode 329 finished with reward: -188.49
# Moving average (last 50 episodes): -198.91 ± 37.47
# Outside PB!
# Episode 330 finished with reward: -165.54
# Moving average (last 50 episodes): -198.21 ± 37.76
# Outside PB!
# Episode 331 finished with reward: -174.62
# Moving average (last 50 episodes): -196.58 ± 36.98
# Outside PB!
# Episode 332 finished with reward: -221.56
# Moving average (last 50 episodes): -196.82 ± 37.10
# Outside PB!
# Episode 333 finished with reward: -195.25
# Moving average (last 50 episodes): -194.73 ± 34.06
# Outside PB!
# Episode 334 finished with reward: -234.73
# Moving average (last 50 episodes): -195.75 ± 34.47
# Outside PB!
# Episode 335 finished with reward: -176.38
# Moving average (last 50 episodes): -194.32 ± 33.76
# Outside PB!
# Episode 336 finished with reward: -255.96
# Moving average (last 50 episodes): -194.08 ± 33.27
# Outside PB!
# Episode 337 finished with reward: -199.94
# Moving average (last 50 episodes): -194.14 ± 33.28
# Outside PB!
# Episode 338 finished with reward: -208.10
# Moving average (last 50 episodes): -193.51 ± 32.71
# Outside PB!
# Episode 339 finished with reward: -155.34
# Moving average (last 50 episodes): -193.54 ± 32.67
# Outside PB!
# Episode 340 finished with reward: -243.38
# Moving average (last 50 episodes): -194.31 ± 33.38
# Outside PB!
# Episode 341 finished with reward: -211.59
# Moving average (last 50 episodes): -194.97 ± 33.38
# Outside PB!
# Episode 342 finished with reward: -178.17
# Moving average (last 50 episodes): -194.61 ± 33.46
# Outside PB!
# Episode 343 finished with reward: -182.94
# Moving average (last 50 episodes): -195.03 ± 33.19
# Outside PB!
# Episode 344 finished with reward: -189.11
# Moving average (last 50 episodes): -195.49 ± 32.94
# Outside PB!
# Episode 345 finished with reward: -180.90
# Moving average (last 50 episodes): -195.86 ± 32.67
# Outside PB!
# Episode 346 finished with reward: -166.78
# Moving average (last 50 episodes): -195.61 ± 32.84
# Outside PB!
# Episode 347 finished with reward: -245.05
# Moving average (last 50 episodes): -196.73 ± 33.55
# Outside PB!
# Episode 348 finished with reward: -208.14
# Moving average (last 50 episodes): -197.04 ± 33.58
# Outside PB!
# Episode 349 finished with reward: -204.48
# Moving average (last 50 episodes): -197.32 ± 33.58
# Outside PB!
# Episode 350 finished with reward: -243.12
# Moving average (last 50 episodes): -199.21 ± 33.45
# Outside PB!
# Episode 351 finished with reward: -199.50
# Moving average (last 50 episodes): -199.16 ± 33.44
# Outside PB!
# Episode 352 finished with reward: -192.37
# Moving average (last 50 episodes): -198.63 ± 33.34
# Outside PB!
# Episode 353 finished with reward: -186.44
# Moving average (last 50 episodes): -197.96 ± 33.24
# Outside PB!
# Episode 354 finished with reward: -216.11
# Moving average (last 50 episodes): -199.31 ± 32.56
# Outside PB!
# Episode 355 finished with reward: -220.70
# Moving average (last 50 episodes): -199.09 ± 32.38
# Outside PB!
# Episode 356 finished with reward: -195.90
# Moving average (last 50 episodes): -199.87 ± 31.82
# Outside PB!
# Episode 357 finished with reward: -227.43
# Moving average (last 50 episodes): -200.96 ± 31.82
# Outside PB!
# Episode 358 finished with reward: -176.33
# Moving average (last 50 episodes): -201.23 ± 31.54
# Outside PB!
# Episode 359 finished with reward: -170.91
# Moving average (last 50 episodes): -201.04 ± 31.70
# Outside PB!
# Episode 360 finished with reward: -190.25
# Moving average (last 50 episodes): -201.44 ± 31.43
# Outside PB!
# Episode 361 finished with reward: -234.83
# Moving average (last 50 episodes): -199.74 ± 26.94
# Outside PB!
# Episode 362 finished with reward: -276.44
# Moving average (last 50 episodes): -201.97 ± 28.53
# Outside PB!
# Episode 363 finished with reward: -200.12
# Moving average (last 50 episodes): -200.49 ± 26.59
# Outside PB!
# Episode 364 finished with reward: -179.70
# Moving average (last 50 episodes): -199.65 ± 26.57
# Outside PB!
# Episode 365 finished with reward: -188.85
# Moving average (last 50 episodes): -199.17 ± 26.55
# Outside PB!
# Episode 366 finished with reward: -209.42
# Moving average (last 50 episodes): -199.30 ± 26.58
# Outside PB!
# Episode 367 finished with reward: -182.28
# Moving average (last 50 episodes): -198.35 ± 26.32
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.8        |
# |    ep_rew_mean          | -210        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 8           |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008850891 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.63       |
# |    explained_variance   | 0.00152     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.69e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00739    |
# |    value_loss           | 1.03e+04    |
# -----------------------------------------
# Outside PB!
# Episode 368 finished with reward: -185.49
# Moving average (last 50 episodes): -198.36 ± 26.32
# Outside PB!
# Episode 369 finished with reward: -163.16
# Moving average (last 50 episodes): -198.39 ± 26.28
# Outside PB!
# Episode 370 finished with reward: -192.30
# Moving average (last 50 episodes): -198.91 ± 25.90
# Outside PB!
# Episode 371 finished with reward: -183.39
# Moving average (last 50 episodes): -198.71 ± 25.98
# Outside PB!
# Episode 372 finished with reward: -168.97
# Moving average (last 50 episodes): -198.58 ± 26.12
# Outside PB!
# Episode 373 finished with reward: -172.91
# Moving average (last 50 episodes): -198.91 ± 25.68
# Outside PB!
# Episode 374 finished with reward: -232.50
# Moving average (last 50 episodes): -199.50 ± 26.10
# Outside PB!
# Episode 375 finished with reward: -233.34
# Moving average (last 50 episodes): -200.39 ± 26.47
# Outside PB!
# Episode 376 finished with reward: -238.25
# Moving average (last 50 episodes): -200.95 ± 26.97
# Outside PB!
# Episode 377 finished with reward: -192.36
# Moving average (last 50 episodes): -200.58 ± 26.96
# Outside PB!
# Episode 378 finished with reward: -185.58
# Moving average (last 50 episodes): -200.51 ± 26.99
# Outside PB!
# Episode 379 finished with reward: -173.96
# Moving average (last 50 episodes): -200.22 ± 27.20
# Outside PB!
# Episode 380 finished with reward: -181.27
# Moving average (last 50 episodes): -200.53 ± 26.89
# Outside PB!
# Episode 381 finished with reward: -336.36
# Moving average (last 50 episodes): -203.77 ± 32.68
# Outside PB!
# Episode 382 finished with reward: -157.66
# Moving average (last 50 episodes): -202.49 ± 33.20
# Outside PB!
# Episode 383 finished with reward: -287.58
# Moving average (last 50 episodes): -204.34 ± 35.25
# Outside PB!
# Episode 384 finished with reward: -160.91
# Moving average (last 50 episodes): -202.86 ± 35.49
# Outside PB!
# Episode 385 finished with reward: -184.88
# Moving average (last 50 episodes): -203.03 ± 35.39
# Outside PB!
# Episode 386 finished with reward: -188.71
# Moving average (last 50 episodes): -201.68 ± 34.62
# Outside PB!
# Episode 387 finished with reward: -218.16
# Moving average (last 50 episodes): -202.05 ± 34.70
# Outside PB!
# Episode 388 finished with reward: -188.23
# Moving average (last 50 episodes): -201.65 ± 34.74
# Outside PB!
# Episode 389 finished with reward: -174.01
# Moving average (last 50 episodes): -202.02 ± 34.34
# Outside PB!
# Episode 390 finished with reward: -192.51
# Moving average (last 50 episodes): -201.01 ± 33.85
# Outside PB!
# Episode 391 finished with reward: -179.30
# Moving average (last 50 episodes): -200.36 ± 33.95
# Outside PB!
# Episode 392 finished with reward: -196.71
# Moving average (last 50 episodes): -200.73 ± 33.80
# Outside PB!
# Episode 393 finished with reward: -157.97
# Moving average (last 50 episodes): -200.23 ± 34.24
# Outside PB!
# Episode 394 finished with reward: -177.75
# Moving average (last 50 episodes): -200.01 ± 34.35
# Outside PB!
# Episode 395 finished with reward: -171.99
# Moving average (last 50 episodes): -199.83 ± 34.47
# Outside PB!
# Episode 396 finished with reward: -190.57
# Moving average (last 50 episodes): -200.30 ± 34.18
# Outside PB!
# Episode 397 finished with reward: -181.21
# Moving average (last 50 episodes): -199.03 ± 33.67
# Outside PB!
# Episode 398 finished with reward: -170.20
# Moving average (last 50 episodes): -198.27 ± 33.88
# Outside PB!
# Episode 399 finished with reward: -189.26
# Moving average (last 50 episodes): -197.96 ± 33.90
# Outside PB!
# Episode 400 finished with reward: -176.52
# Moving average (last 50 episodes): -196.63 ± 33.40
# Outside PB!
# Episode 401 finished with reward: -147.83
# Moving average (last 50 episodes): -195.60 ± 34.09
# Outside PB!
# Episode 402 finished with reward: -184.70
# Moving average (last 50 episodes): -195.44 ± 34.12
# Outside PB!
# Episode 403 finished with reward: -164.40
# Moving average (last 50 episodes): -195.00 ± 34.37
# Outside PB!
# Episode 404 finished with reward: -160.55
# Moving average (last 50 episodes): -193.89 ± 34.57
# Outside PB!
# Episode 405 finished with reward: -207.36
# ...
# Outside PB!
# Episode 29022 finished with reward: -157.69
# Moving average (last 50 episodes): -155.42 ± 11.63
# Outside PB!
# Episode 29023 finished with reward: -128.01
# Moving average (last 50 episodes): -154.89 ± 12.25
# Outside PB!
# Episode 29024 finished with reward: -171.77
# Moving average (last 50 episodes): -155.66 ± 12.09
# Outside PB!
# Episode 29025 finished with reward: -143.87
# Moving average (last 50 episodes): -155.35 ± 12.19
# Outside PB!
# Episode 29026 finished with reward: -166.63
# Moving average (last 50 episodes): -155.66 ± 12.28
# Outside PB!
# Episode 29027 finished with reward: -154.35
# Moving average (last 50 episodes): -155.48 ± 12.23
# Outside PB!
# Episode 29028 finished with reward: -141.30
# Moving average (last 50 episodes): -155.30 ± 12.38
# Outside PB!
# Episode 29029 finished with reward: -156.41
# Moving average (last 50 episodes): -154.98 ± 12.14
# Outside PB!
# Episode 29030 finished with reward: -161.57
# Moving average (last 50 episodes): -155.18 ± 12.16
# Outside PB!
# Episode 29031 finished with reward: -149.91
# Moving average (last 50 episodes): -155.12 ± 12.18
# Outside PB!
# Episode 29032 finished with reward: -141.19
# Moving average (last 50 episodes): -154.75 ± 12.32
# Outside PB!
# Episode 29033 finished with reward: -136.15
# Moving average (last 50 episodes): -154.08 ± 12.40
# Outside PB!
# Episode 29034 finished with reward: -157.18
# Moving average (last 50 episodes): -154.22 ± 12.39
# Outside PB!
# Episode 29035 finished with reward: -148.72
# Moving average (last 50 episodes): -154.04 ± 12.40
# Outside PB!
# Episode 29036 finished with reward: -122.27
# Moving average (last 50 episodes): -153.53 ± 13.15
# Outside PB!
# Episode 29037 finished with reward: -163.36
# Moving average (last 50 episodes): -153.58 ± 13.18
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24.5      |
# |    ep_rew_mean          | -155      |
# | time/                   |           |
# |    fps                  | 14        |
# |    iterations           | 351       |
# |    time_elapsed         | 51034     |
# |    total_timesteps      | 718848    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000447 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 933       |
# |    n_updates            | 3500      |
# |    policy_gradient_loss | -5.24e-10 |
# |    value_loss           | 2e+03     |
# ---------------------------------------
# Outside PB!
# Episode 29038 finished with reward: -136.02
# Moving average (last 50 episodes): -153.17 ± 13.40
# Outside PB!
# Episode 29039 finished with reward: -131.63
# Moving average (last 50 episodes): -152.20 ± 13.17
# Outside PB!
# Episode 29040 finished with reward: -138.72
# Moving average (last 50 episodes): -152.19 ± 13.18
# Outside PB!
# Episode 29041 finished with reward: -160.12
# Moving average (last 50 episodes): -152.56 ± 13.14
# Outside PB!
# Episode 29042 finished with reward: -165.64
# Moving average (last 50 episodes): -152.65 ± 13.21
# Outside PB!
# Episode 29043 finished with reward: -157.18
# Moving average (last 50 episodes): -152.80 ± 13.21
# Outside PB!
# Episode 29044 finished with reward: -138.23
# Moving average (last 50 episodes): -152.60 ± 13.36
# Outside PB!
# Episode 29045 finished with reward: -147.65
# Moving average (last 50 episodes): -152.40 ± 13.36
# Outside PB!
# Episode 29046 finished with reward: -160.71
# Moving average (last 50 episodes): -152.75 ± 13.34
# Outside PB!
# Episode 29047 finished with reward: -171.84
# Moving average (last 50 episodes): -153.15 ± 13.61
# Outside PB!
# Episode 29048 finished with reward: -152.49
# Moving average (last 50 episodes): -152.91 ± 13.51
# Outside PB!
# Episode 29049 finished with reward: -154.15
# Moving average (last 50 episodes): -152.91 ± 13.51
# Outside PB!
# Episode 29050 finished with reward: -146.28
# Moving average (last 50 episodes): -152.77 ± 13.55
# Outside PB!
# Episode 29051 finished with reward: -150.84
# Moving average (last 50 episodes): -152.40 ± 13.33
# Outside PB!
# Episode 29052 finished with reward: -168.64
# Moving average (last 50 episodes): -153.17 ± 13.14
# Outside PB!
# Episode 29053 finished with reward: -154.20
# Moving average (last 50 episodes): -153.53 ± 12.91
# Outside PB!
# Episode 29054 finished with reward: -173.23
# Moving average (last 50 episodes): -153.95 ± 13.20
# Outside PB!
# Episode 29055 finished with reward: -151.51
# Moving average (last 50 episodes): -154.23 ± 13.00
# Outside PB!
# Episode 29056 finished with reward: -166.94
# Moving average (last 50 episodes): -154.46 ± 13.12
# Outside PB!
# Episode 29057 finished with reward: -158.62
# Moving average (last 50 episodes): -154.33 ± 13.05
# Outside PB!
# Episode 29058 finished with reward: -142.27
# Moving average (last 50 episodes): -154.08 ± 13.16
# Outside PB!
# Episode 29059 finished with reward: -169.95
# Moving average (last 50 episodes): -154.03 ± 13.09
# Outside PB!
# Episode 29060 finished with reward: -151.96
# Moving average (last 50 episodes): -153.97 ± 13.09
# Outside PB!
# Episode 29061 finished with reward: -130.69
# Moving average (last 50 episodes): -153.31 ± 13.41
# Outside PB!
# Episode 29062 finished with reward: -132.40
# Moving average (last 50 episodes): -152.91 ± 13.73
# Outside PB!
# Episode 29063 finished with reward: -128.66
# Moving average (last 50 episodes): -152.29 ± 14.10
# Outside PB!
# Episode 29064 finished with reward: -157.39
# Moving average (last 50 episodes): -152.57 ± 14.06
# Outside PB!
# Episode 29065 finished with reward: -141.04
# Moving average (last 50 episodes): -152.38 ± 14.15
# Outside PB!
# Episode 29066 finished with reward: -171.79
# Moving average (last 50 episodes): -152.18 ± 13.81
# Outside PB!
# Episode 29067 finished with reward: -147.86
# Moving average (last 50 episodes): -151.45 ± 13.03
# Outside PB!
# Episode 29068 finished with reward: -161.22
# Moving average (last 50 episodes): -151.32 ± 12.91
# Outside PB!
# Episode 29069 finished with reward: -154.27
# Moving average (last 50 episodes): -151.40 ± 12.91
# Outside PB!
# Episode 29070 finished with reward: -159.97
# Moving average (last 50 episodes): -151.51 ± 12.96
# Outside PB!
# Episode 29071 finished with reward: -161.77
# Moving average (last 50 episodes): -151.93 ± 12.95
# Outside PB!
# Episode 29072 finished with reward: -147.45
# Moving average (last 50 episodes): -151.72 ± 12.94
# Outside PB!
# Episode 29073 finished with reward: -147.48
# Moving average (last 50 episodes): -152.11 ± 12.50
# Outside PB!
# Episode 29074 finished with reward: -170.44
# Moving average (last 50 episodes): -152.08 ± 12.46
# Outside PB!
# Episode 29075 finished with reward: -153.69
# Moving average (last 50 episodes): -152.28 ± 12.41
# Outside PB!
# Episode 29076 finished with reward: -157.05
# Moving average (last 50 episodes): -152.09 ± 12.26
# Outside PB!
# Episode 29077 finished with reward: -165.90
# Moving average (last 50 episodes): -152.32 ± 12.41
# Outside PB!
# Episode 29078 finished with reward: -156.05
# Moving average (last 50 episodes): -152.61 ± 12.32
# Outside PB!
# Episode 29079 finished with reward: -141.38
# Moving average (last 50 episodes): -152.31 ± 12.40
# Outside PB!
# Episode 29080 finished with reward: -127.53
# Moving average (last 50 episodes): -151.63 ± 12.80
# Outside PB!
# Episode 29081 finished with reward: -175.75
# Moving average (last 50 episodes): -152.15 ± 13.24
# Outside PB!
# Episode 29082 finished with reward: -143.00
# Moving average (last 50 episodes): -152.19 ± 13.21
# Outside PB!
# Episode 29083 finished with reward: -154.69
# Moving average (last 50 episodes): -152.56 ± 13.01
# Outside PB!
# Episode 29084 finished with reward: -142.87
# Moving average (last 50 episodes): -152.27 ± 13.07
# Outside PB!
# Episode 29085 finished with reward: -160.66
# Moving average (last 50 episodes): -152.51 ± 13.11
# Outside PB!
# Episode 29086 finished with reward: -156.41
# Moving average (last 50 episodes): -153.19 ± 12.38
# Outside PB!
# Episode 29087 finished with reward: -154.68
# Moving average (last 50 episodes): -153.02 ± 12.30
# Outside PB!
# Episode 29088 finished with reward: -151.02
# Moving average (last 50 episodes): -153.32 ± 12.06
# Outside PB!
# Episode 29089 finished with reward: -159.20
# Moving average (last 50 episodes): -153.87 ± 11.68
# Outside PB!
# Episode 29090 finished with reward: -162.30
# Moving average (last 50 episodes): -154.34 ± 11.54
# Outside PB!
# Episode 29091 finished with reward: -133.23
# Moving average (last 50 episodes): -153.80 ± 11.88
# Outside PB!
# Episode 29092 finished with reward: -165.92
# Moving average (last 50 episodes): -153.81 ± 11.88
# Outside PB!
# Episode 29093 finished with reward: -155.77
# Moving average (last 50 episodes): -153.78 ± 11.88
# Outside PB!
# Episode 29094 finished with reward: -142.40
# Moving average (last 50 episodes): -153.86 ± 11.78
# Outside PB!
# Episode 29095 finished with reward: -124.89
# Moving average (last 50 episodes): -153.41 ± 12.43
# Outside PB!
# Episode 29096 finished with reward: -170.65
# Moving average (last 50 episodes): -153.61 ± 12.63
# Outside PB!
# Episode 29097 finished with reward: -137.04
# Moving average (last 50 episodes): -152.91 ± 12.56
# Outside PB!
# Episode 29098 finished with reward: -138.12
# Moving average (last 50 episodes): -152.62 ± 12.73
# Outside PB!
# Episode 29099 finished with reward: -159.28
# Moving average (last 50 episodes): -152.73 ± 12.76
# Outside PB!
# Episode 29100 finished with reward: -150.07
# Moving average (last 50 episodes): -152.80 ± 12.74
# Outside PB!
# Episode 29101 finished with reward: -168.75
# Moving average (last 50 episodes): -153.16 ± 12.93
# Outside PB!
# Episode 29102 finished with reward: -167.87
# Moving average (last 50 episodes): -153.15 ± 12.91
# Outside PB!
# Episode 29103 finished with reward: -128.94
# Moving average (last 50 episodes): -152.64 ± 13.35
# Outside PB!
# Episode 29104 finished with reward: -170.92
# Moving average (last 50 episodes): -152.59 ± 13.28
# Outside PB!
# Episode 29105 finished with reward: -148.06
# Moving average (last 50 episodes): -152.53 ± 13.29
# Outside PB!
# Episode 29106 finished with reward: -149.93
# Moving average (last 50 episodes): -152.18 ± 13.14
# Outside PB!
# Episode 29107 finished with reward: -166.17
# Moving average (last 50 episodes): -152.34 ± 13.25
# Outside PB!
# Episode 29108 finished with reward: -156.94
# Moving average (last 50 episodes): -152.63 ± 13.19
# Outside PB!
# Episode 29109 finished with reward: -142.30
# Moving average (last 50 episodes): -152.08 ± 13.03
# Outside PB!
# Episode 29110 finished with reward: -172.22
# Moving average (last 50 episodes): -152.48 ± 13.33
# Outside PB!
# Episode 29111 finished with reward: -158.62
# Moving average (last 50 episodes): -153.04 ± 12.99
# Outside PB!
# Episode 29112 finished with reward: -164.32
# Moving average (last 50 episodes): -153.68 ± 12.74
# Outside PB!
# Episode 29113 finished with reward: -140.38
# Moving average (last 50 episodes): -153.91 ± 12.38
# Outside PB!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 107
#     104 callback = TrainingMonitorCallback(window_size=50)
#     106 # Train the model
# --> 107 model.learn(
#     108     total_timesteps=int(total_timesteps_diy),
#     109     callback=callback,
#     110     log_interval=1
#     111 )
#     113 # After training, get metrics for plotting
#     114 metrics = callback.get_metrics()
#
# File c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\ppo\ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:300, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     297 assert self.env is not None
#     299 while self.num_timesteps < total_timesteps:
# --> 300     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     302     if not continue_training:
#     303         break
#
# File c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:195, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     190     else:
#     191         # Otherwise, clip the actions to avoid out of bound error
#     192         # as we are sampling from an unbounded Gaussian distribution
#     193         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 195 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     197 self.num_timesteps += env.num_envs
#     199 # Give access to local variables
#
# File c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:70, in DummyVecEnv.step_wait(self)
#      67     if self.buf_dones[env_idx]:
#      68         # save final observation where user can get it, then reset
#      69         self.buf_infos[env_idx]["terminal_observation"] = obs
# ---> 70         obs, self.reset_infos[env_idx] = self.envs[env_idx].reset()
#      71     self._save_obs(env_idx, obs)
#      72 return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# File c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\monitor.py:83, in Monitor.reset(self, **kwargs)
#      81         raise ValueError(f"Expected you to pass keyword argument {key} into reset")
#      82     self.current_reset_info[key] = value
# ---> 83 return self.env.reset(**kwargs)
#
# File f:\BaiduSyncdisk-mu\Projects CUG\2 Projects STE LX\climate-rl-optimizer\src\envs\iseec_lx_v4_mdp_plot.py:1596, in IEMEnv.reset(self, seed, options)
#    1591 ############ 预热的部分 #############
#    1592 SpingUp_time = np.arange(
#    1593     self.model_init_year, self.control_start_year + 1, self.dt
#    1594 )
# -> 1596 ode_solutions = odeint(
#    1597     func=self.iseec_dynamics_v1_ste,
#    1598     y0=self.state,
#    1599     t=SpingUp_time,
#    1600     mxstep=300,
#    1601 )
#    1602 #####################################
#    1604 self.state = np.array(ode_solutions[-1], dtype=np.float64)
#
# File c:\Users\peter\.conda\envs\torch_env\lib\site-packages\scipy\integrate\_odepack_py.py:242, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     240 t = copy(t)
#     241 y0 = copy(y0)
# --> 242 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     243                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     244                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     245                          int(bool(tfirst)))
#     246 if output[-1] < 0:
#     247     warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# File f:\BaiduSyncdisk-mu\Projects CUG\2 Projects STE LX\climate-rl-optimizer\src\envs\iseec_lx_v4_mdp_plot.py:908, in IEMEnv.iseec_dynamics_v1_ste(self, y, time)
#     904     if self.eta22[-1] < 0:
#     905         self.eta22[-1] = 0
#     907 E22_present = (
# --> 908     0.004 * energy_MYbaseline18502100_total[2016 - self.model_init_year]
#     909 )
#     911 if time < 2010:
#     912     dE22_dt = 0
#
# KeyboardInterrupt:

# %%
def plot_smooth_rewards(rewards, window_sizes=[5, 20, 100]):
    """
    绘制平滑的奖励曲线
    Args:
        rewards: 奖励列表
        window_sizes: 移动平均窗口大小列表
    """
    plt.figure(figsize=(12, 6))
    
    # 绘制原始奖励
    plt.plot(rewards, 'lightgray', alpha=0.3, label='Raw rewards')
    
    # 绘制不同窗口大小的移动平均
    colors = ['blue', 'green', 'red']
    for window, color in zip(window_sizes, colors):
        if len(rewards) >= window:
            # 计算移动平均
            smooth_rewards = np.convolve(rewards, 
                                      np.ones(window)/window, 
                                      mode='valid')
            plt.plot(range(window-1, len(rewards)), 
                    smooth_rewards, 
                    color=color, 
                    label=f'{window}-Episode Moving Average',
                    linewidth=2)
    
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.title('Training Rewards with Different Smoothing Windows')
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.show()


# 绘制平滑奖励曲线
plot_smooth_rewards(metrics["rewards"])

# %% [markdown]
# notes: 如果要训练过程中查看模型，通过 tensorboard 查看

# %%
# 模型保存
model.save(f"./model/{log_name}")

# %% [markdown]
# ### 评估模型训练结果

# %% [markdown]
# > 利用 evaulate policy 函数评估

# %% [markdown]
# # 加载训练好的 RL 模型

# %%
from stable_baselines3.common.evaluation import evaluate_policy
mean_reward, std_reward = evaluate_policy(
    model, 
    model.get_env(), 
    deterministic=True,
    render=True,
    n_eval_episodes=10)

# %%
print(mean_reward)
print(std_reward)

# %%
del model
model = PPO.load(f"./model/{log_name}", env=env_monitor)
# model = DQN.load(f"./model/{log_name}", env=env_monitor)

# %% [markdown]
# ### 结果展示

# %% [markdown]
# #### 纯净展示版本
#
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图

episodes = 2 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆



for ep in range(episodes):
    obs, _ = env_monitor.reset() # 必须的，每次重现一次
    episode_reward = 0
    done = False
     
     
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # 每10步更新一次图像
        if i % 10 == 0:
            env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")

# %% [markdown]
# ### 保存整体运行结果

# %%
env_test = IEMEnv(reward_type=custom_reward_type)

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 3 # 结果展示，只有一个 episode 部分
max_steps = 250

# all_episode_rewards = [] # 记录所有 episode 里面的

for ep in range(episodes):
    
    ##################################
    # 记录所需数组：每次 episode 重置
    total_action = []
    total_state = []
    total_reward = []
    total_done = []
    ##################################
    # 记录每个 episode 的 reward
    episode_reward = 0
    ##################################
    
    obs, _ = env_test.reset() # 必须的，每次重现一次 ，这里可能就需要固定随机种子了
    done = False
    
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        ##################################
        # 添加转换的部分
        action_number, action_name = IEMEnv.action2number_env(action)
        total_action.append(action_number)
        total_state.append(obs)
        total_reward.append(reward)
        total_done.append(done)
        ##################################
        # 记录每个 episode 的 reward
        episode_reward += reward # TODO：可以放在内容记录 step 部分
        ################################## 
        
        if done:
            print(f"Episode {ep} finished at step {i}")
            break
        
        # # 每10步更新一次图像
        # if ep % 10 == 0:
        #     env_monitor.render()
        #     # plt.pause(0.01)
    
    # all_episode_rewards.append(episode_reward)
    
    env_test.append_data_reward(episode_reward)
    
    save_future_data(env=env_test,custom_reward_type=custom_reward_type,rl_model_name=rl_model_name,network_name=policy_kwargs_diy,episode=ep,total_action=total_action,total_state=total_state,total_reward=total_reward,total_done=total_done,total_timesteps_name=total_timesteps_diy)

    save_plot_NSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    save_plot_SSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    # plot_3D_run(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state)
    
    
    print(f"Episode {ep} finished with reward{episode_reward}")
    
    
plot_data = env_test.get_variables()
plot_episode_reward(plot_data)

# %% [markdown]
# 主要针对可视化显示部分操作

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 绘制只展示一次 episode 结果

# env_test

for episode in range(1):
    obs, _ = env_test.reset() # 这里可能就需要固定随机种子了
    
    done = False
    
    for i in range(251):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        
        if done:
            print(f"Episode {episode} finished at step {i}")
            break

# %% [markdown]
# # 保存运行结果
