# %% [markdown]
# # RL 训练

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import scipy.io
from matplotlib.gridspec import GridSpec
import math
import random
import torch

from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.logger import configure
from stable_baselines3.common.monitor import Monitor
from stable_baselines3 import PPO 
from stable_baselines3 import DQN

# 导入 BaseCallback
from stable_baselines3.common.callbacks import BaseCallback

import sys
import os

# 将 src 目录添加到模块搜索路径
sys.path.append(os.path.abspath('src'))

# 导入 IEMEnv 类
from src.envs.iseec_lx_v4_mdp_plot import IEMEnv
from src.utils.run_debug_plot import save_data 
from src.utils.run_debug_plot import save_plot_NSM_data
from src.utils.run_debug_plot import save_plot_SSM_data

from src.utils.run_debug_plot import save_future_data
from src.utils.run_debug_plot import save_plot_NSM_future_data
from src.utils.run_debug_plot import save_plot_SSM_future_data

from src.utils.run_debug_plot import plot_episode_reward
from src.utils.run_debug_plot import plot_episode_reward_simple
from src.utils.run_debug_plot import plot_3D_run

# %% [markdown]
# 定义保存位置参数
#
# > 所有的关键参数都放在最前面

# %%
# 增加随机种子的定义
def set_global_seed(seed):
    """设置全局随机种子"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# 设置全局种子
# SEED = 42 # 非测试，不指定种子
# set_global_seed(SEED)

# custom_reward_type = "2_desirable_region_renewable"
network_name = "Netxxx_no_big_env"
rl_model_name = "PPO"
total_timesteps_diy = 250000

# gamma_diy = 0.99 # 但是是定义在 model 中，

policy_kwargs_diy = "dict_pi_vf_default" # for example: policy_kwargs = dict(activation_fn=th.nn.ReLU,net_arch=[256, 256, dict(pi=[128, 64], vf=[128, 64])])

# 设置保存的日志名字：
log_name = f"iseec_v4_{rl_model_name}_{policy_kwargs_diy}_{int(total_timesteps_diy)}_{custom_reward_type}" # log_name = "iseec_v4_PPO_Net256_6e5_callback"
os.makedirs(f"./logs/{log_name}", exist_ok=True) # # 创建日志目录

# 设置日志保存路径和格式
tmp_path = f"logs/{log_name}"
new_logger = configure(
    tmp_path, 
    # ["stdout",     # 终端输出
    [
     "csv",        # CSV文件
     "tensorboard", # Tensorboard格式
     "json"        # JSON格式
    ]
)
# Out:
# Logging to logs/iseec_v4_PPO_dict_pi_vf_default_250000_2_simple_spare

# %%
log_name
# Out:
# 'iseec_v4_PPO_dict_pi_vf_default_250000_2_simple_spare'

# %% [markdown]
# ### 定义环境

# %%
env = IEMEnv(reward_type=custom_reward_type)

# env.seed(42) 还是需要自己手动定义的

env_monitor = Monitor(env, f'./logs/{log_name}')

# check 环境
from stable_baselines3.common.env_checker import check_env
# check_env(env_monitor)


print("Action space sample:", env.action_space.sample())
# print("Observation space sample:", env.observation_space.sample())

# type(env.action_space), type(env.observation_space)
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]
# Action space sample: 11

# %%
print("Action space sample:", env.action_space.sample())
print("Observation space sample:", env.observation_space.sample())
# Out:
# Action space sample: 4
# Observation space sample: [-0.01383755  0.40746126 -0.4731919   0.01049489 -0.28851235 -1.22527414
#  -0.00465888 -1.68464507 -0.71453013 -0.84010221]

# %% [markdown]
# ### 定义算法

# %%
# 定义模型
model = PPO(
    "MlpPolicy", 
    env_monitor, 
    # ent_coef=0.01, # 增加策略寻找的鼓励
    verbose=1,
    )





# model = DQN(
#     "MlpPolicy", 
#     env_monitor, 

#     verbose=1,
#     )

model.set_logger(new_logger) # set the parameter of the logger

print(model.policy)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# ActorCriticPolicy(
#   (features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (pi_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (vf_features_extractor): FlattenExtractor(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=16, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %% [markdown]
# ### 模型训练

# %%
def plot_callback_reward(metrics):
    """绘制训练过程中的奖励曲线
    
    Args:
        metrics (dict): 包含训练指标的字典，需要包含以下键：
            - rewards: 原始奖励列表
            - moving_avg_rewards: 移动平均奖励列表
            - moving_std_rewards: 移动标准差列表
            - episodes: 总回合数
            - step_idx: 当前步数
    """
    plt.figure(figsize=(20, 5))
    
    # 创建主图
    plt.subplot(131)
    plt.title(f'Step: {metrics["step_idx"]}, Latest reward: {metrics["rewards"][-1]:.2f}\n'
              f'Episode: {metrics["episodes"]}, Moving avg: {metrics["moving_avg_rewards"][-1]:.2f}')
    
    # 绘制原始奖励
    episodes = range(len(metrics["rewards"]))
    plt.plot(episodes, metrics["rewards"], 
             label='Raw rewards', color='gray', alpha=0.3)
    
    # 绘制移动平均
    plt.plot(episodes, metrics["moving_avg_rewards"],
             label='Moving average', color='blue', linewidth=2)
    
    # 添加标准差区域
    moving_avg = np.array(metrics["moving_avg_rewards"])
    moving_std = np.array(metrics["moving_std_rewards"])
    
    # 0.25倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.25 * moving_std,
                    moving_avg + 0.25 * moving_std,
                    color='b', alpha=0.1,
                    label='0.25 std range')
    
    # 0.5倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.5 * moving_std,
                    moving_avg + 0.5 * moving_std,
                    color='b', alpha=0.1,
                    label='0.5 std range')
    
    # 设置坐标轴和标签
    plt.xlabel('Episodes')
    plt.ylabel('Episode Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()


class TrainingMonitorCallback(BaseCallback):
    def __init__(self, verbose=1, window_size=50):
        super().__init__(verbose)
        self.window_size = window_size
        # Initialize data dictionary to store metrics
        self.data = {
            "rewards": [],
            "moving_avg_rewards": [],
            "moving_std_rewards": [],
            "episodes": 0,
            "step_idx": 0
        }
        self.episode_rewards = 0
        
    def _on_step(self):
        # Accumulate rewards for current episode
        reward = self.locals.get('rewards')[0]
        self.episode_rewards += reward
        self.data["step_idx"] += 1
        
        # When episode ends, update all metrics
        if self.locals.get('dones')[0]:
            # Store raw reward
            self.data["rewards"].append(self.episode_rewards)
            
            # Calculate moving average and std
            recent_rewards = self.data["rewards"][-self.window_size:]
            moving_avg = np.mean(recent_rewards)
            moving_std = np.std(recent_rewards) if len(recent_rewards) > 1 else 0
            
            # Store calculated metrics
            self.data["moving_avg_rewards"].append(moving_avg)
            self.data["moving_std_rewards"].append(moving_std)
            self.data["episodes"] += 1
            
            # Print progress
            print(f"Episode {self.data['episodes']} finished with reward: {self.episode_rewards:.2f}")
            print(f"Moving average (last {len(recent_rewards)} episodes): {moving_avg:.2f} ± {moving_std:.2f}")
            
            # Reset episode rewards
            self.episode_rewards = 0
            
        return True
    
    def get_metrics(self):
        """Return the collected metrics"""
        return self.data
# Create callback with custom window size
callback = TrainingMonitorCallback(window_size=50)

# Train the model
model.learn(
    total_timesteps=int(total_timesteps_diy),
    callback=callback,
    log_interval=1
)

# After training, get metrics for plotting
metrics = callback.get_metrics()

# Plot rewards using the plot_callback_reward function
plot_callback_reward(metrics)
# Out:
# Episode 1 finished with reward: 116.00
# Moving average (last 1 episodes): 116.00 ± 0.00
# Episode 2 finished with reward: 116.00
# Moving average (last 2 episodes): 116.00 ± 0.00
# Episode 3 finished with reward: 116.00
# Moving average (last 3 episodes): 116.00 ± 0.00
# Episode 4 finished with reward: 116.00
# Moving average (last 4 episodes): 116.00 ± 0.00
# Episode 5 finished with reward: 116.00
# Moving average (last 5 episodes): 116.00 ± 0.00
# Episode 6 finished with reward: 116.00
# Moving average (last 6 episodes): 116.00 ± 0.00
# Episode 7 finished with reward: 116.00
# Moving average (last 7 episodes): 116.00 ± 0.00
# Episode 8 finished with reward: 116.00
# Moving average (last 8 episodes): 116.00 ± 0.00
# Episode 9 finished with reward: 116.00
# Moving average (last 9 episodes): 116.00 ± 0.00
# Episode 10 finished with reward: 116.00
# Moving average (last 10 episodes): 116.00 ± 0.00
# Episode 11 finished with reward: 116.00
# Moving average (last 11 episodes): 116.00 ± 0.00
# Episode 12 finished with reward: 116.00
# Moving average (last 12 episodes): 116.00 ± 0.00
# Episode 13 finished with reward: 116.00
# Moving average (last 13 episodes): 116.00 ± 0.00
# Episode 14 finished with reward: 116.00
# Moving average (last 14 episodes): 116.00 ± 0.00
# Episode 15 finished with reward: 116.00
# Moving average (last 15 episodes): 116.00 ± 0.00
# Episode 16 finished with reward: 116.00
# Moving average (last 16 episodes): 116.00 ± 0.00
# Episode 17 finished with reward: 116.00
# Moving average (last 17 episodes): 116.00 ± 0.00
# Episode 18 finished with reward: 116.00
# Moving average (last 18 episodes): 116.00 ± 0.00
# Episode 19 finished with reward: 116.00
# Moving average (last 19 episodes): 116.00 ± 0.00
# Episode 20 finished with reward: 116.00
# Moving average (last 20 episodes): 116.00 ± 0.00
# Episode 21 finished with reward: 116.00
# Moving average (last 21 episodes): 116.00 ± 0.00
# Episode 22 finished with reward: 116.00
# Moving average (last 22 episodes): 116.00 ± 0.00
# Episode 23 finished with reward: 116.00
# Moving average (last 23 episodes): 116.00 ± 0.00
# Episode 24 finished with reward: 116.00
# Moving average (last 24 episodes): 116.00 ± 0.00
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85       |
# |    ep_rew_mean     | 116      |
# | time/              |          |
# |    fps             | 206      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Episode 25 finished with reward: 116.00
# Moving average (last 25 episodes): 116.00 ± 0.00
# Episode 26 finished with reward: 116.00
# Moving average (last 26 episodes): 116.00 ± 0.00
# Episode 27 finished with reward: 116.00
# Moving average (last 27 episodes): 116.00 ± 0.00
# Episode 28 finished with reward: 116.00
# Moving average (last 28 episodes): 116.00 ± 0.00
# Episode 29 finished with reward: 116.00
# Moving average (last 29 episodes): 116.00 ± 0.00
# Episode 30 finished with reward: 116.00
# Moving average (last 30 episodes): 116.00 ± 0.00
# Episode 31 finished with reward: 116.00
# Moving average (last 31 episodes): 116.00 ± 0.00
# Episode 32 finished with reward: 116.00
# Moving average (last 32 episodes): 116.00 ± 0.00
# Episode 33 finished with reward: 116.00
# Moving average (last 33 episodes): 116.00 ± 0.00
# Episode 34 finished with reward: 116.00
# Moving average (last 34 episodes): 116.00 ± 0.00
# Episode 35 finished with reward: 116.00
# Moving average (last 35 episodes): 116.00 ± 0.00
# Episode 36 finished with reward: 116.00
# Moving average (last 36 episodes): 116.00 ± 0.00
# Episode 37 finished with reward: 116.00
# Moving average (last 37 episodes): 116.00 ± 0.00
# Episode 38 finished with reward: 116.00
# Moving average (last 38 episodes): 116.00 ± 0.00
# Episode 39 finished with reward: 116.00
# Moving average (last 39 episodes): 116.00 ± 0.00
# Episode 40 finished with reward: 116.00
# Moving average (last 40 episodes): 116.00 ± 0.00
# Episode 41 finished with reward: 116.00
# Moving average (last 41 episodes): 116.00 ± 0.00
# Episode 42 finished with reward: 116.00
# Moving average (last 42 episodes): 116.00 ± 0.00
# Episode 43 finished with reward: 116.00
# Moving average (last 43 episodes): 116.00 ± 0.00
# Episode 44 finished with reward: 116.00
# Moving average (last 44 episodes): 116.00 ± 0.00
# Episode 45 finished with reward: 116.00
# Moving average (last 45 episodes): 116.00 ± 0.00
# Episode 46 finished with reward: 116.00
# Moving average (last 46 episodes): 116.00 ± 0.00
# Episode 47 finished with reward: 116.00
# Moving average (last 47 episodes): 116.00 ± 0.00
# Episode 48 finished with reward: 116.00
# Moving average (last 48 episodes): 116.00 ± 0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 197         |
# |    iterations           | 2           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015137978 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.00281     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.43e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 3.06e+03    |
# -----------------------------------------
# Episode 49 finished with reward: 116.00
# Moving average (last 49 episodes): 116.00 ± 0.00
# Episode 50 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 51 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 52 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 53 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 54 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 55 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 56 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 57 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 58 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 59 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 60 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 61 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 62 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 63 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 64 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 65 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 66 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 67 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 68 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 69 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 70 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 71 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 72 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 3           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011119368 |
# |    clip_fraction        | 0.0759      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.13        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00874    |
# |    value_loss           | 2.83e+03    |
# -----------------------------------------
# Episode 73 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 74 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 75 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 76 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 77 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 78 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 79 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 80 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 81 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 82 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 83 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 84 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 85 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 86 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 87 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 88 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 89 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 90 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 91 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 92 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 93 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 94 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 95 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 96 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 4           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012358952 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00892    |
# |    value_loss           | 2.63e+03    |
# -----------------------------------------
# Episode 97 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 98 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 99 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 100 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 101 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 102 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 103 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 104 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 105 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 106 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 107 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 108 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 109 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 110 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 111 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 112 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 113 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 114 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 115 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 116 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 117 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 118 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 119 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 120 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85         |
# |    ep_rew_mean          | 116        |
# | time/                   |            |
# |    fps                  | 182        |
# |    iterations           | 5          |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01522198 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.7       |
# |    explained_variance   | 0.303      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.5e+03    |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0124    |
# |    value_loss           | 2.48e+03   |
# ----------------------------------------
# Episode 121 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 122 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 123 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 124 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 125 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 126 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 127 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 128 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 129 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 130 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 131 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 132 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 133 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 134 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 135 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 136 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 137 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 138 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 139 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 140 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 141 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 142 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 143 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 144 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 6           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.016447673 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1e+03     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 2.33e+03    |
# -----------------------------------------
# Episode 145 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 146 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 147 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 148 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 149 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 150 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 151 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 152 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 153 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 154 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 155 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 156 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 157 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 158 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 159 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 160 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 161 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 162 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 163 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 164 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 165 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 166 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 167 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 168 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 7           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013982646 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00968    |
# |    value_loss           | 2.19e+03    |
# -----------------------------------------
# Episode 169 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 170 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 171 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 172 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 173 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 174 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 175 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 176 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 177 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 178 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 179 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 180 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 181 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 182 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 183 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 184 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 185 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 186 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 187 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 188 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 189 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 190 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 191 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 192 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 179         |
# |    iterations           | 8           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006921687 |
# |    clip_fraction        | 0.0338      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.426       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1e+03       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00445    |
# |    value_loss           | 2.08e+03    |
# -----------------------------------------
# Episode 193 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 194 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 195 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 196 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 197 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 198 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 199 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 200 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 201 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 202 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 203 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 204 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 205 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 206 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 207 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 208 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 209 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 210 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 211 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 212 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 213 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 214 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 215 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 216 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 179         |
# |    iterations           | 9           |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010401196 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.457       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00577    |
# |    value_loss           | 1.99e+03    |
# -----------------------------------------
# Episode 217 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 218 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 219 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 220 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 221 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 222 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 223 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 224 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 225 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 226 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 227 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 228 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 229 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 230 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 231 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 232 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 233 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 234 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 235 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 236 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 237 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 238 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 239 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 240 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 179         |
# |    iterations           | 10          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012463181 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.461       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 954         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00912    |
# |    value_loss           | 1.89e+03    |
# -----------------------------------------
# Episode 241 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 242 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 243 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 244 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 245 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 246 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 247 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 248 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 249 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 250 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 251 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 252 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 253 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 254 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 255 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 256 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 257 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 258 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 259 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 260 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 261 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 262 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 263 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 264 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 265 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 180         |
# |    iterations           | 11          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012870909 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.48        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 449         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00917    |
# |    value_loss           | 1.79e+03    |
# -----------------------------------------
# Episode 266 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 267 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 268 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 269 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 270 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 271 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 272 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 273 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 274 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 275 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 276 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 277 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 278 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 279 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 280 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 281 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 282 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 283 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 284 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 285 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 286 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 287 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 288 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 289 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 180         |
# |    iterations           | 12          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013088021 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 992         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00851    |
# |    value_loss           | 1.73e+03    |
# -----------------------------------------
# Episode 290 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 291 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 292 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 293 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 294 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 295 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 296 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 297 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 298 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 299 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 300 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 301 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 302 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 303 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 304 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 305 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 306 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 307 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 308 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 309 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 310 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 311 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 312 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 313 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 13          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011975249 |
# |    clip_fraction        | 0.0801      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.515       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 991         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 1.61e+03    |
# -----------------------------------------
# Episode 314 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 315 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 316 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 317 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 318 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 319 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 320 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 321 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 322 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 323 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 324 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 325 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 326 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 327 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 328 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 329 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 330 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 331 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 332 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 333 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 334 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 335 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 336 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 337 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 14          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009240555 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00726    |
# |    value_loss           | 1.51e+03    |
# -----------------------------------------
# Episode 338 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 339 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 340 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 341 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 342 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 343 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 344 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 345 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 346 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 347 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 348 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 349 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 350 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 351 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 352 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 353 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 354 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 355 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 356 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 357 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 358 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 359 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 360 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 361 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 15          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014205204 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.48       |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 678         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00892    |
# |    value_loss           | 1.43e+03    |
# -----------------------------------------
# Episode 362 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 363 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 364 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 365 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 366 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 367 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 368 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 369 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 370 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 371 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 372 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 373 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 374 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 375 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 376 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 377 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 378 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 379 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 380 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 381 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 382 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 383 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 384 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 385 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 16          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008843761 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.48       |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 424         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00537    |
# ...
# |    approx_kl            | 4.5461464e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.678        |
# |    explained_variance   | 0.817         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 54.9          |
# |    n_updates            | 1170          |
# |    policy_gradient_loss | -7.58e-05     |
# |    value_loss           | 463           |
# -------------------------------------------
# Episode 2844 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2845 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2846 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2847 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2848 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2849 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2850 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2851 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2852 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2853 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2854 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2855 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2856 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2857 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2858 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2859 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2860 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2861 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2862 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2863 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2864 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2865 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2866 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2867 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 85            |
# |    ep_rew_mean          | 116           |
# | time/                   |               |
# |    fps                  | 176           |
# |    iterations           | 119           |
# |    time_elapsed         | 1380          |
# |    total_timesteps      | 243712        |
# | train/                  |               |
# |    approx_kl            | 0.00061069545 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.684        |
# |    explained_variance   | 0.822         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 34.9          |
# |    n_updates            | 1180          |
# |    policy_gradient_loss | -0.000256     |
# |    value_loss           | 446           |
# -------------------------------------------
# Episode 2868 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2869 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2870 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2871 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2872 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2873 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2874 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2875 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2876 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2877 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2878 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2879 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2880 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2881 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2882 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2883 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2884 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2885 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2886 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2887 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2888 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2889 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2890 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2891 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 85            |
# |    ep_rew_mean          | 116           |
# | time/                   |               |
# |    fps                  | 176           |
# |    iterations           | 120           |
# |    time_elapsed         | 1392          |
# |    total_timesteps      | 245760        |
# | train/                  |               |
# |    approx_kl            | 0.00096983754 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.628        |
# |    explained_variance   | 0.822         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 79.3          |
# |    n_updates            | 1190          |
# |    policy_gradient_loss | -0.000596     |
# |    value_loss           | 445           |
# -------------------------------------------
# Episode 2892 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2893 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2894 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2895 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2896 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2897 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2898 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2899 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2900 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2901 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2902 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2903 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2904 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2905 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2906 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2907 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2908 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2909 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2910 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2911 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2912 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2913 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2914 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2915 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85           |
# |    ep_rew_mean          | 116          |
# | time/                   |              |
# |    fps                  | 176          |
# |    iterations           | 121          |
# |    time_elapsed         | 1403         |
# |    total_timesteps      | 247808       |
# | train/                  |              |
# |    approx_kl            | 0.0016453322 |
# |    clip_fraction        | 0.00532      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.635       |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 98.1         |
# |    n_updates            | 1200         |
# |    policy_gradient_loss | -0.000326    |
# |    value_loss           | 444          |
# ------------------------------------------
# Episode 2916 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2917 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2918 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2919 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2920 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2921 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2922 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2923 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2924 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2925 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2926 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2927 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2928 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2929 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2930 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2931 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2932 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2933 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2934 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2935 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2936 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2937 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2938 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2939 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85           |
# |    ep_rew_mean          | 116          |
# | time/                   |              |
# |    fps                  | 176          |
# |    iterations           | 122          |
# |    time_elapsed         | 1414         |
# |    total_timesteps      | 249856       |
# | train/                  |              |
# |    approx_kl            | 0.0023159771 |
# |    clip_fraction        | 0.0158       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.745       |
# |    explained_variance   | 0.824        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 468          |
# |    n_updates            | 1210         |
# |    policy_gradient_loss | -0.00165     |
# |    value_loss           | 444          |
# ------------------------------------------
# Episode 2940 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2941 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2942 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2943 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2944 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2945 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2946 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2947 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2948 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2949 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2950 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2951 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2952 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2953 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2954 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2955 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2956 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2957 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2958 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2959 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2960 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2961 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2962 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# Episode 2963 finished with reward: 116.00
# Moving average (last 50 episodes): 116.00 ± 0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 85            |
# |    ep_rew_mean          | 116           |
# | time/                   |               |
# |    fps                  | 176           |
# |    iterations           | 123           |
# |    time_elapsed         | 1427          |
# |    total_timesteps      | 251904        |
# | train/                  |               |
# |    approx_kl            | 0.00027652035 |
# |    clip_fraction        | 0.000293      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.748        |
# |    explained_variance   | 0.824         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 269           |
# |    n_updates            | 1220          |
# |    policy_gradient_loss | -0.000191     |
# |    value_loss           | 445           |
# -------------------------------------------

# %%
def plot_smooth_rewards(rewards, window_sizes=[5, 20, 100]):
    """
    绘制平滑的奖励曲线
    Args:
        rewards: 奖励列表
        window_sizes: 移动平均窗口大小列表
    """
    plt.figure(figsize=(12, 6))
    
    # 绘制原始奖励
    plt.plot(rewards, 'lightgray', alpha=0.3, label='Raw rewards')
    
    # 绘制不同窗口大小的移动平均
    colors = ['blue', 'green', 'red']
    for window, color in zip(window_sizes, colors):
        if len(rewards) >= window:
            # 计算移动平均
            smooth_rewards = np.convolve(rewards, 
                                      np.ones(window)/window, 
                                      mode='valid')
            plt.plot(range(window-1, len(rewards)), 
                    smooth_rewards, 
                    color=color, 
                    label=f'{window}-Episode Moving Average',
                    linewidth=2)
    
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.title('Training Rewards with Different Smoothing Windows')
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.show()


# 绘制平滑奖励曲线
plot_smooth_rewards(metrics["rewards"])

# %% [markdown]
# notes: 如果要训练过程中查看模型，通过 tensorboard 查看

# %%
# 模型保存
model.save(f"./model/{log_name}")

# %% [markdown]
# ### 评估模型训练结果

# %% [markdown]
# > 利用 evaulate policy 函数评估

# %% [markdown]
# # 加载训练好的 RL 模型

# %%
from stable_baselines3.common.evaluation import evaluate_policy
mean_reward, std_reward = evaluate_policy(
    model, 
    model.get_env(), 
    deterministic=True,
    render=True,
    n_eval_episodes=10)
# Out:
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")

# %%
print(mean_reward)
print(std_reward)
# Out:
# 116.0
# 0.0

# %%
del model
model = PPO.load(f"./model/{log_name}", env=env_monitor)
# model = DQN.load(f"./model/{log_name}", env=env_monitor)
# Out:
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### 结果展示

# %% [markdown]
# #### 纯净展示版本
#
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图

episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆



for ep in range(episodes):
    obs, _ = env_monitor.reset() # 必须的，每次重现一次
    episode_reward = 0
    done = False
     
     
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # 每10步更新一次图像
        if i % 10 == 0:
            env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")
# Out:
# Step 0 - Action: 14 - Reward: -1 - Done: False
# Step 1 - Action: 14 - Reward: -1 - Done: False
# Step 2 - Action: 14 - Reward: -1 - Done: False
# Step 3 - Action: 14 - Reward: -1 - Done: False
# Step 4 - Action: 14 - Reward: -1 - Done: False
# Step 5 - Action: 14 - Reward: -1 - Done: False
# Step 6 - Action: 14 - Reward: -1 - Done: False
# Step 7 - Action: 14 - Reward: -1 - Done: False
# Step 8 - Action: 14 - Reward: -1 - Done: False
# Step 9 - Action: 14 - Reward: -1 - Done: False
# Step 10 - Action: 14 - Reward: -1 - Done: False
# Step 11 - Action: 14 - Reward: -1 - Done: False
# Step 12 - Action: 14 - Reward: -1 - Done: False
# Step 13 - Action: 14 - Reward: -1 - Done: False
# Step 14 - Action: 14 - Reward: -1 - Done: False
# Step 15 - Action: 14 - Reward: -1 - Done: False
# Step 16 - Action: 14 - Reward: -1 - Done: False
# Step 17 - Action: 14 - Reward: -1 - Done: False
# Step 18 - Action: 14 - Reward: -1 - Done: False
# Step 19 - Action: 14 - Reward: -1 - Done: False
# Step 20 - Action: 14 - Reward: -1 - Done: False
# Step 21 - Action: 14 - Reward: -1 - Done: False
# Step 22 - Action: 14 - Reward: -1 - Done: False
# Step 23 - Action: 14 - Reward: -1 - Done: False
# Step 24 - Action: 14 - Reward: -1 - Done: False
# Step 25 - Action: 14 - Reward: -1 - Done: False
# Step 26 - Action: 14 - Reward: -1 - Done: False
# Step 27 - Action: 14 - Reward: -1 - Done: False
# Step 28 - Action: 14 - Reward: -1 - Done: False
# Step 29 - Action: 14 - Reward: -1 - Done: False
# Step 30 - Action: 14 - Reward: -1 - Done: False
# Step 31 - Action: 14 - Reward: -1 - Done: False
# Step 32 - Action: 14 - Reward: -1 - Done: False
# Step 33 - Action: 14 - Reward: -1 - Done: False
# Step 34 - Action: 14 - Reward: -1 - Done: False
# Step 35 - Action: 14 - Reward: -1 - Done: False
# Step 36 - Action: 14 - Reward: -1 - Done: False
# Step 37 - Action: 14 - Reward: -1 - Done: False
# Step 38 - Action: 14 - Reward: -1 - Done: False
# Step 39 - Action: 14 - Reward: -1 - Done: False
# Step 40 - Action: 14 - Reward: -1 - Done: False
# Step 41 - Action: 14 - Reward: -1 - Done: False
# Step 42 - Action: 14 - Reward: -1 - Done: False
# Step 43 - Action: 14 - Reward: -1 - Done: False
# Step 44 - Action: 14 - Reward: -1 - Done: False
# Step 45 - Action: 14 - Reward: -1 - Done: False
# Step 46 - Action: 14 - Reward: -1 - Done: False
# Step 47 - Action: 14 - Reward: -1 - Done: False
# Step 48 - Action: 14 - Reward: -1 - Done: False
# Step 49 - Action: 14 - Reward: -1 - Done: False
# Step 50 - Action: 14 - Reward: -1 - Done: False
# Step 51 - Action: 14 - Reward: -1 - Done: False
# Step 52 - Action: 14 - Reward: -1 - Done: False
# Step 53 - Action: 14 - Reward: -1 - Done: False
# Step 54 - Action: 14 - Reward: -1 - Done: False
# Step 55 - Action: 14 - Reward: -1 - Done: False
# Step 56 - Action: 14 - Reward: -1 - Done: False
# Step 57 - Action: 14 - Reward: -1 - Done: False
# Step 58 - Action: 14 - Reward: -1 - Done: False
# Step 59 - Action: 14 - Reward: -1 - Done: False
# Step 60 - Action: 14 - Reward: -1 - Done: False
# Step 61 - Action: 14 - Reward: -1 - Done: False
# Step 62 - Action: 14 - Reward: -1 - Done: False
# Step 63 - Action: 14 - Reward: -1 - Done: False
# Step 64 - Action: 14 - Reward: -1 - Done: False
# Step 65 - Action: 14 - Reward: -1 - Done: False
# Step 66 - Action: 14 - Reward: -1 - Done: False
# Step 67 - Action: 14 - Reward: -1 - Done: False
# Step 68 - Action: 14 - Reward: -1 - Done: False
# Step 69 - Action: 14 - Reward: -1 - Done: False
# Step 70 - Action: 14 - Reward: -1 - Done: False
# Step 71 - Action: 14 - Reward: -1 - Done: False
# Step 72 - Action: 14 - Reward: -1 - Done: False
# Step 73 - Action: 14 - Reward: -1 - Done: False
# Step 74 - Action: 14 - Reward: -1 - Done: False
# Step 75 - Action: 14 - Reward: -1 - Done: False
# Step 76 - Action: 14 - Reward: -1 - Done: False
# Step 77 - Action: 14 - Reward: -1 - Done: False
# Step 78 - Action: 14 - Reward: -1 - Done: False
# Step 79 - Action: 14 - Reward: -1 - Done: False
# Step 80 - Action: 14 - Reward: -1 - Done: False
# Step 81 - Action: 14 - Reward: -1 - Done: False
# Step 82 - Action: 14 - Reward: 99 - Done: False
# Step 83 - Action: 14 - Reward: 99 - Done: False
# Step 84 - Action: 14 - Reward: 0 - Done: True
# Episode ended at step 84 with T_a = 1.2368265541709291
# Episode 0 finished with reward0
# Final T_a: 1.2368265541709291

# %% [markdown]
# ### 保存整体运行结果

# %%
env_test = IEMEnv(reward_type=custom_reward_type)
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 3 # 结果展示，只有一个 episode 部分
max_steps = 250

# all_episode_rewards = [] # 记录所有 episode 里面的

for ep in range(episodes):
    
    ##################################
    # 记录所需数组：每次 episode 重置
    total_action = []
    total_state = []
    total_reward = []
    total_done = []
    ##################################
    # 记录每个 episode 的 reward
    episode_reward = 0
    ##################################
    
    obs, _ = env_test.reset() # 必须的，每次重现一次 ，这里可能就需要固定随机种子了
    done = False
    
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        ##################################
        # 添加转换的部分
        action_number, action_name = IEMEnv.action2number_env(action)
        total_action.append(action_number)
        total_state.append(obs)
        total_reward.append(reward)
        total_done.append(done)
        ##################################
        # 记录每个 episode 的 reward
        episode_reward += reward # TODO：可以放在内容记录 step 部分
        ################################## 
        
        if done:
            print(f"Episode {ep} finished at step {i}")
            break
        
        # # 每10步更新一次图像
        # if ep % 10 == 0:
        #     env_monitor.render()
        #     # plt.pause(0.01)
    
    # all_episode_rewards.append(episode_reward)
    
    env_test.append_data_reward(episode_reward)
    
    save_future_data(env=env_test,custom_reward_type=custom_reward_type,rl_model_name=rl_model_name,network_name=policy_kwargs_diy,episode=ep,total_action=total_action,total_state=total_state,total_reward=total_reward,total_done=total_done,total_timesteps_name=total_timesteps_diy)

    save_plot_NSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    save_plot_SSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    # plot_3D_run(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state)
    
    
    print(f"Episode {ep} finished with reward{episode_reward}")
    
    
plot_data = env_test.get_variables()
plot_episode_reward(plot_data)

# %% [markdown]
# 主要针对可视化显示部分操作

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 绘制只展示一次 episode 结果

# env_test

for episode in range(1):
    obs, _ = env_test.reset() # 这里可能就需要固定随机种子了
    
    done = False
    
    for i in range(251):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        
        if done:
            print(f"Episode {episode} finished at step {i}")
            break
# Out:
# Step 0 - Action: 14 - Reward: -1 - Done: False
# Step 1 - Action: 14 - Reward: -1 - Done: False
# Step 2 - Action: 14 - Reward: -1 - Done: False
# Step 3 - Action: 14 - Reward: -1 - Done: False
# Step 4 - Action: 14 - Reward: -1 - Done: False
# Step 5 - Action: 14 - Reward: -1 - Done: False
# Step 6 - Action: 14 - Reward: -1 - Done: False
# Step 7 - Action: 14 - Reward: -1 - Done: False
# Step 8 - Action: 14 - Reward: -1 - Done: False
# Step 9 - Action: 14 - Reward: -1 - Done: False
# Step 10 - Action: 14 - Reward: -1 - Done: False
# Step 11 - Action: 14 - Reward: -1 - Done: False
# Step 12 - Action: 14 - Reward: -1 - Done: False
# Step 13 - Action: 14 - Reward: -1 - Done: False
# Step 14 - Action: 14 - Reward: -1 - Done: False
# Step 15 - Action: 14 - Reward: -1 - Done: False
# Step 16 - Action: 14 - Reward: -1 - Done: False
# Step 17 - Action: 14 - Reward: -1 - Done: False
# Step 18 - Action: 14 - Reward: -1 - Done: False
# Step 19 - Action: 14 - Reward: -1 - Done: False
# Step 20 - Action: 14 - Reward: -1 - Done: False
# Step 21 - Action: 14 - Reward: -1 - Done: False
# Step 22 - Action: 14 - Reward: -1 - Done: False
# Step 23 - Action: 14 - Reward: -1 - Done: False
# Step 24 - Action: 14 - Reward: -1 - Done: False
# Step 25 - Action: 14 - Reward: -1 - Done: False
# Step 26 - Action: 14 - Reward: -1 - Done: False
# Step 27 - Action: 14 - Reward: -1 - Done: False
# Step 28 - Action: 14 - Reward: -1 - Done: False
# Step 29 - Action: 14 - Reward: -1 - Done: False
# Step 30 - Action: 14 - Reward: -1 - Done: False
# Step 31 - Action: 14 - Reward: -1 - Done: False
# Step 32 - Action: 14 - Reward: -1 - Done: False
# Step 33 - Action: 14 - Reward: -1 - Done: False
# Step 34 - Action: 14 - Reward: -1 - Done: False
# Step 35 - Action: 14 - Reward: -1 - Done: False
# Step 36 - Action: 14 - Reward: -1 - Done: False
# Step 37 - Action: 14 - Reward: -1 - Done: False
# Step 38 - Action: 14 - Reward: -1 - Done: False
# Step 39 - Action: 14 - Reward: -1 - Done: False
# Step 40 - Action: 14 - Reward: -1 - Done: False
# Step 41 - Action: 14 - Reward: -1 - Done: False
# Step 42 - Action: 14 - Reward: -1 - Done: False
# Step 43 - Action: 14 - Reward: -1 - Done: False
# Step 44 - Action: 14 - Reward: -1 - Done: False
# Step 45 - Action: 14 - Reward: -1 - Done: False
# Step 46 - Action: 14 - Reward: -1 - Done: False
# Step 47 - Action: 14 - Reward: -1 - Done: False
# Step 48 - Action: 14 - Reward: -1 - Done: False
# Step 49 - Action: 14 - Reward: -1 - Done: False
# Step 50 - Action: 14 - Reward: -1 - Done: False
# Step 51 - Action: 14 - Reward: -1 - Done: False
# Step 52 - Action: 14 - Reward: -1 - Done: False
# Step 53 - Action: 14 - Reward: -1 - Done: False
# Step 54 - Action: 14 - Reward: -1 - Done: False
# Step 55 - Action: 14 - Reward: -1 - Done: False
# Step 56 - Action: 14 - Reward: -1 - Done: False
# Step 57 - Action: 14 - Reward: -1 - Done: False
# Step 58 - Action: 14 - Reward: -1 - Done: False
# Step 59 - Action: 14 - Reward: -1 - Done: False
# Step 60 - Action: 14 - Reward: -1 - Done: False
# Step 61 - Action: 14 - Reward: -1 - Done: False
# Step 62 - Action: 14 - Reward: -1 - Done: False
# Step 63 - Action: 14 - Reward: -1 - Done: False
# Step 64 - Action: 14 - Reward: -1 - Done: False
# Step 65 - Action: 14 - Reward: -1 - Done: False
# Step 66 - Action: 14 - Reward: -1 - Done: False
# Step 67 - Action: 14 - Reward: -1 - Done: False
# Step 68 - Action: 14 - Reward: -1 - Done: False
# Step 69 - Action: 14 - Reward: -1 - Done: False
# Step 70 - Action: 14 - Reward: -1 - Done: False
# Step 71 - Action: 14 - Reward: -1 - Done: False
# Step 72 - Action: 14 - Reward: -1 - Done: False
# Step 73 - Action: 14 - Reward: -1 - Done: False
# Step 74 - Action: 14 - Reward: -1 - Done: False
# Step 75 - Action: 14 - Reward: -1 - Done: False
# Step 76 - Action: 14 - Reward: -1 - Done: False
# Step 77 - Action: 14 - Reward: -1 - Done: False
# Step 78 - Action: 14 - Reward: -1 - Done: False
# Step 79 - Action: 14 - Reward: -1 - Done: False
# Step 80 - Action: 14 - Reward: -1 - Done: False
# Step 81 - Action: 14 - Reward: -1 - Done: False
# Step 82 - Action: 14 - Reward: 99 - Done: False
# Step 83 - Action: 14 - Reward: 99 - Done: False
# Step 84 - Action: 14 - Reward: 0 - Done: True
# Episode 0 finished at step 84

# %% [markdown]
# # 保存运行结果
