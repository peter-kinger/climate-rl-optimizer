# %% [markdown]
# # RL 训练

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import scipy.io
from matplotlib.gridspec import GridSpec
import math
import random
import torch

from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.logger import configure
from stable_baselines3.common.monitor import Monitor
from stable_baselines3 import PPO 
from stable_baselines3 import DQN

# 导入 BaseCallback
from stable_baselines3.common.callbacks import BaseCallback

import sys
import os

# 将 src 目录添加到模块搜索路径
sys.path.append(os.path.abspath('src'))

# 导入 IEMEnv 类
from src.envs.iseec_lx_v4_mdp_plot import IEMEnv
from src.utils.run_debug_plot import save_data 
from src.utils.run_debug_plot import save_plot_NSM_data
from src.utils.run_debug_plot import save_plot_SSM_data

from src.utils.run_debug_plot import save_future_data
from src.utils.run_debug_plot import save_plot_NSM_future_data
from src.utils.run_debug_plot import save_plot_SSM_future_data

from src.utils.run_debug_plot import plot_episode_reward
from src.utils.run_debug_plot import plot_episode_reward_simple
from src.utils.run_debug_plot import plot_3D_run

# %% [markdown]
# 定义保存位置参数
#
# > 所有的关键参数都放在最前面

# %%
# 增加随机种子的定义
def set_global_seed(seed):
    """设置全局随机种子"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False


# 设置全局种子
# SEED = 42 # 非测试，不指定种子
# set_global_seed(SEED)

# 全新的超参数配置过程，都放在一起
base_config = {
    # MDP 元素
    "custom_reward_type" : "multi_objective_single_T_a_exp8611_reset",
    # 环境 & 策略
    "env_id":   "iseec_lx_v4_mdp_plot",
    "rl_model_name": "DQN",
    "policy":   "MlpPolicy",
    "network_name" : "Netxxx_no_big_env",
    # 训练时长
    "total_timesteps_diy": 700000,
    "policy_kwargs_diy" : "dict_pi_vf_default", # for example: policy_kwargs = dict(activation_fn=th.nn.ReLU,net_arch=[256, 256, dict(pi=[128, 64], vf=[128, 64])])
    # 优化器 & 网络
    "hyperparams_diy": "default", 
    # "learning_rate":   3e-4,
    # "ent_coef":        0.0,
    # "batch_size":      64,
    # "n_epochs":        10,
    # 回放 & 更新频率（PPO 固定写法示例）
    # "gamma":           0.99,
    # "clip_range":      0.2,
    # "gae_lambda":      0.95,
    # 随机种子
    "use_random_reset": False, # 是否使用随机重置
    "seed":            42,
}


############### 具体的配置细节##############
# 设置保存的日志名字：
log_name = f'{base_config["env_id"]}_{base_config["rl_model_name"]}_{base_config["custom_reward_type"]}_{int(base_config["total_timesteps_diy"])}_{base_config["hyperparams_diy"]}' 
os.makedirs(f'./logs/{log_name}', exist_ok=True) # 创建日志目录

# 相当于接口部分
custom_reward_type = base_config["custom_reward_type"]
network_name = base_config["network_name"]
rl_model_name = base_config["rl_model_name"]
total_timesteps_diy = base_config["total_timesteps_diy"]
policy_kwargs_diy = base_config["policy_kwargs_diy"] 

# 设置日志保存路径和格式
new_logger = configure(
    f"logs/{log_name}",  # tmp_path 路径保存位置
    # ["stdout",     # 终端输出
    [
     "csv",        # CSV文件
     "tensorboard", # Tensorboard格式
     "json"        # JSON格式
    ]
)

# %% [markdown]
# ### 定义环境

# %%
env = IEMEnv(reward_type=base_config["custom_reward_type"], seed=base_config["seed"])
env_monitor = Monitor(env, f'./logs/{log_name}')
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# ### 定义算法

# %%
# # 定义模型
# model = PPO(
#     "MlpPolicy", 
#     env_monitor, 
#     # ent_coef=0.01, # 增加策略寻找的鼓励，但是 suggestion 暂时不要改变
#     verbose=1,
#     )

model = DQN(
    "MlpPolicy", 
    env_monitor, 
    verbose=1,
    )

model.set_logger(new_logger) # set the parameter of the logger
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
# check 环境
from stable_baselines3.common.env_checker import check_env
# check_env(env_monitor)
log_name

print("Action space sample:", env.action_space.sample())
# print("Observation space sample:", env.observation_space.sample())

# type(env.action_space), type(env.observation_space)
print("Action space sample:", env.action_space.sample())
print("Observation space sample:", env.observation_space.sample())

print(model.policy)
# Out:
# Action space sample: 7
# Action space sample: 0
# Observation space sample: [ 0.85548031  0.24857056  0.39533634 -3.25939556  1.49192099  1.74656345
#   2.0473067  -0.69800766  1.52331342 -0.22991559]
# DQNPolicy(
#   (q_net): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=16, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=16, bias=True)
#     )
#   )
# )

# %% [markdown]
# ### 模型训练

# %%
def plot_callback_reward(metrics):
    """绘制训练过程中的奖励曲线
    
    Args:
        metrics (dict): 包含训练指标的字典，需要包含以下键：
            - rewards: 原始奖励列表
            - moving_avg_rewards: 移动平均奖励列表
            - moving_std_rewards: 移动标准差列表
            - episodes: 总回合数
            - step_idx: 当前步数
    """
    plt.figure(figsize=(20, 5))
    
    # 创建主图
    plt.subplot(131)
    plt.title(f'Step: {metrics["step_idx"]}, Latest reward: {metrics["rewards"][-1]:.2f}\n'
              f'Episode: {metrics["episodes"]}, Moving avg: {metrics["moving_avg_rewards"][-1]:.2f}')
    
    # 绘制原始奖励
    episodes = range(len(metrics["rewards"]))
    plt.plot(episodes, metrics["rewards"], 
             label='Raw rewards', color='gray', alpha=0.3)
    
    # 绘制移动平均
    plt.plot(episodes, metrics["moving_avg_rewards"],
             label='Moving average', color='blue', linewidth=2)
    
    # 添加标准差区域
    moving_avg = np.array(metrics["moving_avg_rewards"])
    moving_std = np.array(metrics["moving_std_rewards"])
    
    # 0.25倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.25 * moving_std,
                    moving_avg + 0.25 * moving_std,
                    color='b', alpha=0.1,
                    label='0.25 std range')
    
    # 0.5倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.5 * moving_std,
                    moving_avg + 0.5 * moving_std,
                    color='b', alpha=0.1,
                    label='0.5 std range')
    
    # 设置坐标轴和标签
    plt.xlabel('Episodes')
    plt.ylabel('Episode Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

class TrainingMonitorCallback(BaseCallback):
    def __init__(self, verbose=1, window_size=50):
        super().__init__(verbose)
        self.window_size = window_size
        # Initialize data dictionary to store metrics
        self.data = {
            "rewards": [],
            "moving_avg_rewards": [],
            "moving_std_rewards": [],
            "episodes": 0,
            "step_idx": 0
        }
        self.episode_rewards = 0
        
    def _on_step(self):
        # Accumulate rewards for current episode
        reward = self.locals.get('rewards')[0]
        self.episode_rewards += reward
        self.data["step_idx"] += 1
        
        # When episode ends, update all metrics
        if self.locals.get('dones')[0]:
            # Store raw reward
            self.data["rewards"].append(self.episode_rewards)
            
            # Calculate moving average and std
            recent_rewards = self.data["rewards"][-self.window_size:]
            moving_avg = np.mean(recent_rewards)
            moving_std = np.std(recent_rewards) if len(recent_rewards) > 1 else 0
            
            # Store calculated metrics
            self.data["moving_avg_rewards"].append(moving_avg)
            self.data["moving_std_rewards"].append(moving_std)
            self.data["episodes"] += 1
            
            # Print progress
            print(f"Episode {self.data['episodes']} finished with reward: {self.episode_rewards:.2f}")
            print(f"Moving average (last {len(recent_rewards)} episodes): {moving_avg:.2f} ± {moving_std:.2f}")
            
            # Reset episode rewards
            self.episode_rewards = 0
            
        return True
    
    def get_metrics(self):
        """Return the collected metrics"""
        return self.data
    
# Create callback with custom window size
callback = TrainingMonitorCallback(window_size=50)

# Train the model
model.learn(
    total_timesteps=int(total_timesteps_diy),
    callback=callback,
    log_interval=1
)


# After training, get metrics for plotting
metrics = callback.get_metrics()

# Plot rewards using the plot_callback_reward function
plot_callback_reward(metrics)
# Out:
# Episode 1 finished with reward: -128.33
# Moving average (last 1 episodes): -128.33 ± 0.00
# Episode 2 finished with reward: -74.86
# Moving average (last 2 episodes): -101.60 ± 26.74
# Episode 3 finished with reward: -11.52
# Moving average (last 3 episodes): -71.57 ± 47.75
# Episode 4 finished with reward: -67.25
# Moving average (last 4 episodes): -70.49 ± 41.39
# Episode 5 finished with reward: -53.02
# Moving average (last 5 episodes): -67.00 ± 37.68
# Episode 6 finished with reward: 8.11
# Moving average (last 6 episodes): -54.48 ± 44.34
# Episode 7 finished with reward: 25.52
# Moving average (last 7 episodes): -43.05 ± 49.69
# Episode 8 finished with reward: -43.21
# Moving average (last 8 episodes): -43.07 ± 46.48
# Episode 9 finished with reward: 1.26
# Moving average (last 9 episodes): -38.14 ± 45.99
# Episode 10 finished with reward: -102.93
# Moving average (last 10 episodes): -44.62 ± 47.76
# Episode 11 finished with reward: -83.61
# Moving average (last 11 episodes): -48.17 ± 46.90
# Episode 12 finished with reward: -45.26
# Moving average (last 12 episodes): -47.92 ± 44.91
# Episode 13 finished with reward: -91.03
# Moving average (last 13 episodes): -51.24 ± 44.65
# Episode 14 finished with reward: -39.21
# Moving average (last 14 episodes): -50.38 ± 43.13
# Episode 15 finished with reward: -44.29
# Moving average (last 15 episodes): -49.98 ± 41.70
# Episode 16 finished with reward: -16.41
# Moving average (last 16 episodes): -47.88 ± 41.18
# Episode 17 finished with reward: -96.51
# Moving average (last 17 episodes): -50.74 ± 41.56
# Episode 18 finished with reward: -28.98
# Moving average (last 18 episodes): -49.53 ± 40.70
# Episode 19 finished with reward: -60.51
# Moving average (last 19 episodes): -50.11 ± 39.69
# Episode 20 finished with reward: -53.36
# Moving average (last 20 episodes): -50.27 ± 38.69
# Episode 21 finished with reward: -29.58
# Moving average (last 21 episodes): -49.28 ± 38.01
# Episode 22 finished with reward: -48.66
# Moving average (last 22 episodes): -49.26 ± 37.14
# Episode 23 finished with reward: -45.50
# Moving average (last 23 episodes): -49.09 ± 36.33
# Episode 24 finished with reward: -33.19
# Moving average (last 24 episodes): -48.43 ± 35.71
# Episode 25 finished with reward: -11.59
# Moving average (last 25 episodes): -46.96 ± 35.72
# Episode 26 finished with reward: -121.24
# Moving average (last 26 episodes): -49.81 ± 37.83
# Episode 27 finished with reward: -64.36
# Moving average (last 27 episodes): -50.35 ± 37.22
# Episode 28 finished with reward: 5.50
# Moving average (last 28 episodes): -48.36 ± 37.99
# Episode 29 finished with reward: -84.81
# Moving average (last 29 episodes): -49.61 ± 37.92
# Episode 30 finished with reward: -41.54
# Moving average (last 30 episodes): -49.35 ± 37.31
# Episode 31 finished with reward: -69.75
# Moving average (last 31 episodes): -50.00 ± 36.88
# Episode 32 finished with reward: -8.40
# Moving average (last 32 episodes): -48.70 ± 37.02
# Episode 33 finished with reward: -45.41
# Moving average (last 33 episodes): -48.60 ± 36.46
# Episode 34 finished with reward: -53.39
# Moving average (last 34 episodes): -48.74 ± 35.92
# Episode 35 finished with reward: -65.57
# Moving average (last 35 episodes): -49.23 ± 35.52
# Episode 36 finished with reward: -24.22
# Moving average (last 36 episodes): -48.53 ± 35.26
# Episode 37 finished with reward: -47.13
# Moving average (last 37 episodes): -48.49 ± 34.78
# Episode 38 finished with reward: -40.02
# Moving average (last 38 episodes): -48.27 ± 34.35
# Episode 39 finished with reward: -76.90
# Moving average (last 39 episodes): -49.00 ± 34.21
# Episode 40 finished with reward: -36.04
# Moving average (last 40 episodes): -48.68 ± 33.84
# Episode 41 finished with reward: -91.85
# Moving average (last 41 episodes): -49.73 ± 34.08
# Episode 42 finished with reward: -66.20
# Moving average (last 42 episodes): -50.12 ± 33.76
# Episode 43 finished with reward: -59.35
# Moving average (last 43 episodes): -50.34 ± 33.40
# Episode 44 finished with reward: -27.18
# Moving average (last 44 episodes): -49.81 ± 33.20
# Episode 45 finished with reward: -60.41
# Moving average (last 45 episodes): -50.05 ± 32.86
# Episode 46 finished with reward: -55.76
# Moving average (last 46 episodes): -50.17 ± 32.51
# Episode 47 finished with reward: -95.81
# Moving average (last 47 episodes): -51.14 ± 32.83
# Episode 48 finished with reward: -91.75
# Moving average (last 48 episodes): -51.99 ± 33.00
# Episode 49 finished with reward: 2.83
# Moving average (last 49 episodes): -50.87 ± 33.57
# Episode 50 finished with reward: -38.06
# Moving average (last 50 episodes): -50.61 ± 33.28
# Episode 51 finished with reward: -59.37
# Moving average (last 50 episodes): -49.24 ± 31.41
# Episode 52 finished with reward: -17.32
# Moving average (last 50 episodes): -48.08 ± 31.50
# Episode 53 finished with reward: -67.00
# Moving average (last 50 episodes): -49.19 ± 31.17
# Episode 54 finished with reward: -69.97
# Moving average (last 50 episodes): -49.25 ± 31.21
# Episode 55 finished with reward: -91.97
# Moving average (last 50 episodes): -50.03 ± 31.77
# Episode 56 finished with reward: -56.35
# Moving average (last 50 episodes): -51.32 ± 30.67
# Episode 57 finished with reward: -65.36
# Moving average (last 50 episodes): -53.13 ± 28.70
# Episode 58 finished with reward: -72.69
# Moving average (last 50 episodes): -53.72 ± 28.79
# Episode 59 finished with reward: -50.54
# Moving average (last 50 episodes): -54.76 ± 27.70
# Episode 60 finished with reward: -54.23
# Moving average (last 50 episodes): -53.79 ± 26.84
# Episode 61 finished with reward: -60.68
# Moving average (last 50 episodes): -53.33 ± 26.52
# Episode 62 finished with reward: -52.74
# Moving average (last 50 episodes): -53.48 ± 26.49
# Episode 63 finished with reward: -54.17
# Moving average (last 50 episodes): -52.74 ± 25.94
# Episode 64 finished with reward: -68.04
# Moving average (last 50 episodes): -53.32 ± 25.96
# Episode 65 finished with reward: -60.68
# Moving average (last 50 episodes): -53.64 ± 25.94
# Episode 66 finished with reward: -57.67
# Moving average (last 50 episodes): -54.47 ± 25.40
# Episode 67 finished with reward: -127.28
# Moving average (last 50 episodes): -55.08 ± 26.74
# Episode 68 finished with reward: -35.27
# Moving average (last 50 episodes): -55.21 ± 26.64
# Episode 69 finished with reward: -40.43
# Moving average (last 50 episodes): -54.81 ± 26.70
# Episode 70 finished with reward: -43.18
# Moving average (last 50 episodes): -54.61 ± 26.75
# Episode 71 finished with reward: -20.06
# Moving average (last 50 episodes): -54.41 ± 26.96
# Episode 72 finished with reward: -57.14
# Moving average (last 50 episodes): -54.58 ± 26.95
# Episode 73 finished with reward: -24.58
# Moving average (last 50 episodes): -54.17 ± 27.25
# Episode 74 finished with reward: -50.24
# Moving average (last 50 episodes): -54.51 ± 27.09
# Episode 75 finished with reward: -26.35
# Moving average (last 50 episodes): -54.80 ± 26.70
# Episode 76 finished with reward: -69.47
# Moving average (last 50 episodes): -53.77 ± 25.06
# Episode 77 finished with reward: -54.15
# Moving average (last 50 episodes): -53.56 ± 25.01
# Episode 78 finished with reward: -32.16
# Moving average (last 50 episodes): -54.32 ± 23.76
# Episode 79 finished with reward: -39.57
# Moving average (last 50 episodes): -53.41 ± 23.44
# Episode 80 finished with reward: -64.41
# Moving average (last 50 episodes): -53.87 ± 23.43
# Episode 81 finished with reward: -32.44
# Moving average (last 50 episodes): -53.12 ± 23.50
# Episode 82 finished with reward: -47.76
# Moving average (last 50 episodes): -53.91 ± 22.63
# Episode 83 finished with reward: -35.45
# Moving average (last 50 episodes): -53.71 ± 22.75
# Episode 84 finished with reward: -45.40
# Moving average (last 50 episodes): -53.55 ± 22.78
# Episode 85 finished with reward: -32.92
# Moving average (last 50 episodes): -52.90 ± 22.90
# Episode 86 finished with reward: 15.45
# Moving average (last 50 episodes): -52.10 ± 24.51
# Episode 87 finished with reward: -24.04
# Moving average (last 50 episodes): -51.64 ± 24.81
# Episode 88 finished with reward: -13.40
# Moving average (last 50 episodes): -51.11 ± 25.33
# Episode 89 finished with reward: -71.57
# Moving average (last 50 episodes): -51.00 ± 25.24
# Episode 90 finished with reward: -13.91
# Moving average (last 50 episodes): -50.56 ± 25.69
# Episode 91 finished with reward: -37.98
# Moving average (last 50 episodes): -49.48 ± 25.05
# Episode 92 finished with reward: -54.02
# Moving average (last 50 episodes): -49.24 ± 24.95
# Episode 93 finished with reward: -80.59
# Moving average (last 50 episodes): -49.66 ± 25.30
# Episode 94 finished with reward: -76.42
# Moving average (last 50 episodes): -50.65 ± 25.36
# Episode 95 finished with reward: -32.22
# Moving average (last 50 episodes): -50.09 ± 25.45
# Episode 96 finished with reward: 20.84
# Moving average (last 50 episodes): -48.55 ± 27.30
# Episode 97 finished with reward: -87.16
# Moving average (last 50 episodes): -48.38 ± 27.03
# Episode 98 finished with reward: -82.43
# Moving average (last 50 episodes): -48.19 ± 26.76
# Episode 99 finished with reward: -38.42
# Moving average (last 50 episodes): -49.02 ± 25.79
# Episode 100 finished with reward: -43.75
# Moving average (last 50 episodes): -49.13 ± 25.75
# Episode 101 finished with reward: -49.57
# Moving average (last 50 episodes): -48.94 ± 25.71
# Episode 102 finished with reward: -77.71
# Moving average (last 50 episodes): -50.14 ± 25.62
# Episode 103 finished with reward: -9.97
# Moving average (last 50 episodes): -49.00 ± 26.11
# Episode 104 finished with reward: -30.57
# Moving average (last 50 episodes): -48.22 ± 26.06
# Episode 105 finished with reward: -78.98
# Moving average (last 50 episodes): -47.96 ± 25.68
# Episode 106 finished with reward: 24.68
# Moving average (last 50 episodes): -46.34 ± 27.59
# Episode 107 finished with reward: -35.97
# Moving average (last 50 episodes): -45.75 ± 27.49
# Episode 108 finished with reward: -37.82
# Moving average (last 50 episodes): -45.05 ± 27.24
# Episode 109 finished with reward: -46.69
# Moving average (last 50 episodes): -44.97 ± 27.23
# Episode 110 finished with reward: -23.19
# Moving average (last 50 episodes): -44.35 ± 27.36
# Episode 111 finished with reward: -31.71
# Moving average (last 50 episodes): -43.77 ± 27.32
# Episode 112 finished with reward: -28.51
# Moving average (last 50 episodes): -43.29 ± 27.37
# Episode 113 finished with reward: -1.92
# Moving average (last 50 episodes): -42.24 ± 27.92
# Episode 114 finished with reward: 54.31
# Moving average (last 50 episodes): -39.80 ± 30.77
# Episode 115 finished with reward: -66.00
# Moving average (last 50 episodes): -39.90 ± 30.85
# Episode 116 finished with reward: -46.84
# Moving average (last 50 episodes): -39.69 ± 30.77
# Episode 117 finished with reward: 2.77
# Moving average (last 50 episodes): -37.09 ± 28.68
# Episode 118 finished with reward: -50.39
# Moving average (last 50 episodes): -37.39 ± 28.74
# Episode 119 finished with reward: -35.54
# Moving average (last 50 episodes): -37.29 ± 28.73
# Episode 120 finished with reward: -53.01
# Moving average (last 50 episodes): -37.49 ± 28.81
# Episode 121 finished with reward: 0.46
# Moving average (last 50 episodes): -37.08 ± 29.20
# Episode 122 finished with reward: 1.61
# Moving average (last 50 episodes): -35.90 ± 29.54
# Episode 123 finished with reward: -38.07
# Moving average (last 50 episodes): -36.17 ± 29.50
# Episode 124 finished with reward: -73.65
# Moving average (last 50 episodes): -36.64 ± 29.90
# Episode 125 finished with reward: -33.95
# Moving average (last 50 episodes): -36.79 ± 29.87
# Episode 126 finished with reward: -23.80
# Moving average (last 50 episodes): -35.88 ± 29.55
# Episode 127 finished with reward: -59.29
# Moving average (last 50 episodes): -35.98 ± 29.63
# Episode 128 finished with reward: -2.32
# Moving average (last 50 episodes): -35.38 ± 30.00
# Episode 129 finished with reward: -43.34
# Moving average (last 50 episodes): -35.46 ± 30.01
# Episode 130 finished with reward: -29.61
# Moving average (last 50 episodes): -34.76 ± 29.73
# Episode 131 finished with reward: -18.31
# Moving average (last 50 episodes): -34.48 ± 29.82
# Episode 132 finished with reward: -98.95
# Moving average (last 50 episodes): -35.50 ± 31.11
# Episode 133 finished with reward: -55.07
# Moving average (last 50 episodes): -35.90 ± 31.23
# Episode 134 finished with reward: -33.78
# Moving average (last 50 episodes): -35.66 ± 31.20
# Episode 135 finished with reward: -27.00
# Moving average (last 50 episodes): -35.55 ± 31.22
# Episode 136 finished with reward: -34.63
# Moving average (last 50 episodes): -36.55 ± 30.36
# Episode 137 finished with reward: -10.97
# Moving average (last 50 episodes): -36.29 ± 30.53
# Episode 138 finished with reward: -54.57
# Moving average (last 50 episodes): -37.11 ± 30.45
# Episode 139 finished with reward: -130.64
# Moving average (last 50 episodes): -38.29 ± 32.82
# Episode 140 finished with reward: -17.70
# Moving average (last 50 episodes): -38.37 ± 32.77
# Episode 141 finished with reward: -66.05
# Moving average (last 50 episodes): -38.93 ± 33.00
# Episode 142 finished with reward: -67.48
# Moving average (last 50 episodes): -39.20 ± 33.17
# Episode 143 finished with reward: -63.74
# Moving average (last 50 episodes): -38.86 ± 32.83
# Episode 144 finished with reward: -80.39
# Moving average (last 50 episodes): -38.94 ± 32.93
# Episode 145 finished with reward: -55.77
# Moving average (last 50 episodes): -39.41 ± 33.00
# Episode 146 finished with reward: -31.70
# Moving average (last 50 episodes): -40.46 ± 31.88
# Episode 147 finished with reward: -43.78
# Moving average (last 50 episodes): -39.59 ± 31.18
# Episode 148 finished with reward: -79.92
# Moving average (last 50 episodes): -39.54 ± 31.11
# Episode 149 finished with reward: -28.06
# Moving average (last 50 episodes): -39.34 ± 31.15
# Episode 150 finished with reward: -76.59
# Moving average (last 50 episodes): -39.99 ± 31.58
# Episode 151 finished with reward: -16.55
# Moving average (last 50 episodes): -39.33 ± 31.72
# Episode 152 finished with reward: -77.86
# Moving average (last 50 episodes): -39.34 ± 31.73
# Episode 153 finished with reward: -89.26
# Moving average (last 50 episodes): -40.92 ± 32.20
# Episode 154 finished with reward: -43.40
# Moving average (last 50 episodes): -41.18 ± 32.16
# Episode 155 finished with reward: -128.88
# Moving average (last 50 episodes): -42.18 ± 34.04
# Episode 156 finished with reward: -69.02
# Moving average (last 50 episodes): -44.05 ± 32.87
# Episode 157 finished with reward: -46.28
# Moving average (last 50 episodes): -44.26 ± 32.85
# Episode 158 finished with reward: -22.06
# Moving average (last 50 episodes): -43.94 ± 32.98
# Episode 159 finished with reward: -60.41
# Moving average (last 50 episodes): -44.22 ± 33.06
# Episode 160 finished with reward: -43.00
# Moving average (last 50 episodes): -44.61 ± 32.93
# Episode 161 finished with reward: -78.56
# Moving average (last 50 episodes): -45.55 ± 33.21
# Episode 162 finished with reward: -102.77
# Moving average (last 50 episodes): -47.03 ± 34.07
# Episode 163 finished with reward: -60.00
# Moving average (last 50 episodes): -48.20 ± 33.49
# Episode 164 finished with reward: -8.53
# Moving average (last 50 episodes): -49.45 ± 30.68
# Episode 165 finished with reward: -113.42
# Moving average (last 50 episodes): -50.40 ± 31.89
# Episode 166 finished with reward: -28.83
# Moving average (last 50 episodes): -50.04 ± 32.03
# Episode 167 finished with reward: -9.87
# Moving average (last 50 episodes): -50.29 ± 31.66
# Episode 168 finished with reward: -43.07
# Moving average (last 50 episodes): -50.15 ± 31.68
# Episode 169 finished with reward: -41.65
# Moving average (last 50 episodes): -50.27 ± 31.63
# Episode 170 finished with reward: -62.81
# Moving average (last 50 episodes): -50.47 ± 31.68
# Episode 171 finished with reward: -27.08
# Moving average (last 50 episodes): -51.02 ± 31.02
# Episode 172 finished with reward: -75.57
# Moving average (last 50 episodes): -52.56 ± 30.27
# Episode 173 finished with reward: -44.86
# Moving average (last 50 episodes): -52.70 ± 30.22
# Episode 174 finished with reward: -28.33
# Moving average (last 50 episodes): -51.79 ± 30.26
# Episode 175 finished with reward: -79.56
# Moving average (last 50 episodes): -52.70 ± 30.40
# Episode 176 finished with reward: -49.87
# Moving average (last 50 episodes): -53.22 ± 30.12
# Episode 177 finished with reward: -59.05
# Moving average (last 50 episodes): -53.22 ± 30.12
# Episode 178 finished with reward: 12.27
# Moving average (last 50 episodes): -52.93 ± 30.67
# Episode 179 finished with reward: -17.03
# Moving average (last 50 episodes): -52.40 ± 31.06
# Episode 180 finished with reward: -51.07
# Moving average (last 50 episodes): -52.83 ± 30.89
# Episode 181 finished with reward: -34.89
# Moving average (last 50 episodes): -53.16 ± 30.60
# Episode 182 finished with reward: 23.27
# Moving average (last 50 episodes): -50.72 ± 31.71
# Episode 183 finished with reward: -41.01
# Moving average (last 50 episodes): -50.44 ± 31.73
# Episode 184 finished with reward: -28.74
# Moving average (last 50 episodes): -50.34 ± 31.79
# Episode 185 finished with reward: -41.19
# Moving average (last 50 episodes): -50.62 ± 31.65
# Episode 186 finished with reward: -31.43
# Moving average (last 50 episodes): -50.56 ± 31.68
# Episode 187 finished with reward: -53.37
# Moving average (last 50 episodes): -51.40 ± 31.17
# Episode 188 finished with reward: -78.40
# Moving average (last 50 episodes): -51.88 ± 31.40
# Episode 189 finished with reward: -90.60
# Moving average (last 50 episodes): -51.08 ± 29.85
# Episode 190 finished with reward: -69.07
# Moving average (last 50 episodes): -52.11 ± 29.57
# Episode 191 finished with reward: -25.64
# Moving average (last 50 episodes): -51.30 ± 29.73
# Episode 192 finished with reward: -40.50
# Moving average (last 50 episodes): -50.76 ± 29.68
# Episode 193 finished with reward: 12.14
# Moving average (last 50 episodes): -49.24 ± 30.89
# Episode 194 finished with reward: -64.56
# Moving average (last 50 episodes): -48.92 ± 30.65
# Episode 195 finished with reward: -62.12
# Moving average (last 50 episodes): -49.05 ± 30.69
# Episode 196 finished with reward: -70.86
# Moving average (last 50 episodes): -49.83 ± 30.74
# Episode 197 finished with reward: -87.55
# Moving average (last 50 episodes): -50.71 ± 31.17
# Episode 198 finished with reward: -8.95
# Moving average (last 50 episodes): -49.29 ± 31.42
# Episode 199 finished with reward: -94.17
# Moving average (last 50 episodes): -50.61 ± 31.89
# Episode 200 finished with reward: -42.05
# Moving average (last 50 episodes): -49.92 ± 31.69
# Episode 201 finished with reward: -33.00
# Moving average (last 50 episodes): -50.25 ± 31.43
# Episode 202 finished with reward: -79.78
# Moving average (last 50 episodes): -50.29 ± 31.46
# Episode 203 finished with reward: -46.81
# Moving average (last 50 episodes): -49.44 ± 30.97
# Episode 204 finished with reward: -55.73
# Moving average (last 50 episodes): -49.69 ± 30.97
# Episode 205 finished with reward: 2.92
# Moving average (last 50 episodes): -47.05 ± 29.70
# Episode 206 finished with reward: -34.03
# Moving average (last 50 episodes): -46.35 ± 29.59
# Episode 207 finished with reward: -90.60
# Moving average (last 50 episodes): -47.24 ± 30.23
# Episode 208 finished with reward: -67.24
# Moving average (last 50 episodes): -48.14 ± 30.14
# Episode 209 finished with reward: -55.73
# Moving average (last 50 episodes): -48.05 ± 30.11
# Episode 210 finished with reward: -80.49
# Moving average (last 50 episodes): -48.80 ± 30.44
# Episode 211 finished with reward: 2.89
# Moving average (last 50 episodes): -47.17 ± 30.97
# Episode 212 finished with reward: -67.03
# Moving average (last 50 episodes): -46.45 ± 30.08
# Episode 213 finished with reward: -44.08
# Moving average (last 50 episodes): -46.14 ± 30.02
# Episode 214 finished with reward: -33.63
# Moving average (last 50 episodes): -46.64 ± 29.60
# Episode 215 finished with reward: -16.03
# Moving average (last 50 episodes): -44.69 ± 28.31
# Episode 216 finished with reward: -49.34
# Moving average (last 50 episodes): -45.10 ± 28.23
# Episode 217 finished with reward: 6.27
# Moving average (last 50 episodes): -44.78 ± 28.72
# Episode 218 finished with reward: -42.46
# Moving average (last 50 episodes): -44.77 ± 28.72
# Episode 219 finished with reward: -95.20
# Moving average (last 50 episodes): -45.84 ± 29.57
# Episode 220 finished with reward: -32.03
# Moving average (last 50 episodes): -45.22 ± 29.53
# Episode 221 finished with reward: -19.90
# Moving average (last 50 episodes): -45.08 ± 29.64
# Episode 222 finished with reward: -27.49
# Moving average (last 50 episodes): -44.12 ± 29.41
# Episode 223 finished with reward: -117.68
# Moving average (last 50 episodes): -45.57 ± 31.16
# Episode 224 finished with reward: -48.26
# Moving average (last 50 episodes): -45.97 ± 31.06
# Episode 225 finished with reward: 36.59
# Moving average (last 50 episodes): -43.65 ± 32.76
# Episode 226 finished with reward: -22.84
# Moving average (last 50 episodes): -43.11 ± 32.88
# Episode 227 finished with reward: 23.13
# Moving average (last 50 episodes): -41.46 ± 34.07
# Episode 228 finished with reward: -85.64
# Moving average (last 50 episodes): -43.42 ± 33.74
# Episode 229 finished with reward: -48.13
# Moving average (last 50 episodes): -44.04 ± 33.53
# Episode 230 finished with reward: -25.39
# Moving average (last 50 episodes): -43.53 ± 33.62
# Episode 231 finished with reward: -37.23
# Moving average (last 50 episodes): -43.58 ± 33.61
# Episode 232 finished with reward: -11.73
# Moving average (last 50 episodes): -44.28 ± 32.56
# Episode 233 finished with reward: -52.51
# Moving average (last 50 episodes): -44.51 ± 32.57
# Episode 234 finished with reward: -19.22
# Moving average (last 50 episodes): -44.32 ± 32.69
# Episode 235 finished with reward: -43.64
# Moving average (last 50 episodes): -44.36 ± 32.69
# Episode 236 finished with reward: -33.79
# Moving average (last 50 episodes): -44.41 ± 32.67
# Episode 237 finished with reward: -51.20
# Moving average (last 50 episodes): -44.37 ± 32.66
# Episode 238 finished with reward: -20.96
# Moving average (last 50 episodes): -43.22 ± 32.45
# Episode 239 finished with reward: -84.18
# Moving average (last 50 episodes): -43.09 ± 32.28
# Episode 240 finished with reward: -18.35
# Moving average (last 50 episodes): -42.08 ± 32.24
# Episode 241 finished with reward: -64.46
# Moving average (last 50 episodes): -42.85 ± 32.31
# Episode 242 finished with reward: -23.00
# Moving average (last 50 episodes): -42.50 ± 32.42
# Episode 243 finished with reward: -58.63
# Moving average (last 50 episodes): -43.92 ± 31.54
# Episode 244 finished with reward: -51.42
# Moving average (last 50 episodes): -43.66 ± 31.42
# Episode 245 finished with reward: -26.56
# Moving average (last 50 episodes): -42.94 ± 31.40
# Episode 246 finished with reward: -83.38
# Moving average (last 50 episodes): -43.19 ± 31.67
# Episode 247 finished with reward: -13.46
# Moving average (last 50 episodes): -41.71 ± 31.29
# Episode 248 finished with reward: -43.56
# Moving average (last 50 episodes): -42.40 ± 30.94
# Episode 249 finished with reward: -71.99
# Moving average (last 50 episodes): -41.96 ± 30.35
# Episode 250 finished with reward: 65.01
# Moving average (last 50 episodes): -39.82 ± 33.84
# Episode 251 finished with reward: 0.77
# Moving average (last 50 episodes): -39.14 ± 34.30
# Episode 252 finished with reward: -13.70
# Moving average (last 50 episodes): -37.82 ± 33.98
# Episode 253 finished with reward: -64.44
# Moving average (last 50 episodes): -38.18 ± 34.17
# Episode 254 finished with reward: -55.85
# Moving average (last 50 episodes): -38.18 ± 34.17
# Episode 255 finished with reward: -39.10
# Moving average (last 50 episodes): -39.02 ± 33.66
# Episode 256 finished with reward: -20.29
# Moving average (last 50 episodes): -38.74 ± 33.76
# Episode 257 finished with reward: -75.93
# Moving average (last 50 episodes): -38.45 ± 33.36
# Episode 258 finished with reward: -14.55
# Moving average (last 50 episodes): -37.40 ± 33.27
# Episode 259 finished with reward: -38.73
# Moving average (last 50 episodes): -37.06 ± 33.17
# Episode 260 finished with reward: -20.12
# Moving average (last 50 episodes): -35.85 ± 32.66
# Episode 261 finished with reward: -34.89
# Moving average (last 50 episodes): -36.60 ± 32.19
# Episode 262 finished with reward: -6.98
# Moving average (last 50 episodes): -35.40 ± 32.15
# Episode 263 finished with reward: -111.71
# Moving average (last 50 episodes): -36.76 ± 33.86
# Episode 264 finished with reward: -15.29
# Moving average (last 50 episodes): -36.39 ± 34.00
# Episode 265 finished with reward: -69.04
# Moving average (last 50 episodes): -37.45 ± 34.17
# Episode 266 finished with reward: -35.79
# Moving average (last 50 episodes): -37.18 ± 34.13
# Episode 267 finished with reward: -37.78
# Moving average (last 50 episodes): -38.06 ± 33.56
# Episode 268 finished with reward: -11.20
# Moving average (last 50 episodes): -37.43 ± 33.76
# Episode 269 finished with reward: -116.45
# Moving average (last 50 episodes): -37.86 ± 34.61
# Episode 270 finished with reward: -7.34
# Moving average (last 50 episodes): -37.37 ± 34.86
# Episode 271 finished with reward: -86.58
# Moving average (last 50 episodes): -38.70 ± 35.44
# Episode 272 finished with reward: -115.08
# Moving average (last 50 episodes): -40.45 ± 36.98
# Episode 273 finished with reward: -115.03
# Moving average (last 50 episodes): -40.40 ± 36.87
# Episode 274 finished with reward: -39.21
# Moving average (last 50 episodes): -40.22 ± 36.85
# Episode 275 finished with reward: 18.12
# Moving average (last 50 episodes): -40.59 ± 36.16
# Episode 276 finished with reward: -64.57
# Moving average (last 50 episodes): -41.42 ± 36.23
# Episode 277 finished with reward: -3.93
# Moving average (last 50 episodes): -41.96 ± 35.45
# Episode 278 finished with reward: -43.08
# Moving average (last 50 episodes): -41.11 ± 34.90
# Episode 279 finished with reward: -40.85
# Moving average (last 50 episodes): -40.97 ± 34.89
# Episode 280 finished with reward: -33.66
# Moving average (last 50 episodes): -41.13 ± 34.83
# Episode 281 finished with reward: -40.24
# Moving average (last 50 episodes): -41.19 ± 34.83
# Episode 282 finished with reward: -66.90
# Moving average (last 50 episodes): -42.30 ± 34.75
# Episode 283 finished with reward: -64.71
# Moving average (last 50 episodes): -42.54 ± 34.86
# Episode 284 finished with reward: -22.25
# Moving average (last 50 episodes): -42.60 ± 34.83
# Episode 285 finished with reward: -101.94
# Moving average (last 50 episodes): -43.77 ± 35.80
# Episode 286 finished with reward: -42.54
# Moving average (last 50 episodes): -43.94 ± 35.78
# Episode 287 finished with reward: 25.11
# Moving average (last 50 episodes): -42.41 ± 37.04
# Episode 288 finished with reward: -65.63
# Moving average (last 50 episodes): -43.31 ± 37.05
# Episode 289 finished with reward: -53.11
# Moving average (last 50 episodes): -42.69 ± 36.62
# Episode 290 finished with reward: 25.69
# Moving average (last 50 episodes): -41.81 ± 37.70
# Episode 291 finished with reward: -32.43
# Moving average (last 50 episodes): -41.16 ± 37.59
# Episode 292 finished with reward: 15.61
# Moving average (last 50 episodes): -40.39 ± 38.34
# Episode 293 finished with reward: -59.68
# Moving average (last 50 episodes): -40.41 ± 38.35
# Episode 294 finished with reward: -39.05
# Moving average (last 50 episodes): -40.17 ± 38.32
# Episode 295 finished with reward: -89.20
# Moving average (last 50 episodes): -41.42 ± 38.87
# Episode 296 finished with reward: -43.72
# Moving average (last 50 episodes): -40.63 ± 38.41
# Episode 297 finished with reward: -76.83
# Moving average (last 50 episodes): -41.89 ± 38.54
# Episode 298 finished with reward: -86.99
# Moving average (last 50 episodes): -42.76 ± 39.05
# Episode 299 finished with reward: -124.11
# Moving average (last 50 episodes): -43.80 ± 40.49
# Episode 300 finished with reward: -107.07
# Moving average (last 50 episodes): -47.25 ± 38.35
# Episode 301 finished with reward: -59.28
# Moving average (last 50 episodes): -48.45 ± 37.76
# Episode 302 finished with reward: -62.08
# Moving average (last 50 episodes): -49.41 ± 37.48
# Episode 303 finished with reward: -38.09
# Moving average (last 50 episodes): -48.89 ± 37.45
# Episode 304 finished with reward: -63.22
# Moving average (last 50 episodes): -49.03 ± 37.49
# Episode 305 finished with reward: -22.31
# Moving average (last 50 episodes): -48.70 ± 37.65
# Episode 306 finished with reward: -28.97
# Moving average (last 50 episodes): -48.87 ± 37.54
# Episode 307 finished with reward: -73.72
# Moving average (last 50 episodes): -48.83 ± 37.51
# Episode 308 finished with reward: -83.68
# Moving average (last 50 episodes): -50.21 ± 37.50
# Episode 309 finished with reward: -58.19
# Moving average (last 50 episodes): -50.60 ± 37.48
# Episode 310 finished with reward: -29.39
# Moving average (last 50 episodes): -50.79 ± 37.35
# Episode 311 finished with reward: -55.66
# Moving average (last 50 episodes): -51.20 ± 37.28
# Episode 312 finished with reward: -2.27
# Moving average (last 50 episodes): -51.11 ± 37.40
# Episode 313 finished with reward: -39.51
# Moving average (last 50 episodes): -49.66 ± 36.41
# Episode 314 finished with reward: -63.38
# Moving average (last 50 episodes): -50.62 ± 36.13
# Episode 315 finished with reward: -78.26
# Moving average (last 50 episodes): -50.81 ± 36.24
# Episode 316 finished with reward: -33.41
# Moving average (last 50 episodes): -50.76 ± 36.27
# Episode 317 finished with reward: -114.22
# Moving average (last 50 episodes): -52.29 ± 37.28
# Episode 318 finished with reward: -30.05
# Moving average (last 50 episodes): -52.67 ± 36.96
# Episode 319 finished with reward: -75.37
# Moving average (last 50 episodes): -51.85 ± 35.98
# Episode 320 finished with reward: -32.37
# Moving average (last 50 episodes): -52.35 ± 35.52
# Episode 321 finished with reward: -62.06
# Moving average (last 50 episodes): -51.86 ± 35.22
# Episode 322 finished with reward: -45.75
# Moving average (last 50 episodes): -50.47 ± 34.04
# Episode 323 finished with reward: -45.75
# Moving average (last 50 episodes): -49.08 ± 32.77
# Episode 324 finished with reward: -78.05
# Moving average (last 50 episodes): -49.86 ± 32.99
# Episode 325 finished with reward: -19.31
# Moving average (last 50 episodes): -50.61 ± 31.84
# Episode 326 finished with reward: -73.32
# Moving average (last 50 episodes): -50.78 ± 31.95
# Episode 327 finished with reward: -72.49
# Moving average (last 50 episodes): -52.15 ± 31.37
# Episode 328 finished with reward: -37.29
# Moving average (last 50 episodes): -52.04 ± 31.41
# Episode 329 finished with reward: 4.16
# Moving average (last 50 episodes): -51.14 ± 32.35
# Episode 330 finished with reward: -80.46
# Moving average (last 50 episodes): -52.07 ± 32.51
# Episode 331 finished with reward: -28.68
# Moving average (last 50 episodes): -51.84 ± 32.63
# Episode 332 finished with reward: -31.03
# Moving average (last 50 episodes): -51.13 ± 32.69
# Episode 333 finished with reward: 31.88
# Moving average (last 50 episodes): -49.19 ± 34.63
# Episode 334 finished with reward: -57.70
# Moving average (last 50 episodes): -49.90 ± 34.43
# Episode 335 finished with reward: -35.82
# Moving average (last 50 episodes): -48.58 ± 33.67
# Episode 336 finished with reward: -99.58
# Moving average (last 50 episodes): -49.72 ± 34.40
# Episode 337 finished with reward: 24.84
# Moving average (last 50 episodes): -49.73 ± 34.39
# Episode 338 finished with reward: -48.23
# Moving average (last 50 episodes): -49.38 ± 34.32
# Episode 339 finished with reward: -50.17
# Moving average (last 50 episodes): -49.32 ± 34.31
# Episode 340 finished with reward: -65.17
# Moving average (last 50 episodes): -51.14 ± 32.66
# Episode 341 finished with reward: 76.38
# Moving average (last 50 episodes): -48.96 ± 37.15
# Episode 342 finished with reward: -46.18
# Moving average (last 50 episodes): -50.20 ± 35.99
# Episode 343 finished with reward: -61.23
# Moving average (last 50 episodes): -50.23 ± 36.00
# Episode 344 finished with reward: -43.66
# Moving average (last 50 episodes): -50.32 ± 35.98
# Episode 345 finished with reward: -77.65
# Moving average (last 50 episodes): -50.09 ± 35.76
# Episode 346 finished with reward: -43.18
# Moving average (last 50 episodes): -50.08 ± 35.76
# Episode 347 finished with reward: -97.56
# Moving average (last 50 episodes): -50.49 ± 36.19
# Episode 348 finished with reward: -75.19
# Moving average (last 50 episodes): -50.26 ± 35.99
# Episode 349 finished with reward: -66.91
# Moving average (last 50 episodes): -49.11 ± 34.50
# Episode 350 finished with reward: 1.21
# Moving average (last 50 episodes): -46.95 ± 34.19
# Episode 351 finished with reward: -24.46
# Moving average (last 50 episodes): -46.25 ± 34.29
# Episode 352 finished with reward: -48.05
# Moving average (last 50 episodes): -45.97 ± 34.21
# Episode 353 finished with reward: -22.07
# Moving average (last 50 episodes): -45.65 ± 34.36
# Episode 354 finished with reward: -66.19
# Moving average (last 50 episodes): -45.71 ± 34.39
# Episode 355 finished with reward: -6.59
# Moving average (last 50 episodes): -45.40 ± 34.68
# Episode 356 finished with reward: 17.25
# Moving average (last 50 episodes): -44.47 ± 35.70
# Episode 357 finished with reward: 55.39
# Moving average (last 50 episodes): -41.89 ± 38.08
# Episode 358 finished with reward: -37.47
# Moving average (last 50 episodes): -40.96 ± 37.62
# Episode 359 finished with reward: 38.70
# Moving average (last 50 episodes): -39.03 ± 39.14
# Episode 360 finished with reward: -14.20
# Moving average (last 50 episodes): -38.72 ± 39.28
# Episode 361 finished with reward: -46.12
# Moving average (last 50 episodes): -38.53 ± 39.22
# Episode 362 finished with reward: -29.90
# Moving average (last 50 episodes): -39.08 ± 38.90
# Episode 363 finished with reward: -91.85
# Moving average (last 50 episodes): -40.13 ± 39.59
# Episode 364 finished with reward: -137.41
# Moving average (last 50 episodes): -41.61 ± 41.76
# Episode 365 finished with reward: -33.67
# Moving average (last 50 episodes): -40.72 ± 41.44
# Episode 366 finished with reward: -39.60
# Moving average (last 50 episodes): -40.84 ± 41.43
# Episode 367 finished with reward: -88.12
# Moving average (last 50 episodes): -40.32 ± 40.66
# Episode 368 finished with reward: -53.18
# Moving average (last 50 episodes): -40.78 ± 40.67
# Episode 369 finished with reward: -59.28
# Moving average (last 50 episodes): -40.46 ± 40.46
# Episode 370 finished with reward: -67.70
# Moving average (last 50 episodes): -41.17 ± 40.62
# Episode 371 finished with reward: 28.18
# Moving average (last 50 episodes): -39.36 ± 41.64
# Episode 372 finished with reward: -24.13
# Moving average (last 50 episodes): -38.93 ± 41.69
# Episode 373 finished with reward: -85.11
# Moving average (last 50 episodes): -39.72 ± 42.18
# Episode 374 finished with reward: -3.60
# Moving average (last 50 episodes): -38.23 ± 42.11
# Episode 375 finished with reward: -53.78
# Moving average (last 50 episodes): -38.92 ± 42.08
# Episode 376 finished with reward: 20.62
# Moving average (last 50 episodes): -37.04 ± 42.59
# Episode 377 finished with reward: -102.66
# Moving average (last 50 episodes): -37.64 ± 43.30
# Episode 378 finished with reward: -50.08
# Moving average (last 50 episodes): -37.90 ± 43.33
# Episode 379 finished with reward: -50.30
# Moving average (last 50 episodes): -38.99 ± 42.95
# Episode 380 finished with reward: -7.54
# Moving average (last 50 episodes): -37.53 ± 42.75
# Episode 381 finished with reward: -103.74
# Moving average (last 50 episodes): -39.03 ± 43.72
# Episode 382 finished with reward: -42.44
# Moving average (last 50 episodes): -39.26 ± 43.71
# Episode 383 finished with reward: -22.42
# Moving average (last 50 episodes): -40.35 ± 42.59
# Episode 384 finished with reward: -129.38
# Moving average (last 50 episodes): -41.78 ± 44.32
# Episode 385 finished with reward: -117.95
# Moving average (last 50 episodes): -43.42 ± 45.57
# Episode 386 finished with reward: -90.79
# Moving average (last 50 episodes): -43.25 ± 45.37
# Episode 387 finished with reward: -95.71
# Moving average (last 50 episodes): -45.66 ± 44.89
# Episode 388 finished with reward: -96.45
# Moving average (last 50 episodes): -46.62 ± 45.45
# Episode 389 finished with reward: -100.43
# Moving average (last 50 episodes): -47.63 ± 46.07
# Episode 390 finished with reward: -176.58
# Moving average (last 50 episodes): -49.86 ± 49.43
# Episode 391 finished with reward: -68.94
# Moving average (last 50 episodes): -52.76 ± 46.08
# Episode 392 finished with reward: -46.34
# Moving average (last 50 episodes): -52.76 ± 46.08
# Episode 393 finished with reward: -102.80
# Moving average (last 50 episodes): -53.60 ± 46.60
# Episode 394 finished with reward: -39.34
# Moving average (last 50 episodes): -53.51 ± 46.62
# Episode 395 finished with reward: -47.73
# Moving average (last 50 episodes): -52.91 ± 46.50
# Episode 396 finished with reward: -45.06
# Moving average (last 50 episodes): -52.95 ± 46.49
# Episode 397 finished with reward: -34.20
# Moving average (last 50 episodes): -51.68 ± 46.12
# Episode 398 finished with reward: -99.13
# Moving average (last 50 episodes): -52.16 ± 46.49
# Episode 399 finished with reward: -125.24
# Moving average (last 50 episodes): -53.33 ± 47.56
# Episode 400 finished with reward: -55.89
# Moving average (last 50 episodes): -54.47 ± 46.92
# Episode 401 finished with reward: -54.10
# Moving average (last 50 episodes): -55.06 ± 46.72
# Episode 402 finished with reward: -15.53
# Moving average (last 50 episodes): -54.41 ± 47.04
# Episode 403 finished with reward: -24.81
# Moving average (last 50 episodes): -54.47 ± 47.01
# Episode 404 finished with reward: -23.10
# Moving average (last 50 episodes): -53.60 ± 47.18
# Episode 405 finished with reward: -90.09
# Moving average (last 50 episodes): -55.27 ± 46.96
# Episode 406 finished with reward: -34.70
# Moving average (last 50 episodes): -56.31 ± 45.91
# Episode 407 finished with reward: -87.19
# Moving average (last 50 episodes): -59.17 ± 43.23
# Episode 408 finished with reward: -84.63
# Moving average (last 50 episodes): -60.11 ± 43.26
# Episode 409 finished with reward: -9.20
# Moving average (last 50 episodes): -61.07 ± 41.56
# Episode 410 finished with reward: -57.91
# Moving average (last 50 episodes): -61.94 ± 41.02
# Episode 411 finished with reward: -48.72
# Moving average (last 50 episodes): -61.99 ± 41.00
# Episode 412 finished with reward: -49.74
# Moving average (last 50 episodes): -62.39 ± 40.79
# Episode 413 finished with reward: -137.52
# Moving average (last 50 episodes): -63.30 ± 41.93
# Episode 414 finished with reward: -73.85
# Moving average (last 50 episodes): -62.03 ± 40.61
# Episode 415 finished with reward: -8.07
# Moving average (last 50 episodes): -61.52 ± 41.12
# Episode 416 finished with reward: -130.76
# Moving average (last 50 episodes): -63.34 ± 42.12
# Episode 417 finished with reward: -102.48
# Moving average (last 50 episodes): -63.63 ± 42.33
# Episode 418 finished with reward: -187.86
# Moving average (last 50 episodes): -66.32 ± 45.73
# Episode 419 finished with reward: -34.11
# Moving average (last 50 episodes): -65.82 ± 45.94
# Episode 420 finished with reward: 0.50
# Moving average (last 50 episodes): -64.46 ± 46.87
# Episode 421 finished with reward: -7.22
# Moving average (last 50 episodes): -65.16 ± 45.72
# Episode 422 finished with reward: -76.66
# Moving average (last 50 episodes): -66.21 ± 45.37
# Episode 423 finished with reward: -87.74
# Moving average (last 50 episodes): -66.27 ± 45.39
# Episode 424 finished with reward: -98.28
# Moving average (last 50 episodes): -68.16 ± 44.71
# Episode 425 finished with reward: -163.16
# Moving average (last 50 episodes): -70.35 ± 46.59
# Episode 426 finished with reward: -117.27
# Moving average (last 50 episodes): -73.11 ± 45.18
# Episode 427 finished with reward: -25.38
# Moving average (last 50 episodes): -71.56 ± 45.46
# Episode 428 finished with reward: -72.22
# Moving average (last 50 episodes): -72.00 ± 45.36
# Episode 429 finished with reward: -46.95
# Moving average (last 50 episodes): -71.94 ± 45.39
# Episode 430 finished with reward: -133.84
# Moving average (last 50 episodes): -74.46 ± 45.25
# Episode 431 finished with reward: -115.00
# Moving average (last 50 episodes): -74.69 ± 45.43
# Episode 432 finished with reward: -31.04
# Moving average (last 50 episodes): -74.46 ± 45.62
# Episode 433 finished with reward: -114.52
# Moving average (last 50 episodes): -76.30 ± 45.34
# Episode 434 finished with reward: -136.93
# Moving average (last 50 episodes): -76.45 ± 45.52
# Episode 435 finished with reward: -62.24
# Moving average (last 50 episodes): -75.34 ± 45.18
# Episode 436 finished with reward: -46.38
# Moving average (last 50 episodes): -74.45 ± 45.30
# Episode 437 finished with reward: -42.92
# Moving average (last 50 episodes): -73.39 ± 45.41
# Episode 438 finished with reward: -164.08
# Moving average (last 50 episodes): -74.75 ± 47.05
# Episode 439 finished with reward: -37.74
# Moving average (last 50 episodes): -73.49 ± 47.18
# Episode 440 finished with reward: -133.15
# Moving average (last 50 episodes): -72.62 ± 45.65
# Episode 441 finished with reward: -154.51
# Moving average (last 50 episodes): -74.34 ± 47.07
# Episode 442 finished with reward: -103.15
# Moving average (last 50 episodes): -75.47 ± 47.06
# Episode 443 finished with reward: 19.32
# Moving average (last 50 episodes): -73.03 ± 48.72
# Episode 444 finished with reward: -137.49
# Moving average (last 50 episodes): -74.99 ± 49.30
# Episode 445 finished with reward: -51.37
# Moving average (last 50 episodes): -75.07 ± 49.26
# Episode 446 finished with reward: -36.41
# Moving average (last 50 episodes): -74.89 ± 49.38
# Episode 447 finished with reward: -50.96
# Moving average (last 50 episodes): -75.23 ± 49.16
# Episode 448 finished with reward: -3.74
# Moving average (last 50 episodes): -73.32 ± 50.04
# Episode 449 finished with reward: -123.35
# Moving average (last 50 episodes): -73.28 ± 50.00
# Episode 450 finished with reward: -113.28
# Moving average (last 50 episodes): -74.43 ± 50.24
# Episode 451 finished with reward: -107.79
# Moving average (last 50 episodes): -75.50 ± 50.37
# Episode 452 finished with reward: -0.94
# Moving average (last 50 episodes): -75.21 ± 50.76
# Episode 453 finished with reward: -30.57
# Moving average (last 50 episodes): -75.33 ± 50.65
# Episode 454 finished with reward: -108.02
# Moving average (last 50 episodes): -77.03 ± 50.29
# Episode 455 finished with reward: -94.56
# Moving average (last 50 episodes): -77.11 ± 50.32
# Episode 456 finished with reward: 7.14
# Moving average (last 50 episodes): -76.28 ± 51.36
# Episode 457 finished with reward: -101.36
# Moving average (last 50 episodes): -76.56 ± 51.45
# Episode 458 finished with reward: -79.06
# Moving average (last 50 episodes): -76.45 ± 51.44
# Episode 459 finished with reward: -49.88
# Moving average (last 50 episodes): -77.26 ± 50.69
# Episode 460 finished with reward: 2.38
# Moving average (last 50 episodes): -76.06 ± 51.84
# Episode 461 finished with reward: 57.19
# Moving average (last 50 episodes): -73.94 ± 54.98
# Episode 462 finished with reward: -24.93
# Moving average (last 50 episodes): -73.44 ± 55.31
# Episode 463 finished with reward: -125.17
# Moving average (last 50 episodes): -73.20 ± 55.05
# Episode 464 finished with reward: -119.51
# Moving average (last 50 episodes): -74.11 ± 55.43
# Episode 465 finished with reward: -77.06
# Moving average (last 50 episodes): -75.49 ± 54.62
# Episode 466 finished with reward: 37.58
# Moving average (last 50 episodes): -72.12 ± 56.27
# Episode 467 finished with reward: -43.49
# Moving average (last 50 episodes): -70.94 ± 56.24
# Episode 468 finished with reward: -95.09
# Moving average (last 50 episodes): -69.09 ± 53.83
# Episode 469 finished with reward: -93.19
# Moving average (last 50 episodes): -70.27 ± 53.70
# Episode 470 finished with reward: -24.90
# Moving average (last 50 episodes): -70.78 ± 53.15
# Episode 471 finished with reward: -96.18
# Moving average (last 50 episodes): -72.56 ± 52.47
# Episode 472 finished with reward: -52.80
# Moving average (last 50 episodes): -72.08 ± 52.54
# Episode 473 finished with reward: -24.63
# Moving average (last 50 episodes): -70.82 ± 52.91
# Episode 474 finished with reward: -74.45
# Moving average (last 50 episodes): -70.34 ± 52.77
# Episode 475 finished with reward: -52.90
# Moving average (last 50 episodes): -68.14 ± 51.12
# Episode 476 finished with reward: -139.14
# Moving average (last 50 episodes): -68.57 ± 51.63
# Episode 477 finished with reward: -145.76
# Moving average (last 50 episodes): -70.98 ± 52.36
# Episode 478 finished with reward: -91.50
# Moving average (last 50 episodes): -71.37 ± 52.44
# Episode 479 finished with reward: -166.54
# Moving average (last 50 episodes): -73.76 ± 53.98
# Episode 480 finished with reward: 10.27
# Moving average (last 50 episodes): -70.88 ± 54.54
# Episode 481 finished with reward: -90.31
# Moving average (last 50 episodes): -70.38 ± 54.24
# Episode 482 finished with reward: -109.61
# Moving average (last 50 episodes): -71.95 ± 54.22
# Episode 483 finished with reward: -21.97
# Moving average (last 50 episodes): -70.10 ± 54.32
# Episode 484 finished with reward: -68.32
# Moving average (last 50 episodes): -68.73 ± 53.47
# Episode 485 finished with reward: -200.95
# Moving average (last 50 episodes): -71.50 ± 56.57
# Episode 486 finished with reward: -58.61
# Moving average (last 50 episodes): -71.75 ± 56.49
# Episode 487 finished with reward: -62.62
# Moving average (last 50 episodes): -72.14 ± 56.35
# Episode 488 finished with reward: -74.45
# Moving average (last 50 episodes): -70.35 ± 54.80
# Episode 489 finished with reward: -102.67
# Moving average (last 50 episodes): -71.65 ± 54.78
# Episode 490 finished with reward: -78.83
# Moving average (last 50 episodes): -70.56 ± 54.09
# Episode 491 finished with reward: -49.14
# Moving average (last 50 episodes): -68.45 ± 52.81
# Episode 492 finished with reward: 47.69
# Moving average (last 50 episodes): -65.44 ± 55.01
# Episode 493 finished with reward: -51.53
# Moving average (last 50 episodes): -66.86 ± 53.70
# Episode 494 finished with reward: -86.16
# Moving average (last 50 episodes): -65.83 ± 52.83
# Episode 495 finished with reward: -117.98
# Moving average (last 50 episodes): -67.16 ± 53.28
# Episode 496 finished with reward: -133.09
# Moving average (last 50 episodes): -69.09 ± 53.88
# Episode 497 finished with reward: -92.32
# Moving average (last 50 episodes): -69.92 ± 53.92
# Episode 498 finished with reward: -65.53
# Moving average (last 50 episodes): -71.16 ± 53.09
# Episode 499 finished with reward: -119.30
# Moving average (last 50 episodes): -71.08 ± 53.01
# Episode 500 finished with reward: -142.34
# Moving average (last 50 episodes): -71.66 ± 53.63
# Episode 501 finished with reward: -143.07
# Moving average (last 50 episodes): -72.36 ± 54.32
# Episode 502 finished with reward: -47.65
# Moving average (last 50 episodes): -73.30 ± 53.48
# Episode 503 finished with reward: -32.54
# Moving average (last 50 episodes): -73.34 ± 53.45
# Episode 504 finished with reward: -79.89
# Moving average (last 50 episodes): -72.77 ± 53.23
# Episode 505 finished with reward: -51.51
# Moving average (last 50 episodes): -71.91 ± 53.22
# Episode 506 finished with reward: 22.98
# Moving average (last 50 episodes): -71.60 ± 53.74
# Episode 507 finished with reward: -106.03
# Moving average (last 50 episodes): -71.69 ± 53.79
# Episode 508 finished with reward: -146.69
# Moving average (last 50 episodes): -73.04 ± 54.80
# Episode 509 finished with reward: -170.22
# Moving average (last 50 episodes): -75.45 ± 56.35
# Episode 510 finished with reward: -44.85
# Moving average (last 50 episodes): -76.39 ± 55.43
# Episode 511 finished with reward: -103.35
# Moving average (last 50 episodes): -79.60 ± 52.15
# Episode 512 finished with reward: -42.75
# Moving average (last 50 episodes): -79.96 ± 51.83
# Episode 513 finished with reward: -45.30
# Moving average (last 50 episodes): -78.36 ± 51.65
# Episode 514 finished with reward: -2.07
# Moving average (last 50 episodes): -76.01 ± 52.39
# Episode 515 finished with reward: -125.98
# Moving average (last 50 episodes): -76.99 ± 52.85
# Episode 516 finished with reward: -56.43
# Moving average (last 50 episodes): -78.87 ± 50.36
# Episode 517 finished with reward: -78.73
# Moving average (last 50 episodes): -79.58 ± 50.10
# Episode 518 finished with reward: -119.57
# Moving average (last 50 episodes): -80.07 ± 50.37
# Episode 519 finished with reward: -65.96
# Moving average (last 50 episodes): -79.52 ± 50.37
# Episode 520 finished with reward: -72.29
# Moving average (last 50 episodes): -80.47 ± 49.78
# Episode 521 finished with reward: -136.43
# Moving average (last 50 episodes): -81.28 ± 50.35
# Episode 522 finished with reward: -189.38
# Moving average (last 50 episodes): -84.01 ± 52.39
# Episode 523 finished with reward: -88.04
# Moving average (last 50 episodes): -85.28 ± 51.70
# Episode 524 finished with reward: -99.55
# Moving average (last 50 episodes): -85.78 ± 51.72
# Episode 525 finished with reward: -139.07
# Moving average (last 50 episodes): -87.50 ± 52.03
# Episode 526 finished with reward: 43.87
# Moving average (last 50 episodes): -83.84 ± 54.64
# Episode 527 finished with reward: -159.06
# Moving average (last 50 episodes): -84.11 ± 54.97
# Episode 528 finished with reward: -167.99
# Moving average (last 50 episodes): -85.64 ± 56.20
# Episode 529 finished with reward: -85.55
# ...
# Moving average (last 50 episodes): 40.18 ± 15.25
# Episode 8157 finished with reward: 35.64
# Moving average (last 50 episodes): 40.11 ± 15.27
# Episode 8158 finished with reward: 50.03
# Moving average (last 50 episodes): 40.25 ± 15.33
# Episode 8159 finished with reward: 57.76
# Moving average (last 50 episodes): 40.38 ± 15.44
# Episode 8160 finished with reward: 40.78
# Moving average (last 50 episodes): 41.32 ± 13.95
# Episode 8161 finished with reward: 49.89
# Moving average (last 50 episodes): 41.34 ± 13.96
# Episode 8162 finished with reward: 22.70
# Moving average (last 50 episodes): 40.69 ± 14.06
# Episode 8163 finished with reward: 26.46
# Moving average (last 50 episodes): 40.44 ± 14.19
# Episode 8164 finished with reward: 48.19
# Moving average (last 50 episodes): 40.36 ± 14.15
# Episode 8165 finished with reward: 37.04
# Moving average (last 50 episodes): 40.27 ± 14.15
# Episode 8166 finished with reward: 16.74
# Moving average (last 50 episodes): 39.74 ± 14.52
# Episode 8167 finished with reward: 48.65
# Moving average (last 50 episodes): 39.74 ± 14.52
# Episode 8168 finished with reward: 29.52
# Moving average (last 50 episodes): 39.58 ± 14.59
# Episode 8169 finished with reward: 21.22
# Moving average (last 50 episodes): 39.04 ± 14.75
# Episode 8170 finished with reward: 22.49
# Moving average (last 50 episodes): 38.79 ± 14.92
# Episode 8171 finished with reward: 24.06
# Moving average (last 50 episodes): 38.13 ± 14.82
# Episode 8172 finished with reward: 48.95
# Moving average (last 50 episodes): 38.08 ± 14.78
# Episode 8173 finished with reward: 45.15
# Moving average (last 50 episodes): 38.01 ± 14.74
# Episode 8174 finished with reward: 42.07
# Moving average (last 50 episodes): 38.36 ± 14.63
# Episode 8175 finished with reward: 19.82
# Moving average (last 50 episodes): 37.89 ± 14.84
# Episode 8176 finished with reward: 44.13
# Moving average (last 50 episodes): 37.76 ± 14.75
# Episode 8177 finished with reward: 29.96
# Moving average (last 50 episodes): 37.32 ± 14.65
# Episode 8178 finished with reward: 31.80
# Moving average (last 50 episodes): 37.27 ± 14.67
# Episode 8179 finished with reward: 54.04
# Moving average (last 50 episodes): 37.13 ± 14.47
# Episode 8180 finished with reward: 8.51
# Moving average (last 50 episodes): 36.47 ± 15.00
# Episode 8181 finished with reward: 51.62
# Moving average (last 50 episodes): 36.67 ± 15.14
# Episode 8182 finished with reward: 33.15
# Moving average (last 50 episodes): 36.29 ± 14.98
# Episode 8183 finished with reward: 51.87
# Moving average (last 50 episodes): 36.85 ± 15.03
# Episode 8184 finished with reward: 46.81
# Moving average (last 50 episodes): 36.86 ± 15.04
# Episode 8185 finished with reward: 35.60
# Moving average (last 50 episodes): 36.97 ± 15.01
# Episode 8186 finished with reward: 39.72
# Moving average (last 50 episodes): 37.20 ± 14.97
# Episode 8187 finished with reward: 45.31
# Moving average (last 50 episodes): 36.63 ± 14.08
# Episode 8188 finished with reward: 27.57
# Moving average (last 50 episodes): 36.52 ± 14.13
# Episode 8189 finished with reward: 11.19
# Moving average (last 50 episodes): 36.33 ± 14.40
# Episode 8190 finished with reward: 57.83
# Moving average (last 50 episodes): 36.57 ± 14.65
# Episode 8191 finished with reward: 39.84
# Moving average (last 50 episodes): 36.89 ± 14.54
# Episode 8192 finished with reward: 24.57
# Moving average (last 50 episodes): 36.26 ± 14.38
# Episode 8193 finished with reward: 65.47
# Moving average (last 50 episodes): 37.73 ± 13.53
# Episode 8194 finished with reward: 13.47
# Moving average (last 50 episodes): 36.89 ± 13.72
# Episode 8195 finished with reward: -16.09
# Moving average (last 50 episodes): 35.96 ± 15.58
# Episode 8196 finished with reward: 43.98
# Moving average (last 50 episodes): 36.06 ± 15.62
# Episode 8197 finished with reward: 38.76
# Moving average (last 50 episodes): 36.43 ± 15.46
# Episode 8198 finished with reward: 46.15
# Moving average (last 50 episodes): 36.25 ± 15.28
# Episode 8199 finished with reward: 31.98
# Moving average (last 50 episodes): 35.86 ± 15.14
# Episode 8200 finished with reward: 26.72
# Moving average (last 50 episodes): 35.74 ± 15.19
# Episode 8201 finished with reward: 63.19
# Moving average (last 50 episodes): 36.26 ± 15.66
# Episode 8202 finished with reward: 62.20
# Moving average (last 50 episodes): 37.28 ± 15.65
# Episode 8203 finished with reward: 36.94
# Moving average (last 50 episodes): 37.21 ± 15.65
# Episode 8204 finished with reward: 56.93
# Moving average (last 50 episodes): 37.73 ± 15.86
# Episode 8205 finished with reward: 56.72
# Moving average (last 50 episodes): 37.95 ± 16.05
# Episode 8206 finished with reward: 38.84
# Moving average (last 50 episodes): 37.72 ± 15.95
# Episode 8207 finished with reward: 13.82
# Moving average (last 50 episodes): 37.28 ± 16.30
# Episode 8208 finished with reward: 45.75
# Moving average (last 50 episodes): 37.20 ± 16.24
# Episode 8209 finished with reward: 45.30
# Moving average (last 50 episodes): 36.95 ± 16.02
# Episode 8210 finished with reward: 26.44
# Moving average (last 50 episodes): 36.66 ± 16.07
# Episode 8211 finished with reward: 64.51
# Moving average (last 50 episodes): 36.95 ± 16.44
# Episode 8212 finished with reward: 34.13
# Moving average (last 50 episodes): 37.18 ± 16.32
# Episode 8213 finished with reward: 30.25
# Moving average (last 50 episodes): 37.26 ± 16.28
# Episode 8214 finished with reward: -34.08
# Moving average (last 50 episodes): 35.61 ± 19.02
# Episode 8215 finished with reward: 1.23
# Moving average (last 50 episodes): 34.90 ± 19.62
# Episode 8216 finished with reward: 33.78
# Moving average (last 50 episodes): 35.24 ± 19.45
# Episode 8217 finished with reward: 19.68
# Moving average (last 50 episodes): 34.66 ± 19.47
# Episode 8218 finished with reward: 35.90
# Moving average (last 50 episodes): 34.79 ± 19.46
# Episode 8219 finished with reward: 43.75
# Moving average (last 50 episodes): 35.24 ± 19.40
# Episode 8220 finished with reward: 37.81
# Moving average (last 50 episodes): 35.54 ± 19.31
# Episode 8221 finished with reward: 35.51
# Moving average (last 50 episodes): 35.77 ± 19.24
# Episode 8222 finished with reward: 32.37
# Moving average (last 50 episodes): 35.44 ± 19.16
# Episode 8223 finished with reward: 69.78
# Moving average (last 50 episodes): 35.93 ± 19.71
# Episode 8224 finished with reward: 53.33
# Moving average (last 50 episodes): 36.16 ± 19.84
# Episode 8225 finished with reward: 41.18
# Moving average (last 50 episodes): 36.58 ± 19.71
# Episode 8226 finished with reward: 30.84
# Moving average (last 50 episodes): 36.32 ± 19.70
# Episode 8227 finished with reward: 28.05
# Moving average (last 50 episodes): 36.28 ± 19.72
# Episode 8228 finished with reward: 49.87
# Moving average (last 50 episodes): 36.64 ± 19.80
# Episode 8229 finished with reward: 30.37
# Moving average (last 50 episodes): 36.17 ± 19.66
# Episode 8230 finished with reward: 42.22
# Moving average (last 50 episodes): 36.84 ± 19.27
# Episode 8231 finished with reward: 23.17
# Moving average (last 50 episodes): 36.27 ± 19.25
# Episode 8232 finished with reward: 63.30
# Moving average (last 50 episodes): 36.88 ± 19.61
# Episode 8233 finished with reward: 49.54
# Moving average (last 50 episodes): 36.83 ± 19.57
# Episode 8234 finished with reward: 39.37
# Moving average (last 50 episodes): 36.68 ± 19.53
# Episode 8235 finished with reward: 37.03
# Moving average (last 50 episodes): 36.71 ± 19.53
# Episode 8236 finished with reward: 26.56
# Moving average (last 50 episodes): 36.45 ± 19.57
# Episode 8237 finished with reward: 65.53
# Moving average (last 50 episodes): 36.85 ± 19.96
# Episode 8238 finished with reward: 27.28
# Moving average (last 50 episodes): 36.85 ± 19.96
# Episode 8239 finished with reward: 63.84
# Moving average (last 50 episodes): 37.90 ± 19.97
# Episode 8240 finished with reward: 32.74
# Moving average (last 50 episodes): 37.40 ± 19.77
# Episode 8241 finished with reward: 78.44
# Moving average (last 50 episodes): 38.17 ± 20.59
# Episode 8242 finished with reward: 27.95
# Moving average (last 50 episodes): 38.24 ± 20.55
# Episode 8243 finished with reward: 44.94
# Moving average (last 50 episodes): 37.83 ± 20.20
# Episode 8244 finished with reward: 81.94
# Moving average (last 50 episodes): 39.19 ± 20.82
# Episode 8245 finished with reward: 3.56
# Moving average (last 50 episodes): 39.59 ± 19.94
# Episode 8246 finished with reward: 22.83
# Moving average (last 50 episodes): 39.16 ± 20.06
# Episode 8247 finished with reward: 41.47
# Moving average (last 50 episodes): 39.22 ± 20.07
# Episode 8248 finished with reward: 48.88
# Moving average (last 50 episodes): 39.27 ± 20.09
# Episode 8249 finished with reward: 45.01
# Moving average (last 50 episodes): 39.53 ± 20.08
# Episode 8250 finished with reward: 18.71
# Moving average (last 50 episodes): 39.37 ± 20.21
# Episode 8251 finished with reward: 51.09
# Moving average (last 50 episodes): 39.13 ± 20.00
# Episode 8252 finished with reward: 25.48
# Moving average (last 50 episodes): 38.40 ± 19.81
# Episode 8253 finished with reward: 18.15
# Moving average (last 50 episodes): 38.02 ± 20.01
# Episode 8254 finished with reward: 43.95
# Moving average (last 50 episodes): 37.76 ± 19.85
# Episode 8255 finished with reward: 15.38
# Moving average (last 50 episodes): 36.94 ± 19.90
# Episode 8256 finished with reward: 41.78
# Moving average (last 50 episodes): 36.99 ± 19.91
# Episode 8257 finished with reward: 31.89
# Moving average (last 50 episodes): 37.36 ± 19.65
# Episode 8258 finished with reward: 31.53
# Moving average (last 50 episodes): 37.07 ± 19.63
# Episode 8259 finished with reward: 58.42
# Moving average (last 50 episodes): 37.33 ± 19.82
# Episode 8260 finished with reward: 45.87
# Moving average (last 50 episodes): 37.72 ± 19.80
# Episode 8261 finished with reward: 43.03
# Moving average (last 50 episodes): 37.29 ± 19.44
# Episode 8262 finished with reward: 68.68
# Moving average (last 50 episodes): 37.98 ± 19.92
# Episode 8263 finished with reward: 43.29
# Moving average (last 50 episodes): 38.24 ± 19.90
# Episode 8264 finished with reward: 54.93
# Moving average (last 50 episodes): 40.02 ± 17.15
# Episode 8265 finished with reward: 30.30
# Moving average (last 50 episodes): 40.61 ± 16.29
# Episode 8266 finished with reward: 40.12
# Moving average (last 50 episodes): 40.73 ± 16.26
# Episode 8267 finished with reward: 25.26
# Moving average (last 50 episodes): 40.84 ± 16.14
# Episode 8268 finished with reward: 27.64
# Moving average (last 50 episodes): 40.68 ± 16.23
# Episode 8269 finished with reward: 46.31
# Moving average (last 50 episodes): 40.73 ± 16.24
# Episode 8270 finished with reward: -9.18
# Moving average (last 50 episodes): 39.79 ± 17.68
# Episode 8271 finished with reward: 41.12
# Moving average (last 50 episodes): 39.90 ± 17.67
# Episode 8272 finished with reward: 46.06
# Moving average (last 50 episodes): 40.18 ± 17.66
# Episode 8273 finished with reward: 77.09
# Moving average (last 50 episodes): 40.32 ± 17.93
# Episode 8274 finished with reward: 32.49
# Moving average (last 50 episodes): 39.91 ± 17.87
# Episode 8275 finished with reward: 40.68
# Moving average (last 50 episodes): 39.90 ± 17.86
# Episode 8276 finished with reward: 53.26
# Moving average (last 50 episodes): 40.34 ± 17.91
# Episode 8277 finished with reward: 16.72
# Moving average (last 50 episodes): 40.12 ± 18.14
# Episode 8278 finished with reward: 5.23
# Moving average (last 50 episodes): 39.22 ± 18.72
# Episode 8279 finished with reward: 38.56
# Moving average (last 50 episodes): 39.39 ± 18.68
# Episode 8280 finished with reward: 12.89
# Moving average (last 50 episodes): 38.80 ± 19.04
# Episode 8281 finished with reward: 30.99
# Moving average (last 50 episodes): 38.96 ± 18.94
# Episode 8282 finished with reward: 51.26
# Moving average (last 50 episodes): 38.72 ± 18.71
# Episode 8283 finished with reward: 50.88
# Moving average (last 50 episodes): 38.74 ± 18.72
# Episode 8284 finished with reward: 23.12
# Moving average (last 50 episodes): 38.42 ± 18.85
# Episode 8285 finished with reward: 61.08
# Moving average (last 50 episodes): 38.90 ± 19.11
# Episode 8286 finished with reward: 43.00
# Moving average (last 50 episodes): 39.23 ± 19.04
# Episode 8287 finished with reward: 36.98
# Moving average (last 50 episodes): 38.66 ± 18.67
# Episode 8288 finished with reward: 66.50
# Moving average (last 50 episodes): 39.44 ± 18.99
# Episode 8289 finished with reward: 47.81
# Moving average (last 50 episodes): 39.12 ± 18.71
# Episode 8290 finished with reward: 6.86
# Moving average (last 50 episodes): 38.60 ± 19.23
# Episode 8291 finished with reward: 47.79
# Moving average (last 50 episodes): 37.99 ± 18.43
# Episode 8292 finished with reward: -0.08
# Moving average (last 50 episodes): 37.43 ± 19.14
# Episode 8293 finished with reward: 42.05
# Moving average (last 50 episodes): 37.37 ± 19.12
# Episode 8294 finished with reward: 36.32
# Moving average (last 50 episodes): 36.46 ± 18.03
# Episode 8295 finished with reward: 40.15
# Moving average (last 50 episodes): 37.19 ± 17.41
# Episode 8296 finished with reward: 55.24
# Moving average (last 50 episodes): 37.84 ± 17.46
# Episode 8297 finished with reward: 24.64
# Moving average (last 50 episodes): 37.50 ± 17.55
# Episode 8298 finished with reward: 47.37
# Moving average (last 50 episodes): 37.47 ± 17.53
# Episode 8299 finished with reward: 22.74
# Moving average (last 50 episodes): 37.03 ± 17.62
# Episode 8300 finished with reward: 52.04
# Moving average (last 50 episodes): 37.69 ± 17.54
# Episode 8301 finished with reward: 34.06
# Moving average (last 50 episodes): 37.35 ± 17.45
# Episode 8302 finished with reward: -25.60
# Moving average (last 50 episodes): 36.33 ± 19.49
# Episode 8303 finished with reward: 47.43
# Moving average (last 50 episodes): 36.92 ± 19.37
# Episode 8304 finished with reward: 51.72
# Moving average (last 50 episodes): 37.07 ± 19.46
# Episode 8305 finished with reward: 53.14
# Moving average (last 50 episodes): 37.83 ± 19.33
# Episode 8306 finished with reward: 26.18
# Moving average (last 50 episodes): 37.52 ± 19.39
# Episode 8307 finished with reward: 49.43
# Moving average (last 50 episodes): 37.87 ± 19.45
# Episode 8308 finished with reward: 29.07
# Moving average (last 50 episodes): 37.82 ± 19.47
# Episode 8309 finished with reward: -7.99
# Moving average (last 50 episodes): 36.49 ± 20.26
# Episode 8310 finished with reward: 43.04
# Moving average (last 50 episodes): 36.43 ± 20.24
# Episode 8311 finished with reward: 42.58
# Moving average (last 50 episodes): 36.42 ± 20.24
# Episode 8312 finished with reward: 43.50
# Moving average (last 50 episodes): 35.92 ± 19.74
# Episode 8313 finished with reward: -12.54
# Moving average (last 50 episodes): 34.80 ± 20.84
# Episode 8314 finished with reward: 56.12
# Moving average (last 50 episodes): 34.83 ± 20.86
# Episode 8315 finished with reward: 56.97
# Moving average (last 50 episodes): 35.36 ± 21.08
# Episode 8316 finished with reward: 9.42
# Moving average (last 50 episodes): 34.75 ± 21.38
# Episode 8317 finished with reward: 42.16
# Moving average (last 50 episodes): 35.09 ± 21.36
# Episode 8318 finished with reward: 79.49
# Moving average (last 50 episodes): 36.12 ± 22.21
# Episode 8319 finished with reward: 38.50
# Moving average (last 50 episodes): 35.97 ± 22.17
# Episode 8320 finished with reward: 10.29
# Moving average (last 50 episodes): 36.36 ± 21.53
# Episode 8321 finished with reward: -11.45
# Moving average (last 50 episodes): 35.30 ± 22.53
# Episode 8322 finished with reward: 53.57
# Moving average (last 50 episodes): 35.45 ± 22.63
# Episode 8323 finished with reward: 31.08
# Moving average (last 50 episodes): 34.53 ± 21.84
# Episode 8324 finished with reward: 39.20
# Moving average (last 50 episodes): 34.67 ± 21.85
# Episode 8325 finished with reward: 51.82
# Moving average (last 50 episodes): 34.89 ± 21.96
# Episode 8326 finished with reward: 25.13
# Moving average (last 50 episodes): 34.33 ± 21.85
# Episode 8327 finished with reward: 46.71
# Moving average (last 50 episodes): 34.93 ± 21.77
# Episode 8328 finished with reward: 48.42
# Moving average (last 50 episodes): 35.79 ± 21.43
# Episode 8329 finished with reward: 48.16
# Moving average (last 50 episodes): 35.98 ± 21.49
# Episode 8330 finished with reward: 45.01
# Moving average (last 50 episodes): 36.63 ± 21.27
# Episode 8331 finished with reward: 41.23
# Moving average (last 50 episodes): 36.83 ± 21.27
# Episode 8332 finished with reward: 28.51
# Moving average (last 50 episodes): 36.38 ± 21.19
# Episode 8333 finished with reward: 29.56
# Moving average (last 50 episodes): 35.95 ± 21.11

# %%
# def plot_smooth_rewards(rewards, window_sizes=[5, 20, 100]):
#     """
#     绘制平滑的奖励曲线
#     Args:
#         rewards: 奖励列表
#         window_sizes: 移动平均窗口大小列表
#     """
#     plt.figure(figsize=(12, 6))
    
#     # 绘制原始奖励
#     plt.plot(rewards, 'lightgray', alpha=0.3, label='Raw rewards')
    
#     # 绘制不同窗口大小的移动平均
#     colors = ['blue', 'green', 'red']
#     for window, color in zip(window_sizes, colors):
#         if len(rewards) >= window:
#             # 计算移动平均
#             smooth_rewards = np.convolve(rewards, 
#                                       np.ones(window)/window, 
#                                       mode='valid')
#             plt.plot(range(window-1, len(rewards)), 
#                     smooth_rewards, 
#                     color=color, 
#                     label=f'{window}-Episode Moving Average',
#                     linewidth=2)
    
#     plt.xlabel('Episode')
#     plt.ylabel('Reward')
#     plt.title('Training Rewards with Different Smoothing Windows')
#     plt.grid(True, alpha=0.3)
#     plt.legend()
#     plt.show()


# # 绘制平滑奖励曲线
# plot_smooth_rewards(metrics["rewards"])

# %% [markdown]
# notes: 如果要训练过程中查看模型，通过 tensorboard 查看

# %%
# 模型保存
model.save(f"./model/{log_name}")

# %% [markdown]
# ### 评估模型训练结果

# %% [markdown]
# > 利用 evaulate policy 函数评估

# %% [markdown]
# # 加载训练好的 RL 模型

# %%
from stable_baselines3.common.evaluation import evaluate_policy
mean_reward, std_reward = evaluate_policy(
    model, 
    model.get_env(), 
    deterministic=True,
    render=True,
    n_eval_episodes=10)

print(mean_reward)
print(std_reward)
# Out:
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# 30.489988399999998
# 15.624991324439462

# %%
# del model
# model = PPO.load(f"./model/{log_name}", env=env_monitor)
model = DQN.load(f"./model/{log_name}", env=env_monitor)
# Out:
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### 结果展示

# %% [markdown]
# #### 纯净展示版本
#
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆

for ep in range(episodes):
    
    obs, _ = env_monitor.reset(use_random_reset=base_config["use_random_reset"], seed=base_config["seed"]) # 必须的，每次重现一次
    
    episode_reward = 0
    done = False
    
     
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        print(f"year {env_monitor.t}-Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # # 每10步更新一次图像
        # if i == max_steps-1:
        #     env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            env_monitor.render()
            plt.show()  # 添加这行来保持图形窗口
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")
# Out:
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.t to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.t` for environment variables or `env.get_wrapper_attr('t')` that will search the reminding wrappers.
#   logger.warn(
# year 2017-Step 0 - Action: 8 - Reward: 0.0 - Done: False
# year 2018-Step 1 - Action: 10 - Reward: 0.0 - Done: False
# year 2019-Step 2 - Action: 10 - Reward: 0.0 - Done: False
# year 2020-Step 3 - Action: 10 - Reward: 0.0 - Done: False
# year 2021-Step 4 - Action: 2 - Reward: 0.0 - Done: False
# year 2022-Step 5 - Action: 2 - Reward: 2.8380705688586416 - Done: False
# year 2023-Step 6 - Action: 2 - Reward: 2.414581020854514 - Done: False
# year 2024-Step 7 - Action: 2 - Reward: 2.0131075029367977 - Done: False
# year 2025-Step 8 - Action: 10 - Reward: 1.6338677973863736 - Done: False
# year 2026-Step 9 - Action: 10 - Reward: 1.2771802621683814 - Done: False
# year 2027-Step 10 - Action: 10 - Reward: 0.9436065003312871 - Done: False
# year 2028-Step 11 - Action: 10 - Reward: 0.6335212060843615 - Done: False
# year 2029-Step 12 - Action: 10 - Reward: 0.34743472599390035 - Done: False
# year 2030-Step 13 - Action: 10 - Reward: 0.08585499504679128 - Done: False
# year 2031-Step 14 - Action: 10 - Reward: -0.060344852072284905 - Done: False
# year 2032-Step 15 - Action: 10 - Reward: -0.14515875062905415 - Done: False
# year 2033-Step 16 - Action: 10 - Reward: -0.22035180445813096 - Done: False
# year 2034-Step 17 - Action: 12 - Reward: -0.286091036511924 - Done: False
# year 2035-Step 18 - Action: 12 - Reward: -0.34264244745004335 - Done: False
# year 2036-Step 19 - Action: 14 - Reward: -0.3905067767172399 - Done: False
# year 2037-Step 20 - Action: 14 - Reward: -0.43022418770976345 - Done: False
# year 2038-Step 21 - Action: 14 - Reward: -0.46205325477998826 - Done: False
# year 2039-Step 22 - Action: 14 - Reward: -0.4862083903791148 - Done: False
# year 2040-Step 23 - Action: 12 - Reward: -0.5029358598435563 - Done: False
# year 2041-Step 24 - Action: 12 - Reward: -0.5126268127370315 - Done: False
# year 2042-Step 25 - Action: 12 - Reward: -0.5161802572176244 - Done: False
# year 2043-Step 26 - Action: 12 - Reward: -0.5143203994624468 - Done: False
# year 2044-Step 27 - Action: 12 - Reward: -0.5074888845306191 - Done: False
# year 2045-Step 28 - Action: 12 - Reward: -0.4960781984020546 - Done: False
# year 2046-Step 29 - Action: 12 - Reward: -0.4803928053417206 - Done: False
# year 2047-Step 30 - Action: 12 - Reward: -0.46070242640924186 - Done: False
# year 2048-Step 31 - Action: 12 - Reward: -0.4372709699315924 - Done: False
# year 2049-Step 32 - Action: 12 - Reward: -0.41031539976348896 - Done: False
# year 2050-Step 33 - Action: 12 - Reward: -0.38003808468763833 - Done: False
# year 2051-Step 34 - Action: 12 - Reward: -0.3466108339490004 - Done: False
# year 2052-Step 35 - Action: 12 - Reward: -0.31228645680126177 - Done: False
# year 2053-Step 36 - Action: 12 - Reward: -0.27727637727153365 - Done: False
# year 2054-Step 37 - Action: 12 - Reward: -0.24174052842763416 - Done: False
# year 2055-Step 38 - Action: 12 - Reward: -0.20579901392175137 - Done: False
# year 2056-Step 39 - Action: 12 - Reward: -0.16953212241011983 - Done: False
# year 2057-Step 40 - Action: 12 - Reward: -0.13298856097568756 - Done: False
# year 2058-Step 41 - Action: 12 - Reward: -0.09618943126095014 - Done: False
# year 2059-Step 42 - Action: 12 - Reward: -0.059132471552683086 - Done: False
# year 2060-Step 43 - Action: 12 - Reward: -0.021796448919503275 - Done: False
# year 2061-Step 44 - Action: 12 - Reward: 0.03963863081887786 - Done: False
# year 2062-Step 45 - Action: 12 - Reward: 0.13447473171484536 - Done: False
# year 2063-Step 46 - Action: 12 - Reward: 0.22890887685338146 - Done: False
# year 2064-Step 47 - Action: 12 - Reward: 0.3225987131687341 - Done: False
# year 2065-Step 48 - Action: 12 - Reward: 0.41565654882950165 - Done: False
# year 2066-Step 49 - Action: 12 - Reward: 0.5081119254006394 - Done: False
# year 2067-Step 50 - Action: 12 - Reward: 0.5998118061396718 - Done: False
# year 2068-Step 51 - Action: 12 - Reward: 0.6907412253446543 - Done: False
# year 2069-Step 52 - Action: 12 - Reward: 0.7809666314130881 - Done: False
# year 2070-Step 53 - Action: 12 - Reward: 0.870612317513686 - Done: False
# year 2071-Step 54 - Action: 12 - Reward: 0.9598635015024809 - Done: False
# year 2072-Step 55 - Action: 12 - Reward: 1.0488447279475899 - Done: False
# year 2073-Step 56 - Action: 12 - Reward: 1.1371241049033838 - Done: False
# year 2074-Step 57 - Action: 12 - Reward: 1.2226547862021069 - Done: False
# year 2075-Step 58 - Action: 12 - Reward: 1.3059631039704978 - Done: False
# year 2076-Step 59 - Action: 12 - Reward: 1.3875625482752647 - Done: False
# year 2077-Step 60 - Action: 12 - Reward: 1.4679488925405049 - Done: False
# year 2078-Step 61 - Action: 12 - Reward: 1.5475968868909256 - Done: False
# year 2079-Step 62 - Action: 12 - Reward: 1.6269547850348953 - Done: False
# year 2080-Step 63 - Action: 12 - Reward: 1.706444912977323 - Done: False
# year 2081-Step 64 - Action: 12 - Reward: 1.7864607895498097 - Done: False
# year 2082-Step 65 - Action: 12 - Reward: 1.8673409576457967 - Done: False
# year 2083-Step 66 - Action: 12 - Reward: 1.949396160131145 - Done: False
# year 2084-Step 67 - Action: 12 - Reward: 2.032924001275707 - Done: False
# year 2085-Step 68 - Action: 12 - Reward: 2.118200473127943 - Done: False
# year 2086-Step 69 - Action: 12 - Reward: 2.2054844011588415 - Done: False
# year 2087-Step 70 - Action: 12 - Reward: 2.2950155969187507 - Done: False
# year 2088-Step 71 - Action: 12 - Reward: 2.38701444400185 - Done: False
# year 2089-Step 72 - Action: 12 - Reward: 2.4816827892503808 - Done: False
# year 2090-Step 73 - Action: 12 - Reward: 2.5792041220229738 - Done: False
# year 2091-Step 74 - Action: 12 - Reward: 2.679744385128541 - Done: False
# year 2092-Step 75 - Action: 1 - Reward: 2.7834461024039165 - Done: False
# year 2093-Step 76 - Action: 1 - Reward: 2.8899128391888045 - Done: False
# year 2094-Step 77 - Action: 1 - Reward: 2.9985399450876944 - Done: False
# year 2095-Step 78 - Action: 1 - Reward: 3.1088660742023015 - Done: False
# year 2096-Step 79 - Action: 1 - Reward: 0.0 - Done: False
# year 2097-Step 80 - Action: 1 - Reward: 0.0 - Done: False
# year 2098-Step 81 - Action: 1 - Reward: 0.0 - Done: False
# year 2099-Step 82 - Action: 1 - Reward: -10.0 - Done: False
# year 2100-Step 83 - Action: 1 - Reward: -10.0 - Done: True
# Episode ended at step 83 with T_a = 1.2059834232709121
# Episode 0 finished with reward-10.0
# Final T_a: 1.2059834232709121

# %%
# 运行中绘制的图
episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆

for ep in range(episodes):
    
    obs, _ = env_monitor.reset(use_random_reset=True, seed=31) # 必须的，每次重现一次
    
    episode_reward = 0
    done = False
    
     
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        print(f"year {env_monitor.t}-Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # # 每10步更新一次图像
        # if i == max_steps-1:
        #     env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            env_monitor.render()
            plt.show()  # 添加这行来保持图形窗口
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")
# Out:
# year 2017-Step 0 - Action: 2 - Reward: 0.0 - Done: False
# year 2018-Step 1 - Action: 2 - Reward: 0.0 - Done: False
# year 2019-Step 2 - Action: 2 - Reward: 0.0 - Done: False
# year 2020-Step 3 - Action: 10 - Reward: 0.0 - Done: False
# year 2021-Step 4 - Action: 10 - Reward: 0.0 - Done: False
# year 2022-Step 5 - Action: 10 - Reward: 0.0 - Done: False
# year 2023-Step 6 - Action: 10 - Reward: 2.786465635360047 - Done: False
# year 2024-Step 7 - Action: 10 - Reward: 2.2586993812483884 - Done: False
# year 2025-Step 8 - Action: 10 - Reward: 1.7631773896743446 - Done: False
# year 2026-Step 9 - Action: 10 - Reward: 1.2987910457058327 - Done: False
# year 2027-Step 10 - Action: 10 - Reward: 0.8646850209744816 - Done: False
# year 2028-Step 11 - Action: 10 - Reward: 0.46050466973465154 - Done: False
# year 2029-Step 12 - Action: 10 - Reward: 0.08611374136717198 - Done: False
# year 2030-Step 13 - Action: 10 - Reward: -0.1033623886872681 - Done: False
# year 2031-Step 14 - Action: 10 - Reward: -0.22904403829016262 - Done: False
# year 2032-Step 15 - Action: 10 - Reward: -0.34266283390125163 - Done: False
# year 2033-Step 16 - Action: 10 - Reward: -0.4444426212668451 - Done: False
# year 2034-Step 17 - Action: 10 - Reward: -0.534703707430203 - Done: False
# year 2035-Step 18 - Action: 10 - Reward: -0.6137315914463948 - Done: False
# year 2036-Step 19 - Action: 10 - Reward: -0.6818337582597067 - Done: False
# year 2037-Step 20 - Action: 10 - Reward: -0.7393883966748593 - Done: False
# year 2038-Step 21 - Action: 10 - Reward: -0.7869116651321062 - Done: False
# year 2039-Step 22 - Action: 10 - Reward: -0.8250126491882293 - Done: False
# year 2040-Step 23 - Action: 10 - Reward: -0.8543637886633859 - Done: False
# year 2041-Step 24 - Action: 14 - Reward: -0.875653091366505 - Done: False
# year 2042-Step 25 - Action: 14 - Reward: -0.8898813529175009 - Done: False
# year 2043-Step 26 - Action: 14 - Reward: -0.8978768380942082 - Done: False
# year 2044-Step 27 - Action: 14 - Reward: -0.9001001295569799 - Done: False
# year 2045-Step 28 - Action: 14 - Reward: -0.896972419862414 - Done: False
# year 2046-Step 29 - Action: 14 - Reward: -0.8888885023569515 - Done: False
# year 2047-Step 30 - Action: 14 - Reward: -0.8762015316137761 - Done: False
# year 2048-Step 31 - Action: 14 - Reward: -0.8592355036184451 - Done: False
# year 2049-Step 32 - Action: 12 - Reward: -0.8382833263351641 - Done: False
# year 2050-Step 33 - Action: 12 - Reward: -0.8136366020491126 - Done: False
# year 2051-Step 34 - Action: 12 - Reward: -0.7855972991207816 - Done: False
# year 2052-Step 35 - Action: 12 - Reward: -0.7565139052761627 - Done: False
# year 2053-Step 36 - Action: 12 - Reward: -0.7266658721991115 - Done: False
# year 2054-Step 37 - Action: 12 - Reward: -0.6962672502288192 - Done: False
# year 2055-Step 38 - Action: 12 - Reward: -0.6654746325690741 - Done: False
# year 2056-Step 39 - Action: 12 - Reward: -0.6344008660527878 - Done: False
# year 2057-Step 40 - Action: 12 - Reward: -0.6031060805667454 - Done: False
# year 2058-Step 41 - Action: 12 - Reward: -0.5715970585909114 - Done: False
# year 2059-Step 42 - Action: 12 - Reward: -0.5399038522151767 - Done: False
# year 2060-Step 43 - Action: 12 - Reward: -0.5080076608231676 - Done: False
# year 2061-Step 44 - Action: 12 - Reward: -0.47588502646486175 - Done: False
# year 2062-Step 45 - Action: 12 - Reward: -0.4436139194930455 - Done: False
# year 2063-Step 46 - Action: 12 - Reward: -0.4117742455693163 - Done: False
# year 2064-Step 47 - Action: 12 - Reward: -0.3805911063468326 - Done: False
# year 2065-Step 48 - Action: 12 - Reward: -0.350099228045353 - Done: False
# year 2066-Step 49 - Action: 12 - Reward: -0.32026774374725786 - Done: False
# year 2067-Step 50 - Action: 12 - Reward: -0.2910180702976106 - Done: False
# year 2068-Step 51 - Action: 12 - Reward: -0.2623027936200295 - Done: False
# year 2069-Step 52 - Action: 12 - Reward: -0.2340251013538941 - Done: False
# year 2070-Step 53 - Action: 12 - Reward: -0.20605552044849929 - Done: False
# year 2071-Step 54 - Action: 12 - Reward: -0.17825022913982358 - Done: False
# year 2072-Step 55 - Action: 12 - Reward: -0.15052531394837088 - Done: False
# year 2073-Step 56 - Action: 12 - Reward: -0.12302445692712438 - Done: False
# year 2074-Step 57 - Action: 12 - Reward: -0.09654801956533454 - Done: False
# year 2075-Step 58 - Action: 12 - Reward: -0.07087197768359976 - Done: False
# year 2076-Step 59 - Action: 12 - Reward: -0.04578332746029923 - Done: False
# year 2077-Step 60 - Action: 12 - Reward: -0.021080613623003508 - Done: False
# year 2078-Step 61 - Action: 12 - Reward: 0.008562006937229416 - Done: False
# year 2079-Step 62 - Action: 12 - Reward: 0.06977126982540272 - Done: False
# year 2080-Step 63 - Action: 12 - Reward: 0.13132948351050056 - Done: False
# year 2081-Step 64 - Action: 12 - Reward: 0.19360592993207526 - Done: False
# year 2082-Step 65 - Action: 12 - Reward: 0.25692400665247306 - Done: False
# year 2083-Step 66 - Action: 12 - Reward: 0.3215335681486242 - Done: False
# year 2084-Step 67 - Action: 12 - Reward: 0.38767658073360356 - Done: False
# year 2085-Step 68 - Action: 12 - Reward: 0.45561761232211506 - Done: False
# year 2086-Step 69 - Action: 12 - Reward: 0.5255793944869497 - Done: False
# year 2087-Step 70 - Action: 12 - Reward: 0.5977704916867166 - Done: False
# year 2088-Step 71 - Action: 12 - Reward: 0.672370866082761 - Done: False
# year 2089-Step 72 - Action: 12 - Reward: 0.749540482655478 - Done: False
# year 2090-Step 73 - Action: 12 - Reward: 0.8294161944285089 - Done: False
# year 2091-Step 74 - Action: 12 - Reward: 0.912117153142078 - Done: False
# year 2092-Step 75 - Action: 12 - Reward: 0.9977408305606145 - Done: False
# year 2093-Step 76 - Action: 1 - Reward: 1.0863740696026496 - Done: False
# year 2094-Step 77 - Action: 1 - Reward: 1.1776553328641137 - Done: False
# year 2095-Step 78 - Action: 1 - Reward: 1.2710421779632748 - Done: False
# year 2096-Step 79 - Action: 1 - Reward: 1.3661196866768033 - Done: False
# year 2097-Step 80 - Action: 1 - Reward: 1.4625489554688982 - Done: False
# year 2098-Step 81 - Action: 1 - Reward: 1.560060862788895 - Done: False
# year 2099-Step 82 - Action: 1 - Reward: 1.6584424397009663 - Done: False
# year 2100-Step 83 - Action: 1 - Reward: 1.7575273128925706 - Done: True
# Episode ended at step 83 with T_a = 1.3593978149685944
# Episode 0 finished with reward1.7575273128925706
# Final T_a: 1.3593978149685944

# %%
# 运行中绘制的图
episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆

for ep in range(episodes):
    
    obs, _ = env_monitor.reset(use_random_reset=True, seed=16) # 必须的，每次重现一次
    
    episode_reward = 0
    done = False
    
     
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        print(f"year {env_monitor.t}-Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # # 每10步更新一次图像
        # if i == max_steps-1:
        #     env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            env_monitor.render()
            plt.show()  # 添加这行来保持图形窗口
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")
# Out:
# year 2017-Step 0 - Action: 8 - Reward: 0.0 - Done: False
# year 2018-Step 1 - Action: 8 - Reward: 0.0 - Done: False
# year 2019-Step 2 - Action: 8 - Reward: 0.0 - Done: False
# year 2020-Step 3 - Action: 10 - Reward: 0.0 - Done: False
# year 2021-Step 4 - Action: 10 - Reward: 0.0 - Done: False
# year 2022-Step 5 - Action: 2 - Reward: 0.0 - Done: False
# year 2023-Step 6 - Action: 2 - Reward: 0.0 - Done: False
# year 2024-Step 7 - Action: 10 - Reward: 0.0 - Done: False
# year 2025-Step 8 - Action: 10 - Reward: 2.7625822649833682 - Done: False
# year 2026-Step 9 - Action: 10 - Reward: 2.3403077645576946 - Done: False
# year 2027-Step 10 - Action: 10 - Reward: 1.9461300295067097 - Done: False
# year 2028-Step 11 - Action: 10 - Reward: 1.5795769325771674 - Done: False
# year 2029-Step 12 - Action: 10 - Reward: 1.2404734141229556 - Done: False
# year 2030-Step 13 - Action: 10 - Reward: 0.9286641036968385 - Done: False
# year 2031-Step 14 - Action: 10 - Reward: 0.6442394000622603 - Done: False
# year 2032-Step 15 - Action: 10 - Reward: 0.3870270574134277 - Done: False
# year 2033-Step 16 - Action: 10 - Reward: 0.1566059997566066 - Done: False
# year 2034-Step 17 - Action: 10 - Reward: -0.018920938304817225 - Done: False
# year 2035-Step 18 - Action: 14 - Reward: -0.09004228317168739 - Done: False
# year 2036-Step 19 - Action: 14 - Reward: -0.1509457372558598 - Done: False
# year 2037-Step 20 - Action: 14 - Reward: -0.2017926429366157 - Done: False
# year 2038-Step 21 - Action: 14 - Reward: -0.24291086199624168 - Done: False
# year 2039-Step 22 - Action: 14 - Reward: -0.27470063207368667 - Done: False
# year 2040-Step 23 - Action: 14 - Reward: -0.29762365416474146 - Done: False
# year 2041-Step 24 - Action: 12 - Reward: -0.3121908276106655 - Done: False
# year 2042-Step 25 - Action: 12 - Reward: -0.319430403554799 - Done: False
# year 2043-Step 26 - Action: 12 - Reward: -0.32023666002311546 - Done: False
# year 2044-Step 27 - Action: 12 - Reward: -0.31520939668899683 - Done: False
# year 2045-Step 28 - Action: 12 - Reward: -0.30487761809965486 - Done: False
# year 2046-Step 29 - Action: 12 - Reward: -0.28966951569904476 - Done: False
# year 2047-Step 30 - Action: 12 - Reward: -0.2699610279831399 - Done: False
# year 2048-Step 31 - Action: 12 - Reward: -0.24610600831678875 - Done: False
# year 2049-Step 32 - Action: 12 - Reward: -0.2183985502199992 - Done: False
# year 2050-Step 33 - Action: 12 - Reward: -0.18710794726246704 - Done: False
# year 2051-Step 34 - Action: 12 - Reward: -0.15246224870054004 - Done: False
# year 2052-Step 35 - Action: 12 - Reward: -0.11676401147739601 - Done: False
# year 2053-Step 36 - Action: 12 - Reward: -0.08026665475744821 - Done: False
# year 2054-Step 37 - Action: 12 - Reward: -0.04316660237643544 - Done: False
# year 2055-Step 38 - Action: 12 - Reward: -0.005616029584506466 - Done: False
# year 2056-Step 39 - Action: 12 - Reward: 0.08069436658682261 - Done: False
# year 2057-Step 40 - Action: 12 - Reward: 0.17610540235857286 - Done: False
# year 2058-Step 41 - Action: 12 - Reward: 0.2720928043728227 - Done: False
# year 2059-Step 42 - Action: 12 - Reward: 0.3686161847143543 - Done: False
# year 2060-Step 43 - Action: 12 - Reward: 0.46569507652264586 - Done: False
# year 2061-Step 44 - Action: 12 - Reward: 0.563391303181282 - Done: False
# year 2062-Step 45 - Action: 12 - Reward: 0.6616050464256507 - Done: False
# year 2063-Step 46 - Action: 12 - Reward: 0.7591301279243068 - Done: False
# year 2064-Step 47 - Action: 12 - Reward: 0.8555972746057572 - Done: False
# year 2065-Step 48 - Action: 12 - Reward: 0.9511453091995387 - Done: False
# year 2066-Step 49 - Action: 12 - Reward: 1.0459477463338502 - Done: False
# year 2067-Step 50 - Action: 12 - Reward: 1.1402243264062557 - Done: False
# year 2068-Step 51 - Action: 12 - Reward: 1.2340696071091921 - Done: False
# year 2069-Step 52 - Action: 12 - Reward: 1.3274633457339646 - Done: False
# year 2070-Step 53 - Action: 12 - Reward: 1.4204237419150556 - Done: False
# year 2071-Step 54 - Action: 12 - Reward: 1.5130281295231724 - Done: False
# year 2072-Step 55 - Action: 12 - Reward: 1.6053171902489616 - Done: False
# year 2073-Step 56 - Action: 12 - Reward: 1.6967826017057541 - Done: False
# year 2074-Step 57 - Action: 12 - Reward: 1.7853213038229039 - Done: False
# year 2075-Step 58 - Action: 12 - Reward: 1.871418349550244 - Done: False
# year 2076-Step 59 - Action: 12 - Reward: 1.9555624832531175 - Done: False
# year 2077-Step 60 - Action: 12 - Reward: 2.0382363706765605 - Done: False
# year 2078-Step 61 - Action: 12 - Reward: 2.11991275137387 - Done: False
# year 2079-Step 62 - Action: 12 - Reward: 2.2010475409691392 - Done: False
# year 2080-Step 63 - Action: 12 - Reward: 2.2820781484942323 - Done: False
# year 2081-Step 64 - Action: 12 - Reward: 2.3634179099469326 - Done: False
# year 2082-Step 65 - Action: 12 - Reward: 2.445430585397304 - Done: False
# year 2083-Step 66 - Action: 12 - Reward: 2.528456397509032 - Done: False
# year 2084-Step 67 - Action: 12 - Reward: 2.6128206693288276 - Done: False
# year 2085-Step 68 - Action: 12 - Reward: 2.6988323160394625 - Done: False
# year 2086-Step 69 - Action: 12 - Reward: 2.786782372396948 - Done: False
# year 2087-Step 70 - Action: 12 - Reward: 2.87694425848338 - Done: False
# year 2088-Step 71 - Action: 12 - Reward: 2.969571618409772 - Done: False
# year 2089-Step 72 - Action: 12 - Reward: 3.0648992615810053 - Done: False
# year 2090-Step 73 - Action: 12 - Reward: 0.0 - Done: False
# year 2091-Step 74 - Action: 12 - Reward: 0.0 - Done: False
# year 2092-Step 75 - Action: 1 - Reward: 0.0 - Done: False
# year 2093-Step 76 - Action: 1 - Reward: 0.0 - Done: False
# year 2094-Step 77 - Action: 1 - Reward: 0.0 - Done: False
# year 2095-Step 78 - Action: 1 - Reward: 0.0 - Done: False
# year 2096-Step 79 - Action: 1 - Reward: 0.0 - Done: False
# year 2097-Step 80 - Action: 1 - Reward: 0.0 - Done: False
# year 2098-Step 81 - Action: 1 - Reward: 0.0 - Done: False
# year 2099-Step 82 - Action: 1 - Reward: -10.0 - Done: False
# year 2100-Step 83 - Action: 1 - Reward: -10.0 - Done: True
# Episode ended at step 83 with T_a = 1.158282522511321
# Episode 0 finished with reward-10.0
# Final T_a: 1.158282522511321

# %% [markdown]
# ### 保存整体运行结果

# %%
env_test = IEMEnv(reward_type=custom_reward_type)
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 3 # 结果展示，只有一个 episode 部分
max_steps = 250

# all_episode_rewards = [] # 记录所有 episode 里面的
 
for ep in range(episodes):
    
    ##################################
    # 记录所需数组：每次 episode 重置
    total_action = []
    total_state = []
    total_reward = []
    total_done = []
    ##################################
    # 记录每个 episode 的 reward
    episode_reward = 0
    ##################################
    
    obs, _ = env_test.reset() # 必须的，每次重现一次 ，这里可能就需要固定随机种子了
    done = False
    
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        ##################################
        # 添加转换的部分
        action_number, action_name = IEMEnv.action2number_env(action)
        total_action.append(action_number)
        total_state.append(obs)
        total_reward.append(reward)
        total_done.append(done)
        ##################################
        # 记录每个 episode 的 reward
        episode_reward += reward # TODO：可以放在内容记录 step 部分
        ################################## 
        
        if done:
            print(f"Episode {ep} finished at step {i}")
            break
        
        # # 每10步更新一次图像
        # if ep % 10 == 0:
        #     env_monitor.render()
        #     # plt.pause(0.01)
    
    # all_episode_rewards.append(episode_reward)
    
    env_test.append_data_reward(episode_reward)
    
    save_future_data(env=env_test,custom_reward_type=custom_reward_type,rl_model_name=rl_model_name,network_name=policy_kwargs_diy,episode=ep,total_action=total_action,total_state=total_state,total_reward=total_reward,total_done=total_done,total_timesteps_name=total_timesteps_diy)

    save_plot_NSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    save_plot_SSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    # plot_3D_run(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state)
    
    
    print(f"Episode {ep} finished with reward{episode_reward}")
    
    
plot_data = env_test.get_variables()
plot_episode_reward(plot_data)

# %% [markdown]
# 主要针对可视化显示部分操作

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 绘制只展示一次 episode 结果

# env_test

for episode in range(1):
    obs, _ = env_test.reset() # 这里可能就需要固定随机种子了
    
    done = False
    
    for i in range(251):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        
        if done:
            print(f"Episode {episode} finished at step {i}")
            break
# Out:
# Step 0 - Action: 10 - Reward: 0.0 - Done: False
# Step 1 - Action: 2 - Reward: 0.0 - Done: False
# Step 2 - Action: 2 - Reward: 0.0 - Done: False
# Step 3 - Action: 2 - Reward: 0.0 - Done: False
# Step 4 - Action: 2 - Reward: 0.0 - Done: False
# Step 5 - Action: 10 - Reward: 0.0 - Done: False
# Step 6 - Action: 10 - Reward: 0.0 - Done: False
# Step 7 - Action: 10 - Reward: 2.9817527327879705 - Done: False
# Step 8 - Action: 10 - Reward: 2.5394352004253133 - Done: False
# Step 9 - Action: 10 - Reward: 2.130906595510282 - Done: False
# Step 10 - Action: 10 - Reward: 1.755262221088469 - Done: False
# Step 11 - Action: 10 - Reward: 1.411684889324047 - Done: False
# Step 12 - Action: 10 - Reward: 1.0994313937759403 - Done: False
# Step 13 - Action: 12 - Reward: 0.8177624427786745 - Done: False
# Step 14 - Action: 12 - Reward: 0.5658840172503593 - Done: False
# Step 15 - Action: 12 - Reward: 0.3422317060999186 - Done: False
# Step 16 - Action: 12 - Reward: 0.14475330433349198 - Done: False
# Step 17 - Action: 14 - Reward: -0.01126581947628269 - Done: False
# Step 18 - Action: 14 - Reward: -0.0711891733580261 - Done: False
# Step 19 - Action: 14 - Reward: -0.12214779626588235 - Done: False
# Step 20 - Action: 14 - Reward: -0.16435380704878821 - Done: False
# Step 21 - Action: 14 - Reward: -0.1980191339983417 - Done: False
# Step 22 - Action: 12 - Reward: -0.22351986908641153 - Done: False
# Step 23 - Action: 12 - Reward: -0.2412209431543444 - Done: False
# Step 24 - Action: 12 - Reward: -0.25160172573805095 - Done: False
# Step 25 - Action: 12 - Reward: -0.25561212120273735 - Done: False
# Step 26 - Action: 12 - Reward: -0.25401606134942467 - Done: False
# Step 27 - Action: 12 - Reward: -0.24728240105032273 - Done: False
# Step 28 - Action: 12 - Reward: -0.23584150520555291 - Done: False
# Step 29 - Action: 12 - Reward: -0.22002501455725798 - Done: False
# Step 30 - Action: 12 - Reward: -0.20011924938693193 - Done: False
# Step 31 - Action: 12 - Reward: -0.17641006644478874 - Done: False
# Step 32 - Action: 12 - Reward: -0.14912542047750388 - Done: False
# Step 33 - Action: 12 - Reward: -0.11848152224150921 - Done: False
# Step 34 - Action: 12 - Reward: -0.08465707368290443 - Done: False
# Step 35 - Action: 12 - Reward: -0.04991385368526946 - Done: False
# Step 36 - Action: 12 - Reward: -0.01446847985035693 - Done: False
# Step 37 - Action: 12 - Reward: 0.05378463067301498 - Done: False
# Step 38 - Action: 12 - Reward: 0.14477036527504317 - Done: False
# Step 39 - Action: 12 - Reward: 0.23657807742389902 - Done: False
# Step 40 - Action: 12 - Reward: 0.3290788598161981 - Done: False
# Step 41 - Action: 12 - Reward: 0.4222172506303995 - Done: False
# Step 42 - Action: 12 - Reward: 0.515992214846267 - Done: False
# Step 43 - Action: 12 - Reward: 0.6104555245200594 - Done: False
# Step 44 - Action: 12 - Reward: 0.7056973463003741 - Done: False
# Step 45 - Action: 12 - Reward: 0.801637725329582 - Done: False
# Step 46 - Action: 12 - Reward: 0.8970864382373628 - Done: False
# Step 47 - Action: 12 - Reward: 0.9916860537969835 - Done: False
# Step 48 - Action: 12 - Reward: 1.0855834073191961 - Done: False
# Step 49 - Action: 12 - Reward: 1.1789609602955804 - Done: False
# Step 50 - Action: 12 - Reward: 1.2720415376700074 - Done: False
# Step 51 - Action: 12 - Reward: 1.365054692729356 - Done: False
# Step 52 - Action: 12 - Reward: 1.4579955903563673 - Done: False
# Step 53 - Action: 12 - Reward: 1.550838817739633 - Done: False
# Step 54 - Action: 12 - Reward: 1.6436324263793072 - Done: False
# Step 55 - Action: 12 - Reward: 1.7363794989860986 - Done: False
# Step 56 - Action: 12 - Reward: 1.8285418118882042 - Done: False
# Step 57 - Action: 12 - Reward: 1.9179863064401004 - Done: False
# Step 58 - Action: 12 - Reward: 2.0051717054497153 - Done: False
# Step 59 - Action: 12 - Reward: 2.0905643551243442 - Done: False
# Step 60 - Action: 12 - Reward: 2.1746259429840933 - Done: False
# Step 61 - Action: 12 - Reward: 2.257810803435603 - Done: False
# Step 62 - Action: 12 - Reward: 2.340560055817992 - Done: False
# Step 63 - Action: 12 - Reward: 2.4232967946051924 - Done: False
# Step 64 - Action: 12 - Reward: 2.5064226851810423 - Done: False
# Step 65 - Action: 12 - Reward: 2.590291801101757 - Done: False
# Step 66 - Action: 12 - Reward: 2.6752324206650995 - Done: False
# Step 67 - Action: 12 - Reward: 2.761564375829939 - Done: False
# Step 68 - Action: 12 - Reward: 2.8495871687551606 - Done: False
# Step 69 - Action: 12 - Reward: 2.9395887775961165 - Done: False
# Step 70 - Action: 12 - Reward: 3.031836080072864 - Done: False
# Step 71 - Action: 12 - Reward: 0.0 - Done: False
# Step 72 - Action: 12 - Reward: 0.0 - Done: False
# Step 73 - Action: 12 - Reward: 0.0 - Done: False
# Step 74 - Action: 12 - Reward: 0.0 - Done: False
# Step 75 - Action: 1 - Reward: 0.0 - Done: False
# Step 76 - Action: 1 - Reward: 0.0 - Done: False
# Step 77 - Action: 1 - Reward: 0.0 - Done: False
# Step 78 - Action: 1 - Reward: 0.0 - Done: False
# Step 79 - Action: 1 - Reward: 0.0 - Done: False
# Step 80 - Action: 1 - Reward: 0.0 - Done: False
# Step 81 - Action: 1 - Reward: 0.0 - Done: False
# Step 82 - Action: 1 - Reward: -10.0 - Done: False
# Step 83 - Action: 1 - Reward: -10.0 - Done: True
# Episode 0 finished at step 83

# %% [markdown]
# # 保存运行结果
