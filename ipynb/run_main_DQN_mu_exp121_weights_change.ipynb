# %% [markdown]
# # RL 训练

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import scipy.io
from matplotlib.gridspec import GridSpec
import math
import random
import torch

from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.logger import configure
from stable_baselines3.common.monitor import Monitor
from stable_baselines3 import PPO 
from stable_baselines3 import DQN

# 导入 BaseCallback
from stable_baselines3.common.callbacks import BaseCallback

import sys
import os

# 将 src 目录添加到模块搜索路径
sys.path.append(os.path.abspath('src'))

# 导入 IEMEnv 类
from src.envs.iseec_lx_v4_mdp_plot import IEMEnv
from src.utils.run_debug_plot import save_data 
from src.utils.run_debug_plot import save_plot_NSM_data
from src.utils.run_debug_plot import save_plot_SSM_data

from src.utils.run_debug_plot import save_future_data
from src.utils.run_debug_plot import save_plot_NSM_future_data
from src.utils.run_debug_plot import save_plot_SSM_future_data

from src.utils.run_debug_plot import plot_episode_reward
from src.utils.run_debug_plot import plot_episode_reward_simple
from src.utils.run_debug_plot import plot_3D_run

# %% [markdown]
# 定义保存位置参数
#
# > 所有的关键参数都放在最前面

# %%
# 增加随机种子的定义
def set_global_seed(seed):
    """设置全局随机种子"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# 设置全局种子
# SEED = 42 # 非测试，不指定种子
# set_global_seed(SEED)

# 全新的超参数配置过程，都放在一起
base_config = {
    # MDP 元素
    "custom_reward_type" : "multi_objective_all_T_a_Ca_exp121_weights_change",
    # 环境 & 策略
    "env_id":   "iseec_lx_v4_mdp_plot",
    "rl_model_name": "DQN",
    "policy":   "MlpPolicy",
    "network_name" : "Netxxx_no_big_env",
    # 训练时长
    "total_timesteps_diy": 700000,
    "policy_kwargs_diy" : "dict_pi_vf_default", # for example: policy_kwargs = dict(activation_fn=th.nn.ReLU,net_arch=[256, 256, dict(pi=[128, 64], vf=[128, 64])])
    # 优化器 & 网络
    "hyperparams_diy": "default", 
    # "learning_rate":   3e-4,
    # "ent_coef":        0.0,
    # "batch_size":      64,
    # "n_epochs":        10,
    # 回放 & 更新频率（PPO 固定写法示例）
    # "gamma":           0.99,
    # "clip_range":      0.2,
    # "gae_lambda":      0.95,
    # 随机种子
    "use_random_reset": False, # 是否使用随机重置
    "seed":            42,
}


############### 具体的配置细节##############
# 设置保存的日志名字：
log_name = f'{base_config["env_id"]}_{base_config["rl_model_name"]}_{base_config["custom_reward_type"]}_{int(base_config["total_timesteps_diy"])}_{base_config["hyperparams_diy"]}' 
os.makedirs(f'./logs/{log_name}', exist_ok=True) # 创建日志目录

# 相当于接口部分
custom_reward_type = base_config["custom_reward_type"]
network_name = base_config["network_name"]
rl_model_name = base_config["rl_model_name"]
total_timesteps_diy = base_config["total_timesteps_diy"]
policy_kwargs_diy = base_config["policy_kwargs_diy"] 

# 设置日志保存路径和格式
new_logger = configure(
    f"logs/{log_name}",  # tmp_path 路径保存位置
    # ["stdout",     # 终端输出
    [
     "csv",        # CSV文件
     "tensorboard", # Tensorboard格式
     "json"        # JSON格式
    ]
)

# %% [markdown]
# ### 定义环境

# %%
env = IEMEnv(reward_type=base_config["custom_reward_type"])
env_monitor = Monitor(env, f'./logs/{log_name}')
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# ### 定义算法

# %%
# # 定义模型
# model = PPO(
#     "MlpPolicy", 
#     env_monitor, 
#     # ent_coef=0.01, # 增加策略寻找的鼓励，但是 suggestion 暂时不要改变
#     verbose=1,
#     )

model = DQN(
    "MlpPolicy", 
    env_monitor, 
    verbose=1,
    )

model.set_logger(new_logger) # set the parameter of the logger
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.

# %%
# check 环境
from stable_baselines3.common.env_checker import check_env
# check_env(env_monitor)
log_name

print("Action space sample:", env.action_space.sample())
# print("Observation space sample:", env.observation_space.sample())

# type(env.action_space), type(env.observation_space)
print("Action space sample:", env.action_space.sample())
print("Observation space sample:", env.observation_space.sample())

print(model.policy)
# Out:
# Action space sample: 4
# Action space sample: 9
# Observation space sample: [-0.59822143  1.62256296  0.09904749  0.24962738 -1.18013452 -1.28577724
#   0.79353375 -0.62014401  0.95956839  0.70910717]
# DQNPolicy(
#   (q_net): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=16, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=10, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=64, out_features=16, bias=True)
#     )
#   )
# )

# %% [markdown]
# ### 模型训练

# %%
def plot_callback_reward(metrics):
    """绘制训练过程中的奖励曲线
    
    Args:
        metrics (dict): 包含训练指标的字典，需要包含以下键：
            - rewards: 原始奖励列表
            - moving_avg_rewards: 移动平均奖励列表
            - moving_std_rewards: 移动标准差列表
            - episodes: 总回合数
            - step_idx: 当前步数
    """
    plt.figure(figsize=(20, 5))
    
    # 创建主图
    plt.subplot(131)
    plt.title(f'Step: {metrics["step_idx"]}, Latest reward: {metrics["rewards"][-1]:.2f}\n'
              f'Episode: {metrics["episodes"]}, Moving avg: {metrics["moving_avg_rewards"][-1]:.2f}')
    
    # 绘制原始奖励
    episodes = range(len(metrics["rewards"]))
    plt.plot(episodes, metrics["rewards"], 
             label='Raw rewards', color='gray', alpha=0.3)
    
    # 绘制移动平均
    plt.plot(episodes, metrics["moving_avg_rewards"],
             label='Moving average', color='blue', linewidth=2)
    
    # 添加标准差区域
    moving_avg = np.array(metrics["moving_avg_rewards"])
    moving_std = np.array(metrics["moving_std_rewards"])
    
    # 0.25倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.25 * moving_std,
                    moving_avg + 0.25 * moving_std,
                    color='b', alpha=0.1,
                    label='0.25 std range')
    
    # 0.5倍标准差范围
    plt.fill_between(episodes,
                    moving_avg - 0.5 * moving_std,
                    moving_avg + 0.5 * moving_std,
                    color='b', alpha=0.1,
                    label='0.5 std range')
    
    # 设置坐标轴和标签
    plt.xlabel('Episodes')
    plt.ylabel('Episode Reward')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

class TrainingMonitorCallback(BaseCallback):
    def __init__(self, verbose=1, window_size=50):
        super().__init__(verbose)
        self.window_size = window_size
        # Initialize data dictionary to store metrics
        self.data = {
            "rewards": [],
            "moving_avg_rewards": [],
            "moving_std_rewards": [],
            "episodes": 0,
            "step_idx": 0
        }
        self.episode_rewards = 0
        
    def _on_step(self):
        # Accumulate rewards for current episode
        reward = self.locals.get('rewards')[0]
        self.episode_rewards += reward
        self.data["step_idx"] += 1
        
        # When episode ends, update all metrics
        if self.locals.get('dones')[0]:
            # Store raw reward
            self.data["rewards"].append(self.episode_rewards)
            
            # Calculate moving average and std
            recent_rewards = self.data["rewards"][-self.window_size:]
            moving_avg = np.mean(recent_rewards)
            moving_std = np.std(recent_rewards) if len(recent_rewards) > 1 else 0
            
            # Store calculated metrics
            self.data["moving_avg_rewards"].append(moving_avg)
            self.data["moving_std_rewards"].append(moving_std)
            self.data["episodes"] += 1
            
            # Print progress
            # print(f"Episode {self.data['episodes']} finished with reward: {self.episode_rewards:.2f}")
            # print(f"Moving average (last {len(recent_rewards)} episodes): {moving_avg:.2f} ± {moving_std:.2f}")
            
            # Reset episode rewards
            self.episode_rewards = 0
            
        return True
    
    def get_metrics(self):
        """Return the collected metrics"""
        return self.data
    
# Create callback with custom window size
callback = TrainingMonitorCallback(window_size=50)

# Train the model
model.learn(
    total_timesteps=int(total_timesteps_diy),
    callback=callback,
    log_interval=1
)


# After training, get metrics for plotting
metrics = callback.get_metrics()

# Plot rewards using the plot_callback_reward function
plot_callback_reward(metrics)

# %%
# def plot_smooth_rewards(rewards, window_sizes=[5, 20, 100]):
#     """
#     绘制平滑的奖励曲线
#     Args:
#         rewards: 奖励列表
#         window_sizes: 移动平均窗口大小列表
#     """
#     plt.figure(figsize=(12, 6))
    
#     # 绘制原始奖励
#     plt.plot(rewards, 'lightgray', alpha=0.3, label='Raw rewards')
    
#     # 绘制不同窗口大小的移动平均
#     colors = ['blue', 'green', 'red']
#     for window, color in zip(window_sizes, colors):
#         if len(rewards) >= window:
#             # 计算移动平均
#             smooth_rewards = np.convolve(rewards, 
#                                       np.ones(window)/window, 
#                                       mode='valid')
#             plt.plot(range(window-1, len(rewards)), 
#                     smooth_rewards, 
#                     color=color, 
#                     label=f'{window}-Episode Moving Average',
#                     linewidth=2)
    
#     plt.xlabel('Episode')
#     plt.ylabel('Reward')
#     plt.title('Training Rewards with Different Smoothing Windows')
#     plt.grid(True, alpha=0.3)
#     plt.legend()
#     plt.show()


# # 绘制平滑奖励曲线
# plot_smooth_rewards(metrics["rewards"])

# %% [markdown]
# notes: 如果要训练过程中查看模型，通过 tensorboard 查看

# %%
# 模型保存
model.save(f"./model/{log_name}")

# %% [markdown]
# ### 评估模型训练结果

# %% [markdown]
# > 利用 evaulate policy 函数评估

# %% [markdown]
# # 加载训练好的 RL 模型

# %%
from stable_baselines3.common.evaluation import evaluate_policy
mean_reward, std_reward = evaluate_policy(
    model, 
    model.get_env(), 
    deterministic=True,
    render=True,
    n_eval_episodes=10)

print(mean_reward)
print(std_reward)
# Out:
# c:\Users\14842\.conda\envs\torch_env\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# 29.564193799999998
# 99.29799323804843

# %%
# del model
# model = PPO.load(f"./model/{log_name}", env=env_monitor)
model = DQN.load(f"./model/{log_name}", env=env_monitor)
# Out:
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### 结果展示

# %% [markdown]
# #### 纯净展示版本
#
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 1 # 结果展示，只有一个 episode 部分
max_steps = 250 # 注意内容容易与训练时的 max_steps 混淆

for ep in range(episodes):
    
    obs, _ = env_monitor.reset(use_random_reset=base_config["use_random_reset"], seed=base_config["seed"]) # 必须的，每次重现一次
    
    episode_reward = 0
    done = False
    
     
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_monitor.step(action)
        
        print(f"year {env_monitor.t}-Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        # # 每10步更新一次图像
        # if i == max_steps-1:
        #     env_monitor.render()
            # plt.pause(0.01)
        
        episode_reward += reward
        
        if done:
            print(f"Episode ended at step {i} with T_a = {obs[0]}")
            env_monitor.render()
            plt.show()  # 添加这行来保持图形窗口
            break
        
    print(f"Episode {ep} finished with reward{reward}")
    # 打印 obs 的第一维 T_a 的值
    print(f"Final T_a: {obs[0]}")
# Out:
# year 2017-Step 0 - Action: 11 - Reward: 0 - Done: False
# year 2018-Step 1 - Action: 11 - Reward: 0 - Done: False
# year 2019-Step 2 - Action: 11 - Reward: 0 - Done: False
# year 2020-Step 3 - Action: 11 - Reward: 0 - Done: False
# year 2021-Step 4 - Action: 11 - Reward: 0 - Done: False
# year 2022-Step 5 - Action: 11 - Reward: 6.409967067842233 - Done: False
# year 2023-Step 6 - Action: 11 - Reward: 5.823118759331454 - Done: False
# year 2024-Step 7 - Action: 11 - Reward: 5.225191432522285 - Done: False
# year 2025-Step 8 - Action: 10 - Reward: 4.623548862753608 - Done: False
# year 2026-Step 9 - Action: 10 - Reward: 4.0875503361120495 - Done: False
# year 2027-Step 10 - Action: 10 - Reward: 3.596222763179905 - Done: False
# year 2028-Step 11 - Action: 10 - Reward: 3.167661620463385 - Done: False
# year 2029-Step 12 - Action: 10 - Reward: -0.556037893147072 - Done: False
# year 2030-Step 13 - Action: 10 - Reward: -0.4929026354143796 - Done: False
# c:\Users\14842\.conda\envs\torch_env\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.t to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.t` for environment variables or `env.get_wrapper_attr('t')` that will search the reminding wrappers.
#   logger.warn(
# year 2031-Step 14 - Action: 10 - Reward: -0.444094981228883 - Done: False
# year 2032-Step 15 - Action: 10 - Reward: -0.4130776125471469 - Done: False
# year 2033-Step 16 - Action: 10 - Reward: -0.39468921850712635 - Done: False
# year 2034-Step 17 - Action: 10 - Reward: -0.3895355714544195 - Done: False
# year 2035-Step 18 - Action: 10 - Reward: -0.40516322937448834 - Done: False
# year 2036-Step 19 - Action: 10 - Reward: -0.4303786553975337 - Done: False
# year 2037-Step 20 - Action: 10 - Reward: -0.4709323734111782 - Done: False
# year 2038-Step 21 - Action: 10 - Reward: -0.5207756065665661 - Done: False
# year 2039-Step 22 - Action: 15 - Reward: -0.5791092695610026 - Done: False
# year 2040-Step 23 - Action: 15 - Reward: -0.6320938867142349 - Done: False
# year 2041-Step 24 - Action: 15 - Reward: -0.6808580916953039 - Done: False
# year 2042-Step 25 - Action: 15 - Reward: -0.7179322740071774 - Done: False
# year 2043-Step 26 - Action: 15 - Reward: -0.7495197349946849 - Done: False
# year 2044-Step 27 - Action: 11 - Reward: -0.7762290837614306 - Done: False
# year 2045-Step 28 - Action: 11 - Reward: -0.7977128782644645 - Done: False
# year 2046-Step 29 - Action: 11 - Reward: -0.8140770829228878 - Done: False
# year 2047-Step 30 - Action: 11 - Reward: -0.8260569905042386 - Done: False
# year 2048-Step 31 - Action: 11 - Reward: -0.8343560688214258 - Done: False
# year 2049-Step 32 - Action: 11 - Reward: -0.8394981918772346 - Done: False
# year 2050-Step 33 - Action: 11 - Reward: -0.8419063097414865 - Done: False
# year 2051-Step 34 - Action: 11 - Reward: -0.841518701143957 - Done: False
# year 2052-Step 35 - Action: 11 - Reward: -0.8378767435686345 - Done: False
# year 2053-Step 36 - Action: 11 - Reward: -0.832263653886042 - Done: False
# year 2054-Step 37 - Action: 11 - Reward: -0.8249371039927785 - Done: False
# year 2055-Step 38 - Action: 11 - Reward: -0.8157571824352928 - Done: False
# year 2056-Step 39 - Action: 11 - Reward: -0.8059207472847514 - Done: False
# year 2057-Step 40 - Action: 11 - Reward: -0.7947768730247506 - Done: False
# year 2058-Step 41 - Action: 11 - Reward: -0.7827480552913474 - Done: False
# year 2059-Step 42 - Action: 11 - Reward: -0.7684129380154316 - Done: False
# year 2060-Step 43 - Action: 11 - Reward: -0.7514116173360365 - Done: False
# year 2061-Step 44 - Action: 11 - Reward: -0.7315811355492166 - Done: False
# year 2062-Step 45 - Action: 11 - Reward: -0.7072487124762037 - Done: False
# year 2063-Step 46 - Action: 11 - Reward: -0.6793824522865513 - Done: False
# year 2064-Step 47 - Action: 11 - Reward: -0.6484931028716108 - Done: False
# year 2065-Step 48 - Action: 11 - Reward: -0.6150819892724266 - Done: False
# year 2066-Step 49 - Action: 11 - Reward: -0.5796717166603043 - Done: False
# year 2067-Step 50 - Action: 11 - Reward: -0.5428263826960494 - Done: False
# year 2068-Step 51 - Action: 11 - Reward: -0.5051780745639589 - Done: False
# year 2069-Step 52 - Action: 11 - Reward: -0.4674635589316961 - Done: False
# year 2070-Step 53 - Action: 11 - Reward: -0.43057370503424985 - Done: False
# year 2071-Step 54 - Action: 11 - Reward: -0.39557645500627486 - Done: False
# year 2072-Step 55 - Action: 11 - Reward: -0.36334405951847715 - Done: False
# year 2073-Step 56 - Action: 11 - Reward: -0.33601732659666905 - Done: False
# year 2074-Step 57 - Action: 11 - Reward: -0.3161378216035241 - Done: False
# year 2075-Step 58 - Action: 11 - Reward: -0.30612310571648194 - Done: False
# year 2076-Step 59 - Action: 11 - Reward: -0.30774384967256607 - Done: False
# year 2077-Step 60 - Action: 11 - Reward: -0.3214644017519577 - Done: False
# year 2078-Step 61 - Action: 11 - Reward: -0.3463219626686709 - Done: False
# year 2079-Step 62 - Action: 11 - Reward: -0.380675750908693 - Done: False
# year 2080-Step 63 - Action: 11 - Reward: -0.4223313294311632 - Done: False
# year 2081-Step 64 - Action: 11 - Reward: -0.4694712991054609 - Done: False
# year 2082-Step 65 - Action: 11 - Reward: -0.5207832358489458 - Done: False
# year 2083-Step 66 - Action: 11 - Reward: -0.5751783652273325 - Done: False
# year 2084-Step 67 - Action: 11 - Reward: -0.6318429220839712 - Done: False
# year 2085-Step 68 - Action: 11 - Reward: -0.6901674584741995 - Done: False
# year 2086-Step 69 - Action: 11 - Reward: -0.7496887634395504 - Done: False
# year 2087-Step 70 - Action: 11 - Reward: -0.8100480575269551 - Done: False
# year 2088-Step 71 - Action: 11 - Reward: -0.8709645101495637 - Done: False
# year 2089-Step 72 - Action: 11 - Reward: -0.932213885986636 - Done: False
# year 2090-Step 73 - Action: 11 - Reward: -0.9936219291459603 - Done: False
# year 2091-Step 74 - Action: 11 - Reward: -1.0551388840609528 - Done: False
# year 2092-Step 75 - Action: 10 - Reward: -1.1105247215758944 - Done: False
# year 2093-Step 76 - Action: 11 - Reward: -1.1256174438777424 - Done: False
# year 2094-Step 77 - Action: 11 - Reward: -1.144897488783497 - Done: False
# year 2095-Step 78 - Action: 11 - Reward: -1.16565298646708 - Done: False
# year 2096-Step 79 - Action: 11 - Reward: -1.187569832978011 - Done: False
# year 2097-Step 80 - Action: 11 - Reward: -1.210487060139111 - Done: False
# year 2098-Step 81 - Action: 11 - Reward: -1.2342575833628282 - Done: False
# year 2099-Step 82 - Action: 11 - Reward: -1.2587493267935068 - Done: False
# year 2100-Step 83 - Action: 11 - Reward: -1.283800495663644 - Done: True
# Episode ended at step 83 with T_a = 2.1069757000009974
# Episode 0 finished with reward-1.283800495663644
# Final T_a: 2.1069757000009974

# %% [markdown]
# ### 保存整体运行结果

# %%
env_test = IEMEnv(reward_type=custom_reward_type)
# Out:
# [1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863
#  1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876 1877
#  1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890 1891
#  1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904 1905
#  1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918 1919
#  1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932 1933
#  1934 1935 1936 1937 1938 1939 1940 1941 1942 1943 1944 1945 1946 1947
#  1948 1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045
#  2046 2047 2048 2049 2050 2051 2052 2053 2054 2055 2056 2057 2058 2059
#  2060 2061 2062 2063 2064 2065 2066 2067 2068 2069 2070 2071 2072 2073
#  2074 2075 2076 2077 2078 2079 2080 2081 2082 2083 2084 2085 2086 2087
#  2088 2089 2090 2091 2092 2093 2094 2095 2096 2097 2098 2099 2100]

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 运行中绘制的图
episodes = 3 # 结果展示，只有一个 episode 部分
max_steps = 250

# all_episode_rewards = [] # 记录所有 episode 里面的
 
for ep in range(episodes):
    
    ##################################
    # 记录所需数组：每次 episode 重置
    total_action = []
    total_state = []
    total_reward = []
    total_done = []
    ##################################
    # 记录每个 episode 的 reward
    episode_reward = 0
    ##################################
    
    obs, _ = env_test.reset() # 必须的，每次重现一次 ，这里可能就需要固定随机种子了
    done = False
    
    for i in range(max_steps):
        # action = env_monitor.action_space.sample()
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        # print(f"Info: {info['state_values']['T_a']}")
        
        ##################################
        # 添加转换的部分
        action_number, action_name = IEMEnv.action2number_env(action)
        total_action.append(action_number)
        total_state.append(obs)
        total_reward.append(reward)
        total_done.append(done)
        ##################################
        # 记录每个 episode 的 reward
        episode_reward += reward # TODO：可以放在内容记录 step 部分
        ################################## 
        
        if done:
            print(f"Episode {ep} finished at step {i}")
            break
        
        # # 每10步更新一次图像
        # if ep % 10 == 0:
        #     env_monitor.render()
        #     # plt.pause(0.01)
    
    # all_episode_rewards.append(episode_reward)
    
    env_test.append_data_reward(episode_reward)
    
    save_future_data(env=env_test,custom_reward_type=custom_reward_type,rl_model_name=rl_model_name,network_name=policy_kwargs_diy,episode=ep,total_action=total_action,total_state=total_state,total_reward=total_reward,total_done=total_done,total_timesteps_name=total_timesteps_diy)

    save_plot_NSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    save_plot_SSM_future_data(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state, total_timesteps_diy)
    
    # plot_3D_run(env_test, custom_reward_type, rl_model_name, policy_kwargs_diy, ep, total_action, total_state)
    
    
    print(f"Episode {ep} finished with reward{episode_reward}")
    
    
plot_data = env_test.get_variables()
plot_episode_reward(plot_data)

# %% [markdown]
# 主要针对可视化显示部分操作

# %% [markdown]
# 这里可能就需要固定随机种子了

# %%
# 绘制只展示一次 episode 结果

# env_test

for episode in range(1):
    obs, _ = env_test.reset() # 这里可能就需要固定随机种子了
    
    done = False
    
    for i in range(251):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, _, info = env_test.step(action)
        
        print(f"Step {i} - Action: {action} - Reward: {reward} - Done: {done}")
        
        if done:
            print(f"Episode {episode} finished at step {i}")
            break
# Out:
# Step 0 - Action: 10 - Reward: 0 - Done: False
# Step 1 - Action: 10 - Reward: 0 - Done: False
# Step 2 - Action: 10 - Reward: 0 - Done: False
# Step 3 - Action: 10 - Reward: 0 - Done: False
# Step 4 - Action: 10 - Reward: 0 - Done: False
# Step 5 - Action: 10 - Reward: 0 - Done: False
# Step 6 - Action: 10 - Reward: 0 - Done: False
# Step 7 - Action: 10 - Reward: 0 - Done: False
# Step 8 - Action: 10 - Reward: 4.645197965282029 - Done: False
# Step 9 - Action: 10 - Reward: 4.433506021461244 - Done: False
# Step 10 - Action: 10 - Reward: 4.284311644375087 - Done: False
# Step 11 - Action: 10 - Reward: 4.196873973700877 - Done: False
# Step 12 - Action: 10 - Reward: 4.173068118311125 - Done: False
# Step 13 - Action: 10 - Reward: 4.207691871839521 - Done: False
# Step 14 - Action: 10 - Reward: 4.299782224631377 - Done: False
# Step 15 - Action: 10 - Reward: -0.883775421657756 - Done: False
# Step 16 - Action: 10 - Reward: -0.9146570805614894 - Done: False
# Step 17 - Action: 10 - Reward: -0.9503604349811225 - Done: False
# Step 18 - Action: 10 - Reward: -0.9902913580663345 - Done: False
# Step 19 - Action: 10 - Reward: -1.0333150005260592 - Done: False
# Step 20 - Action: 15 - Reward: -1.0784771100851294 - Done: False
# Step 21 - Action: 15 - Reward: -1.1178254229276716 - Done: False
# Step 22 - Action: 11 - Reward: -1.15462914582538 - Done: False
# Step 23 - Action: 11 - Reward: -1.1884625082670115 - Done: False
# Step 24 - Action: 11 - Reward: -1.220272465085555 - Done: False
# Step 25 - Action: 11 - Reward: -1.2388365737189582 - Done: False
# Step 26 - Action: 11 - Reward: -1.2515488563686357 - Done: False
# Step 27 - Action: 11 - Reward: -1.259845545444826 - Done: False
# Step 28 - Action: 11 - Reward: -1.2646280517271917 - Done: False
# Step 29 - Action: 11 - Reward: -1.265770747913467 - Done: False
# Step 30 - Action: 11 - Reward: -1.26356104208475 - Done: False
# Step 31 - Action: 11 - Reward: -1.2590434572959 - Done: False
# Step 32 - Action: 11 - Reward: -1.252780637150277 - Done: False
# Step 33 - Action: 11 - Reward: -1.2448543876730709 - Done: False
# Step 34 - Action: 11 - Reward: -1.2350402258866227 - Done: False
# Step 35 - Action: 11 - Reward: -1.22397065686876 - Done: False
# Step 36 - Action: 11 - Reward: -1.2116914862132409 - Done: False
# Step 37 - Action: 11 - Reward: -1.1983193767676992 - Done: False
# Step 38 - Action: 11 - Reward: -1.184183493600016 - Done: False
# Step 39 - Action: 11 - Reward: -1.1695410839086717 - Done: False
# Step 40 - Action: 11 - Reward: -1.1538696281233787 - Done: False
# Step 41 - Action: 11 - Reward: -1.139112615136588 - Done: False
# Step 42 - Action: 11 - Reward: -1.1243262822501505 - Done: False
# Step 43 - Action: 11 - Reward: -1.1092747727185426 - Done: False
# Step 44 - Action: 11 - Reward: -1.091671238656866 - Done: False
# Step 45 - Action: 11 - Reward: -1.0701075472576331 - Done: False
# Step 46 - Action: 11 - Reward: -1.0446120339654592 - Done: False
# Step 47 - Action: 11 - Reward: -1.0157586540962102 - Done: False
# Step 48 - Action: 11 - Reward: -0.9839216273533226 - Done: False
# Step 49 - Action: 11 - Reward: -0.9494467430179775 - Done: False
# Step 50 - Action: 11 - Reward: -0.9126647065970336 - Done: False
# Step 51 - Action: 11 - Reward: -0.8738944511925392 - Done: False
# Step 52 - Action: 11 - Reward: -0.8334470250376828 - Done: False
# Step 53 - Action: 11 - Reward: -0.7916298765354849 - Done: False
# Step 54 - Action: 11 - Reward: -0.7487019282089894 - Done: False
# Step 55 - Action: 11 - Reward: -0.7041958299712857 - Done: False
# Step 56 - Action: 11 - Reward: -0.6586623949543442 - Done: False
# Step 57 - Action: 11 - Reward: -0.6126133978745552 - Done: False
# Step 58 - Action: 11 - Reward: -0.5665688673965514 - Done: False
# Step 59 - Action: 11 - Reward: -0.5211443165321695 - Done: False
# Step 60 - Action: 11 - Reward: -0.4770923638589897 - Done: False
# Step 61 - Action: 11 - Reward: -0.43536300521038557 - Done: False
# Step 62 - Action: 11 - Reward: -0.3971698081421541 - Done: False
# Step 63 - Action: 11 - Reward: -0.36376353529234207 - Done: False
# Step 64 - Action: 11 - Reward: -0.33741699712282175 - Done: False
# Step 65 - Action: 11 - Reward: -0.3200469470745136 - Done: False
# Step 66 - Action: 11 - Reward: -0.3134136244912737 - Done: False
# Step 67 - Action: 11 - Reward: -0.3183470158583383 - Done: False
# Step 68 - Action: 11 - Reward: -0.33439762442154763 - Done: False
# Step 69 - Action: 11 - Reward: -0.3600671209650199 - Done: False
# Step 70 - Action: 11 - Reward: -0.3934048162225644 - Done: False
# Step 71 - Action: 11 - Reward: -0.43252803537581935 - Done: False
# Step 72 - Action: 11 - Reward: -0.4758720719526214 - Done: False
# Step 73 - Action: 11 - Reward: -0.5222341628165741 - Done: False
# Step 74 - Action: 11 - Reward: -0.570791379495721 - Done: False
# Step 75 - Action: 11 - Reward: -0.6208278602836615 - Done: False
# Step 76 - Action: 11 - Reward: -0.6717975921589591 - Done: False
# Step 77 - Action: 11 - Reward: -0.7233217844267116 - Done: False
# Step 78 - Action: 11 - Reward: -0.7751263422403267 - Done: False
# Step 79 - Action: 11 - Reward: -0.8269969413996314 - Done: False
# Step 80 - Action: 11 - Reward: -0.8787232198777205 - Done: False
# Step 81 - Action: 11 - Reward: -0.9301861921406903 - Done: False
# Step 82 - Action: 11 - Reward: -0.9813563297462149 - Done: False
# Step 83 - Action: 11 - Reward: -1.032247109222709 - Done: True
# Episode 0 finished at step 83

# %% [markdown]
# # 保存运行结果
