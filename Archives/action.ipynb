# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# 构造一个 16×4 的 DataFrame
df = pd.DataFrame([[int(b) for b in f"{k:04b}"] for k in range(16)],
                  columns=["社会↑","可再生↑","ACE↑","投资↑"])
sns.heatmap(df, cmap=["#fff","#2c7bb6"], linecolor="gray", linewidths=0.5,
            yticklabels=[f"{k}" for k in range(16)])
plt.ylabel("动作编号")
plt.xlabel("杠杆加速")
# Out:
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 31038 (\N{CJK UNIFIED IDEOGRAPH-793E}) missing from current font.
#   fig.canvas.draw()
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 20250 (\N{CJK UNIFIED IDEOGRAPH-4F1A}) missing from current font.
#   fig.canvas.draw()
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 21487 (\N{CJK UNIFIED IDEOGRAPH-53EF}) missing from current font.
#   fig.canvas.draw()
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 20877 (\N{CJK UNIFIED IDEOGRAPH-518D}) missing from current font.
#   fig.canvas.draw()
# c:\Users\peter\.conda\envs\torch_env\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 29983 (\N{CJK UNIFIED IDEOGRAPH-751F}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define temperature range
T_a = np.linspace(0, 3, 300)

# Parameters for piecewise function
T_thresh = 1.5     # threshold for piecewise
R_thresh = -100    # reward at the threshold
alpha = 3.0        # shape parameter for the exponential part
linear_rate = 100  # additional penalty per unit above threshold

# Compute reward: exponential approach to R_thresh for Ta <= T_thresh,
# linear decrease beyond.
reward = np.where(
    T_a <= T_thresh,
    R_thresh * (1 - np.exp(-alpha * T_a)) / (1 - np.exp(-alpha * T_thresh)),
    R_thresh - linear_rate * (T_a - T_thresh)
)

# Plotting
plt.figure(figsize=(6, 4))
plt.plot(T_a, reward)
plt.xlabel(r'$T_a$ (°C)')
plt.ylabel('Reward')
plt.title('Piecewise Exponential then Linear Reward Function')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define temperature range
T_a = np.linspace(0, 3, 300)

# Compute reward according to piecewise function
# reward = np.where(
#     T_a <= 1.5,
#     -0.1 * (np.exp(5 * (T_a - 1.5)) - 1.0),  # exponential small penalty
#     -10 * (T_a - 1.5)                        # linear large penalty
# )

reward = -0.1 * (np.exp(5 * (T_a - 1.5)) - 10)
# Plotting
plt.plot(T_a, reward)
plt.xlabel(r'$T_a$ (°C)')
plt.ylabel('Reward')
plt.title('Reward as a Function of Temperature $T_a$')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define temperature range
T_a = np.linspace(0, 3, 300)

# Compute reward according to piecewise function
# reward = np.where(
#     T_a <= 1.5,
#     -0.1 * (np.exp(5 * (T_a - 1.5)) - 1.0),  # exponential small penalty
#     -10 * (T_a - 1.5)                        # linear large penalty
# )

reward = -0.1 * (np.exp(5 * (T_a - 1.5)) - 10)
# Plotting
plt.plot(T_a, reward)
plt.xlabel(r'$T_a$ (°C)')
plt.ylabel('Reward')
plt.title('Reward as a Function of Temperature $T_a$')
plt.grid(True)
plt.show()
